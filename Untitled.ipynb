# %%
import pandas as pd
import numpy as np

# %%
data = open("2023/data2023.txt").read().split("\n\n")
data = [[y for y in x.split("\n") if y != "" and "Logo" not in y] for x in data if x != ""]
bad = [[len(x),x] for x in data if len(x) != 22]
good2023 = [x for x in data if len(x) == 22]
len(good2023)

data = open("2024/data2024.txt").read().split("\n\n")
data = [[y for y in x.split("\n") if y != "" and "Logo" not in y] for x in data if x != ""]
bad = [[len(x),x] for x in data if len(x) != 22]
good2024 = [x for x in data if len(x) == 22]
len(good2024)

labels = ["organization name","num employees", "founded date","description","industries","headquarters location","description","cb rank","postal code","headquarters region","website","actively hiring","linkedin","num articles","email","hub tag","phone num","num of sub org","industry groups","total funding amt","company type","estimated rev"]
dataset = good2023 + good2024
df = pd.DataFrame(dataset,columns=labels)

# %%
df[df["num employees"]=="11-50"]
# Out:
#      organization name num employees  founded date  \
# 981         Mistral AI         11-50          2023
# 982             Sierra         11-50          2023
# 983       Essential AI         11-50          2023
# 984              Lindy         11-50          2023
# 985           Poolside         11-50          2023
# ...                ...           ...           ...
# 5217       Go To Groww         11-50  May 15, 2024
# 5235          Vison AI         11-50  May 27, 2024
# 5238          Sagui.AI         11-50  May 28, 2024
# 5240           Cybrius         11-50  May 29, 2024
# 5248           Solatis         11-50   Jun 5, 2024
#
#                                             description  \
# 981   Mistral AI is an AI startup that provides deve...
# 982   Sierra is an AI startup that tackles essential...
# 983   Essential AI creates AI solutions that enhance...
# 984   Lindy is an AI assistant that can help with al...
# 985   Poolside is an artificial intelligence platfor...
# ...                                                 ...
# 5217  Our expert marketing team specializes in bespo...
# 5235  Vison is an innovative content writing tool th...
# 5238  Sagui AI is an all-in-one solution that can ge...
# 5240  Welcome to Cybrius, A groundbreaking tech comp...
# 5248  Solatis is an innovative AI technology tool de...
#
#                                              industries  \
# 981   Artificial Intelligence (AI), Generative AI, M...
# 982   Artificial Intelligence (AI), Enterprise Softw...
# 983   Artificial Intelligence (AI), Information Tech...
# 984   Artificial Intelligence (AI), Internet, Softwa...
# 985   Artificial Intelligence (AI), Developer Platfo...
# ...                                                 ...
# 5217  Advertising, App Marketing, Brand Marketing, C...
# 5235  Artificial Intelligence (AI), Content, Content...
# 5238  Artificial Intelligence (AI), Content Marketin...
# 5240                             Information Technology
# 5248  Artificial Intelligence (AI), Information Tech...
#
#                           headquarters location  \
# 981                Paris, Ile-de-France, France
# 982    San Francisco, California, United States
# 983    San Francisco, California, United States
# 984    San Francisco, California, United States
# 985                Paris, Ile-de-France, France
# ...                                         ...
# 5217                Noida, Uttar Pradesh, India
# 5235            Portland, Oregon, United States
# 5238                                          —
# 5240  Amsterdam, Noord-Holland, The Netherlands
# 5248          New York, New York, United States
#
#                                             description  cb rank postal code  \
# 981   Mistral AI is an AI startup that provides deve...        7       75001
# 982   Sierra is an AI startup that tackles essential...      259           —
# 983   Essential AI creates AI solutions that enhance...      321           —
# 984                        Your AI executive assistant.      599           —
# 985   Poolside is an artificial intelligence platfor...      924           —
# ...                                                 ...      ...         ...
# 5217  Go To Groww is a Full-Service AI-based Digital...        —      201307
# 5235  Vison multi-skilled AI is developed for Indivi...        —       97214
# 5238  The AI-powered website builder that generates ...        —           —
# 5240                            Artificial Intelligence        —           —
# 5248  Solatis is an AI technology workforce tool tha...  370,592           —
#
#                                     headquarters region  ...  \
# 981   European Union (EU), Europe, Middle East, and ...  ...
# 982      San Francisco Bay Area, West Coast, Western US  ...
# 983      San Francisco Bay Area, West Coast, Western US  ...
# 984      San Francisco Bay Area, West Coast, Western US  ...
# 985   European Union (EU), Europe, Middle East, and ...  ...
# ...                                                 ...  ...
# 5217                                Asia-Pacific (APAC)  ...
# 5235                             West Coast, Western US  ...
# 5238                                                  —  ...
# 5240  European Union (EU), Europe, Middle East, and ...  ...
# 5248  Greater New York Area, East Coast, Northeaster...  ...
#
#               linkedin num articles                  email     hub tag  \
# 981   View on LinkedIn          113     contact@mistral.ai           —
# 982   View on LinkedIn            3                      —           —
# 983   View on LinkedIn           17                      —           —
# 984   View on LinkedIn            1         lindy@lindy.ai  6048488619
# 985   View on LinkedIn            5                      —           —
# ...                ...          ...                    ...         ...
# 5217  View on LinkedIn            3  connect@gotogroww.com           —
# 5235  View on LinkedIn            —  info@infiniticube.com           —
# 5238  View on LinkedIn            —         fabio@sagui.ai           —
# 5240                 —            —     info@cybriusai.com           —
# 5248                 —            —       david@solatis.io           —
#
#             phone num num of sub org  \
# 981           Unicorn              —
# 982                 —              —
# 983                 —              —
# 984                 —              —
# 985                 —              —
# ...               ...            ...
# 5217      09289497982              —
# 5235  +1 415-800-2907              —
# 5238                —              —
# 5240                —              —
# 5248     201-329-4395              —
#
#                                         industry groups total funding amt  \
# 981   Artificial Intelligence (AI), Data and Analyti...    €1,105,000,000
# 982   Artificial Intelligence (AI), Data and Analyti...      $110,000,000
# 983   Artificial Intelligence (AI), Data and Analyti...       $64,500,000
# 984   Apps, Artificial Intelligence (AI), Data and A...       $49,900,000
# 985   Artificial Intelligence (AI), Data and Analyti...      $126,000,000
# ...                                                 ...               ...
# 5217                   Advertising, Sales and Marketing                 —
# 5235  Artificial Intelligence (AI), Data and Analyti...                 —
# 5238  Artificial Intelligence (AI), Data and Analyti...                 —
# 5240                             Information Technology                 —
# 5248  Apps, Artificial Intelligence (AI), Data and A...                 —
#
#      company type estimated rev
# 981    For Profit             —
# 982             —             —
# 983    For Profit             —
# 984    For Profit   $1M to $10M
# 985    For Profit             —
# ...           ...           ...
# 5217   For Profit             —
# 5235   For Profit             —
# 5238   For Profit             —
# 5240   For Profit             —
# 5248   For Profit             —
#
# [881 rows x 22 columns]

# %%
df['description_all'] = df['description'].iloc[:,0] + " " + df['description'].iloc[:,1]

# %%
def generate_embed

# %%
df["num employees"]
# Out:
# 0        1-10
# 1        1-10
# 2        1-10
# 3        1-10
# 4        1-10
#         ...
# 5248    11-50
# 5249     1-10
# 5250     1-10
# 5251     1-10
# 5252     1-10
# Name: num employees, Length: 5253, dtype: object
