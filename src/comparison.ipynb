# %%
import nest_asyncio
import aiohttp
import asyncio
import nest_asyncio
import re
import time
import pandas as pd
import numpy as np
from dotenv import load_dotenv
import os
from os import getenv
from openai import OpenAI
import pathlib
import textwrap
# import google.generativeai as genai
import time
import requests
import ast
import json
from sklearn.metrics.pairwise import cosine_similarity
import re
from llms import chatGPT
from llms import gemini


x_chat = chatGPT()
x_gemini = gemini()
nest_asyncio.apply()

df_exp = pd.read_csv('../input/gpts_labels/gpt_exposure_embeddings.csv')

df_exp.task_embedding = df_exp.task_embedding.apply(lambda x: x.strip("[]").split(", "))

task_embeddings = []
for x in df_exp.task_embedding:
    task_embeddings.append([float(y) for y in x])
df_exp.task_embedding = task_embeddings


task_embeddings = np.array(task_embeddings)
task_embeddings = np.vstack(task_embeddings)

# %%
class prompting():
    def __init__(self):
        self.results_df = pd.DataFrame(columns=["organization name", "value"])

    def set_current_results_df(self, results_df):
        self.results_df = results_df

    async def iterate(self, df, prompt_template, args, value, batch_size=10, start=0, end=False):
        if end == False:
            end = len(df)
        self.results_df = pd.DataFrame(columns=["organization name", value])
        if value in list(df.columns):
            if start != 0:
                self.results_df = pd.concat([df[["organization name", value]].iloc[:start], self.results_df], axis=0)
            df = df.drop(columns=[value])

        batch_prompts = []
        batch_indices = []

        for i, row in list(df.iterrows())[start:end]:
            name = row['organization name']
            website = row['website']
            prompt = prompt_template

            for arg in args:
                prompt = prompt.replace(f"${arg[0]}", row[arg[1]])

            batch_prompts.append((i, name, prompt))
            batch_indices.append(i)

            if len(batch_prompts) >= batch_size:
                await self.process_batch(batch_prompts)
                batch_prompts = []

        if batch_prompts:
            await self.process_batch(batch_prompts)
            self.results_df.to_csv("../output/current_results_df_prompting.csv")

        df = df.merge(self.results_df, on='organization name', how='left')
        return df

    async def process_batch(self, batch_prompts):
        async with aiohttp.ClientSession() as session:
            tasks = []
            for i, name, prompt in batch_prompts:
                tasks.append(self.fetch_result(session, i, name, prompt))
            await asyncio.gather(*tasks)

    async def fetch_result(self, session, i, name, prompt):
        failure_count = 0
        while True:
            try:
                print(f"******************************\nProcessing {i}: {name}")
                result = await x_gemini.ask(session, prompt)
                if result == "N/A": break  # explicit material

                text = re.sub(r"#|#\s+|_|\*", "", result).strip()

                self.results_df.loc[i] = [name, text]

                    
                break
            except Exception as e:
                print(failure_count)
                failure_count += 1
                if failure_count > 10:
                    break
                print(f"Error processing {i}, {name}: {e}")
                await asyncio.sleep(20)

prompting_class = prompting()

# %%
# df2 = pd.read_csv('../output/df_with_parsed_description.csv').iloc[:10]
# df2["Task"] = (df2["Customers"] + " that do " + df2["Tasks/Jobs"]).values
df = pd.read_csv('../output/results/df_with_parsed_description.csv')
df["Task"] = (df["Customers"] + " that do " + df["Tasks/Jobs"]) + " for " + df["Industry"] .values
df = df.sample(800, random_state=2).reset_index(drop=True)

# %%
df.head()
# Out:
#     organization name                website  \
# 0  Divergence Academy        divergence.one/
# 1      Descartes Labs  www.descarteslabs.com
# 2              Qelzal        www.qelzal.com/
# 3       Beyond Limits         www.beyond.ai/
# 4                 RAI        www.rai-inc.com
#
#                                      description_all founded date  \
# 0  Divergence Academy empowers the next generatio...   2014-01-01
# 1  Enabling a better understanding of the physica...   2014-01-01
# 2  Next Generation Obstacle Avoidance for Commerc...   2014-01-01
# 3  Beyond Limits is an industrial and enterprise-...   2014-01-01
# 4  RAI is a mixed reality, generative AI, metaver...   2023-04-04
#
#                            generated_description_llm  \
# 0  Description (in two sentences): Divergence Aca...
# 1  Description (in two sentences): Descartes Labs...
# 2  Here's a description and confidence rating for...
# 3  Description (in two sentences):\n\nBeyond Limi...
# 4  Description (in two sentences):\n\nRAI special...
#
#                                generated_description  \
# 0  Divergence Academy offers online courses and b...
# 1  Descartes Labs offers a SaaS platform that ana...
# 2  Qelzal develops advanced obstacle avoidance sy...
# 3  Beyond Limits is an AI technology company focu...
# 4  RAI specializes in developing mixed reality, g...
#
#    generated_description_conf_interval  \
# 0                                    7
# 1                                    9
# 2                                    8
# 3                                    7
# 4                                    7
#
#        generated_description_conf_interval_reasoning  \
# 0  The website provides limited information about...
# 1  The provided description is clear and accurate...
# 2  The provided information on their website give...
# 3  While the provided information is quite detail...
# 4  The website provides a high-level overview of ...
#
#                               parsed_description_llm  \
# 0  Divergence Academy Analysis\n\nTasks/Jobs: Eth...
# 1  Descartes Labs\n\nTasks/Jobs: Geospatial data ...
# 2  Qelzal Analysis\n\nTasks/Jobs: Obstacle avoida...
# 3  Beyond Limits Analysis\n\nTasks/Jobs: Operatio...
# 4  RAI Analysis\n\nTasks/Jobs:  XR/MR development...
#
#                                   parsed_description  \
# 0  Tasks/Jobs: Ethical hacking, data analysis, ma...
# 1  Tasks/Jobs: Geospatial data analysis, Earth ob...
# 2  Tasks/Jobs: Obstacle avoidance, Object detecti...
# 3  Tasks/Jobs: Operations optimization, Decision ...
# 4  Tasks/Jobs: XR/MR development, AI model develo...
#
#                                           Tasks/Jobs  \
# 0  Ethical hacking, data analysis, machine learni...
# 1  Geospatial data analysis, Earth observation in...
# 2  Obstacle avoidance, Object detection, Navigati...
# 3  Operations optimization, Decision support, Pre...
# 4  XR/MR development, AI model development, Metav...
#
#                                             Industry  \
# 0             Education, Cybersecurity, Data Science
# 1  Environmental science, Agriculture, Energy, Fi...
# 2               Drone technology, Autonomous systems
# 3             Energy, Utilities, Healthcare, Finance
# 4          XR/MR, AI, Metaverse, Media and Streaming
#
#                                            Customers  \
# 0  Students, aspiring professionals, cybersecurit...
# 1  Researchers, Farmers, Energy companies, Financ...
# 2  Drone operators, Drone delivery services, Aeri...
# 3  Operations managers, C-suite executives, Data ...
# 4  Software developers, Media companies, Healthca...
#
#    parsed_description_conf_interval  \
# 0                                 8
# 1                                 9
# 2                                 9
# 3                                 9
# 4                                 9
#
#           parsed_description_conf_interval_reasoning  \
# 0  The website and description clearly indicate t...
# 1  The company's description explicitly mentions ...
# 2  The description clearly focuses on drone safet...
# 3  The company's focus on "Cognitive AI solutions...
# 4  The provided description explicitly details RA...
#
#                                                 Task
# 0  Students, aspiring professionals, cybersecurit...
# 1  Researchers, Farmers, Energy companies, Financ...
# 2  Drone operators, Drone delivery services, Aeri...
# 3  Operations managers, C-suite executives, Data ...
# 4  Software developers, Media companies, Healthca...

# %%
pre.Industry
# Out:
# 3                 Energy, Utilities, Healthcare, Finance
# 12                                    Financial services
# 13                Market Research, Business Intelligence
# 24                      Intellectual Property Management
# 29                              Data Science & Analytics
#                              ...
# 787              Sports analytics, Sports betting, Media
# 791    Marketing technology, Customer relationship ma...
# 796               Financial services, Energy, Industrial
# 797                                            Insurance
# 799              Collaboration tools, Project management
# Name: Industry, Length: 122, dtype: object

# %%
words = ["decision", "automate", "workflow","task", "generate"]

# Create regex pattern
pattern = '|'.join(words)

# Filter the dataframe
df = df[df["generated_description"].str.contains(pattern, case=False, na=False)]

# %%
pre = df[pd.to_datetime(df['founded date'])<'11/30/2022']
post = df[pd.to_datetime(df['founded date'])>='11/30/2022']
len(pre)
# Out:
# 122

# %%
for x in range(10):
    print(df["Task"].iloc[x])
# Out:
# Students, aspiring professionals, cybersecurity professionals, data scientists that do Ethical hacking, data analysis, machine learning, software development for Education, Cybersecurity, Data Science
# Researchers, Farmers, Energy companies, Financial institutions, Government agencies that do Geospatial data analysis, Earth observation interpretation, Predictive modeling, Risk assessment for Environmental science, Agriculture, Energy, Finance, Government
# Drone operators, Drone delivery services, Aerial mapping companies that do Obstacle avoidance, Object detection, Navigation, Flight control for Drone technology, Autonomous systems
# Operations managers, C-suite executives, Data analysts that do Operations optimization, Decision support, Predictive analytics, Risk assessment for Energy, Utilities, Healthcare, Finance
# Software developers, Media companies, Healthcare providers, Game developers, Enterprise businesses that do XR/MR development, AI model development, Metaverse platform creation, Generative AI content creation for XR/MR, AI, Metaverse, Media and Streaming
# Businesses of all sizes, Financial institutions, Online marketplaces, Payment processors that do Identity verification, Fraud detection, AML monitoring, Customer onboarding for Financial services, Fintech
# Farmers, Agribusinesses, Crop consultants that do Crop health monitoring, Soil analysis, Irrigation optimization, Yield prediction for Agriculture
# Finance professionals, Legal professionals, Real estate professionals, Business owners that do Contract abstraction, Payment and amortization calculations, Critical alerts, Data analysis for Financial Services, Real Estate
# Business owners, Data scientists, Software developers that do AI model development, ML model training, Data preparation, Software consulting for Software development, Artificial intelligence, Machine learning
# Banks, Financial institutions that do Risk assessment, Compliance monitoring, Regulatory reporting, Fraud detection for Financial Services

# %%
df['new Task'] = df['new Task'].replace('"', '', regex=True)

# %%
df = x_chat.run_batch_embeddings(df,'Task')
# Out:
# Processing batch 0 to 199
# Processing batch 200 to 399
# Processing batch 400 to 599
# Processing batch 600 to 799

# %%
df["Task"].iloc[0]
# Out:
# 'Students, aspiring professionals, cybersecurity professionals, data scientists that do Ethical hacking, data analysis, machine learning, software development for Education, Cybersecurity, Data Science'

# %%
results = []
for index, row in list(df.iterrows())[0:]:
    print("***********************")
    print(f"Processing {index}")
    name = row["organization name"]
    date = row["founded date"]
    customers = row["Customers"]
    print(name, date, customers)
    print(row["generated_description"])

    job_embedding = np.array(row["Task_embedding"]).reshape(1,-1)
    cosine_sim = cosine_similarity(job_embedding, task_embeddings)
    top3 = list(sorted(zip(cosine_sim[0], df_exp[['description']].values), reverse=True))[0]
    print(top3)
    results.append([name, date, top3[0],top3[1][0]])

onet_df = pd.DataFrame(results,columns = ["organization name", "founded date", "cosine similarity", "description"])
# Out:
# ***********************
# Processing 0
# Divergence Academy 2014-01-01 Students, aspiring professionals, cybersecurity professionals, data scientists
# Divergence Academy offers online courses and bootcamps in ethical hacking, data science, and machine learning. Their curriculum is designed to equip students with the skills and knowledge needed to succeed in these rapidly growing fields.
# (np.float64(0.5099267402052063), array(['Penetration testers that develop presentations on threat intelligence.'],
#       dtype=object))
# ***********************
# Processing 1
# Descartes Labs 2014-01-01 Researchers, Farmers, Energy companies, Financial institutions, Government agencies
# Descartes Labs offers a SaaS platform that analyzes geospatial data at scale, providing insights for various industries like commodity sourcing, resource exploration, and climate resilience. Their technology helps organizations understand the physical world better by leveraging earth observation data.
# (np.float64(0.5968542240937567), array(['Remote sensing scientists and technologists that use remote sensing data for forest or carbon tracking activities to assess the impact of environmental change.'],
#       dtype=object))
# ***********************
# Processing 2
# Qelzal 2014-01-01 Drone operators, Drone delivery services, Aerial mapping companies
# Qelzal develops advanced obstacle avoidance systems for commercial drones, enhancing their autonomy and safety during low-altitude flights. Their technology uses brain-inspired engineering, deep learning, and machine learning to create a robust and adaptable obstacle detection system.
# (np.float64(0.4755814817937498), array(['Robotics engineers that design robotic systems, such as automatic vehicle control, autonomous vehicles, advanced displays, advanced sensing, robotic platforms, computer vision, or telematics systems.'],
#       dtype=object))
# ***********************
# Processing 3
# Beyond Limits 2014-01-01 Operations managers, C-suite executives, Data analysts
# Beyond Limits is an AI technology company focused on developing Cognitive AI solutions for demanding industries like energy, utilities, healthcare, and finance. Their technology combines human knowledge with machine learning to provide decision makers with insights, guidance, and recommendations for optimizing operations and increasing profitability.
# (np.float64(0.5524196137446478), array(['Financial managers that prepare operational or risk reports for management analysis.'],
#       dtype=object))
# ***********************
# Processing 4
# RAI 2023-04-04 Software developers, Media companies, Healthcare providers, Game developers, Enterprise businesses
# RAI specializes in developing mixed reality, generative AI, metaverse, and multiverse software solutions, platforms, and services. They cater to industries such as augmented workspaces, health tech, media and streaming, and human-centered applications within the XR/MR + AI and metaverse domains.
# (np.float64(0.4237343425280059), array(['Blockchain engineers that design and develop blockchain technologies for industries such as finance and music.'],
#       dtype=object))
# ***********************
# Processing 5
# BlueCheck Inc 2014-01-01 Businesses of all sizes, Financial institutions, Online marketplaces, Payment processors
# BlueCheck Inc offers a comprehensive suite of identity verification, fraud detection, and AML monitoring solutions for businesses of all sizes. Their platform helps companies accelerate customer onboarding while ensuring compliance with KYC and AML regulations, protect against fraud, and maintain real-time identity verification.
# (np.float64(0.4605089891710956), array(['Online merchants that investigate products or markets to determine areas for opportunity or viability for merchandising specific products, using online or offline sources.'],
#       dtype=object))
# ***********************
# Processing 6
# Ceres Imaging 2014-01-01 Farmers, Agribusinesses, Crop consultants
# Ceres Imaging is a leading agricultural technology company that provides farmers with advanced insights through aerial spectral imagery and analytics. They leverage proprietary technology and data science to deliver actionable information on crop health, soil conditions, and potential issues, empowering farmers to optimize their operations and yields.
# (np.float64(0.6128791185156535), array(['Farmworkers and laborers, crop, nursery, and greenhouse that inform farmers or farm managers of crop progress.'],
#       dtype=object))
# ***********************
# Processing 7
# Bryckel AI 2023-03-03 Finance professionals, Legal professionals, Real estate professionals, Business owners
# Bryckel AI is a sophisticated AI-powered solution designed for enterprise lease contract management. It automates complex processes like contract abstraction, payment and amortization calculations, critical alerts, and data analytics, ultimately assisting with financial forecasting and risk analysis.
# (np.float64(0.533406577434351), array(['Title examiners, abstractors, and searchers that prepare real estate closing statements, using knowledge and expertise in real estate procedures.'],
#       dtype=object))
# ***********************
# Processing 8
# Bewort 2023-05-01 Business owners, Data scientists, Software developers
# Bewort provides AI and ML software development services to help businesses leverage the power of these technologies. They offer consulting services to guide clients through the process, as well as data preparation services to ensure their models are built on high-quality data.
# (np.float64(0.565479954947918), array(['Data scientists that identify business problems or management objectives that can be addressed through data analysis.'],
#       dtype=object))
# ***********************
# Processing 9
# Vectari 2023-01-01 Banks, Financial institutions
# Vectari offers a suite of AI-powered solutions designed for the financial sector, specifically addressing the complexities of regulatory compliance and risk management. Their technology helps banks and other financial institutions improve efficiency, enhance decision-making, and ensure adherence to relevant regulations.
# (np.float64(0.5384871011918606), array(['Financial risk specialists that devise systems or processes to monitor validity of risk assessments.'],
#       dtype=object))
# ***********************
# Processing 10
# DropGenius 2023-09-01 Entrepreneurs, Small Business Owners, Dropshippers
# DropGenius is an AI-powered dropshipping platform that simplifies the process of starting and running a dropshipping store. It automates key tasks like product curation, pricing, marketing, and fulfillment, allowing users to focus on growth and success.
# (np.float64(0.5551090708174764), array(['Online merchants that prepare or organize online storefront marketing material, including product descriptions or subject lines, optimizing content to search engine criteria.'],
#       dtype=object))
# ***********************
# Processing 11
# Swipecart 2014-01-01 E-commerce business owners, online store managers, marketing professionals
# Swipecart is a free, no-code mobile app builder that helps e-commerce businesses create engaging shopping apps for both Android and iOS platforms within minutes. The tool features drag-and-drop functionality, conversion-led features like push notifications and AI-based product recommendations, and analytics to improve customer engagement and drive sales.
# (np.float64(0.5694450577435604), array(['Online merchants that design customer interface of online storefront, using web programming or e-commerce software.'],
#       dtype=object))
# ***********************
# Processing 12
# Lucena Research 2014-01-01 Hedge fund managers, Wealth advisors, Institutional investors
# Lucena Research is a technology company providing decision support solutions for investment professionals, such as hedge funds and wealth advisors. Their services utilize quantitative analysis and statistical machine learning to empower clients to capitalize on market opportunities while mitigating portfolio risks.
# (np.float64(0.5821095382994335), array(['Investment fund managers that perform or evaluate research, such as detailed company or industry analyses, to inform financial forecasting, decision making, or valuation.'],
#       dtype=object))
# ***********************
# Processing 13
# Venture Scanner 2014-03-24 Venture Capitalists, Corporations, Consultants, Investors
# Venture Scanner is a research firm that provides in-depth reports and data on startups and emerging technologies, helping corporations, consultants, and investors stay ahead of disruptive trends and identify new opportunities for growth. Their unique approach combines data, technology, and human analysts to generate continuously updated reports that offer valuable insights and never miss crucial signals.
# (np.float64(0.529946794497371), array(['Investment fund managers that evaluate the potential of new product developments or market opportunities, according to factors such as business plans, technologies, or market potential.'],
#       dtype=object))
# ***********************
# Processing 14
# Fresno Unlimited 2014-01-01 Content creators, Consumers
# Fresno Unlimited is an entertainment company that uses machine learning to create and distribute premium content. They aim to improve the content creation and distribution process by combining "intelligent content" with "intelligent reach," delivering better programming to consumers.
# (np.float64(0.46094399364279165), array(['Search marketing strategists that create content strategies for digital media.'],
#       dtype=object))
# ***********************
# Processing 15
# Echo Labs 2023-01-01 Lawyers, Doctors, Teachers, Researchers
# Echo Labs is developing a groundbreaking AI transcription technology that aims to achieve human-level accuracy in converting spoken language into text. This technology promises to revolutionize industries like legal, medical, and education by offering reliable and efficient transcription solutions.
# (np.float64(0.5357110581370861), array(['Word processors and typists that transcribe stenotyped notes of court proceedings.'],
#       dtype=object))
# ***********************
# Processing 16
# Bright.md 2014-01-01 Patients, Healthcare Providers
# Bright.md is a telehealth platform that leverages AI to facilitate virtual care consultations between patients and healthcare providers, offering convenient, high-quality, and asynchronous care for urgent and primary medical needs. The platform partners with healthcare organizations, providing virtual care access to millions of patients through their computers or mobile devices.
# (np.float64(0.4928441163795138), array(["Dermatologists that record patients' health histories."],
#       dtype=object))
# ***********************
# Processing 17
# Offered.ai 2022-12-28 Job seekers
# Offered.ai is an AI-powered platform that helps job seekers find their ideal jobs. It combines cutting-edge AI technology with expert recruiter support to provide a personalized and efficient job search experience.
# (np.float64(0.5159997567063881), array(['Human resources specialists that review employment applications and job orders to match applicants with job requirements.'],
#       dtype=object))
# ***********************
# Processing 18
# MUrgency Inc. 2014-03-11 Entrepreneurs, Startups, Investors
# MUrgency Inc. is a holding company that has evolved from a failed emergency response network into a venture builder, incubator, and accelerator. It has invested in and launched a range of businesses across various sectors, including healthcare, technology, and finance.
# (np.float64(0.4445456270604179), array(['Investment fund managers that evaluate the potential of new product developments or market opportunities, according to factors such as business plans, technologies, or market potential.'],
#       dtype=object))
# ***********************
# Processing 19
# CONVOCHAT 2023-01-20 Social media users, Content creators, Community managers
# Convochat is an AI-powered social networking platform designed to facilitate meaningful connections and content creation. Users can engage in conversations, share experiences, and discover new perspectives through the platform's AI-driven features.
# (np.float64(0.48441162258627046), array(['Search marketing strategists that execute or manage social media campaigns to inform search marketing tactics.'],
#       dtype=object))
# ***********************
# Processing 20
# Coverbase 2024-01-01 Compliance officers, Risk managers, Security professionals
# Coverbase is an AI-powered platform that streamlines risk assessment, tier classification, and issue management for businesses. By leveraging machine learning, Coverbase helps organizations identify and prioritize risks, automate classification processes, and manage issues more effectively.
# (np.float64(0.6658121651717892), array(['Compliance managers that develop risk management strategies based on assessment of product, compliance, or operational risks.'],
#       dtype=object))
# ***********************
# Processing 21
# Lexlabs AI 2023-10-01 Legal professionals, Construction businesses, Business owners
# Lexlabs AI is a legal tech platform that helps streamline contract management by automating tasks, analyzing requirements, and drafting industry-specific contracts. It caters to the needs of modern businesses, particularly in the construction sector, with a focus on enhancing efficiency, accuracy, and compliance.
# (np.float64(0.528701959598648), array(['Lawyers that prepare, draft, and review legal documents, such as wills, deeds, patent applications, mortgages, leases, and contracts.'],
#       dtype=object))
# ***********************
# Processing 22
# HUMN Capital 2023-01-01 Managers, HR professionals
# HUMN Capital provides AI-powered coaching for managers, offering real-time feedback and insights to improve their leadership skills and create more effective teams. The platform uses technology similar to Gong to observe and analyze managerial interactions, offering actionable recommendations for growth.
# (np.float64(0.6028664543518667), array(['Industrial-organizational psychologists that train clients to administer human resources functions, including testing, selection, and performance management.'],
#       dtype=object))
# ***********************
# Processing 23
# Semilla Co. (Flou / Seed Academy) 2023-02-01 Music producers, musicians, music labels
# Semilla Co. is a company focused on the music industry, offering both educational resources and technological solutions. They run Seed Academy, an online learning platform for Spanish-speaking creators and entrepreneurs, and Flou, an AI-powered music business management software.
# (np.float64(0.5286625277578841), array(['Music directors and composers that produce recordings of music.'],
#       dtype=object))
# ***********************
# Processing 24
# DataNovo, Inc. 2014-01-01 Patent Attorneys, In-house Counsel, Technology Companies, Research & Development Teams
# DataNovo provides a software-as-a-service platform that utilizes AI and machine learning to streamline patent-related processes like licensing, prior art searches, and patent landscape analysis. Their platform empowers businesses to make informed decisions regarding patent protection, litigation, licensing, and M&A transactions.
# (np.float64(0.5066756244990436), array(['Natural sciences managers that advise or assist in obtaining patents or meeting other legal requirements.'],
#       dtype=object))
# ***********************
# Processing 25
# Toma 2024-01-01 Sales representatives, Customer support agents, Business owners
# Toma is an AI-powered SaaS platform that automates phone calls. Its technology allows businesses to streamline communication by using AI to handle tasks like scheduling appointments, gathering information, and providing customer support.
# (np.float64(0.6221937142688385), array(['Telemarketers that schedule appointments for sales representatives to meet with prospective customers or for customers to attend sales presentations.'],
#       dtype=object))
# ***********************
# Processing 26
# iVeew 2014-01-01 Hotel managers, Tour operators, Activity providers
# iVeew is a comprehensive SaaS platform designed for hospitality companies, offering a range of services including guest recognition, geofencing, hyper-local marketing, and integration with tours and activities. iVeew aims to enhance guest engagement, personalize experiences, and improve business operations through technology and data-driven insights.
# (np.float64(0.6051891078392981), array(['Lodging managers that book tickets for guests for local tours and attractions.'],
#       dtype=object))
# ***********************
# Processing 27
# Dexa AI 2023-02-01 Researchers, Scientists, Students, Academic Institutions, Journalists, Content Creators
# Dexa AI is a platform that uses artificial intelligence to generate summaries of research papers and other long-form texts, making it easier for users to understand and engage with complex information. Dexa AI aims to provide accurate and reliable insights while fostering a deeper understanding of research findings.
# (np.float64(0.5203717748446408), array(['Data scientists that read scientific articles, conference papers, or other sources of research to identify emerging analytic trends and technologies.'],
#       dtype=object))
# ***********************
# Processing 28
# LifeLine.vet AI (SDVOSB) 2024-01-30 Veterans, Active duty military, Mental health professionals
# LifeLine.vet AI is an AI-powered journaling and assessment tool designed to detect and intervene in mental health crises, particularly among veterans and active duty military. Its goal is to reduce suicides, prevent homicides and mass violence, and provide timely support to mental health professionals through AI-driven insights and intervention strategies.
# (np.float64(0.47880849542838283), array(['Mental health counselors that collaborate with mental health professionals and other staff members to perform clinical assessments or develop treatment plans.'],
#       dtype=object))
# ***********************
# Processing 29
# metacog 2014-04-01 Data Scientists, Developers, Businesses
# Metacog is a Platform-as-a-Service solution that utilizes deep learning to analyze data. It empowers users to stream data through APIs, store it securely in the cloud, and build intelligent applications with real-time analytics and automated scoring.
# (np.float64(0.6054426273453604), array(['Data scientists that recommend data-driven solutions to key stakeholders.'],
#       dtype=object))
# ***********************
# Processing 30
# inPowered 2014-01-01 Marketers, Content creators, Digital agencies
# inPowered is an AI-powered platform that helps marketers achieve business outcomes through content marketing. Its solutions, including Content Intelligence and Content Distribution, leverage machine learning to gather proprietary data and drive ROI, ultimately impacting brand perception, website engagement, lead generation, and user interaction.
# (np.float64(0.6454037194830682), array(['Search marketing strategists that create content strategies for digital media.'],
#       dtype=object))
# ***********************
# Processing 31
# Totempole Inc 2023-04-01 Community leaders, Local governments, City planners, Residents
# Totempole Inc offers a platform that combines layered mapping, data analytics, and AI to distribute information effectively within communities. The platform caters to various users and is currently seeking funding opportunities for further development.
# (np.float64(0.497772335108111), array(['Urban and regional planners that prepare, develop and maintain maps and databases.'],
#       dtype=object))
# ***********************
# Processing 32
# Casehopper 2023-01-01 Immigration lawyers, Immigration consultants
# Casehopper is a legal technology company that leverages AI to simplify the immigration application process. Their software provides intelligent drafting tools that help lawyers and immigration professionals create accurate and complete applications, reducing errors and saving time.
# (np.float64(0.4966845115385879), array(['Lawyers that prepare, draft, and review legal documents, such as wills, deeds, patent applications, mortgages, leases, and contracts.'],
#       dtype=object))
# ***********************
# Processing 33
# ezML 2023-09-01 Security professionals, Retail managers, Marketing analysts, Healthcare professionals
# ezML provides an enterprise-grade video analysis platform powered by computer vision. Their solution empowers businesses to extract valuable insights from video data, improving operational efficiency and decision-making.
# (np.float64(0.533387018200837), array(['Security managers that develop or manage investigation programs, including collection and preservation of video and notes of surveillance processes or investigative interviews.'],
#       dtype=object))
# ***********************
# Processing 34
# Ilingo2 2014-01-01 Businesses, individuals with language barriers
# iLingo2 is a company that provides language interpretation and transportation services to businesses. They aim to bridge communication gaps and ensure equal access to information for diverse communities.
# (np.float64(0.49580607748097216), array(['Interpreters and translators that travel with or guide tourists who speak another language.'],
#       dtype=object))
# ***********************
# Processing 35
# Digital Harvest 2014-01-01 Sugarcane mills, Food groups, Growers
# Digital Harvest provides data-driven solutions for the sugarcane industry, offering predictive analytics to help mills and food groups optimize operations, improve yields, and ultimately increase sugar production. Their technology enables growers to make proactive decisions based on field-level data, leading to enhanced efficiency and cost savings.
# (np.float64(0.4196682769576584), array(['Biomass power plant managers that evaluate power production or demand trends to identify opportunities for improved operations.'],
#       dtype=object))
# ***********************
# Processing 36
# SmartWinnr 2014-01-01 Sales managers, Sales representatives
# SmartWinnr is a comprehensive sales enablement platform that empowers field sales teams with gamified KPIs, AI-driven learning, and automated incentive calculations to boost sales, knowledge, and customer interaction skills. The platform combines interactive learning, coaching tools, and performance tracking to create a unified environment for sales team development and success.
# (np.float64(0.5496061529738523), array(['Sales managers that plan and direct staffing, training, and performance evaluations to develop and control sales and service programs.'],
#       dtype=object))
# ***********************
# Processing 37
# Yellow 2023-01-01 Designers, Animators, Content Creators, Game Developers
# Yellow offers a suite of AI-powered tools that utilize cutting-edge 3D generation technology to empower creative professionals. Their products aim to simplify and enhance the creative process for tasks like design, animation, and content creation.
# (np.float64(0.5729399945558221), array(['Special effects artists and animators that create two-dimensional and three-dimensional images depicting objects in motion or illustrating a process, using computer animation or modeling programs.'],
#       dtype=object))
# ***********************
# Processing 38
# Sups 2023-11-01 High School Students, College Applicants
# Sups is an AI-powered platform that assists students in crafting their college application essays. By providing guidance on brainstorming, outlining, and revising, Sups empowers students to write strong essays without directly writing for them, aiming to level the playing field in college admissions.
# (np.float64(0.42825950191761064), array(['Educational, guidance, and career counselors and advisors that review transcripts to ensure that students meet graduation or college entrance requirements, and write letters of recommendation.'],
#       dtype=object))
# ***********************
# Processing 39
# RevMaxx AI 2023-10-24 Physicians, Healthcare providers, Medical staff
# RevMaxx AI is an AI-powered medical scribe platform that automates documentation for healthcare providers, streamlining workflows and improving patient care. Their product, the RevMaxx EHR Assistant, converts clinical discussions into actionable insights, adhering to HIPAA regulations for secure and efficient healthcare operations.
# (np.float64(0.568303875155857), array(['Medical transcriptionists that produce medical reports, correspondence, records, patient-care information, statistics, medical research, and administrative material.'],
#       dtype=object))
# ***********************
# Processing 40
# Rabbet 2014-01-01 Homeowners, Contractors
# Rabbet is a construction finance platform that streamlines the renovation process by using AI to automate document parsing, connect information, and facilitate smooth transactions. It aims to improve trust, transparency, and efficiency for both homeowners and contractors by simplifying the construction draw process and providing everyone with real-time access to accurate information.
# (np.float64(0.4500333656148844), array(['Property, real estate, and community association managers that contract with architectural firms to draw up detailed plans for new structures.'],
#       dtype=object))
# ***********************
# Processing 41
# yippy GREEN 2023-01-01 Consumers interested in sustainability, Businesses promoting sustainable practices, Environmental activists, Researchers
# yippy GREEN is a specialized search engine and online community dedicated to natural and green topics. The platform uses AI to provide a curated, trustworthy experience for both businesses and individuals interested in sustainable and environmentally friendly information.
# (np.float64(0.5723831456038959), array(['Sustainability specialists that collect information about waste stream management or green building practices to inform decision makers.'],
#       dtype=object))
# ***********************
# Processing 42
# Arkeo Ai 2024-01-26 Business owners, Marketing managers, Customer success managers
# Arkeo AI is a SaaS platform that aggregates data from various business tools like HubSpot, Stripe, and Jira to deliver actionable insights, automate workflows, and help businesses achieve higher revenue and customer satisfaction. By connecting this data with a network of AI specialists, Arkeo AI provides personalized recommendations and guidance to drive growth and optimize business operations.
# (np.float64(0.5312358133399501), array(['Business intelligence analysts that identify or monitor current and potential customers, using business intelligence tools.'],
#       dtype=object))
# ***********************
# Processing 43
# Keywords AI 2023-01-01 Software developers, Data scientists, AI researchers
# Keywords AI is a software development platform that simplifies building and deploying AI applications using Large Language Models. It offers a comprehensive set of features for creating robust, scalable AI applications, from development to deployment.
# (np.float64(0.5388413297651615), array(['Data scientists that write new functions or applications in programming languages to conduct analyses.'],
#       dtype=object))
# ***********************
# Processing 44
# Junogo 2023-07-07 Marketing managers, Content creators, Business owners
# Junogo is a B2B SaaS platform that utilizes generative AI to develop organic content strategies and draft SEO-optimized content for businesses. The platform aims to simplify the content creation process and boost organic visibility for businesses.
# (np.float64(0.6448613570387982), array(['Search marketing strategists that create content strategies for digital media.'],
#       dtype=object))
# ***********************
# Processing 45
# CogniPro.ai 2024-01-10 Knowledge workers, Project managers, Team leaders
# CogniPro.ai is a platform that leverages large language models and generative AI to enhance team productivity. It streamlines knowledge sharing, enables no-code automation, and facilitates seamless collaboration within organizations.
# (np.float64(0.502444179921834), array(['Document management specialists that propose recommendations for improving content management system capabilities.'],
#       dtype=object))
# ***********************
# Processing 46
# Marinus Analytics 2014-05-01 Law enforcement agencies, Government agencies, Anti-trafficking organizations
# Marinus Analytics is a non-profit organization dedicated to combating serious crimes like human trafficking, child sex abuse, and money laundering. They achieve this by utilizing machine learning and data mining techniques to analyze open-source intelligence and identify potential victims and perpetrators.
# (np.float64(0.5633751692387111), array(['Intelligence analysts that analyze intelligence data to identify patterns and trends in criminal activity.'],
#       dtype=object))
# ***********************
# Processing 47
# Pinch AI 2023-05-01 Businesses, Organizations, Researchers
# Pinch AI is a stealth-mode AI company developing a product that is currently unknown. Their website offers minimal information about their offerings, and they have not publicly announced any specific products or services.
# (np.float64(0.544679367925438), array(['Data scientists that identify business problems or management objectives that can be addressed through data analysis.'],
#       dtype=object))
# ***********************
# Processing 48
# Ark 2024-04-01 Technology companies, Non-profit organizations
# Ark is a boutique government affairs and public policy strategy firm specializing in helping technology companies and nonprofits navigate the complexities of government regulations and build successful relationships with government entities. They offer fractional government affairs services, providing expertise and support across various technology sectors, including SaaS, cybersecurity, AI, and more.
# (np.float64(0.44836623413472865), array(['Chief executives that review and analyze legislation, laws, or public policy and recommend changes to promote or support interests of the general population or special groups.'],
#       dtype=object))
# ***********************
# Processing 49
# ComplexChaos 2023-08-14 Project managers, Team leaders, Decision-making groups
# ComplexChaos is an AI-powered platform designed to facilitate collaborative decision-making within groups. It uses artificial intelligence to guide discussions, analyze data, and offer insights to help teams arrive at more informed and effective decisions.
# (np.float64(0.5130874366964884), array(['Project management specialists that schedule or facilitate project meetings.'],
#       dtype=object))
# ***********************
# Processing 50
# Lumme Health 2014-01-01 Individuals seeking weight management, Smokers looking for cessation support
# Lumme Health develops AI-powered smartwatch applications that track and analyze high-frequency behaviors like eating and smoking, helping users understand their habits and create personalized strategies for weight management and smoking cessation. These applications use continuous passive data collection and machine learning to provide real-time insights and tailored guidance for behavior change.
# (np.float64(0.44184955518029134), array(['Fitness and wellness coordinators that track attendance, participation, or performance data related to wellness events.'],
#       dtype=object))
# ***********************
# Processing 51
# Cantaloupe AI 2023-01-01 Jobseekers, Employers
# Cantaloupe AI is a SaaS platform that leverages AI to match jobseekers with employers in the service industry based on compatibility. Their platform uses a 'swipe' system similar to dating apps to connect users, with AI refining matches over time and providing a compatibility score.
# (np.float64(0.5192647108135864), array(['Human resources specialists that review employment applications and job orders to match applicants with job requirements.'],
#       dtype=object))
# ***********************
# Processing 52
# BDEX 2014-01-01 Marketers, Advertising agencies, Data scientists
# BDEX is a data exchange platform that leverages AI and identity resolution to help marketers understand and target their audiences more effectively. By aggregating billions of data signals from hundreds of partners, BDEX enables precise targeting and personalized experiences, ultimately increasing return on ad spend.
# (np.float64(0.555436199841847), array(['Market research analysts and marketing specialists that develop and implement procedures for identifying advertising needs.'],
#       dtype=object))
# ***********************
# Processing 53
# SydeLabs 2023-01-01 AI Developers, Machine Learning Engineers, Data Scientists
# SydeLabs offers AI security solutions that protect your AI systems from vulnerabilities and attacks, allowing you to focus on building innovative AI applications. Their aim is to ensure the security of your AI systems, eliminating concerns about security gaps and empowering you to create powerful AI applications.
# (np.float64(0.5381053410574526), array(['Information security engineers that develop or implement software tools to assist in the detection, prevention, and analysis of security threats.'],
#       dtype=object))
# ***********************
# Processing 54
# MPIRICA Health Analytics 2014-04-04 Patients, Healthcare consumers
# MPIRICA Health Analytics provides an AI-driven scoring system that helps patients evaluate medical providers based on objective clinical outcomes. This data-driven approach, available through a cloud-based platform and API, aims to improve patient decision-making and potentially reduce unnecessary surgeries and associated costs.
# (np.float64(0.48452851610215375), array(['Medical and health services managers that review and analyze facility activities and data to aid planning and cash and risk management and to improve service utilization.'],
#       dtype=object))
# ***********************
# Processing 55
# Instant AI for Google Slides 2023-05-28 Marketing professionals, Educators, Business presenters, Sales teams
# Instant AI for Google Slides is an AI-powered tool that generates visually engaging and fully-editable slides within Google Slides. Users can input a topic, presentation type, and desired length, and the AI creates slides using professionally-designed templates, including diagrams, flowcharts, and infographics.
# (np.float64(0.5667576783710727), array(['Demonstrators and product promoters that prepare or alter presentation contents to target specific audiences.'],
#       dtype=object))
# ***********************
# Processing 56
# MixiP 2023-02-20 AI developers, Ad agencies, Content creators
# MixiP is a platform that provides rights-cleared media libraries for AI training models and AdTech campaigns. It connects businesses needing diverse media content with a vast network of creators, ensuring legal compliance and fair compensation for artists.
# (np.float64(0.4552309274440641), array(["Writers and authors that develop advertising campaigns for a wide range of clients, working with an advertising agency's creative director and art director to determine the best way to present advertising information."],
#       dtype=object))
# ***********************
# Processing 57
# VOIQ 2014-01-01 Website visitors, App users, Business owners
# VOIQ provides a SaaS platform that enables businesses to create AI-powered conversational voice assistants for their websites, web apps, and mobile apps. These voice assistants can engage with potential customers, answer their questions, and help convert them into paying customers.
# (np.float64(0.4511043746742932), array(['Online merchants that measure and analyze web site usage data to maximize search engine returns or refine customer interfaces.'],
#       dtype=object))
# ***********************
# Processing 58
# Certilytics 2014-01-01 Healthcare providers, Insurance companies, Pharmaceutical companies
# Certilytics is a health analytics company specializing in data science, clinical, actuarial, and engineering expertise. They focus on leveraging data to improve healthcare outcomes, potentially through insights on risk assessment, cost management, or treatment effectiveness.
# (np.float64(0.4759528141273309), array(['Medical and health services managers that review and analyze facility activities and data to aid planning and cash and risk management and to improve service utilization.'],
#       dtype=object))
# ***********************
# Processing 59
# WiZR 2014-01-01 Security professionals, Hotel managers, Retail store owners
# WiZR is a platform that helps businesses quickly deploy video analytics solutions on edge devices and in hybrid cloud environments. They offer features like human detection, people counting, and object tracking, designed for security, hospitality, retail, and other industries.
# (np.float64(0.4997309079140452), array(['Security management specialists that design, implement, or establish requirements for security systems, video surveillance, motion detection, or closed-circuit television systems to ensure proper installation and operation.'],
#       dtype=object))
# ***********************
# Processing 60
# Vitagene 2014-01-01 Individuals seeking personalized health guidance
# Vitagene is a personalized health and wellness platform that uses your DNA and lifestyle information to provide tailored recommendations for diet, fitness, and supplements. Their platform leverages big data and machine learning to deliver actionable insights and personalized guidance to help users achieve their health goals.
# (np.float64(0.4968669590815341), array(['Fitness and wellness coordinators that provide individual support or counseling in general wellness or nutrition.'],
#       dtype=object))
# ***********************
# Processing 61
# Quill AI 2023-01-01 Financial analysts, Investment firms
# Quill AI is an AI-powered tool designed to assist financial analysts and investment firms. It functions as a personal assistant, automating tasks like data analysis, report generation, and communication, allowing analysts to focus on higher-level tasks.
# (np.float64(0.6370119362031114), array(['Financial and investment analysts that prepare all materials for transactions or execution of deals.'],
#       dtype=object))
# ***********************
# Processing 62
# PotentiaMetrics 2014-01-01 Payers, Providers, Pharmaceutical companies, Medical technology companies
# PotentiaMetrics is a company offering AI-powered platforms, specifically PotentiaMED, that analyze real-world clinical and economic outcomes data to provide actionable insights for healthcare stakeholders like payers, providers, pharmaceutical companies, and medical technology companies. These insights help improve patient outcomes, boost revenue, and reduce healthcare spending.
# (np.float64(0.4338785523895353), array(['Bioengineers and biomedical engineers that analyze new medical procedures to forecast likely outcomes.'],
#       dtype=object))
# ***********************
# Processing 63
# Sober Grid 2014-01-01 Individuals in recovery from substance use disorders, Family members and friends of those in recovery, Addiction recovery professionals
# Sober Grid is a mobile app designed for people in recovery from substance use disorders. It offers a community-based approach through features like GPS-based connections, messaging, coaching, educational content, and daily challenges, helping users build sobriety and connect with others.
# (np.float64(0.4215118537837646), array(['Substance abuse and behavioral disorder counselors that provide clients or family members with information about addiction issues and about available services or programs, making appropriate referrals when necessary.'],
#       dtype=object))
# ***********************
# Processing 64
# Quokka AI 2024-01-01 IT Managers, System Administrators
# Quokka AI offers an intelligent automation platform that streamlines and automates IT operations. It uses AI to automate tasks, improve efficiency, and reduce human error, freeing up IT teams to focus on more strategic initiatives.
# (np.float64(0.5966260510640431), array(['Web administrators that monitor systems for intrusions or denial of service attacks, and report security breaches to appropriate personnel.'],
#       dtype=object))
# ***********************
# Processing 65
# Synaptrix Labs 2023-03-01 Individuals with paralysis, Medical professionals, Researchers
# Synaptrix Labs specializes in developing advanced brain-computer interface technology powered by artificial intelligence. Their solutions aim to empower individuals with paralysis by translating brain signals into control commands for various assistive devices.
# (np.float64(0.5734776582365257), array(['Bioengineers and biomedical engineers that design and deliver technology, such as prosthetic devices, to assist people with disabilities.'],
#       dtype=object))
# ***********************
# Processing 66
# Ushur 2014-01-01 Insurance brokers, Insurance agents, Insurance policyholders
# Ushur is a cloud-based AI company specializing in automating service workflows for businesses, particularly in the insurance industry. They offer a suite of intelligent automation solutions, including a virtual customer assistant, automated email processing, and a no-code workflow builder, all designed to improve customer experience, increase efficiency, and reduce operational costs.
# (np.float64(0.5716743778311897), array(['Insurance claims and policy processing clerks that provide customer service, such as limited instructions on proceeding with claims or referrals to auto repair facilities or local contractors.'],
#       dtype=object))
# ***********************
# Processing 67
# Nurdle AI 2023-09-01 Data Scientists, Machine Learning Engineers, AI Researchers
# Nurdle AI specializes in creating high-quality synthetic data for AI projects by leveraging privacy-compliant, human-labeled datasets. This synthetic data addresses the common "cold-start problem" by offering a cost-effective and efficient solution for building accurate and effective AI models.
# (np.float64(0.5636373174186509), array(['Data scientists that test, validate, and reformulate models to ensure accurate prediction of outcomes of interest.'],
#       dtype=object))
# ***********************
# Processing 68
# Robozaps 2024-06-16 Individuals, Businesses, Researchers, Developers
# Robozaps is an online marketplace that specializes in the buying and selling of humanoid robots. The platform features a wide selection of robots from leading brands such as Tesla Optimus, Figure AI, UBTECH, and Boston Dynamics.
# (np.float64(0.47359542715944736), array(['Robotics engineers that conduct research into the feasibility, design, operation, or performance of robotic mechanisms, components, or systems, such as planetary rovers, multiple mobile robots, reconfigurable robots, or man-machine interactions.'],
#       dtype=object))
# ***********************
# Processing 69
# Litmus Learn 2023-05-23 Teachers, School administrators
# Litmus Learn is an interactive learning platform designed for K-12 schools, primarily targeting private schools in India. Utilizing generative AI, Litmus Learn empowers teachers to create engaging content, track student progress, and gain insights to improve teaching methods, all within a single platform.
# (np.float64(0.6113320936906008), array(['Education administrators, kindergarten through secondary that create school improvement plans, using student performance data.'],
#       dtype=object))
# ***********************
# Processing 70
# Destined AI 2023-08-30 AI Developers, Data Scientists, Machine Learning Engineers
# Destined AI is a platform that helps developers detect and mitigate bias in their AI models. It offers tools and insights to analyze data, identify potential biases, and implement solutions for fairness and ethical AI development.
# (np.float64(0.5138563893018481), array(['Data scientists that test, validate, and reformulate models to ensure accurate prediction of outcomes of interest.'],
#       dtype=object))
# ***********************
# Processing 71
# Endorsed 2023-01-01 HR managers, Recruiters
# Endorsed is an AI-powered recruitment platform that integrates seamlessly with existing Applicant Tracking Systems. Its AI technology analyzes candidate data, identifies top talent, and automates tasks like screening and scheduling, improving efficiency and reducing bias.
# (np.float64(0.5906548931922364), array(['Human resources managers that identify staff vacancies and recruit, interview, and select applicants.'],
#       dtype=object))
# ***********************
# Processing 72
# AWS Impact Accelerator 2023-04-04 Underrepresented founders, early-stage companies
# The AWS Impact Accelerator is a program designed to support underrepresented founder companies by providing access to resources, mentorship, and expert guidance within the AWS ecosystem. The program offers a range of benefits, including exclusive webinars, free 1:1 sessions with AWS experts, and access to the AWS Startup Loft, a dedicated space for early-stage companies to grow.
# (np.float64(0.38841943318261724), array(['Financial managers that network within communities to find and attract new business.'],
#       dtype=object))
# ***********************
# Processing 73
# mode.ai 2014-01-01 Retailers, Publishers, Shoppers
# mode.ai provides AI-powered virtual stylists for retailers and publishers, enabling customers to interact with bots through messaging platforms for personalized style suggestions and product recommendations. The platform utilizes computer vision and deep learning to deliver image-based recommendations, search filters, size personalization, and styling inspiration.
# (np.float64(0.5309576988304492), array(['Online merchants that compose images of products, using video or still cameras, lighting equipment, props, or photo or video editing software.'],
#       dtype=object))
# ***********************
# Processing 74
# Codio 2014-01-01 Teachers, Educators, Students, Online Learning Platforms, Bootcamps
# Codio is an evidence-based learning platform designed for computer science and tech skills education, providing educators with tools to effectively teach and measure student outcomes through hands-on virtual labs, AI-enhanced support, and interactive texts. It caters to schools, higher education institutions, boot camps, and online learning platforms, offering a comprehensive solution for technology education.
# (np.float64(0.4835624311586798), array(['Computer science teachers, postsecondary that develop and maintain web sites for online courses.'],
#       dtype=object))
# ***********************
# Processing 75
# Koolay 2023-05-30 Teachers, Non-profit staff, Marketing professionals
# Koolay is an AI-powered CMS platform designed specifically for schools, NGOs, and businesses. It offers AI-driven content creation, collaboration, SEO optimization, and analytics within a user-friendly interface built on the Liquid syntax.
# (np.float64(0.5263895683882602), array(['Search marketing strategists that create content strategies for digital media.'],
#       dtype=object))
# ***********************
# Processing 76
# Colburn Hill Group 2014-01-01 Healthcare providers, Hospitals, Medical billing companies, Insurance companies
# Colburn Hill Group specializes in robotic process automation solutions tailored for the healthcare industry's revenue cycle management. Their technology uses advanced analytics to automate tasks, improve efficiency, and reduce errors in billing, claims processing, and other crucial RCM functions.
# (np.float64(0.4763809263172193), array(['Medical records specialists that post medical insurance billings.'],
#       dtype=object))
# ***********************
# Processing 77
# Endo Health 2024-01-01 Individuals with Type 2 Diabetes
# Endo Health is developing a gamified AI-powered digital health assistant for individuals with type 2 diabetes. The platform aims to provide personalized support and guidance to help patients manage their condition through interactive and engaging methods.
# (np.float64(0.44476034379874535), array(['Fitness and wellness coordinators that interpret insurance data or health reimbursement account (hra) data to develop programs that address specific needs of target populations.'],
#       dtype=object))
# ***********************
# Processing 78
# DigiFabster 2014-01-01 Manufacturing shop owners, Machine operators
# ...
# (np.float64(0.5235433222497013), array(['Farmers, ranchers, and other agricultural managers that evaluate marketing or sales alternatives for products.'],
#       dtype=object))
# ***********************
# Processing 774
# ModerateKit 2023-10-01 Community platform owners, Social media managers, Content moderators, Customer support teams
# ModerateKit offers AI-powered moderation tools for online communities, aiming to automate content moderation processes, improve efficiency, and reduce associated costs. Their solutions are designed to help community platforms manage content effectively, identify harmful or inappropriate content, and enhance overall user experience.
# (np.float64(0.4396142133802631), array(['Web administrators that review or update web page content or links in a timely manner, using appropriate tools.'],
#       dtype=object))
# ***********************
# Processing 775
# Layerpath 2023-01-01 Product managers, Marketing teams, Sales representatives, Demo creators
# Layerpath is a tool that simplifies the creation of interactive product demos by utilizing AI technology. By leveraging screen recordings, Layerpath transforms them into engaging product tours, making it easier to showcase your product across different platforms and touchpoints.
# (np.float64(0.5404848206248047), array(['Demonstrators and product promoters that prepare or alter presentation contents to target specific audiences.'],
#       dtype=object))
# ***********************
# Processing 776
# Swarmer 2023-05-01 Drone operators, Security companies, Inspection teams, Delivery companies
# Swarmer is an AI-powered mission control center designed for coordinated drone operations. It provides firmware for video streaming, logging, and monitoring, enabling users to manage and control multiple drones effectively.
# (np.float64(0.4193945784883797), array(['Surveyors that direct aerial surveys of specified geographical areas.'],
#       dtype=object))
# ***********************
# Processing 777
# Sahaj Software 2014-03-27 Businesses, Enterprises, Startups
# Sahaj Software specializes in crafting bespoke AI and data-driven solutions for clients, leveraging expertise in software and data engineering to unlock the full potential of data. They prioritize ethical practices, focusing on fair treatment of employees and transparency in their operations to combat modern slavery.
# (np.float64(0.4260035233118741), array(['Data scientists that identify business problems or management objectives that can be addressed through data analysis.'],
#       dtype=object))
# ***********************
# Processing 778
# Gobi 2023-06-29 Individuals, Businesses seeking to personalize their user experiences
# Description: Gobi is a platform that utilizes artificial intelligence to personalize your online experience. By analyzing your data and preferences, Gobi helps you discover and connect with products, services, and opportunities that align with your unique interests and needs.
# (np.float64(0.49857380289908104), array(['Online merchants that measure and analyze web site usage data to maximize search engine returns or refine customer interfaces.'],
#       dtype=object))
# ***********************
# Processing 779
# Spot 2014-01-01 DevOps engineers, Cloud architects, IT managers
# Spot is a cloud cost optimization platform that leverages AI to manage and procure cost-effective cloud infrastructure, specifically "spot instances," for businesses seeking to optimize their cloud expenses. Spot helps companies predict price fluctuations, automate scaling, and find the most economical cloud resources, ultimately reducing their overall cloud costs.
# (np.float64(0.4717112779734295), array(['Logistics engineers that identify cost-reduction or process-improvement logistic opportunities.'],
#       dtype=object))
# ***********************
# Processing 780
# GeoCV 2014-01-01 Real Estate Agents, Property Developers, Interior Designers
# GeoCV is a PropTech startup that utilizes mobile phone technology and AI to create photorealistic 3D virtual tours of spaces, primarily for real estate but with plans to expand to other industries. Their focus on hardware agnosticism and an open data approach aims to create a shared economy of photographers, accelerating business transactions and providing immersive experiences.
# (np.float64(0.5549043793545548), array(['Real estate brokers that give buyers virtual tours of properties in which they are interested, using computers.'],
#       dtype=object))
# ***********************
# Processing 781
# TopOPPS 2014-01-01 Sales managers, Sales representatives
# TopOPPS is an AI-powered sales forecasting and pipeline management solution. It provides insights into deal likelihood, identifies gaps in the sales pipeline, and offers coaching and alignment for sales representatives, ultimately accelerating sales cycles and achieving sales targets.
# (np.float64(0.6203749316732329), array(['Sales engineers that maintain sales forecasting reports.'],
#       dtype=object))
# ***********************
# Processing 782
# Mantis Analytics 2023-03-01 Security professionals, C-suite executives, Compliance officers
# Mantis Analytics is an AI-powered risk management platform that monitors online information spaces in real-time, delivering actionable insights for both physical and digital risks. Its deep intelligence provides organizations with comprehensive risk assessments, enabling proactive mitigation strategies.
# (np.float64(0.6268417241514461), array(['Security management specialists that perform risk analyses so that appropriate countermeasures can be developed.'],
#       dtype=object))
# ***********************
# Processing 783
# FreshSurety 2014-01-01 Food producers, Distributors, Retailers, Wholesalers
# FreshSurety provides a real-time freshness monitoring solution for perishable goods, using proprietary sensors and AI algorithms to determine the current and future value of inventory. The technology helps businesses optimize their inventory, reduce waste, and improve decision-making throughout the supply chain, ultimately making perishable food less risky to handle.
# (np.float64(0.5475483845691114), array(['Supply chain managers that analyze inventories to determine how to increase inventory turns, reduce waste, or optimize customer service.'],
#       dtype=object))
# ***********************
# Processing 784
# Kwibal 2024-01-15 Consumers, Secondhand buyers
# Kwibal is an AI-powered platform that consolidates the browsing and purchasing experience across various secondhand marketplaces, simplifying the process for consumers and making it feel like a traditional online retail experience. It aims to promote sustainability by encouraging secondhand shopping and fostering a more equitable marketplace for buyers and sellers.
# (np.float64(0.5788546909702647), array(['Online merchants that purchase new or used items from online or physical sources for resale via retail or auction web site.'],
#       dtype=object))
# ***********************
# Processing 785
# Sapucay 2023-01-30 Farmers, Agricultural businesses
# Sapucay is an AI-powered platform that helps farmers measure and reduce their carbon footprint, promoting sustainable agricultural practices. Their technology likely analyzes data from various sources to identify areas for improvement and optimize resource usage, leading to eco-efficient farming.
# (np.float64(0.6068008231837682), array(['Farmers, ranchers, and other agricultural managers that collect and record growth, production, and environmental data.'],
#       dtype=object))
# ***********************
# Processing 786
# SKUR 2014-02-01 Project Managers, Operations Managers, Facility Managers
# SKUR is a Software-as-a-Service analytics platform designed specifically for the construction, oil & gas, and facilities management industries. SKUR provides valuable insights and data analysis tools to help these sectors optimize their operations and make better decisions.
# (np.float64(0.598713325859027), array(['Facilities managers that prepare and review operational reports and schedules to ensure accuracy and efficiency.'],
#       dtype=object))
# ***********************
# Processing 787
# Swish Analytics 2014-03-01 Sports fans, Sports bettors, Media outlets
# Swish Analytics is a machine learning platform that analyzes historical sports data using proprietary algorithms to generate predictions, insights, and analytics. This information is made accessible to fans, bettors, and media partners through subscription-based services and licensing agreements, empowering them with data-driven insights and forecasts.
# (np.float64(0.4849324256193335), array(['Umpires, referees, and other sports officials that research and study players and teams to anticipate issues that might arise in future engagements.'],
#       dtype=object))
# ***********************
# Processing 788
# MathGPTPro 2023-01-01 Students, Teachers, Parents
# MathGPTPro is an AI-powered personal learning platform that uses natural language processing to help students understand and solve complex math problems. It provides step-by-step solutions, explains concepts in a clear and concise manner, and offers personalized learning recommendations to improve user understanding.
# (np.float64(0.5142593123755403), array(['Tutors that review class material with students by discussing text, working solutions to problems, or reviewing worksheets or other assignments.'],
#       dtype=object))
# ***********************
# Processing 789
# LOCALLY 2014-01-01 Marketers, Retailers, Location-based service providers
# LOCALLY is a company that leverages blockchain, big data, and AI to provide real-time location intelligence and consumer engagement solutions. Their technology helps businesses understand consumer behavior, optimize marketing campaigns, and enhance location-based services.
# (np.float64(0.4821374686373665), array(['Online merchants that determine location for product listings to maximize exposure to online traffic.'],
#       dtype=object))
# ***********************
# Processing 790
# Askdata 2014-01-01 Data analysts, Business analysts, Data scientists, Data engineers
# Askdata is a data analytics platform that simplifies data interaction by enabling users to ask questions in natural language and receive answers from across their data sources. This platform leverages Human2SQL, a vast repository of natural language and SQL statements, to offer a collaborative and frictionless data experience.
# (np.float64(0.6254381927668692), array(['Data scientists that identify business problems or management objectives that can be addressed through data analysis.'],
#       dtype=object))
# ***********************
# Processing 791
# Significo 2014-01-01 Marketing teams, Product managers, Data analysts
# Significo provides an AI-powered personalization platform that allows businesses to deliver tailored experiences to their users at scale, without requiring a dedicated data science team. The platform automates data analysis and insights generation, enabling companies to personalize content, recommendations, and other interactions based on individual user preferences and behaviors.
# (np.float64(0.5544713104983411), array(['Marketing managers that initiate market research studies, or analyze their findings.'],
#       dtype=object))
# ***********************
# Processing 792
# StackUp 2014-01-01 Students, Educators, School administrators
# StackUp is a system that tracks and reports online reading and learning activity across the web. It aims to improve reading skills for students, offer credit for independent learning, and provide educators with real-time data on device usage within schools and districts.
# (np.float64(0.5063699486129124), array(['Education administrators, kindergarten through secondary that create school improvement plans, using student performance data.'],
#       dtype=object))
# ***********************
# Processing 793
# Wallaroo 2014-01-01 Data Scientists, Machine Learning Engineers, AI Teams
# Wallaroo offers an enterprise AI platform specifically designed for deploying and managing machine learning models in production, streamlining the process of putting AI projects to work. The platform focuses on simplifying deployment, ensuring security, and scaling ML models for real-world applications, making it a valuable tool for organizations looking to unlock the full potential of their AI projects.
# (np.float64(0.568338500255936), array(['Data scientists that recommend data-driven solutions to key stakeholders.'],
#       dtype=object))
# ***********************
# Processing 794
# BAILEY AI 2023-07-10 Filmmakers, Production companies, Content creators
# BAILEY AI Film Company provides AI-powered filmmaking services. They utilize artificial intelligence technology to create innovative and efficient film production workflows, empowering creators to bring their stories to life.
# (np.float64(0.5906028952844196), array(['Producers and directors that compose and edit scripts or provide screenwriters with story outlines from which scripts can be written.'],
#       dtype=object))
# ***********************
# Processing 795
# Graph Story 2014-01-01 Data scientists, Developers, Data analysts
# Graph Story offers a cloud-based graph database service that makes it easy for businesses to manage and utilize data connections, freeing them from infrastructure management and enabling them to focus on core operations. Their platform runs on major cloud providers like AWS, Azure, and Google Cloud Platform, providing scalability and security.
# (np.float64(0.6401531407611836), array(['Data scientists that identify business problems or management objectives that can be addressed through data analysis.'],
#       dtype=object))
# ***********************
# Processing 796
# LawIQ 2014-01-01 Financial analysts, Compliance officers, Risk managers, Legal professionals
# LawIQ is a platform that uses AI and machine learning to analyze regulatory, legal, and financial data for blue-chip energy, industrial, and financial firms. This allows users to make informed decisions by identifying potential risks, opportunities, and forecasting regulatory milestones.
# (np.float64(0.6169101357152793), array(['Financial managers that prepare operational or risk reports for management analysis.'],
#       dtype=object))
# ***********************
# Processing 797
# Intellect SEEC 2014-01-01 Insurance companies, Insurance brokers
# Intellect SEEC is a leading provider of AI-powered solutions specifically tailored for the insurance industry. They utilize big data, machine learning, and advanced technologies to help insurance companies improve efficiency, automate processes, and enhance decision-making.
# (np.float64(0.5339129367995783), array(['Insurance claims and policy processing clerks that apply insurance rating systems.'],
#       dtype=object))
# ***********************
# Processing 798
# TravelWits 2014-01-01 Travel managers, Business travelers, HR departments
# TravelWits is an AI-powered travel platform that optimizes itineraries for business travelers, factoring in meeting times and locations. The company also aims to save companies money by providing employee incentives and streamlining travel policy management.
# (np.float64(0.49626704809773026), array(['Travel agents that plan, describe, arrange, and sell itinerary tour packages and promotional travel incentives offered by various travel carriers.'],
#       dtype=object))
# ***********************
# Processing 799
# ALLO 2014-01-01 Team leaders, Project managers, Team members
# ALLO is an AI-powered collaboration platform that helps teams brainstorm, manage complex projects, and align towards common goals. It adapts to specific workflows to enhance productivity and facilitate seamless communication.
# (np.float64(0.5175424869725069), array(['Project management specialists that schedule or facilitate project meetings.'],
#       dtype=object))

# %%
pre = onet_df[pd.to_datetime(onet_df['founded date'])<'11/30/2022']
post = onet_df[pd.to_datetime(onet_df['founded date'])>='11/30/2022']

# %%
pre[pre['cosine similarity'] > .5]
# Out:
#       organization name founded date  cosine similarity  \
# 0    Divergence Academy   2014-01-01           0.509927
# 1        Descartes Labs   2014-01-01           0.596854
# 3         Beyond Limits   2014-01-01           0.552420
# 6         Ceres Imaging   2014-01-01           0.612879
# 11            Swipecart   2014-01-01           0.569445
# ..                  ...          ...                ...
# 793            Wallaroo   2014-01-01           0.568339
# 795         Graph Story   2014-01-01           0.640153
# 796               LawIQ   2014-01-01           0.616910
# 797      Intellect SEEC   2014-01-01           0.533913
# 799                ALLO   2014-01-01           0.517542
#
#                                            description
# 0    Penetration testers that develop presentations...
# 1    Remote sensing scientists and technologists th...
# 3    Financial managers that prepare operational or...
# 6    Farmworkers and laborers, crop, nursery, and g...
# 11   Online merchants that design customer interfac...
# ..                                                 ...
# 793  Data scientists that recommend data-driven sol...
# 795  Data scientists that identify business problem...
# 796  Financial managers that prepare operational or...
# 797  Insurance claims and policy processing clerks ...
# 799  Project management specialists that schedule o...
#
# [274 rows x 4 columns]

# %%
post[post['cosine similarity'] > .5]
# Out:
#     organization name founded date  cosine similarity  \
# 7          Bryckel AI   2023-03-03           0.533407
# 8              Bewort   2023-05-01           0.565480
# 9             Vectari   2023-01-01           0.538487
# 10         DropGenius   2023-09-01           0.555109
# 15          Echo Labs   2023-01-01           0.535711
# ..                ...          ...                ...
# 782  Mantis Analytics   2023-03-01           0.626842
# 784            Kwibal   2024-01-15           0.578855
# 785           Sapucay   2023-01-30           0.606801
# 788        MathGPTPro   2023-01-01           0.514259
# 794         BAILEY AI   2023-07-10           0.590603
#
#                                            description
# 7    Title examiners, abstractors, and searchers th...
# 8    Data scientists that identify business problem...
# 9    Financial risk specialists that devise systems...
# 10   Online merchants that prepare or organize onli...
# 15   Word processors and typists that transcribe st...
# ..                                                 ...
# 782  Security management specialists that perform r...
# 784  Online merchants that purchase new or used ite...
# 785  Farmers, ranchers, and other agricultural mana...
# 788  Tutors that review class material with student...
# 794  Producers and directors that compose and edit ...
#
# [281 rows x 4 columns]
