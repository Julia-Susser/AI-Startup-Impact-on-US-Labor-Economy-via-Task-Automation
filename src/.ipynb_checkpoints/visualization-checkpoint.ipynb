# %%
import pandas as pd
import numpy as np

# %%
class output():
    def __init__(self):
        self.codes = pd.read_csv("../output/soc_codes.csv",index_col=0)

    
    def getONET(self,task_sim, title_sim, conf_interval=True):
        self.task_sim = task_sim
        self.title_sim = title_sim
        self.conf_interval = conf_interval
        self.onet_df = pd.read_csv("../output/onet_df.csv")
        self.onet_df = self.onet_df[(self.onet_df.task_similarity > task_sim) & (self.onet_df.job_title_similarity > title_sim)].reset_index(drop=True)
        self.onet_df = self.onet_df[self.onet_df.situation_conf_interval > conf_interval]
        self.computeONETWeights()
        self.getStartupData()
        
        print(f"{len(self.onet_df)} tasks with task similarity > {task_sim} and title similarity > {title_sim}")
        num_onet_startups = len(self.df["organization name"].unique())
        num_startups = len(self.startup_df["organization name"].unique())
        print(f"{num_onet_startups} startups out of {num_startups} decomposed")
        
    def computeONETWeights(self):
        self.onet_weights = self.onet_df.groupby("organization_name")["onet_title"].count().apply(lambda x: 1/x).reset_index().rename({"onet_title":"onet_weight"},axis=1)
        self.onet_df = self.onet_df.merge(self.onet_weights, on="organization_name")

    def getONETTitles(self):
        self.onet_titles = self.onet_df.groupby("onet_title")["onet_weight"].sum().round(2).sort_values(ascending=False).reset_index()
        return self.onet_titles

    def getStartupGeneratedLLMTitles(self):
        self.example_job_titles_df = onet_df.example_job_title.value_counts().apply(lambda x: x/3).reset_index()
        return self.example_job_titles_df

    def printTop100ONETTasks(self):
        self.top_100_ONETtasks = onet_df['onet_task'].value_counts().reset_index().head(100)
        self.top_100_tasks.columns = ['Task', 'Frequency']
        for index, row in self.top_100_tasks.iterrows():
            print(f"Task = {row['Task']}, Frequency = {row['Frequency']}\n")
    
    def getStartupData(self):
        self.startup_df = pd.read_csv("../output/df_with_examples.csv")
        cols = ['organization name', 'num employees', 'founded date','website','description_all', 'industries_parsed', 'generated_description', 'parsed_description', 'Tasks/Jobs', 'Industry', 'Customers','generated_description_conf_interval','parsed_description_conf_interval']
        self.df = self.startup_df[cols]
        self.df = self.df.merge(self.onet_df,left_on="organization name",right_on="organization_name")
        self.df = self.df.merge(self.codes,left_on="onet_title",right_on="Title")

    
    def printExamples(self,x):
        for x, row in list(self.df.iterrows())[:x]:
                print("***************************")
                print(f"Processing {x+1}")
                print("_________________________")
                for col in ['organization name','website','generated_description','Tasks/Jobs', 'Industry', 'Customers','generated_description_conf_interval','parsed_description_conf_interval']:
                    print(f"{col}: {row[col]}")
                print("_________________________")
                for col in list(self.onet_df.columns):
                    print(f"{col}: {row[col]}")
                print("***************************\n")
    def generateOutput(self):
        # %%capture captured_output

        group_sums = self.df.groupby('Minor Group Name')['onet_weight'].sum().sort_values(ascending=False)
        print(f"{len(self.startup_df)} Startups Founded post launch of chatGPT with 1-10 employees")
        print(f"Task Similarity: {self.task_sim}, Title Similarity {self.title_sim}, Confidence Interval: {self.conf_interval if self.conf_interval != True else 'all'}")
        print("Decomposition of startup effect on labor market")
        
        for group_name in group_sums.index:
            group_data = self.df[self.df['Minor Group Name'] == group_name]
            print("*****************")
            print(f"Group: {group_name}")
            onet_titles = group_data.groupby('onet_title')['onet_weight'].sum().round(2).sort_values(ascending=False).reset_index()
            onet_tasks = group_data.groupby('onet_task')['onet_weight'].sum().round(2).sort_values(ascending=False).reset_index()
            
            print("________________")
            print("10 Most Highly Weighted Titles:")
            for index, row in onet_titles.iterrows():
                print(f"Title: {row['onet_title']}, Weight: {row['onet_weight']}")
            print("\n")  
        
            print("10 Most Highly Weighted Tasks:")
            for index, row in list(onet_tasks.iterrows())[:10]:
                print(f"Task: {row['onet_task']}, Weight: {row['onet_weight']}")
            print("\n")  
        
            print("10 Example Startups:")
            startups = group_data.groupby(['organization_name','website'])['onet_weight'].sum().round(2).sort_values(ascending=False).reset_index()
            for index, row in list(startups.iterrows())[:10]:
                print(f"Startup: {row['organization_name']}, Website: {row['website']}")
            print("\n")  
            
        with open('../output/output.txt', 'w') as f:
            f.write(captured_output.stdout)

# %%
out = output()
out.getONET(task_sim=.67,title_sim=.7)
out.printExamples(20)
out.generateOutput()
# Out:
# 2023 tasks with task similarity > 0.67 and title similarity > 0.7
# 518 startups out of 990 decomposed
# ***************************
# Processing 1
# _________________________
# organization name: Catio
# website: San Francisco Bay Area, Silicon Valley, West Coast
# generated_description: Catio is a cloud architecture platform that helps companies design and optimize their cloud-native tech stacks. Using AI, Catio provides guidance on technology selection, planning, and continuous improvement, acting as a "copilot" for architects and engineers.
# Tasks/Jobs: Cloud architecture design, Technology selection, Cloud optimization, Continuous improvement
# Industry: Cloud computing
# Customers: Cloud architects, Engineers, IT professionals
# generated_description_conf_interval: 7
# parsed_description_conf_interval: 8
# _________________________
# organization_name: Catio
# example: A cloud architect uses Catio to evaluate different cloud service offerings from various providers, comparing costs, performance, and security features to select the most suitable options for their company's specific needs.
# situation_conf_interval: 9.0
# situation_conf_interval_reasoning: The provided description aligns with the responsibilities of Computer and Information Systems Managers, particularly in the context of cloud computing.
# job: Computer and Information Systems Managers that evaluate cloud service offerings from different providers to select the most suitable options for the company's needs.
# onet_title: Computer and Information Systems Managers
# onet_task: Evaluate the organization's technology use and needs and recommend improvements, such as hardware and software upgrades.
# example_job_title: Computer and Information Systems Managers
# task_similarity: 0.7308420357826921
# job_title_similarity: 0.9999987394994386
# onet_weight: 0.3333333333333333
# ***************************
#
# ***************************
# Processing 2
# _________________________
# organization name: Catio
# website: San Francisco Bay Area, Silicon Valley, West Coast
# generated_description: Catio is a cloud architecture platform that helps companies design and optimize their cloud-native tech stacks. Using AI, Catio provides guidance on technology selection, planning, and continuous improvement, acting as a "copilot" for architects and engineers.
# Tasks/Jobs: Cloud architecture design, Technology selection, Cloud optimization, Continuous improvement
# Industry: Cloud computing
# Customers: Cloud architects, Engineers, IT professionals
# generated_description_conf_interval: 7
# parsed_description_conf_interval: 8
# _________________________
# organization_name: Catio
# example: A cloud architect uses Catio to evaluate different cloud service offerings from various providers, comparing costs, performance, and security features to select the most suitable options for their company's specific needs.
# situation_conf_interval: 9.0
# situation_conf_interval_reasoning: The provided description aligns with the responsibilities of Computer and Information Systems Managers, particularly in the context of cloud computing.
# job: Computer and Information Systems Managers that evaluate cloud service offerings from different providers to select the most suitable options for the company's needs.
# onet_title: Computer and Information Systems Managers
# onet_task: Consult with users, management, vendors, and technicians to assess computing needs and system requirements.
# example_job_title: Computer and Information Systems Managers
# task_similarity: 0.7046414376949868
# job_title_similarity: 0.9999987394994386
# onet_weight: 0.3333333333333333
# ***************************
#
# ***************************
# Processing 3
# _________________________
# organization name: Catio
# website: San Francisco Bay Area, Silicon Valley, West Coast
# generated_description: Catio is a cloud architecture platform that helps companies design and optimize their cloud-native tech stacks. Using AI, Catio provides guidance on technology selection, planning, and continuous improvement, acting as a "copilot" for architects and engineers.
# Tasks/Jobs: Cloud architecture design, Technology selection, Cloud optimization, Continuous improvement
# Industry: Cloud computing
# Customers: Cloud architects, Engineers, IT professionals
# generated_description_conf_interval: 7
# parsed_description_conf_interval: 8
# _________________________
# organization_name: Catio
# example: A cloud architect uses Catio to evaluate different cloud service offerings from various providers, comparing costs, performance, and security features to select the most suitable options for their company's specific needs.
# situation_conf_interval: 9.0
# situation_conf_interval_reasoning: The provided description aligns with the responsibilities of Computer and Information Systems Managers, particularly in the context of cloud computing.
# job: Computer and Information Systems Managers that evaluate cloud service offerings from different providers to select the most suitable options for the company's needs.
# onet_title: Computer and Information Systems Managers
# onet_task: Develop computer information resources, providing for data security and control, strategic computing, and disaster recovery.
# example_job_title: Computer and Information Systems Managers
# task_similarity: 0.7045860675666318
# job_title_similarity: 0.9999987394994386
# onet_weight: 0.3333333333333333
# ***************************
#
# ***************************
# Processing 4
# _________________________
# organization name: OpsBeacon
# website: opsbeacon.com
# generated_description: OpsBeacon is a no-code, AI-powered platform that simplifies system orchestration, automates repetitive tasks, and streamlines incident response for IT and cloud operations. It aims to boost productivity and security by allowing users to create and manage workflows without writing code.
# Tasks/Jobs: Workflow automation, Incident management, System orchestration, Repetitive task automation
# Industry: IT Operations and Cloud Management
# Customers: IT professionals, DevOps engineers, Cloud engineers
# generated_description_conf_interval: 8
# parsed_description_conf_interval: 9
# _________________________
# organization_name: OpsBeacon
# example: An IT professional uses OpsBeacon to automate the process of provisioning new servers by creating a workflow that includes tasks like obtaining server resources, configuring the operating system, and installing necessary software.
# situation_conf_interval: 9.0
# situation_conf_interval_reasoning: This is a common task for IT professionals that OpsBeacon automates through its no-code workflow system.
# job: Computer and Information Systems Managers that provision new servers by obtaining server resources, configuring the operating system, and installing necessary software.
# onet_title: Computer and Information Systems Managers
# onet_task: Purchase necessary equipment.
# example_job_title: Computer and Information Systems Managers
# task_similarity: 0.7230740231785159
# job_title_similarity: 0.9999999999999972
# onet_weight: 0.3333333333333333
# ***************************
#
# ***************************
# Processing 5
# _________________________
# organization name: OpsBeacon
# website: opsbeacon.com
# generated_description: OpsBeacon is a no-code, AI-powered platform that simplifies system orchestration, automates repetitive tasks, and streamlines incident response for IT and cloud operations. It aims to boost productivity and security by allowing users to create and manage workflows without writing code.
# Tasks/Jobs: Workflow automation, Incident management, System orchestration, Repetitive task automation
# Industry: IT Operations and Cloud Management
# Customers: IT professionals, DevOps engineers, Cloud engineers
# generated_description_conf_interval: 8
# parsed_description_conf_interval: 9
# _________________________
# organization_name: OpsBeacon
# example: An IT professional uses OpsBeacon to automate the process of provisioning new servers by creating a workflow that includes tasks like obtaining server resources, configuring the operating system, and installing necessary software.
# situation_conf_interval: 9.0
# situation_conf_interval_reasoning: This is a common task for IT professionals that OpsBeacon automates through its no-code workflow system.
# job: Computer and Information Systems Managers that provision new servers by obtaining server resources, configuring the operating system, and installing necessary software.
# onet_title: Computer and Information Systems Managers
# onet_task: Develop computer information resources, providing for data security and control, strategic computing, and disaster recovery.
# example_job_title: Computer and Information Systems Managers
# task_similarity: 0.7073326754782605
# job_title_similarity: 0.9999999999999972
# onet_weight: 0.3333333333333333
# ***************************
#
# ***************************
# Processing 6
# _________________________
# organization name: OpsBeacon
# website: opsbeacon.com
# generated_description: OpsBeacon is a no-code, AI-powered platform that simplifies system orchestration, automates repetitive tasks, and streamlines incident response for IT and cloud operations. It aims to boost productivity and security by allowing users to create and manage workflows without writing code.
# Tasks/Jobs: Workflow automation, Incident management, System orchestration, Repetitive task automation
# Industry: IT Operations and Cloud Management
# Customers: IT professionals, DevOps engineers, Cloud engineers
# generated_description_conf_interval: 8
# parsed_description_conf_interval: 9
# _________________________
# organization_name: OpsBeacon
# example: An IT professional uses OpsBeacon to automate the process of provisioning new servers by creating a workflow that includes tasks like obtaining server resources, configuring the operating system, and installing necessary software.
# situation_conf_interval: 9.0
# situation_conf_interval_reasoning: This is a common task for IT professionals that OpsBeacon automates through its no-code workflow system.
# job: Computer and Information Systems Managers that provision new servers by obtaining server resources, configuring the operating system, and installing necessary software.
# onet_title: Computer and Information Systems Managers
# onet_task: Manage backup, security and user help systems.
# example_job_title: Computer and Information Systems Managers
# task_similarity: 0.6903894268379506
# job_title_similarity: 0.9999988001296204
# onet_weight: 0.3333333333333333
# ***************************
#
# ***************************
# Processing 7
# _________________________
# organization name: CloudImpact Solutions
# website: www.cloud-impact.org/
# generated_description: CloudImpact Solutions offers a range of cloud-based solutions and services, including cloud migration, DevOps automation, cybersecurity, and ongoing support. They also developed the CloudMate mobile app, which allows users to manage and monitor their cloud environments across various platforms like AWS, Azure, and GCP.
# Tasks/Jobs: Cloud migration, DevOps automation, Cybersecurity, Cloud monitoring
# Industry: Cloud Computing
# Customers: Businesses, Organizations, Cloud users
# generated_description_conf_interval: 8
# parsed_description_conf_interval: 8
# _________________________
# organization_name: CloudImpact Solutions
# example: A system administrator uses the CloudMate app to monitor the performance of their cloud infrastructure, identifying and resolving potential issues before they impact users. This helps them maintain optimal system performance and prevent costly downtime.
# situation_conf_interval: 8.0
# situation_conf_interval_reasoning: System administrators commonly monitor cloud infrastructure, and the app automates the monitoring process.
# job: Computer and Information Systems Managers that monitor the performance of computer systems and networks.
# onet_title: Computer and Information Systems Managers
# onet_task: Manage backup, security and user help systems.
# example_job_title: Computer and Information Systems Managers
# task_similarity: 0.7975302692460455
# job_title_similarity: 0.9999999999999972
# onet_weight: 0.25
# ***************************
#
# ***************************
# Processing 8
# _________________________
# organization name: CloudImpact Solutions
# website: www.cloud-impact.org/
# generated_description: CloudImpact Solutions offers a range of cloud-based solutions and services, including cloud migration, DevOps automation, cybersecurity, and ongoing support. They also developed the CloudMate mobile app, which allows users to manage and monitor their cloud environments across various platforms like AWS, Azure, and GCP.
# Tasks/Jobs: Cloud migration, DevOps automation, Cybersecurity, Cloud monitoring
# Industry: Cloud Computing
# Customers: Businesses, Organizations, Cloud users
# generated_description_conf_interval: 8
# parsed_description_conf_interval: 8
# _________________________
# organization_name: CloudImpact Solutions
# example: A system administrator uses the CloudMate app to monitor the performance of their cloud infrastructure, identifying and resolving potential issues before they impact users. This helps them maintain optimal system performance and prevent costly downtime.
# situation_conf_interval: 8.0
# situation_conf_interval_reasoning: System administrators commonly monitor cloud infrastructure, and the app automates the monitoring process.
# job: Computer and Information Systems Managers that monitor the performance of computer systems and networks.
# onet_title: Computer and Information Systems Managers
# onet_task: Develop computer information resources, providing for data security and control, strategic computing, and disaster recovery.
# example_job_title: Computer and Information Systems Managers
# task_similarity: 0.787258882486396
# job_title_similarity: 0.9999987394994386
# onet_weight: 0.25
# ***************************
#
# ***************************
# Processing 9
# _________________________
# organization name: CloudImpact Solutions
# website: www.cloud-impact.org/
# generated_description: CloudImpact Solutions offers a range of cloud-based solutions and services, including cloud migration, DevOps automation, cybersecurity, and ongoing support. They also developed the CloudMate mobile app, which allows users to manage and monitor their cloud environments across various platforms like AWS, Azure, and GCP.
# Tasks/Jobs: Cloud migration, DevOps automation, Cybersecurity, Cloud monitoring
# Industry: Cloud Computing
# Customers: Businesses, Organizations, Cloud users
# generated_description_conf_interval: 8
# parsed_description_conf_interval: 8
# _________________________
# organization_name: CloudImpact Solutions
# example: A system administrator uses the CloudMate app to monitor the performance of their cloud infrastructure, identifying and resolving potential issues before they impact users. This helps them maintain optimal system performance and prevent costly downtime.
# situation_conf_interval: 8.0
# situation_conf_interval_reasoning: System administrators commonly monitor cloud infrastructure, and the app automates the monitoring process.
# job: Computer and Information Systems Managers that monitor the performance of computer systems and networks.
# onet_title: Computer and Information Systems Managers
# onet_task: Evaluate the organization's technology use and needs and recommend improvements, such as hardware and software upgrades.
# example_job_title: Computer and Information Systems Managers
# task_similarity: 0.75943907022386
# job_title_similarity: 0.9999999999999972
# onet_weight: 0.25
# ***************************
#
# ***************************
# Processing 10
# _________________________
# organization name: Incendrify LTD
# website: www.Incendrify.com
# generated_description: — IT Management, AI, Development, Business Improvement   Description: Incendrify LTD is a technology company specializing in IT management, artificial intelligence, development, and business improvement. They offer a range of solutions and services to help businesses optimize their operations, leverage data insights, and enhance their overall efficiency.
# Tasks/Jobs: IT Automation, Data Analysis, Software Development, Business Process Optimization
# Industry: IT Services
# Customers: Businesses of all sizes, IT departments
# generated_description_conf_interval: 6
# parsed_description_conf_interval: 7
# _________________________
# organization_name: Incendrify LTD
# example: An IT manager uses Incendrify's platform to automate the process of deploying new software updates across the company's network, ensuring consistent and efficient distribution of critical patches and security updates.
# situation_conf_interval: 9.0
# situation_conf_interval_reasoning: This example aligns with the common task of managing software updates and deployments, a core responsibility of IT managers as detailed in the ONET database for Computer and Information Systems Managers.
# job: Computer and Information Systems Managers that deploy new software updates across a company's network.
# onet_title: Computer and Information Systems Managers
# onet_task: Evaluate the organization's technology use and needs and recommend improvements, such as hardware and software upgrades.
# example_job_title: Computer and Information Systems Managers
# task_similarity: 0.7107036900596506
# job_title_similarity: 0.9997819789067524
# onet_weight: 0.1111111111111111
# ***************************
#
# ***************************
# Processing 11
# _________________________
# organization name: Incendrify LTD
# website: www.Incendrify.com
# generated_description: — IT Management, AI, Development, Business Improvement   Description: Incendrify LTD is a technology company specializing in IT management, artificial intelligence, development, and business improvement. They offer a range of solutions and services to help businesses optimize their operations, leverage data insights, and enhance their overall efficiency.
# Tasks/Jobs: IT Automation, Data Analysis, Software Development, Business Process Optimization
# Industry: IT Services
# Customers: Businesses of all sizes, IT departments
# generated_description_conf_interval: 6
# parsed_description_conf_interval: 7
# _________________________
# organization_name: Incendrify LTD
# example: An IT manager uses Incendrify's platform to automate the process of deploying new software updates across the company's network, ensuring consistent and efficient distribution of critical patches and security updates.
# situation_conf_interval: 9.0
# situation_conf_interval_reasoning: This example aligns with the common task of managing software updates and deployments, a core responsibility of IT managers as detailed in the ONET database for Computer and Information Systems Managers.
# job: Computer and Information Systems Managers that deploy new software updates across a company's network.
# onet_title: Computer and Information Systems Managers
# onet_task: Stay abreast of advances in technology.
# example_job_title: Computer and Information Systems Managers
# task_similarity: 0.6974180943012743
# job_title_similarity: 0.9997819789067524
# onet_weight: 0.1111111111111111
# ***************************
#
# ***************************
# Processing 12
# _________________________
# organization name: Incendrify LTD
# website: www.Incendrify.com
# generated_description: — IT Management, AI, Development, Business Improvement   Description: Incendrify LTD is a technology company specializing in IT management, artificial intelligence, development, and business improvement. They offer a range of solutions and services to help businesses optimize their operations, leverage data insights, and enhance their overall efficiency.
# Tasks/Jobs: IT Automation, Data Analysis, Software Development, Business Process Optimization
# Industry: IT Services
# Customers: Businesses of all sizes, IT departments
# generated_description_conf_interval: 6
# parsed_description_conf_interval: 7
# _________________________
# organization_name: Incendrify LTD
# example: An IT manager uses Incendrify's platform to automate the process of deploying new software updates across the company's network, ensuring consistent and efficient distribution of critical patches and security updates.
# situation_conf_interval: 9.0
# situation_conf_interval_reasoning: This example aligns with the common task of managing software updates and deployments, a core responsibility of IT managers as detailed in the ONET database for Computer and Information Systems Managers.
# job: Computer and Information Systems Managers that deploy new software updates across a company's network.
# onet_title: Computer and Information Systems Managers
# onet_task: Manage backup, security and user help systems.
# example_job_title: Computer and Information Systems Managers
# task_similarity: 0.6898304575390475
# job_title_similarity: 0.9997805063423888
# onet_weight: 0.1111111111111111
# ***************************
#
# ***************************
# Processing 13
# _________________________
# organization name: Univext
# website: univext.com
# generated_description: Univext is an online learning platform offering a wide range of courses including languages, programming, and web design, delivered by native, experienced instructors. The platform leverages AI to personalize learning, offers real-time interaction, and provides flexible learning options, all while striving to make high-quality education accessible.
# Tasks/Jobs: Learning path personalization, Content recommendation, AI-powered tutoring, Real-time interaction with instructors
# Industry: Online Education
# Customers: Students, Learners, Individuals seeking to acquire new skills
# generated_description_conf_interval: 8
# parsed_description_conf_interval: 9
# _________________________
# organization_name: Univext
# example: An aspiring web designer leverages the platform's AI-powered tutoring system to receive personalized instruction and guidance on complex coding concepts, overcoming learning obstacles and accelerating their skill development.
# situation_conf_interval: 7.0
# situation_conf_interval_reasoning: The platform replaces the need for a human tutor or mentor by providing an AI-powered solution that offers personalized instruction and guidance on technical concepts.
# job: Computer and Information Systems Managers that provide guidance and support to software developers and web designers.
# onet_title: Computer and Information Systems Managers
# onet_task: Develop computer information resources, providing for data security and control, strategic computing, and disaster recovery.
# example_job_title: Computer and Information Systems Managers
# task_similarity: 0.7636436126914183
# job_title_similarity: 0.9999999999999972
# onet_weight: 0.3333333333333333
# ***************************
#
# ***************************
# Processing 14
# _________________________
# organization name: Univext
# website: univext.com
# generated_description: Univext is an online learning platform offering a wide range of courses including languages, programming, and web design, delivered by native, experienced instructors. The platform leverages AI to personalize learning, offers real-time interaction, and provides flexible learning options, all while striving to make high-quality education accessible.
# Tasks/Jobs: Learning path personalization, Content recommendation, AI-powered tutoring, Real-time interaction with instructors
# Industry: Online Education
# Customers: Students, Learners, Individuals seeking to acquire new skills
# generated_description_conf_interval: 8
# parsed_description_conf_interval: 9
# _________________________
# organization_name: Univext
# example: An aspiring web designer leverages the platform's AI-powered tutoring system to receive personalized instruction and guidance on complex coding concepts, overcoming learning obstacles and accelerating their skill development.
# situation_conf_interval: 7.0
# situation_conf_interval_reasoning: The platform replaces the need for a human tutor or mentor by providing an AI-powered solution that offers personalized instruction and guidance on technical concepts.
# job: Computer and Information Systems Managers that provide guidance and support to software developers and web designers.
# onet_title: Computer and Information Systems Managers
# onet_task: Manage backup, security and user help systems.
# example_job_title: Computer and Information Systems Managers
# task_similarity: 0.7522144158483208
# job_title_similarity: 0.9999999999999972
# onet_weight: 0.3333333333333333
# ***************************
#
# ***************************
# Processing 15
# _________________________
# organization name: Univext
# website: univext.com
# generated_description: Univext is an online learning platform offering a wide range of courses including languages, programming, and web design, delivered by native, experienced instructors. The platform leverages AI to personalize learning, offers real-time interaction, and provides flexible learning options, all while striving to make high-quality education accessible.
# Tasks/Jobs: Learning path personalization, Content recommendation, AI-powered tutoring, Real-time interaction with instructors
# Industry: Online Education
# Customers: Students, Learners, Individuals seeking to acquire new skills
# generated_description_conf_interval: 8
# parsed_description_conf_interval: 9
# _________________________
# organization_name: Univext
# example: An aspiring web designer leverages the platform's AI-powered tutoring system to receive personalized instruction and guidance on complex coding concepts, overcoming learning obstacles and accelerating their skill development.
# situation_conf_interval: 7.0
# situation_conf_interval_reasoning: The platform replaces the need for a human tutor or mentor by providing an AI-powered solution that offers personalized instruction and guidance on technical concepts.
# job: Computer and Information Systems Managers that provide guidance and support to software developers and web designers.
# onet_title: Computer and Information Systems Managers
# onet_task: Develop and interpret organizational goals, policies, and procedures.
# example_job_title: Computer and Information Systems Managers
# task_similarity: 0.7475924039455649
# job_title_similarity: 0.9999999999999972
# onet_weight: 0.3333333333333333
# ***************************
#
# ***************************
# Processing 16
# _________________________
# organization name: OpsBerry AI
# website: opsberry.ai
# generated_description: OpsBerry AI is a no-code platform that automates workflows and runbooks for IT operations teams, similar to Retool but specifically designed for DevOps, SREs, and IT operations. OpsBerry AI's AI-powered automation helps reduce manual work, incident response time, and escalations, freeing up teams to focus on strategic initiatives and improving overall operational efficiency.
# Tasks/Jobs: Workflow automation, Runbook execution, Incident response, Alerting and monitoring
# Industry: IT Operations
# Customers: DevOps teams, SREs, IT operations teams
# generated_description_conf_interval: 9
# parsed_description_conf_interval: 9
# _________________________
# organization_name: OpsBerry AI
# example: An IT operations manager uses OpsBerry AI to automatically gather data from various monitoring tools and generate reports on system performance, identifying potential bottlenecks and areas for improvement.
# situation_conf_interval: 7.0
# situation_conf_interval_reasoning: While this task is broader, OpsBerry AI's ability to automate data collection and reporting from various sources makes it a useful tool for this task, freeing up IT operations managers to focus on higher-level decisions.
# job: Computer and Information Systems Managers that collect data on system performance and generate reports manually to identify bottlenecks and areas for improvement.
# onet_title: Computer and Information Systems Managers
# onet_task: Prepare and review operational reports or project progress reports.
# example_job_title: Computer and Information Systems Managers
# task_similarity: 0.7734474437146663
# job_title_similarity: 0.9999999999999972
# onet_weight: 0.3333333333333333
# ***************************
#
# ***************************
# Processing 17
# _________________________
# organization name: OpsBerry AI
# website: opsberry.ai
# generated_description: OpsBerry AI is a no-code platform that automates workflows and runbooks for IT operations teams, similar to Retool but specifically designed for DevOps, SREs, and IT operations. OpsBerry AI's AI-powered automation helps reduce manual work, incident response time, and escalations, freeing up teams to focus on strategic initiatives and improving overall operational efficiency.
# Tasks/Jobs: Workflow automation, Runbook execution, Incident response, Alerting and monitoring
# Industry: IT Operations
# Customers: DevOps teams, SREs, IT operations teams
# generated_description_conf_interval: 9
# parsed_description_conf_interval: 9
# _________________________
# organization_name: OpsBerry AI
# example: An IT operations manager uses OpsBerry AI to automatically gather data from various monitoring tools and generate reports on system performance, identifying potential bottlenecks and areas for improvement.
# situation_conf_interval: 7.0
# situation_conf_interval_reasoning: While this task is broader, OpsBerry AI's ability to automate data collection and reporting from various sources makes it a useful tool for this task, freeing up IT operations managers to focus on higher-level decisions.
# job: Computer and Information Systems Managers that collect data on system performance and generate reports manually to identify bottlenecks and areas for improvement.
# onet_title: Computer and Information Systems Managers
# onet_task: Evaluate the organization's technology use and needs and recommend improvements, such as hardware and software upgrades.
# example_job_title: Computer and Information Systems Managers
# task_similarity: 0.7036502467820869
# job_title_similarity: 0.9999999999999972
# onet_weight: 0.3333333333333333
# ***************************
#
# ***************************
# Processing 18
# _________________________
# organization name: OpsBerry AI
# website: opsberry.ai
# generated_description: OpsBerry AI is a no-code platform that automates workflows and runbooks for IT operations teams, similar to Retool but specifically designed for DevOps, SREs, and IT operations. OpsBerry AI's AI-powered automation helps reduce manual work, incident response time, and escalations, freeing up teams to focus on strategic initiatives and improving overall operational efficiency.
# Tasks/Jobs: Workflow automation, Runbook execution, Incident response, Alerting and monitoring
# Industry: IT Operations
# Customers: DevOps teams, SREs, IT operations teams
# generated_description_conf_interval: 9
# parsed_description_conf_interval: 9
# _________________________
# organization_name: OpsBerry AI
# example: An IT operations manager uses OpsBerry AI to automatically gather data from various monitoring tools and generate reports on system performance, identifying potential bottlenecks and areas for improvement.
# situation_conf_interval: 7.0
# situation_conf_interval_reasoning: While this task is broader, OpsBerry AI's ability to automate data collection and reporting from various sources makes it a useful tool for this task, freeing up IT operations managers to focus on higher-level decisions.
# job: Computer and Information Systems Managers that collect data on system performance and generate reports manually to identify bottlenecks and areas for improvement.
# onet_title: Computer and Information Systems Managers
# onet_task: Manage backup, security and user help systems.
# example_job_title: Computer and Information Systems Managers
# task_similarity: 0.6852962033606356
# job_title_similarity: 0.9999999999999972
# onet_weight: 0.3333333333333333
# ***************************
#
# ***************************
# Processing 19
# _________________________
# organization name: MyMagic AI
# website: mymagic.ai/
# generated_description: MyMagic AI is a platform that provides scalable and high-performance distributed compute clusters for batch inference of open-source LLMs. This enables users to conduct large-scale inference and fine-tuning with open-source models at a significantly lower cost compared to other solutions.
# Tasks/Jobs: Large-scale inference, model fine-tuning, distributed compute, batch processing
# Industry: Machine Learning/AI
# Customers: Researchers, Developers, Businesses
# generated_description_conf_interval: 8
# parsed_description_conf_interval: 9
# _________________________
# organization_name: MyMagic AI
# example: A researcher utilizes the platform to conduct large-scale inference on an open-source language model, analyzing a massive dataset of text to uncover trends and insights. This replaces the need for manual analysis and allows for processing significantly more data.
# situation_conf_interval: 8.0
# situation_conf_interval_reasoning: This task aligns with the job responsibilities of Computer and Information Systems Managers, particularly in the area of data analysis and research.
# job: Computer and Information Systems Managers who analyze data and perform research.
# onet_title: Computer and Information Systems Managers
# onet_task: Develop computer information resources, providing for data security and control, strategic computing, and disaster recovery.
# example_job_title: Computer and Information Systems Managers
# task_similarity: 0.757587747938723
# job_title_similarity: 0.9999999999999972
# onet_weight: 0.2
# ***************************
#
# ***************************
# Processing 20
# _________________________
# organization name: MyMagic AI
# website: mymagic.ai/
# generated_description: MyMagic AI is a platform that provides scalable and high-performance distributed compute clusters for batch inference of open-source LLMs. This enables users to conduct large-scale inference and fine-tuning with open-source models at a significantly lower cost compared to other solutions.
# Tasks/Jobs: Large-scale inference, model fine-tuning, distributed compute, batch processing
# Industry: Machine Learning/AI
# Customers: Researchers, Developers, Businesses
# generated_description_conf_interval: 8
# parsed_description_conf_interval: 9
# _________________________
# organization_name: MyMagic AI
# example: A researcher utilizes the platform to conduct large-scale inference on an open-source language model, analyzing a massive dataset of text to uncover trends and insights. This replaces the need for manual analysis and allows for processing significantly more data.
# situation_conf_interval: 8.0
# situation_conf_interval_reasoning: This task aligns with the job responsibilities of Computer and Information Systems Managers, particularly in the area of data analysis and research.
# job: Computer and Information Systems Managers who analyze data and perform research.
# onet_title: Computer and Information Systems Managers
# onet_task: Prepare and review operational reports or project progress reports.
# example_job_title: Computer and Information Systems Managers
# task_similarity: 0.7203512359997397
# job_title_similarity: 0.9999999999999972
# onet_weight: 0.2
# ***************************
# UsageError: Line magic function `%%capture` not found.

# %%
# Out:
#                    organization_name  \
# 0                              Catio
# 1                              Catio
# 2                              Catio
# 3                              Catio
# 4     Helios Artificial Intelligence
# ...                              ...
# 3179               Redacted Holdings
# 3180               Redacted Holdings
# 3181               Redacted Holdings
# 3182               Redacted Holdings
# 3183               Redacted Holdings
#
#                                                 example  \
# 0     A cloud architect uses Catio to evaluate diffe...
# 1     A cloud architect uses Catio to evaluate diffe...
# 2     A cloud architect uses Catio to evaluate diffe...
# 3     An IT professional uses Catio to continuously ...
# 4     A supply chain manager uses the AI platform to...
# ...                                                 ...
# 3179  A venture capitalist uses the platform to auto...
# 3180  A venture capitalist uses the platform to cond...
# 3181  A venture capitalist uses the platform to moni...
# 3182  A venture capitalist uses the platform to moni...
# 3183  A venture capitalist uses the platform to moni...
#
#       situation_conf_interval  \
# 0                         9.0
# 1                         9.0
# 2                         9.0
# 3                         7.0
# 4                         9.0
# ...                       ...
# 3179                      8.0
# 3180                      7.0
# 3181                      8.0
# 3182                      8.0
# 3183                      8.0
#
#                       situation_conf_interval_reasoning  \
# 0     The provided description aligns with the respo...
# 1     The provided description aligns with the respo...
# 2     The provided description aligns with the respo...
# 3     While the task description is broad, it aligns...
# 4     The ONET Job description for Supply Chain Mana...
# ...                                                 ...
# 3179  This is a common task for financial analysts w...
# 3180  This is a core activity in venture capital, an...
# 3181  This is a crucial task for venture capitalists...
# 3182  This is a crucial task for venture capitalists...
# 3183  This is a crucial task for venture capitalists...
#
#                                                     job  \
# 0     Computer and Information Systems Managers that...
# 1     Computer and Information Systems Managers that...
# 2     Computer and Information Systems Managers that...
# 3     Systems Administrators that monitor and analyz...
# 4     Supply Chain Managers that analyze global trad...
# ...                                                 ...
# 3179  Financial Analysts that analyze market trends ...
# 3180  Financial Analysts that conduct due diligence ...
# 3181  Portfolio Managers that monitor the performanc...
# 3182  Portfolio Managers that monitor the performanc...
# 3183  Portfolio Managers that monitor the performanc...
#
#                                        onet_title  \
# 0       Computer and Information Systems Managers
# 1       Computer and Information Systems Managers
# 2       Computer and Information Systems Managers
# 3     Network and Computer Systems Administrators
# 4                           Supply Chain Managers
# ...                                           ...
# 3179            Financial and Investment Analysts
# 3180            Financial and Investment Analysts
# 3181                     Investment Fund Managers
# 3182                     Investment Fund Managers
# 3183                     Investment Fund Managers
#
#                                               onet_task  \
# 0     Evaluate the organization's technology use and...
# 1     Consult with users, management, vendors, and t...
# 2     Develop computer information resources, provid...
# 3     Monitor network performance to determine wheth...
# 4     Monitor forecasts and quotas to identify chang...
# ...                                                 ...
# 3179  Recommend investments and investment timing to...
# 3180  Assess companies as investments for clients by...
# 3181  Monitor financial or operational performance o...
# 3182  Perform or evaluate research, such as detailed...
# 3183  Develop, implement, or monitor security valuat...
#
#                               example_job_title  task_similarity  \
# 0     Computer and Information Systems Managers         0.730842
# 1     Computer and Information Systems Managers         0.704641
# 2     Computer and Information Systems Managers         0.704586
# 3                        Systems Administrators         0.650572
# 4                         Supply Chain Managers         0.708903
# ...                                         ...              ...
# 3179                         Financial Analysts         0.738179
# 3180                         Financial Analysts         0.654443
# 3181                         Financial Analysts         0.773301
# 3182                         Financial Analysts         0.680770
# 3183                         Financial Analysts         0.671068
#
#       job_title_similarity  onet_weight
# 0                 0.999999     0.250000
# 1                 0.999999     0.250000
# 2                 0.999999     0.250000
# 3                 0.741931     0.250000
# 4                 1.000000     0.111111
# ...                    ...          ...
# 3179              0.843050     0.142857
# 3180              0.842992     0.142857
# 3181              0.450171     0.142857
# 3182              0.450058     0.142857
# 3183              0.450171     0.142857
#
# [3184 rows x 11 columns]

# %%
len(df["organization name"].unique())
# Out:
# 419

# %%
len(startup_df)
# Out:
# 990

# %%
out.onet_weights
# Out:
#     organization_name  onet_weight
# 0     AI Fashion Week     0.500000
# 1        AI Mavericks     1.000000
# 2           AI Square     0.166667
# 3               AIcon     1.000000
# 4            AIgeeked     0.333333
# ..                ...          ...
# 235           inPlace     0.500000
# 236       mimilabs.ai     0.333333
# 237            reprai     1.000000
# 238         stylio.ai     1.000000
# 239      tenXclinical     0.500000
#
# [240 rows x 2 columns]
