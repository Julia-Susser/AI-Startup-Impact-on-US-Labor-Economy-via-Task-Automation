# %%
import pandas as pd


onet_df = pd.read_csv("../output/onet_df.csv")
df = pd.read_csv('../output/df_with_examples.csv')
df.automation_rating
# Out:
# 0    7
# 1    4
# 2    7
# 3    3
# 4    8
# 5    4
# 6    4
# 7    7
# 8    3
# 9    7
# Name: automation_rating, dtype: int64

# %%
df = df[["organization name","automation_rating"]]

# %%
onet_df = onet_df.groupby("example").aggregate({"task_similarity":"max","organization_name":"first"}).reset_index()

# %%
onet_df.merge(df,left_on="organization_name",right_on="organization name")
# Out:
#                                               example  task_similarity  \
# 0   A company is seeking to streamline its hiring ...         0.576671
# 1   A hiring manager at a tech company is struggli...         0.791690
# 2   A job seeker is looking for a new role in mark...         0.412760
# 3   A company wants to use AI to analyze their web...         0.629135
# 4   A marketing team wants to automate their email...         0.634060
# 5   A small business owner is looking to improve t...         0.657969
# 6   A content marketing manager for a technology c...         0.671612
# 7   A freelance writer is struggling to come up wi...         0.621673
# 8   A small business owner needs to write engaging...         0.614281
# 9   A customer service representative at a financi...         0.716859
# 10  A marketing manager at a large retail company ...         0.751364
# 11  A project manager at a software development co...         0.700576
# 12  A customer support agent at a SaaS company is ...         0.782619
# 13  A marketing team at a SaaS company wants to se...         0.722792
# 14  A software developer needs to integrate a thir...         0.738137
# 15  A data scientist at a financial institution is...         0.782953
# 16  A research scientist at a pharmaceutical compa...         0.656189
# 17  An engineer at an automotive company is workin...         0.709211
# 18  A dental assistant at a busy dental practice u...         0.780110
# 19  A new patient contacts the dental practice. Ro...         0.649855
# 20  A patient calls the dental practice with quest...         0.668298
# 21  A digital marketing agency is tasked with impr...         0.713392
# 22  A small business owner wants to increase their...         0.600800
# 23  A website owner is struggling to rank their we...         0.878078
# 24  A financial services company wants to move the...         0.752480
# 25  A marketing team at a large e-commerce company...         0.680006
# 26  A software developer working on a new mobile a...         0.676111
# 27  A robotics engineer is developing a robotic ar...         0.727449
# 28  An AI researcher is developing an AI system fo...         0.510436
# 29  An autonomous vehicle manufacturer is testing ...         0.569015
#
#          organization_name       organization name  automation_rating
# 0                  Magnifi                 Magnifi                  7
# 1                  Magnifi                 Magnifi                  7
# 2                  Magnifi                 Magnifi                  7
# 3   Learn Marketing AI LLC  Learn Marketing AI LLC                  2
# 4   Learn Marketing AI LLC  Learn Marketing AI LLC                  2
# 5   Learn Marketing AI LLC  Learn Marketing AI LLC                  2
# 6                 crear.ai                crear.ai                  8
# 7                 crear.ai                crear.ai                  8
# 8                 crear.ai                crear.ai                  8
# 9                  Sentius                 Sentius                  8
# 10                 Sentius                 Sentius                  8
# 11                 Sentius                 Sentius                  8
# 12                DryMerge                DryMerge                  8
# 13                DryMerge                DryMerge                  8
# 14                DryMerge                DryMerge                  8
# 15             Luming Labs             Luming Labs                  7
# 16             Luming Labs             Luming Labs                  7
# 17             Luming Labs             Luming Labs                  7
# 18               Rondah AI               Rondah AI                  9
# 19               Rondah AI               Rondah AI                  9
# 20               Rondah AI               Rondah AI                  9
# 21            Post Cheetah            Post Cheetah                  7
# 22            Post Cheetah            Post Cheetah                  7
# 23            Post Cheetah            Post Cheetah                  7
# 24               N3XGEN.io               N3XGEN.io                  7
# 25               N3XGEN.io               N3XGEN.io                  7
# 26               N3XGEN.io               N3XGEN.io                  7
# 27                ViVum AI                ViVum AI                  8
# 28                ViVum AI                ViVum AI                  8
# 29                ViVum AI                ViVum AI                  8

# %%
df_exp = pd.read_csv('../input/gpts_labels/gpt_exposure_embeddings.csv')

df_exp.task_embedding = df_exp.task_embedding.apply(lambda x: x.strip("[]").split(", "))

task_embeddings = []
for x in df_exp.task_embedding:
    task_embeddings.append([float(y) for y in x])
df_exp.task_embedding = task_embeddings


task_embeddings = np.array(task_embeddings)
task_embeddings = np.vstack(task_embeddings)

# %%
df_exp.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 O*NET-SOC Code           title  Task ID  \
# 0             0           0     11-2022.00  Sales Managers        1
# 1             1           1     11-2022.00  Sales Managers        2
# 2             2           2     11-2022.00  Sales Managers        4
# 3             3           3     11-2022.00  Sales Managers        5
# 4             4           4     11-2022.00  Sales Managers        7
#
#                                                 Task human_labels  \
# 0  Resolve customer complaints regarding sales an...           E1
# 1  Monitor customer preferences to determine focu...           E2
# 2      Determine price schedules and discount rates.           E2
# 3  Review operational records and reports to proj...           E2
# 4  Confer or consult with department heads to pla...           E2
#
#   gpt_4_exposure gpt_4_automation  human_numeric  gpt_4_numeric  \
# 0             E2               T2            1.0            0.5
# 1             E2               T2            0.5            0.5
# 2             E2               T3            0.5            0.5
# 3             E2               T3            0.5            0.5
# 4             E2               T1            0.5            0.5
#
#    gpt_4_automation_numeric  \
# 0                      0.50
# 1                      0.50
# 2                      0.75
# 3                      0.75
# 4                      0.25
#
#                                          description  \
# 0  Sales managers that resolve customer complaint...
# 1  Sales managers that monitor customer preferenc...
# 2  Sales managers that determine price schedules ...
# 3  Sales managers that review operational records...
# 4  Sales managers that confer or consult with dep...
#
#                                description_lemmatize title_lemmatize  \
# 0  Sales manager resolve customer complaint regar...  Sales Managers
# 1  Sales manager monitor customer preference dete...  Sales Managers
# 2  Sales manager determine price schedule discoun...  Sales Managers
# 3  Sales manager review operational record report...  Sales Managers
# 4  Sales manager confer consult department head p...  Sales Managers
#
#                                       task_embedding  \
# 0  [0.016493750736117363, -0.03148558735847473, -...
# 1  [0.014145652763545513, -0.03190561383962631, -...
# 2  [-0.012617304921150208, -0.019522329792380333,...
# 3  [0.0030988624785095453, -0.014100999571383, -0...
# 4  [0.020260345190763474, -0.029667407274246216, ...
#
#                                      title_embedding
# 0  [0.009512732736766338, -0.012322365306317806, ...
# 1  [0.009512732736766338, -0.012322365306317806, ...
# 2  [0.009512732736766338, -0.012322365306317806, ...
# 3  [0.009496078826487064, -0.012364077381789684, ...
# 4  [0.009512732736766338, -0.012322365306317806, ...

# %%
import nest_asyncio
import aiohttp
import asyncio
import nest_asyncio
import re
import time
import pandas as pd
import numpy as np
from dotenv import load_dotenv
import os
from os import getenv
from openai import OpenAI
import pathlib
import textwrap
# import google.generativeai as genai
import time
import requests
import ast
import json
from sklearn.metrics.pairwise import cosine_similarity
import re
from llms import chatGPT
from llms import gemini


x_chat = chatGPT()
x_gemini = gemini()
nest_asyncio.apply()


class prompting():
    def __init__(self):
        self.results_df = pd.DataFrame(columns=["organization name", "value"])

    def set_current_results_df(self, results_df):
        self.results_df = results_df

    async def iterate(self, df, prompt_template, args, value, batch_size=10, start=0, end=False):
        if end == False:
            end = len(df)
        self.results_df = pd.DataFrame(columns=["organization name", value])
        if value in list(df.columns):
            if start != 0:
                self.results_df = pd.concat([df[["organization name", value]].iloc[:start], self.results_df], axis=0)
            df = df.drop(columns=[value])

        batch_prompts = []
        batch_indices = []

        for i, row in list(df.iterrows())[start:end]:
            name = row['organization name']
            website = row['website']
            prompt = prompt_template

            for arg in args:
                prompt = prompt.replace(f"${arg[0]}", row[arg[1]])

            batch_prompts.append((i, name, prompt))
            batch_indices.append(i)

            if len(batch_prompts) >= batch_size:
                await self.process_batch(batch_prompts)
                batch_prompts = []

        if batch_prompts:
            await self.process_batch(batch_prompts)
            self.results_df.to_csv("../output/current_results_df_prompting.csv")

        df = df.merge(self.results_df, on='organization name', how='left')
        return df

    async def process_batch(self, batch_prompts):
        async with aiohttp.ClientSession() as session:
            tasks = []
            for i, name, prompt in batch_prompts:
                tasks.append(self.fetch_result(session, i, name, prompt))
            await asyncio.gather(*tasks)

    async def fetch_result(self, session, i, name, prompt):
        failure_count = 0
        while True:
            try:
                print(f"******************************\nProcessing {i}: {name}")
                result = await x_gemini.ask(session, prompt)
                if result == "N/A": break  # explicit material

                text = re.sub(r"#|#\s+|_|\*", "", result).strip()

                self.results_df.loc[i] = [name, text]

                    
                break
            except Exception as e:
                print(failure_count)
                failure_count += 1
                if failure_count > 10:
                    break
                print(f"Error processing {i}, {name}: {e}")
                await asyncio.sleep(20)

prompting_class = prompting()

# %%
# df2 = pd.read_csv('../output/df_with_parsed_description.csv').iloc[:10]
# df2["Task"] = (df2["Customers"] + " that do " + df2["Tasks/Jobs"]).values
df = pd.read_csv('../output/results/df_with_parsed_description.csv').iloc[:10]
df["Task"] = (df["Customers"] + " that do " + df["Tasks/Jobs"]).values

# %%
df.head()
# Out:
#   organization name                                   full_description  \
# 0      AI Mavericks  AI Mavericks is an event management company th...
# 1    Campaign Brain                                                  —
# 2           Sentius  Utilize AI like never before. At Sentius, we’r...
# 3       Vadar Alpha  Vadar Alpha provides intelligence augmentation...
# 4         Cognifyze  The revolutionary AI-based platform that enabl...
#
#                                           industries  \
# 0  Artificial Intelligence (AI), Consulting, Even...
# 1  Artificial Intelligence (AI), Cyber Security, ...
# 2        Artificial Intelligence (AI), Generative AI
# 3                                           Software
# 4                             Information Technology
#
#                   headquarters location founded date  \
# 0             Lehi, Utah, United States   2023-10-24
# 1     New York, New York, United States   2023-01-01
# 2  San Mateo, California, United States   2023-05-04
# 3   Green Bay, Wisconsin, United States   2024-01-01
# 4   Wilmington, Delaware, United States   2023-10-06
#
#                                          description  CB rank  \
# 0                           Event Management Company        —
# 1  Campaign Brain offers AI-driven tools for targ...        —
# 2  We automate enterprise tasks with Generative A...  266,701
# 3  Vadar Alpha provides intelligence augmentation...        —
# 4  Our SaaS platform uses AI to analyze sales dat...        —
#
#                                  headquarters region postal code  \
# 0                                         Western US           —
# 1  Greater New York Area, East Coast, Northeaster...       10013
# 2  San Francisco Bay Area, Silicon Valley, West C...       94404
# 3                         Great Lakes, Midwestern US           —
# 4  Greater Philadelphia Area, East Coast, Souther...       19808
#
#   estimated revenue  ... automation_rating  \
# 0                 —  ...                 2
# 1                 —  ...                 8
# 2                 —  ...                 8
# 3                 —  ...                 8
# 4                 —  ...                 8
#
#                          automation_rating_reasoning  \
# 0  AI Mavericks is an event management company th...
# 1  Campaign Brain automates tasks currently done ...
# 2  Sentius's focus on automating enterprise tasks...
# 3  Vadar Alpha directly tackles a core function w...
# 4  Cognifyze's AI-powered platform directly analy...
#
#                               parsed_description_llm  \
# 0  AI Mavericks Analysis:\n\nTasks/Jobs: Conferen...
# 1  Campaign Brain Analysis\n\nTasks/Jobs: Voter t...
# 2  Sentius\n\nTasks/Jobs: Task automation, Proces...
# 3  Vadar Alpha\n\nTasks/Jobs: Freight route optim...
# 4  Cognifyze Analysis\n\nTasks/Jobs: Sales data a...
#
#                                   parsed_description  \
# 0  Tasks/Jobs: Conference planning, Workshop orga...
# 1  Tasks/Jobs: Voter targeting, Messaging optimiz...
# 2  Tasks/Jobs: Task automation, Process optimizat...
# 3  Tasks/Jobs: Freight route optimization, shipme...
# 4  Tasks/Jobs: Sales data analysis, Sales strateg...
#
#                                           Tasks/Jobs  \
# 0  Conference planning, Workshop organization, AI...
# 1  Voter targeting, Messaging optimization, Fundr...
# 2  Task automation, Process optimization, Data an...
# 3  Freight route optimization, shipment tracking,...
# 4  Sales data analysis, Sales strategy optimizati...
#
#                                 Industry  \
# 0        Event management, AI consulting
# 1          Political Campaign Management
# 2                  Enterprise automation
# 3  Logistics and Supply Chain Management
# 4                             B2B Retail
#
#                                            Customers  \
# 0                   Business leaders, Founders, CEOs
# 1  Campaign Managers, Political Candidates, Campa...
# 2       Business leaders, IT managers, Data analysts
# 3  Freight forwarders, Shipping companies, Logist...
# 4   Sales managers, Sales directors, Business owners
#
#   parsed_description_conf_interval  \
# 0                                9
# 1                                9
# 2                                6
# 3                                9
# 4                                9
#
#           parsed_description_conf_interval_reasoning  \
# 0  The description explicitly mentions AI-focused...
# 1  The company description explicitly states the ...
# 2  The description highlights AI-powered agents f...
# 3  The company's focus on optimizing freight oper...
# 4  The description directly outlines the platform...
#
#                                                 Task
# 0  Business leaders, Founders, CEOs that do Confe...
# 1  Campaign Managers, Political Candidates, Campa...
# 2  Business leaders, IT managers, Data analysts t...
# 3  Freight forwarders, Shipping companies, Logist...
# 4  Sales managers, Sales directors, Business owne...
#
# [5 rows x 50 columns]

# %%
args = [["Task","Task"]]
prompt = """
$Task
Make into ONE sentence about task (no AI)!! SIMPLE!!! 
Format as: (OCCUPATION TITLE) + "that" + (ACTIVITY)
"""
async def main(df):
    df = await prompting_class.iterate(df, prompt, args, "new Task")
    df.to_csv('../output/df_with_generated_description.csv', index=False)
    return df

df = asyncio.run(main(df))
# Out:
# ******************************
# Processing 0: AI Mavericks
# ******************************
# Processing 1: Campaign Brain
# ******************************
# Processing 2: Sentius
# ******************************
# Processing 3: Vadar Alpha
# ******************************
# Processing 4: Cognifyze
# ******************************
# Processing 5: Beneree
# ******************************
# Processing 6: Insightful Revenue
# ******************************
# Processing 7: Sups
# ******************************
# Processing 8: SQDL
# ******************************
# Processing 9: Intelizen

# %%
df["new Task"].iloc[3]
# Out:
# 'Freight forwarders, shipping companies, and logistics providers that optimize freight routes, track shipments, forecast demand, and manage risk.'

# %%
df['new Task'] = df['new Task'].replace('"', '', regex=True)

# %%
df = x_chat.run_batch_embeddings(df,'new Task')
for index, row in list(df.iterrows())[0:]:
    print("***********************")
    print(f"Processing {index}")
    name = row["organization name"]
    print(name)
    print(row["generated_description"])
# Out:
#               organization name founded date number of employees  \
# 0                 Anima Biotech   2014-01-01              51-100
# 1  Few - Digital Product Agency   2014-01-03               11-50
# 2                   Bliss Point   2014-01-01             101-250
# 3                    Sober Grid   2014-01-01               11-50
# 4                        Trupik   2014-01-01               11-50
# 5               Seamless Planet   2014-01-01                1-10
# 6                Quartet Health   2014-01-01             101-250
# 7                            ON   2014-02-01              51-100
# 8                ROBOTERRA, Inc   2014-01-26              51-100
# 9        Esperanto Technologies   2014-01-01              51-100
#
#                                           industries  \
# 0                                      Biotechnology
# 1  Android,Artificial Intelligence (AI),Augmented...
# 2  Advertising,Machine Learning,Marketing,Video S...
# 3  Addiction Treatment,Health Care,Home Health Ca...
# 4  Apps,Artificial Intelligence (AI),Computer Vis...
# 5  Artificial Intelligence (AI),Impact Investing,...
# 6  Health Care,Hospital,Information Technology,Me...
# 7        Digital Media,Messaging,Social Media,Sports
# 8  Artificial Intelligence (AI),DIY,Education,Har...
# 9  Artificial Intelligence (AI),Computer,Energy E...
#
#                                     full description  \
# 0  We are advancing mRNA Lightning, a novel platf...
# 1  Few is an award-winning agency that works with...
# 2  Bliss Point renders video advertising and perf...
# 3  Sober Grid is digital health company focused o...
# 4  TRUPIK is the result of a shared vision, of a ...
# 5  At Seamless Planet our mission is to provide a...
# 6  Quartet is a platform that makes it easier for...
# 7  ON is an enterprise-grade AI platform that is ...
# 8  RoboTerra, Inc. is an educational robotics com...
# 9  Esperanto Technologies develops massively para...
#
#                                          description  \
# 0  Discovery of small molecule mRNA drugs and the...
# 1  Few helps you get your digital products, apps,...
# 2  Bliss Point renders video advertising and perf...
# 3  Sober Grid is a digital health application foc...
# 4  Trupik - Helping Retailers Revolutionize Onlin...
# 5  Seamless Planet provides real-time access to a...
# 6  Quartet Health is a platform that makes it eas...
# 7  ON is an enterprise AI platform trusted for co...
# 8  RoboTerra Inc. is a robotics company aiming to...
# 9  Esperanto Technologies develops massively para...
#
#                     website  \
# 0     www.animabiotech.com/
# 1                   few.io/
# 2  www.blisspointmedia.com/
# 3         www.sobergrid.com
# 4            www.trupik.com
# 5    www.seamlessplanet.com
# 6     www.quartethealth.com
# 7        www.onplatform.com
# 8         www.roboterra.com
# 9         www.esperanto.ai/
#
#                                      description_all  \
# 0  Discovery of small molecule mRNA drugs and the...
# 1  Few helps you get your digital products, apps,...
# 2  Bliss Point renders video advertising and perf...
# 3  Sober Grid is a digital health application foc...
# 4  Trupik - Helping Retailers Revolutionize Onlin...
# 5  Seamless Planet provides real-time access to a...
# 6  Quartet Health is a platform that makes it eas...
# 7  ON is an enterprise AI platform trusted for co...
# 8  RoboTerra Inc. is a robotics company aiming to...
# 9  Esperanto Technologies develops massively para...
#
#                            generated_description_llm  \
# 0  Description (in two sentences):\n\nAnima Biote...
# 1  Description (in two sentences): \n\nFew is a d...
# 2  Here is the description and rating for Bliss P...
# 3  Description (in two sentences): Sober Grid is ...
# 4  Description (in two sentences):\n\nTrupik is a...
# 5  Description (in two sentences): Seamless Plane...
# 6  Description (in two sentences): Quartet Health...
# 7  Description (in two sentences): ON is an enter...
# 8  Description (in two sentences): ROBOTERRA, Inc...
# 9  Description (in two sentences):\n\nEsperanto T...
#
#                                generated_description  ...  \
# 0  Anima Biotech is a company focused on discover...  ...
# 1  Few is a digital product agency that specializ...  ...
# 2  Bliss Point specializes in video advertising a...  ...
# 3  Sober Grid is a mobile app designed to support...  ...
# 4  Trupik is an AI-powered platform that leverage...  ...
# 5  Seamless Planet is a platform that connects tr...  ...
# 6  Quartet Health is a mental health care platfor...  ...
# 7  ON is an enterprise AI platform that specializ...  ...
# 8  ROBOTERRA, Inc. is an educational robotics com...  ...
# 9  Esperanto Technologies develops specialized ch...  ...
#
#        generated_description_conf_interval_reasoning  \
# 0  This description is based on information direc...
# 1  The provided description is a good starting po...
# 2  The information provided on the Bliss Point we...
# 3  The provided description accurately captures t...
# 4  The provided information is fairly limited, bu...
# 5  The provided description outlines the core fun...
# 6  The provided description accurately reflects t...
# 7  The provided description is accurate and conci...
# 8  The provided description accurately summarizes...
# 9  The provided description offers a solid overvi...
#
#                               parsed_description_llm  \
# 0  Anima Biotech Analysis\n\nTasks/Jobs: High-thr...
# 1  Few - Digital Product Agency\n\nTasks/Jobs: UX...
# 2  Bliss Point\n\nTasks/Jobs: Video Ad Optimizati...
# 3  Sober Grid\n\nTasks/Jobs: Social networking, L...
# 4  Trupik Analysis\n\nTasks/Jobs:  Product visual...
# 5  Seamless Planet Analysis\n\nTasks/Jobs: Experi...
# 6  Quartet Health\n\nTasks/Jobs:  Mental health s...
# 7  ON\n\nTasks/Jobs: Customer interaction, AI-pow...
# 8  ROBOTERRA, Inc\n\nTasks/Jobs: Robotics program...
# 9  Esperanto Technologies\n\nTasks/Jobs: Generati...
#
#                                   parsed_description  \
# 0  Tasks/Jobs: High-throughput phenotypic screeni...
# 1  Tasks/Jobs: UX/UI design, Web development, Mob...
# 2  Tasks/Jobs: Video Ad Optimization, Performance...
# 3  Tasks/Jobs: Social networking, Location tracki...
# 4  Tasks/Jobs: Product visualization, Virtual try...
# 5  Tasks/Jobs: Experience recommendations, Itiner...
# 6  Tasks/Jobs: Mental health service discovery, A...
# 7  Tasks/Jobs: Customer interaction, AI-powered c...
# 8  Tasks/Jobs: Robotics programming, Game design,...
# 9  Tasks/Jobs: Generative AI model training, Infe...
#
#                                           Tasks/Jobs  \
# 0  High-throughput phenotypic screening, AI-drive...
# 1  UX/UI design, Web development, Mobile app deve...
# 2  Video Ad Optimization, Performance Marketing, ...
# 3  Social networking, Location tracking, Relapse ...
# 4  Product visualization, Virtual try-on, Image r...
# 5  Experience recommendations, Itinerary planning...
# 6  Mental health service discovery, Appointment s...
# 7  Customer interaction, AI-powered chat, Revenue...
# 8  Robotics programming, Game design, STEM educat...
# 9  Generative AI model training, Inference execut...
#
#                                      Industry  \
# 0               Pharmaceutical, Biotechnology
# 1                 Digital Product Development
# 2              Digital Advertising, Marketing
# 3          Mental health & Addiction Recovery
# 4                  E-commerce, Fashion retail
# 5                            Travel & Tourism
# 6                                  Healthcare
# 7       Retail, Sports, Media & Entertainment
# 8  Educational Technology, Robotics Education
# 9    Artificial Intelligence, Cloud Computing
#
#                                            Customers  \
# 0  Pharmaceutical companies, Biotech companies, R...
# 1                  Startups, Businesses, Enterprises
# 2  Streaming Platforms, Television Networks, Adve...
# 3  Individuals in recovery, Addiction support gro...
# 4  Fashion brands, Apparel retailers, E-commerce ...
# 5         Travelers, Travel agencies, Tour operators
# 6  Individuals seeking mental health care, Health...
# 7  Brands, Retailers, Sports Teams, Media & Enter...
# 8                       Students, Educators, Parents
# 9  Data centers, Cloud service providers, AI deve...
#
#   parsed_description_conf_interval  \
# 0                                9
# 1                                9
# 2                                9
# 3                                9
# 4                                8
# 5                                8
# 6                                9
# 7                                9
# 8                                8
# 9                                9
#
#           parsed_description_conf_interval_reasoning  \
# 0  The company's website and product description ...
# 1  The website and description explicitly mention...
# 2  The provided description clearly focuses on vi...
# 3  The description clearly states the app's focus...
# 4  The provided description highlights Trupik's f...
# 5  The platform's focus on personalized travel ex...
# 6  The description clearly states Quartet Health'...
# 7  The description clearly states the company's f...
# 8  The description clearly states the company's f...
# 9  The company explicitly mentions targeting larg...
#
#                                                 Task  \
# 0  Pharmaceutical companies, Biotech companies, R...
# 1  Startups, Businesses, Enterprises that do UX/U...
# 2  Streaming Platforms, Television Networks, Adve...
# 3  Individuals in recovery, Addiction support gro...
# 4  Fashion brands, Apparel retailers, E-commerce ...
# 5  Travelers, Travel agencies, Tour operators tha...
# 6  Individuals seeking mental health care, Health...
# 7  Brands, Retailers, Sports Teams, Media & Enter...
# 8  Students, Educators, Parents that do Robotics ...
# 9  Data centers, Cloud service providers, AI deve...
#
#                                             new Task
# 0  Pharmaceutical companies, Biotech companies, a...
# 1  Tech companies that design and build digital p...
# 2  Streaming Platforms, Television Networks, and ...
# 3  Recovery support system that helps individuals...
# 4  Fashion companies that enhance customer experi...
# 5  Travel Services that provide experience recomm...
# 6  Mental Health Ecosystem  that facilitates acce...
# 7  Brands, Retailers, Sports Teams, Media & Enter...
# 8  STEM Education Innovators that build robots, d...
# 9  Data centers, Cloud service providers, and AI ...
#
# [10 rows x 21 columns]
