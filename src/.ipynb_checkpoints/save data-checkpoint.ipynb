# %%
import pandas as pd

# %%
data = open("../input/2019/data2019.txt").read().split("\n\n")
data = [[y for y in x.split("\n") if y != "" and "Logo" not in y] for x in data if x != ""]
bad = [[len(x),x] for x in data if len(x) != 22]
good2019 = [x for x in data if len(x) == 22]
print(len(good2019))

data = open("../input/2020/data2020.txt").read().split("\n\n")
data = [[y for y in x.split("\n") if y != "" and "Logo" not in y] for x in data if x != ""]
bad = [[len(x),x] for x in data if len(x) != 22]
good2020 = [x for x in data if len(x) == 22]
print(len(good2020))

data = open("../input/2021/data2021.txt").read().split("\n\n")
data = [[y for y in x.split("\n") if y != "" and "Logo" not in y] for x in data if x != ""]
bad = [[len(x),x] for x in data if len(x) != 22]
good2021 = [x for x in data if len(x) == 22]
print(len(good2021))

data = open("../input/2022/data2022.txt").read().split("\n\n")
data = [[y for y in x.split("\n") if y != "" and "Logo" not in y] for x in data if x != ""]
bad = [[len(x),x] for x in data if len(x) != 22]
good2022 = [x for x in data if len(x) == 22]
#weird formatting when scrapping
good2022 = [x[:9]+x[10:11]+x[9:10]+x[11:] for x in data if len(x) == 22]
print(len(good2022))

data = open("../input/2023/data2023.txt").read().split("\n\n")
data = [[y for y in x.split("\n") if y != "" and "Logo" not in y] for x in data if x != ""]
bad = [[len(x),x] for x in data if len(x) != 22]
good2023 = [x for x in data if len(x) == 22]
print(len(good2023))

data = open("../input/2024/data2024.txt").read().split("\n\n")
data = [[y for y in x.split("\n") if y != "" and "Logo" not in y] for x in data if x != ""]
bad = [[len(x),x] for x in data if len(x) != 22]
good2024 = [x for x in data if len(x) == 22]
print(len(good2024))

labels = ["organization name","num employees", "founded date","description","industries","headquarters location","description","cb rank","postal code","headquarters region","website","actively hiring","linkedin","num articles","email","hub tag","phone num","num of sub org","industry groups","total funding amt","company type","estimated rev"]
dataset = good2019+ good2020 + good2021 + good2022 + good2023 + good2024
df = pd.DataFrame(dataset,columns=labels)

df['description_all'] = df['description'].iloc[:,0] + " " + df['description'].iloc[:,1]
df['industries_parsed'] = df['industries'].apply(lambda x: [i.strip() for i in x.split(',') if i.strip() != 'Artificial Intelligence (AI)' and i.strip() !='—'])
df['founded date'] = pd.to_datetime(df['founded date'], format='%b %Y', errors='coerce').combine_first(pd.to_datetime(df['founded date'], errors='coerce', infer_datetime_format=True))
df.to_csv("../output/data.csv")
# Out:
# 4669
# 4558
# 4349
# 3802
# 4266
# 987
# /var/folders/nf/2dvvlnxj5v962kwwzmpfj17h0000gn/T/ipykernel_6116/87670957.py:45: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df['founded date'] = pd.to_datetime(df['founded date'], format='%b %Y', errors='coerce').combine_first(pd.to_datetime(df['founded date'], errors='coerce', infer_datetime_format=True))

# %%
pd.DataFrame(good2022,columns=labels)
# Out:
#          organization name num employees  founded date  \
# 0            Inflection AI          1-10          2022
# 1                 Ideogram          1-10          2022
# 2                AutogenAI          1-10          2022
# 3                 Nomic AI          1-10          2022
# 4     Moonwalk Biosciences          1-10          2022
# ...                    ...           ...           ...
# 3797                 Seele         11-50  Nov 15, 2022
# 3798               Andiron          1-10  Nov 10, 2022
# 3799               LETT DO         11-50      Nov 2022
# 3800           CosmosIQ.AI        51-100  Dec 30, 2022
# 3801               Jack AI          1-10   Dec 1, 2022
#
#                                             description  \
# 0     Inflection AI is a machine learning startup th...
# 1     Ideogram is an artificial intelligence startup...
# 2     AutogenAI provides cutting edge natural langua...
# 3     Nomic AI engages in improving both the explain...
# 4     Moonwalk Biosciences is a genomic medicine sta...
# ...                                                 ...
# 3797  Seele is developing an advanced 3D AI platform...
# 3798                                                  —
# 3799  LETT DO facilitates connections between local ...
# 3800  CosmosIQ.ai is a comprehensive online learning...
# 3801  Most marketers struggle to write copy. We use ...
#
#                                              industries  \
# 0     Artificial Intelligence (AI), Chatbot, Generat...
# 1     Artificial Intelligence (AI), Generative AI, I...
# 2     Artificial Intelligence (AI), Business Develop...
# 3     Artificial Intelligence (AI), Information Tech...
# 4     Artificial Intelligence (AI), Biopharma, Biote...
# ...                                                 ...
# 3797  3D Technology, Generative AI, Information Tech...
# 3798             Artificial Intelligence (AI), Software
# 3799  Advertising Platforms, Content Marketing, Digi...
# 3800         Artificial Intelligence (AI), EdTech, SaaS
# 3801                             Copywriting, Marketing
#
#                          headquarters location  \
# 0         Palo Alto, California, United States
# 1                     Toronto, Ontario, Canada
# 2              London, England, United Kingdom
# 3            New York, New York, United States
# 4     San Francisco, California, United States
# ...                                        ...
# 3797                Shenzhen, Guangdong, China
# 3798                                         —
# 3799                Tel Aviv, Tel Aviv, Israel
# 3800      Singapore, Central Region, Singapore
# 3801                                         —
#
#                                             description cb rank postal code  \
# 0     Inflection AI is an artificial intelligence st...      24       94304
# 1     Ideogram is an artificial intelligence startup...     304     M5C 1C4
# 2     AutogenAI provides cutting edge natural langua...   1,405    EC4M 7JN
# 3     Nomic AI engages in improving both the explain...   2,905           —
# 4     Moonwalk Biosciences operates a genomic medici...   3,348       94080
# ...                                                 ...     ...         ...
# 3797  Seele is crafting 3D Multi-Modal Large Models ...       —      518057
# 3798  Context-driven marketing optimization for busi...       —           —
# 3799    Services Marketplace & Business Growth Platform       —           —
# 3800                          AI,EdTech,SaaS,Mobile App       —           —
# 3801  Jack AI is an AI tool that aids marketers in c...       —           —
#
#                                     headquarters region  ...  \
# 0     San Francisco Bay Area, Silicon Valley, West C...  ...
# 1                                           Great Lakes  ...
# 2                Europe, Middle East, and Africa (EMEA)  ...
# 3     Greater New York Area, East Coast, Northeaster...  ...
# 4        San Francisco Bay Area, West Coast, Western US  ...
# ...                                                 ...  ...
# 3797                                Asia-Pacific (APAC)  ...
# 3798                                                  —  ...
# 3799  Europe, Middle East, and Africa (EMEA), Middle...  ...
# 3800  Asia-Pacific (APAC), Association of Southeast ...  ...
# 3801                                                  —  ...
#
#               linkedin num articles                email  hub tag  \
# 0     View on LinkedIn           64                    —  Unicorn
# 1     View on LinkedIn           31                    —        —
# 2     View on LinkedIn           19                    —        —
# 3     View on LinkedIn           12                    —        —
# 4     View on LinkedIn           16                    —        —
# ...                ...          ...                  ...      ...
# 3797                 —            —   business@seeles.ai        —
# 3798  View on LinkedIn            —                    —        —
# 3799  View on LinkedIn            —   support@lettdo.com        —
# 3800  View on LinkedIn            —  sanjeev@cosmosiq.in        —
# 3801  View on LinkedIn            —   info@usejackai.com        —
#
#             phone num num of sub org  \
# 0                   —              1
# 1                   —              —
# 2                   —              —
# 3                   —              —
# 4     +1 650-540-9709              —
# ...               ...            ...
# 3797   86-17722505381              —
# 3798                —              —
# 3799                —              —
# 3800   +91-9860003147              —
# 3801    +447414117511              —
#
#                                         industry groups total funding amt  \
# 0     Artificial Intelligence (AI), Data and Analyti...    $1,525,000,000
# 1     Artificial Intelligence (AI), Data and Analyti...    CA$102,300,000
# 2     Artificial Intelligence (AI), Data and Analyti...       $61,734,517
# 3     Artificial Intelligence (AI), Data and Analyti...       $17,000,000
# 4     Artificial Intelligence (AI), Biotechnology, D...       $57,000,000
# ...                                                 ...               ...
# 3797  Artificial Intelligence (AI), Hardware, Inform...     CN¥15,000,000
# 3798  Artificial Intelligence (AI), Data and Analyti...                 —
# 3799  Advertising, Commerce and Shopping, Other, Sal...           $30,000
# 3800  Artificial Intelligence (AI), Data and Analyti...           $77,764
# 3801        Content and Publishing, Sales and Marketing                 —
#
#      company type estimated rev
# 0      For Profit             —
# 1      For Profit   $1M to $10M
# 2      For Profit   $1M to $10M
# 3      For Profit   $1M to $10M
# 4      For Profit             —
# ...           ...           ...
# 3797   For Profit             —
# 3798   For Profit             —
# 3799   For Profit             —
# 3800   For Profit             —
# 3801            —             —
#
# [3802 rows x 22 columns]

# %%
df = df[df["headquarters location"].str.contains("United States")]
df = df[pd.to_datetime(df['founded date'])>'11/30/2022']
df.website
# Out:
# 16817                 stack-ai.com
# 16818              trykintsugi.com
# 16820             www.sesameai.com
# 16823     procurementsciences.com/
# 16826               www.catio.tech
#                    ...
# 22624             www.supallama.ai
# 22625              www.geolava.com
# 22626                   solatis.ai
# 22627    www.degreesofinterest.com
# 22628                  aicomply.ai
# Name: website, Length: 1304, dtype: object

# %%
import pandas as pd
codes = pd.read_csv("../input/soc_structure_2018.csv")

codes['Major Group Name'] = codes.apply(lambda x: x[4] if pd.notnull(x['Major Group']) else None, axis=1)
codes['Minor Group Name'] = codes.apply(lambda x: x[4] if pd.notnull(x['Minor Group']) else None, axis=1)
codes['Broad Group Name'] = codes.apply(lambda x: x[4] if pd.notnull(x['Broad Group']) else None, axis=1)

codes['Major Group'] = codes['Major Group'].fillna(method='ffill')
codes['Minor Group'] = codes['Minor Group'].fillna(method='ffill')
codes['Broad Group'] = codes['Broad Group'].fillna(method='ffill')
codes['Major Group Name'] = codes['Major Group Name'].fillna(method='ffill')
codes['Minor Group Name'] = codes['Minor Group Name'].fillna(method='ffill')
codes['Broad Group Name'] = codes['Broad Group Name'].fillna(method='ffill')

codes = codes[codes["Detailed Occupation"].notna()]
codes = codes.rename({"Unnamed: 4":"Title"},axis=1)
codes.to_csv("../output/soc_codes.csv")
# Out:
# /var/folders/nf/2dvvlnxj5v962kwwzmpfj17h0000gn/T/ipykernel_42932/683242698.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   codes['Major Group Name'] = codes.apply(lambda x: x[4] if pd.notnull(x['Major Group']) else None, axis=1)
# /var/folders/nf/2dvvlnxj5v962kwwzmpfj17h0000gn/T/ipykernel_42932/683242698.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   codes['Minor Group Name'] = codes.apply(lambda x: x[4] if pd.notnull(x['Minor Group']) else None, axis=1)
# /var/folders/nf/2dvvlnxj5v962kwwzmpfj17h0000gn/T/ipykernel_42932/683242698.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   codes['Broad Group Name'] = codes.apply(lambda x: x[4] if pd.notnull(x['Broad Group']) else None, axis=1)
# /var/folders/nf/2dvvlnxj5v962kwwzmpfj17h0000gn/T/ipykernel_42932/683242698.py:8: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   codes['Major Group'] = codes['Major Group'].fillna(method='ffill')
# /var/folders/nf/2dvvlnxj5v962kwwzmpfj17h0000gn/T/ipykernel_42932/683242698.py:9: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   codes['Minor Group'] = codes['Minor Group'].fillna(method='ffill')
# /var/folders/nf/2dvvlnxj5v962kwwzmpfj17h0000gn/T/ipykernel_42932/683242698.py:10: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   codes['Broad Group'] = codes['Broad Group'].fillna(method='ffill')
# /var/folders/nf/2dvvlnxj5v962kwwzmpfj17h0000gn/T/ipykernel_42932/683242698.py:11: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   codes['Major Group Name'] = codes['Major Group Name'].fillna(method='ffill')
# /var/folders/nf/2dvvlnxj5v962kwwzmpfj17h0000gn/T/ipykernel_42932/683242698.py:12: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   codes['Minor Group Name'] = codes['Minor Group Name'].fillna(method='ffill')
# /var/folders/nf/2dvvlnxj5v962kwwzmpfj17h0000gn/T/ipykernel_42932/683242698.py:13: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   codes['Broad Group Name'] = codes['Broad Group Name'].fillna(method='ffill')

# %%
df_exp = pd.read_csv("../input/gpts_labels_new.csv")
df_exp = df_exp[(df_exp.human_labels!='E0') | (df_exp.gpt_4_exposure!='E0')]
df_exp["description"] = df_exp.apply(lambda x: f"{x.Title.capitalize()} that {x.Task.lower()}",axis=1)
df_exp[(df_exp.gpt_4_exposure=='EO')]
df_exp.gpt_4_exposure.unique()
# Out:
# array(['E2', 'E0', 'E1'], dtype=object)

# %%
for i, row in df_exp[df_exp.Title == "Sales Managers"].iterrows():
    print(row.description)
# Out:
# Sales managers that resolve customer complaints regarding sales and service.
# Sales managers that monitor customer preferences to determine focus of sales efforts.
# Sales managers that determine price schedules and discount rates.
# Sales managers that review operational records and reports to project sales and determine profitability.
# Sales managers that confer or consult with department heads to plan advertising services and to secure information on equipment and customer specifications.
# Sales managers that advise dealers and distributors on policies and operating procedures to ensure functional effectiveness of business.
# Sales managers that prepare budgets and approve budget expenditures.
# Sales managers that plan and direct staffing, training, and performance evaluations to develop and control sales and service programs.
# Sales managers that visit franchised dealers to stimulate interest in establishment or expansion of leasing programs.
# Sales managers that oversee regional and local sales managers and their staffs.
# Sales managers that direct clerical staff to keep records of export correspondence, bid requests, and credit collections, and to maintain current information on tariffs, licenses, and restrictions.
# Sales managers that direct foreign sales and service outlets of an organization.
# Sales managers that assess marketing potential of new and existing store locations, considering statistics and expenditures.
# Sales managers that direct and coordinate activities involving sales of manufactured products, services, commodities, real estate, or other subjects of sale.
# Sales managers that direct, coordinate, and review sales and service accounting and record-keeping, as well as receiving and shipping.
# Sales managers that confer with potential customers regarding equipment needs, and advise customers on types of equipment to purchase.

# %%
results = []
for i, x in df_exp.reset_index().iterrows():
    description = x["description"]
    print(f"Processing {str(i), len(results)}: {description}")
    result = x_chat.get_embedding(description)
    results.append([description,result])

df = pd.DataFrame(results, columns=['Description', 'Embeddings'])
df_exp = pd.concat([df_exp.reset_index(), df], axis=1)


# df_exp.to_csv("gpt_exposure_embeddings.csv")
# Out:
# array(['NLSQL', '1-10', Timestamp('2018-11-30 00:00:00'),
#        'NLSQL Allows anyone to easily make data-driven decisions, increasing productivity and driving businesses forward faster. NLSQL technology with text AI bot interface can provide you with data analytics, business insights, and data visualization.',
#        'Analytics, Artificial Intelligence (AI), Big Data, Information Technology',
#        'London, England, United Kingdom',
#        'NLSQL is cognitive BI technology, which helps company employees to get information quickly and easily using only Natural Language',
#        '382,585', 'N2 9ED', 'Europe, Middle East, and Africa (EMEA)',
#        'www.nlsql.com/', '—', 'View on LinkedIn', '2', 'denis@nlsql.com',
#        '—', '—', '—',
#        'Artificial Intelligence (AI), Data and Analytics, Information Technology, Science and Engineering, Software',
#        '—', 'For Profit', '—',
#        'NLSQL Allows anyone to easily make data-driven decisions, increasing productivity and driving businesses forward faster. NLSQL technology with text AI bot interface can provide you with data analytics, business insights, and data visualization. NLSQL is cognitive BI technology, which helps company employees to get information quickly and easily using only Natural Language',
#        list(['Analytics', 'Big Data', 'Information Technology'])],
#       dtype=object)

# %%
from lemmatize import lemmatize
lemmatize("julia runs")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from lemmatize import lemmatize
#       2 lemmatize("julia runs")
#
# ImportError: cannot import name 'lemmatize' from 'lemmatize' (/Users/juliasusser/Desktop/govAI research/startups/src/lemmatize.py)

# %%
df.website
# Out:
# 0                     www.nlsql.com/
# 1        www.truefocusautomation.com
# 2                    www.immunai.com
# 3               kili-technology.com/
# 4                       www.soda.io/
#                     ...
# 22626                     solatis.ai
# 22627      www.degreesofinterest.com
# 22628                    aicomply.ai
# 22629                    pawfoto.com
# 22630                   sleepfast.io
# Name: website, Length: 22631, dtype: object

# %%
# Out:
# [['NLSQL',
#   '1-10',
#   'Nov 30, 2018',
#   'NLSQL Allows anyone to easily make data-driven decisions, increasing productivity and driving businesses forward faster. NLSQL technology with text AI bot interface can provide you with data analytics, business insights, and data visualization.',
#   'Analytics, Artificial Intelligence (AI), Big Data, Information Technology',
#   'London, England, United Kingdom',
#   'NLSQL is cognitive BI technology, which helps company employees to get information quickly and easily using only Natural Language',
#   '382,585',
#   'N2 9ED',
#   'Europe, Middle East, and Africa (EMEA)',
#   'www.nlsql.com/',
#   '—',
#   'View on LinkedIn',
#   '2',
#   'denis@nlsql.com',
#   '—',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Data and Analytics, Information Technology, Science and Engineering, Software',
#   '—',
#   'For Profit',
#   '—'],
#  ['TrueFocus Automation',
#   '11-50',
#   'Nov 30, 2018',
#   'TrueFocus Automation, a robotic process automation (RPA) services firm founded in 2018 and based in Plano, Texas, helps customers transition away from labor-intensive, error-prone processes to automated ones which are more efficient, accurate, and scalable at a lower cost. Our team designs, builds, implements, and manages software "robots" (digital workers) to maximize results. Contact us to learn how to transition your workflows from manual, repetitive, and error-prone processes to automation. info@truefocusautomation.com',
#   'Consulting, Information Technology, Insurance, Outsourcing, Robotic Process Automation (RPA), Software',
#   'Plano, Texas, United States',
#   'RPA (Robotic Process Automation) software solutions provider to the US Title Insurance and Mortgage industries',
#   '471,639',
#   '75093',
#   'Dallas/Fort Worth Metroplex, Southern US',
#   'www.truefocusautomation.com',
#   '—',
#   'View on LinkedIn',
#   '—',
#   'info@truefocusautomation.com',
#   '—',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Financial Services, Information Technology, Professional Services, Software',
#   '—',
#   'For Profit',
#   '$1M to $10M'],
#  ['Immunai',
#   '101-250',
#   'Dec 2018',
#   "Immunai is a biotech company that combines single-cell genomics with ML algorithms to enable high-resolution profiling of the immune system. Immunai's mission is to map the entire immune system and its functions using single-cell genomics and machine learning. Immunai leverages single-cell technologies to profile cells from a blood sample, and uses machine-learning algorithms (powered by its proprietary database) to map the hundreds of cell types and their states to create an immune profile. They work on biomarker discovery and insights that identify how a cell responds to its changing environment. The company is located in New York City, San Francisco, and Tel Aviv, Israel.",
#   'Analytics, Artificial Intelligence (AI), Biotechnology, Machine Learning, Therapeutics',
#   'New York, New York, United States',
#   'Immunai is a biotech company that provides mapping and reprogramming immunology, machine learning, and software engineering.',
#   '1,664',
#   '10016',
#   'Greater New York Area, East Coast, Northeastern US',
#   'www.immunai.com',
#   '—',
#   'View on LinkedIn',
#   '42',
#   'info@immunai.com',
#   '+1 727 543 2286',
#   'Unicorn',
#   '—',
#   'Artificial Intelligence (AI), Biotechnology, Data and Analytics, Health Care, Science and Engineering, Software',
#   '$295,000,000',
#   'For Profit',
#   '$10M to $50M'],
#  ['Kili Technology',
#   '51-100',
#   'Dec 1, 2018',
#   'Kili Technology enables large companies to transform their raw data into high-quality annotated data, ready for AI-driven projects.',
#   'Analytics, Artificial Intelligence (AI), Computer, Machine Learning, Software',
#   'Paris, Ile-de-France, France',
#   'Kili Technology enables large companies to transform their raw data into high-quality annotated data, ready for AI-driven projects.',
#   '6,509',
#   '75008',
#   'European Union (EU), Europe, Middle East, and Africa (EMEA)',
#   'kili-technology.com/',
#   '—',
#   'View on LinkedIn',
#   '9',
#   '—',
#   '—',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Consumer Electronics, Data and Analytics, Hardware, Science and Engineering, Software',
#   '$31,933,463',
#   'For Profit',
#   '—'],
#  ['Soda',
#   '11-50',
#   'Dec 1, 2018',
#   'Soda is the data monitoring platform that keeps your data fit for purpose, verifiable and trustworthy. We uncover data issues, alert the right teams, and trigger resolution workflows to identify causes that impede data quality. Our open source testing projects and monitoring platform brings together data engineers, operations and the business to create trusted data. Data-driven organisations choose Soda to realise the value of their data and secure its quality. Data Monitoring | Data Testing | Observability | Data Quality | Data Management',
#   'Analytics, Big Data, Business Intelligence, Cloud Data Services, Machine Learning, Software, Test and Measurement',
#   'Brussels, Brussels Hoofdstedelijk Gewest, Belgium',
#   'Data Quality for the Data Product Era',
#   '7,257',
#   '—',
#   'European Union (EU), Europe, Middle East, and Africa (EMEA)',
#   'www.soda.io/',
#   'Yes',
#   'View on LinkedIn',
#   '4',
#   'info@soda.io',
#   '+32 2 786 43 65',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Data and Analytics, Information Technology, Internet Services, Software',
#   '€23,100,000',
#   'For Profit',
#   '$1M to $10M'],
#  ['Shipfix',
#   '51-100',
#   'Dec 2018',
#   'Shipfix is a fast-growing collaborative workflow and data platform for the maritime and trade sectors, driven by groundbreaking AI-enabled tools. The platform streamlines maritime workflows with market and operational intelligence with a focus on shipowners, commodity traders, industrials, freight forwarders, and shipbrokers. With Shipfix, maritime and trade professionals make better-informed decisions and move faster.',
#   'Artificial Intelligence (AI), Business Intelligence, Machine Learning, Marine Transportation, Shipping',
#   'Vincennes, Ile-de-France, France',
#   'Shipfix operates as a data and community platform that helps with the operational efficiency in the maritime industry.',
#   '11,441',
#   '—',
#   'European Union (EU), Europe, Middle East, and Africa (EMEA)',
#   'shipfix.com',
#   '—',
#   'View on LinkedIn',
#   '21',
#   'enquiry@shipfix.com',
#   '—',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Data and Analytics, Science and Engineering, Software, Transportation',
#   '$19,000,000',
#   'For Profit',
#   '$1M to $10M'],
#  ['MyWays.ai',
#   '11-50',
#   'Dec 1, 2018',
#   'MyWays is a B2B Job-Tech venture, backed by CIIE.CO IIM Ahmedabad and Wami Capital. We are an AI platform providing a customized end-to-end, Zero Effort hiring, and training ecosystem for corporates. We help onboard and train entry-level techies tailored to the needs of the employers such that the fresh candidates are ready to assume their new roles as "Experienced Freshers" as quickly as possible, leading to lowering efforts and costs and increasing retention.',
#   'Artificial Intelligence (AI), Corporate Training, Education, Human Resources, Training',
#   'New Delhi, Delhi, India',
#   'MyWays.ai is an AI based Job-Tech Platform establishing customized hiring and training ecosystem for the corporates',
#   '12,031',
#   '—',
#   'Asia-Pacific (APAC)',
#   'www.myways.ai/',
#   '—',
#   'View on LinkedIn',
#   '9',
#   'info@myways.ai',
#   '91 88-2398-2398',
#   '—',
#   '—',
#   'Administrative Services, Artificial Intelligence (AI), Data and Analytics, Education, Science and Engineering, Software',
#   '$346,755',
#   'For Profit',
#   '$1M to $10M'],
#  ['Mona',
#   '11-50',
#   'Dec 2018',
#   'Mona provides intelligent and flexible AI monitoring for AI-first companies and teams who need to continuously adapt and optimize their production environments for fast business growth. Our platform enables machine learning teams to track data and model performance metrics in production, and get alerted on potential drifts. biases and integrity issues, to business risk and enable fast and reliable improvements. Customers across verticals use the platform for a variety of use cases such as fraud detection, data-driven healthcare, e-commerce marketing optimization, and revenue intelligence. Founded in late 2018 by product leaders and operators from Google and McKinsey & Co.',
#   'Analytics, Artificial Intelligence (AI), Information Services, Information Technology, Machine Learning, SaaS, Software',
#   'Atlanta, Georgia, United States',
#   "Mona's performance monitoring platform for production AI systems, enabling data and engineer teams to resolve model underperformance issues.",
#   '24,096',
#   '—',
#   'Greater Atlanta Area, East Coast, Southern US',
#   'www.monalabs.io',
#   '—',
#   'View on LinkedIn',
#   '3',
#   'info@monbalabs.io',
#   '—',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Data and Analytics, Information Technology, Science and Engineering, Software',
#   '$6,950,000',
#   'For Profit',
#   '$1M to $10M'],
#  ['Action Face',
#   '11-50',
#   'Dec 2018',
#   'Action Face has created the leading AI-powered 3D avatar of YOU! As simple as taking a selfie, we allow you to create instantly recognizable 3D face on fantasy avatars. Customize your avatar, create AR videos and even order a color 3D printed action figure of yourself. Partners with the NBA and Hewlett Packard. Winner of SXSW 2022 - Best Startup in Entertainment and Gaming UC Berkeley SkyDeck HotDesk Accelerator Series A - $9MM Raised to Date #MakeSomethingOfYourself #ActionFaceMe',
#   '3D Printing, Consumer Goods, Consumer Software, Media and Entertainment, Sports Leagues and Teams, Video Games',
#   'Berkeley, California, United States',
#   'Action Face has created the leading AI-powered 3D avatar of YOU! As simple as taking a selfie.',
#   '24,516',
#   '94708',
#   'San Francisco Bay Area, West Coast, Western US',
#   'actionface.ai',
#   '—',
#   'View on LinkedIn',
#   '3',
#   'info@actionface.app',
#   '—',
#   '—',
#   '—',
#   'Consumer Goods, Gaming, Manufacturing, Media and Entertainment, Software, Sports',
#   '$9,000,000',
#   'For Profit',
#   '—'],
#  ['MrMandoob',
#   '101-250',
#   'Dec 1, 2018',
#   'MrMandoob provides an enjoyable and simple delivery experience with unique benefits and features. It connects customers with stores in the most convenient way possible by utilizing a wide range of options available in the application. It provides the following services: (store delivery, parcel delivery, dock car delivery, intercity delivery, gas delivery, charge cards).',
#   'Courier Service, Delivery, Delivery Service, Food Delivery, Predictive Analytics',
#   'Riyadh, Ar Riyad, Saudi Arabia',
#   'A super app on a heroic mission to connect people in the Saudi Arabia and Egypt with the best delivery services, straight to their doors.',
#   '24,532',
#   '13321',
#   'Europe, Middle East, and Africa (EMEA), Gulf Cooperation Council (GCC), Middle East',
#   'www.mrmandoob.com/',
#   '—',
#   'View on LinkedIn',
#   '—',
#   'invesment@mrmandoob.com',
#   '—',
#   '—',
#   '—',
#   'Administrative Services, Artificial Intelligence (AI), Data and Analytics, Food and Beverage, Software, Transportation',
#   '$20,263,333',
#   'For Profit',
#   '—'],
#  ['Vastai Technologies',
#   '101-250',
#   'Dec 2018',
#   'Vastai Technologies is focused on developing AI chips for the optimization of computer vision and video processing.',
#   'Electronics, GPU, Semiconductor',
#   'Shanghai, Shanghai, China',
#   'Vastai Technologies is focused on developing AI chips for the optimization of computer vision and video processing.',
#   '26,056',
#   '—',
#   'Asia-Pacific (APAC)',
#   'www.vastaitech.com/',
#   '—',
#   'View on LinkedIn',
#   '4',
#   'info@vastaitech.com',
#   '+021-61060282',
#   '—',
#   '1',
#   'Consumer Electronics, Hardware, Science and Engineering',
#   '$378,206,321',
#   'For Profit',
#   '—'],
#  ['Kiira Health',
#   '11-50',
#   'Dec 2018',
#   "Kiira Health is an advanced AI care coordinator and women's health clinic for young women. Kiira is connecting users to trusted health experts including primary care providers, ObGyn's, nurse practitioners, mental health experts, and more via phone, chat, and video. Kiira is available 24/7, 365 days a year. It was founded in 2018 and is headquartered in Los Angeles, California.",
#   "Artificial Intelligence (AI), Fertility, Health Care, Personal Health, Women's",
#   'Los Angeles, California, United States',
#   'Kiira is a virtual health clinic for women that makes use of advanced AI to offer telemedicine services.',
#   '29,928',
#   '90012',
#   'Greater Los Angeles Area, West Coast, Western US',
#   'www.kiira.io',
#   '—',
#   'View on LinkedIn',
#   '3',
#   'support@kiira.io',
#   '+1 323-317-8320',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Community and Lifestyle, Data and Analytics, Health Care, Science and Engineering, Software',
#   '$4,000,000',
#   'For Profit',
#   '$1M to $10M'],
#  ['estie',
#   '51-100',
#   'Dec 1, 2018',
#   "Estie is a real estate tech startup that creates algorithms for estimating rents and other quantitative real estate indicators. The startup's estie pro is building an information platform, with over 80,000 properties and 90% coverage of Tokyo's five central wards. This is the only service that offers all of the information required for the office rental business, including property information, vacancy information, asking for rent, and tenants. Estie provides a rental office matching service to make office search easier. It is the largest/only service in the industry that allows receiving proposals from all office recruitment information on the market, and the unique AI assists in finding the ideal office. Estie was established in December 2018 and is headquartered in Tokyo, Japan.",
#   'Artificial Intelligence (AI), Machine Learning, Reservations, Search Engine, SEM',
#   'Tokyo, Tokyo, Japan',
#   'Estie is a real estate tech startup that creates algorithms for estimating rents and other quantitative real estate indicators.',
#   '35,963',
#   '—',
#   'Asia-Pacific (APAC)',
#   'www.estie.jp',
#   '—',
#   'View on LinkedIn',
#   '—',
#   '—',
#   '—',
#   '—',
#   '—',
#   'Advertising, Artificial Intelligence (AI), Data and Analytics, Events, Internet Services, Media and Entertainment, Sales and Marketing, Science and Engineering, Software',
#   '¥400,010,000',
#   'For Profit',
#   '$1M to $10M'],
#  ['Babbly',
#   '1-10',
#   'Dec 2018',
#   "Babbly is building the world's largest data platform to help parents monitor and support their child's development. Our first product is a mobile app that lets parents track their baby's speech development using a video recording of their child.",
#   'Artificial Intelligence (AI), Software',
#   'Toronto, Ontario, Canada',
#   "Babbly offers an AI-powered platform to track a baby's speech and language development.",
#   '38,001',
#   '—',
#   'Great Lakes',
#   'Babbly.co',
#   '—',
#   'View on LinkedIn',
#   '8',
#   'hello@babbly.co',
#   '6475302934',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Data and Analytics, Science and Engineering, Software',
#   '$2,679,521',
#   'For Profit',
#   '$1M to $10M'],
#  ['Purlin',
#   '11-50',
#   'Dec 2018',
#   'Purlin makes the homebuying experience better, helps real estate professionals succeed, and improves the businesses of brokerages and lenders, through intelligent personalization. We use image-based AI to create the best possible real-estate experience from finding to buying a home. We take users on an exploration of home styles and design and let them “peek” inside to find what they like so that we can deliver home matches that they want. We create profiles that combine personal style with life, geographic, and budgetary inputs, and continually enrich them as buyers interact with our AI. We guide them through the entire dynamic process, with automated intelligence and deep real estate and mortgage expertise. Our intelligent real estate experience was created to make finding the right home more satisfying for buyers, more efficient for RE professionals and more profitable for brokers and lenders.',
#   'Artificial Intelligence (AI), Image Recognition, Machine Learning, Real Estate',
#   'Torrance, California, United States',
#   'Purlin makes the homebuying experience better and improve the businesses of brokerages and lenders, through intelligent personalization.',
#   '38,789',
#   '90503',
#   'Greater Los Angeles Area, West Coast, Western US',
#   'www.purlin.com/',
#   '—',
#   'View on LinkedIn',
#   '6',
#   'info@purlin.com',
#   '415-787-5462',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Data and Analytics, Real Estate, Science and Engineering, Software',
#   '$2,050,000',
#   'For Profit',
#   '$1M to $10M'],
#  ['VAIOT LIMITED',
#   '11-50',
#   'Dec 2018',
#   'Founded in 2018, VAIOT is the first company regulated (since 2020) under the Virtual Financial Assets regulatory framework in Malta (EU). It combines AI and Blockchain, developing a portfolio of blockchain-based AI Assistants for B2B, B2C, and C2C purposes to create new ways of digitally accessing services and securely concluding legal contracts. Built on top of Open AI’s GPT3, MS Luis, IBM Watson, Google’s AI features, and its own AI algorithms VAIOT uses AI to allow wider adoption of blockchain technology through its AI Contract Assistant and set of technologies called Intelligent Contracts. Cooperated with IBM and partnered with the likes of Grant Thornton and DAO Maker.',
#   'Artificial Intelligence (AI), Blockchain, InsurTech, Legal Tech',
#   'Mosta, NA - Malta, Malta',
#   'VAIOT offers a portfolio of blockchain-based AI Assistants and on-chain Intelligent Contracts for businesses and consumers.',
#   '49,831',
#   '1180',
#   'European Union (EU), Europe, Middle East, and Africa (EMEA)',
#   'vaiot.ai/',
#   '—',
#   'View on LinkedIn',
#   '1',
#   '—',
#   '—',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Blockchain and Cryptocurrency, Data and Analytics, Financial Services, Other, Professional Services, Science and Engineering, Software',
#   '€6,500,000',
#   'For Profit',
#   '$1M to $10M'],
#  ['Skylab Technologies',
#   '11-50',
#   'Dec 2018',
#   'Skylab Technologies ULC is a Vancouver-based computational photography SaaS company that focuses on the next generation of AI-powered photography tools. We develop image processing algorithms using a proprietary dataset of high-resolution images. To date, we have processed over one million portraits for commercial purposes.',
#   'Artificial Intelligence (AI), Computer, Machine Learning, Photography, SaaS, Software',
#   'Vancouver, British Columbia, Canada',
#   'Skylab Technologies develops A.I. photo editing tools, empowering businesses, freelancers, and hobbyists to succeed in the digital age.',
#   '55,203',
#   'V5T 1G7',
#   '—',
#   'www.skylabtech.ai/',
#   '—',
#   'View on LinkedIn',
#   '3',
#   'info@skylabtech.ai',
#   '—',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Consumer Electronics, Content and Publishing, Data and Analytics, Hardware, Media and Entertainment, Science and Engineering, Software',
#   'CA$500,000',
#   'For Profit',
#   '$1M to $10M'],
#  ['Hefring Marine',
#   '1-10',
#   'Dec 1, 2018',
#   'Hefring Marine is an Icelandic data-driven deep-tech marine startup leveraging AI/ML and IoT for their hardware-enabled SaaS solution, the Intelligent Marine Assistance System (IMAS). The solution is an on-board AI that saves fuel consumption, significantly reduces carbon emissions and improves safety in boats and vessels through real time operating guidance for both manned and unmanned boats and vessels. Operators receive instant real time navigation guidance that only improves over time as the AI continues to learn. This helps to mitigate inexperience, enhance situational awareness and minimize the risk of ‘bad habits’. The solution can save up to 25% in fuel and CO2 and can reduce wave slamming impacts significantly, or by up to 70%, resulting in a significantly safer and more comfortable ride.',
#   'Autonomous Vehicles, Internet of Things, Marine Technology, Marine Transportation, SaaS, Software',
#   'Reykjavík, Gullbringusysla, Iceland',
#   'An Icelandic deep-tech company building AI to enhance fuel efficiency, reduce carbon emissions and improve safety for boat operations.',
#   '67,583',
#   '101',
#   'Nordic Countries, Scandinavia, Europe, Middle East, and Africa (EMEA)',
#   'www.hefringmarine.com/',
#   '—',
#   'View on LinkedIn',
#   '7',
#   'info@hefringmarine.com',
#   '00354-620-3800',
#   '—',
#   '—',
#   'Internet Services, Science and Engineering, Software, Transportation',
#   '€2,271,429',
#   'For Profit',
#   'Less than $1M'],
#  ['foodforecast',
#   '1-10',
#   'Dec 2018',
#   'AI supported solution to reduce food waste.',
#   'Artificial Intelligence (AI), Bakery, Food and Beverage, Machine Learning, Restaurants, Software',
#   'Cologne, Nordrhein-Westfalen, Germany',
#   'IT Software using Artificial Intelligence',
#   '67,638',
#   '—',
#   'European Union (EU), Europe, Middle East, and Africa (EMEA)',
#   'foodforecast.com',
#   '—',
#   'View on LinkedIn',
#   '—',
#   'info@foodforecast.com',
#   '—',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Data and Analytics, Food and Beverage, Science and Engineering, Software',
#   '€500,000',
#   'For Profit',
#   '—'],
#  ['Volan Technology',
#   '1-10',
#   'Dec 1, 2018',
#   'Volan Technology is an early stage real-time people positioning platform that produces powerful new workforce optimization and safety SaaS data insights. The Volan Positioning System (VPS) is a new micro-location technology and a machine learning data engine that identify operational inefficiencies and undiscovered labor cost savings at scale with accuracy, low cost of deployment, and privacy-protected data.',
#   'Analytics, Artificial Intelligence (AI), Machine Learning, Physical Security, SaaS, Software',
#   'Hoboken, New Jersey, United States',
#   'Volan is a people-positioning SaaS analytics platform that companies use to reduce labor cost and increase safety and productivity.',
#   '68,848',
#   '07030',
#   'Greater New York Area, East Coast, Northeastern US',
#   'www.volantechnology.com',
#   '—',
#   'View on LinkedIn',
#   '4',
#   'info@volantechnology.com',
#   '551-249-1247',
#   '—',
#   '—',
#   'Administrative Services, Artificial Intelligence (AI), Data and Analytics, Privacy and Security, Science and Engineering, Software',
#   '$5,525,000',
#   'For Profit',
#   '$1M to $10M'],
#  ['ASMI',
#   '1-10',
#   'Dec 2018',
#   'ASMI is a B2B venture incorporating AI to finally remove all the friction of live, short and game streaming video monetization with product placement and E-commerce advertisement. User-generated content is uniquely paired with an automated non-invasive ad, providing upside in both UX and ROI for content providers.',
#   'Artificial Intelligence (AI)',
#   'San Francisco, California, United States',
#   'ASMI is a B2B venture incorporating AI to finally remove all the friction of in-video advertisement for user-generated content.',
#   '71,172',
#   '—',
#   'San Francisco Bay Area, West Coast, Western US',
#   'www.asmi.co',
#   '—',
#   'View on LinkedIn',
#   '14',
#   'david.thomas@asmi.co',
#   '6502084875',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Data and Analytics, Science and Engineering, Software',
#   '$2,000,000',
#   'For Profit',
#   '—'],
#  ['CKM Analytix',
#   '11-50',
#   'Dec 2018',
#   'CKM Analytix is a provider of operations intelligence that heavily relies on AI and data science. CKM distinguishes itself from other major players in the data analytics space by being technology agnostic. Its primary goal is to use data science to solve business problems. It connects all types of empirical/digital data (including systems, voice, text, and structured and unstructured data) to improve effectiveness, mitigate risks, and optimize client service. It achieves ROI-driven AI and ML quickly.',
#   'Apps, Artificial Intelligence (AI), Information Technology, Machine Learning, Predictive Analytics, SaaS, Software',
#   'New York, New York, United States',
#   'CKM Analytix develops and distributes T-K, an Intelligence Engine for service operations in SaaS delivery',
#   '79,607',
#   '10018',
#   'Greater New York Area, East Coast, Northeastern US',
#   'www.ckmanalytix.com',
#   '—',
#   'View on LinkedIn',
#   '—',
#   '—',
#   '—',
#   '—',
#   '—',
#   'Apps, Artificial Intelligence (AI), Data and Analytics, Information Technology, Science and Engineering, Software',
#   '$1,500,000',
#   'For Profit',
#   '—'],
#  ['VoiceSell',
#   '11-50',
#   'Dec 1, 2018',
#   'VoiceSell is a privately-held company specialized in the development and deployment of practical conversational artificial intelligence systems focused on eCommerce using on its proprietary patented platform technologies.',
#   'Artificial Intelligence (AI), E-Commerce, Software',
#   'Santa Clara, California, United States',
#   'Mobile is becoming the dominant commerce customer source yet interacting on a mobile device is a slow and frustrating process.',
#   '95,021',
#   '95051-3097',
#   'San Francisco Bay Area, Silicon Valley, West Coast',
#   'www.voicesell.com',
#   '—',
#   'View on LinkedIn',
#   '—',
#   'info@VoiceSell.com',
#   '+1 408 690 2270',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Commerce and Shopping, Data and Analytics, Science and Engineering, Software',
#   '$4,000,000',
#   'For Profit',
#   '$1M to $10M'],
#  ['RubiQ',
#   '11-50',
#   'Dec 1, 2018',
#   'RubiQ empowers passengers to self manage disruptions through Artificial intelligence-based real-time communication. RubiQ offers Aircules, a white label AI-powered mobile solution which will keep the passengers updated, allow them to rebook from personalized alternatives and to skip the lines.',
#   'Artificial Intelligence (AI), Machine Learning',
#   'Tel Aviv, Tel Aviv, Israel',
#   'RubiQ empowers passengers to self manage disruptions through Artificial intelligence-based real-time communication.',
#   '100,030',
#   '—',
#   'Europe, Middle East, and Africa (EMEA), Middle East',
#   'www.rubiq.tech',
#   '—',
#   'View on LinkedIn',
#   '—',
#   'amos.bj@rubiq.tech',
#   '—',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Data and Analytics, Science and Engineering, Software',
#   '$1,100,000',
#   'For Profit',
#   '$1M to $10M'],
#  ['cyex',
#   '1-10',
#   'Dec 2018',
#   'cyex develops an AI-based tool that generates personalized cybersecurity exercises with a special focus on cyber threat specifics for its clients.',
#   'Artificial Intelligence (AI), Cyber Security, Information Technology, Machine Learning',
#   'Tallinn, Harjumaa, Estonia',
#   'cyex develops an AI-based tool that generates personalized cybersecurity exercises with a special focus on cyber threat specifics.',
#   '114,839',
#   '—',
#   'European Union (EU), Europe, Middle East, and Africa (EMEA)',
#   'cyex.io/',
#   '—',
#   'View on LinkedIn',
#   '1',
#   'hello@cyex.io',
#   '—',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Data and Analytics, Information Technology, Privacy and Security, Science and Engineering, Software',
#   '$40,000',
#   'For Profit',
#   '—'],
#  ['Athletech',
#   '1-10',
#   'Dec 2018',
#   'Athletech is a sports technology company that provides amateur athletes, coaches, officials, and fans with the same resources and tools as professional sports organizations. We use modern hardware and software to create affordable and scalable technology solutions for these audiences and the businesses that serve them, such as gym owners, private coaches and trainers, sports equipment manufacturers and retailers, and batting cage owners.',
#   'Artificial Intelligence (AI), Information Technology, Machine Learning, Personal Health, Software, Sports',
#   'San Diego, California, United States',
#   'Athletech is a sports technology company that provides athletes, coaches, and officials with custom hardware and software solutions.',
#   '130,589',
#   '—',
#   'Greater San Diego Area, West Coast, Western US',
#   'www.athletech.co',
#   '—',
#   'View on LinkedIn',
#   '1',
#   'andre@athletech.co',
#   '2148659068',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Data and Analytics, Health Care, Information Technology, Science and Engineering, Software, Sports',
#   '$16,000',
#   'For Profit',
#   '—'],
#  ['Geoalert',
#   '11-50',
#   'Dec 2018',
#   'Mapflow AI platform performs instant analysis of any location in the world using satellite and aerial imagery. We empower cartographers and data analysts to make faster and better decisions. Our product is classified into two categories: SaaS: Mapflow.ai – recognize buildings, roads, forest, construction with powerful AI tools embedded into the platform Service: It consists of 3 things - Urban Mapping: The ready to use datasets of building footprints and other infrastructures - Construction Monitoring: Detect and outline construction sites, estimate time of completion - Powerline Monitoring: Monitor powerlines risks, the vegetation within powerline corridors',
#   'Analytics, Artificial Intelligence (AI), Big Data, Geospatial, Machine Learning, SaaS',
#   'Tashkent, NA - Uzbekistan, Uzbekistan',
#   'Geoalert is a technology company that provides AI powered GIS services to the world.',
#   '132,640',
#   '—',
#   '—',
#   'geoalert.io/',
#   '—',
#   'View on LinkedIn',
#   '3',
#   'hello@geoalert.io',
#   '—',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Data and Analytics, Navigation and Mapping, Science and Engineering, Software',
#   '$45,000',
#   'For Profit',
#   '—'],
#  ['NoCodeZ',
#   '1-10',
#   'Dec 1, 2018',
#   'NoCodeZ is the first app development tool that starts with a business story to build an app. The builder answers a series of questions (to narrate their app/solution) and our app ending uses NLP, AI and automation to build web and true native IOS and Android apps. We auto generate cloud infrastructure, app management portal and enterprise security features for each application. NoCodeZ is building an intuitive platform to democratize and simplify the process of building applications within an enterprise. We care deeply about simplicity and ease of use - in the complete process of planning, building and supporting enterprise apps. We see two types of customers - product builders (& product engineers), and Operations improvers (digitization, new integrations, business process).Our customers see us as "an agile automation and integration fabric for enterprise apps" or "a complete digital tech & support team."',
#   'Artificial Intelligence (AI), Enterprise Software, Machine Learning, Software',
#   'Saratoga, California, United States',
#   'A conversational approach to build enterprise apps, with next gen No Code.',
#   '142,615',
#   '95070',
#   'San Francisco Bay Area, Silicon Valley, West Coast',
#   'www.nocodez.com',
#   '—',
#   'View on LinkedIn',
#   '—',
#   'sridhar@nocodez.com',
#   '408-647-2888',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Data and Analytics, Science and Engineering, Software',
#   '$290,000',
#   'For Profit',
#   'Less than $1M'],
#  ['CSQ Holdings',
#   '1-10',
#   'Dec 1, 2018',
#   'CSQ Holdings is a team comprised of the owner-operators of SynQ Suite, CryptoSyndicate, and AE Software; focusing on the cryptocurrency markets, sentiment analysis, data aggregation, communication hub development, project management application development, and business intelligence reports in the Blockchain space.',
#   'Blockchain, Business Intelligence, Predictive Analytics, Software',
#   'Los Angeles, California, United States',
#   'Owners of SynQ Suite and CryptoSyndicate',
#   '149,635',
#   '90013',
#   'Greater Los Angeles Area, West Coast, Western US',
#   'csqholdings.net',
#   '—',
#   'View on LinkedIn',
#   '—',
#   'enrique@thecryptosyndicate.com',
#   '310-773-5305',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Blockchain and Cryptocurrency, Data and Analytics, Other, Software',
#   '$100,000',
#   'For Profit',
#   'Less than $1M'],
#  ['Sanction Scanner',
#   '11-50',
#   'Dec 1, 2018',
#   'Sanction Scanner is an anti-money laundering solutions provider established in 2019. We aimed to provide cost-efficient AML solutions that all-size businesses can use. Today, we are happy to serve in more than 35 countries with global AML solutions. The principal goal of Sanction Scanner is, fighting with financial crimes. With our solutions, companies know their clients, monitor transactions and check adverse media data. As we know, financial crimes destroy the economy and cause human trafficking, drug trafficking, and terrorist funding. With Sanction Scanner Software, your company won’t let it that. Join our family today, and together we create a better world without black money.',
#   'Artificial Intelligence (AI), Compliance, FinTech, Information Services, Information Technology, Machine Learning, Risk Management, Software',
#   'London, England, United Kingdom',
#   'Protect your business from financial crimes with Sanction Scanner, an AI-driven compliance software.',
#   '178,391',
#   '—',
#   'Europe, Middle East, and Africa (EMEA)',
#   'sanctionscanner.com/',
#   '—',
#   'View on LinkedIn',
#   '30',
#   'info@sanctionscanner.com',
#   '44 20 4577 0427',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Data and Analytics, Financial Services, Information Technology, Professional Services, Science and Engineering, Software',
#   '—',
#   'For Profit',
#   '$1M to $10M'],
#  ['Wiview',
#   '1-10',
#   'Dec 2018',
#   'Witview helps consumers make better purchasing decisions by gathering “What the Internet Thinks” of products being purchased online. With the AI-powered software Witview aggregates product review data from all around the internet and creates easy-to-read summaries on how the product has been rated, what is good and what is lacking from the product in question.',
#   'Artificial Intelligence (AI), E-Commerce, Internet, Retail, SEO, Software',
#   'Tampere, Western Finland, Finland',
#   'Witview helps consumers make better purchasing decisions by gathering “What the Internet Thinks” of products being purchased online.',
#   '180,085',
#   '33210',
#   'European Union (EU), Nordic Countries, Scandinavia',
#   'witview.io/',
#   '—',
#   'View on LinkedIn',
#   '1',
#   '—',
#   '—',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Commerce and Shopping, Data and Analytics, Internet Services, Sales and Marketing, Science and Engineering, Software',
#   '€50,000',
#   'For Profit',
#   'Less than $1M'],
#  ['Darhub',
#   '1-10',
#   'Dec 1, 2018',
#   "DarHub is an AI-based online marketplace connecting homeowners and SME's for contracting and finishing projects with credit scoring and smart cities at its core.",
#   'E-Commerce, Marketplace, Real Estate',
#   'Al Jizah, Al Jizah, Egypt',
#   'Marketplace for Home Improvement',
#   '199,924',
#   '—',
#   'Europe, Middle East, and Africa (EMEA), Middle East, Europe, Middle East, and Africa (EMEA)',
#   'darhub.com',
#   '—',
#   'View on LinkedIn',
#   '—',
#   'malek.azzam@darhub.com',
#   '00201200117992',
#   '—',
#   '—',
#   'Commerce and Shopping, Real Estate',
#   '$30,000',
#   'For Profit',
#   '—'],
#  ['SmartBots.ai',
#   '11-50',
#   'Dec 1, 2018',
#   'SmartBots is a cohesive bot development platform that designs, develops, validates, and deploys AI-powered conversational chatbots. It is a Conversational AI studio with all the necessary components for bots. The platform enables businesses to quickly build and deploy conversational bots for various channels, domains, and industries with significantly reduced time to market. It was founded in 2018 and is based in Texas.',
#   'Artificial Intelligence (AI), Chatbot, Information Technology, Machine Learning',
#   'Dallas, Texas, United States',
#   'SmartBots is a cohesive bot development platform that designs, develops, validates, and deploys AI-powered conversational chatbots.',
#   '236,880',
#   '75070',
#   'Dallas/Fort Worth Metroplex, Southern US',
#   'www.smartbots.ai',
#   '—',
#   'View on LinkedIn',
#   '2',
#   'info@smartbots.ai',
#   '419-290-6779',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Data and Analytics, Information Technology, Science and Engineering, Software',
#   '—',
#   'For Profit',
#   '$1M to $10M'],
#  ['Blue Pulse',
#   '51-100',
#   'Dec 2018',
#   'Blue Pulse is a technology-based company focusing on speech recognition and natural language understanding. They provide video captioning and audio-to-text services.',
#   'Apps, Software, Translation Service',
#   'Haidian, Beijing, China',
#   'Blue Pulse offers AI captioning platform intended to provide video subtitling services.',
#   '260,400',
#   '—',
#   'Asia-Pacific (APAC)',
#   'www.bluepulse.cn/',
#   '—',
#   '—',
#   '—',
#   'zhangguanqun@bluepulse.cn',
#   '158-0144-6895',
#   '—',
#   '1',
#   'Apps, Professional Services, Software',
#   '—',
#   'For Profit',
#   '—'],
#  ['Helixa',
#   '11-50',
#   'Dec 1, 2018',
#   'Helixa is a forward-thinking audience insights platform that uses ethical AI and machine learning technology to connect data sources in one easy to use tool. We build research platforms for the 21st century that have more depth and detail than you would ever get from a single source research platform. The results are incredibly detailed personas of the consumers who matter to your business.',
#   'Analytics, Artificial Intelligence (AI), Machine Learning, Market Research, SaaS, Software',
#   'New York, New York, United States',
#   'SAAS - Audience Intelligence Platform uncovering Human Complexity with AI Power',
#   '280,909',
#   '10017',
#   'Greater New York Area, East Coast, Northeastern US',
#   'www.helixa.ai',
#   '—',
#   'View on LinkedIn',
#   '1',
#   'marketing@helixa.ai',
#   '212-547-9897',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Data and Analytics, Design, Science and Engineering, Software',
#   '—',
#   'For Profit',
#   '$1M to $10M'],
#  ['Ampliz | Prospect Decisions. Supercharged.',
#   '11-50',
#   'Dec 2018',
#   'Ampliz SalesBuddy – An AI backed Sales Intelligence Platform to help Sales folks score target prospects against their core criteria. Ampliz ensures you make sense of humongous volumes of data in seconds. Here’s how Ampliz SalesBuddy is set to scale your sales efficiency: 1. Assess prospects based on your core criteria – Get a prospect fit score 2. Find top decision makers & target company information worth prospecting 3. Get custom information based on your niche preferences',
#   'Artificial Intelligence (AI), Business Development, Data Mining, Database, Machine Learning, Marketing Automation, Sales, Sales Automation',
#   'Emeryville, California, United States',
#   'Ampliz is a Sales Intelligence Platform that assists Sales professionals make smart data driven decisions.',
#   '286,059',
#   '—',
#   'San Francisco Bay Area, West Coast, Western US',
#   'www.ampliz.com/',
#   '—',
#   'View on LinkedIn',
#   '1',
#   'getsuperpowers@ampliz.com',
#   '+1(844) 289-3513',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Data and Analytics, Information Technology, Professional Services, Sales and Marketing, Science and Engineering, Software',
#   '—',
#   'For Profit',
#   '$1M to $10M'],
#  ['Galliot',
#   '11-50',
#   'Dec 2018',
#   '—',
#   'Artificial Intelligence (AI), DevOps, Machine Learning',
#   'San Francisco, California, United States',
#   'Web/Mobile App development, AI, Machine Learning and DevOps',
#   '360,576',
#   '94107',
#   'San Francisco Bay Area, West Coast, Western US',
#   'galliot.us/',
#   '—',
#   'View on LinkedIn',
#   '2',
#   'hello@galliot.us',
#   '628-254-0780',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Data and Analytics, Information Technology, Science and Engineering, Software',
#   '—',
#   'For Profit',
#   '—'],
#  ['AristanderAI',
#   '1-10',
#   'Dec 2018',
#   "We're bringing the dynamic pricing algorithms that power companies like Amazon to medium and small e-commerce companies. You install our plugin, we begin tracking the customer journeys, and we deliver better prices using machine learning - bringing our users up to 15% in net profit uplift. We're making a faster, low-cost solution for price optimization, therefore reaching a much wider audience. We're doing this by using automated machine learning + e-commerce plugins to reduce # of data scientists required per project, and cost of integration + feature annotation.",
#   'Machine Learning',
#   'Berlin, Berlin, Germany',
#   "We're bringing the dynamic pricing algorithms that power companies like Amazon to medium and small e-commerce companies.",
#   '401,779',
#   '10437',
#   'European Union (EU), Europe, Middle East, and Africa (EMEA)',
#   'aristander.ai',
#   '—',
#   'View on LinkedIn',
#   '1',
#   '—',
#   '—',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Data and Analytics, Software',
#   '—',
#   'For Profit',
#   '—'],
#  ['Synkar Autonomous',
#   '11-50',
#   'Dec 1, 2018',
#   'Synkar is a Brazilian-Canadian Startup developing autonomous delivery solutions for indoor and outdoor applications. From its beginning with factory indoor robots to its latest products for sidewalk delivery, Synkar uses the previous academic and research experience in robotics and AI to change the way we do deliveries. Our business model makes robots available as a service, with any business being able to subscribe to a scalable fee and use the robotic fleet the way they want! These delivery robots are providing affordability and scalability to the needs of our partners, being a Closed-Community Delivery Service, an In-Company Delivery, or a B2C Delivery APP. We already have a partnership with the largest delivery app in South America (iFood) to use our robots for First-Mile delivery in Shopping Centers, and we hope to start sidewalk deliveries in Canada in the second half of 2020.',
#   'Artificial Intelligence (AI), Delivery Service, Food Delivery, Robotics, Software',
#   'Oshawa, Ontario, Canada',
#   'Synkar is a Canadian company making autonomous delivery solutions to the world.',
#   '408,754',
#   'L1H 8C1',
#   'Great Lakes',
#   'www.synkar.com',
#   '—',
#   'View on LinkedIn',
#   '9',
#   'synkar@synkar.com',
#   '+55 16 35123330',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Data and Analytics, Food and Beverage, Hardware, Science and Engineering, Software, Transportation',
#   '—',
#   'For Profit',
#   '—'],
#  ['Terroir AI',
#   '1-10',
#   'Dec 2018',
#   'Terroir AI provides real-time insights to help farmers manage their farms and meet harvest targets.It is a real-time red leaf virus mapping app.  They translate data collected in the field into maps, summary statistics, and forecasts to make decisions when it counts.',
#   'Agriculture, Artificial Intelligence (AI), CRM, Food and Beverage, Machine Learning, Software',
#   'Menlo Park, California, United States',
#   'Terroir AI is a machine learning to help take the uncertainty out of farming.',
#   '417,691',
#   '—',
#   'San Francisco Bay Area, Silicon Valley, West Coast',
#   'terroirai.com',
#   '—',
#   'View on LinkedIn',
#   '—',
#   'nathanstrong@terroirai.com',
#   '—',
#   '—',
#   '—',
#   'Agriculture and Farming, Artificial Intelligence (AI), Data and Analytics, Food and Beverage, Information Technology, Sales and Marketing, Science and Engineering, Software',
#   '—',
#   'For Profit',
#   '—'],
#  ['Optiwisdom',
#   '11-50',
#   'Dec 1, 2018',
#   'Optiwisdom is an AI-based software development company. It created Auto ML engines Optiscorer, Optimatcher, and Optisegment in order to make machine learning available to all companies without the need of a data scientist. Optiwisdom focuses on developing software for industry specific solutions based on these engines namely Collectwiser and Optifraud. Collectwiser is a debt collection tool that predicts who are more likely to pay and optimizes the time and the reach method to debtors with the best payment offers and Optifraud is a tool that identifies and prevents financial fraud.',
#   'Artificial Intelligence (AI), Big Data, Consulting, CRM, Enterprise Software, FinTech, Machine Learning, Software',
#   'San Francisco, California, United States',
#   'Optiwisdom is an AI-based software development company. Optiwisdom created Auto ML engines Optiscorer, Optimatcher, and Optisegment',
#   '428,385',
#   '94119',
#   'San Francisco Bay Area, West Coast, Western US',
#   'www.optiwisdom.com',
#   '—',
#   'View on LinkedIn',
#   '—',
#   'optiwisdom@optiwisdom.com',
#   '905316056726',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Data and Analytics, Financial Services, Information Technology, Professional Services, Sales and Marketing, Science and Engineering, Software',
#   '—',
#   'For Profit',
#   'Less than $1M'],
#  ['KidX',
#   '11-50',
#   'Dec 2018',
#   'KidX is an interactive AI education company. It is creating the next-generation education experience enhanced with state-of-the-art technology, empowering AI to bridge the physical and digital world. It integrates its own hardware, software, technology, and content to deliver an interactive video and play experience using real-world physical play.',
#   'Artificial Intelligence (AI), Children, Consumer Electronics, Education, Machine Learning',
#   'Wilmington, Delaware, United States',
#   'KidX is is an interactive AI education company creating the next generation education experience to bridge the physical and digital world.',
#   '479,286',
#   '19804',
#   'Greater Philadelphia Area, East Coast, Southern US',
#   'www.playkidx.com/',
#   '—',
#   'View on LinkedIn',
#   '—',
#   'media@playkidx.com',
#   '—',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Community and Lifestyle, Consumer Electronics, Data and Analytics, Education, Hardware, Science and Engineering, Software',
#   '—',
#   'For Profit',
#   'Less than $1M'],
#  ['Movez Analytics',
#   '11-50',
#   'Dec 1, 2018',
#   "Movez is a computer software company that develops a sports analytics platform based on artificial intelligence and machine learning. Its platform analyzes its users' sports capability and provides a guide and tips on each chosen sports. The company was founded in 2018 and headquartered in Tel Aviv, Israel.",
#   'Analytics, Artificial Intelligence (AI), Machine Learning, Software',
#   'Herzliya, Tel Aviv, Israel',
#   'Movez is a computer software company that develops a sports analytics platform based on artificial intelligence and machine learning.',
#   '559,010',
#   '—',
#   'Europe, Middle East, and Africa (EMEA), Middle East',
#   'movez.ai',
#   '—',
#   'View on LinkedIn',
#   '—',
#   'Info@movez.ai',
#   '—',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Data and Analytics, Science and Engineering, Software',
#   '—',
#   'For Profit',
#   '—'],
#  ['Tech Phenomenon',
#   '1-10',
#   'Dec 1, 2018',
# ...
#   '—',
#   'For Profit',
#   '—'],
#  ['RELU Labs',
#   '1-10',
#   'Jan 2019',
#   'Our platform aims to alleviate issues throughout the hiring process for data scientists by creating a cohesive platform to attract, retain, and train top level data science talent. Furthermore, we aim to streamline the hiring process for companies seeking data science professionals by integrating evaluation and benchmarking tools into one site. Lastly, we are baking in social features that make it easier for data scientists to network and share problems.',
#   'Analytics, Artificial Intelligence (AI), Education, Human Resources, Information Technology, Machine Learning, Small and Medium Businesses, Warehouse Automation',
#   'Cypress, California, United States',
#   'RELU Labs is working on improving robotic perception and automation capabilities in the space of assembly and warehouse logistics.',
#   '1,088,059',
#   '90630',
#   'Greater Los Angeles Area, West Coast, Western US',
#   'www.relulabs.ai',
#   '—',
#   'View on LinkedIn',
#   '—',
#   'contact@relulabs.ai',
#   '714-743-2407',
#   '—',
#   '—',
#   'Administrative Services, Artificial Intelligence (AI), Data and Analytics, Education, Information Technology, Other, Science and Engineering, Software, Transportation',
#   '—',
#   'For Profit',
#   '—'],
#  ['straiqr.ai',
#   '1-10',
#   '2019',
#   "The company Straiqr.ai develops NFT-based artificial intelligence platforms for shopping and fashion. Among the company's products is PHIBER which is a NFT platform that merges cutting-edge technology with fashion. AI and AR for Virtual Try-On of digital fashion to share on social media. The PHIBER also includes: - A user-friendly NFT marketplace: NFTs & Blockchain as a simple e-commerce solution, without requiring any knowledge of blockchain technology or ownership of cryptocurrencies - facilitating interoperability of digital fashion: skins 2.0 for nft games and virtual worlds - building a design studio so PHIBER users can co-create and customize their digital fashion outfits",
#   'Blockchain, Fashion, Shopping, Software, Software Engineering',
#   'Düsseldorf, Nordrhein-Westfalen, Germany',
#   'straiqr.ai is a software development company making artificial intelligence-based NFT platforms for shopping and fashion solutions.',
#   '1,095,816',
#   '40221',
#   'European Union (EU), Europe, Middle East, and Africa (EMEA)',
#   'www.straiqr.ai/',
#   '—',
#   'View on LinkedIn',
#   '—',
#   'mail@straiqr.ai',
#   '+49(0)1723870510',
#   '—',
#   '—',
#   'Blockchain and Cryptocurrency, Clothing and Apparel, Commerce and Shopping, Design, Other, Science and Engineering, Software',
#   '—',
#   'For Profit',
#   '$1M to $10M'],
#  ['DataEthics4All',
#   '1-10',
#   '2019',
#   'DataEthics4Allᵀᴹ Foundation Raising Ethics 1st Data and AI Champions through STEAM in AI College Prep, Mentoring, and Experiential Learning! DataEthics4All has developed a framework called Ethics 1stᵀᴹ Data and AI Framework, which consists of 12 pillars that cover various aspects of ethical data and AI practices, such as responsible data collection and use, data transparency and trust, explicit consent, sunset policy, data privacy and security, data brokering, data inclusivity, data power, and control. It was founded in 2020.',
#   'Artificial Intelligence (AI), Social, Social Assistance, Social Media',
#   'Lewes, Delaware, United States',
#   'DataEthics4All raise awareness on the Ethical use of Data and build the next-generation of Inclusive AI.',
#   '1,098,295',
#   '19958',
#   'East Coast, Southern US',
#   'dataethics4all.org/',
#   '—',
#   'View on LinkedIn',
#   '—',
#   '—',
#   '—',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Community and Lifestyle, Data and Analytics, Government and Military, Internet Services, Media and Entertainment, Science and Engineering, Software',
#   '—',
#   'Non-profit',
#   '—'],
#  ['Prosh',
#   '1-10',
#   '2019',
#   'Prosh is an eCommerce platform combines the community of local markets with the accessibility of online shopping. They give local business owners the tools to successfully tap into the boom of eCommerce consumer shopping habits and empower the growth of our local economy. They’ve taken all the advantages of shopping at your local farmer’s or Christmas market and created an online platform with both the vendor and the customer in mind. Their AI-powered marketing solutions personalize product recommendations to optimize purchasing conversions for our vendors. They are able to offer better and cheaper delivery options with courier partner, enabling customers to support homegrown business.',
#   'E-Commerce, E-Commerce Platforms, Marketing, Shopping',
#   'Calgary, Alberta, Canada',
#   'Prosh is an eCommerce platform combines the community of local markets with the accessibility of online shopping.',
#   '1,099,633',
#   '—',
#   '—',
#   'shopprosh.com/',
#   '—',
#   'View on LinkedIn',
#   '—',
#   'admin@shopprosh.com',
#   '(403) 453-2990',
#   '—',
#   '—',
#   'Commerce and Shopping, Internet Services, Sales and Marketing',
#   '—',
#   'For Profit',
#   '—'],
#  ['CoantumLeap',
#   '1-10',
#   '2019',
#   '—',
#   'Analytics, Artificial Intelligence (AI), Digital Marketing, Information Technology',
#   'Singapore, Central Region, Singapore',
#   'CoantumLeap is a digital transformation platform that focuses on technology growth in artificial intelligence, automation, and analytics.',
#   '1,102,854',
#   '259959',
#   'Asia-Pacific (APAC), Association of Southeast Asian Nations (ASEAN), Southeast Asia',
#   'coantumleap.com/index.html',
#   '—',
#   'View on LinkedIn',
#   '—',
#   'stratops@coantumleap.com',
#   '—',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Data and Analytics, Information Technology, Sales and Marketing, Science and Engineering, Software',
#   '—',
#   'For Profit',
#   '—'],
#  ['Virtu House',
#   '1-10',
#   '2019',
#   'Welcome to Virtuhouse, the new and innovative way to relocate across town or even across the country! With our innovative technology you can view your new home from the comfort of your own bed! You save time and energy by scheduling virtual tours of properties you are interested before going to see them in person. Our unique AI Technology will anticipate your needs and even recommend locations based on your needs and wants. Life can take you to unexpected places, we will take you home.',
#   '—',
#   'Orlando, Florida, United States',
#   'Virtuhouse is the new and innovative way to relocate across town or even across the country.',
#   '1,107,552',
#   '—',
#   'East Coast, Southern US',
#   'virtuhouse.com/',
#   '—',
#   'View on LinkedIn',
#   '—',
#   '—',
#   '—',
#   '—',
#   '—',
#   '—',
#   '—',
#   'For Profit',
#   '—'],
#  ['ERMES-X',
#   '1-10',
#   '2019',
#   'ERMES-X offers the development and supply of software as a service using operational research algorithms and artificial intelligence supported by cloud architectures, personnel planning, and warehouse management services.',
#   'Artificial Intelligence (AI), Information Technology, Software',
#   'Gossolengo, Emilia-Romagna, Italy',
#   'ERMES-X provides software development services for the optimization of operational activities.',
#   '1,113,361',
#   '29020',
#   'European Union (EU), Europe, Middle East, and Africa (EMEA)',
#   'www.ermes-x.com',
#   '—',
#   'View on LinkedIn',
#   '—',
#   'amministrazione@ermes-x.com',
#   '—',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Data and Analytics, Information Technology, Science and Engineering, Software',
#   '—',
#   'For Profit',
#   '—'],
#  ['Audapio',
#   '1-10',
#   '2019',
#   'Audapio develops analytics solutions for auditing professionals by leveraging open banking data and artificial intelligence.',
#   'Accounting, Analytics, Artificial Intelligence (AI), Machine Learning',
#   'Brighton, East Sussex, United Kingdom',
#   'Audapio develops analytics solutions for auditing professionals by leveraging open banking data and artificial intelligence.',
#   '1,120,529',
#   'BN1 6SB',
#   'Europe, Middle East, and Africa (EMEA)',
#   'www.audapio.com/',
#   '—',
#   'View on LinkedIn',
#   '—',
#   'hello@audapio.com',
#   '—',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Data and Analytics, Financial Services, Professional Services, Science and Engineering, Software',
#   '—',
#   'For Profit',
#   '—'],
#  ['Pack Moose',
#   '1-10',
#   '2019',
#   'Pack Moose operates as a Machine Learning incubator, focusing on the development of new products across various industries. The company specializes in offering comprehensive data solutions including database setup and management, data visualization, as well as statistical modeling and machine learning services. Pack Moose leverages its Consumer Fingerprint technology to predict specific consumer behaviors such as purchasing patterns and moving trends. This approach enables businesses to gain insightful data about their customers, enhancing decision-making processes and strategic planning. The team at Pack Moose consists of experts in data science, including roles such as Founder/Director of Data Science, Senior Data Scientist / Machine Learning Engineer, and Director of Technology.',
#   'Artificial Intelligence (AI), Data Visualization, Database, Machine Learning',
#   'Waterloo, Iowa, United States',
#   'Pack Moose specializes in Machine Learning, offering database management, data visualization, and predictive analytics.',
#   '1,122,535',
#   '50613',
#   'Midwestern US',
#   'www.packmoose.com',
#   '—',
#   'View on LinkedIn',
#   '—',
#   '—',
#   '—',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Data and Analytics, Design, Information Technology, Science and Engineering, Software',
#   '—',
#   'For Profit',
#   '$1M to $10M'],
#  ['Universal Intelligence',
#   '1-10',
#   '2019',
#   '—',
#   'Artificial Intelligence (AI), Enterprise Software, Product Management',
#   'Austin, Texas, United States',
#   'Universal Intelligence is a consultancy firm that specializes in AI strategy, spatial computing, and enterprise software development.',
#   '1,126,088',
#   '—',
#   'Southern US',
#   'www.universalintelligence.io/',
#   '—',
#   'View on LinkedIn',
#   '—',
#   'info@universalintelligence.io',
#   '—',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Data and Analytics, Other, Science and Engineering, Software',
#   '—',
#   'For Profit',
#   'Less than $1M'],
#  ['360MAKER',
#   '1-10',
#   '2019',
#   '360MAKER provides 360 video, 3D animation, marketing strategy, marketing communications, virtual reality, augmented reality, graphic design, video editing, mobile applications, digital marketing, marketing online, virtual tour, storytelling, web design, public relations, marketing, creative direction, social media, advertising, adobe suite, and project management services.',
#   'Artificial Intelligence (AI), Augmented Reality, Virtual Reality',
#   'Offanengo, Lombardia, Italy',
#   '360MAKER provides augmented reality, virtual reality, and artificial intelligence services.',
#   '1,127,859',
#   '26010',
#   'European Union (EU), Europe, Middle East, and Africa (EMEA)',
#   '360maker.it',
#   '—',
#   'View on LinkedIn',
#   '—',
#   'info@360maker.it',
#   '+39 0373 780466',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Data and Analytics, Hardware, Science and Engineering, Software',
#   '—',
#   'For Profit',
#   '$1M to $10M'],
#  ['Mettle Capital',
#   '1-10',
#   '2019',
#   '—',
#   'Finance, Financial Services, Predictive Analytics',
#   'London, England, United Kingdom',
#   'Mettle Capital provides data, visualizations, and gen AI analytics of evolving risks for companies around the issues of sustainability.',
#   '1,130,379',
#   '—',
#   'Europe, Middle East, and Africa (EMEA)',
#   'mettle.capital',
#   '—',
#   'View on LinkedIn',
#   '—',
#   '—',
#   '—',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Data and Analytics, Financial Services, Software',
#   '—',
#   'For Profit',
#   '$1M to $10M'],
#  ['Stratobotic',
#   '1-10',
#   '2019',
#   'Stratobotic offers data relay, earth observation, haps prototyping, and AI application services. Their HAPS prototyping consists of prototypes of new innovative HAPS platforms. AI Applications The development of software that uses AI methods for mission support.',
#   'Artificial Intelligence (AI), Satellite Communication, Telecommunications',
#   'Torino, Piemonte, Italy',
#   'Stratobotic offers telecommunications and earth observation services.',
#   '1,139,304',
#   '10128',
#   'European Union (EU), Europe, Middle East, and Africa (EMEA)',
#   'stratobotic.com',
#   '—',
#   '—',
#   '—',
#   'info@stratobotic.com',
#   '—',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Data and Analytics, Hardware, Science and Engineering, Software',
#   '—',
#   'For Profit',
#   '—'],
#  ['Intercept CX',
#   '1-10',
#   '2019',
#   "Surveys are fundamentally flawed for understanding a customer’s thoughts, feelings, and actions. Intercept uses mobile video and machine learning technologies to enable business leaders to effortlessly collect and interpret customer experience research at scale. Instead of capturing a customer’s feedback via surveys delivered long after an experience with your brand, Intercept captures that feedback at the instant the customer is experiencing it. All while providing a low barrier-to-entry for your company’s customer experience team and a simple, browser-based video response experience for your customers. Whether used for testing and improving physical products or for understanding and improving in-person experiences, Intercept is a digital ethnography platform that uncovers the stories and sentiment behind your actual customer's experiences. Ultimately allowing brand leaders to bring the voice of the customer into every decision that is made.",
#   'Analytics, Machine Learning, Software',
#   'Tempe, Arizona, United States',
#   'Real Time Customer Experience Feedback Via Video and Voice',
#   '1,147,945',
#   '85281',
#   'Greater Phoenix Area, Western US',
#   'intercept.cx',
#   '—',
#   'View on LinkedIn',
#   '—',
#   'hello@intercept.cx',
#   '—',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Data and Analytics, Software',
#   '—',
#   'For Profit',
#   '—'],
#  ['Predict Point',
#   '1-10',
#   '2019',
#   'PredictPoint Inc., is a young Seattle based Internet start-up focused on helping e-commerce companies realize greater profitability through intelligent merchandising applications. Founded in January 1999, PredictPoint provides e-commerce marketing and merchandising managers with next generation tools to help them analyze and maximize their e-commerce initiatives. PredictPoint is currently developing its flagship product and is seeking talented and motivated individuals to help take e-commerce to the next frontier.',
#   'E-Commerce, Internet, Machine Learning, SaaS, Software',
#   'Seattle, Washington, United States',
#   'SaaS, AI, Machine Learning, Supply Chain, Sales Optimization',
#   '1,152,225',
#   '98104',
#   'Greater Seattle Area, West Coast, Western US',
#   'predictpoint.com',
#   '—',
#   '—',
#   '—',
#   'info@predictpoint.com',
#   '9187860900',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Commerce and Shopping, Data and Analytics, Internet Services, Software',
#   '$1,000,000',
#   'For Profit',
#   '—'],
#  ['Spartan Capital Intelligence',
#   '1-10',
#   '2019',
#   'Spartan Capital Intel machine learning algorithms are trained to determine patterns, causation, and correlation in order to predict the impact of factors affecting the company’s performance that in turn have a direct impact on the company’s valuation. Using similar technologies and with the addition of knowledge graphs and logic engines, SCI is also creating a system for financial reporting that will be the first of its kind and will be launched to market soon.',
#   'Analytics, Artificial Intelligence (AI), Data Storage, Financial Services, Machine Learning',
#   'Boulder, Colorado, United States',
#   'Spartan Capital Intelligence offers web-based and AI-enabled financial reporting, analysis, and forecasting services to consumers.',
#   '1,155,446',
#   '80302',
#   'Greater Denver Area, Western US',
#   'www.spartancapitalintel.com',
#   '—',
#   'View on LinkedIn',
#   '—',
#   '—',
#   '—',
#   '—',
#   '—',
#   'Artificial Intelligence (AI), Data and Analytics, Financial Services, Hardware, Science and Engineering, Software',
#   '—',
#   'For Profit',
#   'Less than $1M'],
#  ...]
