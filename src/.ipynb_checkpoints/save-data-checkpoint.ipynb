# %%
import json
import pandas as pd 
from datetime import datetime
def parse_date(date):
    if "," in date:
        return datetime.strptime(date, "%b %d, %Y")
    elif len(date)==4:
        return datetime.strptime(date, "%Y")
    else:
        return datetime.strptime(date, "%b %Y")
        
with open('../input/crunchbase/2014/log.json', 'r') as file:
    data = json.load(file)

header = data[0]
processed_data = []
count = 0
for i, line in enumerate(data):
    if count % 51 == 0:
        count = 1
        continue
    processed_data.append(line)
    count += 1
    


df = pd.DataFrame(processed_data)
df.columns = [x.lower() for x in header]
df["founded date"] = df["founded date"].apply(lambda x: parse_date(x))
df['description_all'] = df['description'] + " " + df['full description']

# %%
df.to_csv("../output/data/2014-data.csv")

# %%
df.head()
# Out:
#   organization name founded date number of employees  \
# 0  Gro Intelligence   2014-01-01             101-250
# 1          Affinity   2014-01-01             101-250
# 2             Rokid   2014-01-01             251-500
# 3       Indico Data   2014-01-01             101-250
# 4  Camino Financial   2014-01-01             101-250
#
#                                           industries  \
# 0  Agriculture,Artificial Intelligence (AI),Big D...
# 1  Analytics,Artificial Intelligence (AI),Busines...
# 2  Artificial Intelligence (AI),Augmented Reality...
# 3  Analytics,Artificial Intelligence (AI),Machine...
# 4  Artificial Intelligence (AI),Commercial Lendin...
#
#                                     full description  \
# 0  Gro is a global team of technology, climate, a...
# 1  Affinity is a relationship intelligence platfo...
# 2  Rokid is a Chinese technology company speciali...
# 3  Indico Data transforms unstructured data into ...
# 4  Camino Financial is an AI-powered community le...
#
#                                          description  \
# 0  The AI-powered decision engine across agricult...
# 1  Affinity is a relationship intelligence platfo...
# 2  Rokid specializes in augmented reality technol...
# 3  Indico Data provides data intelligent intake s...
# 4  Camino Financial is an online finance company ...
#
#                     website                                    description_all
# 0  www.gro-intelligence.com  The AI-powered decision engine across agricult...
# 1              affinity.co/  Affinity is a relationship intelligence platfo...
# 2                  rokid.ai  Rokid specializes in augmented reality technol...
# 3             indicodata.ai  Indico Data provides data intelligent intake s...
# 4  www.caminofinancial.com/  Camino Financial is an online finance company ...
