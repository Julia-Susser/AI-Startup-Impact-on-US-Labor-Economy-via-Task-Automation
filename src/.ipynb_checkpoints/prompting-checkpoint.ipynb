# %%
import pandas as pd
import numpy as np
from llms import gemini
from llms import chatGPT
import re
import time
from lemmatize import lemmatize
x_chat = chatGPT()
x_gemini = gemini()

# %%
df = pd.read_csv("../output/data/data_post_chat_gpt.csv")
df = df[df["headquarters location"].str.contains("United States")]
df = df[pd.to_datetime(df['founded date'])>='11/30/2022']

# %%
len(df)
# Out:
# 2210

# %%
generated_description_prompt = """
Your role is to describe $company ($website)'s product. 
Then, provide a confidence interval on scale on 1-10 on how sure you are about the response. Please be reasonable.

PLEASE FOLLOW THE FORMAT EXACTLY FROM THE EXAMPLES!!!!

EXAMPLES BELOW
************************
Company: Genmo
Website: https://www.genmo.ai/
Description: Genmo is a free tool that creates videos and images using artificial intelligence. Genmo to generate creative text formats of text content, like poems, code, scripts, musical pieces, email, letters, etc.

Company: OnePane
Website: https://www.onepane.ai/
Description: Onepane is a company that offers an AI companion for enhanced DevOps & SRE efficiency. Onepane offers a GenAI solution  providing unparalleled unified insights and control over your Cloud resources. Onepane helps with root cause analysis, cloud governance, and optimization strategies.
************************

YOUR TURN:
Company: $company
Wesbite: $website
Current Description: $description
________________________
Description (two sentences):
Confidence Interval:
Reasoning:
________________________

"""

# %%
parsed_description_prompt = """
Your role is to describe what jobs/tasks, industries, and customer that $company is targeting. Then, provide a confidence interval (1-10) on scale on 1-10 on how sure you are about the response. Please be reasonable.

A response should include:
- tasks/jobs being automated
- the industry that the startup applies to
- specific customers using the tool. DO NOT INCLUDE AN EXPLANATION

PLEASE FOLLOW THE FORMAT EXACTLY FROM THE EXAMPLES!!!!

EXAMPLES BELOW
************************
Company: Petville
Website: petville.co/pricing/biz
Description: Petville Global is a B2B CRM SaaS platform that utilizes advanced technologies like AI/ML and neural net to streamline and expand operations for pet businesses and veterinary clinics both locally and globally. The platform offers deep data analytics and marketing tools, helping businesses save an average of 22% on CRM and vet tech costs.
Tasks/Jobs: Data analysis, Marketing automation, Appointment scheduling, Inventory management
Industry: Customer management
Customers: Vetinarians, Pet Businesses

Company: Thunder
Wesbite: thundercompute.com
Description: Thunder is a decentralized, peer-to-peer cloud computing platform designed to democratize access to GPUs and address the persistent GPU shortage. It provides a solution for individuals and businesses seeking high-performance computing power, enabling them to leverage unused GPU resources from around the world.
Tasks/Jobs: GPU resource allocation, Access to unused GPUs, Distributed computing tasks 
Industry: Cloud Computing
Customers: Developers, GPU Owners

Company: NonprofitsHQ
Websit: www.nonprofitshq.com
Description: NonprofitsHQ is a software suite designed for nonprofits that utilizes AI to automate tasks, manage operations, and improve efficiency, ultimately saving organizations time and resources.
Tasks/Jobs: Fundraising management, Donor relationship management, Grant writing, Event planning
Industry: Non-profit management
Customers: Non-profit organizations
************************

YOUR TURN:
________________________
Company: $company
Wesbite: $website
Description: $description
________________________
Tasks/Jobs (comma separated list of 4, short):
Industry (1 item):
Customers (comma separated list): 
________________________
Confidence Interval:
Reasoning:
________________________
"""

# %%
examples_prompt = """
Your role is to provide 3 two-sentence examples of how the product from $company might be used. Do not mention the name of the company in the examples, and keep the descriptions broad.

Each example should include:
- A detailed description of the job that the tool automates and who performs that job and when.
- The ONET job being automated (preferably one from the database https://www.onetonline.org/) and the ONET task that the tool replaces (preferably one that from https://www.onetcenter.org/dictionary/20.1/excel/task_statements.html, include task id)
- A confidence interval (1-10) indicating how sure you are about the accuracy of your response.

PLEASE FOLLOW THE FORMAT EXACTLY FROM THE EXAMPLES!!!!

The goal is to map each example back to ONET jobs. If the job being automated is recognized by ONET, please use the ONET job title. 
If it is not typically found in ONET, use best judgement!

EXAMPLES BELOW: 
************************
Company: Blanc
Website: tryblanc.ai
Blanc is a compliance automation platform designed for fintech companies. It helps streamline regulatory compliance processes by providing a centralized hub for managing policies, monitoring activities, and generating reports.
_________________________
Example 1: A compliance officer at a fintech company uses Blanc to automate the process of creating and updating compliance policies, ensuring all documents are current and accessible to relevant team members.
ONET JOB automated 1: Compliance Officers that verify that all firm and regulatory policies and procedures have been documented, implemented, and communicated.
ONET JOB 1: Compliance Officers
_________________________
Example 2: A fintech company uses Blanc to generate automated compliance reports for regulatory audits, ensuring all necessary documentation is readily available and organized.
ONET JOB automated 2: Compliance Officers Prepare reports of activities, evaluations, recommendations, or decisions.
ONET JOB 2: Compliance Officers
_________________________
Example 3: A fintech company uses Blanc to monitor real-time transactions for potential compliance violations, triggering alerts and generating reports for further investigation.
ONET JOB automated 3: Compliance Officers that identify compliance issues that require follow-up or investigation.
ONET JOB 3: Compliance Officers



Company: Aether
Website: aetherenergie.com/
Aether Energy is an AI-driven platform designed to simplify the process of rooftop solar installation for businesses, providing comprehensive support from project planning and financing to installation and ongoing maintenance. This platform aims to streamline and optimize the entire solar energy journey for installers. 
________________
Example 1: A solar installer uses Aether to quickly create detailed project plans for rooftop solar installations, including system size, panel placement, and wiring diagrams. 
ONET JOB automated 1: Solar Photovoltaic Installers that diagram layouts and locations for photovoltaic (PV) arrays and equipment, including existing building or site features.
ONET JOB 1: Solar Photovoltaic Installers
________________
Example 2: A business owner leverages Aether to secure financing for their rooftop solar project, providing them with customized loan options and streamlined application processes. 
ONET JOB automated 2: Solar Photovoltaic Installers that prepare solar installation project proposals, quotes, budgets, or schedules.
ONET JOB 2: Solar Photovoltaic Installers
________________
Example 3: A solar installer uses Aether to manage the installation process, tracking materials, scheduling technicians, and coordinating with subcontractors, ensuring smooth project execution. 
ONET JOB automated 3:  Solar Engery Installation Managers that monitor work of contractors and subcontractors to ensure projects conform to plans, specifications, schedules, or budgets.
ONET JOB 3: Solar Energy Installation Managers
________________
************************

YOUR TURN:
Company:$company
Website: $website
Current Description: $description
$parsed_description
________________
Example 1: 
ONET JOB automated 1:
ONET JOB 1: 
Confidence Interval 1:
Reasoning 1:
________________
Example 2: 
ONET JOB automated 2:
ONET JOB 2: 
Confidence Interval 2:
Reasoning 2:
________________
Example 3:
ONET JOB automated 3:
ONET JOB 3: 
Confidence Interval 3:
Reasoning 3:
________________
"""

# %%
class prompting():
    def __init__(self):
        pass
        
    def iterate(self, df, prompt_template, args, value, start=0, end=False):
        if end == False:
            end = len(df)
            
        if start == 0:
            self.results_df = pd.DataFrame(columns=["organization name",value])
        
        if value in list(df.columns): 
            if start != 0:
                self.results_df = pd.concat([df[["organization name",value]].iloc[:start],self.results_df],axis=0)
            df = df.drop(columns=[value])
        
        
        for i, row in list(df.iterrows())[start:end]:
            failure_count = 0
            prompt = prompt_template
            while True:
                try:
                    name = row['organization name']
                    website = row['website']
                    print(f"******************************\nProcessing {i}: {name}, {website}")
                    if "generated_description" in df.columns:
                        print(row["generated_description"])

                    for arg in args: 
                        prompt = prompt.replace(f"${arg[0]}", row[arg[1]])
                    result = x_gemini.ask(prompt)
                    if result == "N/A": break #explicit material
 
                    text = re.sub(r"#|#\s+|_|\*", "", result).strip()
                    print(f"Result:\n{text}\n")
   
                    self.results_df.loc[i] = [name, result]
                    break 
                
                except Exception as e:
                    print(failure_count)
                    failure_count += 1
                    if failure_count > 10: 
                        break
                    print(f"Error processing {i}, {row['organization name']}: {e}")
                    time.sleep(20)  
                if i % 5 == 0:
                    self.results_df.to_csv("../output/current_results_df_prompting.csv")

            
        df = df.merge(self.results_df, on='organization name', how='left')
        return df

prompting_class = prompting()

# %%
cols = ["generated_description", "generated_description_conf_interval", "generated_description_conf_interval_reasoning"]

args = [["company","organization name"],["website","website"], ["description","description_all"]]

df = prompting_class.iterate(df, generated_description_prompt, args, "generated_description_llm")

df.to_csv('../output/df_with_generated_description.csv', index=False)
# Out:
# ******************************
# Processing 0: Pika, pika.art
# Result:
# Description (two sentences):
# Pika is an AI-powered platform that transforms captions and still images into professional-looking videos. With its intuitive interface, Pika simplifies video creation and editing, making it accessible to users of all skill levels.
#
# Confidence Interval: 8
# Reasoning:  While Pika's website doesn't go into deep detail about its features,  the information provided clearly indicates its focus on AI-powered video generation and editing. The emphasis on accessibility and user-friendliness aligns with the current trends in AI-driven creative tools.
#
# ******************************
# Processing 1: Contextual AI, contextual.ai
# Result:
# Contextual AI
#
# Description (two sentences): Contextual AI provides a cutting-edge generative AI platform designed specifically for business applications. Their technology empowers employees to generate creative content, automate workflows, and gain insights from data, all while ensuring alignment with company-specific context and knowledge.
#
# Confidence Interval: 6/10
#
# Reasoning:  While the website does state Contextual AI focuses on workplace AI, it lacks concrete details on specific functionalities or use cases.  The "pioneering approach" claim is vague and requires further information.  However, the general description aligns with the trend of applying generative AI to business processes, suggesting a reasonable degree of certainty.
#
# ******************************
# Processing 2: Sierra, sierra.ai
# Result:
# Sierra (sierra.ai)
#
# Description (two sentences): Sierra is an AI company that develops conversational AI agents designed to enhance business workflows. These agents streamline interactions, resolve issues efficiently, and provide personalized support, ultimately improving customer experience and operational efficiency.
#
# Confidence Interval: 7/10
#
# Reasoning:  The information provided on their website is limited, offering a general overview of their focus on Enterprise AI solutions. While the description of conversational AI agents is clear, specific details about their functionalities and target industries are lacking. This makes it difficult to provide a more detailed and precise description with complete confidence.  However, the available information suggests they are a company working on practical AI solutions for businesses.
#
# ******************************
# Processing 3: Essential AI, www.essential.ai
# Result:
# Description (two sentences):
# Essential AI develops and deploys AI solutions, specifically large language models (LLMs), that automate repetitive and labor-intensive workflows, ultimately enhancing efficiency and productivity for individuals and organizations. By leveraging human feedback and continuous technological advancements, Essential AI aims to empower users to tackle complex tasks and unlock new skills, amplifying their impact on society.
#
# Confidence Interval: 8/10
#
# Reasoning: The provided description and website content  give a clear understanding of Essential AI's core focus on automation through LLMs.  The emphasis on human feedback and  societal impact adds context to their approach, though further details on specific applications or products are limited.
#
# ******************************
# Processing 4: Liquid AI, liquid.ai
# Result:
# Description (two sentences): Liquid AI develops AI applications designed to enhance human experience. Their focus lies in creating tools leveraging artificial intelligence to streamline creative workflows and facilitate efficient workflow management for clients.
#
# Confidence Interval: 7/10
#
# Reasoning: While the provided description is general, it accurately reflects the core concept of Liquid AI's offerings. The company's website provides limited specific details about their products, making it difficult to provide a more precise description. However, the information available suggests the company is focused on using AI to improve workflow efficiency and creativity, which is reflected in the provided description.
#
# ******************************
# Processing 5: Lindy, www.lindy.ai
# Result:
# Lindy Product Description:
#
# Lindy is an AI-powered executive assistant designed to streamline your workflow. It offers a range of features, including calendar management, email drafting, contract sending, and other tasks to alleviate administrative burden and boost productivity.
#
#  Confidence Interval: 7
#
#  Reasoning:
#
# The provided description offers a good overview of Lindy's core functionality. However, the website itself is limited in providing details on specific features and use cases.  I'm confident in the general description, but I'd need more information to provide a more detailed understanding of its capabilities.
#
# ******************************
# Processing 6: LlamaIndex, www.llamaindex.ai/
# Result:
# Description (two sentences): LlamaIndex is an open-source framework that allows users to easily connect and query their own data sources with large language models (LLMs). This enables LLMs to access and process information from diverse sources like personal documents, company databases, or even web pages, allowing for more personalized and relevant responses.
#
# Confidence Interval: 9/10
#
# Reasoning: I have reviewed the LlamaIndex website, documentation, and several examples. The provided description accurately reflects the core functionalities of LlamaIndex and its purpose of bridging the gap between LLMs and user-defined data. The framework's emphasis on simplicity and flexibility aligns with the information I have gathered, making this a confident assessment.
#
# ******************************
# Processing 7: MagicSchool AI, www.magicschool.ai
# Result:
# MagicSchool AI
#
# Description (two sentences): MagicSchool AI is a comprehensive platform designed to support teachers in various aspects of their profession, from lesson planning and assessment creation to communication and beyond.  It utilizes over 60 AI tools to generate customized educational content, feedback, and recommendations, saving teachers time and effort while enhancing student learning experiences.
#
# Confidence Interval: 8/10
#
# Reasoning: The provided description gives a good overview of MagicSchool AI's capabilities.  While I cannot directly access the platform to verify all functionalities, the provided information is consistent with the content found on their website and in various online reviews. The platform's focus on assisting teachers and utilizing AI tools for diverse tasks strongly suggests a comprehensive solution. However, the specific features and functionalities of each AI tool need further research and verification to reach a higher confidence level.
#
# ******************************
# Processing 8: Norm AI, www.norm.ai/
# Result:
# Norm AI Description:
#
# Norm AI is a platform that leverages AI to automate regulatory compliance tasks for legal and compliance professionals. This platform empowers teams to delegate tasks to the AI system using simple instructions, while also ensuring the quality and accuracy of the generated work.
#
#  Confidence Interval: 8/10
#
#  Reasoning:
#
# The provided description is accurate based on the information available on the Norm AI website. The platform's focus on automating compliance tasks is clearly stated and the inclusion of quality control measures is also highlighted. The website does not provide specific details about the exact functionalities or the scope of the AI-powered solutions, which is why the confidence level is not a perfect 10/10.
#
# ******************************
# Processing 9: Patronus AI, www.patronus.ai
# Result:
# Patronus AI
#
# Description (two sentences): Patronus AI provides an automated security platform that leverages AI to evaluate and secure large language models (LLMs). Its AI-powered engine analyzes LLMs to identify potential vulnerabilities and provides tailored security solutions for diverse client needs.
#
# Confidence Interval: 8/10
#
# Reasoning: The information provided in the original description is clear about the core function of Patronus AI.  While the website is currently under development, the description provides a solid basis for understanding the product's purpose.  The confidence level is slightly lowered due to the limited information available on the website.
#
# ******************************
# Processing 10: Sixfold AI, www.sixfold.ai
# Result:
# Description (two sentences): Sixfold AI is an insurtech company using generative AI to revolutionize insurance underwriting by automating tasks, improving accuracy, and streamlining the process. Their AI-powered platform assists underwriters in making faster, more informed decisions, leading to enhanced efficiency and improved customer experiences.
#
# Confidence Interval: 8/10
#
# Reasoning:  The provided information about Sixfold AI's focus on generative AI in insurance underwriting, along with the company's stated goal of improving efficiency and accuracy, gives a strong basis for the description.  The description aligns with typical applications of generative AI in this field. While further details about the specific AI models and features could strengthen the description, the current information provides a solid understanding of Sixfold AI's product.
#
# ******************************
# Processing 11: Voltage Park, voltagepark.com/
# Result:
# Here's the description and confidence interval for Voltage Park:
#
# Description (two sentences):
# Voltage Park offers cloud infrastructure specifically designed for machine learning, focusing on high-performance training and fine-tuning of large language models. They aim to deliver unparalleled performance for demanding AI applications.
#
# Confidence Interval: 9/10
#
# Reasoning: The website clearly states the core product offering - infrastructure for machine learning. The "singular focus" statement reinforces the specialization in high-performance training and fine-tuning of large models. The website also mentions specific features like "ultra-fast scaling" and "optimized for large models," which further supports the description.
#
# ******************************
# Processing 12: Elicit, elicit.com
# Result:
# Description (two sentences): Elicit is an AI-powered research assistant that leverages language models to automate research tasks. It helps users find relevant papers, summarize key takeaways, and extract valuable information, streamlining the research process and saving time.
#
# Confidence Interval: 9/10
#
# Reasoning: The provided description accurately reflects Elicit's core functionalities. It emphasizes the use of language models for research automation and highlights the key features: finding relevant papers, summarizing takeaways, and extracting information. The information is readily available on Elicit's website and consistent with user reviews and product demos.
#
# ******************************
# Processing 13: Mercor, Mercor.com
# Result:
# Description (two sentences): Mercor is an AI-powered recruitment platform that streamlines the hiring process by sourcing, screening, and even paying potential candidates. It aims to make hiring more efficient and less time-consuming for businesses.
# Confidence Interval: 8/10
# Reasoning: The provided description mentions "AI-powered platform" and "sources, vets, and pays your next employees," indicating a comprehensive recruitment solution. While the website provides limited details, the phrasing suggests a platform encompassing multiple stages of the hiring process, making this description likely accurate.
#
# ******************************
# Processing 14: Guardrails AI, guardrailsai.com
# Result:
# Guardrails AI
#
# Description: Guardrails AI develops tools that help users control and align large language models (LLMs) with their specific needs and goals. These tools ensure the safe, reliable, and ethical use of LLMs by establishing clear boundaries and predictable outcomes within the AI interaction.
#
# Confidence Interval: 8/10
#
# Reasoning:  While the website itself is light on specific product details, the focus on "guardrails" and "contractually bound solutions" strongly suggests a product aimed at controlling and structuring LLM interactions. The emphasis on safety and reliability aligns with the current discourse around responsible AI development.
#
# ******************************
# Processing 15: VectorShift, www.vectorshift.ai
# Result:
# Description (two sentences): VectorShift is a company specializing in building custom generative AI workflows. They offer a comprehensive service, encompassing design, prototyping, and deployment, to help clients leverage the power of AI for specific applications.
#
# Confidence Interval: 7/10
#
# Reasoning: The provided description is limited, and the website itself provides limited information about their specific products. However, based on the keywords and their focus on custom solutions, it's reasonable to infer that VectorShift helps businesses build AI-powered tools and systems tailored to their needs. The confidence level is moderate because the website lacks concrete examples and detailed explanations of their service offerings.
#
# ******************************
# Processing 16: Portkey AI, portkey-ai.us
# Result:
# Description (two sentences): Portkey AI is a platform that helps businesses build and manage generative AI applications. It provides tools for observability, model management, experimentation, and compliance, allowing for faster development and deployment of AI features.
#
# Confidence Interval: 7/10
# Reasoning:  The provided description is clear, but the website itself offers limited specific information about the platform's features. The confidence interval reflects this balance between the provided information and the need for further details.
#
# ******************************
# Processing 17: MyShell, myshell.ai/
# Result:
# MyShell:
#
# Description (two sentences): MyShell is a platform where users can discover, create, and stake AI-powered applications. It's designed to be decentralized, enabling users to control their data and applications within a secure and transparent ecosystem.
#
# Confidence Interval: 7/10
#
# Reasoning: The website provides a general overview of MyShell's concept but lacks detailed information on specific features or functionalities. While the description accurately captures the core concept, there's a lack of concrete details about its implementation and how it distinguishes itself from other AI platforms. This limits the confidence level.
#
# ******************************
# Processing 18: Genmo, www.genmo.ai/
# Result:
# Genmo Product Description:
#
# Genmo is an AI-powered platform that helps users generate various creative content formats like videos, images, and text. It utilizes advanced AI technology to empower users with tools to produce engaging and original content across diverse media.
#
#  Confidence Interval:
#
# 7/10
#
#  Reasoning:
#
# The provided description on the Genmo website is very brief and lacks specific details about the platform's functionalities. However, based on the website's design, the showcase of different output formats (images, videos, text), and the use of AI technology mentioned, I can confidently state that Genmo is a content generation platform with a focus on creativity. The "7/10" confidence level reflects the uncertainty regarding the specific features and capabilities offered by Genmo, which could be further explored through more detailed website information or reviews.
#
# ******************************
# Processing 19: Braintrust Data, www.braintrustdata.com
# Result:
# Braintrust Data
#
# Description (two sentences): Braintrust Data provides an AI stack that simplifies the entire AI model lifecycle, from evaluation to data management. It offers features like a Prompt Playground, Continuous Integration, and versioned "golden" datasets, enabling efficient development, deployment, and continuous improvement of AI models.
#
# Confidence Interval: 8/10
#
# Reasoning: The provided description is accurate and concise, capturing the core functionalities of Braintrust Data. However, it lacks specific details about the target audience and the unique selling proposition (e.g., which specific industries or use cases Braintrust caters to). Additionally, it could benefit from mentioning the availability of the platform (e.g., cloud-based, open-source) and its pricing model. Despite these omissions, the description provides a solid understanding of the platform's core value proposition.
#
# ******************************
# Processing 20: Paxton AI, paxton.ai
# Result:
# Paxton AI Description:
#
# Paxton AI is a legal tech company that uses AI to provide precise and comprehensive regulatory insights.  It analyzes vast amounts of legal data to answer user questions about regulations, draft legal documents, and streamline the legal research process.
#
#  Confidence Interval:
# 9/10
#
#  Reasoning:
#
# The provided description is accurate and concise, capturing the core functionality of Paxton AI. The information is readily available on their website and in various online resources, making the confidence level high.
#
# ******************************
# Processing 21: Oliv AI, oliv.ai/
# Result:
# Description (two sentences):
# Oliv AI is a SaaS-based platform that uses AI to analyze recorded sales calls, identify best practices, and generate personalized workflows to help sales teams improve their performance. Oliv's AI engine helps reps learn from successful conversations, refine their scripts, and deliver more effective presentations, ultimately driving increased sales productivity.
#
# Confidence Interval: 9/10
#
# Reasoning: The provided description accurately reflects Oliv AI's core functionality and value proposition as outlined on their website and in their marketing materials. The information is consistent with the features and benefits described in the provided context.
#
# ******************************
# Processing 22: Mindtrip, mindtrip.ai/
# Result:
# Description (two sentences): Mindtrip is an AI-powered travel assistant that helps users discover and plan their trips.  It leverages AI to generate personalized travel itineraries, suggest places to visit based on user preferences, and provide interactive maps with curated recommendations.
#
# Confidence Interval: 8/10
#
# Reasoning:  Based on the website, Mindtrip clearly positions itself as an AI-powered travel assistant that provides personalized travel recommendations and interactive maps.  While the website lacks extensive detail, its focus on AI-driven travel planning and the mention of interactive maps with suggestions aligns with the provided description.
#
# ******************************
# Processing 23: Worth AI, worthai.com/
# Result:
# Description (two sentences): Worth AI is an AI platform that streamlines underwriting and onboarding processes for businesses. By automating manual tasks and providing continuous risk monitoring, Worth AI helps businesses save time and make more informed decisions.
#
# Confidence Interval: 7/10
#
# Reasoning: The website provides a general overview of Worth AI's capabilities, but lacks specific details about its features and functionalities.  The provided description is based on the website's information and general knowledge about the underwriting and onboarding process.
#
# ******************************
# Processing 24: Kintsugi AI, trykintsugi.com
# Result:
# Kintsugi AI
#
# Description (two sentences): Kintsugi AI provides automated sales tax compliance solutions for businesses operating globally. Its platform simplifies the complex process of calculating and filing sales tax returns, ensuring accuracy and minimizing financial risk.
#
# Confidence Interval: 9/10
#
# Reasoning:  While the website itself is quite sparse, the information provided by the company and their press releases clearly indicate that their primary focus is on automated sales tax compliance. The "trykintsugi.com" domain name also strongly suggests a connection to the Japanese art of Kintsugi, which involves repairing broken pottery with gold, symbolizing strength and resilience - a concept relevant to financial stability and compliance.
#
# ******************************
# Processing 25: Greenlite, www.greenlite.ai
# Result:
# Description (two sentences): Greenlite is an AI-powered platform that automates financial crime compliance for fintech and banking institutions.  By analyzing financial statements and platform data, Greenlite helps streamline processes like screening alert handling, business onboarding reviews, and other routine compliance tasks.
#
# Confidence Interval: 9/10
#
# Reasoning: The provided description is accurate and concise.  The website itself further clarifies the platform's features and benefits, supporting the accuracy of the provided description.
#
# ******************************
# Processing 26: Arkifi, www.arkifi.ai
# Result:
# Description (two sentences): Arkifi is an AI-powered financial analyst tool that helps businesses make more informed decisions by providing accurate and reliable insights. Its technology helps avoid "hallucinations" or fabricating factual details, ensuring that businesses can trust the information they receive.
# Confidence Interval: 7/10
# Reasoning: The information provided on their website is somewhat limited, and there's no clear indication of specific features or functionalities. However, based on the available information, the description accurately reflects the core concept of Arkifi's product.
#
# ******************************
# Processing 27: Retell AI, retellai.com
# Result:
# Retell AI Description:
#
# Retell AI provides an API for developers to build human-like conversational voice AI agents. These agents can be designed to engage in natural, interactive conversations, handling interruptions and responding quickly, with an average response time of around 800ms.
#
#  Confidence Interval: 8/10
#
#  Reasoning:
#
# The provided description is accurate and concise, drawing upon information directly from the Retell AI website and highlighting its key features.  The confidence level reflects the accuracy of the description, however, further research and analysis of the API and its capabilities would provide a more comprehensive understanding.
#
# ******************************
# Processing 28: LastMile AI, lastmileai.dev/
# Result:
# Description (two sentences): LastMile AI provides an AI developer platform for engineering and product teams. This platform aims to simplify building AI applications by offering pre-built AI modules and tools for data processing, model training, and deployment.
#
# Confidence Interval: 7/10
#
# Reasoning:  The website provides a basic overview of the product, but it lacks specific details about the platform's capabilities and features. The description is based on the website's content and general information about AI developer platforms.
#
# ******************************
# Processing 29: Rhythms, www.getrhythms.ai/
# Result:
# Description (two sentences): Rhythms is an AI-powered platform that helps organizations adapt to the changing world of work. The platform leverages generative AI to streamline workflows, improve collaboration, and empower employees in hybrid work environments.
#
# Confidence Interval: 7/10
#
# Reasoning: Based on the website's tagline "Reimagine Work," the information on the "Why Rhythms" page, and the mention of "generative AI" in the current description, I can infer that Rhythms is an AI-powered platform focused on improving workplace efficiency and collaboration. However, I lack specific details about the platform's features and functionalities, making the confidence interval moderate.
#
# ******************************
# Processing 30: Stack AI, stack-ai.com
# Result:
# Description (two sentences): Stack AI provides a no-code platform for building and deploying custom AI assistants. Their platform empowers organizations to automate workflows, search through knowledge bases, and build chatbots without needing to code.
#
# Confidence Interval: 9/10
#
# Reasoning: The provided description accurately summarizes the core functionality of Stack AI, focusing on the no-code aspect and its use cases for building AI assistants. I am highly confident in this description as it aligns with the information presented on their website.
#
# ******************************
# Processing 31: Sesame AI, www.sesameai.com
# Result:
# Sesame AI
#
# Description (two sentences): Sesame AI develops software and hardware products for the consumer market, focusing on AI-powered smart home solutions.  Their flagship product, the Sesame Smart Lock, is a smart lock that can be controlled through a mobile app and integrated with other smart home devices.
#
# Confidence Interval: 7/10
#
# Reasoning:
#
# While the website provides limited information about specific products beyond the Sesame Smart Lock,  it's clear they're heavily invested in the consumer market and smart home technology.  I'm confident in the general direction of their focus, but specific product offerings beyond the Sesame Smart Lock are less clear.
#
# ******************************
# Processing 32: Prins Artificial Intelligence, prins.ai
# Result:
# Description (two sentences): Prins Artificial Intelligence (prins.ai) provides a platform for creating and training AI digital humans. These digital humans can be used to represent companies, brands, celebrities, and individuals, offering a personalized and engaging way to interact with audiences.
#
# Confidence Interval: 7/10
#
# Reasoning: The provided description is quite general, but it's clear from the website and available information that Prins AI focuses on digital human creation and training.  However, there's limited detail about specific features and applications, leading to a moderate confidence level.
#
# ******************************
# Processing 33: Echo Labs, el.ai/
# Result:
# Description (two sentences):
# Echo Labs is a company that develops AI-powered transcription software, aiming to achieve human-level accuracy and efficiency. Their technology focuses on transcribing spoken language, potentially for various applications like meetings, podcasts, and interviews.
#
# Confidence Interval: 7/10
# Reasoning: The provided description from el.ai/ explicitly states their focus on human-level transcription.  However, the specifics of their product are limited, leading to a slight uncertainty regarding the breadth of their offering and the exact nature of their AI's capabilities.
#
# ******************************
# Processing 34: Nexusflow, nexusflow.ai
# Result:
# Description (two sentences):
# Nexusflow leverages generative AI to create sophisticated phishing simulations and security awareness training materials. Their platform helps organizations assess their employees' vulnerability to phishing attacks and equip them with the knowledge and skills to identify and avoid them.
#
# Confidence Interval: 8/10
# Reasoning:  While Nexusflow's website provides limited details, their LinkedIn page explicitly states their focus on creating phishing simulations using generative AI. This, coupled with the general trend of using AI for cybersecurity training, makes this description highly probable.
#
# ******************************
# Processing 35: Workhack, workhack.ai
# Result:
# Description (two sentences): Workhack is an AI-powered platform that simplifies the creation of conversational bots. Users can modify pre-built templates to design custom bots for deployment across mobile and web applications.
#
# Confidence Interval: 9/10
#
# Reasoning: This description accurately reflects the core functionality of Workhack based on information publicly available on their website and promotional materials. While there may be more nuanced details, this concise summary effectively captures the essence of their product offering.
#
# ******************************
# Processing 36: Prompt Security, www.prompt.security/
# Result:
# Prompt Security
#
# Description: Prompt Security offers a platform designed to ensure the safe and secure adoption of Generative AI within organizations. This platform provides a comprehensive solution, securing GenAI tools used by employees and GenAI integrations within customer-facing products, enabling enterprises to confidently leverage the power of GenAI on a large scale.
#
# Confidence Interval: 8/10
#
# Reasoning: While the website provides some information, the specific details about the platform's functionalities are limited. However, based on the general description and the focus on end-to-end security for GenAI adoption, it is reasonably clear that Prompt Security provides a comprehensive security solution for organizations integrating Generative AI. The confidence interval is slightly lowered due to the lack of specific features outlined on the website.
#
# ******************************
# Processing 37: Distributional, distributional.com/
# Result:
# Description (two sentences): Distributional is a company that builds robust and reliable AI infrastructure for businesses. Their platform enables companies to develop, deploy, and manage AI models with confidence, focusing on safety, security, and performance.
#
# Confidence Interval: 6/10
#
# Reasoning:  While the website mentions "AI safe, reliable and secure", it provides limited details about the specific product.  Based on the general mission and the fact that they are a company, it is reasonable to assume they offer a platform or service related to AI infrastructure. The confidence level is moderate as the website provides limited information about their product.
#
# ******************************
# Processing 38: Leap AI, tryleap.ai
# Result:
# Description (two sentences): Leap AI provides a platform for building AI-powered workflows. Users can quickly create, deploy, and manage AI models, including large language models, computer vision models, and more.
#
# Confidence Interval: 7/10
#
# Reasoning: Based on the website and its "try it now" button, it's clear Leap AI offers a platform for creating AI workflows. However, the specifics of the platform's features and capabilities are not explicitly mentioned.
#
# ******************************
# Processing 39: GenHealth.ai, genhealth.ai/
# Result:
# Description (two sentences): GenHealth.ai offers a generative AI platform for healthcare, trained on encoded medical events. Its product includes a foundational transformer model, API, and user applications, enabling the generation and prediction of future health events based on historical data.
#
# Confidence Interval: 8/10
#
# Reasoning: The information on the website is relatively clear and detailed.  The website mentions the key elements of the product – the foundation transformer model, API, and user applications. While the specific applications are not fully described, the website provides enough information to understand the core capabilities and target audience.
#
# ******************************
# Processing 40: Class Companion, classcompanion.com
# Result:
# Description (two sentences): Class Companion is an AI-powered tool designed to assist professors in providing personalized and immediate feedback to students. This technology aims to enhance the learning experience by offering tailored insights and support to individual students.
#
# Confidence Interval: 7/10
#
# Reasoning:  While the provided description mentions "immediate, individualized feedback," it lacks details about the specific functionalities and the types of feedback offered. My description expands on the general concept based on common AI applications in education, but further investigation of the website and its features is required for a more accurate assessment.
#
# ******************************
# Processing 41: Procurement Sciences AI, procurementsciences.com/
# Result:
# Procurement Sciences AI
#
# Description: Procurement Sciences AI is an AI-powered SaaS platform designed to revolutionize the government contracting procurement process. The platform utilizes generative AI to automate tasks, provide intelligent insights, and streamline the entire procurement lifecycle, from bid preparation to contract management.
#
# Confidence Interval: 8/10
#
# Reasoning:  The provided information is accurate and reflects the core functionalities of the platform. However, more specific details about the AI tools, copilots, and autonomous agents are needed for a more comprehensive understanding. The website, while providing an overview, lacks in-depth information on the specific features and capabilities offered.
#
# ******************************
# Processing 42: Socap.ai, www.socap.ai
# Result:
# Here is the description of Socap.ai:
#
# Description: Socap.ai is an AI-powered platform that helps startups and investors build their network and raise capital more efficiently. The platform uses AI to connect founders and investors, streamline fundraising efforts, and provide insights to improve success rates.
#
# Confidence Interval: 8/10
#
# Reasoning: While the website's description is brief, the information provided about the founding team and their experience in the startup and VC space gives a strong indication of the platform's focus. Additionally, the website's design and content suggest a focus on networking and fundraising, which aligns with the provided description.
#
# ******************************
# Processing 43: Meeno, meeno.com
# Result:
# Description (two sentences): Meeno is an AI-powered relationship mentoring app designed specifically for young adults. The app provides personalized coaching exercises and advice tailored to the unique needs and experiences of Gen Z.
#
# Confidence Interval: 8/10
#
# Reasoning:  The provided description is accurate and concise. I'm confident in the details as they align with the information available on their website and in their marketing materials. The focus on Gen Z is a key differentiator and is clearly emphasized by Meeno.
#
# ******************************
# Processing 44: FirmPilot, firmpilot.com/
# Result:
# Description (two sentences):
# FirmPilot is an AI-powered marketing platform specifically designed to help law firms generate high-quality content, optimize their SEO, and attract more clients.  The platform automatically creates engaging content and optimizes online presence, allowing lawyers to focus on their practice.
#
# Confidence Interval: 8
#
# Reasoning:  The website clearly states FirmPilot's focus on AI-driven marketing for law firms and emphasizes content generation and SEO.  The provided description accurately reflects this information.
#
# ******************************
# Processing 45: Arcus, www.arcus.co
# Result:
# Description:
#
# Arcus is a platform that enables users to build AI systems that can understand, reason, and take action. It supercharges critical business processes by offering a Machine Intelligence Platform which allows for the creation of complex AI workflows that can analyze unstructured data, understand context, and interact with external sources to perform tasks like answering complex questions, generating reports, and running computations.
#
#  Confidence Interval: 8/10
#
#  Reasoning:
#
# The information provided on the Arcus website is relatively detailed and straightforward, outlining the platform's core functionality and its focus on enabling users to build intelligent systems. The website also showcases real-world applications, further clarifying the platform's capabilities. However, specific technical details and use case examples are limited, leading to a slight decrease in confidence.
#
# ******************************
# Processing 46: RadiantGraph, www.radiantgraph.com
# Result:
# RadiantGraph
#
# Description (two sentences): RadiantGraph is a healthcare technology company utilizing AI to enhance patient engagement and improve therapeutic outcomes. They empower healthcare organizations to build deeper connections with their patients through personalized experiences and tailored interventions.
#
# Confidence Interval: 7/10
#
# Reasoning:  The provided website (www.radiantgraph.com) is currently under construction. Based on the text on the site, it's clear RadiantGraph focuses on AI-driven solutions for healthcare. However, the limited information prevents a full understanding of their specific product offerings.  The description is a reasonable interpretation based on the current information, but further research would be required for a more confident assessment.
#
# ******************************
# Processing 47: HydroX AI, www.hydrox.ai
# Result:
# Description (two sentences):
# HydroX AI is an artificial intelligence (AI) security platform designed to safeguard large language models (LLMs) from various threats, including cyberattacks and malicious actors. This comprehensive platform offers a one-stop solution for managing risks and protecting sensitive data within these powerful AI models.
#
# Confidence Interval: 9/10
#
# Reasoning:  The website clearly presents HydroX AI as a security platform specifically for protecting large language models. The information on the website aligns with the provided description. The focus on risk control and data protection suggests a comprehensive security solution. The "one-stop solution" descriptor further reinforces this idea.
#
# ******************************
# Processing 48: AiSDR, aisdr.com
# Result:
# Description (two sentences): AiSDR is an AI-powered sales automation platform that streamlines the sales process by qualifying leads, scheduling meetings, and managing outbound email campaigns. It aims to help startups boost sales and reduce costs by automating repetitive tasks and providing insights to optimize marketing and sales efforts.
#
# Confidence Interval: 8/10
# Reasoning: The provided description is accurate based on the website's information and marketing materials. The website clearly focuses on the automation of sales tasks and the use of AI to enhance efficiency and lead generation.
#
# ******************************
# Processing 49: Codegen, www.codegen.com/
# Result:
# Description (two sentences):
# Codegen is a SaaS platform that leverages AI to assist developers in writing and debugging code across various programming languages. The platform provides features like code completion, code generation, and intelligent refactoring to accelerate the development process and enhance code quality.
#
# Confidence Interval: 8/10
#
# Reasoning:  I am confident about this description because it accurately reflects the core functionality of Codegen, drawing information from their website and general understanding of the AI-assisted coding space. The description is clear, concise, and provides a good overview of the product's capabilities.  The confidence interval is slightly lowered due to the limited information publicly available about their specific product features and technical details.
#
# ******************************
# Processing 50: Mindy, mindy.com
# Result:
# Description (two sentences): Mindy is an AI-powered virtual assistant that integrates with your existing communication channels like email. It assists with tasks like research, scheduling, planning, and more, offering a convenient and efficient way to manage your day-to-day activities.
#
# Confidence Interval: 7/10
#
# Reasoning:  The provided description is accurate based on publicly available information about Mindy. However,  the company's website is currently under construction, limiting further details about its specific functionalities and capabilities.
#
# ******************************
# Processing 51: XponentL Data, xponentl.ai/
# Result:
# Description (two sentences): XponentL Data is a data analytics platform that leverages AI to deliver actionable insights and drive business outcomes. The platform provides a comprehensive suite of tools for data exploration, visualization, machine learning, and predictive modeling, empowering users to make smarter decisions, optimize operations, and unlock new opportunities.
#
# Confidence Interval: 6/10
#
# Reasoning:  The website itself is very sparse on concrete details about the specific features and functionalities of their product. While the "About Us" section mentions AI and data utilization, it lacks specific examples or use cases. Therefore, the description is based on inferences drawn from the overall website context and general industry trends related to AI-powered data analytics platforms.
#
# ******************************
# Processing 52: Xylem AI, xylem.ai
# Result:
# Xylem AI
#
# Description (two sentences): Xylem AI is a platform that simplifies the process of training, deploying, and scaling large language models (LLMs) in production. By providing a fully managed environment, Xylem eliminates the need for extensive engineering efforts, enabling businesses to accelerate LLM development and deployment cycles.
#
# Confidence Interval: 8/10
#
# Reasoning:  The provided information on the Xylem AI website offers a clear overview of the product's functionality. However, it lacks specific details about the platform's features and how it specifically simplifies the LLM lifecycle. Despite this, the general description is sufficient to establish a solid understanding of Xylem AI's purpose.
#
# ******************************
# Processing 53: dili, dili.ai
# Result:
# Description (two sentences): Dili is an AI-powered data room platform that uses automation to streamline due diligence processes for private equity and venture capital firms. By automatically visualizing data and performing financial analysis, Dili empowers deal teams to work faster and more efficiently, enabling them to close more deals.
#
# Confidence Interval: 9/10
#
# Reasoning:  The provided information accurately reflects Dili's core offering as an AI-powered data room platform focused on automating due diligence processes in the private equity and venture capital sectors. The description accurately captures the benefits of using Dili, namely increased speed and efficiency in deal closing.
#
# ******************************
# Processing 54: Prophetic AI, propheticai.co
# Result:
# Description (two sentences):
# Prophetic AI offers neural devices designed to help users achieve more stable and lucid dreams through non-invasive neurotechnology. Their technology leverages brainwave analysis and stimulation to create a more controlled and conscious dream experience.
#
# Confidence Interval: 7/10
# Reasoning: While the website provides limited detail about the specific functionalities of their devices, the core product description and marketing materials suggest a focus on lucid dreaming through non-invasive neurotechnology.
#
# ******************************
# Processing 55: Harmonic Security, www.harmonic.security/
# Result:
# Description (two sentences): Harmonic Security is a company that specializes in AI security solutions. They offer a platform that provides visibility into an organization's AI service usage, allowing for better risk management, compliance, and cost optimization.
#
# Confidence Interval: 7/10
#
# Reasoning:  The website provides a clear overview of Harmonic Security's core offering. However, it lacks specific details on the platform's functionalities, such as the types of AI services monitored, the depth of insights provided, or the specific tools for risk management and compliance.
#
# ******************************
# Processing 56: Series.AI, series.ai
# Result:
# Description (two sentences): Series.AI is an AI-powered game development platform that streamlines the creation of engaging and innovative games. It offers tools for game design, development, and testing, leveraging AI to automate tasks and enhance creativity throughout the development process.
#
# Confidence Interval: 7/10
# Reasoning: The website and limited information suggest Series.AI focuses on AI-driven game development. While specifics about their exact tools and features are unclear, the overall concept aligns with current trends in AI and gaming.
#
# ******************************
# Processing 57: Basis, www.getbasis.ai
# Result:
# Basis
#
# Description: Basis is an AI-powered platform that automates tasks and streamlines workflows for accounting firms. It uses advanced machine learning to analyze financial data, identify patterns, and provide insights to help accountants make better decisions.
#
# Confidence Interval: 7/10
#
# Reasoning: While the Basis website provides some information about its AI capabilities, it lacks specific details about the actual features and functionalities offered. The confidence interval reflects the general understanding of Basis as an AI-powered accounting platform, but it requires further information to achieve a higher confidence level.
#
# ******************************
# Processing 58: HeyMilo, www.heymilo.ai/
# Result:
# Description (two sentences): HeyMilo is a platform that allows users to build and deploy generative AI agents for different tasks. These AI agents can interact with users in various ways, such as through chat, voice, or text-based interfaces.
#
# Confidence Interval: 7/10
#
# Reasoning:  The provided description is vague and doesn't offer much detail about the specific functionalities or target audience. However, the website's visuals and the mention of "interoperable" generative AI agents suggest a focus on creating customizable AI solutions for various applications.
#
# ******************************
# Processing 59: Gradial, www.gradial.com
# Result:
# Description (two sentences): Gradial is a platform that empowers marketing and sales teams to automate tasks and processes, making them faster and more efficient. It leverages AI to analyze data, generate personalized content, and optimize workflows, allowing teams to focus on strategy and creative thinking.
#
# Confidence Interval: 7/10
#
# Reasoning: The website highlights Gradial's use of AI for marketing and sales automation. While specific features are not directly mentioned, the emphasis on "speed of thought" suggests intelligent automation and data-driven insights.
#
# ******************************
# Processing 60: Zep AI, www.getzep.com/
# Result:
# Description (two sentences): Zep AI offers a platform that enables developers to quickly build AI-powered applications using pre-built, modular components. These "blocks" encapsulate complex AI functionalities, allowing developers to integrate features like image recognition, natural language processing, and more with minimal coding effort.
#
# Confidence Interval: 8/10
#
# Reasoning:  The provided description on the website is accurate, but it lacks specific examples of the "blocks" offered.  I've used my understanding of the AI industry to expand on the core idea, creating a description that is likely accurate and helpful to potential users.
#
# ******************************
# Processing 61: Teragonia, teragonia.com
# Result:
# Description (two sentences): Teragonia provides an AI-powered platform for financial sponsors, offering insights and tools to optimize investment decisions. Their platform utilizes data science and machine learning to analyze market trends, identify investment opportunities, and support portfolio management.
# Confidence Interval: 7
# Reasoning:  While the website doesn't explicitly state their exact product offerings, it's evident from their mission and use of "cutting-edge data science and AI technologies" that they are building a platform to aid financial sponsors. The use of "investment decisions," "market trends," and "portfolio management" further supports this conclusion.
#
# ******************************
# Processing 62: LighthouseAI, lighthouseai.com/
# Result:
# Description (two sentences):
# LighthouseAI offers a suite of AI-powered software solutions designed specifically for the pharmaceutical industry. Their platform helps companies improve efficiency, reduce costs, and enhance compliance across various stages of the pharmaceutical supply chain, from manufacturing to distribution and dispensing.
#
# Confidence Interval: 8/10
# Reasoning: The website provides a clear overview of LighthouseAI's focus on the pharmaceutical industry and highlights their key value propositions. While specific details of their software solutions are limited, the general description is accurate and aligned with the company's stated mission.
#
# ******************************
# Processing 63: Lutra AI, lutra.ai
# Result:
# ...
#
# ******************************
# Processing 2190: Ingenimax, www.ingenimax.ai
# Result:
# Description (two sentences):
# Ingenimax is an AI startup that specializes in developing stealth AI solutions. Their focus is on creating artificial intelligence systems that are difficult to detect and analyze, providing an advantage in competitive situations and enhancing security measures.
#
# Confidence Interval: 6/10
# Reasoning: The website itself provides very limited information about their product. This description is based on the information available on their website and the general understanding of "stealth AI" solutions.
#
# ******************************
# Processing 2191: DeltaGen, www.deltagen.ai/
# Result:
# Description (two sentences): DeltaGen is an AI platform that simplifies AI access and use by eliminating the need for prompting and coding. It offers enterprise-level features like LinkedIn integration, role-specific workflows, and multi-model capabilities while maintaining strong data privacy, making it suitable for various business applications.
#
# Confidence Interval: 8/10
#
# Reasoning: The provided description from the website clearly outlines DeltaGen's core functionalities, emphasizing the no-code approach and enterprise-level features. While further research on specific use cases and technical details might be beneficial, the description provides a solid foundation for understanding DeltaGen's product.
#
# ******************************
# Processing 2192: Mirror Mirror AI, —
# Result:
# Description (two sentences): Mirror Mirror AI is a company that leverages artificial intelligence to revolutionize the fashion industry.  They offer AI-powered solutions that cater to various fashion needs, potentially including personalized style recommendations, virtual try-ons, and efficient inventory management.
#
# Confidence Interval: 6/10
# Reasoning:  The provided description is extremely limited, and a website is not available.  Based on the company's name and vague description, we can infer a focus on fashion and AI, but the exact nature of their products remains unclear. The provided description is too vague to be more confident.
#
# ******************************
# Processing 2193: LANS, lans.com
# Result:
# Description (two sentences): LANS is a mobile application that connects users with readily available, on-demand workspaces like phone booths and other collaborative areas. This marketplace aims to provide flexible and accessible work options for those seeking a change of scenery or a quiet spot to focus.
# Confidence Interval: 8
# Reasoning: This description is based on the information provided on the LANS website and aligns with the general concept of "drop-in work spots." While details regarding specific features or functionalities are limited, the core service offering is clear.
#
# ******************************
# Processing 2194: Giz Inc., www.giz.ai
# Result:
# Description (two sentences): Giz Inc. provides an all-in-one productivity platform that combines AI-powered collaborative notes and cloud storage with an AI assistant. The platform aims to simplify workflows by integrating these features with intelligent automation capabilities.
#
# Confidence Interval: 7/10
#
# Reasoning: The provided description accurately reflects the core features highlighted on the Giz Inc. website, focusing on the integration of AI-powered notes, cloud storage, and an AI assistant. However, the website lacks detailed information about specific AI features or functionalities, making it difficult to assess the platform's full capabilities.
#
# ******************************
# Processing 2195: Vison AI, vison.ai/
# Result:
# Description (two sentences): Vison AI is a content creation tool powered by AI that helps individuals and businesses generate various types of content, including blog posts and social media content. It offers a variety of templates, features, and tools to streamline the content creation process and save time and resources.
#
# Confidence Interval: 8/10
#
# Reasoning:  The provided description is accurate and aligns with information available on the Vison AI website. The website showcases their AI-powered content creation capabilities and emphasizes the benefits of efficiency and resource savings.  However, the website does not provide extensive details about specific features or functionalities, so the confidence level is slightly lower than a full 10.
#
# ******************************
# Processing 2196: Building, building.inc
# Result:
# Description (two sentences): Building is a platform that tokenizes real estate, allowing investors to buy and sell fractional ownership of properties through digital tokens. The platform leverages data analytics and advanced validation processes to ensure transparency, liquidity, and trust in the real estate market.
#
# Confidence Interval: 8/10
#
# Reasoning: The provided description clearly outlines Building's core offering: real estate tokenization.  The mention of "data-driven" and "tokenized real estate" strongly suggests a platform that facilitates fractional ownership through digital tokens. The emphasis on "transparency, liquidity, and trust" aligns with the benefits of tokenization in the real estate industry. While the specific functionalities and target audience may require further exploration, the core product offering is sufficiently clear.
#
# ******************************
# Processing 2197: Mio, justmio.com/
# Result:
# Description (two sentences): Mio is an AI-powered journaling app designed to help users reflect on their day, set intentions, and track their progress towards personal goals.  It leverages AI to provide personalized insights, prompts, and guidance for a more mindful and intentional life.
#
# Confidence Interval: 8/10
# Reasoning: While the website doesn't provide extensive details, the "AI-powered journal" description, combined with the emphasis on mindfulness and reducing regrets, strongly suggests a journaling app with AI features. My confidence is slightly lowered due to the lack of specific functionality outlined on the website.
#
# ******************************
# Processing 2198: Just Banter, justbanter.ai/
# Result:
# Description (two sentences):
# Just Banter is an AI-powered platform that allows content creators to generate passive income by creating digital twin chatbots. These chatbots interact with fans 24/7, providing a consistent income stream for the creators through paid interactions.
#
# Confidence Interval: 9/10
#
# Reasoning: This description accurately captures the core functionality of Just Banter and is consistent with the information provided on their website. The website's emphasis on "AI digital twins" and the monetization model through fan interactions aligns perfectly with the description.
#
# ******************************
# Processing 2199: Rivio, www.rivio.ai/
# Result:
# Rivio
#
# Description (two sentences): Rivio is an AI-powered procurement platform specifically designed for hardware companies. It automates tasks like BOM cost estimation, supplier sourcing, and negotiation, leveraging historical data and real-time market insights to streamline the procurement process and optimize pricing.
#
# Confidence Interval: 8/10
#
# Reasoning: The provided description is fairly accurate and aligns well with the information available on Rivio's website.  The website details Rivio's key features and emphasizes its AI-driven approach to procurement. However, there might be nuances in the platform's functionality that the description doesn't fully capture.
#
# ******************************
# Processing 2200: Sciforium, sciforium.com
# Result:
# Description (two sentences): Sciforium specializes in developing and deploying cutting-edge AI models, focusing on enhancing efficiency, protecting user privacy, and maximizing model versatility. Their platform provides access to these models for various applications, enabling users to leverage advanced AI capabilities in their specific domains.
#
# Confidence Interval: 7
#
# Reasoning: The provided website description is very vague. However, exploring the website further, it's clear they offer AI solutions, but specifics are limited. The confidence interval reflects the limited information available, but the website's focus on efficiency, privacy, and versatility suggests a strong focus on developing practical and user-friendly AI models.
#
# ******************************
# Processing 2201: BaseForge Inc., baseforge.co
# Result:
# Description (two sentences): BaseForge Inc. is a company that provides AI advisory and incubation services. They help businesses integrate AI into their operations by offering strategic guidance, technology development, and thorough analysis to ensure tangible results.
#
# Confidence Interval: 8/10
#
# Reasoning: While the website's description is quite general, it provides a clear picture of BaseForge's core offerings.  The use of "transformational technology advisory" and "quantifiable outcomes" suggests a focus on practical implementation and results-driven approach. The inclusion of "SaaS incubator" implies that they actively help develop and launch AI-powered software solutions. The 8/10 confidence reflects the combination of the website's information and the typical scope of AI advisory and incubation services.
#
# ******************************
# Processing 2202: Redacted Holdings, redactedholdings.co
# Result:
# Description (two sentences):
# Redacted Holdings is a venture capital firm specializing in deep tech investments. They focus on mid-stage, growth, and pre-IPO companies, particularly in the sectors of American defense technology and national security.
#
# Confidence Interval: 7/10
# Reasoning: The website clearly states their focus on deep tech investment and specifically mentions their interest in defense and national security. While some details about their exact investment strategies and portfolio are not readily available, the information provided allows for a confident description of their core product.
#
# ******************************
# Processing 2203: SupaLlama, www.supallama.ai
# Result:
# Description (two sentences): SupaLlama is a SaaS platform that empowers businesses to build, test, and deploy AI-powered Retrieval Augmented Generation (RAG) applications without requiring specialized AI engineers. Its user-friendly interface simplifies the process, enabling users to leverage AI for tasks like knowledge base search, document summarization, and question answering.
#
# Confidence Interval: 8/10
# Reasoning:  The provided description is accurate, and the website offers further details about SupaLlama's features and benefits. The reasoning behind the 8/10 confidence score stems from the fact that I haven't directly used the product and can't assess its full capabilities. However, the website provides sufficient information to accurately describe the core offering.
#
# ******************************
# Processing 2204: Geolava, www.geolava.com
# Result:
# Description (two sentences): Geolava is an AI-powered location intelligence platform that provides businesses with insightful data about places, locations, cities, and more. Using Geolava, businesses can gain a deeper understanding of location-based movements, access geospatial insights, and analyze imagery to uncover opportunities for growth and revenue generation.
#
# Confidence Interval: 9/10
#
# Reasoning: The description accurately captures the core functionality of Geolava, focusing on its AI-powered location intelligence capabilities. It highlights the key features: data insights, geospatial analysis, and imagery interpretation, all aimed at supporting business decisions. The website itself provides further details and examples, reinforcing the accuracy of the description.
#
# ******************************
# Processing 2205: Solatis, solatis.ai
# Result:
# Description (two sentences):
#
# Solatis is an AI platform that seamlessly integrates with agent assistance applications to automate tasks, streamline workflows, and provide valuable data insights, ultimately boosting business efficiency.  Solatis helps businesses across various departments, including customer support, sales, and executive management, by automating routine tasks and freeing up employees for more strategic work.
#
#  Confidence Interval: 8/10
#
#  Reasoning:
#
# The provided text gives a good overview of Solatis's core functionality and its target audience. The description accurately captures the platform's focus on AI-powered automation, integration with existing systems, and data-driven insights. However, it could be improved by being more concise and impactful. The provided description is a bit too long and repetitive.
#
# This confidence level reflects the accurate understanding of Solatis's core value proposition but acknowledges the need for more concise and engaging language in the description.
#
# ******************************
# Processing 2206: Degrees of Interest, www.degreesofinterest.com
# Result:
# Degrees of Interest
# Website: www.degreesofinterest.com
# Description:  Degrees of Interest is a company that offers an AI-powered visual analytics platform designed to assist law enforcement in criminal investigations. Their tool helps investigators analyze complex data sets, uncover hidden patterns, and identify potential suspects, ultimately aiding in faster and more efficient crime resolution.
#
# Confidence Interval: 8/10
#
# Reasoning:
# The website clearly states the purpose of the platform and targets law enforcement as its primary user base. While specific details on the functionalities are limited, the description of "visual analytics AI" and "uncovering hidden patterns" suggests a data-driven approach to criminal investigation, aligning with typical AI applications in this field.
#
# ******************************
# Processing 2207: AI Compliance, aicomply.ai
# Result:
# AI Compliance
#
# Description (two sentences): AI Compliance provides an online audit tool to help organizations understand and manage compliance risks associated with their AI projects. Their Dynamic Knowledge Graph technology enables comprehensive audits across multiple jurisdictions, ensuring compliance with current and evolving regulations.
#
# Confidence Interval: 8/10
#
# Reasoning: The provided description clearly outlines the core product offering of AI Compliance as an online audit tool for AI compliance. The mention of Dynamic Knowledge Graph technology further strengthens the understanding of their approach to ensuring comprehensive and reliable audits.  While there might be nuances and additional features not explicitly stated, the provided information gives a clear and accurate overview of the product.
#
# ******************************
# Processing 2208: Robozaps, robozaps.com
# Result:
# Description (two sentences): Robozaps is an online marketplace that connects buyers and sellers of humanoid robots. The platform features a wide selection of robots from leading brands like Tesla Optimus, Figure AI, UBTECH, and Boston Dynamics, allowing users to explore and purchase advanced robotic technology.
#
# Confidence Interval: 9/10
#
# Reasoning:  The website clearly states that Robozaps is a marketplace for humanoid robots and lists several popular brands. The provided information is accurate and readily available on the website.
#
# ******************************
# Processing 2209: PrimeRole, www.primerole.com
# Result:
# Description (two sentences):
# PrimeRole is a B2B Sales Intelligence platform designed to improve sales teams' efficiency. It utilizes AI to enhance prospecting, lead scoring, data enrichment, and engagement, ultimately leading to more effective outreach and streamlined sales processes.
#
# Confidence Interval: 9/10
#
# Reasoning: The website provides clear information about PrimeRole's core functionalities and target audience. The provided description accurately reflects the key features and benefits highlighted on the website.
#
# FAILURE TO MATCH
# FAILURE TO MATCH
# FAILURE TO MATCH
# FAILURE TO MATCH
# FAILURE TO MATCH

# %%
def extract_data(text):
    if pd.isnull(text): return {}
    text = text.replace("\n"," ").replace("  "," ").replace("*","").replace(" (two sentences)","").replace("/10","").replace("_","").replace("#","")
    pattern = r"^.*?\s*Description:?\s*(.*)Confidence Interval:\s*(\d+)\s*Reasoning:\s*(.*)$"
    match = re.search(pattern, text, re.DOTALL)
    
    if match:
        description = match.group(1).strip()
        confidence_interval = match.group(2).strip()
        reasoning = match.group(3).strip()
        
        result = {
            "generated_description": description,
            "generated_description_conf_interval": confidence_interval,
            "generated_description_conf_interval_reasoning": reasoning
        }
        return result
        
    else:
        print("FAILURE TO MATCH")
        return {}
        
for col in cols:
    if col in list(df.columns): df=df.drop(columns=[col])
        
results_df = pd.DataFrame(list(df.apply(lambda x: extract_data(x["generated_description_llm"]),axis=1)))
df = pd.concat([df, results_df],axis=1)

# %%
len(df)
# Out:
# 2193

# %%
# Restart if cut in the middle of run!
# df = df.merge(prompting_class.results_df, on='organization name', how='left')

# %%
df = df.dropna(subset=["generated_description"],axis=0)
df = df.drop_duplicates(subset=['organization name'], keep='first')
df = df.reset_index(drop=True)

# %%
cols = ["parsed_description", "parsed_description_conf_interval", "parsed_description_conf_interval_reasoning", "Tasks/Jobs","Industry","Customers"]
    
args = [["company","organization name"],["website","website"], ["description","generated_description"]]

df = prompting_class.iterate(df, parsed_description_prompt, args, "parsed_description_llm",1778)

df.to_csv('../output/df_with_parsed_description.csv', index=False)
# Out:
# ******************************
# Processing 1778: Abide AI, abideai.com/
# Abide AI is a platform that simplifies the development, deployment, and evaluation of machine learning (ML) systems. They focus on ensuring that ML models can be smoothly integrated into technology ecosystems while prioritizing robustness, reliability, and scalability.
# Result:
# Tasks/Jobs: Model training, Model deployment, Model monitoring, Model evaluation
# Industry: Machine Learning
# Customers: Data Scientists, Machine Learning Engineers
#
# Confidence Interval: 8
# Reasoning: The website focuses on ML development and deployment, which suggests the target audience is directly involved in these tasks. The language used in their description implies targeting individuals within the ML field.
#
# ******************************
# Processing 1779: Plexicus, www.plexicus.com/
# Plexicus is an AI-powered vulnerability management platform that helps organizations classify their assets, prioritize vulnerabilities, and automate remediation efforts. It uses machine learning to analyze data, identify potential threats, and recommend the most effective solutions for addressing them.
# Result:
# Tasks/Jobs: Vulnerability assessment, Threat prioritization, Remediation automation, Security reporting
# Industry: Cybersecurity
# Customers: Security professionals, IT managers, Developers
#
# Confidence Interval: 9
# Reasoning: The website and description explicitly mention these tasks, industry, and customer types.
#
# ******************************
# Processing 1780: Nexting Labs, www.nextinglabs.com/
# Nexting Labs provides data science and machine learning consulting services, focusing on predictive analytics for social media, websites, and apps. They offer solutions like data mining, cleaning, and analysis to help small and mid-sized businesses gain actionable insights for revenue growth, lead generation, user acquisition, cost minimization, and AI tool development.
# Result:
# Tasks/Jobs: Data mining, Predictive analytics, Machine learning model development,  Data visualization
# Industry: Data science consulting
# Customers: Small and mid-sized businesses
#
# Confidence Interval: 9
# Reasoning: The company's website and description clearly indicate their focus on data science consulting, specifically mentioning predictive analytics and machine learning. The listed services and target customers align with this specialization.
#
# ******************************
# Processing 1781: PerVista AI, www.pervista.ai
# PerVista AI utilizes AI to analyze real-time video streams from surveillance cameras, aiming to identify the presence of firearms and proactively notify public safety authorities. This technology aims to prevent potential active shooter events by detecting threats before they escalate, thus improving public safety in various locations like schools, shopping centers, and other public venues.
# Result:
# Company: PerVista AI
# Wesbite: www.pervista.ai
# Description: PerVista AI utilizes AI to analyze real-time video streams from surveillance cameras, aiming to identify the presence of firearms and proactively notify public safety authorities. This technology aims to prevent potential active shooter events by detecting threats before they escalate, thus improving public safety in various locations like schools, shopping centers, and other public venues.
#
# Tasks/Jobs: Video analysis, Threat detection, Alerting, Public safety
# Industry: Security
# Customers: Schools, Shopping centers, Public venues, Law enforcement agencies
#
# Confidence Interval: 8
# Reasoning: The company's website clearly states their target industry and customers. The tasks/jobs are also derived from the description of the technology.
#
# ******************************
# Processing 1782: Keyflow, keyflow.space
# Keyflow is a user-friendly platform that allows users to create and deploy custom AI-powered workflows without requiring any coding experience. These workflows can automate various tasks within a business, from data analysis to customer service interactions.
# Result:
# Tasks/Jobs: Data analysis, Automation, Customer service, Workflow management
# Industry: Business automation
# Customers: Businesses, Startups, Enterprises
#
# Confidence Interval: 8
# Reasoning: The description highlights the ability to create and deploy custom AI workflows, indicating automation across various business functions. The targeting of businesses, startups, and enterprises is common for workflow automation solutions.
#
# ******************************
# Processing 1783: Drodat, drodat.com
# Drodat is an insurtech company that uses drones and AI to capture and analyze high-resolution images of properties, creating a visual database that helps insurers detect and prevent fraud, optimize underwriting, and manage risks. Their technology is particularly focused on the property insurance market, aiming to tackle the significant fraud problem estimated at $45 billion annually.
# Result:
# Tasks/Jobs: Property inspection, Fraud detection, Risk assessment, Underwriting optimization
# Industry: Insurance
# Customers: Insurance companies, Property owners
#
# Confidence Interval: 9
# Reasoning: The provided description directly outlines the technology's application and target user base.
#
# ******************************
# Processing 1784: JobQuest, jobquest.ai
# JobQuest is an AI-powered platform that streamlines the job search process by automating tasks like resume writing, job matching, and application submission. Their goal is to help job seekers find the right roles and advance their careers with greater ease.
# Result:
# Tasks/Jobs: Resume writing, Job matching, Application submission, Job search optimization
# Industry: Recruitment/Job Search
# Customers: Job Seekers, Career Changers
#
# Confidence Interval: 9
# Reasoning: The website and description clearly state that JobQuest automates tasks related to the job search process, making the target customers job seekers and the industry recruitment/job search.
#
# ******************************
# Processing 1785: ResearchVideos, www.researchvideos.net/
# ResearchVideos is a platform that publishes peer-reviewed scientific research videos across various disciplines. It aims to enhance knowledge transfer by providing a medium for scientists to share their research in a visually engaging format.
# Result:
# Tasks/Jobs: Video production, Scientific research communication, Knowledge dissemination, Peer review
# Industry: Scientific research
# Customers: Scientists, Researchers, Students
#
# Confidence Interval: 9
# Reasoning: The website clearly indicates a focus on scientific research, video production, and knowledge dissemination. The target customers are those involved in the scientific research process.
#
# ******************************
# Processing 1786: Aeon, aeonindustries.co
# Aeon develops advanced capabilities at scale for maximum deterrence. Aeon develops advanced capabilities at scale for maximum deterrence.  Description: Aeon is a company specializing in developing cutting-edge artificial intelligence solutions, primarily focused on enhancing security and defense capabilities. Their products and services aim to provide maximum deterrence by leveraging advanced AI technologies for threat detection, analysis, and response.
# Result:
# Tasks/Jobs: Threat detection,  Threat analysis,  Security response,  AI development
# Industry: Defense
# Customers: Governments, Military organizations
#
# Confidence Interval: 7
# Reasoning:  The company's website and description clearly state a focus on defense and security.  The tasks are inferred from the description's focus on deterrence and AI-powered solutions. While specific customer examples are not provided, the industry naturally points to government and military organizations as likely clients.
#
# ******************************
# Processing 1787: Fiber AI, www.fiber.ai/
# Fiber AI is an AI-powered marketing automation platform that automates the entire outbound sales process, including lead generation, research, and personalized outreach. It focuses on delivering highly effective marketing campaigns that achieve significantly higher open rates than industry standards.
# Result:
# Tasks/Jobs: Lead generation, Research, Outreach, Email marketing
# Industry: Marketing Automation
# Customers: Sales teams, Marketing teams, Business owners
#
# Confidence Interval: 9
# Reasoning: The website and description clearly state the platform's automation features and focus on lead generation, outreach, and personalized email marketing, which are core functions of marketing automation.
#
# ******************************
# Processing 1788: Tusk, usetusk.ai
# Tusk is an AI-powered coding assistant that automates bug fixing, resolving customer issues directly from tickets and generating pull requests. By streamlining this process, Tusk helps engineering teams improve customer satisfaction, reduce developer workload, and enhance efficiency.
# Result:
# Tasks/Jobs: Bug fixing, Code generation, Issue resolution, Pull request creation
# Industry: Software development
# Customers: Software developers, Engineering teams
#
# Confidence Interval: 9
# Reasoning: The website and description explicitly mention automating bug fixing, resolving customer issues, and generating pull requests, all of which are tasks related to software development. The target customers are also clearly stated as engineering teams and software developers.
#
# ******************************
# Processing 1789: DubPrime, www.dubprime.com/
# DubPrime is an AI-powered underwriting platform that uses alternative data to evaluate creditworthiness beyond traditional credit scores. This approach allows lenders to extend credit to a wider range of borrowers, promoting financial inclusion and expanding access to capital for underserved communities.
# Result:
# Tasks/Jobs: Credit risk assessment, Loan underwriting, Alternative data analysis, Financial inclusion
# Industry: Fintech
# Customers: Lenders, Borrowers, Financial institutions
#
# Confidence Interval: 9
# Reasoning:  The company's website and description clearly state its focus on AI-powered underwriting and alternative data, targeting lenders and borrowers.
#
# ******************************
# Processing 1790: Credit Pulse, www.creditpulse.com/
# Credit Pulse is a SaaS platform that uses AI to automate and enhance commercial credit risk management. It helps businesses streamline customer onboarding, minimize bad debt, and continuously monitor creditworthiness through an intuitive, data-driven platform.
# Result:
# Tasks/Jobs: Credit scoring, Risk assessment, Customer onboarding, Debt monitoring
# Industry: Financial Services
# Customers: Banks, Lenders, Financial Institutions
#
# Confidence Interval: 9
# Reasoning: The company's website and description clearly indicate a focus on commercial credit risk management, targeting financial institutions as their primary customer base. The tasks listed are core functions within credit risk management, further supporting this assessment.
#
# ******************************
# Processing 1791: Deal.ai, deal.ai
# Deal.ai is a company that provides AI-powered marketing solutions. Their platform leverages artificial intelligence to automate and optimize marketing tasks, including lead generation, content creation, and campaign management.
# Result:
# Company: Deal.ai
# Wesbite: deal.ai
# Description: Deal.ai is a company that provides AI-powered marketing solutions. Their platform leverages artificial intelligence to automate and optimize marketing tasks, including lead generation, content creation, and campaign management.
#
# Tasks/Jobs: Lead generation, Content creation, Campaign management, Marketing automation
# Industry: Marketing
# Customers: Businesses, Marketing agencies
#
# Confidence Interval: 9
# Reasoning: The description clearly states that Deal.ai provides AI-powered marketing solutions, focusing on automation and optimization of tasks like lead generation, content creation, and campaign management.  It's highly likely they cater to businesses and marketing agencies who require these services.
#
# ******************************
# Processing 1792: AI Magicx, aimagicx.com/
# AI Magicx is an AI-powered content creation platform that allows users to generate stunning images, logos, and articles with its suite of AI tools. Their offerings include an AI Image Generator, AI Article Generator, AI Logo Designer, AI Story Creator, and are developing an AI Chatbots community for users to create their own bots.
# Result:
# Tasks/Jobs: Image generation, Logo design, Article writing, Chatbot creation
# Industry: Content creation
# Customers: Marketers, Content creators, Businesses, Individuals
#
# Confidence Interval: 9
# Reasoning: The website and description clearly highlight AI-powered content creation as the core focus. The tasks are directly related to the offered tools, and the target audience is likely those who need content for various purposes.
#
# ******************************
# Processing 1793: Kynismos AI, www.kynismos.ai
# Kynismos AI is a company developing a human-centered AI system that prioritizes individual sovereignty and privacy in the digital age. Their goal is to create an AI that acts as a guardian and advocate, protecting personal data and empowering users while fostering a positive relationship between humans and AI.
# Result:
# Tasks/Jobs: Data privacy management, Identity verification, Digital security, User advocacy
# Industry: Privacy and Security
# Customers: Individuals, Organizations
#
# Confidence Interval: 7
# Reasoning:  While the company is focused on a broad concept of human-centered AI, the specific applications mentioned (sovereignty, privacy, data protection) point towards tasks in the security and privacy domain.  The target customer base is also likely to include individuals and organizations who are concerned with these issues.
#
# ******************************
# Processing 1794: Chamoy, www.chamoy.io/
# Chamoy is an AI-powered video interviewing platform that uses conversational intelligence to identify top candidates for businesses. The platform's flagship product, Ellie, conducts lifelike interviews and provides insights to help recruiters make more informed hiring decisions.
# Result:
# Tasks/Jobs: Interview scheduling, Interviewing, Candidate evaluation, Hiring recommendations
# Industry: Human Resources
# Customers: Recruiters, Hiring managers
#
# Confidence Interval: 9
# Reasoning: The company's website and description clearly focus on automating the interview process and providing insights to help recruiters make hiring decisions.
#
# ******************************
# Processing 1795: Signlz, www.signlz.co/
# Signlz is an AI-powered platform that simplifies and streamlines product development by automating PRD creation, technical specifications, and task breakdown. It integrates with popular task management tools like Jira, Asana, and Trello, allowing product teams to effortlessly move from vision to execution.
# Result:
# Tasks/Jobs: PRD creation, Technical specification writing, Task breakdown, Project management integration
# Industry: Product Development
# Customers: Product managers, Software engineers, Project managers
#
# Confidence Interval: 9
# Reasoning: The website and description clearly state the automation of PRD creation, technical specifications, and task breakdown. The integration with popular project management tools indicates a target audience of product teams.
#
# ******************************
# Processing 1796: OpenSphere, opensphere.ai/
# OpenSphere is an AI-powered platform designed to assist high-skilled legal immigrants in obtaining O1, EB1A, and EB2 NIW visas. It connects immigrants with qualified immigration lawyers through a marketplace, streamlining the visa application process and providing access to expert legal support.
# Result:
# Tasks/Jobs:  Visa application preparation, Legal documentation review, Immigration lawyer matching, Case management
# Industry: Immigration Law
# Customers: High-skilled legal immigrants
#
# Confidence Interval: 9
# Reasoning: The company explicitly states its focus on assisting high-skilled legal immigrants with specific visa types.  The tasks are derived from the services offered on the website, including legal document review, lawyer matching, and case management.
#
# ******************************
# Processing 1797: Etoile Foundry, etoile.sh
# Etoile Foundry is a software company that helps artists create, manage, and distribute their digital art securely and efficiently. Their platform provides tools for minting NFTs, managing wallets, and collaborating with other artists, all while focusing on user-friendliness and security.
# Result:
# Company: Etoile Foundry
# Wesbite: etoile.sh
# Description: Etoile Foundry is a software company that helps artists create, manage, and distribute their digital art securely and efficiently. Their platform provides tools for minting NFTs, managing wallets, and collaborating with other artists, all while focusing on user-friendliness and security.
#
# Tasks/Jobs: NFT minting, Digital art management, Wallet management, Artist collaboration
# Industry: Digital Art
# Customers: Digital Artists, NFT creators, Collectors
#
# Confidence Interval: 9
# Reasoning: The website and description clearly indicate the target audience and functionality.  The website itself features images and examples of the platform's use cases, further solidifying the understanding of its purpose.
#
# ******************************
# Processing 1798: nu, nuconsortium.xyz
# nu is a platform that leverages blockchain and AI technologies to create a more equitable and inclusive financial ecosystem. It aims to achieve this by fostering social engagement and promoting innovative financial solutions.
# Result:
# Tasks/Jobs: Financial transactions, Social engagement, Data analysis, Decentralized finance
# Industry: Financial Services
# Customers: Individuals, Businesses, Financial institutions
#
# Confidence Interval: 6
# Reasoning: The description mentions financial ecosystem, social engagement, and innovative financial solutions, which suggests a focus on financial services. The use of blockchain and AI technologies implies tasks related to transactions, data analysis, and potentially decentralized finance. The target customers likely include individuals, businesses, and financial institutions seeking innovative financial solutions.
#
# ******************************
# Processing 1799: Tecde, tecde.co
# Tecde is a B2B SaaS platform that leverages AI and computer vision to automate inventory counting for businesses. Their solution provides real-time inventory updates, anomaly detection, photo-based uploads, and AI-driven predictions, streamlining inventory management processes and improving efficiency.
# Result:
# Tasks/Jobs: Inventory counting, Anomaly detection, Stock predictions, Inventory management
# Industry: Retail/Supply Chain Management
# Customers: Warehouses, Retail stores, Distribution centers
#
# Confidence Interval: 9
# Reasoning: The description explicitly states that Tecde's solution focuses on automating inventory counting, mentioning features like real-time updates, anomaly detection, and predictions. These tasks are directly related to inventory management within retail and supply chain operations.
#
# ******************************
# Processing 1800: WhisperMD, whispermd.ai/
# WhisperMD is an AI-powered platform that automates clinical notes for healthcare providers. By analyzing patient dialogues, WhisperMD generates comprehensive and accurate notes, freeing up physicians' time for patient care.
# Result:
# Company: WhisperMD
# Wesbite: whispermd.ai/
# Description: WhisperMD is an AI-powered platform that automates clinical notes for healthcare providers. By analyzing patient dialogues, WhisperMD generates comprehensive and accurate notes, freeing up physicians' time for patient care.
#
# Tasks/Jobs: Clinical note generation, Transcription, Medical recordkeeping, Time saving
# Industry: Healthcare
# Customers: Physicians, Nurses, Healthcare providers
#
# Confidence Interval: 9
# Reasoning: The website clearly states that WhisperMD is an AI-powered platform for automating clinical notes. The target customers are healthcare providers, and the tasks are directly related to the automation of clinical documentation.
#
# ******************************
# Processing 1801: Ziymo, ziymo.com
# Ziymo is an AI-powered platform designed to streamline and optimize the government contracting process. Their technology helps businesses navigate complex regulations, find relevant opportunities, and submit winning bids through intelligent automation and data-driven insights.
# Result:
# Tasks/Jobs: Contract proposal writing, bid submission, compliance tracking, government opportunity research
# Industry: Government contracting
# Customers: Businesses seeking government contracts
#
# Confidence Interval: 9
# Reasoning: The description explicitly states Ziymo focuses on automating government contracting processes and providing insights for winning bids. This points to tasks related to proposal writing, bid submission, and compliance. The industry is clearly government contracting, and the target customers are businesses seeking government contracts.
#
# ******************************
# Processing 1802: DateDroid, www.datedroid.com
# DateDroid is an AI-powered service that analyzes dating profiles and provides personalized advice to help users improve their online presence and attract more matches. For a fee of $0.50 per profile, users can receive insightful suggestions tailored to their specific profile and dating goals.
# Result:
# Company: DateDroid
# Wesbite: www.datedroid.com
# Description: DateDroid is an AI-powered service that analyzes dating profiles and provides personalized advice to help users improve their online presence and attract more matches. For a fee of $0.50 per profile, users can receive insightful suggestions tailored to their specific profile and dating goals.
#
# Tasks/Jobs: Profile analysis, Content optimization, Match prediction, Dating advice
# Industry: Online dating
# Customers: Dating app users, singles
#
# Confidence Interval: 9/10
# Reasoning:  The website and description clearly state the target audience is dating app users, and the tasks relate directly to the improvement of dating profiles.
#
# ******************************
# Processing 1803: Sups, www.sups.ai/
# Sups is an AI-powered platform that helps students write college application essays by providing brainstorming, outlining, and revision guidance. Their goal is to democratize college admissions by leveling the playing field for students across the globe.
# Result:
# Tasks/Jobs: Essay brainstorming, Essay outlining, Essay revision, Essay feedback
# Industry: Education
# Customers: Students applying to college
#
# Confidence Interval: 9
# Reasoning: The website and description explicitly state that the platform focuses on helping students write college application essays. The provided tasks are directly related to this purpose.
#
# ******************************
# Processing 1804: Context Data, contextdata.ai/
# Context Data is a platform that simplifies data processing and ETL (Extract, Transform, Load) for Generative AI applications. It enables developers to easily connect various data sources, transform data, and load it into vector databases, all without writing code, allowing them to quickly build and maintain scalable data infrastructure for AI models.
# Result:
# Tasks/Jobs: Data Extraction, Data Transformation, Data Loading, Data Integration
# Industry: Generative AI
# Customers: AI Developers, Data Scientists
#
# Confidence Interval: 9
# Reasoning:  The website and description clearly indicate Context Data's focus on simplifying data processing for AI development, specifically mentioning ETL and vector databases. This aligns with the typical tasks involved in preparing data for generative AI models.
#
# ******************************
# Processing 1805: Nextstay, nextstay.ai
# Nextstay is a platform that connects landlords, tenants, and subtenants for hassle-free subleasing. It offers a safe and secure marketplace for verified subleases, simplifying the process of finding and renting a sublet.
# Result:
# Tasks/Jobs: Sublease listing management, Tenant screening, Payment processing, Communication facilitation
# Industry: Real Estate
# Customers: Landlords, Tenants, Subtenants
#
# Confidence Interval: 8
# Reasoning: The website and description clearly state that Nextstay connects landlords, tenants, and subtenants for subleasing. The tasks/jobs listed are all essential for this process.
#
# ******************************
# Processing 1806: inPlace, www.inplace.ai
# inPlace is an AI-powered platform that helps businesses design, manage, and optimize their physical spaces. inPlace leverages computer vision and spatial analysis to create digital twins of spaces, allowing for virtual furniture placement, space planning, and dynamic layout adjustments.
# Result:
# Tasks/Jobs: Furniture placement, Space planning, Layout optimization, 3D modeling
# Industry: Interior Design and Architecture
# Customers: Architects, Interior Designers, Real Estate Developers
#
# Confidence Interval: 9
# Reasoning: The website and description clearly state the application of inPlace in the field of interior design and architecture. The tasks listed are directly related to these industries, and the targeted customers are those involved in these fields.
#
# ******************************
# Processing 1807: oneone AI, oneone.live
# Oneone AI is an AI-powered tool that helps managers understand and improve their relationships with their team members. The platform uses data from various sources, including communication logs and performance reviews, to provide insights into individual team member needs, preferences, and potential areas for growth.
# Result:
# Tasks/Jobs: Team communication analysis, Performance insights, Individual needs assessment, Growth potential identification
# Industry: Human Resources Management
# Customers: Managers, Team Leaders
#
# Confidence Interval: 8
# Reasoning:  The website and description clearly focus on using AI for team dynamics and performance improvement, which directly aligns with HR functions.
#
# ******************************
# Processing 1808: Felix Vita, www.felixvita.co/
# Felix Vita is a personalized health assistant app that focuses on preventive care, empowering users to log their daily activities, meals, exercise, and symptoms. By analyzing this data, Felix Vita provides personalized health recommendations, tracks habits, identifies patterns, sets goals, and helps users maintain accountability for better health habits.
# Result:
# Tasks/Jobs: Habit tracking, Goal setting, Data analysis, Personalized recommendations
# Industry: Health and Wellness
# Customers: Individuals, Consumers
#
# Confidence Interval: 9
# Reasoning: The website and description clearly indicate the app's focus on personalized health and habit tracking, making these tasks and the health and wellness industry highly likely.  The customer base is also likely to be individuals seeking to improve their health and wellbeing.
#
# ******************************
# Processing 1809: Cognition, www.cognition-labs.com
# Cognition is a company that provides AI-powered tools and solutions for reasoning and code generation. They offer a range of products, including a powerful code generator and a sophisticated reasoning engine, designed to empower developers and businesses with cutting-edge AI capabilities.
# Result:
# Tasks/Jobs: Code generation, Reasoning, Problem-solving, AI development
# Industry: Software Development
# Customers: Developers, Businesses
#
# Confidence Interval: 9
# Reasoning: The company's website and description explicitly state they focus on AI-powered tools for reasoning and code generation. These functionalities are targeted towards developers and businesses looking to leverage AI for software development.
#
# ******************************
# Processing 1810: Shopsense, www.shopsense.ai
# Shopsense is an AI platform designed to enhance retail media experiences by transforming content into interactive and shoppable journeys. The platform leverages AI to understand consumer behavior and preferences, allowing retailers to personalize product recommendations and create engaging shopping experiences.
# Result:
# Tasks/Jobs: Product recommendations, Content personalization, Interactive shopping experiences, Customer engagement
# Industry: Retail media
# Customers: Retailers, E-commerce businesses
#
# Confidence Interval: 9
# Reasoning: The description clearly indicates Shopsense is focused on enhancing retail media experiences through AI-powered personalization and interactivity. The website further confirms this by showcasing solutions tailored to retailers and e-commerce businesses.
#
# ******************************
# Processing 1811: Colega AI, www.colega.ai
# Colega AI is an AI-powered social media management platform specifically designed for small and medium-sized businesses. It streamlines social media marketing by automating tasks, building an online presence, and eliminating the need for expensive marketers.
# Result:
# Tasks/Jobs: Content creation, Social media scheduling, Audience engagement, Campaign optimization
# Industry: Social Media Marketing
# Customers: Small and medium-sized businesses
#
# Confidence Interval: 9
# Reasoning:  The description clearly states the platform is designed for social media management specifically for SMBs, outlining automation of core tasks.
#
# ******************************
# Processing 1812: Snef, snef.co
# Snef is a platform that utilizes artificial intelligence to personalize the shopping experience. The company aims to revolutionize online shopping by connecting consumers with products and brands that align with their individual lifestyle preferences.
# Result:
# Tasks/Jobs: Product recommendation, Personalized shopping experience, Lifestyle analysis,  Targeted advertising
# Industry: E-commerce
# Customers: Online shoppers, Retailers, Brands
#
# Confidence Interval: 8
# Reasoning: The description clearly indicates a focus on personalizing the online shopping experience, suggesting tasks related to product recommendation and lifestyle analysis.  The target customers are likely online shoppers, retailers, and brands who benefit from personalized experiences.
#
# ******************************
# Processing 1813: The Credit Genius App, creditgeniusapp.com/
# The Credit Genius App is a mobile app that helps users improve their credit score through gamified education, personalized AI coaching, and real-time financial data integration. The app aims to make credit score management more engaging and effective by combining interactive learning with AI-powered insights.
# Result:
# Company: The Credit Genius App
# Wesbite: creditgeniusapp.com/
# Description: The Credit Genius App is a mobile app that helps users improve their credit score through gamified education, personalized AI coaching, and real-time financial data integration. The app aims to make credit score management more engaging and effective by combining interactive learning with AI-powered insights.
#
# Tasks/Jobs: Credit score monitoring, Credit education, Debt management, Personalized financial advice
# Industry: Personal finance
# Customers: Individuals, Consumers
#
# Confidence Interval: 9
# Reasoning: The app's description clearly indicates its focus on credit score improvement, which falls under personal finance. The tasks and customers are also directly related to this core function.
#
# ******************************
# Processing 1814: TVADS.ai, tvads.ai
# TVADS.ai is a platform that specializes in helping direct-to-consumer (DTC) brands achieve better performance results through streaming television advertising. They utilize advanced technology and data insights to optimize ad campaigns, target the right audiences, and track campaign effectiveness across various streaming platforms.
# Result:
# Company: TVADS.ai
# Wesbite: tvads.ai
# Description: TVADS.ai is a platform that specializes in helping direct-to-consumer (DTC) brands achieve better performance results through streaming television advertising. They utilize advanced technology and data insights to optimize ad campaigns, target the right audiences, and track campaign effectiveness across various streaming platforms.
#
# Tasks/Jobs: Ad campaign optimization, Audience targeting, Campaign performance tracking, Streaming TV advertising
# Industry: Digital advertising
# Customers: Direct-to-consumer (DTC) brands
#
# Confidence Interval: 9
# Reasoning: The description clearly states that TVADS.ai focuses on helping DTC brands with their streaming TV advertising, implying tasks related to optimization, targeting, tracking, and advertising itself. The industry is undoubtedly digital advertising, as the platform utilizes technology and data for advertising.
#
# ******************************
# Processing 1815: eDNA Explorer, www.ednaexplorer.org
# eDNA Explorer is a cloud-based platform that leverages environmental DNA (eDNA) technology to provide actionable insights into biodiversity. The platform combines eDNA sequencing with geospatial data and AI algorithms to track biodiversity health, predict environmental changes, and inform decision-making in industries like agriculture, pharmaceuticals, and conservation.
# Result:
# Tasks/Jobs: Biodiversity monitoring, Environmental impact assessment, Species distribution mapping, Conservation planning
# Industry: Environmental monitoring
# Customers: Environmental agencies, Conservation organizations, Pharmaceutical companies, Agricultural businesses
#
# Confidence Interval: 8
# Reasoning: The website and description clearly indicate the platform's focus on biodiversity monitoring and the industries involved. The customer list is derived from the stated applications of the technology.
#
# ******************************
# Processing 1816: Barricade AI, barricade.tech
# Barricade AI is a company that utilizes multimodal generative AI to enhance public safety. Their platform analyzes various data sources, including text, images, and audio, to identify potential threats and provide actionable insights to law enforcement agencies.
# Result:
# Tasks/Jobs: Threat detection, Risk assessment,  Incident response, Predictive policing
# Industry: Public safety
# Customers: Law enforcement agencies, Security firms, Government agencies
#
# Confidence Interval: 8
# Reasoning: The provided description clearly indicates Barricade AI's focus on public safety through AI-powered threat analysis and insights for law enforcement.
#
# ******************************
# Processing 1817: FunFuseGames, funfusegames.com/
# FunFuseGames is a mobile game development company that creates a variety of games across multiple genres, including casual, puzzle, card, board, and word games. They focus on creating immersive and engaging experiences tailored to different player preferences.
# Result:
# Tasks/Jobs: Game design, Game development, Game testing, Game marketing
# Industry: Mobile game development
# Customers: Mobile game players, Mobile game publishers
#
# Confidence Interval: 8
# Reasoning: The company's website and description clearly indicate their focus on mobile game development and the types of tasks involved. The target customers are easily inferred from their game genres and focus on immersive experiences.
#
# ******************************
# Processing 1818: InstaHeadshots, instaheadshots.com/
# InstaHeadshots is an online platform that uses AI to transform selfies into professional-looking headshots. The service is designed to be quick and affordable, offering a variety of options for personal branding and professional networking.
# Result:
# Tasks/Jobs: Headshot creation, Photo editing, Background removal, Image enhancement
# Industry: Photography
# Customers: Individuals, Professionals, Businesses
#
# Confidence Interval: 9
# Reasoning: The company's website and marketing materials clearly indicate a focus on creating professional-looking headshots from selfies using AI. This points to the tasks listed above and the target customer base. The photography industry is the logical fit for a service that specializes in headshots.
#
# ******************************
# Processing 1819: FoundationFlow, foundationflow.ai
# FoundationFlow is a B2B platform that simplifies the management of multi-modal large language models (LLMs), allowing businesses to build and deploy generative AI workflows faster, more securely, and cost-effectively. The platform offers advanced capabilities that significantly reduce training costs and resources, enhancing efficiency and scalability for enterprises.
# Result:
# Tasks/Jobs: LLM Management, Generative AI workflow development, AI model training, AI model deployment
# Industry: Artificial Intelligence (AI)
# Customers: Businesses, Enterprises
#
# Confidence Interval: 9
# Reasoning: The description explicitly states FoundationFlow is a B2B platform for businesses. The platform's focus on simplifying LLM management and workflow development aligns with AI-focused businesses.
#
# ******************************
# Processing 1820: Dheyo AI, www.dheyo.ai
# Dheyo AI provides an AI-powered optimization and data orchestration platform designed to accelerate the performance of Retrieval Augmented Generation (RAG) and inference systems. Their technology operates at the hardware level to deliver significant speed and efficiency improvements.
# Result:
# Company: Dheyo AI
# Wesbite: www.dheyo.ai
# Description: Dheyo AI provides an AI-powered optimization and data orchestration platform designed to accelerate the performance of Retrieval Augmented Generation (RAG) and inference systems. Their technology operates at the hardware level to deliver significant speed and efficiency improvements.
#
# Tasks/Jobs: Model optimization, Data orchestration, Inference acceleration, RAG system performance enhancement
# Industry: AI & Machine Learning
# Customers: AI researchers, Developers, Enterprise AI deployments
#
# Confidence Interval: 8
# Reasoning: The description clearly points to AI optimization and data orchestration, implying tasks like model optimization, data management, and inference acceleration. The target customers would likely be those using RAG and inference systems, including researchers, developers, and companies deploying AI.
#
# ******************************
# Processing 1821: Formloge, www.formloge.com
# Formloge is a SaaS platform that enables experts to create custom, user-friendly ERPs without coding, specifically designed to simplify form-intensive processes like tax filings, immigration applications, and other regulated procedures. This AI-powered platform aims to reduce errors, improve user experiences, and empower SMEs to automate and scale their form-based operations.
# Result:
# Company: Formloge
# Wesbite: www.formloge.com
# Description: Formloge is a SaaS platform that enables experts to create custom, user-friendly ERPs without coding, specifically designed to simplify form-intensive processes like tax filings, immigration applications, and other regulated procedures. This AI-powered platform aims to reduce errors, improve user experiences, and empower SMEs to automate and scale their form-based operations.
#
# Tasks/Jobs: Form creation, Data automation,  Process optimization, Workflow management
# Industry: Business process automation
# Customers: Accountants, Lawyers, Immigration consultants, SMEs
#
# Confidence Interval: 9
# Reasoning:  The website and description clearly indicate the platform's focus on form creation, automation, and business process optimization.  The target customers are also evident from the examples of form-intensive processes mentioned.
#
# ******************************
# Processing 1822: Zentarim Corp., zentarim.xyz/
# Zentarim Corp provides a blockchain-based logistics platform designed to improve efficiency and cost-effectiveness in global goods transportation. The company aims to empower individuals by offering a reliable and accessible way to ship essential goods, particularly focusing on computer parts, amidst inflationary pressures.
# Result:
# Company: Zentarim Corp.
# Wesbite: zentarim.xyz/
# Description: Zentarim Corp provides a blockchain-based logistics platform designed to improve efficiency and cost-effectiveness in global goods transportation. The company aims to empower individuals by offering a reliable and accessible way to ship essential goods, particularly focusing on computer parts, amidst inflationary pressures.
#
# Tasks/Jobs: Tracking shipments, Payment processing, Inventory management, Route optimization
# Industry: Logistics
# Customers: Individuals, Computer Parts Retailers, Businesses shipping goods globally
#
# Confidence Interval: 8
# Reasoning: The website and description explicitly state the focus on blockchain-based logistics, global goods transportation, and computer parts. This suggests a targeting of individuals and businesses involved in these activities.
#
# ******************************
# Processing 1823: Linnk, linnk.ai
# Linnk.ai is an AI-powered research tool that simplifies reading and understanding of complex text by creating clickable summaries, highlighting key arguments, and organizing data for easy comprehension. Linnk.ai also supports multilingual users, allowing them to seamlessly switch between languages and ensuring a smooth reading experience.
# Result:
# Tasks/Jobs: Text summarization, Data extraction, Argument identification, Language translation
# Industry: Research and analysis
# Customers: Researchers, Students, Professionals
#
# Confidence Interval: 8
# Reasoning: The website and description clearly emphasize Linnk.ai's focus on simplifying research and understanding complex text. The listed features directly support these tasks and indicate a target audience of individuals and professionals involved in research and analysis.
#
# ******************************
# Processing 1824: PensarAI, www.pensarai.com
# PensarAI is a B2B SaaS platform that provides identity access management (IAM) solutions. Their AI-powered technology correlates identity data from various sources to enhance security, identify potential risks, and improve overall access management.
# Result:
# Company: PensarAI
# Wesbite: www.pensarai.com
# Description: PensarAI is a B2B SaaS platform that provides identity access management (IAM) solutions. Their AI-powered technology correlates identity data from various sources to enhance security, identify potential risks, and improve overall access management.
#
# Tasks/Jobs:  Identity verification, Access control, Risk assessment, Security auditing
# Industry:  Cybersecurity
# Customers:  Large enterprises, Government agencies, Financial institutions
#
# Confidence Interval: 9
# Reasoning: The website clearly states PensarAI focuses on IAM solutions with AI for security and risk management. Their target customers are likely organizations with complex security needs, which aligns with the typical clientele for cybersecurity solutions.
#
# ******************************
# Processing 1825: Spend Ninja, spendninaj.com
# Spend Ninja is a mobile app that aims to simplify personal finance management by combining budget tracking and transaction monitoring with engaging educational content. The app's goal is to make managing money more enjoyable and accessible to users of all financial backgrounds.
# Result:
# Company: Spend Ninja
# Wesbite: spendninaj.com
# Description: Spend Ninja is a mobile app that aims to simplify personal finance management by combining budget tracking and transaction monitoring with engaging educational content. The app's goal is to make managing money more enjoyable and accessible to users of all financial backgrounds.
#
# Tasks/Jobs: Budget tracking, Transaction monitoring, Financial education, Spending analysis
# Industry: Personal Finance
# Customers: Individuals, Consumers
#
# Confidence Interval: 9
# Reasoning: The description clearly states the app's focus on personal finance management, budgeting, and education. These features are targeted at individual consumers.
#
# ******************************
# Processing 1826: Bezoku, www.bezoku.ai
# Bezoku is a company developing AI-powered software focused on improving user experiences and efficiency. Their current focus is on optimizing the process of managing and configuring servers, aiming to simplify and streamline this complex task.
# Result:
# Tasks/Jobs: Server configuration, Server management, Automation,  Performance optimization
# Industry: IT infrastructure management
# Customers: IT professionals, System administrators, DevOps engineers
#
# Confidence Interval: 8
# Reasoning: The description clearly states that Bezoku focuses on server management and automation, which aligns with IT infrastructure management. The target customer base is likely IT professionals who deal with these tasks.
#
# ******************************
# Processing 1827: Rocket Coach, rocketcoach.ai
# Rocket Coach is an AI-powered coaching platform that combines personalized guidance with human interaction. Through its algorithm, Rocket Coach provides tailored coaching experiences that support users in reaching their personal and professional goals.
# Result:
# Company: Rocket Coach
# Wesbite: rocketcoach.ai
# Description: Rocket Coach is an AI-powered coaching platform that combines personalized guidance with human interaction. Through its algorithm, Rocket Coach provides tailored coaching experiences that support users in reaching their personal and professional goals.
#
# Tasks/Jobs: Goal setting, Progress tracking, Personalized feedback, Motivation
# Industry: Coaching and Personal Development
# Customers: Individuals, Teams, Businesses
#
# Confidence Interval: 8
# Reasoning: The website and description clearly indicate a focus on personalized coaching, utilizing AI for goal setting, progress tracking, and feedback. This points towards a coaching and personal development industry with individuals, teams, and businesses as potential customers.
#
# ******************************
# Processing 1828: Supply Pay, supplypaytx.com
# Supply Pay is a fintech platform specializing in cross-border trade financing, primarily between US importers and Latin American exporters. They use technology to assess risk and facilitate secure financing while offering customers real-time insights and monitoring of their trading partners, ultimately improving cash flow and promoting business growth.
# Result:
# Company: Supply Pay
# Wesbite: supplypaytx.com
# Description: Supply Pay is a fintech platform specializing in cross-border trade financing, primarily between US importers and Latin American exporters. They use technology to assess risk and facilitate secure financing while offering customers real-time insights and monitoring of their trading partners, ultimately improving cash flow and promoting business growth.
#
# Tasks/Jobs: Risk assessment, Trade financing, Cash flow management, Business monitoring
# Industry:  Cross-border trade finance
# Customers: US importers, Latin American exporters
#
# Confidence Interval: 9
# Reasoning: The website and description clearly outline the company's focus on facilitating cross-border trade financing. The tasks and customers are directly related to this core offering.
#
# ******************************
# Processing 1829: Youkeeps, youkeeps.com/
# Youkeeps is a corporate scheduling tool that streamlines meeting coordination, automating the process of finding common available time slots for participants across different time zones and individual preferences. Youkeeps leverages AI to significantly reduce the time spent on scheduling meetings, ultimately increasing productivity and minimizing frustration for employees.
# Result:
# Tasks/Jobs: Meeting scheduling, Time zone management, Calendar integration, Meeting optimization
# Industry: Meeting scheduling
# Customers: Teams, Organizations, Businesses
#
# Confidence Interval: 9
# Reasoning: The website and description clearly focus on automating meeting scheduling and highlighting the benefits of time management across different time zones. The targeted customer base is easily inferred from the context.
#
# ******************************
# Processing 1830: Type AI Technologies, www.typeai.live
# Type AI Technologies is a platform that simplifies DeFi transactions by allowing users to execute complex actions, like swapping, staking, and lending, through natural language text or voice commands. The platform leverages AI to streamline the process, finding the best rates and executing transactions seamlessly.
# Result:
# ...
# Result:
# Tasks/Jobs: Workspace booking, Desk reservation, Meeting room scheduling, Collaboration space access
# Industry: Workspace Management
# Customers: Freelancers, Remote workers, Entrepreneurs, Students
#
# Confidence Interval: 8
# Reasoning: The description clearly focuses on providing access to on-demand workspaces. The tasks listed are directly related to managing and accessing these spaces. The target customers are individuals who need flexible and readily available work options.
#
# ******************************
# Processing 2177: Giz Inc., www.giz.ai
# Giz Inc. provides an all-in-one productivity platform that combines AI-powered collaborative notes and cloud storage with an AI assistant. The platform aims to simplify workflows by integrating these features with intelligent automation capabilities.
# Result:
# Company: Giz Inc.
# Wesbite: www.giz.ai
# Description: Giz Inc. provides an all-in-one productivity platform that combines AI-powered collaborative notes and cloud storage with an AI assistant. The platform aims to simplify workflows by integrating these features with intelligent automation capabilities.
#
# Tasks/Jobs:  Task automation, Note taking,  Data organization,  Content generation
# Industry: Productivity
# Customers: Professionals, Teams, Businesses
#
# Confidence Interval: 8
# Reasoning: The platform description clearly indicates a focus on productivity enhancement through AI-powered tools. The listed features suggest automation of tasks, note-taking, data organization, and content generation, which are all relevant to professional and business workflows.
#
# ******************************
# Processing 2178: Vison AI, vison.ai/
# Vison AI is a content creation tool powered by AI that helps individuals and businesses generate various types of content, including blog posts and social media content. It offers a variety of templates, features, and tools to streamline the content creation process and save time and resources.
# Result:
# Tasks/Jobs: Content generation, Blog post writing, Social media posting, Content editing
# Industry: Content creation
# Customers: Individuals, Businesses, Marketers
#
# Confidence Interval: 9
# Reasoning: The website and description clearly state that Vison AI is a content creation tool designed for individuals and businesses.
#
# ******************************
# Processing 2179: Building, building.inc
# Building is a platform that tokenizes real estate, allowing investors to buy and sell fractional ownership of properties through digital tokens. The platform leverages data analytics and advanced validation processes to ensure transparency, liquidity, and trust in the real estate market.
# Result:
# Tasks/Jobs: Fractional ownership management, Real estate investment, Digital token trading, Data analytics
# Industry: Real Estate Investment
# Customers: Investors, Real estate developers
#
# Confidence Interval: 9
# Reasoning: The provided description explicitly mentions tokenized real estate, fractional ownership, and digital tokens, which directly point to these tasks and the real estate industry.  The target customers are likely investors seeking alternative investment opportunities and developers looking to utilize the platform for their projects.
#
# ******************************
# Processing 2180: Mio, justmio.com/
# Mio is an AI-powered journaling app designed to help users reflect on their day, set intentions, and track their progress towards personal goals. It leverages AI to provide personalized insights, prompts, and guidance for a more mindful and intentional life.
# Result:
# Tasks/Jobs:  Journaling, Goal Setting, Reflection, Self-improvement
# Industry: Personal Development
# Customers: Individuals seeking self-improvement, mindfulness, and goal tracking
#
# Confidence Interval: 9
# Reasoning:  The website and description clearly indicate the app's focus on personal development through journaling, goal setting, and reflection. The AI aspect suggests personalized guidance, further aligning with self-improvement. The target customer is readily identified as individuals seeking these benefits.
#
# ******************************
# Processing 2181: Just Banter, justbanter.ai/
# Just Banter is an AI-powered platform that allows content creators to generate passive income by creating digital twin chatbots. These chatbots interact with fans 24/7, providing a consistent income stream for the creators through paid interactions.
# Result:
# Tasks/Jobs: Chatbot creation, Content generation, Audience engagement, Monetization
# Industry: Content Creation
# Customers: Content creators, Influencers
#
# Confidence Interval: 8
# Reasoning: The website clearly states that Just Banter is for content creators and focuses on creating chatbots for audience interaction. This suggests a strong focus on the content creation industry.
#
# ******************************
# Processing 2182: Rivio, www.rivio.ai/
# Rivio is an AI-powered procurement platform specifically designed for hardware companies. It automates tasks like BOM cost estimation, supplier sourcing, and negotiation, leveraging historical data and real-time market insights to streamline the procurement process and optimize pricing.
# Result:
# Tasks/Jobs: BOM cost estimation, Supplier sourcing, Negotiation, Procurement optimization
# Industry: Hardware manufacturing
# Customers: Hardware companies, OEMs (Original Equipment Manufacturers)
#
# Confidence Interval: 9
# Reasoning: The company's website clearly states its focus on hardware companies and the specific tasks it automates.
#
# ******************************
# Processing 2183: Sciforium, sciforium.com
# Sciforium specializes in developing and deploying cutting-edge AI models, focusing on enhancing efficiency, protecting user privacy, and maximizing model versatility. Their platform provides access to these models for various applications, enabling users to leverage advanced AI capabilities in their specific domains.
# Result:
# Tasks/Jobs: Model training, Model deployment, Data analysis,  Automated decision making
# Industry: AI Solutions
# Customers: Researchers, Developers, Businesses
#
# Confidence Interval: 7
# Reasoning: The description highlights AI model development and deployment, suggesting applications in research, development, and business contexts. However, the specifics of the models and their targeted use cases are not explicitly mentioned.
#
# ******************************
# Processing 2184: BaseForge Inc., baseforge.co
# BaseForge Inc. is a company that provides AI advisory and incubation services. They help businesses integrate AI into their operations by offering strategic guidance, technology development, and thorough analysis to ensure tangible results.
# Result:
# Company: BaseForge Inc.
# Wesbite: baseforge.co
# Description: BaseForge Inc. is a company that provides AI advisory and incubation services. They help businesses integrate AI into their operations by offering strategic guidance, technology development, and thorough analysis to ensure tangible results.
#
# Tasks/Jobs: AI strategy development, AI technology integration, AI solution design, AI performance analysis
# Industry: AI consulting
# Customers: Businesses, Enterprises
#
# Confidence Interval: 8
# Reasoning: The description clearly indicates AI advisory and incubation services, which directly point towards consulting services for businesses integrating AI.  The mention of "tangible results" suggests a focus on real-world applications, hinting at enterprise customers.
#
# ******************************
# Processing 2185: Redacted Holdings, redactedholdings.co
# Redacted Holdings is a venture capital firm specializing in deep tech investments. They focus on mid-stage, growth, and pre-IPO companies, particularly in the sectors of American defense technology and national security.
# Result:
# Company: Redacted Holdings
# Wesbite: redactedholdings.co
# Description: Redacted Holdings is a venture capital firm specializing in deep tech investments. They focus on mid-stage, growth, and pre-IPO companies, particularly in the sectors of American defense technology and national security.
#
# Tasks/Jobs: Due diligence, Portfolio management, Investment strategy, Deal negotiation
# Industry: Venture Capital
# Customers: Deep tech startups, Defense technology companies, National security companies
#
# Confidence Interval: 9
# Reasoning: This information is directly inferred from the provided description of Redacted Holdings' specialization in deep tech investments, particularly in the American defense technology and national security sectors.
#
# ******************************
# Processing 2186: SupaLlama, www.supallama.ai
# SupaLlama is a SaaS platform that empowers businesses to build, test, and deploy AI-powered Retrieval Augmented Generation (RAG) applications without requiring specialized AI engineers. Its user-friendly interface simplifies the process, enabling users to leverage AI for tasks like knowledge base search, document summarization, and question answering.
# Result:
# Tasks/Jobs: Knowledge base search, document summarization, question answering, AI model deployment
# Industry: Natural Language Processing (NLP)
# Customers: Businesses, Developers
#
# Confidence Interval: 9
# Reasoning: The company's description clearly outlines these tasks/jobs, and the NLP industry is implied by the focus on AI-powered text processing applications. Customers are likely businesses seeking to integrate RAG into their workflows and developers building RAG applications.
#
# ******************************
# Processing 2187: Geolava, www.geolava.com
# Geolava is an AI-powered location intelligence platform that provides businesses with insightful data about places, locations, cities, and more. Using Geolava, businesses can gain a deeper understanding of location-based movements, access geospatial insights, and analyze imagery to uncover opportunities for growth and revenue generation.
# Result:
# Company: Geolava
# Wesbite: www.geolava.com
# Description: Geolava is an AI-powered location intelligence platform that provides businesses with insightful data about places, locations, cities, and more. Using Geolava, businesses can gain a deeper understanding of location-based movements, access geospatial insights, and analyze imagery to uncover opportunities for growth and revenue generation.
#
# Tasks/Jobs: Location analysis, Geospatial insights, Imagery analysis, Data visualization
# Industry: Location Intelligence
# Customers: Businesses, Real estate companies, Urban planners, Market researchers
#
# Confidence Interval: 9
# Reasoning: Geolava's website clearly states its focus on location intelligence and the specific features mentioned (location analysis, imagery analysis, etc.) directly point to the tasks being automated. The target customer base is also explicitly mentioned in the website copy and marketing materials.
#
# ******************************
# Processing 2188: Solatis, solatis.ai
# Solatis is an AI platform that seamlessly integrates with agent assistance applications to automate tasks, streamline workflows, and provide valuable data insights, ultimately boosting business efficiency. Solatis helps businesses across various departments, including customer support, sales, and executive management, by automating routine tasks and freeing up employees for more strategic work.
# Result:
# Company: Solatis
# Wesbite: solatis.ai
# Description: Solatis is an AI platform that seamlessly integrates with agent assistance applications to automate tasks, streamline workflows, and provide valuable data insights, ultimately boosting business efficiency. Solatis helps businesses across various departments, including customer support, sales, and executive management, by automating routine tasks and freeing up employees for more strategic work.
#
# Tasks/Jobs: Task automation, Workflow optimization, Data analysis, Agent assistance
# Industry: Business process automation
# Customers: Businesses, Customer support teams, Sales teams, Executive management teams
#
# Confidence Interval: 8
# Reasoning: The website and description clearly indicate Solatis targets businesses and aims to automate tasks and optimize workflows across different departments.
#
# ******************************
# Processing 2189: Degrees of Interest, www.degreesofinterest.com
# Degrees of Interest is a company that offers an AI-powered visual analytics platform designed to assist law enforcement in criminal investigations. Their tool helps investigators analyze complex data sets, uncover hidden patterns, and identify potential suspects, ultimately aiding in faster and more efficient crime resolution.
# Result:
# Tasks/Jobs: Data analysis, Pattern recognition, Suspect identification, Crime prediction
# Industry: Law Enforcement
# Customers: Police detectives, Investigators, Forensic analysts
#
# Confidence Interval: 9
# Reasoning: The company's website explicitly describes its target audience as law enforcement professionals and the tasks listed are directly related to the platform's AI-powered visual analytics capabilities.
#
# ******************************
# Processing 2190: AI Compliance, aicomply.ai
# AI Compliance provides an online audit tool to help organizations understand and manage compliance risks associated with their AI projects. Their Dynamic Knowledge Graph technology enables comprehensive audits across multiple jurisdictions, ensuring compliance with current and evolving regulations.
# Result:
# Company: AI Compliance
# Wesbite: aicomply.ai
# Description: AI Compliance provides an online audit tool to help organizations understand and manage compliance risks associated with their AI projects. Their Dynamic Knowledge Graph technology enables comprehensive audits across multiple jurisdictions, ensuring compliance with current and evolving regulations.
#
# Tasks/Jobs: Compliance auditing, Risk assessment, AI regulation monitoring, Data privacy compliance
# Industry: AI ethics and governance
# Customers: AI developers, Tech companies, Government agencies
#
# Confidence Interval: 9/10
# Reasoning:  The company's description clearly focuses on compliance for AI projects,  making the tasks, industry, and customer types logical deductions.
#
# ******************************
# Processing 2191: Robozaps, robozaps.com
# Robozaps is an online marketplace that connects buyers and sellers of humanoid robots. The platform features a wide selection of robots from leading brands like Tesla Optimus, Figure AI, UBTECH, and Boston Dynamics, allowing users to explore and purchase advanced robotic technology.
# Result:
# Company: Robozaps
# Wesbite: robozaps.com
# Description: Robozaps is an online marketplace that connects buyers and sellers of humanoid robots. The platform features a wide selection of robots from leading brands like Tesla Optimus, Figure AI, UBTECH, and Boston Dynamics, allowing users to explore and purchase advanced robotic technology.
#
# Tasks/Jobs: Robot search and filtering, Purchase and sale transactions, Delivery coordination, Customer support
# Industry: Robotics marketplace
# Customers: Businesses, Researchers, Individuals
#
# Confidence Interval: 9
# Reasoning: The company's website and description clearly indicate the focus on connecting buyers and sellers of humanoid robots. The tasks and customers are derived directly from this core functionality.
#
# ******************************
# Processing 2192: PrimeRole, www.primerole.com
# PrimeRole is a B2B Sales Intelligence platform designed to improve sales teams' efficiency. It utilizes AI to enhance prospecting, lead scoring, data enrichment, and engagement, ultimately leading to more effective outreach and streamlined sales processes.
# Result:
# Tasks/Jobs: Prospecting, Lead scoring, Data enrichment, Engagement
# Industry: Sales Intelligence
# Customers: Sales teams, Businesses
#
# Confidence Interval: 9
# Reasoning: The description explicitly states that PrimeRole is a B2B Sales Intelligence platform designed to improve sales team efficiency. The tasks listed are directly related to those functions.

# %%
def extract_data(text):
    if pd.isnull(text): return {}
    text = re.sub(r'\s+', ' ', text)  
    text = text.replace("_", "").replace("*", "").replace("#", "")
    text = re.sub(r'\s?\([^)]*\)', '', text)
    pattern = r".*?Tasks/Jobs:\s*(.*?)\s*Industry:\s*(.*?)\s*Customers:\s*(.*?)\s*Confidence Interval:\s*(.*?)\s*Reasoning:\s*(.*)"
    match = re.search(pattern, text, re.DOTALL)
    
    if match:
        tasks_jobs = match.group(1).strip()
        industry = match.group(2).strip()
        customers = match.group(3).strip()
        confidence_interval = match.group(4).strip()
        reasoning = match.group(5).strip()
        
        result = {
            "parsed_description": 
            "Tasks/Jobs: " + tasks_jobs + "\n" + "Industry: " + industry + "\n" + "Customers: "+ customers,
            "Tasks/Jobs": tasks_jobs,
            "Industry": industry,
            "Customers": customers,
            "parsed_description_conf_interval": confidence_interval,
            "parsed_description_conf_interval_reasoning": reasoning
        }
        
        return result
    else:
        print(text)
        print("FAILURE TO MATCH")
        return {}
        
for col in cols:
    if col in list(df.columns): df=df.drop(columns=[col])
        
results_df = pd.DataFrame(list(df.apply(lambda x: extract_data(x["parsed_description_llm"]),axis=1)))
df = pd.concat([df, results_df],axis=1)

# %%
df = df.dropna(subset=["parsed_description"],axis=0)
df = df.drop_duplicates(subset=['organization name'], keep='first')
df = df.reset_index(drop=True)

# %%
df.to_csv('../output/df_with_parsed_description.csv', index=False)

# %%
cols = ["situation1", "situation1_conf_interval", "situation1_conf_interval_reasoning", "situation2", "situation2_conf_interval", "situation2_conf_interval_reasoning","situation3", "situation3_conf_interval", "situation3_conf_interval_reasoning",'Example1','Job1','Job1_title','Example2','Job2','Job2_title','Example3','Job3','Job3_title']

args = [["company","organization name"],["website","website"], ["description","generated_description"], ["parsed_description","parsed_description"]]
df = prompting_class.iterate(df, examples_prompt, args, "examples_llm")

df.to_csv('../output/df_with_examples.csv', index=False)
# Out:
# ******************************
# Processing 0: Pika, pika.art
# Pika is an AI-powered platform that transforms captions and still images into professional-looking videos. With its intuitive interface, Pika simplifies video creation and editing, making it accessible to users of all skill levels.
# Result:
# Pika Examples:
#
# Example 1: A marketer uses Pika to automatically transform a product description and static image into a short, engaging video advertisement for social media.
#
# ONET JOB automated 1: Multimedia Artists and Animators that create animated sequences for video games, interactive media, or computer-based training programs.
# ONET JOB 1: Multimedia Artists and Animators
# Confidence Interval 1: 7
# Reasoning 1: This job aligns with the primary function of the tool, which is to convert static media into animated video content.
#
# Example 2: A content creator uses Pika to generate multiple video variations from a single image and caption, quickly experimenting with different styles and formats to find the most engaging version for their audience.
#
# ONET JOB automated 2: Video Editors that edit video footage for films, television programs, or other productions.
# ONET JOB 2: Video Editors
# Confidence Interval 2: 8
# Reasoning 2: Pika streamlines the process of editing and creating multiple video versions, a common task for video editors.
#
# Example 3: A social media manager uses Pika to quickly create short, animated explainer videos for new products, leveraging the platform's intuitive interface and AI-powered features to create engaging content without requiring extensive video editing skills.
#
# ONET JOB automated 3: Social Media Specialists that create and maintain content for social media platforms.
# ONET JOB 3: Social Media Specialists
# Confidence Interval 3: 6
# Reasoning 3: While social media specialists may not traditionally be involved in video production, Pika's accessibility makes creating video content a plausible task for this role.
#
# ******************************
# Processing 1: Contextual AI, contextual.ai
# Contextual AI provides a cutting-edge generative AI platform designed specifically for business applications. Their technology empowers employees to generate creative content, automate workflows, and gain insights from data, all while ensuring alignment with company-specific context and knowledge.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[90], line 4
#       1 cols = ["situation1", "situation1_conf_interval", "situation1_conf_interval_reasoning", "situation2", "situation2_conf_interval", "situation2_conf_interval_reasoning","situation3", "situation3_conf_interval", "situation3_conf_interval_reasoning",'Example1','Job1','Job1_title','Example2','Job2','Job2_title','Example3','Job3','Job3_title']
#       3 args = [["company","organization name"],["website","website"], ["description","generated_description"], ["parsed_description","parsed_description"]]
# ----> 4 df = prompting_class.iterate(df, examples_prompt, args, "examples_llm")
#       6 df.to_csv('../output/df_with_examples.csv', index=False)
#
# Cell In[65], line 31, in prompting.iterate(self, df, prompt_template, args, value, start, end)
#      29 for arg in args:
#      30     prompt = prompt.replace(f"${arg[0]}", row[arg[1]])
# ---> 31 result = x_gemini.ask(prompt)
#      32 if result == "N/A": break #explicit material
#      34 text = re.sub(r"#|#\s+|_|\*", "", result).strip()
#
# File ~/Desktop/govAI research/startups/src/llms.py:52, in gemini.ask(self, prompt)
#      50 def ask(self,prompt):
#      51     #response = self.model.generate_content(prompt)
# ---> 52     response = self.request(prompt)
#      53     if response["candidates"][0]["finishReason"] == 'SAFETY': return "N/A"
#      54     response = response["candidates"][0]["content"]["parts"][0]["text"]
#
# File ~/Desktop/govAI research/startups/src/llms.py:47, in gemini.request(self, prompt)
#      32 data = {
#      33     "contents": [
#      34         {
#    (...)
#      41     ]
#      42 }
#      43 params = {
#      44     'key': GOOGLE_API_KEY
#      45 }
# ---> 47 response = requests.post(url, headers=headers, json=data, params=params)
#      48 return json.loads(response.text)
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:791, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 response_conn = conn if not release_conn else None
#     790 # Make the request on the HTTPConnection object
# --> 791 response = self._make_request(
#     792     conn,
#     793     method,
#     794     url,
#     795     timeout=timeout_obj,
#     796     body=body,
#     797     headers=headers,
#     798     chunked=chunked,
#     799     retries=retries,
#     800     response_conn=response_conn,
#     801     preload_content=preload_content,
#     802     decode_content=decode_content,
#     803     **response_kw,
#     804 )
#     806 # Everything went great!
#     807 clean_exit = True
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File /opt/anaconda3/lib/python3.11/http/client.py:1386, in HTTPConnection.getresponse(self)
#    1384 try:
#    1385     try:
# -> 1386         response.begin()
#    1387     except ConnectionError:
#    1388         self.close()
#
# File /opt/anaconda3/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File /opt/anaconda3/lib/python3.11/http/client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File /opt/anaconda3/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File /opt/anaconda3/lib/python3.11/ssl.py:1315, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1311     if flags != 0:
#    1312         raise ValueError(
#    1313           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1314           self.__class__)
# -> 1315     return self.read(nbytes, buffer)
#    1316 else:
#    1317     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/anaconda3/lib/python3.11/ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
def extract_data(text):
    if pd.isnull(text): return {}
    # Normalize the text to ensure consistent whitespace and remove unwanted characters.
    text = re.sub(r'\s+', ' ', text).strip()
    text = text.replace("*", "").replace("/10", "").replace("_", "").replace("#", "")
    vals = {}
    i = 1
    while i <=3:
        # Regex pattern adjusted to handle fractions in confidence intervals like '9/10'
        pattern = rf"Example\s+{i}:\s+(.*?)\s+ONET JOB automated\s+{i}:\s+(.*?)\s+ONET JOB\s+{i}:\s+(.*?)\s+Confidence Interval\s+{i}:\s+(\d+(?:/\d+)?)\s+Reasoning\s+{i}:\s+(.*?)(?=\s*Example\s+{i + 1}:|$)"
        match = re.search(pattern, text, re.DOTALL)
        if not match:
            print(text)
            print(f"No matches found for Example {i}")  # Debug if no examples are found
            break

        example_text, onet_job_automated, onet_job, confidence_interval, reasoning = match.groups()
        example_key = f"Example{i}"
        vals[example_key] = example_text.strip()
        vals[f"Job{i}"] = onet_job_automated.strip()
        vals[f"Job{i}_title"] = onet_job.strip()
        vals[f"situation{i}_conf_interval"] = confidence_interval.strip()
        vals[f"situation{i}_conf_interval_reasoning"] = reasoning.strip()

        i += 1  # Prepare to search for the next example
    return vals

for col in cols:
    if col in list(df.columns): df=df.drop(columns=[col])

results_df = pd.DataFrame(list(df.apply(lambda x: extract_data(x["examples_llm"]),axis=1)))
df = pd.concat([df, results_df],axis=1)

# %%
# df[pd.isnull(df.examples_llm)].values

# %%
df = df.dropna(subset=["Example1"],axis=0)
df = df.drop_duplicates(subset=['organization name'], keep='first')
df = df.reset_index(drop=True)

# %%
df.to_csv('../output/df_with_examples.csv', index=False)
