# %%
import pandas as pd
import numpy as np
from llms import gemini
from llms import chatGPT
import re
import time
from lemmatize import lemmatize
x_chat = chatGPT()
x_gemini = gemini()

# %%
df = pd.read_csv("../output/data/data_post_chat_gpt.csv")
df = df[df["headquarters location"].str.contains("United States")]
df = df[pd.to_datetime(df['founded date'])>='11/30/2022']

# %%
len(df)
# Out:
# 2196

# %%
generated_description_prompt = """
Your role is to describe $company ($website)'s product. 
Then, provide a confidence interval on scale on 1-10 on how sure you are about the response. Please be reasonable.

PLEASE FOLLOW THE FORMAT EXACTLY FROM THE EXAMPLES!!!!

EXAMPLES BELOW
************************
Company: Genmo
Website: https://www.genmo.ai/
Description: Genmo is a free tool that creates videos and images using artificial intelligence. Genmo to generate creative text formats of text content, like poems, code, scripts, musical pieces, email, letters, etc.

Company: OnePane
Website: https://www.onepane.ai/
Description: Onepane is a company that offers an AI companion for enhanced DevOps & SRE efficiency. Onepane offers a GenAI solution  providing unparalleled unified insights and control over your Cloud resources. Onepane helps with root cause analysis, cloud governance, and optimization strategies.
************************

YOUR TURN:
Company: $company
Wesbite: $website
Current Description: $description
________________________
Description (two sentences):
Confidence Interval:
Reasoning:
________________________

"""

# %%
parsed_description_prompt = """
Your role is to describe what jobs/tasks, industries, and customer that $company is targeting. Then, provide a confidence interval (1-10) on scale on 1-10 on how sure you are about the response. Please be reasonable.

A response should include:
- tasks/jobs being automated
- the industry that the startup applies to
- specific customers using the tool. DO NOT INCLUDE AN EXPLANATION

PLEASE FOLLOW THE FORMAT EXACTLY FROM THE EXAMPLES!!!!

EXAMPLES BELOW
************************
Company: Petville
Website: petville.co/pricing/biz
Description: Petville Global is a B2B CRM SaaS platform that utilizes advanced technologies like AI/ML and neural net to streamline and expand operations for pet businesses and veterinary clinics both locally and globally. The platform offers deep data analytics and marketing tools, helping businesses save an average of 22% on CRM and vet tech costs.
Tasks/Jobs: Data analysis, Marketing automation, Appointment scheduling, Inventory management
Industry: Customer management
Customers: Vetinarians, Pet Businesses

Company: Thunder
Wesbite: thundercompute.com
Description: Thunder is a decentralized, peer-to-peer cloud computing platform designed to democratize access to GPUs and address the persistent GPU shortage. It provides a solution for individuals and businesses seeking high-performance computing power, enabling them to leverage unused GPU resources from around the world.
Tasks/Jobs: GPU resource allocation, Access to unused GPUs, Distributed computing tasks 
Industry: Cloud Computing
Customers: Developers, GPU Owners

Company: NonprofitsHQ
Websit: www.nonprofitshq.com
Description: NonprofitsHQ is a software suite designed for nonprofits that utilizes AI to automate tasks, manage operations, and improve efficiency, ultimately saving organizations time and resources.
Tasks/Jobs: Fundraising management, Donor relationship management, Grant writing, Event planning
Industry: Non-profit management
Customers: Non-profit organizations
************************

YOUR TURN:
________________________
Company: $company
Wesbite: $website
Description: $description
________________________
Tasks/Jobs (comma separated list of 4, short):
Industry (1 item):
Customers (comma separated list): 
________________________
Confidence Interval:
Reasoning:
________________________
"""

# %%
examples_prompt = """
Your role is to provide 3 two-sentence examples of how the product from $company might be used. Do not mention the name of the company in the examples, and keep the descriptions broad.

Each example should include:
- A detailed description of the job that the tool automates and who performs that job and when.
- The ONET job being automated (preferably one from the database https://www.onetonline.org/) and the ONET task that the tool replaces (preferably one that from https://www.onetcenter.org/dictionary/20.1/excel/task_statements.html, include task id)
- A confidence interval (1-10) indicating how sure you are about the accuracy of your response.

PLEASE FOLLOW THE FORMAT EXACTLY FROM THE EXAMPLES!!!!

The goal is to map each example back to ONET jobs. If the job being automated is recognized by ONET, please use the ONET job title. 
If it is not typically found in ONET, use best judgement!

EXAMPLES BELOW: 
************************
Company: Blanc
Website: tryblanc.ai
Blanc is a compliance automation platform designed for fintech companies. It helps streamline regulatory compliance processes by providing a centralized hub for managing policies, monitoring activities, and generating reports.
_________________________
Example 1: A compliance officer at a fintech company uses Blanc to automate the process of creating and updating compliance policies, ensuring all documents are current and accessible to relevant team members.
ONET JOB automated 1: Compliance Officers that verify that all firm and regulatory policies and procedures have been documented, implemented, and communicated.
ONET JOB 1: Compliance Officers
_________________________
Example 2: A fintech company uses Blanc to generate automated compliance reports for regulatory audits, ensuring all necessary documentation is readily available and organized.
ONET JOB automated 2: Compliance Officers Prepare reports of activities, evaluations, recommendations, or decisions.
ONET JOB 2: Compliance Officers
_________________________
Example 3: A fintech company uses Blanc to monitor real-time transactions for potential compliance violations, triggering alerts and generating reports for further investigation.
ONET JOB automated 3: Compliance Officers that identify compliance issues that require follow-up or investigation.
ONET JOB 3: Compliance Officers



Company: Aether
Website: aetherenergie.com/
Aether Energy is an AI-driven platform designed to simplify the process of rooftop solar installation for businesses, providing comprehensive support from project planning and financing to installation and ongoing maintenance. This platform aims to streamline and optimize the entire solar energy journey for installers. 
________________
Example 1: A solar installer uses Aether to quickly create detailed project plans for rooftop solar installations, including system size, panel placement, and wiring diagrams. 
ONET JOB automated 1: Solar Photovoltaic Installers that diagram layouts and locations for photovoltaic (PV) arrays and equipment, including existing building or site features.
ONET JOB 1: Solar Photovoltaic Installers
________________
Example 2: A business owner leverages Aether to secure financing for their rooftop solar project, providing them with customized loan options and streamlined application processes. 
ONET JOB automated 2: Solar Photovoltaic Installers that prepare solar installation project proposals, quotes, budgets, or schedules.
ONET JOB 2: Solar Photovoltaic Installers
________________
Example 3: A solar installer uses Aether to manage the installation process, tracking materials, scheduling technicians, and coordinating with subcontractors, ensuring smooth project execution. 
ONET JOB automated 3:  Solar Engery Installation Managers that monitor work of contractors and subcontractors to ensure projects conform to plans, specifications, schedules, or budgets.
ONET JOB 3: Solar Energy Installation Managers
________________
************************

YOUR TURN:
Company:$company
Website: $website
Current Description: $description
$parsed_description
________________
Example 1: 
ONET JOB automated 1:
ONET JOB 1: 
Confidence Interval 1:
Reasoning 1:
________________
Example 2: 
ONET JOB automated 2:
ONET JOB 2: 
Confidence Interval 2:
Reasoning 2:
________________
Example 3:
ONET JOB automated 3:
ONET JOB 3: 
Confidence Interval 3:
Reasoning 3:
________________
"""

# %%
class prompting():
    def __init__(self):
        pass
    def set_current_results_df(self,results_df):
        self.results_df = results_df
        
    def iterate(self, df, prompt_template, args, value, start=0, end=False):
        if end == False:
            end = len(df)
            
        if start == 0:
            self.results_df = pd.DataFrame(columns=["organization name",value])
        
        if value in list(df.columns): 
            if start != 0:
                self.results_df = pd.concat([df[["organization name",value]].iloc[:start],self.results_df],axis=0)
            df = df.drop(columns=[value])
        
        
        for i, row in list(df.iterrows())[start:end]:
            failure_count = 0
            prompt = prompt_template
            while True:
                try:
                    name = row['organization name']
                    website = row['website']
                    print(f"******************************\nProcessing {i}: {name}, {website}")
                    if "generated_description" in df.columns:
                        print(row["generated_description"])

                    for arg in args: 
                        prompt = prompt.replace(f"${arg[0]}", row[arg[1]])
                    result = x_gemini.ask(prompt)
                    if result == "N/A": break #explicit material
 
                    text = re.sub(r"#|#\s+|_|\*", "", result).strip()
                    print(f"Result:\n{text}\n")
   
                    self.results_df.loc[i] = [name, result]

                    if i % 5 == 0:
                        self.results_df.to_csv("../output/current_results_df_prompting.csv")
                    break 
                
                except Exception as e:
                    print(failure_count)
                    failure_count += 1
                    if failure_count > 10: 
                        break
                    print(f"Error processing {i}, {row['organization name']}: {e}")
                    time.sleep(20)  
               

            
        df = df.merge(self.results_df, on='organization name', how='left')
        return df

prompting_class = prompting()

# %%
cols = ["generated_description", "generated_description_conf_interval", "generated_description_conf_interval_reasoning"]

args = [["company","organization name"],["website","website"], ["description","description_all"]]

df = prompting_class.iterate(df, generated_description_prompt, args, "generated_description_llm")

df.to_csv('../output/df_with_generated_description.csv', index=False)

# %%
def extract_data(text):
    if pd.isnull(text): return {}
    text = text.replace("\n"," ").replace("  "," ").replace("*","").replace(" (two sentences)","").replace("/10","").replace("_","").replace("#","")
    pattern = r"^.*?\s*Description:?\s*(.*)Confidence Interval:\s*(\d+)\s*Reasoning:\s*(.*)$"
    match = re.search(pattern, text, re.DOTALL)
    
    if match:
        description = match.group(1).strip()
        confidence_interval = match.group(2).strip()
        reasoning = match.group(3).strip()
        
        result = {
            "generated_description": description,
            "generated_description_conf_interval": confidence_interval,
            "generated_description_conf_interval_reasoning": reasoning
        }
        return result
        
    else:
        print("FAILURE TO MATCH")
        return {}
        
for col in cols:
    if col in list(df.columns): df=df.drop(columns=[col])
        
results_df = pd.DataFrame(list(df.apply(lambda x: extract_data(x["generated_description_llm"]),axis=1)))
df = pd.concat([df, results_df],axis=1)

# %%
len(df)

# %%
# Restart if cut in the middle of run!
# df = df.merge(prompting_class.results_df, on='organization name', how='left')

# %%
df = df.dropna(subset=["generated_description"],axis=0)
df = df.drop_duplicates(subset=['organization name'], keep='first')
df = df.reset_index(drop=True)

# %%
cols = ["parsed_description", "parsed_description_conf_interval", "parsed_description_conf_interval_reasoning", "Tasks/Jobs","Industry","Customers"]
    
args = [["company","organization name"],["website","website"], ["description","generated_description"]]

df = prompting_class.iterate(df, parsed_description_prompt, args, "parsed_description_llm",1778)

df.to_csv('../output/df_with_parsed_description.csv', index=False)
# Out:
# ******************************
# Processing 1778: Abide AI, abideai.com/
# Abide AI is a platform that simplifies the development, deployment, and evaluation of machine learning (ML) systems. They focus on ensuring that ML models can be smoothly integrated into technology ecosystems while prioritizing robustness, reliability, and scalability.
# Result:
# Tasks/Jobs: Model training, Model deployment, Model monitoring, Model evaluation
# Industry: Machine Learning
# Customers: Data Scientists, Machine Learning Engineers
#
# Confidence Interval: 8
# Reasoning: The website focuses on ML development and deployment, which suggests the target audience is directly involved in these tasks. The language used in their description implies targeting individuals within the ML field.
#
# ******************************
# Processing 1779: Plexicus, www.plexicus.com/
# Plexicus is an AI-powered vulnerability management platform that helps organizations classify their assets, prioritize vulnerabilities, and automate remediation efforts. It uses machine learning to analyze data, identify potential threats, and recommend the most effective solutions for addressing them.
# Result:
# Tasks/Jobs: Vulnerability assessment, Threat prioritization, Remediation automation, Security reporting
# Industry: Cybersecurity
# Customers: Security professionals, IT managers, Developers
#
# Confidence Interval: 9
# Reasoning: The website and description explicitly mention these tasks, industry, and customer types.
#
# ******************************
# Processing 1780: Nexting Labs, www.nextinglabs.com/
# Nexting Labs provides data science and machine learning consulting services, focusing on predictive analytics for social media, websites, and apps. They offer solutions like data mining, cleaning, and analysis to help small and mid-sized businesses gain actionable insights for revenue growth, lead generation, user acquisition, cost minimization, and AI tool development.
# Result:
# Tasks/Jobs: Data mining, Predictive analytics, Machine learning model development,  Data visualization
# Industry: Data science consulting
# Customers: Small and mid-sized businesses
#
# Confidence Interval: 9
# Reasoning: The company's website and description clearly indicate their focus on data science consulting, specifically mentioning predictive analytics and machine learning. The listed services and target customers align with this specialization.
#
# ******************************
# Processing 1781: PerVista AI, www.pervista.ai
# PerVista AI utilizes AI to analyze real-time video streams from surveillance cameras, aiming to identify the presence of firearms and proactively notify public safety authorities. This technology aims to prevent potential active shooter events by detecting threats before they escalate, thus improving public safety in various locations like schools, shopping centers, and other public venues.
# Result:
# Company: PerVista AI
# Wesbite: www.pervista.ai
# Description: PerVista AI utilizes AI to analyze real-time video streams from surveillance cameras, aiming to identify the presence of firearms and proactively notify public safety authorities. This technology aims to prevent potential active shooter events by detecting threats before they escalate, thus improving public safety in various locations like schools, shopping centers, and other public venues.
#
# Tasks/Jobs: Video analysis, Threat detection, Alerting, Public safety
# Industry: Security
# Customers: Schools, Shopping centers, Public venues, Law enforcement agencies
#
# Confidence Interval: 8
# Reasoning: The company's website clearly states their target industry and customers. The tasks/jobs are also derived from the description of the technology.
#
# ******************************
# Processing 1782: Keyflow, keyflow.space
# Keyflow is a user-friendly platform that allows users to create and deploy custom AI-powered workflows without requiring any coding experience. These workflows can automate various tasks within a business, from data analysis to customer service interactions.
# Result:
# Tasks/Jobs: Data analysis, Automation, Customer service, Workflow management
# Industry: Business automation
# Customers: Businesses, Startups, Enterprises
#
# Confidence Interval: 8
# Reasoning: The description highlights the ability to create and deploy custom AI workflows, indicating automation across various business functions. The targeting of businesses, startups, and enterprises is common for workflow automation solutions.
#
# ******************************
# Processing 1783: Drodat, drodat.com
# Drodat is an insurtech company that uses drones and AI to capture and analyze high-resolution images of properties, creating a visual database that helps insurers detect and prevent fraud, optimize underwriting, and manage risks. Their technology is particularly focused on the property insurance market, aiming to tackle the significant fraud problem estimated at $45 billion annually.
# Result:
# Tasks/Jobs: Property inspection, Fraud detection, Risk assessment, Underwriting optimization
# Industry: Insurance
# Customers: Insurance companies, Property owners
#
# Confidence Interval: 9
# Reasoning: The provided description directly outlines the technology's application and target user base.
#
# ******************************
# Processing 1784: JobQuest, jobquest.ai
# JobQuest is an AI-powered platform that streamlines the job search process by automating tasks like resume writing, job matching, and application submission. Their goal is to help job seekers find the right roles and advance their careers with greater ease.
# Result:
# Tasks/Jobs: Resume writing, Job matching, Application submission, Job search optimization
# Industry: Recruitment/Job Search
# Customers: Job Seekers, Career Changers
#
# Confidence Interval: 9
# Reasoning: The website and description clearly state that JobQuest automates tasks related to the job search process, making the target customers job seekers and the industry recruitment/job search.
#
# ******************************
# Processing 1785: ResearchVideos, www.researchvideos.net/
# ResearchVideos is a platform that publishes peer-reviewed scientific research videos across various disciplines. It aims to enhance knowledge transfer by providing a medium for scientists to share their research in a visually engaging format.
# Result:
# Tasks/Jobs: Video production, Scientific research communication, Knowledge dissemination, Peer review
# Industry: Scientific research
# Customers: Scientists, Researchers, Students
#
# Confidence Interval: 9
# Reasoning: The website clearly indicates a focus on scientific research, video production, and knowledge dissemination. The target customers are those involved in the scientific research process.
#
# ******************************
# Processing 1786: Aeon, aeonindustries.co
# Aeon develops advanced capabilities at scale for maximum deterrence. Aeon develops advanced capabilities at scale for maximum deterrence.  Description: Aeon is a company specializing in developing cutting-edge artificial intelligence solutions, primarily focused on enhancing security and defense capabilities. Their products and services aim to provide maximum deterrence by leveraging advanced AI technologies for threat detection, analysis, and response.
# Result:
# Tasks/Jobs: Threat detection,  Threat analysis,  Security response,  AI development
# Industry: Defense
# Customers: Governments, Military organizations
#
# Confidence Interval: 7
# Reasoning:  The company's website and description clearly state a focus on defense and security.  The tasks are inferred from the description's focus on deterrence and AI-powered solutions. While specific customer examples are not provided, the industry naturally points to government and military organizations as likely clients.
#
# ******************************
# Processing 1787: Fiber AI, www.fiber.ai/
# Fiber AI is an AI-powered marketing automation platform that automates the entire outbound sales process, including lead generation, research, and personalized outreach. It focuses on delivering highly effective marketing campaigns that achieve significantly higher open rates than industry standards.
# Result:
# Tasks/Jobs: Lead generation, Research, Outreach, Email marketing
# Industry: Marketing Automation
# Customers: Sales teams, Marketing teams, Business owners
#
# Confidence Interval: 9
# Reasoning: The website and description clearly state the platform's automation features and focus on lead generation, outreach, and personalized email marketing, which are core functions of marketing automation.
#
# ******************************
# Processing 1788: Tusk, usetusk.ai
# Tusk is an AI-powered coding assistant that automates bug fixing, resolving customer issues directly from tickets and generating pull requests. By streamlining this process, Tusk helps engineering teams improve customer satisfaction, reduce developer workload, and enhance efficiency.
# Result:
# Tasks/Jobs: Bug fixing, Code generation, Issue resolution, Pull request creation
# Industry: Software development
# Customers: Software developers, Engineering teams
#
# Confidence Interval: 9
# Reasoning: The website and description explicitly mention automating bug fixing, resolving customer issues, and generating pull requests, all of which are tasks related to software development. The target customers are also clearly stated as engineering teams and software developers.
#
# ******************************
# Processing 1789: DubPrime, www.dubprime.com/
# DubPrime is an AI-powered underwriting platform that uses alternative data to evaluate creditworthiness beyond traditional credit scores. This approach allows lenders to extend credit to a wider range of borrowers, promoting financial inclusion and expanding access to capital for underserved communities.
# Result:
# Tasks/Jobs: Credit risk assessment, Loan underwriting, Alternative data analysis, Financial inclusion
# Industry: Fintech
# Customers: Lenders, Borrowers, Financial institutions
#
# Confidence Interval: 9
# Reasoning:  The company's website and description clearly state its focus on AI-powered underwriting and alternative data, targeting lenders and borrowers.
#
# ******************************
# Processing 1790: Credit Pulse, www.creditpulse.com/
# Credit Pulse is a SaaS platform that uses AI to automate and enhance commercial credit risk management. It helps businesses streamline customer onboarding, minimize bad debt, and continuously monitor creditworthiness through an intuitive, data-driven platform.
# Result:
# Tasks/Jobs: Credit scoring, Risk assessment, Customer onboarding, Debt monitoring
# Industry: Financial Services
# Customers: Banks, Lenders, Financial Institutions
#
# Confidence Interval: 9
# Reasoning: The company's website and description clearly indicate a focus on commercial credit risk management, targeting financial institutions as their primary customer base. The tasks listed are core functions within credit risk management, further supporting this assessment.
#
# ******************************
# Processing 1791: Deal.ai, deal.ai
# Deal.ai is a company that provides AI-powered marketing solutions. Their platform leverages artificial intelligence to automate and optimize marketing tasks, including lead generation, content creation, and campaign management.
# Result:
# Company: Deal.ai
# Wesbite: deal.ai
# Description: Deal.ai is a company that provides AI-powered marketing solutions. Their platform leverages artificial intelligence to automate and optimize marketing tasks, including lead generation, content creation, and campaign management.
#
# Tasks/Jobs: Lead generation, Content creation, Campaign management, Marketing automation
# Industry: Marketing
# Customers: Businesses, Marketing agencies
#
# Confidence Interval: 9
# Reasoning: The description clearly states that Deal.ai provides AI-powered marketing solutions, focusing on automation and optimization of tasks like lead generation, content creation, and campaign management.  It's highly likely they cater to businesses and marketing agencies who require these services.
#
# ******************************
# Processing 1792: AI Magicx, aimagicx.com/
# AI Magicx is an AI-powered content creation platform that allows users to generate stunning images, logos, and articles with its suite of AI tools. Their offerings include an AI Image Generator, AI Article Generator, AI Logo Designer, AI Story Creator, and are developing an AI Chatbots community for users to create their own bots.
# Result:
# Tasks/Jobs: Image generation, Logo design, Article writing, Chatbot creation
# Industry: Content creation
# Customers: Marketers, Content creators, Businesses, Individuals
#
# Confidence Interval: 9
# Reasoning: The website and description clearly highlight AI-powered content creation as the core focus. The tasks are directly related to the offered tools, and the target audience is likely those who need content for various purposes.
#
# ******************************
# Processing 1793: Kynismos AI, www.kynismos.ai
# Kynismos AI is a company developing a human-centered AI system that prioritizes individual sovereignty and privacy in the digital age. Their goal is to create an AI that acts as a guardian and advocate, protecting personal data and empowering users while fostering a positive relationship between humans and AI.
# Result:
# Tasks/Jobs: Data privacy management, Identity verification, Digital security, User advocacy
# Industry: Privacy and Security
# Customers: Individuals, Organizations
#
# Confidence Interval: 7
# Reasoning:  While the company is focused on a broad concept of human-centered AI, the specific applications mentioned (sovereignty, privacy, data protection) point towards tasks in the security and privacy domain.  The target customer base is also likely to include individuals and organizations who are concerned with these issues.
#
# ******************************
# Processing 1794: Chamoy, www.chamoy.io/
# Chamoy is an AI-powered video interviewing platform that uses conversational intelligence to identify top candidates for businesses. The platform's flagship product, Ellie, conducts lifelike interviews and provides insights to help recruiters make more informed hiring decisions.
# Result:
# Tasks/Jobs: Interview scheduling, Interviewing, Candidate evaluation, Hiring recommendations
# Industry: Human Resources
# Customers: Recruiters, Hiring managers
#
# Confidence Interval: 9
# Reasoning: The company's website and description clearly focus on automating the interview process and providing insights to help recruiters make hiring decisions.
#
# ******************************
# Processing 1795: Signlz, www.signlz.co/
# Signlz is an AI-powered platform that simplifies and streamlines product development by automating PRD creation, technical specifications, and task breakdown. It integrates with popular task management tools like Jira, Asana, and Trello, allowing product teams to effortlessly move from vision to execution.
# Result:
# Tasks/Jobs: PRD creation, Technical specification writing, Task breakdown, Project management integration
# Industry: Product Development
# Customers: Product managers, Software engineers, Project managers
#
# Confidence Interval: 9
# Reasoning: The website and description clearly state the automation of PRD creation, technical specifications, and task breakdown. The integration with popular project management tools indicates a target audience of product teams.
#
# ******************************
# Processing 1796: OpenSphere, opensphere.ai/
# OpenSphere is an AI-powered platform designed to assist high-skilled legal immigrants in obtaining O1, EB1A, and EB2 NIW visas. It connects immigrants with qualified immigration lawyers through a marketplace, streamlining the visa application process and providing access to expert legal support.
# Result:
# Tasks/Jobs:  Visa application preparation, Legal documentation review, Immigration lawyer matching, Case management
# Industry: Immigration Law
# Customers: High-skilled legal immigrants
#
# Confidence Interval: 9
# Reasoning: The company explicitly states its focus on assisting high-skilled legal immigrants with specific visa types.  The tasks are derived from the services offered on the website, including legal document review, lawyer matching, and case management.
#
# ******************************
# Processing 1797: Etoile Foundry, etoile.sh
# Etoile Foundry is a software company that helps artists create, manage, and distribute their digital art securely and efficiently. Their platform provides tools for minting NFTs, managing wallets, and collaborating with other artists, all while focusing on user-friendliness and security.
# Result:
# Company: Etoile Foundry
# Wesbite: etoile.sh
# Description: Etoile Foundry is a software company that helps artists create, manage, and distribute their digital art securely and efficiently. Their platform provides tools for minting NFTs, managing wallets, and collaborating with other artists, all while focusing on user-friendliness and security.
#
# Tasks/Jobs: NFT minting, Digital art management, Wallet management, Artist collaboration
# Industry: Digital Art
# Customers: Digital Artists, NFT creators, Collectors
#
# Confidence Interval: 9
# Reasoning: The website and description clearly indicate the target audience and functionality.  The website itself features images and examples of the platform's use cases, further solidifying the understanding of its purpose.
#
# ******************************
# Processing 1798: nu, nuconsortium.xyz
# nu is a platform that leverages blockchain and AI technologies to create a more equitable and inclusive financial ecosystem. It aims to achieve this by fostering social engagement and promoting innovative financial solutions.
# Result:
# Tasks/Jobs: Financial transactions, Social engagement, Data analysis, Decentralized finance
# Industry: Financial Services
# Customers: Individuals, Businesses, Financial institutions
#
# Confidence Interval: 6
# Reasoning: The description mentions financial ecosystem, social engagement, and innovative financial solutions, which suggests a focus on financial services. The use of blockchain and AI technologies implies tasks related to transactions, data analysis, and potentially decentralized finance. The target customers likely include individuals, businesses, and financial institutions seeking innovative financial solutions.
#
# ******************************
# Processing 1799: Tecde, tecde.co
# Tecde is a B2B SaaS platform that leverages AI and computer vision to automate inventory counting for businesses. Their solution provides real-time inventory updates, anomaly detection, photo-based uploads, and AI-driven predictions, streamlining inventory management processes and improving efficiency.
# Result:
# Tasks/Jobs: Inventory counting, Anomaly detection, Stock predictions, Inventory management
# Industry: Retail/Supply Chain Management
# Customers: Warehouses, Retail stores, Distribution centers
#
# Confidence Interval: 9
# Reasoning: The description explicitly states that Tecde's solution focuses on automating inventory counting, mentioning features like real-time updates, anomaly detection, and predictions. These tasks are directly related to inventory management within retail and supply chain operations.
#
# ******************************
# Processing 1800: WhisperMD, whispermd.ai/
# WhisperMD is an AI-powered platform that automates clinical notes for healthcare providers. By analyzing patient dialogues, WhisperMD generates comprehensive and accurate notes, freeing up physicians' time for patient care.
# Result:
# Company: WhisperMD
# Wesbite: whispermd.ai/
# Description: WhisperMD is an AI-powered platform that automates clinical notes for healthcare providers. By analyzing patient dialogues, WhisperMD generates comprehensive and accurate notes, freeing up physicians' time for patient care.
#
# Tasks/Jobs: Clinical note generation, Transcription, Medical recordkeeping, Time saving
# Industry: Healthcare
# Customers: Physicians, Nurses, Healthcare providers
#
# Confidence Interval: 9
# Reasoning: The website clearly states that WhisperMD is an AI-powered platform for automating clinical notes. The target customers are healthcare providers, and the tasks are directly related to the automation of clinical documentation.
#
# ******************************
# Processing 1801: Ziymo, ziymo.com
# Ziymo is an AI-powered platform designed to streamline and optimize the government contracting process. Their technology helps businesses navigate complex regulations, find relevant opportunities, and submit winning bids through intelligent automation and data-driven insights.
# Result:
# Tasks/Jobs: Contract proposal writing, bid submission, compliance tracking, government opportunity research
# Industry: Government contracting
# Customers: Businesses seeking government contracts
#
# Confidence Interval: 9
# Reasoning: The description explicitly states Ziymo focuses on automating government contracting processes and providing insights for winning bids. This points to tasks related to proposal writing, bid submission, and compliance. The industry is clearly government contracting, and the target customers are businesses seeking government contracts.
#
# ******************************
# Processing 1802: DateDroid, www.datedroid.com
# DateDroid is an AI-powered service that analyzes dating profiles and provides personalized advice to help users improve their online presence and attract more matches. For a fee of $0.50 per profile, users can receive insightful suggestions tailored to their specific profile and dating goals.
# Result:
# Company: DateDroid
# Wesbite: www.datedroid.com
# Description: DateDroid is an AI-powered service that analyzes dating profiles and provides personalized advice to help users improve their online presence and attract more matches. For a fee of $0.50 per profile, users can receive insightful suggestions tailored to their specific profile and dating goals.
#
# Tasks/Jobs: Profile analysis, Content optimization, Match prediction, Dating advice
# Industry: Online dating
# Customers: Dating app users, singles
#
# Confidence Interval: 9/10
# Reasoning:  The website and description clearly state the target audience is dating app users, and the tasks relate directly to the improvement of dating profiles.
#
# ******************************
# Processing 1803: Sups, www.sups.ai/
# Sups is an AI-powered platform that helps students write college application essays by providing brainstorming, outlining, and revision guidance. Their goal is to democratize college admissions by leveling the playing field for students across the globe.
# Result:
# Tasks/Jobs: Essay brainstorming, Essay outlining, Essay revision, Essay feedback
# Industry: Education
# Customers: Students applying to college
#
# Confidence Interval: 9
# Reasoning: The website and description explicitly state that the platform focuses on helping students write college application essays. The provided tasks are directly related to this purpose.
#
# ******************************
# Processing 1804: Context Data, contextdata.ai/
# Context Data is a platform that simplifies data processing and ETL (Extract, Transform, Load) for Generative AI applications. It enables developers to easily connect various data sources, transform data, and load it into vector databases, all without writing code, allowing them to quickly build and maintain scalable data infrastructure for AI models.
# Result:
# Tasks/Jobs: Data Extraction, Data Transformation, Data Loading, Data Integration
# Industry: Generative AI
# Customers: AI Developers, Data Scientists
#
# Confidence Interval: 9
# Reasoning:  The website and description clearly indicate Context Data's focus on simplifying data processing for AI development, specifically mentioning ETL and vector databases. This aligns with the typical tasks involved in preparing data for generative AI models.
#
# ******************************
# Processing 1805: Nextstay, nextstay.ai
# Nextstay is a platform that connects landlords, tenants, and subtenants for hassle-free subleasing. It offers a safe and secure marketplace for verified subleases, simplifying the process of finding and renting a sublet.
# Result:
# Tasks/Jobs: Sublease listing management, Tenant screening, Payment processing, Communication facilitation
# Industry: Real Estate
# Customers: Landlords, Tenants, Subtenants
#
# Confidence Interval: 8
# Reasoning: The website and description clearly state that Nextstay connects landlords, tenants, and subtenants for subleasing. The tasks/jobs listed are all essential for this process.
#
# ******************************
# Processing 1806: inPlace, www.inplace.ai
# inPlace is an AI-powered platform that helps businesses design, manage, and optimize their physical spaces. inPlace leverages computer vision and spatial analysis to create digital twins of spaces, allowing for virtual furniture placement, space planning, and dynamic layout adjustments.
# Result:
# Tasks/Jobs: Furniture placement, Space planning, Layout optimization, 3D modeling
# Industry: Interior Design and Architecture
# Customers: Architects, Interior Designers, Real Estate Developers
#
# Confidence Interval: 9
# Reasoning: The website and description clearly state the application of inPlace in the field of interior design and architecture. The tasks listed are directly related to these industries, and the targeted customers are those involved in these fields.
#
# ******************************
# Processing 1807: oneone AI, oneone.live
# Oneone AI is an AI-powered tool that helps managers understand and improve their relationships with their team members. The platform uses data from various sources, including communication logs and performance reviews, to provide insights into individual team member needs, preferences, and potential areas for growth.
# Result:
# Tasks/Jobs: Team communication analysis, Performance insights, Individual needs assessment, Growth potential identification
# Industry: Human Resources Management
# Customers: Managers, Team Leaders
#
# Confidence Interval: 8
# Reasoning:  The website and description clearly focus on using AI for team dynamics and performance improvement, which directly aligns with HR functions.
#
# ******************************
# Processing 1808: Felix Vita, www.felixvita.co/
# Felix Vita is a personalized health assistant app that focuses on preventive care, empowering users to log their daily activities, meals, exercise, and symptoms. By analyzing this data, Felix Vita provides personalized health recommendations, tracks habits, identifies patterns, sets goals, and helps users maintain accountability for better health habits.
# Result:
# Tasks/Jobs: Habit tracking, Goal setting, Data analysis, Personalized recommendations
# Industry: Health and Wellness
# Customers: Individuals, Consumers
#
# Confidence Interval: 9
# Reasoning: The website and description clearly indicate the app's focus on personalized health and habit tracking, making these tasks and the health and wellness industry highly likely.  The customer base is also likely to be individuals seeking to improve their health and wellbeing.
#
# ******************************
# Processing 1809: Cognition, www.cognition-labs.com
# Cognition is a company that provides AI-powered tools and solutions for reasoning and code generation. They offer a range of products, including a powerful code generator and a sophisticated reasoning engine, designed to empower developers and businesses with cutting-edge AI capabilities.
# Result:
# Tasks/Jobs: Code generation, Reasoning, Problem-solving, AI development
# Industry: Software Development
# Customers: Developers, Businesses
#
# Confidence Interval: 9
# Reasoning: The company's website and description explicitly state they focus on AI-powered tools for reasoning and code generation. These functionalities are targeted towards developers and businesses looking to leverage AI for software development.
#
# ******************************
# Processing 1810: Shopsense, www.shopsense.ai
# Shopsense is an AI platform designed to enhance retail media experiences by transforming content into interactive and shoppable journeys. The platform leverages AI to understand consumer behavior and preferences, allowing retailers to personalize product recommendations and create engaging shopping experiences.
# Result:
# Tasks/Jobs: Product recommendations, Content personalization, Interactive shopping experiences, Customer engagement
# Industry: Retail media
# Customers: Retailers, E-commerce businesses
#
# Confidence Interval: 9
# Reasoning: The description clearly indicates Shopsense is focused on enhancing retail media experiences through AI-powered personalization and interactivity. The website further confirms this by showcasing solutions tailored to retailers and e-commerce businesses.
#
# ******************************
# Processing 1811: Colega AI, www.colega.ai
# Colega AI is an AI-powered social media management platform specifically designed for small and medium-sized businesses. It streamlines social media marketing by automating tasks, building an online presence, and eliminating the need for expensive marketers.
# Result:
# Tasks/Jobs: Content creation, Social media scheduling, Audience engagement, Campaign optimization
# Industry: Social Media Marketing
# Customers: Small and medium-sized businesses
#
# Confidence Interval: 9
# Reasoning:  The description clearly states the platform is designed for social media management specifically for SMBs, outlining automation of core tasks.
#
# ******************************
# Processing 1812: Snef, snef.co
# Snef is a platform that utilizes artificial intelligence to personalize the shopping experience. The company aims to revolutionize online shopping by connecting consumers with products and brands that align with their individual lifestyle preferences.
# Result:
# Tasks/Jobs: Product recommendation, Personalized shopping experience, Lifestyle analysis,  Targeted advertising
# Industry: E-commerce
# Customers: Online shoppers, Retailers, Brands
#
# Confidence Interval: 8
# Reasoning: The description clearly indicates a focus on personalizing the online shopping experience, suggesting tasks related to product recommendation and lifestyle analysis.  The target customers are likely online shoppers, retailers, and brands who benefit from personalized experiences.
#
# ******************************
# Processing 1813: The Credit Genius App, creditgeniusapp.com/
# The Credit Genius App is a mobile app that helps users improve their credit score through gamified education, personalized AI coaching, and real-time financial data integration. The app aims to make credit score management more engaging and effective by combining interactive learning with AI-powered insights.
# Result:
# Company: The Credit Genius App
# Wesbite: creditgeniusapp.com/
# Description: The Credit Genius App is a mobile app that helps users improve their credit score through gamified education, personalized AI coaching, and real-time financial data integration. The app aims to make credit score management more engaging and effective by combining interactive learning with AI-powered insights.
#
# Tasks/Jobs: Credit score monitoring, Credit education, Debt management, Personalized financial advice
# Industry: Personal finance
# Customers: Individuals, Consumers
#
# Confidence Interval: 9
# Reasoning: The app's description clearly indicates its focus on credit score improvement, which falls under personal finance. The tasks and customers are also directly related to this core function.
#
# ******************************
# Processing 1814: TVADS.ai, tvads.ai
# TVADS.ai is a platform that specializes in helping direct-to-consumer (DTC) brands achieve better performance results through streaming television advertising. They utilize advanced technology and data insights to optimize ad campaigns, target the right audiences, and track campaign effectiveness across various streaming platforms.
# Result:
# Company: TVADS.ai
# Wesbite: tvads.ai
# Description: TVADS.ai is a platform that specializes in helping direct-to-consumer (DTC) brands achieve better performance results through streaming television advertising. They utilize advanced technology and data insights to optimize ad campaigns, target the right audiences, and track campaign effectiveness across various streaming platforms.
#
# Tasks/Jobs: Ad campaign optimization, Audience targeting, Campaign performance tracking, Streaming TV advertising
# Industry: Digital advertising
# Customers: Direct-to-consumer (DTC) brands
#
# Confidence Interval: 9
# Reasoning: The description clearly states that TVADS.ai focuses on helping DTC brands with their streaming TV advertising, implying tasks related to optimization, targeting, tracking, and advertising itself. The industry is undoubtedly digital advertising, as the platform utilizes technology and data for advertising.
#
# ******************************
# Processing 1815: eDNA Explorer, www.ednaexplorer.org
# eDNA Explorer is a cloud-based platform that leverages environmental DNA (eDNA) technology to provide actionable insights into biodiversity. The platform combines eDNA sequencing with geospatial data and AI algorithms to track biodiversity health, predict environmental changes, and inform decision-making in industries like agriculture, pharmaceuticals, and conservation.
# Result:
# Tasks/Jobs: Biodiversity monitoring, Environmental impact assessment, Species distribution mapping, Conservation planning
# Industry: Environmental monitoring
# Customers: Environmental agencies, Conservation organizations, Pharmaceutical companies, Agricultural businesses
#
# Confidence Interval: 8
# Reasoning: The website and description clearly indicate the platform's focus on biodiversity monitoring and the industries involved. The customer list is derived from the stated applications of the technology.
#
# ******************************
# Processing 1816: Barricade AI, barricade.tech
# Barricade AI is a company that utilizes multimodal generative AI to enhance public safety. Their platform analyzes various data sources, including text, images, and audio, to identify potential threats and provide actionable insights to law enforcement agencies.
# Result:
# Tasks/Jobs: Threat detection, Risk assessment,  Incident response, Predictive policing
# Industry: Public safety
# Customers: Law enforcement agencies, Security firms, Government agencies
#
# Confidence Interval: 8
# Reasoning: The provided description clearly indicates Barricade AI's focus on public safety through AI-powered threat analysis and insights for law enforcement.
#
# ******************************
# Processing 1817: FunFuseGames, funfusegames.com/
# FunFuseGames is a mobile game development company that creates a variety of games across multiple genres, including casual, puzzle, card, board, and word games. They focus on creating immersive and engaging experiences tailored to different player preferences.
# Result:
# Tasks/Jobs: Game design, Game development, Game testing, Game marketing
# Industry: Mobile game development
# Customers: Mobile game players, Mobile game publishers
#
# Confidence Interval: 8
# Reasoning: The company's website and description clearly indicate their focus on mobile game development and the types of tasks involved. The target customers are easily inferred from their game genres and focus on immersive experiences.
#
# ******************************
# Processing 1818: InstaHeadshots, instaheadshots.com/
# InstaHeadshots is an online platform that uses AI to transform selfies into professional-looking headshots. The service is designed to be quick and affordable, offering a variety of options for personal branding and professional networking.
# Result:
# Tasks/Jobs: Headshot creation, Photo editing, Background removal, Image enhancement
# Industry: Photography
# Customers: Individuals, Professionals, Businesses
#
# Confidence Interval: 9
# Reasoning: The company's website and marketing materials clearly indicate a focus on creating professional-looking headshots from selfies using AI. This points to the tasks listed above and the target customer base. The photography industry is the logical fit for a service that specializes in headshots.
#
# ******************************
# Processing 1819: FoundationFlow, foundationflow.ai
# FoundationFlow is a B2B platform that simplifies the management of multi-modal large language models (LLMs), allowing businesses to build and deploy generative AI workflows faster, more securely, and cost-effectively. The platform offers advanced capabilities that significantly reduce training costs and resources, enhancing efficiency and scalability for enterprises.
# Result:
# Tasks/Jobs: LLM Management, Generative AI workflow development, AI model training, AI model deployment
# Industry: Artificial Intelligence (AI)
# Customers: Businesses, Enterprises
#
# Confidence Interval: 9
# Reasoning: The description explicitly states FoundationFlow is a B2B platform for businesses. The platform's focus on simplifying LLM management and workflow development aligns with AI-focused businesses.
#
# ******************************
# Processing 1820: Dheyo AI, www.dheyo.ai
# Dheyo AI provides an AI-powered optimization and data orchestration platform designed to accelerate the performance of Retrieval Augmented Generation (RAG) and inference systems. Their technology operates at the hardware level to deliver significant speed and efficiency improvements.
# Result:
# Company: Dheyo AI
# Wesbite: www.dheyo.ai
# Description: Dheyo AI provides an AI-powered optimization and data orchestration platform designed to accelerate the performance of Retrieval Augmented Generation (RAG) and inference systems. Their technology operates at the hardware level to deliver significant speed and efficiency improvements.
#
# Tasks/Jobs: Model optimization, Data orchestration, Inference acceleration, RAG system performance enhancement
# Industry: AI & Machine Learning
# Customers: AI researchers, Developers, Enterprise AI deployments
#
# Confidence Interval: 8
# Reasoning: The description clearly points to AI optimization and data orchestration, implying tasks like model optimization, data management, and inference acceleration. The target customers would likely be those using RAG and inference systems, including researchers, developers, and companies deploying AI.
#
# ******************************
# Processing 1821: Formloge, www.formloge.com
# Formloge is a SaaS platform that enables experts to create custom, user-friendly ERPs without coding, specifically designed to simplify form-intensive processes like tax filings, immigration applications, and other regulated procedures. This AI-powered platform aims to reduce errors, improve user experiences, and empower SMEs to automate and scale their form-based operations.
# Result:
# Company: Formloge
# Wesbite: www.formloge.com
# Description: Formloge is a SaaS platform that enables experts to create custom, user-friendly ERPs without coding, specifically designed to simplify form-intensive processes like tax filings, immigration applications, and other regulated procedures. This AI-powered platform aims to reduce errors, improve user experiences, and empower SMEs to automate and scale their form-based operations.
#
# Tasks/Jobs: Form creation, Data automation,  Process optimization, Workflow management
# Industry: Business process automation
# Customers: Accountants, Lawyers, Immigration consultants, SMEs
#
# Confidence Interval: 9
# Reasoning:  The website and description clearly indicate the platform's focus on form creation, automation, and business process optimization.  The target customers are also evident from the examples of form-intensive processes mentioned.
#
# ******************************
# Processing 1822: Zentarim Corp., zentarim.xyz/
# Zentarim Corp provides a blockchain-based logistics platform designed to improve efficiency and cost-effectiveness in global goods transportation. The company aims to empower individuals by offering a reliable and accessible way to ship essential goods, particularly focusing on computer parts, amidst inflationary pressures.
# Result:
# Company: Zentarim Corp.
# Wesbite: zentarim.xyz/
# Description: Zentarim Corp provides a blockchain-based logistics platform designed to improve efficiency and cost-effectiveness in global goods transportation. The company aims to empower individuals by offering a reliable and accessible way to ship essential goods, particularly focusing on computer parts, amidst inflationary pressures.
#
# Tasks/Jobs: Tracking shipments, Payment processing, Inventory management, Route optimization
# Industry: Logistics
# Customers: Individuals, Computer Parts Retailers, Businesses shipping goods globally
#
# Confidence Interval: 8
# Reasoning: The website and description explicitly state the focus on blockchain-based logistics, global goods transportation, and computer parts. This suggests a targeting of individuals and businesses involved in these activities.
#
# ******************************
# Processing 1823: Linnk, linnk.ai
# Linnk.ai is an AI-powered research tool that simplifies reading and understanding of complex text by creating clickable summaries, highlighting key arguments, and organizing data for easy comprehension. Linnk.ai also supports multilingual users, allowing them to seamlessly switch between languages and ensuring a smooth reading experience.
# Result:
# Tasks/Jobs: Text summarization, Data extraction, Argument identification, Language translation
# Industry: Research and analysis
# Customers: Researchers, Students, Professionals
#
# Confidence Interval: 8
# Reasoning: The website and description clearly emphasize Linnk.ai's focus on simplifying research and understanding complex text. The listed features directly support these tasks and indicate a target audience of individuals and professionals involved in research and analysis.
#
# ******************************
# Processing 1824: PensarAI, www.pensarai.com
# PensarAI is a B2B SaaS platform that provides identity access management (IAM) solutions. Their AI-powered technology correlates identity data from various sources to enhance security, identify potential risks, and improve overall access management.
# Result:
# Company: PensarAI
# Wesbite: www.pensarai.com
# Description: PensarAI is a B2B SaaS platform that provides identity access management (IAM) solutions. Their AI-powered technology correlates identity data from various sources to enhance security, identify potential risks, and improve overall access management.
#
# Tasks/Jobs:  Identity verification, Access control, Risk assessment, Security auditing
# Industry:  Cybersecurity
# Customers:  Large enterprises, Government agencies, Financial institutions
#
# Confidence Interval: 9
# Reasoning: The website clearly states PensarAI focuses on IAM solutions with AI for security and risk management. Their target customers are likely organizations with complex security needs, which aligns with the typical clientele for cybersecurity solutions.
#
# ******************************
# Processing 1825: Spend Ninja, spendninaj.com
# Spend Ninja is a mobile app that aims to simplify personal finance management by combining budget tracking and transaction monitoring with engaging educational content. The app's goal is to make managing money more enjoyable and accessible to users of all financial backgrounds.
# Result:
# Company: Spend Ninja
# Wesbite: spendninaj.com
# Description: Spend Ninja is a mobile app that aims to simplify personal finance management by combining budget tracking and transaction monitoring with engaging educational content. The app's goal is to make managing money more enjoyable and accessible to users of all financial backgrounds.
#
# Tasks/Jobs: Budget tracking, Transaction monitoring, Financial education, Spending analysis
# Industry: Personal Finance
# Customers: Individuals, Consumers
#
# Confidence Interval: 9
# Reasoning: The description clearly states the app's focus on personal finance management, budgeting, and education. These features are targeted at individual consumers.
#
# ******************************
# Processing 1826: Bezoku, www.bezoku.ai
# Bezoku is a company developing AI-powered software focused on improving user experiences and efficiency. Their current focus is on optimizing the process of managing and configuring servers, aiming to simplify and streamline this complex task.
# Result:
# Tasks/Jobs: Server configuration, Server management, Automation,  Performance optimization
# Industry: IT infrastructure management
# Customers: IT professionals, System administrators, DevOps engineers
#
# Confidence Interval: 8
# Reasoning: The description clearly states that Bezoku focuses on server management and automation, which aligns with IT infrastructure management. The target customer base is likely IT professionals who deal with these tasks.
#
# ******************************
# Processing 1827: Rocket Coach, rocketcoach.ai
# Rocket Coach is an AI-powered coaching platform that combines personalized guidance with human interaction. Through its algorithm, Rocket Coach provides tailored coaching experiences that support users in reaching their personal and professional goals.
# Result:
# Company: Rocket Coach
# Wesbite: rocketcoach.ai
# Description: Rocket Coach is an AI-powered coaching platform that combines personalized guidance with human interaction. Through its algorithm, Rocket Coach provides tailored coaching experiences that support users in reaching their personal and professional goals.
#
# Tasks/Jobs: Goal setting, Progress tracking, Personalized feedback, Motivation
# Industry: Coaching and Personal Development
# Customers: Individuals, Teams, Businesses
#
# Confidence Interval: 8
# Reasoning: The website and description clearly indicate a focus on personalized coaching, utilizing AI for goal setting, progress tracking, and feedback. This points towards a coaching and personal development industry with individuals, teams, and businesses as potential customers.
#
# ******************************
# Processing 1828: Supply Pay, supplypaytx.com
# Supply Pay is a fintech platform specializing in cross-border trade financing, primarily between US importers and Latin American exporters. They use technology to assess risk and facilitate secure financing while offering customers real-time insights and monitoring of their trading partners, ultimately improving cash flow and promoting business growth.
# Result:
# Company: Supply Pay
# Wesbite: supplypaytx.com
# Description: Supply Pay is a fintech platform specializing in cross-border trade financing, primarily between US importers and Latin American exporters. They use technology to assess risk and facilitate secure financing while offering customers real-time insights and monitoring of their trading partners, ultimately improving cash flow and promoting business growth.
#
# Tasks/Jobs: Risk assessment, Trade financing, Cash flow management, Business monitoring
# Industry:  Cross-border trade finance
# Customers: US importers, Latin American exporters
#
# Confidence Interval: 9
# Reasoning: The website and description clearly outline the company's focus on facilitating cross-border trade financing. The tasks and customers are directly related to this core offering.
#
# ******************************
# Processing 1829: Youkeeps, youkeeps.com/
# Youkeeps is a corporate scheduling tool that streamlines meeting coordination, automating the process of finding common available time slots for participants across different time zones and individual preferences. Youkeeps leverages AI to significantly reduce the time spent on scheduling meetings, ultimately increasing productivity and minimizing frustration for employees.
# Result:
# Tasks/Jobs: Meeting scheduling, Time zone management, Calendar integration, Meeting optimization
# Industry: Meeting scheduling
# Customers: Teams, Organizations, Businesses
#
# Confidence Interval: 9
# Reasoning: The website and description clearly focus on automating meeting scheduling and highlighting the benefits of time management across different time zones. The targeted customer base is easily inferred from the context.
#
# ******************************
# Processing 1830: Type AI Technologies, www.typeai.live
# Type AI Technologies is a platform that simplifies DeFi transactions by allowing users to execute complex actions, like swapping, staking, and lending, through natural language text or voice commands. The platform leverages AI to streamline the process, finding the best rates and executing transactions seamlessly.
# Result:
# ...
# Result:
# Tasks/Jobs: Workspace booking, Desk reservation, Meeting room scheduling, Collaboration space access
# Industry: Workspace Management
# Customers: Freelancers, Remote workers, Entrepreneurs, Students
#
# Confidence Interval: 8
# Reasoning: The description clearly focuses on providing access to on-demand workspaces. The tasks listed are directly related to managing and accessing these spaces. The target customers are individuals who need flexible and readily available work options.
#
# ******************************
# Processing 2177: Giz Inc., www.giz.ai
# Giz Inc. provides an all-in-one productivity platform that combines AI-powered collaborative notes and cloud storage with an AI assistant. The platform aims to simplify workflows by integrating these features with intelligent automation capabilities.
# Result:
# Company: Giz Inc.
# Wesbite: www.giz.ai
# Description: Giz Inc. provides an all-in-one productivity platform that combines AI-powered collaborative notes and cloud storage with an AI assistant. The platform aims to simplify workflows by integrating these features with intelligent automation capabilities.
#
# Tasks/Jobs:  Task automation, Note taking,  Data organization,  Content generation
# Industry: Productivity
# Customers: Professionals, Teams, Businesses
#
# Confidence Interval: 8
# Reasoning: The platform description clearly indicates a focus on productivity enhancement through AI-powered tools. The listed features suggest automation of tasks, note-taking, data organization, and content generation, which are all relevant to professional and business workflows.
#
# ******************************
# Processing 2178: Vison AI, vison.ai/
# Vison AI is a content creation tool powered by AI that helps individuals and businesses generate various types of content, including blog posts and social media content. It offers a variety of templates, features, and tools to streamline the content creation process and save time and resources.
# Result:
# Tasks/Jobs: Content generation, Blog post writing, Social media posting, Content editing
# Industry: Content creation
# Customers: Individuals, Businesses, Marketers
#
# Confidence Interval: 9
# Reasoning: The website and description clearly state that Vison AI is a content creation tool designed for individuals and businesses.
#
# ******************************
# Processing 2179: Building, building.inc
# Building is a platform that tokenizes real estate, allowing investors to buy and sell fractional ownership of properties through digital tokens. The platform leverages data analytics and advanced validation processes to ensure transparency, liquidity, and trust in the real estate market.
# Result:
# Tasks/Jobs: Fractional ownership management, Real estate investment, Digital token trading, Data analytics
# Industry: Real Estate Investment
# Customers: Investors, Real estate developers
#
# Confidence Interval: 9
# Reasoning: The provided description explicitly mentions tokenized real estate, fractional ownership, and digital tokens, which directly point to these tasks and the real estate industry.  The target customers are likely investors seeking alternative investment opportunities and developers looking to utilize the platform for their projects.
#
# ******************************
# Processing 2180: Mio, justmio.com/
# Mio is an AI-powered journaling app designed to help users reflect on their day, set intentions, and track their progress towards personal goals. It leverages AI to provide personalized insights, prompts, and guidance for a more mindful and intentional life.
# Result:
# Tasks/Jobs:  Journaling, Goal Setting, Reflection, Self-improvement
# Industry: Personal Development
# Customers: Individuals seeking self-improvement, mindfulness, and goal tracking
#
# Confidence Interval: 9
# Reasoning:  The website and description clearly indicate the app's focus on personal development through journaling, goal setting, and reflection. The AI aspect suggests personalized guidance, further aligning with self-improvement. The target customer is readily identified as individuals seeking these benefits.
#
# ******************************
# Processing 2181: Just Banter, justbanter.ai/
# Just Banter is an AI-powered platform that allows content creators to generate passive income by creating digital twin chatbots. These chatbots interact with fans 24/7, providing a consistent income stream for the creators through paid interactions.
# Result:
# Tasks/Jobs: Chatbot creation, Content generation, Audience engagement, Monetization
# Industry: Content Creation
# Customers: Content creators, Influencers
#
# Confidence Interval: 8
# Reasoning: The website clearly states that Just Banter is for content creators and focuses on creating chatbots for audience interaction. This suggests a strong focus on the content creation industry.
#
# ******************************
# Processing 2182: Rivio, www.rivio.ai/
# Rivio is an AI-powered procurement platform specifically designed for hardware companies. It automates tasks like BOM cost estimation, supplier sourcing, and negotiation, leveraging historical data and real-time market insights to streamline the procurement process and optimize pricing.
# Result:
# Tasks/Jobs: BOM cost estimation, Supplier sourcing, Negotiation, Procurement optimization
# Industry: Hardware manufacturing
# Customers: Hardware companies, OEMs (Original Equipment Manufacturers)
#
# Confidence Interval: 9
# Reasoning: The company's website clearly states its focus on hardware companies and the specific tasks it automates.
#
# ******************************
# Processing 2183: Sciforium, sciforium.com
# Sciforium specializes in developing and deploying cutting-edge AI models, focusing on enhancing efficiency, protecting user privacy, and maximizing model versatility. Their platform provides access to these models for various applications, enabling users to leverage advanced AI capabilities in their specific domains.
# Result:
# Tasks/Jobs: Model training, Model deployment, Data analysis,  Automated decision making
# Industry: AI Solutions
# Customers: Researchers, Developers, Businesses
#
# Confidence Interval: 7
# Reasoning: The description highlights AI model development and deployment, suggesting applications in research, development, and business contexts. However, the specifics of the models and their targeted use cases are not explicitly mentioned.
#
# ******************************
# Processing 2184: BaseForge Inc., baseforge.co
# BaseForge Inc. is a company that provides AI advisory and incubation services. They help businesses integrate AI into their operations by offering strategic guidance, technology development, and thorough analysis to ensure tangible results.
# Result:
# Company: BaseForge Inc.
# Wesbite: baseforge.co
# Description: BaseForge Inc. is a company that provides AI advisory and incubation services. They help businesses integrate AI into their operations by offering strategic guidance, technology development, and thorough analysis to ensure tangible results.
#
# Tasks/Jobs: AI strategy development, AI technology integration, AI solution design, AI performance analysis
# Industry: AI consulting
# Customers: Businesses, Enterprises
#
# Confidence Interval: 8
# Reasoning: The description clearly indicates AI advisory and incubation services, which directly point towards consulting services for businesses integrating AI.  The mention of "tangible results" suggests a focus on real-world applications, hinting at enterprise customers.
#
# ******************************
# Processing 2185: Redacted Holdings, redactedholdings.co
# Redacted Holdings is a venture capital firm specializing in deep tech investments. They focus on mid-stage, growth, and pre-IPO companies, particularly in the sectors of American defense technology and national security.
# Result:
# Company: Redacted Holdings
# Wesbite: redactedholdings.co
# Description: Redacted Holdings is a venture capital firm specializing in deep tech investments. They focus on mid-stage, growth, and pre-IPO companies, particularly in the sectors of American defense technology and national security.
#
# Tasks/Jobs: Due diligence, Portfolio management, Investment strategy, Deal negotiation
# Industry: Venture Capital
# Customers: Deep tech startups, Defense technology companies, National security companies
#
# Confidence Interval: 9
# Reasoning: This information is directly inferred from the provided description of Redacted Holdings' specialization in deep tech investments, particularly in the American defense technology and national security sectors.
#
# ******************************
# Processing 2186: SupaLlama, www.supallama.ai
# SupaLlama is a SaaS platform that empowers businesses to build, test, and deploy AI-powered Retrieval Augmented Generation (RAG) applications without requiring specialized AI engineers. Its user-friendly interface simplifies the process, enabling users to leverage AI for tasks like knowledge base search, document summarization, and question answering.
# Result:
# Tasks/Jobs: Knowledge base search, document summarization, question answering, AI model deployment
# Industry: Natural Language Processing (NLP)
# Customers: Businesses, Developers
#
# Confidence Interval: 9
# Reasoning: The company's description clearly outlines these tasks/jobs, and the NLP industry is implied by the focus on AI-powered text processing applications. Customers are likely businesses seeking to integrate RAG into their workflows and developers building RAG applications.
#
# ******************************
# Processing 2187: Geolava, www.geolava.com
# Geolava is an AI-powered location intelligence platform that provides businesses with insightful data about places, locations, cities, and more. Using Geolava, businesses can gain a deeper understanding of location-based movements, access geospatial insights, and analyze imagery to uncover opportunities for growth and revenue generation.
# Result:
# Company: Geolava
# Wesbite: www.geolava.com
# Description: Geolava is an AI-powered location intelligence platform that provides businesses with insightful data about places, locations, cities, and more. Using Geolava, businesses can gain a deeper understanding of location-based movements, access geospatial insights, and analyze imagery to uncover opportunities for growth and revenue generation.
#
# Tasks/Jobs: Location analysis, Geospatial insights, Imagery analysis, Data visualization
# Industry: Location Intelligence
# Customers: Businesses, Real estate companies, Urban planners, Market researchers
#
# Confidence Interval: 9
# Reasoning: Geolava's website clearly states its focus on location intelligence and the specific features mentioned (location analysis, imagery analysis, etc.) directly point to the tasks being automated. The target customer base is also explicitly mentioned in the website copy and marketing materials.
#
# ******************************
# Processing 2188: Solatis, solatis.ai
# Solatis is an AI platform that seamlessly integrates with agent assistance applications to automate tasks, streamline workflows, and provide valuable data insights, ultimately boosting business efficiency. Solatis helps businesses across various departments, including customer support, sales, and executive management, by automating routine tasks and freeing up employees for more strategic work.
# Result:
# Company: Solatis
# Wesbite: solatis.ai
# Description: Solatis is an AI platform that seamlessly integrates with agent assistance applications to automate tasks, streamline workflows, and provide valuable data insights, ultimately boosting business efficiency. Solatis helps businesses across various departments, including customer support, sales, and executive management, by automating routine tasks and freeing up employees for more strategic work.
#
# Tasks/Jobs: Task automation, Workflow optimization, Data analysis, Agent assistance
# Industry: Business process automation
# Customers: Businesses, Customer support teams, Sales teams, Executive management teams
#
# Confidence Interval: 8
# Reasoning: The website and description clearly indicate Solatis targets businesses and aims to automate tasks and optimize workflows across different departments.
#
# ******************************
# Processing 2189: Degrees of Interest, www.degreesofinterest.com
# Degrees of Interest is a company that offers an AI-powered visual analytics platform designed to assist law enforcement in criminal investigations. Their tool helps investigators analyze complex data sets, uncover hidden patterns, and identify potential suspects, ultimately aiding in faster and more efficient crime resolution.
# Result:
# Tasks/Jobs: Data analysis, Pattern recognition, Suspect identification, Crime prediction
# Industry: Law Enforcement
# Customers: Police detectives, Investigators, Forensic analysts
#
# Confidence Interval: 9
# Reasoning: The company's website explicitly describes its target audience as law enforcement professionals and the tasks listed are directly related to the platform's AI-powered visual analytics capabilities.
#
# ******************************
# Processing 2190: AI Compliance, aicomply.ai
# AI Compliance provides an online audit tool to help organizations understand and manage compliance risks associated with their AI projects. Their Dynamic Knowledge Graph technology enables comprehensive audits across multiple jurisdictions, ensuring compliance with current and evolving regulations.
# Result:
# Company: AI Compliance
# Wesbite: aicomply.ai
# Description: AI Compliance provides an online audit tool to help organizations understand and manage compliance risks associated with their AI projects. Their Dynamic Knowledge Graph technology enables comprehensive audits across multiple jurisdictions, ensuring compliance with current and evolving regulations.
#
# Tasks/Jobs: Compliance auditing, Risk assessment, AI regulation monitoring, Data privacy compliance
# Industry: AI ethics and governance
# Customers: AI developers, Tech companies, Government agencies
#
# Confidence Interval: 9/10
# Reasoning:  The company's description clearly focuses on compliance for AI projects,  making the tasks, industry, and customer types logical deductions.
#
# ******************************
# Processing 2191: Robozaps, robozaps.com
# Robozaps is an online marketplace that connects buyers and sellers of humanoid robots. The platform features a wide selection of robots from leading brands like Tesla Optimus, Figure AI, UBTECH, and Boston Dynamics, allowing users to explore and purchase advanced robotic technology.
# Result:
# Company: Robozaps
# Wesbite: robozaps.com
# Description: Robozaps is an online marketplace that connects buyers and sellers of humanoid robots. The platform features a wide selection of robots from leading brands like Tesla Optimus, Figure AI, UBTECH, and Boston Dynamics, allowing users to explore and purchase advanced robotic technology.
#
# Tasks/Jobs: Robot search and filtering, Purchase and sale transactions, Delivery coordination, Customer support
# Industry: Robotics marketplace
# Customers: Businesses, Researchers, Individuals
#
# Confidence Interval: 9
# Reasoning: The company's website and description clearly indicate the focus on connecting buyers and sellers of humanoid robots. The tasks and customers are derived directly from this core functionality.
#
# ******************************
# Processing 2192: PrimeRole, www.primerole.com
# PrimeRole is a B2B Sales Intelligence platform designed to improve sales teams' efficiency. It utilizes AI to enhance prospecting, lead scoring, data enrichment, and engagement, ultimately leading to more effective outreach and streamlined sales processes.
# Result:
# Tasks/Jobs: Prospecting, Lead scoring, Data enrichment, Engagement
# Industry: Sales Intelligence
# Customers: Sales teams, Businesses
#
# Confidence Interval: 9
# Reasoning: The description explicitly states that PrimeRole is a B2B Sales Intelligence platform designed to improve sales team efficiency. The tasks listed are directly related to those functions.

# %%
def extract_data(text):
    if pd.isnull(text): return {}
    text = re.sub(r'\s+', ' ', text)  
    text = text.replace("_", "").replace("*", "").replace("#", "")
    text = re.sub(r'\s?\([^)]*\)', '', text)
    pattern = r".*?Tasks/Jobs:\s*(.*?)\s*Industry:\s*(.*?)\s*Customers:\s*(.*?)\s*Confidence Interval:\s*(.*?)\s*Reasoning:\s*(.*)"
    match = re.search(pattern, text, re.DOTALL)
    
    if match:
        tasks_jobs = match.group(1).strip()
        industry = match.group(2).strip()
        customers = match.group(3).strip()
        confidence_interval = match.group(4).strip()
        reasoning = match.group(5).strip()
        
        result = {
            "parsed_description": 
            "Tasks/Jobs: " + tasks_jobs + "\n" + "Industry: " + industry + "\n" + "Customers: "+ customers,
            "Tasks/Jobs": tasks_jobs,
            "Industry": industry,
            "Customers": customers,
            "parsed_description_conf_interval": confidence_interval,
            "parsed_description_conf_interval_reasoning": reasoning
        }
        
        return result
    else:
        print(text)
        print("FAILURE TO MATCH")
        return {}
        
for col in cols:
    if col in list(df.columns): df=df.drop(columns=[col])
        
results_df = pd.DataFrame(list(df.apply(lambda x: extract_data(x["parsed_description_llm"]),axis=1)))
df = pd.concat([df, results_df],axis=1)

# %%
df = df.dropna(subset=["parsed_description"],axis=0)
df = df.drop_duplicates(subset=['organization name'], keep='first')
df = df.reset_index(drop=True)

# %%
df.to_csv('../output/df_with_parsed_description.csv', index=False)

# %%
cols = ["situation1", "situation1_conf_interval", "situation1_conf_interval_reasoning", "situation2", "situation2_conf_interval", "situation2_conf_interval_reasoning","situation3", "situation3_conf_interval", "situation3_conf_interval_reasoning",'Example1','Job1','Job1_title','Example2','Job2','Job2_title','Example3','Job3','Job3_title']

args = [["company","organization name"],["website","website"], ["description","generated_description"], ["parsed_description","parsed_description"]]
df = prompting_class.iterate(df, examples_prompt, args, "examples_llm",1060)

df.to_csv('../output/df_with_examples.csv', index=False)
# Out:
# ******************************
# Processing 1060: OpsBeacon, opsbeacon.com
# OpsBeacon is a no-code SaaS platform designed to streamline and automate IT and cloud operations. It utilizes AI to orchestrate systems, automate tasks, and manage incident responses, enabling organizations to enhance productivity and security.
# Result:
# OpsBeacon Example Scenarios:
#
# Example 1: A DevOps engineer uses OpsBeacon to automatically deploy new code updates to a cloud-based application, ensuring consistent deployment processes and minimizing downtime.
#
# ONET JOB automated 1:  Software Developers who deploy software or program code to test or production environments (ONET 15-1199.00, Task ID 22-0107.01)
# ONET JOB 1:  Software Developers
# Confidence Interval 1: 9
# Reasoning 1:  The example directly relates to a core function of software developers, which OpsBeacon automates through its deployment orchestration capabilities.
#
# Example 2: An IT technician leverages OpsBeacon to automate routine system maintenance tasks, such as patching and updating servers, freeing up time for more complex troubleshooting and problem-solving.
#
# ONET JOB automated 2:  Computer Network Architects who monitor and evaluate network performance and troubleshoot network problems (ONET 15-1241.00, Task ID 22-0081.03)
# ONET JOB 2:  Computer Network Architects
# Confidence Interval 2: 8
# Reasoning 2:  While the example focuses on a general IT tech, it aligns with tasks commonly performed by network architects, showcasing how OpsBeacon can reduce their workload.
#
# Example 3: A cloud engineer uses OpsBeacon to trigger automated incident response workflows in case of system outages or security breaches, allowing for faster remediation and reduced impact on service availability.
#
# ONET JOB automated 3:  Computer and Information Systems Managers who analyze, evaluate, and develop procedures for resolving IT issues (ONET 11-3021.00, Task ID 22-0087.01)
# ONET JOB 3:  Computer and Information Systems Managers
# Confidence Interval 3: 7
# Reasoning 3: This example highlights how OpsBeacon can automate tasks usually performed by managers, allowing them to focus on strategic decision-making related to incident response.
#
# ******************************
# Processing 1061: Stackmatic.ai, stackmatic.ai
# Stackmatic.ai is an AI-powered platform that automates data entry tasks, freeing up employees to focus on higher-value work. Their solution promises to increase efficiency, boost morale, and improve data accuracy by handling data cleaning, manipulation, and automation.
# Result:
# Stackmatic.ai Example Use Cases
#
#
# Example 1: A customer service representative at a retail company uses Stackmatic.ai to automate the process of entering customer orders into the company's inventory system, freeing up time for handling customer inquiries and resolving issues.
# ONET JOB automated 1:  Data Entry Keyers that enter data into computer systems using keyboards.  [Task ID: 20.1.1.1.11]
# ONET JOB 1: Data Entry Keyers
# Confidence Interval 1: 9
# Reasoning 1:  This example directly describes automating data entry tasks, a core function of Data Entry Keyers.
#
# Example 2: A marketing analyst uses Stackmatic.ai to clean and manipulate data from multiple sources to identify trends in customer behavior, enabling them to develop more targeted marketing campaigns.
# ONET JOB automated 2: Market Research Analysts that analyze and interpret market research data. [Task ID: 13.1.1.1.5]
# ONET JOB 2: Market Research Analysts
# Confidence Interval 2: 8
# Reasoning 2: While the platform doesn't directly replace the analytical tasks of Market Research Analysts, it automates the pre-processing of data, a key step in their workflow.
#
# Example 3: A financial analyst uses Stackmatic.ai to automate the process of updating financial spreadsheets with real-time data from various sources, ensuring accuracy and reducing the risk of errors.
# ONET JOB automated 3: Financial Analysts that collect, analyze, and interpret financial information. [Task ID: 13.2.1.1.10]
# ONET JOB 3: Financial Analysts
# Confidence Interval 3: 7
# Reasoning 3: Stackmatic.ai automates data entry and manipulation tasks, which are often part of the financial information gathering and analysis process performed by financial analysts.
#
# ******************************
# Processing 1062: stylio.ai, stylio.ai
# Stylio.ai is an AI-driven platform that personalizes the shopping experience for fashion and beauty products. The platform recommends items based on user preferences and provides a curated selection of products, making it easier to find the perfect fit.
# Result:
# Stylio.ai Examples:
#
# Example 1:  A fashion retailer uses Stylio.ai to automatically generate personalized product recommendations for customers based on their browsing history and purchase preferences, helping them discover new items they might like.
#
# ONET JOB automated 1:  Market Research Analysts that gather, analyze, and interpret information about consumer behavior, product preferences, or market trends.
#
# ONET JOB 1: Market Research Analysts
#
# Confidence Interval 1: 8
#
# Reasoning 1: Stylio.ai's platform directly supports the task of gathering and analyzing information about consumer preferences, a core function of Market Research Analysts.
#
#
#
# Example 2: A customer uses Stylio.ai to create a personalized style profile, selecting their preferred brands, aesthetics, and sizes, allowing the platform to curate a curated selection of clothing and beauty products tailored to their individual style.
#
# ONET JOB automated 2:  Fashion Buyers that select merchandise for retail stores or other retail outlets.
#
# ONET JOB 2:  Fashion Buyers
#
# Confidence Interval 2: 7
#
# Reasoning 2: This task is similar to a fashion buyer's role in curating a selection of products based on specific criteria (in this case, the customer's preferences).
#
#
#
# Example 3: A consumer uses Stylio.ai to browse a curated selection of fashion and beauty products, leveraging the platform's AI-powered recommendations to refine their search and discover products they may not have found otherwise.
#
# ONET JOB automated 3:  Retail Salespersons that assist customers with selecting merchandise and advise customers on product features, uses, or benefits.
#
# ONET JOB 3:  Retail Salespersons
#
# Confidence Interval 3: 6
#
# Reasoning 3:  While not directly automating sales, Stylio.ai assists with the core function of product discovery and recommendation, similar to a salesperson's role in guiding a customer's purchase decisions.
#
# ******************************
# Processing 1063: Go Boldly, gobold.ly
# Go Boldly is a mobile app that provides personalized financial education for young adults. It utilizes AI and gamification to create engaging learning experiences that cater to individual financial goals and challenges, such as saving for a home, budgeting, or planning for college expenses.
# Result:
# Go Boldly Example Use Cases:
#
#
# Example 1:  A young adult uses Go Boldly to create a personalized budget plan that tracks their income and expenses, helping them identify areas for saving and manage their finances more effectively.
# ONET JOB automated 1: Financial Analysts that analyze financial data and prepare financial reports, statements, or projections.
# ONET JOB 1: Financial Analysts
# Confidence Interval 1: 7
# Reasoning 1:  While the app doesn't replace the full role of a Financial Analyst, it automates the basic budgeting and financial planning tasks that an analyst would guide a client through.
#
#
# Example 2:  A college student utilizes Go Boldly to set and track savings goals towards a down payment for a first apartment, visualizing progress and receiving personalized insights to stay on track.
# ONET JOB automated 2: Personal Financial Advisors that advise clients on financial matters, such as investments, insurance, and retirement planning.
# ONET JOB 2: Personal Financial Advisors
# Confidence Interval 2: 6
# Reasoning 2:  The app provides goal-setting and tracking features, similar to the basic advice and guidance a financial advisor would provide, especially for those with simpler financial needs.
#
#
# Example 3:  A young adult uses Go Boldly to create a customized plan for managing student loan debt, optimizing repayment strategies and exploring options like consolidation or refinancing.
# ONET JOB automated 3: Loan Officers who analyze credit histories and approve or decline loans.
# ONET JOB 3: Loan Officers
# Confidence Interval 3: 5
# Reasoning 3:  While the app provides educational resources and tools for debt management, it doesn't actually handle the loan applications or decisions made by a Loan Officer. However, it automates the information gathering and analysis that would normally be part of a loan officer's job.
#
# ******************************
# Processing 1064: Sloped, www.sloped.xyz/
# Sloped is a data platform that simplifies data analysis by allowing users to turn complex data queries into shareable, visually appealing dashboards. Through its intuitive search bar, users can easily generate new insights by searching through their data using plain text queries.
# Result:
# Sloped Examples:
#
# Example 1: A data analyst uses Sloped to quickly create an interactive dashboard showcasing key sales trends by region, replacing the tedious process of manually writing complex SQL queries and building visualizations.
# ONET JOB automated 1: Market Research Analysts that analyze data and prepare reports.
# ONET JOB 1: Market Research Analysts
# Confidence Interval 1: 8
# Reasoning 1: The tool automates data analysis and report generation, key tasks for market research analysts.
#
# Example 2: A business intelligence professional uses Sloped to search through customer data to find insights about user behavior patterns, identifying trends in purchasing habits and preferences through natural language queries.
# ONET JOB automated 2: Business Intelligence Analysts that analyze data to identify trends, patterns, and insights.
# ONET JOB 2: Business Intelligence Analysts
# Confidence Interval 2: 9
# Reasoning 2: This example directly relates to the core task of business intelligence analysts, who are responsible for data analysis and insight generation.
#
# Example 3: A researcher uses Sloped to create an interactive dashboard summarizing research data, allowing colleagues to easily explore findings and filter data based on different criteria.
# ONET JOB automated 3: Social Science Research Assistants that analyze data to summarize findings.
# ONET JOB 3: Social Science Research Assistants
# Confidence Interval 3: 7
# Reasoning 3: This example focuses on data analysis and visualization, which are key aspects of the role of a research assistant in social science fields.
#
# ******************************
# Processing 1065: SQDL, www.sqdl.ai
# SQDL is an AI-powered SaaS platform designed to simplify and automate ecommerce marketing. The platform leverages advanced AI to manage campaigns across various channels, optimizing for conversions and maximizing return on investment.
# Result:
# SQDL Examples:
#
# Example 1:
# An e-commerce marketer uses SQDL to create and manage targeted advertising campaigns across multiple platforms, automatically optimizing ad spend based on real-time performance data and customer engagement.
# ONET JOB automated 1: Marketing Specialists that create and implement marketing plans, including budgets, timelines, and activities.
# ONET JOB 1: Marketing Specialists
# Confidence Interval 1: 9
# Reasoning 1: This task is common for marketing specialists, and SQDL automates the optimization process, which is a key task for campaign management.
#
# Example 2:
# An online retailer utilizes SQDL to analyze customer data and identify new audience segments for targeted marketing campaigns, leveraging AI to personalize messaging and maximize conversion rates.
# ONET JOB automated 2: Market Research Analysts that analyze consumer behavior and preferences and identify new markets or products for the company.
# ONET JOB 2: Market Research Analysts
# Confidence Interval 2: 8
# Reasoning 2: While market research analysts have broader responsibilities, SQDL simplifies audience targeting, which is a key task in market research for marketing.
#
# Example 3:
# An e-commerce business employs SQDL to track the performance of its marketing campaigns across various channels, providing automated reporting on key metrics like conversion rates, customer lifetime value, and return on investment.
# ONET JOB automated 3: Marketing and Sales Coordinators that analyze data on sales performance, customer satisfaction, and marketing campaigns to identify trends, patterns, or areas for improvement.
# ONET JOB 3: Marketing and Sales Coordinators
# Confidence Interval 3: 7
# Reasoning 3: This example reflects a task that is performed by marketing and sales coordinators, and SQDL provides automated reporting, which is a common aspect of their role.
#
# ******************************
# Processing 1066: EzBusy, ezbusy.ai/
# EzBusy is a company that provides a suite of digital solutions for businesses, including website development, branding, and AI-powered automation. Their services aim to help businesses create compelling online presences and launch minimum viable products quickly and efficiently.
# Result:
# EzBusy Examples:
#
# Example 1:
# A startup founder uses EzBusy to create a basic website for their new business, including a homepage, about page, and contact form, streamlining the process of establishing an online presence.
# ONET JOB automated 1: Web Developers that design or develop user interfaces (UIs) for websites, including user navigation, visual layout, and interactivity.
# ONET JOB 1: Web Developers
# Confidence Interval 1: 8
# Reasoning 1: EzBusy aims to help businesses create compelling online presences quickly and efficiently, which aligns with the task of designing user interfaces for websites.
#
# Example 2:
# A small business owner utilizes EzBusy's AI-powered automation tools to generate marketing content, such as social media posts and email newsletters, saving time and resources on content creation.
# ONET JOB automated 2: Marketing Specialists that generate content for social media platforms, including copywriting, image selection, and video creation.
# ONET JOB 2: Marketing Specialists
# Confidence Interval 2: 7
# Reasoning 2: EzBusy offers AI-powered automation tools, which could encompass tasks such as generating social media posts or email newsletters, typically handled by Marketing Specialists.
#
# Example 3:
# An entrepreneur leverages EzBusy to build a minimum viable product (MVP) for their mobile app, rapidly prototyping and testing features with real users before investing in full-scale development.
# ONET JOB automated 3: Software Developers that develop or modify software applications, including design, coding, testing, and debugging.
# ONET JOB 3: Software Developers
# Confidence Interval 3: 6
# Reasoning 3: Although MVP development is not a specific ONET task, it involves rapid prototyping and testing, aligning with tasks typically performed by Software Developers.
#
# ******************************
# Processing 1067: Rubberband, rubberband.social
# Rubberband is a social media platform where users can create and share scrollable vlogs called "Bands." These "Bands" combine user-generated content with AI-powered features to enhance storytelling and engagement.
# Result:
# Here are three examples of how Rubberband's platform could be used, along with ONET job mapping:
#
# Example 1: A social media influencer uses Rubberband to automatically edit their "Bands," adding music, transitions, and captions, creating engaging content in minutes.
# ONET JOB automated 1: Video Editors that edit video content, including splicing, adding transitions, and creating special effects.
# ONET JOB 1: Video Editors
# Confidence Interval 1: 8
# Reasoning 1: This example directly maps to the tasks associated with video editing, which is a recognized job in ONET. The platform's automation of tasks like adding music and transitions aligns with the work of video editors.
#
# Example 2: A content creator leverages Rubberband's AI to analyze their "Bands" for audience engagement, identifying the most popular content formats and timing for maximum impact.
# ONET JOB automated 2: Social Media Managers that analyze social media data to understand audience demographics, preferences, and engagement patterns.
# ONET JOB 2: Social Media Managers
# Confidence Interval 2: 7
# Reasoning 2: While the exact task of analyzing "Bands" for engagement doesn't have a specific ONET code, the broader concept of analyzing social media data for insights falls within the realm of Social Media Managers.
#
# Example 3: A brand uses Rubberband to create interactive "Bands" that allow users to customize their experience, selecting different content paths or interactive elements, fostering deeper engagement with their products or services.
# ONET JOB automated 3:  Web Developers that develop interactive elements for websites, including dynamic content, quizzes, and user-generated content features.
# ONET JOB 3: Web Developers
# Confidence Interval 3: 6
# Reasoning 3: While "Bands" are not websites, the interactive features described in this example map to the tasks associated with web development. While the platform might not require traditional coding skills, the outcome is similar to what a web developer would achieve, creating a more engaging and interactive experience.
#
# ******************************
# Processing 1068: Tidby LLC, Tidby.app
# Tidby is a social news reader app that provides AI-powered concise summaries of current events from around the world. Users can personalize their news feed and create custom news rooms tailored to their interests, mood, and social circles.
# Result:
# Tidby LLC - Example Usage Scenarios
#
# Company: Tidby LLC
# Website: Tidby.app
# Current Description: Tidby is a social news reader app that provides AI-powered concise summaries of current events from around the world. Users can personalize their news feed and create custom news rooms tailored to their interests, mood, and social circles.
# Tasks/Jobs: News summarization, News curation, Personalization, Social sharing
# Industry: News consumption
# Customers: Individuals, News enthusiasts, Social media users
#
#
# Example 1:  A busy professional uses Tidby to stay informed about current events without having to read lengthy articles, saving them time by providing concise summaries of important news stories.
# ONET JOB automated 1:  News Analysts that summarize news stories for publication.
# ONET JOB 1: News Analysts
# Confidence Interval 1: 8
# Reasoning 1: Tidby's AI-powered summarization directly automates the task of summarizing news stories, a key function of News Analysts.
#
#
#
# Example 2: A news enthusiast uses Tidby to create a personalized newsroom with curated feeds from various sources, tailored to their interests in specific topics and regions, allowing them to focus on their desired news content.
# ONET JOB automated 2: News Analysts that select, evaluate, and summarize news stories.
# ONET JOB 2: News Analysts
# Confidence Interval 2: 8
# Reasoning 2: Tidby's personalized newsroom feature automates the selection and curation of news stories, a task typically performed by News Analysts.
#
#
#
# Example 3:  A social media user shares news stories from Tidby with their friends and family, engaging in discussions and sharing perspectives based on the concise summaries provided by the app.
# ONET JOB automated 3:  Social Media Specialists that share relevant content on social media platforms.
# ONET JOB 3: Social Media Specialists
# Confidence Interval 3: 7
# Reasoning 3: Tidby's social sharing functionality facilitates the sharing of news content, a task often undertaken by Social Media Specialists. While Tidby doesn't fully replace the broader role of a Social Media Specialist, it streamlines the sharing of news content specifically.
#
# ******************************
# Processing 1069: Apollon Upskilling Solutions, www.theapollon.ai
# Apollon Upskilling Solutions is an AI-powered platform that helps individuals and organizations prepare for the future of work. Their platform uses AI to identify skill gaps, recommend personalized learning pathways, and provide interactive training modules, ensuring users are equipped with the skills they need for success in a rapidly evolving job market.
# Result:
# Apollon Upskilling Solutions Examples:
#
# Example 1: A job seeker uses Apollon to analyze their current skills and identify gaps in their knowledge, allowing them to create a personalized learning plan for acquiring the skills needed for their desired career path.
#
# ONET JOB automated 1: Career Counselors that advise individuals on job opportunities and career development.
#
# ONET JOB 1: Career Counselors
#
# Confidence Interval 1: 8
#
# Reasoning 1: Apollon's platform automates the tasks traditionally performed by career counselors, such as analyzing skills and providing personalized recommendations for learning and career development.
#
#
#
# Example 2: An HR manager at a large organization leverages Apollon to identify skills gaps across their workforce and develop targeted training programs to ensure employees possess the necessary skills for future roles.
#
# ONET JOB automated 2: Training and Development Specialists that conduct training needs assessments to determine what training and development activities are needed.
#
# ONET JOB 2: Training and Development Specialists
#
# Confidence Interval 2: 9
#
# Reasoning 2: Apollon's platform automates the tasks of identifying skills gaps and creating training plans, which are typically performed by training and development specialists.
#
#
#
# Example 3: A college student uses Apollon to explore various career paths and discover the skills required for each profession. The platform then recommends personalized learning resources and courses aligned with their career goals.
#
# ONET JOB automated 3: Postsecondary Education Administrators that counsel students on career and educational planning.
#
# ONET JOB 3: Postsecondary Education Administrators
#
# Confidence Interval 3: 7
#
# Reasoning 3: Apollon's platform provides similar career guidance and personalized learning recommendations traditionally offered by postsecondary education administrators.
#
# ******************************
# Processing 1070: SureSteps, www.suresteps.io
# SureSteps is a customer service platform that utilizes AI to deliver personalized and efficient support to users. The platform provides interactive documentation, real-time assistance, and seamless integration with existing systems, empowering users with easy-to-access and effective support solutions.
# Result:
# SureSteps Examples:
#
# Example 1: A customer service representative uses SureSteps to access interactive documentation and resolve customer inquiries without needing to manually search through large knowledge bases or contact a supervisor.
# ONET JOB automated 1: Customer Service Representatives who provide information to customers regarding products, services, or company policies.
# ONET JOB 1: Customer Service Representatives
# Confidence Interval 1: 9
# Reasoning 1: The tool directly automates the task of providing information to customers, which is a core function of customer service representatives.
#
# Example 2: A software user encounters an error while working on a project and utilizes SureSteps to receive real-time assistance via an AI chatbot that guides them through troubleshooting steps, resolving the issue without needing to contact support.
# ONET JOB automated 2: Software Developers who provide technical support to users experiencing problems with software applications.
# ONET JOB 2: Software Developers
# Confidence Interval 2: 7
# Reasoning 2: While not a primary function of software developers, this example highlights a scenario where the tool provides technical support that could traditionally be handled by developers.
#
# Example 3: A business uses SureSteps to automate common customer service inquiries like password resets or order tracking, freeing up their human agents to focus on more complex issues requiring personalized support.
# ONET JOB automated 3: Customer Service Representatives who answer incoming calls, emails, or other inquiries from customers to provide information, resolve problems, or handle complaints.
# ONET JOB 3: Customer Service Representatives
# Confidence Interval 3: 8
# Reasoning 3: This scenario directly demonstrates how SureSteps automates tasks commonly handled by customer service representatives, freeing them up for more complex responsibilities.
#
# ******************************
# Processing 1071: Ventrilo.ai, ventrilo.ai/
# Ventrilo.ai is a stealth startup developing AI-powered solutions for software testing. Their technology likely aims to automate and enhance the testing process, making it more efficient and effective.
# Result:
# Ventrilo.ai Examples
#
# Company: Ventrilo.ai
# Website: ventrilo.ai/
# Current Description: Ventrilo.ai is a stealth startup developing AI-powered solutions for software testing. Their technology likely aims to automate and enhance the testing process, making it more efficient and effective.
# Tasks/Jobs: Test case generation, Test automation, Bug detection, Test reporting
# Industry: Software development
# Customers: Software developers, QA engineers
#
# Example 1:  A software developer uses Ventrilo to automatically generate comprehensive test cases for a new software feature, saving significant time and ensuring thorough testing coverage.
# ONET JOB automated 1: Software Developers, Quality Assurance Analysts that develop, write, and execute test plans, procedures, and scripts.
# ONET JOB 1: Software Developers
# Confidence Interval 1: 8
# Reasoning 1: Ventrilo is specifically aimed at software testing, and the example describes automating a key task performed by software developers and QA analysts.
#
# Example 2: A QA engineer utilizes Ventrilo to automate repetitive testing tasks, such as regression testing, freeing up time to focus on more complex and critical testing scenarios.
# ONET JOB automated 2: Software Developers, Quality Assurance Analysts that conduct tests to ensure quality and performance of software or applications.
# ONET JOB 2: Software Developers
# Confidence Interval 2: 8
# Reasoning 2: The example showcases a common task in software testing, and Ventrilo's automation capabilities directly address the need for efficiency in repetitive testing processes.
#
# Example 3:  A team of software developers uses Ventrilo to analyze test results and automatically identify potential bugs or performance issues, accelerating the bug-fixing process and improving software quality.
# ONET JOB automated 3: Software Developers, Quality Assurance Analysts that perform troubleshooting activities to isolate and resolve software or application defects.
# ONET JOB 3: Software Developers
# Confidence Interval 3: 7
# Reasoning 3: The example reflects Ventrilo's potential to aid in the bug detection and resolution process, a key responsibility of software developers and QA analysts.
#
# ******************************
# Processing 1072: AI Virtual Staging, www.virtualstaging.art
# AI Virtual Staging offers a service that utilizes artificial intelligence to digitally stage vacant properties. By adding virtual furniture, décor, and lighting, they create realistic, visually appealing images and 3D tours to help real estate agents market listings more effectively.
# Result:
# Here are three examples of how AI Virtual Staging might be used, along with ONET job mappings and confidence levels:
#
#
# Example 1: A real estate agent uses AI Virtual Staging to automatically generate realistic, furnished images of a vacant property, eliminating the need for physical staging and saving time and resources.
# ONET JOB automated 1: Real Estate Agents that prepare property for sale, including arranging for staging of property.
# ONET JOB 1: Real Estate Sales Agents
# Confidence Interval 1: 9
# Reasoning 1: This tool directly replaces the manual work involved in staging a property by real estate agents. The software handles the virtual staging process, which would otherwise involve hiring a staging company or spending time and resources on physical staging.
#
# Example 2: A property owner utilizes AI Virtual Staging to create a virtual tour of their empty home, allowing potential buyers to experience the space virtually and visualize its potential.
# ONET JOB automated 2: Real Estate Agents that conduct virtual tours of listed properties.
# ONET JOB 2: Real Estate Sales Agents
# Confidence Interval 2: 8
# Reasoning 2:  The AI Virtual Staging platform allows for the creation of 3D tours that would otherwise require the agent to manually conduct physical tours or use expensive 3D scanning technology.
#
# Example 3: An AI Virtual Staging platform automatically adjusts lighting and color tones in property photos to create more visually appealing images, highlighting the best features of the space.
# ONET JOB automated 3: Photographers that edit images to improve image quality, such as lighting, color correction, and cropping.
# ONET JOB 3: Photographers
# Confidence Interval 3: 7
# Reasoning 3: While real estate agents may use a photographer, the AI tool automates the process of photo editing to enhance visuals, reducing the need for the agent or photographer to spend time on this task.
#
# ******************************
# Processing 1073: HousMthr, housmthr.com/
# HousMthr is an AI-powered travel app designed specifically for groups, offering a comprehensive suite of tools to manage accommodation, experiences, and logistics. The app aims to streamline the group travel experience, ensuring a seamless and enjoyable stay for all.
# Result:
# HousMthr Examples:
#
# Example 1: A group organizer uses HousMthr to efficiently book accommodations for their travel group, comparing options, negotiating rates, and managing reservations across multiple platforms.
# ONET JOB automated 1: Travel Agents that book accommodations for clients, such as hotels, motels, bed and breakfasts, or resorts.
# ONET JOB 1: Travel Agents
# Confidence Interval 1: 8
# Reasoning 1: While the specific tasks may differ from traditional travel agents (i.e., comparison tools, negotiation), the overall function of finding and securing accommodation remains similar.
#
# Example 2: A group of friends uses HousMthr to collaboratively plan their trip itinerary, sharing ideas, managing activities, and allocating responsibilities for each day.
# ONET JOB automated 2: Travel Agents that plan itineraries for clients based on time constraints, budgets, interests, and travel style.
# ONET JOB 2: Travel Agents
# Confidence Interval 2: 7
# Reasoning 2: While not fully replacing the planning process, the app allows for collaborative creation and sharing of an itinerary, a key task of a travel agent.
#
# Example 3: A group leader utilizes HousMthr to track expenses for their group trip, including shared costs, individual spending, and payment reminders, streamlining the accounting process.
# ONET JOB automated 3: Travel Agents that handle financial transactions, including collecting payments, managing accounts, and reconciling expenses.
# ONET JOB 3: Travel Agents
# Confidence Interval 3: 6
# Reasoning 3: While the tool doesn't directly manage finances, it facilitates the tracking and organization of group expenses, a key component of financial management for travel agents.
#
# ******************************
# Processing 1074: Future in Quantum, futureinquantum.com/
# Future in Quantum is a technology blog that covers the latest trends and developments in the tech world, particularly focusing on quantum computing. It provides in-depth analysis, news, and reviews to help readers stay informed about the rapidly evolving field of quantum technology.
# Result:
# Here are three examples of how a product from Future in Quantum might be used, mapped to ONET jobs:
#
# Example 1:
# A quantum computing researcher uses the tool to analyze and synthesize data from a recent academic paper on quantum algorithms, identifying key findings and potential applications.
# ONET JOB automated 1: Market Research Analysts that review and evaluate published information, including professional journals, government publications, and trade journals.
# ONET JOB 1: Market Research Analysts
# Confidence Interval 1: 7
# Reasoning 1: The tool would automate the research analysis tasks, but it would still require a human to interpret the findings and apply them to their research.
#
# Example 2:
# A software developer leverages the tool to generate code for a new quantum simulation program, reducing development time and ensuring accuracy.
# ONET JOB automated 2: Software Developers that write, modify, and debug code to create, test, and implement software applications.
# ONET JOB 2: Software Developers
# Confidence Interval 2: 6
# Reasoning 2: The tool would help automate the code-generation process, but the developer would still need to review and debug the code.
#
# Example 3:
# A technology journalist utilizes the tool to generate a comprehensive overview of the latest advancements in quantum computing for a popular science magazine article, simplifying complex topics for a general audience.
# ONET JOB automated 3: Technical Writers that prepare instructional or technical manuals, specifications, training materials, or other documents that explain procedures or products.
# ONET JOB 3: Technical Writers
# Confidence Interval 3: 5
# Reasoning 3: While the tool could help generate content, the journalist would still need to fact-check, edit, and refine the final article.
#
# ******************************
# Processing 1075: Ainstein.com, ainstein.com
# Ainstein.com provides affordable and accessible AI-powered workers that can perform tasks autonomously, helping users boost their productivity and efficiency. The platform aims to empower individuals and businesses by democratizing access to AI technology and making it easier for everyone to utilize its capabilities.
# Result:
# Ainstein.com Examples
#
# Company: Ainstein.com
# Website: ainstein.com
# Current Description: Ainstein.com provides affordable and accessible AI-powered workers that can perform tasks autonomously, helping users boost their productivity and efficiency. The platform aims to empower individuals and businesses by democratizing access to AI technology and making it easier for everyone to utilize its capabilities.
# Tasks/Jobs: Data entry, Research, Content creation, Customer service
# Industry: AI-powered automation
# Customers: Individuals, Businesses, Startups
#
# Example 1: A freelance writer uses Ainstein's AI to automatically research and generate high-quality blog content based on provided keywords and target audience, saving them time and effort.
# ONET JOB automated 1: Writers and Authors that research topics or subjects to gather information for articles, books, or other written materials.
# ONET JOB 1: Writers and Authors
# Confidence Interval 1: 8
# Reasoning 1: Ainstein's AI is likely automating the research and initial writing process, tasks commonly done by writers.
#
# Example 2: A small business owner utilizes Ainstein to automate data entry tasks, such as uploading invoices and customer information into their accounting software, freeing up time for other business operations.
# ONET JOB automated 2: Data Entry Keyers that enter data into computer systems from a variety of sources, such as documents, forms, or databases.
# ONET JOB 2: Data Entry Keyers
# Confidence Interval 2: 7
# Reasoning 2: This aligns with the common use of AI for data entry tasks, automating a job traditionally done by data entry keyers.
#
# Example 3: A customer service representative uses Ainstein to automatically answer frequently asked questions from customers via chat, providing quick and accurate responses while allowing the representative to focus on more complex issues.
# ONET JOB automated 3: Customer Service Representatives that answer questions, resolve problems, and provide information to customers.
# ONET JOB 3: Customer Service Representatives
# Confidence Interval 3: 9
# Reasoning 3: Ainstein's AI likely automates the handling of basic customer inquiries, a common task for customer service representatives.
#
# ******************************
# Processing 1076: NonprofitsHQ, www.nonprofitshq.com
# NonprofitsHQ is a B2B SaaS platform designed specifically for nonprofits, offering a suite of AI-powered tools to streamline operations and boost efficiency. These tools cover areas such as grant management, fundraising, donor engagement, and communication, helping nonprofits save time and resources while maximizing their impact.
# Result:
# NonprofitsHQ Examples:
#
#
# Example 1: A development director at a nonprofit uses NonprofitsHQ to automate the process of identifying and researching potential grant opportunities, saving them time and allowing them to focus on building relationships with funders.
# ONET JOB automated 1:  Grant Writers that conduct research to identify potential grant opportunities.
# ONET JOB 1: Grant Writers
# Confidence Interval 1: 8
# Reasoning 1:  Grant Writers are typically involved in researching grant opportunities. While the tool may not replace all research, it can significantly automate the initial stage of finding potential opportunities.
#
# Example 2: A nonprofit utilizes NonprofitsHQ to manage its donor database, segmenting donors based on giving history and interests, and automating personalized email campaigns for increased engagement and retention.
# ONET JOB automated 2:  Fundraisers that maintain records of past contributions and other donor information.
# ONET JOB 2:  Fundraisers
# Confidence Interval 2: 9
# Reasoning 2:  The tool automates database management and segmentation, tasks typically performed by fundraisers.
#
# Example 3: A communications manager at a nonprofit uses NonprofitsHQ to create and schedule automated social media posts, streamlining their communication efforts and reaching a wider audience with impactful content.
# ONET JOB automated 3:  Public Relations Specialists that prepare and distribute press releases or news releases, or develop and maintain social media accounts.
# ONET JOB 3: Public Relations Specialists
# Confidence Interval 3: 7
# Reasoning 3: While Public Relations Specialists often manage social media, the tool automates posting scheduling, potentially reducing the need for manual scheduling.
#
# ******************************
# Processing 1077: Post Cheetah, postcheetah.com/
# Post Cheetah is an AI-powered SEO tool that helps users create comprehensive SEO strategies by leveraging Google data and artificial intelligence. The platform provides insights into keyword research, content optimization, and competitor analysis, enabling users to improve their website's ranking and organic traffic.
# Result:
# Post Cheetah Examples:
#
# Example 1: A blogger uses Post Cheetah to quickly identify high-volume, low-competition keywords for their next blog post, ensuring their content reaches a wider audience.
#
# ONET JOB automated 1:  Market Research Analysts that conduct market research and analyze data to identify opportunities for new product development or market expansion.
# ONET JOB 1: Market Research Analysts
# Confidence Interval 1: 8
# Reasoning 1: Post Cheetah assists in identifying relevant keywords for content creation, which aligns with Market Research Analyst's tasks of gathering and analyzing market information.
#
# Example 2: A website owner leverages Post Cheetah to analyze their competitors' SEO strategies, identifying areas for improvement in their own website's content and technical optimization.
#
# ONET JOB automated 2: Marketing Specialists that analyze customer data to develop marketing strategies.
# ONET JOB 2: Marketing Specialists
# Confidence Interval 2: 7
# Reasoning 2: Post Cheetah's competitor analysis feature assists in understanding competitive strategies, which aligns with the task of analyzing customer data for marketing strategies.
#
# Example 3: A small business owner utilizes Post Cheetah to generate a comprehensive SEO strategy, outlining specific actions for optimizing website content, technical SEO, and link building, leading to increased organic traffic and improved online visibility.
#
# ONET JOB automated 3:  Marketing Managers that develop and implement marketing plans and programs.
# ONET JOB 3: Marketing Managers
# Confidence Interval 3: 9
# Reasoning 3: Post Cheetah enables the development of a strategic plan for optimizing website presence, which aligns with the Marketing Manager's role in developing and implementing marketing plans.
#
# ******************************
# Processing 1078: TheXYZdotAI, Inc, www.thexyz.ai
# TheXYZdotAI, Inc. provides a web application that enables users to generate unique and imaginative images using artificial intelligence. These AI-generated images can be minted as NFTs, offering a new avenue for digital art creation and ownership.
# Result:
# Example 1:
#
# A digital artist uses the web application to create unique, AI-generated images for their online portfolio, expanding their creative output and exploring new artistic styles.
# ONET JOB automated 1: Fine Artists that create original works of art, using traditional or digital media.
# ONET JOB 1: Fine Artists
# Confidence Interval 1: 8
# Reasoning 1: The platform facilitates the creation of unique images, which is a core task for Fine Artists. While the process is automated, the artist still retains control over the final product and its artistic expression.
#
#  Example 2:
#
# An NFT collector leverages the application to generate and mint exclusive, AI-powered artwork as NFTs, diversifying their digital art collection and potentially accessing unique and rare pieces.
# ONET JOB automated 2: Art Appraisers that examine, evaluate, and authenticate works of art for authenticity, quality, and value.
# ONET JOB 2: Art Appraisers
# Confidence Interval 2: 6
# Reasoning 2: The platform helps identify and evaluate the value of AI-generated art, a task commonly associated with Art Appraisers. However, the platform's automation makes this evaluation less subjective than traditional appraisal methods.
#
#  Example 3:
#
# A cryptocurrency enthusiast uses the application to generate and sell AI-powered art as NFTs, entering the world of digital art and potentially profiting from the growing demand for unique digital assets.
# ONET JOB automated 3: Art Dealers that buy and sell works of art on behalf of artists or collectors.
# ONET JOB 3: Art Dealers
# Confidence Interval 3: 7
# Reasoning 3: While the user is not a traditional art dealer, they are effectively acting as one by generating and selling artwork. This aligns with the core function of Art Dealers, although the platform simplifies the process.
#
# ******************************
# Processing 1079: AccoAI, www.accoai.com/
# AccoAI is an AI-powered platform designed specifically for accounting firms, offering a suite of tools to streamline operations, enhance efficiency, and provide a centralized hub for managing client interactions, workflows, and team collaboration. The platform features automation capabilities, client tracking systems, employee management tools, and various other features to optimize accounting firm workflows.
# Result:
# AccoAI Examples:
#
# Example 1:
# An accountant at a small accounting firm uses AccoAI to automatically process invoices for clients, eliminating the need for manual data entry and saving time.
# ONET JOB automated 1: Accounting and Auditing Clerks that record, verify, and post transactions or other accounting or auditing information to maintain accounting records.
# ONET JOB 1: Accounting and Auditing Clerks
# Confidence Interval 1: 9
# Reasoning 1: This is a core task of accounting clerks, which AccoAI aims to automate.
#
# Example 2:
# A CPA firm utilizes AccoAI's client onboarding system to gather essential client information, automate paperwork, and seamlessly integrate new clients into their workflow, streamlining the onboarding process.
# ONET JOB automated 2:  Financial Analysts that perform a variety of analytical tasks that support the organization's financial planning and decision-making process.
# ONET JOB 2: Financial Analysts
# Confidence Interval 2: 7
# Reasoning 2:  While this is not a core task for financial analysts, it is a common aspect of client acquisition, which AccoAI aims to simplify.
#
# Example 3:
# An accounting firm leverages AccoAI to automatically generate customized financial reports for their clients, based on pre-defined parameters and data pulled from various sources, saving time and ensuring accuracy.
# ONET JOB automated 3: Accounting and Auditing Clerks that compile, analyze, and prepare financial reports.
# ONET JOB 3: Accounting and Auditing Clerks
# Confidence Interval 3: 9
# Reasoning 3: This task is directly within the scope of accounting and auditing clerks, which AccoAI automates through its report generation capabilities.
#
# ******************************
# Processing 1080: Stock Pal, stockpal.ai
# Stock Pal is a mobile app that utilizes AI to analyze a user's social media feeds, identifying publicly traded companies and brands frequently discussed by their friends. This information empowers new investors to discover potential investment opportunities based on their personal networks and interests.
# Result:
# Stock Pal Examples:
#
# Company: Stock Pal
# Website: stockpal.ai
# Current Description: Stock Pal is a mobile app that utilizes AI to analyze a user's social media feeds, identifying publicly traded companies and brands frequently discussed by their friends. This information empowers new investors to discover potential investment opportunities based on their personal networks and interests.
# Tasks/Jobs: Stock identification, Social media analysis, Investment recommendation, Portfolio tracking
# Industry: Investment management
# Customers: New investors, Individuals
#
#
# Example 1:
# A new investor uses Stock Pal to identify stocks mentioned in their friends' social media posts, discovering potential investment opportunities based on their social circle's interests.
# ONET JOB automated 1: Financial Analysts that research and analyze financial data and trends, including identifying investment opportunities.
# ONET JOB 1: Financial Analysts
# Confidence Interval 1: 8
# Reasoning 1: Stock Pal automates the initial research phase of finding potential investments based on social media data, a task often done by financial analysts.
#
#
# Example 2:
# Stock Pal analyzes social media posts about specific companies, gauging public sentiment and identifying potential market trends, providing insights for new investors.
# ONET JOB automated 2: Market Research Analysts that analyze market trends, competitor activities, and consumer preferences to identify growth opportunities and risks.
# ONET JOB 2: Market Research Analysts
# Confidence Interval 2: 7
# Reasoning 2:  This task involves analyzing social media sentiment and identifying trends, which are common activities for market research analysts.
#
#
# Example 3:
# Stock Pal automatically tracks and monitors a user's investment portfolio based on their social media activity, allowing new investors to easily manage their holdings and track their performance.
# ONET JOB automated 3:  Financial Analysts that manage and analyze client portfolios, including monitoring performance and recommending adjustments.
# ONET JOB 3: Financial Analysts
# Confidence Interval 3: 9
# Reasoning 3: Stock Pal handles the automated tracking and monitoring of a portfolio, a task typically performed by financial analysts.
#
# ******************************
# Processing 1081: FlowGPT, flowgpt.com
# FlowGPT is a platform for discovering and sharing high-quality prompts for various AI models, fostering a collaborative community of prompt engineers and AI enthusiasts. It serves as a central repository and resource for prompts, allowing users to integrate them into their projects and leverage the collective wisdom of the community.
# Result:
# FlowGPT Examples:
#
# Example 1:
#
# An AI developer uses FlowGPT to quickly find and test various prompts for a new language model they're building, saving time and effort in the development process.
#
# ONET JOB automated 1: Software Developers that conduct research and experimentation to develop or enhance software systems or applications.
# ...
# ONET JOB automated 3:  Web Developers that install, configure, maintain, and support computer network systems.
# ONET JOB 3: Web Developers
# Confidence Interval 3: 6
# Reasoning 3:  While the ONET task for "install, configure, maintain, and support computer network systems" is not directly related to chatbot deployment, the task of deploying a chat-based interface on a website is likely to be included within the scope of a web developer's responsibilities.
#
# ******************************
# Processing 2185: Geolava, www.geolava.com
# Geolava is an AI-powered location intelligence platform that provides businesses with insightful data about places, locations, cities, and more. Using Geolava, businesses can gain a deeper understanding of location-based movements, access geospatial insights, and analyze imagery to uncover opportunities for growth and revenue generation.
# Result:
# Geolava Example Use Cases:
#
# Example 1: A real estate company uses Geolava to automatically analyze foot traffic patterns and customer demographics near potential development sites, providing valuable insights for site selection and development strategies.
# ONET JOB automated 1: Market Research Analysts that use data from a variety of sources to analyze trends, develop forecasts, and make recommendations to clients.
# ONET JOB 1: Market Research Analysts
# Confidence Interval 1: 8
# Reasoning 1: This task aligns with the core function of market research analysts, who analyze data to understand market trends and consumer behavior. Geolava's location intelligence capabilities directly support this process.
#
# Example 2: An urban planner utilizes Geolava to analyze satellite imagery and aerial photographs to identify areas for potential infrastructure development, such as transportation networks or public spaces.
# ONET JOB automated 2: Urban and Regional Planners that study, analyze, and interpret data on population growth, land use, and economic trends.
# ONET JOB 2: Urban and Regional Planners
# Confidence Interval 2: 7
# Reasoning 2:  Urban planners often analyze geospatial data and imagery to understand urban dynamics and make informed decisions about infrastructure and development. Geolava's capabilities align with this task.
#
# Example 3: A business owner uses Geolava to visualize their customer base on a map, identifying high-traffic areas and potential locations for new store openings or targeted marketing campaigns.
# ONET JOB automated 3:  Market Research Analysts that prepare reports, charts, graphs, presentations, and other visual aids to summarize or highlight data, findings, or trends.
# ONET JOB 3: Market Research Analysts
# Confidence Interval 3: 9
# Reasoning 3: Geolava's ability to visualize customer data on a map directly supports the task of data visualization, which is commonly performed by market research analysts to present insights to clients.
#
# ******************************
# Processing 2186: Solatis, solatis.ai
# Solatis is an AI platform that seamlessly integrates with agent assistance applications to automate tasks, streamline workflows, and provide valuable data insights, ultimately boosting business efficiency. Solatis helps businesses across various departments, including customer support, sales, and executive management, by automating routine tasks and freeing up employees for more strategic work.
# Result:
# Solatis Examples
#
# Company: Solatis
# Website: solatis.ai
# Current Description: Solatis is an AI platform that seamlessly integrates with agent assistance applications to automate tasks, streamline workflows, and provide valuable data insights, ultimately boosting business efficiency. Solatis helps businesses across various departments, including customer support, sales, and executive management, by automating routine tasks and freeing up employees for more strategic work.
# Tasks/Jobs: Task automation, Workflow optimization, Data analysis, Agent assistance
# Industry: Business process automation
# Customers: Businesses, Customer support teams, Sales teams, Executive management teams
#
#
# Example 1:
# A customer support representative uses Solatis to automatically answer frequently asked questions, freeing up their time to handle more complex inquiries and provide personalized customer service.
# ONET JOB automated 1: Customer Service Representatives that respond to customer inquiries regarding orders, products, services, or company procedures.
# ONET JOB 1: Customer Service Representatives
# Confidence Interval 1: 9
# Reasoning 1: This example aligns with the core function of customer service representatives, which includes responding to inquiries. Solatis automates the initial response to common questions, allowing representatives to focus on more complex issues.
#
#
#
# Example 2:
# A sales representative uses Solatis to automate the process of scheduling appointments and sending follow-up emails, allowing them to focus on building relationships and closing deals.
# ONET JOB automated 2: Sales Representatives that schedule appointments with customers, and manage client appointments and contacts.
# ONET JOB 2: Sales Representatives
# Confidence Interval 2: 8
# Reasoning 2: Solatis streamlines the repetitive tasks of scheduling and sending emails, enabling sales representatives to focus on their primary tasks like relationship building and closing deals. This is a common function within the scope of a sales representative.
#
#
# Example 3:
# A manager uses Solatis to analyze data from customer interactions and identify trends, enabling them to make data-driven decisions about product development, marketing strategies, and customer service improvements.
# ONET JOB automated 3: Market Research Analysts that conduct market research, analyzing consumer behavior, pricing, competition, and industry trends.
# ONET JOB 3: Market Research Analysts
# Confidence Interval 3: 7
# Reasoning 3: While managers are not always directly involved in market research, Solatis provides them with valuable insights derived from customer interactions, allowing them to perform the tasks of a market research analyst. This demonstrates the potential for data-driven decision making across different departments.
#
# ******************************
# Processing 2187: Degrees of Interest, www.degreesofinterest.com
# Degrees of Interest is a company that offers an AI-powered visual analytics platform designed to assist law enforcement in criminal investigations. Their tool helps investigators analyze complex data sets, uncover hidden patterns, and identify potential suspects, ultimately aiding in faster and more efficient crime resolution.
# Result:
# Example 1:
#
# A police detective uses Degrees of Interest to quickly analyze a vast amount of crime scene data, identifying patterns and connections between potential suspects and the crime.
#
# ONET JOB automated 1: Police Detectives that analyze reports and crime scene evidence to develop leads and identify suspects.
#
# ONET JOB 1: Police Detectives
#
# Confidence Interval 1: 9
#
# Reasoning 1: The tool directly supports the task of analyzing evidence and identifying suspects, a core function of police detectives.
#
#  Example 2:
#
# A forensic analyst leverages Degrees of Interest to analyze phone records, social media activity, and other digital footprints to identify potential suspects and link them to the crime.
#
# ONET JOB automated 2: Forensic Science Technicians that analyze and interpret data from crime scenes and other sources, including fingerprints, DNA, and trace evidence.
#
# ONET JOB 2: Forensic Science Technicians
#
# Confidence Interval 2: 8
#
# Reasoning 2: This scenario describes a task that falls within the scope of forensic analysis, specifically focusing on digital evidence analysis, a growing area within the field.
#
#  Example 3:
#
# A police department uses Degrees of Interest to predict potential crime hotspots based on historical data, allowing them to allocate resources more effectively and proactively deter crime.
#
# ONET JOB automated 3: Police and Sheriff's Patrol Officers that patrol assigned areas to prevent crime, enforce laws, and apprehend suspects.
#
# ONET JOB 3: Police and Sheriff's Patrol Officers
#
# Confidence Interval 3: 7
#
# Reasoning 3: While the tool doesn't directly replace the patrol officer's role, it provides insights that inform their patrol strategy and resource allocation, enhancing their ability to prevent crime.
#
# ******************************
# Processing 2188: AI Compliance, aicomply.ai
# AI Compliance provides an online audit tool to help organizations understand and manage compliance risks associated with their AI projects. Their Dynamic Knowledge Graph technology enables comprehensive audits across multiple jurisdictions, ensuring compliance with current and evolving regulations.
# Result:
# AI Compliance Examples
#
# Company: AI Compliance
# Website: aicomply.ai
# Current Description: AI Compliance provides an online audit tool to help organizations understand and manage compliance risks associated with their AI projects. Their Dynamic Knowledge Graph technology enables comprehensive audits across multiple jurisdictions, ensuring compliance with current and evolving regulations.
# Tasks/Jobs: Compliance auditing, Risk assessment, AI regulation monitoring, Data privacy compliance
# Industry: AI ethics and governance
# Customers: AI developers, Tech companies, Government agencies
#
#
# Example 1: An AI developer uses AI Compliance to automatically assess the compliance risks of their AI project against multiple regulations, generating a detailed report outlining potential violations and mitigation strategies.
# ONET JOB automated 1: Software Developers, Applications that identify and analyze risks and opportunities in software development.
# ONET JOB 1: Software Developers, Applications
# Confidence Interval 1: 8
# Reasoning 1: This example aligns with the common task of software developers to identify and analyze risks, which is automated by the AI compliance tool.
#
#
# Example 2: A tech company leverages AI Compliance to continuously monitor the evolving landscape of AI regulations across various jurisdictions, ensuring their AI systems remain compliant with the latest requirements.
# ONET JOB automated 2: Compliance Officers that keep abreast of changes in the law, regulations, or industry standards by reviewing legislation, regulations, publications, and other materials.
# ONET JOB 2: Compliance Officers
# Confidence Interval 2: 9
# Reasoning 2: AI Compliance automates the task of monitoring regulatory changes, a key responsibility of Compliance Officers.
#
#
# Example 3: A government agency utilizes AI Compliance to conduct comprehensive audits of AI projects submitted for approval, ensuring adherence to ethical guidelines and data privacy regulations.
# ONET JOB automated 3: Compliance Auditors that conduct audits to ensure compliance with federal, state, or local regulations, and company policies.
# ONET JOB 3: Compliance Auditors
# Confidence Interval 3: 7
# Reasoning 3: AI Compliance automates the auditing process, which is a core task of Compliance Auditors. The tool is used to ensure adherence to regulations and ethical guidelines, a common component of government agency reviews.
#
# ******************************
# Processing 2189: Robozaps, robozaps.com
# Robozaps is an online marketplace that connects buyers and sellers of humanoid robots. The platform features a wide selection of robots from leading brands like Tesla Optimus, Figure AI, UBTECH, and Boston Dynamics, allowing users to explore and purchase advanced robotic technology.
# Result:
# Robozaps Examples
#
#
# Example 1: A researcher uses Robozaps to quickly find and purchase a specific humanoid robot for their research project, filtering through a vast inventory of available robots by manufacturer, specifications, and price.
#
# ONET JOB automated 1:  Market Research Analysts that collect and analyze information about the supply and demand of goods and services. (Task ID: 19-2011.01 -  Analyze market data to identify trends, competitor activities, and customer preferences.)
#
# ONET JOB 1: Market Research Analysts
#
# Confidence Interval 1: 8
#
# Reasoning 1: This example utilizes the core functionality of Robozaps, which involves filtering and searching through a large selection of products, a task that is often performed by market research analysts.
#
#
# Example 2:  A business owner uses Robozaps to sell a humanoid robot they no longer need, listing it on the platform and managing the sale process, including communication with potential buyers and coordinating delivery.
#
# ONET JOB automated 2: Sales Representatives, Wholesale and Manufacturing that negotiate sales contracts and manage the processing of sales transactions. (Task ID: 41-4011.02 -  Negotiate terms of sale with customers.)
#
# ONET JOB 2: Sales Representatives, Wholesale and Manufacturing
#
# Confidence Interval 2: 7
#
# Reasoning 2: Robozaps is a marketplace, where buyers and sellers interact. While this is not explicitly a "wholesale" scenario, the platform supports the sale of industrial robots, and the task of negotiating sales is a key responsibility for sales representatives.
#
#
# Example 3:  A customer contacts Robozaps' customer support team to inquire about the technical specifications of a specific robot, receiving prompt assistance and detailed information through the platform's online chat interface.
#
# ONET JOB automated 3: Customer Service Representatives that provide information about products and services to customers. (Task ID: 43-4061.01 - Provide information to customers about products and services.)
#
# ONET JOB 3: Customer Service Representatives
#
# Confidence Interval 3: 9
#
# Reasoning 3: This example clearly focuses on customer support, a common role in online marketplaces. The platform's online chat feature allows for efficient communication and information sharing, automating tasks traditionally performed by customer service representatives.
#
# ******************************
# Processing 2190: PrimeRole, www.primerole.com
# PrimeRole is a B2B Sales Intelligence platform designed to improve sales teams' efficiency. It utilizes AI to enhance prospecting, lead scoring, data enrichment, and engagement, ultimately leading to more effective outreach and streamlined sales processes.
# Result:
# Example 1:
#
# A sales representative uses PrimeRole to identify potential leads within specific industries and generate personalized outreach messages tailored to each individual's interests and needs.
# ONET JOB automated 1: Sales Representatives that search for and contact potential customers to solicit orders or subscriptions.
# ONET JOB 1: Sales Representatives
# Confidence Interval 1: 9
# Reasoning 1:  PrimeRole automates the task of identifying potential leads and tailoring outreach messages, a common task for Sales Representatives.
#
#  Example 2:
#
# A sales manager leverages PrimeRole to score leads based on their likelihood of conversion, prioritizing outreach to high-potential prospects and optimizing their team's time and resources.
# ONET JOB automated 2: Sales Managers that assess and evaluate potential customers.
# ONET JOB 2: Sales Managers
# Confidence Interval 2: 8
# Reasoning 2: PrimeRole's lead scoring feature directly impacts a Sales Manager's ability to prioritize their team's efforts, aligning with their task of assessing potential customers.
#
#  Example 3:
#
# A sales team uses PrimeRole to enrich their customer profiles with up-to-date information, ensuring accurate contact details and relevant insights for effective communication and tailored sales strategies.
# ONET JOB automated 3: Sales Representatives that research and gather information about potential customers.
# ONET JOB 3: Sales Representatives
# Confidence Interval 3: 7
# Reasoning 3: While data enrichment is a broader task, the tool's ability to update contact details and provide insights for tailored sales strategies aligns with a Sales Representative's research and information gathering duties.

# %%
df.head()
# Out:
#   organization name                                   full_description  \
# 0              Pika  Pika is a startup that is developing an AI-pow...
# 1              Pika  Pika is a startup that is developing an AI-pow...
# 2     Contextual AI  Contextual AI offers a pioneering approach to ...
# 3     Contextual AI  Contextual AI offers a pioneering approach to ...
# 4            Sierra  Sierra is an AI startup that tackles essential...
#
#                                           industries  \
# 0  Artificial Intelligence (AI), Generative AI, G...
# 1  Artificial Intelligence (AI), Generative AI, G...
# 2  Artificial Intelligence (AI), Generative AI, S...
# 3  Artificial Intelligence (AI), Generative AI, S...
# 4  Artificial Intelligence (AI), Enterprise Softw...
#
#                       headquarters location founded date  \
# 0      Palo Alto, California, United States   2023-01-01
# 1      Palo Alto, California, United States   2023-01-01
# 2  Mountain View, California, United States   2023-01-01
# 3  Mountain View, California, United States   2023-01-01
# 4  San Francisco, California, United States   2023-01-01
#
#                                          description CB rank  \
# 0  Pika is a startup that develops an AI-powered ...      71
# 1  Pika is a startup that develops an AI-powered ...      71
# 2  Contextual AI offers a pioneering approach to ...     217
# 3  Contextual AI offers a pioneering approach to ...     217
# 4  Sierra is an AI startup that tackles essential...     273
#
#                                  headquarters region postal code  \
# 0  San Francisco Bay Area, Silicon Valley, West C...       94301
# 1  San Francisco Bay Area, Silicon Valley, West C...       94301
# 2  San Francisco Bay Area, Silicon Valley, West C...       94040
# 3  San Francisco Bay Area, Silicon Valley, West C...       94040
# 4     San Francisco Bay Area, West Coast, Western US           —
#
#   estimated revenue  ... generated_description_conf_interval  \
# 0                 —  ...                                   8
# 1                 —  ...                                   8
# 2                 —  ...                                   6
# 3                 —  ...                                   6
# 4                 —  ...                                   7
#
#        generated_description_conf_interval_reasoning  \
# 0  While Pika's website doesn't go into deep deta...
# 1  While Pika's website doesn't go into deep deta...
# 2  While the website does state Contextual AI foc...
# 3  While the website does state Contextual AI foc...
# 4  The information provided on their website is l...
#
#                               parsed_description_llm  \
# 0  ________________________\nTasks/Jobs: Video cr...
# 1  ________________________\nTasks/Jobs: Video cr...
# 2  ________________________\nTasks/Jobs: Content ...
# 3  ________________________\nTasks/Jobs: Content ...
# 4  ________________________\nTasks/Jobs: Customer...
#
#                                   parsed_description  \
# 0  Tasks/Jobs: Video creation, Video editing, Ima...
# 1  Tasks/Jobs: Video creation, Video editing, Ima...
# 2  Tasks/Jobs: Content generation, Workflow autom...
# 3  Tasks/Jobs: Content generation, Workflow autom...
# 4  Tasks/Jobs: Customer service, Issue resolution...
#
#                                           Tasks/Jobs             Industry  \
# 0  Video creation, Video editing, Image animation...     Video Production
# 1  Video creation, Video editing, Image animation...     Video Production
# 2  Content generation, Workflow automation, Data ...  Business Automation
# 3  Content generation, Workflow automation, Data ...  Business Automation
# 4  Customer service, Issue resolution, Lead gener...     Customer service
#
#                                            Customers  \
# 0  Marketers, Content creators, Social media mana...
# 1  Marketers, Content creators, Social media mana...
# 2                            Businesses, Enterprises
# 3                            Businesses, Enterprises
# 4                            Businesses, Enterprises
#
#   parsed_description_conf_interval  \
# 0                                9
# 1                                9
# 2                                9
# 3                                9
# 4                                9
#
#           parsed_description_conf_interval_reasoning  \
# 0  Pika's website and description clearly state i...
# 1  Pika's website and description clearly state i...
# 2  The website and description clearly indicate a...
# 3  The website and description clearly indicate a...
# 4  The description explicitly states Sierra's AI ...
#
#                                         examples_llm
# 0  ## Pika Examples:\n\n**Example 1:** A social m...
# 1  ## Pika Examples:\n\n**Example 1:** A social m...
# 2  ## Contextual AI Example Uses\n\nCompany: Cont...
# 3  ## Contextual AI Example Uses\n\nCompany: Cont...
# 4  ## Sierra AI Example Use Cases\n\nCompany: Sie...
#
# [5 rows x 47 columns]

# %%
def extract_data(text):
    if pd.isnull(text): return {}
    # Normalize the text to ensure consistent whitespace and remove unwanted characters.
    text = re.sub(r'\s+', ' ', text).strip()
    text = text.replace("*", "").replace("/10", "").replace("_", "").replace("#", "")
    vals = {}
    i = 1
    while i <=3:
        # Regex pattern adjusted to handle fractions in confidence intervals like '9/10'
        pattern = rf"Example\s+{i}:\s+(.*?)\s+ONET JOB automated\s+{i}:\s+(.*?)\s+ONET JOB\s+{i}:\s+(.*?)\s+Confidence Interval\s+{i}:\s+(\d+(?:/\d+)?)\s+Reasoning\s+{i}:\s+(.*?)(?=\s*Example\s+{i + 1}:|$)"
        match = re.search(pattern, text, re.DOTALL)
        if not match:
            print(text+"\n\n")
            print(f"No matches found for Example {i}")  # Debug if no examples are found
            return {}
            break

        example_text, onet_job_automated, onet_job, confidence_interval, reasoning = match.groups()
        example_key = f"Example{i}"
        vals[example_key] = example_text.strip()
        vals[f"Job{i}"] = onet_job_automated.strip()
        vals[f"Job{i}_title"] = onet_job.strip()
        vals[f"situation{i}_conf_interval"] = confidence_interval.strip()
        vals[f"situation{i}_conf_interval_reasoning"] = reasoning.strip()

        i += 1  # Prepare to search for the next example
    return vals

for col in cols:
    if col in list(df.columns): df=df.drop(columns=[col])

results_df = pd.DataFrame(list(df.apply(lambda x: extract_data(x["examples_llm"]),axis=1)))
df = pd.concat([df, results_df],axis=1)
# Out:
#  Brzzy Examples Company: Brzzy Website: brzzy.co Current Description: Brzzy is a weather app that utilizes GIFs, music, and quirky forecasts to make the weather engaging and entertaining. Their goal is to transform how people interact with weather information by making it more fun and interactive. Tasks/Jobs: Weather information presentation, GIF creation, Music selection, Forecast personalization Industry: Weather information Customers: Individuals, Casual users, Social media users  Example 1: A social media manager uses Brzzy to find the perfect GIF to illustrate the weather conditions in their region, adding a touch of humor and engaging their audience. ONET JOB automated 1: Social media specialists who select and post digital content to promote a company's brand. ONET JOB 1: Social Media Specialists Confidence Interval 1: 7 Reasoning 1: While the ONET task is broad, it reflects the core action of selecting media to share, which aligns with Brzzy's focus on GIF-based weather presentation.  Example 2: A casual user, browsing their social media feed, sees a personalized Brzzy forecast featuring a catchy song and a funny GIF, prompting them to check the weather more frequently for entertainment. ONET JOB automated 2: Not applicable (This example involves a change in user behavior, not a specific job automation). ONET JOB 2: Not applicable Confidence Interval 2: N/A Reasoning 2: The example is focused on user engagement and does not describe a specific job function that's automated.  Example 3: A meteorologist uses Brzzy to select appropriate music and GIFs to accompany their weather reports, enhancing their presentations and making weather information more engaging for viewers. ONET JOB automated 3: Broadcast Meteorologists that present weather information to the public. ONET JOB 3: Broadcast Meteorologists Confidence Interval 3: 8 Reasoning 3: This aligns with the ONET task "Prepare and deliver weather forecasts or reports for broadcast," highlighting the use of Brzzy's tools to enhance the presentation aspect of weather information.
#
#
# No matches found for Example 2
#  Brzzy Examples Company: Brzzy Website: brzzy.co Current Description: Brzzy is a weather app that utilizes GIFs, music, and quirky forecasts to make the weather engaging and entertaining. Their goal is to transform how people interact with weather information by making it more fun and interactive. Tasks/Jobs: Weather information presentation, GIF creation, Music selection, Forecast personalization Industry: Weather information Customers: Individuals, Casual users, Social media users  Example 1: A social media manager uses Brzzy to find the perfect GIF to illustrate the weather conditions in their region, adding a touch of humor and engaging their audience. ONET JOB automated 1: Social media specialists who select and post digital content to promote a company's brand. ONET JOB 1: Social Media Specialists Confidence Interval 1: 7 Reasoning 1: While the ONET task is broad, it reflects the core action of selecting media to share, which aligns with Brzzy's focus on GIF-based weather presentation.  Example 2: A casual user, browsing their social media feed, sees a personalized Brzzy forecast featuring a catchy song and a funny GIF, prompting them to check the weather more frequently for entertainment. ONET JOB automated 2: Not applicable (This example involves a change in user behavior, not a specific job automation). ONET JOB 2: Not applicable Confidence Interval 2: N/A Reasoning 2: The example is focused on user engagement and does not describe a specific job function that's automated.  Example 3: A meteorologist uses Brzzy to select appropriate music and GIFs to accompany their weather reports, enhancing their presentations and making weather information more engaging for viewers. ONET JOB automated 3: Broadcast Meteorologists that present weather information to the public. ONET JOB 3: Broadcast Meteorologists Confidence Interval 3: 8 Reasoning 3: This aligns with the ONET task "Prepare and deliver weather forecasts or reports for broadcast," highlighting the use of Brzzy's tools to enhance the presentation aspect of weather information.
#
#
# No matches found for Example 2
# I need more information about Neurotone AI's product to provide accurate examples. Please provide a detailed description of what Neurotone AI does. For example, tell me:  What industry does Neurotone AI serve? (e.g., healthcare, finance, education)  What problems does Neurotone AI solve? (e.g., improves efficiency, reduces errors, automates tasks)  What types of users are targeted? (e.g., data analysts, marketers, customer service representatives)  What is the product's primary functionality? (e.g., AI-powered chatbot, data visualization tool, workflow automation platform) Once I have this information, I can create relevant examples and map them to ONET jobs.
#
#
# No matches found for Example 1
# I need more information about Neurotone AI's product to provide accurate examples. Please provide a detailed description of what Neurotone AI does. For example, tell me:  What industry does Neurotone AI serve? (e.g., healthcare, finance, education)  What problems does Neurotone AI solve? (e.g., improves efficiency, reduces errors, automates tasks)  What types of users are targeted? (e.g., data analysts, marketers, customer service representatives)  What is the product's primary functionality? (e.g., AI-powered chatbot, data visualization tool, workflow automation platform) Once I have this information, I can create relevant examples and map them to ONET jobs.
#
#
# No matches found for Example 1
#  Example 1: A writer uses Arcane to rapidly develop character backstories, motivations, and relationships, drawing from the platform's AI-powered character generation tools to enrich their narratives. ONET JOB automated 1: Writers that develop fictional characters or create descriptions of characters. ONET JOB 1: Writers and Authors Confidence Interval 1: 8 Reasoning 1: Writers often create characters and backstories for their work. Arcane's AI tools can automate this process, aiding in character development and world-building.  Example 2: A game developer leverages Arcane's AI to create branching storylines and interactive dialogues for their role-playing game, dynamically adapting the narrative based on player choices. ONET JOB automated 2: Game Developers that design the interactive storyline or plot of the game. ONET JOB 2: Software Developers, Applications Confidence Interval 2: 7 Reasoning 2: Game developers often create interactive narratives and dialogues. Arcane's AI can automate this process, assisting with branching storylines and dialogue generation.  Example 3: A gamer uses Arcane to experience immersive role-playing scenarios, engaging in real-time conversations with AI-powered characters and making choices that influence the narrative's direction. ONET JOB automated 3: Not Applicable (This is a gamer using the tool, not a specific role) ONET JOB 3: Not Applicable Confidence Interval 3: N/A Reasoning 3: This example illustrates a user experience, not a specific role or task automated. Arcane's platform likely involves roles like game designers and developers, but this example highlights user interaction rather than a specific job function.
#
#
# No matches found for Example 3
#  Example 1: A writer uses Arcane to rapidly develop character backstories, motivations, and relationships, drawing from the platform's AI-powered character generation tools to enrich their narratives. ONET JOB automated 1: Writers that develop fictional characters or create descriptions of characters. ONET JOB 1: Writers and Authors Confidence Interval 1: 8 Reasoning 1: Writers often create characters and backstories for their work. Arcane's AI tools can automate this process, aiding in character development and world-building.  Example 2: A game developer leverages Arcane's AI to create branching storylines and interactive dialogues for their role-playing game, dynamically adapting the narrative based on player choices. ONET JOB automated 2: Game Developers that design the interactive storyline or plot of the game. ONET JOB 2: Software Developers, Applications Confidence Interval 2: 7 Reasoning 2: Game developers often create interactive narratives and dialogues. Arcane's AI can automate this process, assisting with branching storylines and dialogue generation.  Example 3: A gamer uses Arcane to experience immersive role-playing scenarios, engaging in real-time conversations with AI-powered characters and making choices that influence the narrative's direction. ONET JOB automated 3: Not Applicable (This is a gamer using the tool, not a specific role) ONET JOB 3: Not Applicable Confidence Interval 3: N/A Reasoning 3: This example illustrates a user experience, not a specific role or task automated. Arcane's platform likely involves roles like game designers and developers, but this example highlights user interaction rather than a specific job function.
#
#
# No matches found for Example 3

# %%
l = pd.read_csv('../output/df_with_examples.csv',index_col=0)
len(l)
# Out:
# 3251

# %%
# Out:
#                                                       full_description  \
# organization name
# Pika                 Pika is a startup that is developing an AI-pow...
# Pika                 Pika is a startup that is developing an AI-pow...
# Contextual AI        Contextual AI offers a pioneering approach to ...
# Contextual AI        Contextual AI offers a pioneering approach to ...
# Sierra               Sierra is an AI startup that tackles essential...
# ...                                                                ...
# Solatis              Solatis is an innovative AI technology tool de...
# Degrees of Interest  Harnessing the power of AI to help law enforce...
# AI Compliance        Many potential users of AI are held back by th...
# Robozaps             Robozaps is a marketplace to buy and sell huma...
# PrimeRole            PrimeRole is a cutting-edge B2B Sales Intellig...
#
#                                                             industries  \
# organization name
# Pika                 Artificial Intelligence (AI), Generative AI, G...
# Pika                 Artificial Intelligence (AI), Generative AI, G...
# Contextual AI        Artificial Intelligence (AI), Generative AI, S...
# Contextual AI        Artificial Intelligence (AI), Generative AI, S...
# Sierra               Artificial Intelligence (AI), Enterprise Softw...
# ...                                                                ...
# Solatis              Artificial Intelligence (AI), Information Tech...
# Degrees of Interest      Artificial Intelligence (AI), Law Enforcement
# AI Compliance        Artificial Intelligence (AI), Internet, Legal ...
# Robozaps             Artificial Intelligence (AI), Marketplace, Rob...
# PrimeRole                                       Information Technology
#
#                                         headquarters location founded date  \
# organization name
# Pika                     Palo Alto, California, United States   2023-01-01
# Pika                     Palo Alto, California, United States   2023-01-01
# Contextual AI        Mountain View, California, United States   2023-01-01
# Contextual AI        Mountain View, California, United States   2023-01-01
# Sierra               San Francisco, California, United States   2023-01-01
# ...                                                       ...          ...
# Solatis                     New York, New York, United States   2024-06-05
# Degrees of Interest        Arlington, Virginia, United States   2024-06-06
# AI Compliance                 Newark, Delaware, United States   2024-06-06
# Robozaps             San Francisco, California, United States   2024-06-16
# PrimeRole            San Francisco, California, United States   2024-06-18
#
#                                                            description  \
# organization name
# Pika                 Pika is a startup that develops an AI-powered ...
# Pika                 Pika is a startup that develops an AI-powered ...
# Contextual AI        Contextual AI offers a pioneering approach to ...
# Contextual AI        Contextual AI offers a pioneering approach to ...
# Sierra               Sierra is an AI startup that tackles essential...
# ...                                                                ...
# Solatis              Solatis is an AI technology workforce tool tha...
# Degrees of Interest   Visual analytics AI for criminal investigations.
# AI Compliance         Online Audit tools for AI compliance regulations
# Robozaps                The world's #1 marketplace for humanoid robots
# PrimeRole            PrimeRole is a cutting-edge B2B Sales Intellig...
#
#                      CB rank  \
# organization name
# Pika                      71
# Pika                      71
# Contextual AI            217
# Contextual AI            217
# Sierra                   273
# ...                      ...
# Solatis              205,522
# Degrees of Interest        —
# AI Compliance              —
# Robozaps                   —
# PrimeRole                  —
#
#                                                    headquarters region  \
# organization name
# Pika                 San Francisco Bay Area, Silicon Valley, West C...
# Pika                 San Francisco Bay Area, Silicon Valley, West C...
# Contextual AI        San Francisco Bay Area, Silicon Valley, West C...
# Contextual AI        San Francisco Bay Area, Silicon Valley, West C...
# Sierra                  San Francisco Bay Area, West Coast, Western US
# ...                                                                ...
# Solatis              Greater New York Area, East Coast, Northeaster...
# Degrees of Interest  Washington DC Metro Area, East Coast, Southern US
# AI Compliance        Greater Philadelphia Area, East Coast, Souther...
# Robozaps                San Francisco Bay Area, West Coast, Western US
# PrimeRole               San Francisco Bay Area, West Coast, Western US
#
#                     postal code estimated revenue operating status  ...  \
# organization name                                                   ...
# Pika                      94301                 —           Active  ...
# Pika                      94301                 —           Active  ...
# Contextual AI             94040                 —           Active  ...
# Contextual AI             94040                 —           Active  ...
# Sierra                        —                 —           Active  ...
# ...                         ...               ...              ...  ...
# Solatis                       —                 —           Active  ...
# Degrees of Interest       22201                 —           Active  ...
# AI Compliance             19713                 —           Active  ...
# Robozaps                  94103                 —           Active  ...
# PrimeRole                 94114                 —           Active  ...
#
#                     generated_description_conf_interval  \
# organization name
# Pika                                                  8
# Pika                                                  8
# Contextual AI                                         6
# Contextual AI                                         6
# Sierra                                                7
# ...                                                 ...
# Solatis                                               8
# Degrees of Interest                                   8
# AI Compliance                                         8
# Robozaps                                              9
# PrimeRole                                             9
#
#                          generated_description_conf_interval_reasoning  \
# organization name
# Pika                 While Pika's website doesn't go into deep deta...
# Pika                 While Pika's website doesn't go into deep deta...
# Contextual AI        While the website does state Contextual AI foc...
# Contextual AI        While the website does state Contextual AI foc...
# Sierra               The information provided on their website is l...
# ...                                                                ...
# Solatis              The provided text gives a good overview of Sol...
# Degrees of Interest  The website clearly states the purpose of the ...
# AI Compliance        The provided description clearly outlines the ...
# Robozaps             The website clearly states that Robozaps is a ...
# PrimeRole            The website provides clear information about P...
#
#                                                 parsed_description_llm  \
# organization name
# Pika                 ________________________\nTasks/Jobs: Video cr...
# Pika                 ________________________\nTasks/Jobs: Video cr...
# Contextual AI        ________________________\nTasks/Jobs: Content ...
# Contextual AI        ________________________\nTasks/Jobs: Content ...
# Sierra               ________________________\nTasks/Jobs: Customer...
# ...                                                                ...
# Solatis              ________________________\nCompany: Solatis\nWe...
# Degrees of Interest  ________________________\nTasks/Jobs: Data ana...
# AI Compliance        ________________________\nCompany: AI Complian...
# Robozaps             ________________________\nCompany: Robozaps\nW...
# PrimeRole            ________________________\nTasks/Jobs: Prospect...
#
#                                                     parsed_description  \
# organization name
# Pika                 Tasks/Jobs: Video creation, Video editing, Ima...
# Pika                 Tasks/Jobs: Video creation, Video editing, Ima...
# Contextual AI        Tasks/Jobs: Content generation, Workflow autom...
# Contextual AI        Tasks/Jobs: Content generation, Workflow autom...
# Sierra               Tasks/Jobs: Customer service, Issue resolution...
# ...                                                                ...
# Solatis              Tasks/Jobs: Task automation, Workflow optimiza...
# Degrees of Interest  Tasks/Jobs: Data analysis, Pattern recognition...
# AI Compliance        Tasks/Jobs: Compliance auditing, Risk assessme...
# Robozaps             Tasks/Jobs: Robot search and filtering, Purcha...
# PrimeRole            Tasks/Jobs: Prospecting, Lead scoring, Data en...
#
#                                                             Tasks/Jobs  \
# organization name
# Pika                 Video creation, Video editing, Image animation...
# Pika                 Video creation, Video editing, Image animation...
# Contextual AI        Content generation, Workflow automation, Data ...
# Contextual AI        Content generation, Workflow automation, Data ...
# Sierra               Customer service, Issue resolution, Lead gener...
# ...                                                                ...
# Solatis              Task automation, Workflow optimization, Data a...
# Degrees of Interest  Data analysis, Pattern recognition, Suspect id...
# AI Compliance        Compliance auditing, Risk assessment, AI regul...
# Robozaps             Robot search and filtering, Purchase and sale ...
# PrimeRole            Prospecting, Lead scoring, Data enrichment, En...
#
#                                         Industry  \
# organization name
# Pika                            Video Production
# Pika                            Video Production
# Contextual AI                Business Automation
# Contextual AI                Business Automation
# Sierra                          Customer service
# ...                                          ...
# Solatis              Business process automation
# Degrees of Interest              Law Enforcement
# AI Compliance           AI ethics and governance
# Robozaps                    Robotics marketplace
# PrimeRole                     Sales Intelligence
#
#                                                              Customers  \
# organization name
# Pika                 Marketers, Content creators, Social media mana...
# Pika                 Marketers, Content creators, Social media mana...
# Contextual AI                                  Businesses, Enterprises
# Contextual AI                                  Businesses, Enterprises
# Sierra                                         Businesses, Enterprises
# ...                                                                ...
# Solatis              Businesses, Customer support teams, Sales team...
# Degrees of Interest  Police detectives, Investigators, Forensic ana...
# AI Compliance        AI developers, Tech companies, Government agen...
# Robozaps                          Businesses, Researchers, Individuals
# PrimeRole                                      Sales teams, Businesses
#
#                     parsed_description_conf_interval  \
# organization name
# Pika                                               9
# Pika                                               9
# Contextual AI                                      9
# Contextual AI                                      9
# Sierra                                             9
# ...                                              ...
# Solatis                                            8
# Degrees of Interest                                9
# AI Compliance                                   9/10
# Robozaps                                           9
# PrimeRole                                          9
#
#                             parsed_description_conf_interval_reasoning  \
# organization name
# Pika                 Pika's website and description clearly state i...
# Pika                 Pika's website and description clearly state i...
# Contextual AI        The website and description clearly indicate a...
# Contextual AI        The website and description clearly indicate a...
# Sierra               The description explicitly states Sierra's AI ...
# ...                                                                ...
# Solatis              The website and description clearly indicate S...
# Degrees of Interest  The company's website explicitly describes its...
# AI Compliance        The company's description clearly focuses on c...
# Robozaps             The company's website and description clearly ...
# PrimeRole            The description explicitly states that PrimeRo...
#
#                                                           examples_llm
# organization name
# Pika                 ## Pika Examples:\n\n**Example 1:** A social m...
# Pika                 ## Pika Examples:\n\n**Example 1:** A social m...
# Contextual AI        ## Contextual AI Example Uses\n\nCompany: Cont...
# Contextual AI        ## Contextual AI Example Uses\n\nCompany: Cont...
# Sierra               ## Sierra AI Example Use Cases\n\nCompany: Sie...
# ...                                                                ...
# Solatis              ## Solatis Examples\n\n**Company: Solatis**\n*...
# Degrees of Interest  ## Example 1: \n\nA police detective uses Degr...
# AI Compliance        ## AI Compliance Examples\n\n**Company: AI Com...
# Robozaps             ## Robozaps Examples\n\n________________\n**Ex...
# PrimeRole            ## Example 1: \n\nA sales representative uses ...
#
# [3251 rows x 46 columns]

# %%
df = df.drop_duplicates(subset=['organization name'], keep='first')
df = df.reset_index(drop=True)

# %%
len(df)
# Out:
# 2188

# %%
df = df.dropna(subset=["Example1"],axis=0)
df = df.drop_duplicates(subset=['organization name'], keep='first')
df = df.reset_index(drop=True)

# %%
df.to_csv('../output/df_with_examples.csv', index=False)

# %%
#RERUN STOPPED IN MIDDLE
# results_df = pd.read_csv("result.csv",index_col=0)
# df = pd.read_csv('../output/df_with_parsed_description.csv',index_col=0)
# prompting_class.set_current_results_df(results_df)
# df = df.merge(results_df, on='organization name', how='left')

# %%
prompting_class.results_df
# Out:
#         organization name                             parsed_description_llm
# 0                    Pika  ________________________\nTasks/Jobs: Video cr...
# 1           Contextual AI  ________________________\nTasks/Jobs: Content ...
# 2                  Sierra  ________________________\nTasks/Jobs: Customer...
# 3            Essential AI  ________________________\nTasks/Jobs: Content ...
# 4               Liquid AI  ________________________\nTasks/Jobs: Content ...
# ...                   ...                                                ...
# 2188              Solatis  ________________________\nCompany: Solatis\nWe...
# 2189  Degrees of Interest  ________________________\nTasks/Jobs: Data ana...
# 2190        AI Compliance  ________________________\nCompany: AI Complian...
# 2191             Robozaps  ________________________\nCompany: Robozaps\nW...
# 2192            PrimeRole  ________________________\nTasks/Jobs: Prospect...
#
# [2191 rows x 2 columns]
