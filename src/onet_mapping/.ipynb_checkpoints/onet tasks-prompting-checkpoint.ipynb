# %%
import pandas as pd
import numpy as np
from dotenv import load_dotenv
import os
from os import getenv
from openai import OpenAI
import pathlib
import textwrap
import google.generativeai as genai
import time

load_dotenv("../.env",override=True)
GOOGLE_API_KEY = getenv("GEMINI_API_KEY")
OPENAI_API_KEY = getenv("OPENAI_API_KEY")

# %%
import json
genai.configure(api_key=GOOGLE_API_KEY)
class gemini():
    def __init__(self):
        self.model = genai.GenerativeModel('gemini-1.5-flash')
    def request(self,prompt):
        url = 'https://generativelanguage.googleapis.com/v1beta/models/gemini-1.5-flash-latest:generateContent'
        headers = {
            'Content-Type': 'application/json',
        }
        data = {
            "contents": [
                {
                    "parts": [
                        {
                            "text": prompt
                        }
                    ]
                }
            ]
        }
        params = {
            'key': GOOGLE_API_KEY
        }
        
        response = requests.post(url, headers=headers, json=data, params=params)
        return json.loads(response.text)

    def ask(self,prompt):
        #response = self.model.generate_content(prompt)
        response = self.request(prompt)
        response = response["candidates"][0]["content"]["parts"][0]["text"]
        return response

x_gemini = gemini()
x_gemini.ask("hi")
# Out:
# 'Hi! How can I help you today? \n'

# %%
class chatGPT():
    def __init__(self):
        self.client = OpenAI(api_key=OPENAI_API_KEY)
        
    def ask(self, q):
        stream = self.client.chat.completions.create(
            model="gpt-4",
            messages=[{"role": "user", "content": q}],
            stream=True,
            temperature=0
        )
        response = ""
        for chunk in stream:
            if chunk.choices[0].delta.content is not None:
                response += chunk.choices[0].delta.content

        self.response = response
        return response

    def get_embedding(self,text, model="text-embedding-3-large"):
       text = text.replace("\n", " ")
       return self.client.embeddings.create(input = [text], model=model).data[0].embedding

x_chat = chatGPT()

# %%
sample_df = pd.read_csv("./output/sample_df_current.csv")
sample_df = sample_df.sample(n=200)

# %%
prompt = """
Your role is to give me 3 two sentence example that would be using the product of $company. Do not use name of company in description. Keep it broad.
The goal is to give the a detailed description of the job that the tool automates and who performs that job and when.

IF THE PERSON AUTOMATED IS NOT DOING A JOB THAT IS NOT DONE AT WORK THEN WRITE "NOT_ONET" IN FRONT OF IT.

EXAMPLE: 
________________
Company: DreamGenerator.ai
Website: DreamGenerator.ai
DreamGenerator.ai is an innovative platform that utilizes generative AI to transform user ideas into stunning and diverse images. It offers a unique creative experience, encouraging users to experiment with prompts and share their AI-generated art, while also providing an opportunity to receive recognition through likes and shares.
Tasks/Jobs: Image generation, Artistic exploration, Prompt engineering, Social media sharing
Industry: Creative arts
People Using Tool: Artists, Designers, Everyone
**************************
Example 1: A writer uses generates images that will inspire ideas for their new book by typing in fun prompts into the website.
Job automated 1: Writer has to generate create ideas for book.
Example 2: A social media marketer creates eye-catching visuals for their summer fitness campaign, like "people doing yoga on a sunrise beach," then uses them for engaging social media posts.
Job automated 2: Graphic designer createsn images for summer fitness brand campaign.
Example 3: An architect generates images that spark ideas to for the new building. They type prompts like "skyscraper covered in living walls" and "underwater hotel with transparent pods," generating visuals to inspire their sustainable architecture concepts.
Job autoamted 3: Architect generates ideas for new building.
**************************

Company: Cozy Ventures
Wesbite: https://cozy.ventures/
Current Description: Cozy Ventures is a boutique software development company that provides startups with innovative digital solutions to accelerate their growth. Composed of a team of seasoned engineers and designers, they specialize in creating custom software tailored to meet the unique needs of each client.
Tasks/Jobs: Software development,  UI/UX design,  Project management,  Technical consulting
Industry:  Software development
People Using Tool:  Startups,  Entrepreneurs
**************************
Example 1: A food delivery startup develop a custom app that integrates real-time tracking, route optimization, and communication features. 
Person automated 1: A food deliver manager is in charge of real-time tracking, route optimization, and communication for food delivery employees.
Example 2: An e-commerce company build a custom recommendation engine, powered by AI, that analyzes user behavior and preferences to offer relevant product suggestions.
Person automated 2: A market research analyst for a ecommerce company analyzes user behavior and preferences to offer relevant product suggestions
Example 3: A social media platform develops an app a sophisticated content moderation system that leverages machine learning algorithms to identify and flag inappropriate content in real-time. 
Person automated 3: A social media content moderator identifies and flag inappropriate content in real-time.
**************************


Company: PnPAI
Website: www.pnpai.co
PnPAI is an AIaaS platform that standardizes the implementation of AI across various industries, providing pre-built solutions that can be easily integrated without the need for in-house AI expertise. Catering to businesses of all sizes, PnPAI offers industry-focused solutions for sectors like ecommerce, retail, healthcare, and finance, making AI an accessible and integral part of decision-making and growth strategies.
Tasks/Jobs:  Data analysis, Predictive modeling, Automation, Optimization
Industry: AIaaS (AI as a Service)
People Using Tool: Businesses, Professionals 
**************************
Example 1: A retail manager uses PnPAI to analyze customer purchasing patterns and predict future demand for specific products. They then adjust inventory levels and optimize product placement in stores based on the AI-generated insights.
Person automated 1: A data analyst for a retail manager performs inventory management assestment to predict future custumer demand.
Example 2: An insurance company uses PnPAI to automate the risk assessment process for new clients. The AI system analyzes various data points, including credit history, driving records, and health information, to quickly determine insurance premiums and coverage options. 
Person automated 2: A risk assesser for an insurance agency uses data to perform risk assement for new clients. 
Example 3: A healthcare provider leverages PnPAI to personalize treatment plans for patients with chronic diseases. The AI analyzes patient medical history, current symptoms, and lifestyle factors to recommend optimal medication dosages and treatment strategies. 
Person automated 3: A data analysts for a healthcare company uses patient data to form personalized treatment plan creation. 
**************************
________________
Now your turn:
Company:$company
Website: $website
Current Description: $generated_description
$parsed_description
YOUR TURN:
**************************
Example 1: 
Person automated 1:
Example 2: 
Person automated 2:
Example 3:
Person automated 3:
**************************




"""
websites = list(sample_df['website'])
companies = list(sample_df['organization name'])
descriptions = list(sample_df['generated_description'])
industries = list(sample_df['parsed_description'])
labels = list(sample_df['generated_cluster_label'])
results = []
n = len(sample_df)
for i in range(0,n):
    while True:
        try:
            print(f"Processing {str(i)}: {companies[i]}")
            print(websites[i])
            print(descriptions[i])
            print(industries[i])
            print(f"Label Cluster: {labels[i]}")
            p1 = prompt.replace("$website", websites[i])\
                       .replace("$company", companies[i])\
                       .replace("$generated_description", descriptions[i])\
                       .replace("$parsed_description",industries[i])
            result = x_gemini.ask(p1)
            result = result.replace("*","").replace("Product: ","").replace("\n\n","\n")
    
            print(f"Result: {result}\n")
            results.append(result)
            break
    
        
        except Exception as e:
            print(f"Error processing {str(i)}, {companies[i]}: {e}")
            results.append(None)
            time.sleep(20)

sample_df = sample_df[:len(results)]
sample_df['examples'] = results
# Out:
# Processing 0: BLOVO Animal Health
# www.blovo.org
# BLOVO Animal Health is a cutting-edge platform that utilizes artificial intelligence and predictive data analytics to anticipate and prevent health problems in animals. The service is designed to revolutionize animal healthcare by providing proactive solutions and insights to ensure optimal animal health and wellbeing.
#
# Tasks/Jobs: Health risk prediction, Disease prevention, Early intervention, Animal health management
# Industry: Animal healthcare
# People Using Tool: Veterinarians, Animal owners
#
#
# Label Cluster: Veterinary and Pet Care Technologies
# Result:
# Example 1: A veterinarian uses a platform to analyze a pet's medical history and current health data to predict potential future health issues. This allows them to proactively recommend preventive measures and early interventions, such as diet adjustments or specific medications.
# Person automated 1: A veterinarian analyzes medical and health data to predict and diagnose health issues.
# Example 2: An animal owner uses a platform to monitor their pet's activity levels, feeding habits, and sleep patterns. The platform flags any unusual changes, alerting the owner to potential health concerns and prompting them to seek veterinary care if needed.
# Person automated 2: An animal owner analyzes and tracks pet's activity, eating habits, and sleep to detect potential health issues.
# Example 3: A farmer uses a platform to analyze herd data to identify animals at risk for specific diseases based on their breed, age, and environmental conditions. This allows the farmer to implement targeted preventive measures, such as vaccinations or dietary changes, to protect the entire herd.
# Person automated 3: A farmer analyzes herd data to identify animals at risk for specific diseases based on their breed, age, and environmental conditions.
#
#
#
# Processing 1: Enkrypt AI
# www.enkryptai.com
# Enkrypt AI provides a platform that facilitates the swift and secure integration of General AI models into enterprise systems. Their service is designed to enhance business operations by leveraging the power of AI, ensuring data security and accelerating the AI adoption process.
#
# Tasks/Jobs: AI model integration, Data security, Business process automation, AI adoption
# Industry: Enterprise software
# People Using Tool: Developers, Data scientists
#
#
# Label Cluster: AI Research and Development
# Result:
# Example 1: A software developer integrates a pre-trained language model into their company's customer service chatbot, allowing the chatbot to respond to customer inquiries in a more human-like and helpful way.
# Person automated 1:  A developer who programs chatbots for customer service has to manually integrate the language model into the system.
# Example 2: A data scientist uses Enkrypt AI to securely integrate a fraud detection AI model into their company's financial transaction system. This helps to prevent fraudulent transactions in real-time.
# Person automated 2: NOT_ONET A data scientist who secures and programs AI fraud detection systems manually integrates the AI models into the system.
# Example 3: A business analyst uses Enkrypt AI to streamline the onboarding process for new employees. By integrating a pre-trained AI model into the company's HR system, the AI can automatically collect and process information from new hires, speeding up the onboarding process.
# Person automated 3: NOT_ONET A business analyst manually manages the collection and processing of information from new hires.
#
#
#
# Processing 2: Almo Chat
# almochat.com/
# Almo Chat is an AI-driven chatbot designed to mimic human conversation, significantly increasing the capacity of customer support teams to handle and resolve customer inquiries. With multi-language support, it caters to global businesses, enhancing customer satisfaction and streamlining the efficiency of customer service operations.
#
# Tasks/Jobs: Customer support, Lead generation, Query resolution,  Information retrieval
# Industry: Customer service
# People Using Tool: Businesses, Customers
#
#
# Label Cluster: Automated Business Systems
# Result:
# Example 1: A customer service representative uses Almo Chat to answer frequently asked questions about product features and order tracking. The chatbot handles routine inquiries, freeing up the representative to focus on more complex issues.
# Person automated 1: A customer service representative answers customer questions about product features and order tracking.
# Example 2: A marketing team uses Almo Chat to collect leads and qualify potential customers. The chatbot engages website visitors with personalized greetings and prompts, collecting contact information and qualifying their interest in the company's products or services.
# Person automated 2: A marketing manager collects leads and qualifies potential customers.
# Example 3: A tech support team utilizes Almo Chat to provide immediate assistance to users experiencing technical difficulties. The chatbot can troubleshoot common problems, walk users through troubleshooting steps, and provide relevant documentation or links.
# Person automated 3: A tech support specialist provides immediate assistance to users experiencing technical difficulties.
#
#
#
# Processing 3: AsFIn
# www.asfin.ai
# AsFIn is a digital platform that utilizes artificial intelligence to provide comprehensive financial intelligence, including data analysis, diagnosis, and action plans, to organizations and professionals assisting SMEs. It essentially acts as a digital CFO for SMEs, enabling them to make informed business decisions.
#
# Tasks/Jobs: Financial analysis,  Financial reporting, Business planning, Risk assessment
# Industry: Financial intelligence
# People Using Tool:  SMEs, CFOs
#
#
# Label Cluster: Financial Management Systems
# Result: ## AsFIn Examples:
# Example 1: A small business owner uses AsFIn to analyze their financial data and identify areas for cost optimization. AsFIn suggests ways to improve cash flow, reduce expenses, and potentially renegotiate contracts.
# Person automated 1: A CFO for a small business would be responsible for cost optimization, cash flow analysis, and contract negotiations.
# Example 2: A startup uses AsFIn to create detailed financial projections for their upcoming fundraising round. AsFIn helps them build a compelling pitch deck with realistic financial data and growth projections to attract investors.
# Person automated 2: A financial analyst for a startup would be responsible for building financial projections and preparing pitch decks.
# Example 3: A company uses AsFIn to automate their monthly financial reporting process. AsFIn gathers data from various sources, analyzes it, and generates comprehensive reports, freeing up the finance team to focus on strategic initiatives.
# Person automated 3:  A financial reporting specialist would normally be responsible for gathering financial data, analyzing it, and generating reports.
#
#
# Processing 4: AI WebAssist Inc.
# www.aiwebassist.com
# AI WebAssist Inc. is an AI-driven platform that enhances internet user experience by providing intelligent analysis, promoting reliable content, and warning against deceptive websites. Additionally, it offers time-management tools to help users optimize their online activities, aiming to promote a healthier and more productive digital lifestyle.
#
# Tasks/Jobs: Website analysis, Content evaluation, Time management, Online safety
# Industry: Internet browsing
# People Using Tool: Everyone, Users
#
#
# Label Cluster: Social Media and Digital Insights
# Result:
# Example 1: A college student uses AI WebAssist to analyze the websites of different online courses, evaluating content quality and identifying potential scams before enrolling in any.
# Person automated 1: The student is performing their own website evaluation and online safety checks.
# Example 2: A busy professional utilizes AI WebAssist's time-management features to schedule specific online activities throughout the day, ensuring they efficiently manage their time for work, research, and leisure.
# Person automated 2: The professional is performing their own online time management.
# Example 3: A senior citizen relies on AI WebAssist's content evaluation to ensure the news articles they read are from reputable sources, avoiding the spread of misinformation and promoting informed decision-making.
# Person automated 3: NOT_ONET  The senior citizen is performing their own online information gathering and information verification.
#
#
#
# Processing 5: Doowii, Inc
# www.doowii.io/
# Doowii, Inc is an innovative AI-driven data platform designed to provide valuable insights to educators in the K-12 education sector. By utilizing predictive and generative AI, it revolutionizes analytics, enabling a more effective and personalized learning experience.
#
# Tasks/Jobs: Student performance analysis, Personalized learning recommendations,  Learning material creation,  Teacher workload optimization
# Industry: Education
# People Using Tool: Teachers, Students
#
#
# Label Cluster: Educational Technologies and Learning Platforms
# Result:
# Example 1: A teacher uses the platform to analyze student performance data, identifying patterns and trends to tailor their teaching strategies and provide individualized support to students who are struggling.
# Person automated 1: A teacher analyzes student performance data to personalize their teaching strategies.
# Example 2:  A student uses the AI-powered tool to receive personalized learning recommendations. Based on their learning style and progress, the platform suggests relevant learning materials, practice exercises, and supplemental resources.
# Person automated 2: NOT_ONET A student analyzes their own learning style and progress to choose learning materials, practice exercises, and supplemental resources.
# Example 3:  A teacher uses the tool to generate engaging learning materials, such as interactive quizzes, simulations, and personalized study guides, to enhance student engagement and comprehension.
# Person automated 3: A teacher generates engaging learning materials.
#
#
#
# Processing 6: SimLoop AI
# simloop.ai
# SimLoop AI is an innovative platform that enables businesses to conduct extensive user testing through millions of simulated users that replicate real-life website interactions. By identifying a metric for optimization, SimLoop AI progressively modifies the website and evaluates its performance with the simulated users, enhancing the metric with each iteration.
#
# Tasks/Jobs: Website testing, User interaction simulation, Optimization, A/B testing
# Industry: Website optimization
# People Using Tool: Developers, Marketers
#
#
# Label Cluster: Web Development and AI tools
# Result:
# Example 1: A developer uses the tool to test different website layouts to see which one results in the highest click-through rate on their call-to-action button.
# Person automated 1: A UX/UI designer or developer conducts A/B testing to see which website layout is the most effective.
# Example 2: A marketer uses the tool to optimize their landing page for conversions. They use the tool to test different headlines, images, and call-to-actions, and then use the results to improve their landing page performance.
# Person automated 2: A marketing analyst or digital marketer conducts conversion optimization for a landing page.
# Example 3: A product manager uses the tool to simulate user interactions with their new app to identify and address potential usability issues before launch.
# Person automated 3: A product manager conducts user testing for their new app to assess its usability.
#
#
#
# Processing 7: Pacerr
# pacerr.co
# Pacerr is an AI-powered platform designed to assist managers in implementing effective and engaging strategies for their teams. It provides a user-friendly interface and intelligent tools to streamline team management and enhance productivity.
#
# Tasks/Jobs: Team management, Performance tracking, Task delegation, Communication automation
# Industry: Team Management
# People Using Tool: Managers, Team leaders
#
#
# Label Cluster: Project and Team Management
# Result: ## Pacerr Examples:
# Example 1: A project manager uses Pacerr to track team members' progress on individual tasks, automatically assigning tasks based on skillsets and availability.
# Person automated 1: Project manager manually tracks team member progress and assigns tasks based on their skills.
# Example 2: A sales manager uses Pacerr to analyze team performance metrics, identifying areas for improvement and providing personalized coaching to individual team members.
# Person automated 2: Sales manager manually analyzes team performance metrics, identifies areas for improvement and provides personalized coaching.
# Example 3: A team leader uses Pacerr to automate routine communication, sending out team updates, reminders, and feedback, freeing up time for more strategic tasks.
# Person automated 3: Team leader manually sends out team updates, reminders, and feedback.
#
#
# Processing 8: Thunder
# thundercompute.com
# Thunder is a decentralized, peer-to-peer cloud computing platform designed to democratize access to GPUs and address the persistent GPU shortage. It provides a solution for individuals and businesses seeking high-performance computing power, enabling them to leverage unused GPU resources from around the world.
#
# Tasks/Jobs: GPU resource allocation, Access to unused GPUs, Distributed computing tasks, High-performance computing
# Industry: Cloud Computing
# People Using Tool: Developers, Researchers, Data Scientists
#
#
# Label Cluster: High-Performance Computing Solutions
# Result:
# Example 1: A developer uses Thunder to access high-performance GPUs for training deep learning models. This allows them to accelerate the training process and achieve faster model convergence.
# Person automated 1: NOT_ONET - Developers have to wait longer to train models.
# Example 2: A researcher utilizes Thunder to conduct computationally intensive simulations for their scientific research. They can distribute tasks across a network of GPUs, enabling faster processing and more complex simulations.
# Person automated 2: NOT_ONET - Researchers have to wait longer to complete their research.
# Example 3: A data scientist leverages Thunder to perform large-scale data processing and analysis. This enables them to handle massive datasets and extract valuable insights, driving more informed decision-making.
# Person automated 3:  NOT_ONET - Data scientists have to wait longer to complete data analysis.
#
#
#
# Processing 9: Medicod AI
# medicod-ai.tech/
# Medicod AI is an innovative healthcare software that utilizes artificial intelligence to automate and enhance medical coding and billing procedures. It aims to increase efficiency, reduce errors, ensure compliance, and improve financial performance in healthcare organizations by streamlining workflows and integrating seamlessly into existing systems.
#
# Tasks/Jobs: Medical coding, Billing, Claims processing, Workflow automation
# Industry: Healthcare
# People Using Tool: Physicians, Coders, Billers
#
#
# Label Cluster: AI Systems Development
# Result:
# Example 1: A medical coder uses Medicod AI to quickly and accurately assign codes to patient diagnoses and procedures. The software automatically identifies the most relevant codes, minimizing the risk of errors and ensuring compliance with billing regulations.
# Person automated 1: A medical coder assigns codes to patient diagnoses and procedures.
# Example 2: A billing specialist utilizes Medicod AI to process claims electronically, verifying patient eligibility, calculating charges, and submitting bills to insurance companies. The automated system reduces manual effort and streamlines the billing process.
# Person automated 2: A billing specialist processes claims electronically.
# Example 3: A physician uses Medicod AI to generate detailed patient summaries and medical reports. The AI-powered tool automatically extracts key information from medical records, saving time and reducing the likelihood of errors in documentation.
# Person automated 3: A physician generates detailed patient summaries and medical reports.
#
#
#
# Processing 10: AiToolHunt
# www.aitoolhunt.com/
# AiToolHunt is a comprehensive online platform that aggregates and provides access to the best free AI tools, software, and websites to enhance users' digital experiences. It serves as a one-stop destination for discovering top-tier AI innovations and use cases, aiming to empower users in their tech journey.
#
# Tasks/Jobs: AI tool discovery, AI tool comparison, AI tool integration, AI tool access
# Industry: AI tools discovery
# People Using Tool:  Everyone, Developers, Businesses
#
#
# Label Cluster: AI Research and Development
# Result:
# Example 1: A developer uses AiToolHunt to quickly find the most suitable image recognition API for their project, saving time on researching and comparing various options.
# Person automated 1: A developer spends time researching and comparing various image recognition APIs.
# Example 2:  A business owner uses AiToolHunt to discover and compare AI-powered customer service chatbots, ultimately selecting the best one to automate their customer support and improve response times.
# Person automated 2: A business owner has to research AI-powered customer service chatbots.
# Example 3: A student utilizes AiToolHunt to access a free AI-powered writing assistant that helps them write better essays by providing grammar suggestions, improving sentence structure, and generating ideas.
# Person automated 3: A student writes essays.
#
#
#
# Processing 11: AIrtizen
# airtizen.com/
# AIrtizen is a solopreneur-driven venture that specializes in creating automated workflows using artificial intelligence to transform ordinary businesses into efficient entities. With a focus on simplicity and cost-effectiveness, AIrtizen leverages AI to develop innovative, time-saving tools that have proven to be lucrative game changers, contributing to over $30 million in business revenue.
#
# Tasks/Jobs: Workflow automation, Business process optimization, Customer service, Data analysis
# Industry: Business automation
# People Using Tool: Entrepreneurs, Solopreneurs
#
#
# Label Cluster: Creative Business Tools
# Result:
# Example 1: A solopreneur uses AI to automate customer service responses, allowing them to focus on other aspects of their business. The AI system analyzes incoming emails and messages, providing instant answers to frequently asked questions, while escalating complex inquiries to the entrepreneur.
# Person automated 1:  NOT_ONET A solopreneur would be the one responding to customer service requests.
# Example 2: An entrepreneur uses AI to optimize their social media marketing strategy. The AI analyzes data on audience engagement, identifies peak posting times, and suggests content formats that resonate with their target audience.
# Person automated 2:  NOT_ONET  An entrepreneur would be the one managing their social media marketing.
# Example 3: A solopreneur uses AI to automate their bookkeeping tasks. The AI system extracts data from invoices and bank statements, categorizes expenses, and generates financial reports, allowing the entrepreneur to focus on other business activities.
# Person automated 3:  NOT_ONET A solopreneur would be the one handling bookkeeping.
#
#
#
# Processing 12: fyby.io
# fyby.io
# Fyby.io is an AI-powered marketplace that assists businesses in discovering, purchasing, and managing software, tech services, and bundled solutions. It streamlines the procurement process by providing a data-driven platform for SaaS products and tech-related service solutions.
#
# Tasks/Jobs: Software discovery, Software procurement, Software management, Service discovery
# Industry: SaaS Marketplace
# People Using Tool: Businesses, IT managers
#
#
# Label Cluster: Mobile and Software Development Technologies
# Result:
# Example 1:  An IT manager uses the platform to research and compare different cloud storage solutions for their company's data backup needs. They then purchase the most suitable option directly through the platform, streamlining the procurement process.
# Person automated 1: An IT manager researches and compares different cloud storage solutions.
# Example 2:  A small business owner utilizes the platform to identify and acquire a CRM system that aligns with their specific needs. The platform's recommendation engine suggests relevant software options based on the business's size, industry, and budget.
# Person automated 2: A small business owner researches and compares different CRM systems.
# Example 3: A marketing team uses the platform to find and subscribe to a marketing automation tool. The platform helps them manage their subscription, access support resources, and track their usage, simplifying the management of the software.
# Person automated 3: A marketing manager researches and compares different marketing automation software.
#
#
#
# Processing 13: Adhesible
# www.adhesible.com/
# Adhesible is an AI-powered platform that scans and analyzes digital content in real time, extracting a multitude of data points such as sentiment, emotion, categories, keywords, age-rating, and brand safety. This service provides a comprehensive understanding of digital content, enabling users to make informed decisions and strategies.
#
# Tasks/Jobs: Content analysis, Sentiment analysis, Keyword extraction, Brand safety assessment
# Industry: Digital content analysis
# People Using Tool: Marketers, Advertisers
#
#
# Label Cluster: Social Media and Digital Insights
# Result:
# Example 1: A marketing manager uses Adhesible to analyze the sentiment of social media posts about a new product launch, identifying any negative feedback and proactively addressing customer concerns.
# Person automated 1: A social media analyst uses social media data to identify and address negative feedback about a product.
# Example 2: An advertiser uses Adhesible to optimize their ad campaigns by analyzing the keywords and categories associated with various content, ensuring that their ads are displayed alongside relevant and brand-safe material.
# Person automated 2: A marketing specialist analyzes digital content to find the most appropriate keywords to use in an ad campaign.
# Example 3: A content creator uses Adhesible to determine the age rating and brand safety of their videos before publishing them online, ensuring that they are appropriate for their target audience and align with their brand values.
# Person automated 3: A content creator uses data to determine the age rating of their content.
#
#
#
# Processing 14: Ycotek
# ycotek.ai/
# Ycotek is an AI-powered professional services firm that provides expertise in cloud enablement, application development, data, analytics, and artificial intelligence. Their dynamic, global delivery model allows clients to gain a competitive edge through innovative and efficient solutions.
#
# Tasks/Jobs: Cloud enablement, application development, data analysis, AI implementation
# Industry: Professional services
# People Using Tool: Businesses, Enterprises
#
#
# Label Cluster: AI Systems Development
# Result:
# Example 1: A marketing manager uses the AI-powered platform to analyze customer data and identify trends in purchase behavior. The insights are then used to create targeted marketing campaigns that resonate with specific customer segments.
# Person automated 1: A market researcher for a marketing manager analyzes customer data and trends in purchase behavior.
# Example 2: A software development team utilizes the platform to automate code testing and deployment processes, reducing manual effort and accelerating development cycles.
# Person automated 2: A software developer performs code testing and deployment tasks.
# Example 3: A financial institution deploys the platform to assess creditworthiness and automate loan application processing, streamlining operations and improving efficiency.
# Person automated 3: A loan officer assesses creditworthiness and performs loan application processing tasks.
#
#
#
# Processing 15: Locusive
# www.locusive.com
# Locusive is an AI-powered assistant designed to streamline customer service for businesses, providing users with quick and accurate answers to their queries. This platform not only enhances the user experience by simplifying the process of finding information, but also allows Customer Success Managers to focus on more strategic tasks by automating responses to common questions.
#
# Tasks/Jobs: Customer service automation, Knowledge base management, Response generation, Customer support scaling
# Industry: Customer service
# People Using Tool: Customer service managers, Customer support teams
#
#
# Label Cluster: Automated Business Systems
# Result:
# Example 1: A customer support agent uses Locusive to instantly answer a customer's question about the company's return policy, freeing up time to handle more complex issues.
# Person automated 1: A customer service agent answers customer questions about return policies.
# Example 2: A customer success manager uses Locusive to create a comprehensive knowledge base for their product, enabling customers to easily find answers to their questions without needing to contact support.
# Person automated 2: NOT_ONET A customer success manager creates a comprehensive knowledge base for their product.
# Example 3: A small business owner uses Locusive to automate responses to common customer inquiries, allowing them to scale their customer support operations without hiring additional staff.
# Person automated 3: NOT_ONET A small business owner answers common customer inquiries.
#
#
#
# Processing 16: Embriot
# embriot.net
# Embriot is a forward-thinking startup that leverages machine learning and deep learning technologies to create data-driven solutions capable of predicting industry trends and events. Their goal is to equip businesses and individuals with the ability to anticipate and strategize, transforming uncertainty into proactive planning and fostering data-driven growth and operational efficiency.
#
# Tasks/Jobs: Trend prediction, Event forecasting, Data-driven strategy, Operational optimization
# Industry: Predictive Analytics
# People Using Tool: Businesses, Individuals
#
#
# Label Cluster: AI Systems Development
# Result:
# Example 1: A marketing manager uses Embriot to analyze customer trends and predict which products will be in high demand during the upcoming holiday season. They then adjust their marketing campaigns and inventory levels accordingly.
# Person automated 1: A data analyst for a marketing agency uses data to analyze customer trends and predict product demand.
# Example 2: A financial advisor uses Embriot to forecast potential market fluctuations based on global economic indicators and political events. They use this information to advise their clients on investment strategies and risk management.
# Person automated 2: A financial analyst for a financial advising agency uses global economic indicators and political events to forecast potential market fluctuations.
# Example 3: An HR manager uses Embriot to identify emerging skills gaps in their industry and predict future workforce needs. They then implement training programs and talent acquisition strategies to proactively address these anticipated challenges.
# Person automated 3: A data analyst for an HR agency uses data to identify emerging skills gaps in the workforce and predict future needs.
#
#
#
# Processing 17: Tellen
# www.tellen.ai/
# Tellen provides an AI infrastructure specifically designed for accounting firms, facilitating the development and deployment of secure, compliant generative AI solutions. This platform aims to boost productivity, enhance quality, and address talent shortages in the accounting industry by enabling firms to seamlessly integrate generative AI technology into their operations.
#
# Tasks/Jobs: Financial reporting, Auditing, Tax preparation, Client communication
# Industry: Accounting
# People Using Tool: Accountants, CPAs
#
#
# Label Cluster: Tax and Accounting Automation
# Result:
# Example 1: An accountant uses Tellen to generate personalized financial reports for their clients, tailoring the information based on individual needs and preferences.
# Person automated 1: An accountant creates personalized financial reports for their clients.
# Example 2: A CPA utilizes Tellen to automate the process of auditing financial records, identifying potential discrepancies and anomalies through AI-powered analysis.
# Person automated 2: A CPA audits financial records.
# Example 3: An accounting firm uses Tellen to draft comprehensive tax preparation documents for clients, leveraging AI to ensure accuracy and compliance with ever-changing tax regulations.
# Person automated 3: An accountant drafts tax preparation documents for clients.
#
#
#
# Processing 18: AI Generative Lab - AIGL
# www.aigenerative.ae/
# AI Generative Lab - AIGL is a company focused on the development and commercialization of AI-driven products designed to enhance human potential and transform lifestyles. Their diverse range of AI products, including the Prompt Engineer, are aimed at simplifying and optimizing AI interactions.
#
# Tasks/Jobs: Prompt engineering, Content generation, AI model training, AI application development
# Industry: AI-driven products
# People Using Tool: Developers, Businesses, Individuals
#
#
# Label Cluster: AI Systems Development
# Result:
# Example 1: A content writer uses AIGL's Prompt Engineer to generate engaging and informative blog posts on various topics by inputting specific keywords and desired writing styles.
# Person automated 1: NOT_ONET A writer creates  engaging and informative blog posts by hand, spending hours researching, crafting, and editing.
# Example 2: A marketing team uses AIGL to create personalized email campaigns for customers, tailoring the content and offers based on individual purchase history and preferences.
# Person automated 2: A marketer develops email marketing campaigns that are generally targeted to demographics rather than individual preferences.
# Example 3: A software developer uses AIGL to streamline the process of building and deploying AI-powered applications. The tool automates tasks such as data preparation, model selection, and code generation, enabling faster and more efficient development.
# Person automated 3: A software developer builds and deploys AI-powered applications from scratch, performing time consuming tasks such as data preparation, model selection, and code generation.
#
#
#
# Processing 19: Go Boldly
# gobold.ly
# Go Boldly is a mobile application that uses AI and gamification to provide personalized financial education for young adults. The app offers bite-sized lessons on various financial topics, such as saving for a home or planning for college expenses, empowering users with the knowledge and skills needed to navigate their financial journey.
#
# Tasks/Jobs: Financial literacy, Budgeting, Investing, Savings planning
# Industry: Personal finance
# People Using Tool: Young adults
#
#
# Label Cluster: Financial Management Systems
# Result:
# Example 1: A young adult uses Go Boldly to set up a budget that aligns with their personal financial goals, like saving for a down payment on a car. The app provides personalized guidance and insights to help them track expenses, manage income, and achieve their financial aspirations.
# Person automated 1: NOT_ONET A young adult learns how to make a budget by using the Go Boldly app.
# Example 2: A college student uses Go Boldly to learn about different investing strategies, such as mutual funds and index funds, and to begin investing small amounts of money to build wealth over time. The app's gamified approach makes learning engaging and helps them develop a solid financial foundation.
# Person automated 2: A financial advisor gives investment advice and education.
# Example 3:  A young adult uses Go Boldly to learn about credit scores and the importance of managing debt. The app provides educational resources and tools to help them understand their credit history and make informed decisions about borrowing money.
# Person automated 3: NOT_ONET A young adult learns how to manage credit scores and debt by using the Go Boldly app.
#
#
#
# Processing 20: AppJust
# appjust.co
# AppJust is a cutting-edge platform that leverages artificial intelligence to develop advanced mobile applications. It offers AI-powered mobile apps designed to enhance user experience and streamline business operations.
#
# Tasks/Jobs: Mobile app development, UI/UX design, Feature optimization, Data analysis
# Industry: Mobile app development
# People Using Tool: Developers, Businesses
#
#
# Label Cluster: Mobile and Software Development Technologies
# Result:
# Example 1: A developer uses AppJust to quickly build a prototype of a new mobile game, testing different game mechanics and user interface designs with AI-powered suggestions.
# Person automated 1:  A game developer creates a prototype mobile game using their own code.
# Example 2: An e-commerce business utilizes AppJust to create a personalized mobile shopping experience for their customers, analyzing user data to suggest products and streamline the checkout process.
# Person automated 2: A data scientist analyzes user data to create a personalized mobile shopping experience for customers.
# Example 3: A restaurant owner uses AppJust to develop a mobile ordering and delivery app, integrating real-time order tracking and online payment options.
# Person automated 3: A software developer integrates real-time order tracking and online payment options into a mobile ordering app for a restaurant.
#
#
#
# Processing 21: Gigly
# gigly.io
# Gigly is an AI-driven platform designed to optimize the work experience for gig economy participants by providing intelligent scheduling and seamless earnings management. It also fosters a supportive community for gig workers, enabling them to maximize their income, achieve work flexibility, and fully realize their potential in the gig economy.
#
# Tasks/Jobs: Scheduling, Earnings management, Community building, Work flexibility
# Industry: Gig economy
# People Using Tool: Gig workers, Freelancers
#
#
# Label Cluster: Educational Technologies and Learning Platforms
# Result:
# Example 1: A freelance writer uses Gigly to optimize their workload, accepting projects that fit their desired schedule and earning potential, while also connecting with other freelance writers in the community.
# Person automated 1: A freelance writer is in charge of scheduling work and finding clients.
# Example 2: A delivery driver utilizes Gigly to manage their daily routes, maximizing efficiency and earnings by accepting delivery requests that optimize their travel time and ensure optimal compensation.
# Person automated 2: A delivery driver is in charge of scheduling their route and accepting delivery requests.
# Example 3: A freelance graphic designer uses Gigly to find design projects that align with their skills and interests, leveraging the platform's community to network with other designers and collaborate on projects.
# Person automated 3: A freelance graphic designer is in charge of finding design work and networking with other freelance graphic designers.
#
#
#
# Processing 22: SendBlue.ai
# www.sendblue.ai/
# SendBlue.ai is an AI-powered platform designed to streamline B2B sales outreach by generating personalized emails using the URL of a target company. It utilizes generative AI technology to research potential leads, craft tailored messages, and enable sales professionals to send personalized sales pitches at scale, freeing up time for relationship building and deal closing.
#
# Tasks/Jobs: Sales outreach, Email writing, Lead generation, Sales automation
# Industry: B2B Sales
# People Using Tool: Sales professionals, Business developers
#
#
# Label Cluster: Sales and Marketing Outreach
# Result:
# Example 1: A sales representative uses SendBlue.ai to generate personalized emails to potential clients in the tech industry. The platform researches the companies, identifies key decision-makers, and crafts tailored messages that highlight the value proposition of the representative's products or services.
# Person automated 1: A sales representative researches the companies, identifies key decision-makers, and crafts tailored messages that highlight the value proposition of the representative's products or services.
# Example 2: A business development manager utilizes SendBlue.ai to launch a targeted email campaign to startups in the fintech sector. The platform automatically generates emails that resonate with the specific challenges and opportunities faced by these companies, leading to more relevant conversations and potential partnerships.
# Person automated 2: A business development manager researches the companies, identifies key decision-makers, and crafts tailored messages that highlight the value proposition of the representative's products or services.
# Example 3: A sales team uses SendBlue.ai to automate the process of sending follow-up emails to leads who have expressed interest in their services. The platform analyzes the lead's website and past interactions to create personalized emails that encourage engagement and ultimately drive conversions.
# Person automated 3: NOT_ONET  This is a task that would likely be done by the sales team but may not be a dedicated role within the organization.
#
#
#
# Processing 23: WriteAI.me
# writeai.me
# WriteAI.me is an all-inclusive AI writing tool that offers a wide range of features including over 80 templates, a document editor, a blog post wizard, and a brand voice generator. It also provides an image generator, a license-free image search, and an AI chatbot, making it a comprehensive solution for content creation and editing needs.
#
# Tasks/Jobs: Content creation, Blog writing,  Copywriting, Email writing
# Industry: AI writing tools
# People Using Tool: Marketers, Writers, Bloggers, Anyone
#
#
# Label Cluster: Creative Content and Media Tools
# Result:
# Example 1: A blogger uses the platform to create an engaging and informative blog post about "the top 10 travel destinations for solo travelers," using the built-in template and AI-generated content suggestions.
# Person automated 1: NOT_ONET - A blogger writes a blog post about the top 10 travel destinations for solo travelers.
# Example 2: A marketing manager creates compelling social media captions for a new product launch, using the AI-powered copywriting tool to generate catchy and persuasive language that resonates with their target audience.
# Person automated 2: A marketing manager writes social media captions for a new product launch.
# Example 3: A freelance writer uses the AI writing assistant to generate a professional email to a potential client, customizing the tone and style to match their brand voice and making sure the message is persuasive and concise.
# Person automated 3: A freelance writer composes a professional email to a potential client.
#
#
#
# Processing 24: WOWie
# —
# WOWie is an AI-driven retail platform designed to revolutionize the retail sector by facilitating enhanced interactions between businesses and their customers. It leverages artificial intelligence to provide a smart retail experience, aiming to streamline operations and improve customer engagement.
#
# Tasks/Jobs: Customer service, Product recommendations, Inventory management, Marketing automation
# Industry: Retail
# People Using Tool: Retailers, Shoppers
#
#
# Label Cluster: E-commerce and Retail Strategies
# Result:
# Example 1: A retail worker uses WOWie to answer customer questions about product availability, store hours, and promotions, all while suggesting complementary items based on the customer's interests.
# Person automated 1: A customer service representative answers customer questions about product availability, store hours, and promotions.
# Example 2: An online retailer uses WOWie to analyze customer purchase history and browsing behavior, providing personalized product recommendations that drive sales and increase customer satisfaction.
# Person automated 2: A market research analyst for an online retailer analyzes customer purchase history and browsing behavior to recommend products for sales.
# Example 3: A clothing store owner uses WOWie to optimize inventory levels by forecasting demand based on seasonal trends, weather patterns, and customer preferences, reducing waste and maximizing profitability.
# Person automated 3: A data analyst for a retail store forecasts demand based on seasonal trends, weather patterns, and customer preferences to adjust inventory levels.
#
#
#
# Processing 25: Palatine Growth Credit
# palatinegrowthcredit.com/
# Palatine Growth Credit offers financial support to ambitious and innovative tech businesses located outside of London, particularly in the North, Midlands, South West, and South East regions of the UK. Their Growth Credit strategy targets companies in sectors such as cyber, fintech, SaaS, healthtech, medtech, AI, and advanced manufacturing, fostering growth in these burgeoning technology ecosystems.
#
# Tasks/Jobs: Financial analysis, Investment decision making, Due diligence, Portfolio management
# Industry: Venture Capital
# People Using Tool: Venture capitalists, Investors
#
#
# Label Cluster: Venture Capital and Financing
# Result:
# Example 1: A venture capitalist uses Palatine Growth Credit's platform to evaluate the financial health and growth potential of a promising fintech startup in the Midlands. The platform analyzes key financial metrics and market trends, highlighting potential risks and opportunities.
# Person automated 1: A financial analyst evaluates the financial health and growth potential of a promising startup.
# Example 2: An investor uses Palatine Growth Credit's platform to assess the viability of investing in a cyber security company in the South West. The platform provides detailed information about the company's technology, market position, and competitive landscape, helping the investor make an informed decision.
# Person automated 2: A market researcher assesses the viability of investing in a company.
# Example 3: A portfolio manager uses Palatine Growth Credit's platform to track the performance of their investments in the AI sector. The platform provides real-time updates on the companies' financial performance, industry trends, and regulatory changes, enabling the manager to optimize their portfolio.
# Person automated 3: A portfolio manager tracks the performance of their investments.
#
#
#
# Processing 26: Rivio
# www.rivio.ai/
# Rivio is an AI-driven procurement platform specifically designed for hardware companies, aiming to streamline and optimize the procurement process. By utilizing AI to analyze historical data and real-time market prices, Rivio can autonomously contact suppliers, negotiate terms, and identify potential savings, all with a single click.
#
# Tasks/Jobs: Supplier identification, Price negotiation, Order placement, Contract management
# Industry: Procurement
# People Using Tool: Hardware companies, Procurement teams
#
#
# Label Cluster: Industrial Sourcing Solutions
# Result:
# Example 1: A procurement manager at a hardware company uses Rivio to identify potential new suppliers for a specific component. The platform analyzes market data and recommends suppliers based on factors like price, quality, and delivery time.
# Person automated 1: A procurement manager at a hardware company researches and identifies potential new suppliers.
# Example 2: A procurement specialist uses Rivio to negotiate better pricing on a large order of circuit boards. The platform automatically gathers historical pricing data, analyzes market trends, and suggests optimal negotiation strategies, helping the specialist secure a more favorable deal.
# Person automated 2: A procurement specialist negotiates better pricing for components with suppliers.
# Example 3: An engineer at a hardware company needs to order a specific type of semiconductor. Rivio automatically finds the best supplier based on the engineer's requirements, places the order, and manages the contract, freeing up the engineer to focus on their core work.
# Person automated 3: An engineer at a hardware company places an order for components and manages contracts with suppliers.
#
#
#
# Processing 27: doctor Z
# drzvitals.com/
# Doctor Z is developing a compact, all-in-one diagnostic device that measures blood pressure, sugar levels, oxygen levels, and body temperature, and uses AI to detect early signs of lifestyle diseases. The device pairs with your smartphone, sending reports directly to your doctor, making it a convenient tool for online consultations and rendering traditional individual devices obsolete.
#
# Tasks/Jobs: Blood pressure monitoring, Blood sugar monitoring, Oxygen level monitoring, Body temperature monitoring
# Industry: Healthcare
# People Using Tool: Everyone, Doctors
#
#
# Label Cluster: Healthcare Data Management Systems
# Result:
# Example 1: A person at home takes their blood pressure reading using the device, and the results are automatically sent to their doctor.
# Person automated 1: A person takes their own blood pressure.
# Example 2: A doctor reviews the health data collected by the device, detecting early signs of potential health issues and suggesting follow-up appointments or lifestyle changes.
# Person automated 2: A doctor reviews patient data and makes recommendations.
# Example 3: A person checks their blood sugar levels before a meal, and the device helps them to track their levels over time, aiding them in managing their diabetes.
# Person automated 3: A diabetic patient monitors their own blood sugar levels.
#
#
#
# Processing 28: Taxly.Ai
# taxly.ai/
# Taxly.Ai is an AI-powered tax assistant that simplifies and streamlines the tax filing process in Australia, offering features such as intelligent tax filing, real-time guidance, and secure data handling. With advanced algorithms for increased accuracy and automation for time efficiency, Taxly.Ai provides a cost-effective solution for stress-free tax filing.
#
# Tasks/Jobs: Tax return preparation, Tax planning, Tax documentation management, Tax compliance reporting
# Industry: Tax preparation
# People Using Tool: Taxpayers, Australians
#
#
# Label Cluster: Tax and Accounting Automation
# Result:
# Example 1: A small business owner uses Taxly.ai to prepare their annual income tax return, providing the AI with information on their income, expenses, and deductions. The tool then automatically calculates the tax owed and files the return on their behalf.
# Person automated 1: A tax accountant prepares an annual income tax return for a small business owner.
# Example 2: An individual uses Taxly.ai to track their income and expenses throughout the year, receiving real-time tax advice and guidance on how to maximize their deductions. The AI tool helps them understand their tax liability and plan for future tax obligations.
# Person automated 2:  NOT_ONET.
# Example 3: A property investor uses Taxly.ai to manage their tax-related paperwork, including rental income, expenses, and depreciation claims. The AI platform simplifies documentation management, ensures compliance with tax regulations, and helps optimize their investment strategies.
# Person automated 3: A financial advisor manages tax related paperwork for a property investor.
#
#
#
# Processing 29: Resume Ninja
# resumeninja.io/
# Resume Ninja is a comprehensive online tool that simplifies the process of creating professional resumes through its user-friendly interface and a wide selection of customizable templates. Leveraging advanced AI technology, it can generate engaging summaries, bullet points, and even a full resume tailored to specific job descriptions, making the task of resume creation quick and effortless.
#
# Tasks/Jobs: Resume writing, Cover letter writing, Job application, Job search
# Industry: Career development
# People Using Tool: Job seekers, Professionals
#
#
# Label Cluster: Career Development Tools
# Result:
# Example 1: A job seeker uses Resume Ninja to create a compelling resume that highlights their skills and experience relevant to a specific job they're applying for. They simply input their information and select from various templates, and the tool automatically generates a professional document.
# ...
#
# Tasks/Jobs: Calendar scheduling, Notifications prioritization, Project tracking, Data analysis
# Industry: Productivity & Workflow Automation
# People Using Tool: Knowledge Workers, Teams
#
#
# Label Cluster: Automated Business Systems
# Result:
# Example 1: A marketing manager uses the platform to analyze customer engagement data and identify trends, helping them to prioritize marketing efforts and optimize campaign performance.
# Person automated 1: A marketing analyst uses data to analyze customer engagement data and identify trends.
# Example 2: A software developer uses the platform to track project deadlines and collaborate with team members, ensuring timely completion of tasks and effective communication.
# Person automated 2: A project manager tracks project deadlines and collaborates with team members.
# Example 3: A sales representative uses the platform to schedule meetings and prioritize follow-up tasks, maximizing their time and increasing sales conversion rates.
# Person automated 3: A sales rep manages their schedule and prioritizes task by using a planner or calendar.
#
#
#
# Processing 191: Panza AI
# www.panza.ai/
# Panza AI offers an artificial intelligence platform designed to assist financial institutions in mitigating balance sheet risk and ensuring product compliance. The platform leverages AI to continuously monitor and evaluate risks across various data sources, enabling banks to reduce risks, enforce regulatory compliance, and streamline risk analysis workflows at a fraction of the cost of a full-time employee.
#
# Tasks/Jobs: Risk analysis, Regulatory compliance, Data monitoring, Workflow optimization
# Industry: Financial Services
# People Using Tool: Financial institutions, Risk managers
#
#
# Label Cluster: Regulatory Compliance and Risk Management
# Result:
# Example 1: A bank uses Panza AI to analyze customer credit history and transaction patterns to identify potential fraud risks in real-time, automatically flagging suspicious activities and reducing losses.
# Person automated 1: A fraud analyst analyzes customer credit history and transaction patterns to identify potential fraud risks.
# Example 2: A financial advisor uses Panza AI to monitor market trends and regulatory changes, ensuring their investment strategies remain compliant and minimizing potential legal and financial risks.
# Person automated 2: A compliance officer monitors market trends and regulatory changes to ensure their investment strategies remain compliant.
# Example 3: A risk manager for a large investment firm uses Panza AI to evaluate the creditworthiness of potential borrowers, automating the process of gathering and analyzing financial data to make faster and more informed lending decisions.
# Person automated 3: A credit analyst evaluates the creditworthiness of potential borrowers by gathering and analyzing financial data to make faster and more informed lending decisions.
#
#
#
# Processing 192: RAIBS
# raibs.co/
# RAIBS specializes in the development of advanced, user-friendly mobile applications that integrate artificial intelligence to boost your business's digital presence. Their dedicated team designs immersive and dynamic app interfaces aimed at engaging your target audience and promoting business growth.
#
# Tasks/Jobs: App Development, User Interface Design, Artificial Intelligence Integration, Business Growth Promotion
# Industry: Mobile App Development
# People Using Tool: Business Owners, App Developers
#
#
# Label Cluster: Mobile and Software Development Technologies
# Result:
# Example 1: A retail store owner develops a mobile app with RAIBS that utilizes AI to personalize customer recommendations, boosting sales and loyalty.
# Person automated 1: A marketing manager for a retail store identifies and implements marketing tactics to improve customer loyalty and boost sales.
# Example 2: A restaurant owner uses RAIBS to create an app that allows customers to order food online, manage reservations, and receive personalized recommendations based on their past preferences.
# Person automated 2: A restaurant manager creates a system of online ordering, manages reservations and generates customer recommendations based on preferences.
# Example 3: An event planner uses RAIBS to build a mobile app that facilitates event registration, ticketing, and real-time updates, ensuring a smooth and seamless experience for attendees.
# Person automated 3: An event planner manages event registration and ticketing systems, providing real-time updates.
#
#
#
# Processing 193: Fincortex.ai
# fincortex.ai
# Fincortex.ai is an AI-powered platform that enhances business productivity by providing real-time insights, intelligence, and automated workflows through a conversational interface named Leo. Users can interact with Leo using voice commands to ask questions or give complex instructions, unlocking endless possibilities for business growth and efficiency.
#
# Tasks/Jobs: Data analysis, Process automation, Workflow management, Business intelligence
# Industry: Business automation
# People Using Tool: Business owners, Managers, Employees
#
#
# Label Cluster: Automated Business Systems
# Result: ## Fincortex.ai Examples:
# Example 1: A marketing manager uses Fincortex.ai to analyze customer feedback from social media posts, identify emerging trends, and automate the creation of targeted marketing campaigns based on the insights.
# Person automated 1: A social media analyst would typically analyze customer feedback and create targeted marketing campaigns.
# Example 2: A sales manager uses Fincortex.ai to streamline the sales process by automating lead qualification, generating personalized sales proposals, and scheduling follow-up appointments based on customer interactions.
# Person automated 2: A sales representative would normally qualify leads, generate proposals, and schedule appointments.
# Example 3: A project manager uses Fincortex.ai to monitor project progress, identify potential risks and delays, and automatically adjust resource allocation and deadlines based on real-time updates.
# Person automated 3:  A project manager would usually track project progress, identify risks, and adjust resources and deadlines.
#
#
# Processing 194: AI Lawyer
# ailawyer.pro/
# AI Lawyer is an AI-driven platform designed to assist both legal professionals and consumers by providing instant legal advice and support. For lawyers, it acts as a co-pilot, helping to streamline their work, while for consumers, it offers immediate legal assistance, making legal advice more accessible and understandable.
#
# Tasks/Jobs: Legal research, Document drafting, Contract review, Legal advice
# Industry: Legal Tech
# People Using Tool: Lawyers, Consumers
#
#
# Label Cluster: Legal and Technological Automation
# Result:
# Example 1: A lawyer uses AI Lawyer to quickly draft a standard contract, saving time and ensuring the document is legally sound.
# Person automated 1: A lawyer spends time drafting contracts and ensuring they are legally sound.
# Example 2: A small business owner uses AI Lawyer to get immediate answers to basic legal questions regarding their business operations, like employment contracts or intellectual property rights.
# Person automated 2: NOT_ONET A person needing legal advice regarding business operations would have to call a lawyer.
# Example 3: A paralegal uses AI Lawyer to conduct thorough legal research, gathering relevant case law and statutes to support a case being prepared for trial.
# Person automated 3: A paralegal spends time conducting legal research, gathering relevant case law and statutes to support a case being prepared for trial.
#
#
#
# Processing 195: Diawiser
# diawiser.com
# Diawiser is an AI-powered health assistant designed to transform unstructured data into personalized, medically accurate insights for efficient diabetes management. It leverages artificial intelligence to provide actionable and understandable health insights, empowering individuals with diabetes to better manage their condition.
#
# Tasks/Jobs: Data analysis, Health insights, Medication management, Personalized recommendations
# Industry: Healthcare
# People Using Tool: Diabetics, Healthcare professionals
#
#
# Label Cluster: Healthcare Data Management Systems
# Result:
# Example 1: A person with diabetes uses Diawiser to analyze their blood glucose readings, meal logs, and medication data to identify patterns and trends, allowing them to make informed decisions about their diabetes management.
# Person automated 1:  A diabetic person manually analyzes their blood glucose readings, meal logs, and medication data to identify patterns and trends, allowing them to make informed decisions about their diabetes management.
# Example 2: A healthcare professional uses Diawiser to track their diabetic patients' progress, providing personalized insights and recommendations for medication adjustments, lifestyle changes, and follow-up appointments.
# Person automated 2:  A healthcare professional manually tracks their diabetic patients' progress and provides personalized insights and recommendations for medication adjustments, lifestyle changes, and follow-up appointments.
# Example 3: A diabetic individual uses Diawiser to set personalized reminders for medication intake, blood glucose testing, and appointments, ensuring they stay on track with their diabetes management plan.
# Person automated 3: A diabetic individual sets manual reminders for medication intake, blood glucose testing, and appointments, ensuring they stay on track with their diabetes management plan.
#
#
#
# Processing 196: ROBOPIC
# robopic.me/
# ROBOPIC is an innovative platform that utilizes artificial intelligence to generate high-quality photos and videos without the need for a physical camera. It offers a unique solution for content creators, marketers, and businesses seeking to create visually appealing and professional-grade digital content.
#
# Tasks/Jobs: Photo generation, Video creation, Content creation, Marketing materials
# Industry: Digital content creation
# People Using Tool: Marketers, Content creators, Businesses
#
#
# Label Cluster: Creative Business Tools
# Result:
# Example 1: A social media manager uses the platform to generate high-quality images for an upcoming product launch, creating visual assets that highlight the key features of the product.
# Person automated 1: NOT_ONET A social media manager is in charge of generating high-quality images for an upcoming product launch.
# Example 2: A freelance graphic designer uses the platform to quickly generate different variations of a logo for a client, showcasing different color palettes and design styles.
# Person automated 2: A freelance graphic designer is responsible for generating logo ideas for a client.
# Example 3: A marketing team uses the platform to create engaging video content for a new marketing campaign, incorporating diverse visuals and animation elements to capture audience attention.
# Person automated 3: NOT_ONET  A marketer uses the platform to create engaging video content for a new marketing campaign.
#
#
#
# Processing 197: Permio AI
# www.permio.ai/
# Permio AI is an innovative platform that utilizes artificial intelligence to expedite the building permit approval process by identifying and correcting submittal and code compliance errors. This results in faster approval times, enabling users to commence construction sooner, reduce costs, and achieve better returns.
#
# Tasks/Jobs: Permit review, Code compliance checks, Error identification, Submittal correction
# Industry: Construction
# People Using Tool: Architects, Contractors
#
#
# Label Cluster: Construction and Workflow Automation
# Result:
# Example 1: An architect uses Permio AI to review building plans before submitting them for approval. The tool automatically identifies and highlights potential code violations and submittal errors, enabling the architect to make corrections before submitting the plans.
# Person automated 1: A building inspector checks for code violations and submittal errors in building plans.
# Example 2: A contractor submits plans for a new residential project. Permio AI quickly reviews the plans and flags a missing fire sprinkler system, allowing the contractor to make the necessary changes and expedite the permit approval process.
# Person automated 2: A building permit reviewer checks for completeness and code compliance in building plans.
# Example 3: A developer uses Permio AI to review the plans for a large-scale commercial project. The AI system identifies a structural weakness and recommends design modifications to ensure the building’s safety. This proactive approach saves time and costs by preventing costly rework later in the construction process.
# Person automated 3: A structural engineer reviews building plans for structural integrity and compliance with building codes.
#
#
#
# Processing 198: Kapeta
# kapeta.com
# Kapeta is an innovative platform that utilizes advanced open-source technology and AI to streamline and automate the software development process. It integrates various aspects of software development such as framework, API management, CI/CD, security, and monitoring, allowing software engineers to focus on value creation while the platform handles the rest.
#
# Tasks/Jobs: Framework creation, API management, CI/CD automation, Security and monitoring
# Industry: Software Development
# People Using Tool: Software engineers, Developers
#
#
# Label Cluster: Development Tools Automation
# Result:
# Example 1: A software developer uses the platform to automate the deployment of their web application to a cloud server, ensuring smooth and consistent releases while they focus on coding new features.
# Person automated 1: A DevOps engineer deploys web applications to cloud servers.
# Example 2: A developer leverages the platform to create a secure API for their mobile application, ensuring data privacy and efficient communication between the app and backend systems.
# Person automated 2: A security engineer creates and maintains secure APIs for mobile applications.
# Example 3: An engineer utilizes the platform to automatically test and monitor their software for vulnerabilities, proactively identifying and fixing issues before they impact users.
# Person automated 3: A quality assurance engineer tests and monitors software for vulnerabilities.
#
#
#
# Processing 199: Metalware
# www.metalware.io
# Metalware is a cutting-edge platform that streamlines hardware development by automating the process of low-level programming, significantly reducing the time to market for embedded systems. It provides a solution for businesses seeking to expedite their hardware development process and launch their products more efficiently.
#
# Tasks/Jobs: Embedded system programming, Hardware development, Low-level programming, Time to market reduction
# Industry: Embedded systems development
# People Using Tool: Hardware engineers, Developers
#
#
# Label Cluster: Mobile and Software Development Technologies
# Result:
# Example 1: A hardware engineer uses Metalware to automate the process of writing complex low-level code for a new smart home security system. This allows them to focus on the system's design and functionality, speeding up the development process.
# Person automated 1: A hardware engineer writes complex low-level code for a new smart home security system.
# Example 2: A developer uses Metalware to quickly create and test different firmware versions for a new IoT sensor.  By automating the programming process, they can iterate through multiple versions quickly and identify the most efficient solution.
# Person automated 2: A developer creates and tests different firmware versions for a new IoT sensor.
# Example 3: A team of engineers uses Metalware to develop a custom embedded system for a medical device, significantly reducing the time needed to bring the device to market. The platform streamlines the programming process, allowing them to focus on product validation and testing.
# Person automated 3: A team of engineers develops a custom embedded system for a medical device.

# %%
def extract_data(row, pattern):
    row = row.replace("\n"," ").replace("  "," ")
    pattern = r"(Example \d+: .*?)(Person automated \d+: .*?)(?= Example \d+|$)"
    matches = re.findall(pattern, row, flags=re.DOTALL)
    matches = [[m.split(":")[1].strip() for m in match] for match in matches]
    results = []
    for m in matches: 
        for l in m: results.append(l)
    return results


if "JOB1_ONET" not in sample_df.columns:
    sample_df[["Job1_ONET","Job2_ONET","Job3_ONET"]] = 'N/A'
    sample_df = sample_df.reset_index()

sample_df[['Example1','Job1','Example2','Job2','Example3','Job3']] = list(sample_df['examples'].apply(lambda x: extract_data(x, pattern)))

# %%
# sample_df.to_csv("sample_df_with_examples.csv")

# %%
sample_df
# Out:
#    level_0  index  Unnamed: 0  \
# 0        0    135         135
# 1        1     40          40
#
#                                    organization name num employees  \
# 0                                           AIrtizen          1-10
# 1  ICAI Icelandic Center for Artificial Intelligence          1-10
#
#   founded date                                        description  \
# 0   2023-09-05  Solopreneur that creates no to low-code automa...
# 1   2023-02-03                                                  —
#
#                                           industries  \
# 0  Artificial Intelligence (AI), Developer Tools,...
# 1                       Artificial Intelligence (AI)
#
#                  headquarters location  \
# 0                                    —
# 1  Reykjavík, Gullbringusysla, Iceland
#
#                                        description.1  ...  \
# 0            AI artisan that creates efficient tools  ...
# 1  Elevating Artificial Intelligence in Iceland t...  ...
#
#                                            Job1_ONET  \
# 0  [[Loan Officers, Analyze applicants' financial...
# 1                                                N/A
#
#                                            Job2_ONET  \
# 0  [[Financial Quantitative Analysts, Develop met...
# 1                                                N/A
#
#                                            Job3_ONET  \
# 0  [[Financial Quantitative Analysts, Assess the ...
# 1                                                N/A
#
#                                             examples  \
# 0  \nExample 1: A solopreneur uses AIrtizen to au...
# 1  \nExample 1: A researcher uses ICAI's AI tools...
#
#                                             Example1  \
# 0  A solopreneur uses AIrtizen to automate their ...
# 1  A researcher uses ICAI's AI tools to analyze l...
#
#                                                 Job1  \
# 0  A solopreneur performs email marketing by send...
# 1  A data analyst for a researcher performs analy...
#
#                                             Example2  \
# 0  A small business owner leverages AIrtizen to c...
# 1  A software developer utilizes ICAI's AI platfo...
#
#                                                 Job2  \
# 0  A small business owner is in charge of providi...
# 1  A software engineer builds a custom AI model f...
#
#                                             Example3  \
# 0  An entrepreneur uses AIrtizen to analyze custo...
# 1  An entrepreneur uses ICAI's resources to devel...
#
#                                                 Job3
# 0  An entrepreneur analyzes customer data and ide...
# 1  NOT_ONET An entrepreneur working on an AI-powe...
#
# [2 rows x 49 columns]

# %%
# sample_df[['Example1', 'Job1', 'Example2', 'Job2', 'Example3', 'Job3']] = sample_df['examples'].str.extract(r'Example 1: (.*?)\nPerson automated 1: (.*?)\nExample 2: (.*?)\nPerson automated 2: (.*?)\nExample 3: (.*?)\nPerson automated 3: (.*)', flags=re.DOTALL)

results = []
for i, x in sample_df.reset_index().iterrows():
    name = x["organization name"]
    print(f"Processing {str(i), len(results)}: {name}")
    job1_embedding = x_chat.get_embedding(x["Job1"])
    job2_embedding = x_chat.get_embedding(x["Job2"])
    job3_embedding = x_chat.get_embedding(x["Job3"])
    results.append([name,job1_embedding, job2_embedding, job3_embedding])

df = pd.DataFrame(results, columns=['name', "Job1_embedding","Job2_embedding","Job3_embedding"])
sample_df = pd.concat([sample_df.reset_index(), df], axis=1)
# Out:
# Processing ('0', 0): BLOVO Animal Health
# Processing ('1', 1): Enkrypt AI
# Processing ('2', 2): Almo Chat
# Processing ('3', 3): AsFIn
# Processing ('4', 4): AI WebAssist Inc.
# Processing ('5', 5): Doowii, Inc
# Processing ('6', 6): SimLoop AI
# Processing ('7', 7): Pacerr
# Processing ('8', 8): Thunder
# Processing ('9', 9): Medicod AI
# Processing ('10', 10): AiToolHunt
# Processing ('11', 11): AIrtizen
# Processing ('12', 12): fyby.io
# Processing ('13', 13): Adhesible
# Processing ('14', 14): Ycotek
# Processing ('15', 15): Locusive
# Processing ('16', 16): Embriot
# Processing ('17', 17): Tellen
# Processing ('18', 18): AI Generative Lab - AIGL
# Processing ('19', 19): Go Boldly
# Processing ('20', 20): AppJust
# Processing ('21', 21): Gigly
# Processing ('22', 22): SendBlue.ai
# Processing ('23', 23): WriteAI.me
# Processing ('24', 24): WOWie
# Processing ('25', 25): Palatine Growth Credit
# Processing ('26', 26): Rivio
# Processing ('27', 27): doctor Z
# Processing ('28', 28): Taxly.Ai
# Processing ('29', 29): Resume Ninja
# Processing ('30', 30): DateDroid
# Processing ('31', 31): AIToolWise
# Processing ('32', 32): Localportal
# Processing ('33', 33): Cylect.io
# Processing ('34', 34): Trident AI
# Processing ('35', 35): Pet Portal AI
# Processing ('36', 36): Gesticle
# Processing ('37', 37): AutoTask
# Processing ('38', 38): MamZero AI
# Processing ('39', 39): PAINTIT.AI
# Processing ('40', 40): ShopSymphoni
# Processing ('41', 41): Steppit
# Processing ('42', 42): Interleap
# Processing ('43', 43): Mira Labs AI, Inc.
# Processing ('44', 44): Kopyst
# Processing ('45', 45): UpBrand
# Processing ('46', 46): Digi
# Processing ('47', 47): geminiaiapk
# Processing ('48', 48): Competitor Research
# Processing ('49', 49): Valar Tech
# Processing ('50', 50): Oscar Robotics
# Processing ('51', 51): OM Live Real Estate
# Processing ('52', 52): Intriq
# Processing ('53', 53): CloEE
# Processing ('54', 54): zerodivide.ai
# Processing ('55', 55): Sharly AI
# Processing ('56', 56): TrainThis.AI
# Processing ('57', 57): Plino
# Processing ('58', 58): Latimer.AI
# Processing ('59', 59): AgentOps.ai /Staf.ai
# Processing ('60', 60): NaijaBuzz300
# Processing ('61', 61): Snooky.io
# Processing ('62', 62): StockCake
# Processing ('63', 63): Wakon Livos
# Processing ('64', 64): Kapnetix
# Processing ('65', 65): ChatGPT Nederlands - GPTNederlands.com
# Processing ('66', 66): Opbardai
# Processing ('67', 67): Twing
# Processing ('68', 68): DocUnlock
# Processing ('69', 69): elggo
# Processing ('70', 70): Quris8
# Processing ('71', 71): Bids Master AI
# Processing ('72', 72): 1337
# Processing ('73', 73): Skarbe
# Processing ('74', 74): Charlie's Angel Agency
# Processing ('75', 75): YOLY
# Processing ('76', 76): Snipzo
# Processing ('77', 77): Corner League
# Processing ('78', 78): Easel AI, Inc.
# Processing ('79', 79): Sapucay
# Processing ('80', 80): Maion
# Processing ('81', 81): TreesGro
# Processing ('82', 82): Versos AI Inc
# Processing ('83', 83): Talamo
# Processing ('84', 84): 2 Dude Studios
# Processing ('85', 85): Elementera
# Processing ('86', 86): AI Library
# Processing ('87', 87): AgentOps.ai /Staf.ai
# Processing ('88', 88): ProperPlan
# Processing ('89', 89): Regimen
# Processing ('90', 90): Earthian AI
# Processing ('91', 91): Lexlabs AI
# Processing ('92', 92): NectarGPT
# Processing ('93', 93): agenci3
# Processing ('94', 94): Bolo AI
# Processing ('95', 95): Goji.mx
# Processing ('96', 96): AIbeat
# Processing ('97', 97): Dealer Data Solutions
# Processing ('98', 98): Snapby AI
# Processing ('99', 99): Pulsli
# Processing ('100', 100): SylloTips
# Processing ('101', 101): Smart Firms
# Processing ('102', 102): WriteO
# Processing ('103', 103): getpantom
# Processing ('104', 104): Wame
# Processing ('105', 105): Docusynth Ai
# Processing ('106', 106): Techtuv
# Processing ('107', 107): DaLMatian
# Processing ('108', 108): YStory
# Processing ('109', 109): QA.tech
# Processing ('110', 110): PraxySante
# Processing ('111', 111): NeronesAI
# Processing ('112', 112): Skillsun
# Processing ('113', 113): Day1 AI
# Processing ('114', 114): RobotTools.AI
# Processing ('115', 115): Tire Robot
# Processing ('116', 116): Magic Alpha
# Processing ('117', 117): Archaic Group
# Processing ('118', 118): Come Home AI
# Processing ('119', 119): Newton Health
# Processing ('120', 120): Industrial Data Labs
# Processing ('121', 121): BismillahAi
# Processing ('122', 122): Gomera Therapeutics
# Processing ('123', 123): MyMeet.ai
# Processing ('124', 124): Singularico
# Processing ('125', 125): Drafton
# Processing ('126', 126): Clinch
# Processing ('127', 127): Sympl Software Solutions
# Processing ('128', 128): LETSTOP
# Processing ('129', 129): San Justo Research Corporation
# Processing ('130', 130): Highliner.ai
# Processing ('131', 131): AutoNotes
# Processing ('132', 132): Finrep
# Processing ('133', 133): Veritas Labs
# Processing ('134', 134): Vibey
# Processing ('135', 135): ego
# Processing ('136', 136): LoveGenius
# Processing ('137', 137): Breeze
# Processing ('138', 138): Plexicus
# Processing ('139', 139): Mindora
# Processing ('140', 140): Cap
# Processing ('141', 141): Causatum Pictures
# Processing ('142', 142): csky.ai
# Processing ('143', 143): IndiHQ
# Processing ('144', 144): ChatMemoir
# Processing ('145', 145): gigDev.ai
# Processing ('146', 146): Fledgling AI
# Processing ('147', 147): Reflective Works
# Processing ('148', 148): KubicBits
# Processing ('149', 149): BLYNE
# Processing ('150', 150): Porfin
# Processing ('151', 151): Pelles.ai
# Processing ('152', 152): LTG Academy
# Processing ('153', 153): Trudy AI
# Processing ('154', 154): PromptDen
# Processing ('155', 155): theGPTlab
# Processing ('156', 156): Brightside AI
# Processing ('157', 157): swyvl
# Processing ('158', 158): qomodo
# Processing ('159', 159): PnPAI
# Processing ('160', 160): Instafill
# Processing ('161', 161): Advoria
# Processing ('162', 162): TraceChain
# Processing ('163', 163): GPTConsole
# Processing ('164', 164): RetiNov
# Processing ('165', 165): Ebris Tech
# Processing ('166', 166): Unimatch AI
# Processing ('167', 167): Topy AI
# Processing ('168', 168): IMERZO
# Processing ('169', 169): NewRoom
# Processing ('170', 170): Outhire
# Processing ('171', 171): keymate
# Processing ('172', 172): HoundDog.ai
# Processing ('173', 173): SMMA Freedom
# Processing ('174', 174): Quizmatch
# Processing ('175', 175): MagicalAPI
# Processing ('176', 176): ReiseGenie
# Processing ('177', 177): AgileHire Structured Behavioral Interview Questions
# Processing ('178', 178): Linqura
# Processing ('179', 179): Kuyin Online
# Processing ('180', 180): LegalDex AI
# Processing ('181', 181): Interfas
# Processing ('182', 182): Best AI Cryptocurrency
# Processing ('183', 183): M.IA
# Processing ('184', 184): CREcentric
# Processing ('185', 185): Emilio
# Processing ('186', 186): ResumeRanker
# Processing ('187', 187): Kwazii
# Processing ('188', 188): Protechbro Media
# Processing ('189', 189): SafetyKit
# Processing ('190', 190): four40
# Processing ('191', 191): Panza AI
# Processing ('192', 192): RAIBS
# Processing ('193', 193): Fincortex.ai
# Processing ('194', 194): AI Lawyer
# Processing ('195', 195): Diawiser
# Processing ('196', 196): ROBOPIC
# Processing ('197', 197): Permio AI
# Processing ('198', 198): Kapeta
# Processing ('199', 199): Metalware

# %%
sample_df.head()
# Out:
#    level_0  index  Unnamed: 0    organization name num employees founded date  \
# 0        0    274         274  BLOVO Animal Health          1-10   2023-03-20
# 1        1     50          50           Enkrypt AI          1-10   2023-03-31
# 2        2    250         250            Almo Chat          1-10   2023-05-01
# 3        3    319         319                AsFIn          1-10   2023-01-27
# 4        4    297         297    AI WebAssist Inc.          1-10   2023-05-17
#
#                                          description  \
# 0                                                  —
# 1  Enabling faster and secure adoption of Gen AI ...
# 2  Almo is an innovative AI-powered chatbot that ...
# 3  AsFIn brings, thru its best-in-class digital p...
# 4  We are currently combining different machine l...
#
#                                           industries  \
# 0                                                  —
# 1  Artificial Intelligence (AI), Asset Management...
# 2                   Customer Service, SaaS, Software
# 3  Financial Services, FinTech, Predictive Analytics
# 4                                                  —
#
#                   headquarters location  \
# 0                                     —
# 1  Boston, Massachusetts, United States
# 2      Hyderabad, Andhra Pradesh, India
# 3                 Madrid, Madrid, Spain
# 4                                     —
#
#                                        description.1  ...  \
# 0  BLOVO is focused on innovative methods to pred...  ...
# 1  Enabling faster and secure adoption of Gen AI ...  ...
# 2                             SaaS, Customer Support  ...
# 3  The Digital CFO for SMEs. Digital platform del...  ...
# 4               Artificial Intelligent Web Assistant  ...
#
#                                             Example1  \
# 0  A veterinarian uses a platform to analyze a pe...
# 1  A software developer integrates a pre-trained ...
# 2  A customer service representative uses Almo Ch...
# 3  A small business owner uses AsFIn to analyze t...
# 4  A college student uses AI WebAssist to analyze...
#
#                                                 Job1  \
# 0  A veterinarian analyzes medical and health dat...
# 1  A developer who programs chatbots for customer...
# 2  A customer service representative answers cust...
# 3  A CFO for a small business would be responsibl...
# 4  The student is performing their own website ev...
#
#                                             Example2  \
# 0  An animal owner uses a platform to monitor the...
# 1  A data scientist uses Enkrypt AI to securely i...
# 2  A marketing team uses Almo Chat to collect lea...
# 3  A startup uses AsFIn to create detailed financ...
# 4  A busy professional utilizes AI WebAssist's ti...
#
#                                                 Job2  \
# 0  An animal owner analyzes and tracks pet's acti...
# 1  NOT_ONET A data scientist who secures and prog...
# 2  A marketing manager collects leads and qualifi...
# 3  A financial analyst for a startup would be res...
# 4  The professional is performing their own onlin...
#
#                                             Example3  \
# 0  A farmer uses a platform to analyze herd data ...
# 1  A business analyst uses Enkrypt AI to streamli...
# 2  A tech support team utilizes Almo Chat to prov...
# 3  A company uses AsFIn to automate their monthly...
# 4  A senior citizen relies on AI WebAssist's cont...
#
#                                                 Job3                 name  \
# 0  A farmer analyzes herd data to identify animal...  BLOVO Animal Health
# 1  NOT_ONET A business analyst manually manages t...           Enkrypt AI
# 2  A tech support specialist provides immediate a...            Almo Chat
# 3  A financial reporting specialist would normall...                AsFIn
# 4  NOT_ONET The senior citizen is performing thei...    AI WebAssist Inc.
#
#                                       Job1_embedding  \
# 0  [-0.048964887857437134, 0.015215005725622177, ...
# 1  [-0.005359786096960306, 0.0005912086926400661,...
# 2  [-0.04567105695605278, -0.019649511203169823, ...
# 3  [-0.016614355146884918, 0.011362160556018353, ...
# 4  [-0.0022539575584232807, 0.03838570415973663, ...
#
#                                       Job2_embedding  \
# 0  [-0.05107363685965538, 0.012268440797924995, -...
# 1  [-0.00414356030523777, -0.0055502853356301785,...
# 2  [0.00018257819465361536, -0.014048346318304539...
# 3  [-0.046705733984708786, 0.019734270870685577, ...
# 4  [0.006720120087265968, -0.019216211512684822, ...
#
#                                       Job3_embedding
# 0  [-0.034672852605581284, -0.01153380423784256, ...
# 1  [-0.0015187064418569207, 0.0013835820136591792...
# 2  [-0.014262042939662933, -0.002772251144051552,...
# 3  [-0.023972684517502785, 0.01975742168724537, -...
# 4  [0.022356342524290085, 0.00433908449485898, -0...
#
# [5 rows x 53 columns]

# %%
sample_df.to_csv("sample_df_with_examples_embeddings.csv")

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
from nltk.corpus import wordnet

# Download the required resources
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
def get_wordnet_pos(treebank_tag):
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return None

sentence = "A voice actor produces voiceovers for podcast introductions."
tokens = nltk.word_tokenize(sentence)
tagged_tokens = pos_tag(tokens)

def get_person(text):
    text = text.replace("A ","")
    lemmatizer = WordNetLemmatizer()
    for word, tag in tagged_tokens:
        wntag = get_wordnet_pos(tag)
        if wntag == wordnet.VERB:
            first_verb = lemmatizer.lemmatize(word, pos=wntag)
            break
    return text.split(" "+first_verb)[0]
get_person("A voice actor produces voiceovers for podcast introductions.")
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/juliasusser/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/juliasusser/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# 'voice actor'

# %%
np.vstack(job_embeddings)
# Out:
# array([[-0.04896489,  0.01521501, -0.0172018 , ...,  0.01338203,
#         -0.01152982, -0.01339485],
#        [-0.05107364,  0.01226844, -0.00913018, ...,  0.00093119,
#         -0.00062929, -0.02295237],
#        [-0.03467285, -0.0115338 , -0.01705066, ...,  0.00600107,
#          0.00746562, -0.02033696]])

# %%
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

for index, row in sample_df.iterrows():
    print("***********************")
    print(row["organization name"])
    print(row["generated_description"])
    jobs = row[["Job1","Job2","Job3"]].values
    job_embeddings = row[["Job1_embedding","Job2_embedding","Job3_embedding"]].values
    startup_results = []
    for i in range(len(jobs)):
        job = jobs[i]
        job_embedding = np.vstack(job_embeddings)
        print(f"\nProcessing Job: {job}")
        cosine_sim = cosine_similarity(job_embedding, embeddings, 'cosine')
        person = get_person(job)
        person_embedding = np.array([x_chat.get_embedding(person)])
        top3 = sorted(zip(cosine_sim[0], df_exp[['Title', 'Task']].values), reverse=True)[:3]
        job_results = []
        for x,y in top3:
            
            onet_person = y[0]
            onet_person_embedding = np.array([x_chat.get_embedding(onet_person)])
            cosine_sim = cosine_similarity(person_embedding, onet_person_embedding, 'cosine')[0][0]
            print(f"{y}\n Cosine Similarity: {x}, Person Cosine Similarity: {cosine_sim}")
            job_results.append([y[0],y[1],x,cosine_sim])
        startup_results.append(job_results)
    sample_df.loc[index, ["Job1_ONET", "Job2_ONET", "Job3_ONET"]] = startup_results
        
    print("***********************\n\n")
# Out:
# ***********************
# BLOVO Animal Health
# BLOVO Animal Health is a cutting-edge platform that utilizes artificial intelligence and predictive data analytics to anticipate and prevent health problems in animals. The service is designed to revolutionize animal healthcare by providing proactive solutions and insights to ensure optimal animal health and wellbeing.
#
# Processing Job: A veterinarian analyzes medical and health data to predict and diagnose health issues.
# ['Veterinarians'
#  'Research diseases to which animals could be susceptible.']
#  Cosine Similarity: 0.5644843187073701, Person Cosine Similarity: 0.513404694847263
# ['Veterinarians'
#  'Operate diagnostic equipment, such as radiographic or ultrasound equipment, and interpret the resulting images.']
#  Cosine Similarity: 0.560867075190992, Person Cosine Similarity: 0.513404694847263
# ['Veterinary Technologists and Technicians'
#  'Perform laboratory tests on blood, urine, or feces, such as urinalyses or blood counts, to assist in the diagnosis and treatment of animal health problems.']
#  Cosine Similarity: 0.5437136407728252, Person Cosine Similarity: 0.44490116203998753
#
# Processing Job: An animal owner analyzes and tracks pet's activity, eating habits, and sleep to detect potential health issues.
# ['Veterinarians'
#  'Research diseases to which animals could be susceptible.']
#  Cosine Similarity: 0.5644843187073701, Person Cosine Similarity: 0.3509660629521461
# ['Veterinarians'
#  'Operate diagnostic equipment, such as radiographic or ultrasound equipment, and interpret the resulting images.']
#  Cosine Similarity: 0.560867075190992, Person Cosine Similarity: 0.3509451116350669
# ['Veterinary Technologists and Technicians'
#  'Perform laboratory tests on blood, urine, or feces, such as urinalyses or blood counts, to assist in the diagnosis and treatment of animal health problems.']
#  Cosine Similarity: 0.5437136407728252, Person Cosine Similarity: 0.29101786405362906
#
# Processing Job: A farmer analyzes herd data to identify animals at risk for specific diseases based on their breed, age, and environmental conditions.
# ['Veterinarians'
#  'Research diseases to which animals could be susceptible.']
#  Cosine Similarity: 0.5644843187073701, Person Cosine Similarity: 0.3334645844348505
# ['Veterinarians'
#  'Operate diagnostic equipment, such as radiographic or ultrasound equipment, and interpret the resulting images.']
#  Cosine Similarity: 0.560867075190992, Person Cosine Similarity: 0.3334645844348505
# ['Veterinary Technologists and Technicians'
#  'Perform laboratory tests on blood, urine, or feces, such as urinalyses or blood counts, to assist in the diagnosis and treatment of animal health problems.']
#  Cosine Similarity: 0.5437136407728252, Person Cosine Similarity: 0.269447739260563
# ***********************
#
#
# ***********************
# Enkrypt AI
# Enkrypt AI provides a platform that facilitates the swift and secure integration of General AI models into enterprise systems. Their service is designed to enhance business operations by leveraging the power of AI, ensuring data security and accelerating the AI adoption process.
#
# Processing Job: A developer who programs chatbots for customer service has to manually integrate the language model into the system.
# ['Blockchain Engineers'
#  'Update client and server applications responsible for integration and business logic.']
#  Cosine Similarity: 0.35449203011187147, Person Cosine Similarity: 0.20653663176404957
# ['Web Developers'
#  'Respond to user email inquiries, or set up automated systems to send responses.']
#  Cosine Similarity: 0.3431333845242333, Person Cosine Similarity: 0.27417186313012176
# ['Data Scientists'
#  'Write new functions or applications in programming languages to conduct analyses.']
#  Cosine Similarity: 0.31527204318103563, Person Cosine Similarity: 0.2133931072171262
#
# Processing Job: NOT_ONET A data scientist who secures and programs AI fraud detection systems manually integrates the AI models into the system.
# ['Blockchain Engineers'
#  'Update client and server applications responsible for integration and business logic.']
#  Cosine Similarity: 0.35449203011187147, Person Cosine Similarity: 0.2799808728365478
# ['Web Developers'
#  'Respond to user email inquiries, or set up automated systems to send responses.']
#  Cosine Similarity: 0.3431333845242333, Person Cosine Similarity: 0.2554666427781223
# ['Data Scientists'
#  'Write new functions or applications in programming languages to conduct analyses.']
#  Cosine Similarity: 0.31527204318103563, Person Cosine Similarity: 0.48017175132683326
#
# Processing Job: NOT_ONET A business analyst manually manages the collection and processing of information from new hires.
# ['Blockchain Engineers'
#  'Update client and server applications responsible for integration and business logic.']
#  Cosine Similarity: 0.35449203011187147, Person Cosine Similarity: 0.1898531006669583
# ['Web Developers'
#  'Respond to user email inquiries, or set up automated systems to send responses.']
#  Cosine Similarity: 0.3431333845242333, Person Cosine Similarity: 0.20366261400437102
# ['Data Scientists'
#  'Write new functions or applications in programming languages to conduct analyses.']
#  Cosine Similarity: 0.31527204318103563, Person Cosine Similarity: 0.2532704452558033
# ***********************
#
#
# ***********************
# Almo Chat
# Almo Chat is an AI-driven chatbot designed to mimic human conversation, significantly increasing the capacity of customer support teams to handle and resolve customer inquiries. With multi-language support, it caters to global businesses, enhancing customer satisfaction and streamlining the efficiency of customer service operations.
#
# Processing Job: A customer service representative answers customer questions about product features and order tracking.
# ['Telemarketers'
#  'Explain products or services and prices, and answer questions from customers.']
#  Cosine Similarity: 0.5585362759925545, Person Cosine Similarity: 0.29535159518541465
# ['Sales Representatives of Services, Except Advertising, Insurance, Financial Services, and Travel'
#  "Answer customers' questions about services, prices, availability, or credit terms."]
#  Cosine Similarity: 0.5581252625109173, Person Cosine Similarity: 0.3605176425270563
# ['Customer Service Representatives'
#  'Confer with customers by telephone or in person to provide information about products or services, take or enter orders, cancel accounts, or obtain details of complaints.']
#  Cosine Similarity: 0.5571440834371231, Person Cosine Similarity: 0.6709648762250118
#
# Processing Job: A marketing manager collects leads and qualifies potential customers.
# ['Telemarketers'
#  'Explain products or services and prices, and answer questions from customers.']
#  Cosine Similarity: 0.5585362759925545, Person Cosine Similarity: 0.30621212114992447
# ['Sales Representatives of Services, Except Advertising, Insurance, Financial Services, and Travel'
#  "Answer customers' questions about services, prices, availability, or credit terms."]
#  Cosine Similarity: 0.5581252625109173, Person Cosine Similarity: 0.17426783713523375
# ['Customer Service Representatives'
#  'Confer with customers by telephone or in person to provide information about products or services, take or enter orders, cancel accounts, or obtain details of complaints.']
#  Cosine Similarity: 0.5571440834371231, Person Cosine Similarity: 0.2372786871006168
#
# Processing Job: A tech support specialist provides immediate assistance to users experiencing technical difficulties.
# ['Telemarketers'
#  'Explain products or services and prices, and answer questions from customers.']
#  Cosine Similarity: 0.5585362759925545, Person Cosine Similarity: 0.2343652630412666
# ['Sales Representatives of Services, Except Advertising, Insurance, Financial Services, and Travel'
#  "Answer customers' questions about services, prices, availability, or credit terms."]
#  Cosine Similarity: 0.5581252625109173, Person Cosine Similarity: 0.18706930352247603
# ['Customer Service Representatives'
#  'Confer with customers by telephone or in person to provide information about products or services, take or enter orders, cancel accounts, or obtain details of complaints.']
#  Cosine Similarity: 0.5571440834371231, Person Cosine Similarity: 0.338926484943192
# ***********************
#
#
# ***********************
# AsFIn
# AsFIn is a digital platform that utilizes artificial intelligence to provide comprehensive financial intelligence, including data analysis, diagnosis, and action plans, to organizations and professionals assisting SMEs. It essentially acts as a digital CFO for SMEs, enabling them to make informed business decisions.
#
# Processing Job: A CFO for a small business would be responsible for cost optimization, cash flow analysis, and contract negotiations.
# ['Treasurers and Controllers'
#  'Analyze the financial details of past, present, and expected operations to identify development opportunities and areas where improvement is needed.']
#  Cosine Similarity: 0.4567318250819246, Person Cosine Similarity: 0.3441880441699979
# ['Chief Executives'
#  "Direct or coordinate an organization's financial or budget activities to fund operations, maximize investments, or increase efficiency."]
#  Cosine Similarity: 0.43104873268820243, Person Cosine Similarity: 0.25307759197347435
# ['Chief Executives'
#  'Analyze operations to evaluate performance of a company or its staff in meeting objectives or to determine areas of potential cost reduction, program improvement, or policy change.']
#  Cosine Similarity: 0.42763035106947933, Person Cosine Similarity: 0.2530671533008758
#
# Processing Job: A financial analyst for a startup would be responsible for building financial projections and preparing pitch decks.
# ['Treasurers and Controllers'
#  'Analyze the financial details of past, present, and expected operations to identify development opportunities and areas where improvement is needed.']
#  Cosine Similarity: 0.4567318250819246, Person Cosine Similarity: 0.23938179237810137
# ['Chief Executives'
#  "Direct or coordinate an organization's financial or budget activities to fund operations, maximize investments, or increase efficiency."]
#  Cosine Similarity: 0.43104873268820243, Person Cosine Similarity: 0.13404343474574146
# ['Chief Executives'
#  'Analyze operations to evaluate performance of a company or its staff in meeting objectives or to determine areas of potential cost reduction, program improvement, or policy change.']
#  Cosine Similarity: 0.42763035106947933, Person Cosine Similarity: 0.13404343474574146
#
# Processing Job: A financial reporting specialist would normally be responsible for gathering financial data, analyzing it, and generating reports.
# ['Treasurers and Controllers'
#  'Analyze the financial details of past, present, and expected operations to identify development opportunities and areas where improvement is needed.']
#  Cosine Similarity: 0.4567318250819246, Person Cosine Similarity: 0.3402613723022253
# ['Chief Executives'
#  "Direct or coordinate an organization's financial or budget activities to fund operations, maximize investments, or increase efficiency."]
#  Cosine Similarity: 0.43104873268820243, Person Cosine Similarity: 0.16012142190942238
# ['Chief Executives'
#  'Analyze operations to evaluate performance of a company or its staff in meeting objectives or to determine areas of potential cost reduction, program improvement, or policy change.']
#  Cosine Similarity: 0.42763035106947933, Person Cosine Similarity: 0.16012142190942238
# ***********************
#
#
# ***********************
# AI WebAssist Inc.
# AI WebAssist Inc. is an AI-driven platform that enhances internet user experience by providing intelligent analysis, promoting reliable content, and warning against deceptive websites. Additionally, it offers time-management tools to help users optimize their online activities, aiming to promote a healthier and more productive digital lifestyle.
#
# Processing Job: The student is performing their own website evaluation and online safety checks.
# ['Web Administrators'
#  'Evaluate testing routines or procedures for adequacy, sufficiency, and effectiveness.']
#  Cosine Similarity: 0.417198461816871, Person Cosine Similarity: 0.29979695671133477
# ['Web and Digital Interface Designers'
#  'Identify or maintain links to and from other Web sites and check links to ensure proper functioning.']
#  Cosine Similarity: 0.37983118916162156, Person Cosine Similarity: 0.29510153072328893
# ['Web Administrators'
#  "Perform user testing or usage analyses to determine Web sites' effectiveness or usability."]
#  Cosine Similarity: 0.3784119978324572, Person Cosine Similarity: 0.29979695671133477
#
# Processing Job: The professional is performing their own online time management.
# ['Web Administrators'
#  'Evaluate testing routines or procedures for adequacy, sufficiency, and effectiveness.']
#  Cosine Similarity: 0.417198461816871, Person Cosine Similarity: 0.30911326723372123
# ['Web and Digital Interface Designers'
#  'Identify or maintain links to and from other Web sites and check links to ensure proper functioning.']
#  Cosine Similarity: 0.37983118916162156, Person Cosine Similarity: 0.251411799335838
# ['Web Administrators'
#  "Perform user testing or usage analyses to determine Web sites' effectiveness or usability."]
#  Cosine Similarity: 0.3784119978324572, Person Cosine Similarity: 0.30913553944157496
#
# Processing Job: NOT_ONET The senior citizen is performing their own online information gathering and information verification.
# ['Web Administrators'
#  'Evaluate testing routines or procedures for adequacy, sufficiency, and effectiveness.']
#  Cosine Similarity: 0.417198461816871, Person Cosine Similarity: 0.27034574503657877
# ['Web and Digital Interface Designers'
#  'Identify or maintain links to and from other Web sites and check links to ensure proper functioning.']
#  Cosine Similarity: 0.37983118916162156, Person Cosine Similarity: 0.23437611296603733
# ['Web Administrators'
#  "Perform user testing or usage analyses to determine Web sites' effectiveness or usability."]
#  Cosine Similarity: 0.3784119978324572, Person Cosine Similarity: 0.27034574503657877
# ***********************
#
#
# ***********************
# Doowii, Inc
# Doowii, Inc is an innovative AI-driven data platform designed to provide valuable insights to educators in the K-12 education sector. By utilizing predictive and generative AI, it revolutionizes analytics, enabling a more effective and personalized learning experience.
#
# Processing Job: A teacher analyzes student performance data to personalize their teaching strategies.
# ['Education Administrators, Kindergarten through Secondary'
#  'Create school improvement plans, using student performance data.']
#  Cosine Similarity: 0.5204575509404505, Person Cosine Similarity: 0.22607740545264043
# ['Instructional Coordinators'
#  'Analyze performance data to determine effectiveness of instructional systems, courses, or instructional materials.']
#  Cosine Similarity: 0.5139355948866389, Person Cosine Similarity: 0.3027871772877003
# ['Self-Enrichment Teachers'
#  "Adapt teaching methods and instructional materials to meet students' varying needs and interests."]
#  Cosine Similarity: 0.49747776081258255, Person Cosine Similarity: 0.3178047633658472
#
# Processing Job: NOT_ONET A student analyzes their own learning style and progress to choose learning materials, practice exercises, and supplemental resources.
# ['Education Administrators, Kindergarten through Secondary'
#  'Create school improvement plans, using student performance data.']
#  Cosine Similarity: 0.5204575509404505, Person Cosine Similarity: 0.17030895175243488
# ['Instructional Coordinators'
#  'Analyze performance data to determine effectiveness of instructional systems, courses, or instructional materials.']
#  Cosine Similarity: 0.5139355948866389, Person Cosine Similarity: 0.2733904741477112
# ['Self-Enrichment Teachers'
#  "Adapt teaching methods and instructional materials to meet students' varying needs and interests."]
#  Cosine Similarity: 0.49747776081258255, Person Cosine Similarity: 0.34584368388065234
#
# Processing Job: A teacher generates engaging learning materials.
# ['Education Administrators, Kindergarten through Secondary'
#  'Create school improvement plans, using student performance data.']
#  Cosine Similarity: 0.5204575509404505, Person Cosine Similarity: 0.22013742378890488
# ['Instructional Coordinators'
#  'Analyze performance data to determine effectiveness of instructional systems, courses, or instructional materials.']
#  Cosine Similarity: 0.5139355948866389, Person Cosine Similarity: 0.3276271094079481
# ['Self-Enrichment Teachers'
#  "Adapt teaching methods and instructional materials to meet students' varying needs and interests."]
#  Cosine Similarity: 0.49747776081258255, Person Cosine Similarity: 0.402531614223152
# ***********************
#
#
# ***********************
# SimLoop AI
# SimLoop AI is an innovative platform that enables businesses to conduct extensive user testing through millions of simulated users that replicate real-life website interactions. By identifying a metric for optimization, SimLoop AI progressively modifies the website and evaluates its performance with the simulated users, enhancing the metric with each iteration.
#
# Processing Job: A UX/UI designer or developer conducts A/B testing to see which website layout is the most effective.
# ['Web and Digital Interface Designers'
#  'Perform Web site tests according to planned schedules, or after any Web site or product revision.']
#  Cosine Similarity: 0.5877789554700213, Person Cosine Similarity: 0.4492308297049141
# ['Web and Digital Interface Designers'
#  'Conduct user research to determine design requirements and analyze user feedback to improve design quality.']
#  Cosine Similarity: 0.5579818819055502, Person Cosine Similarity: 0.4492308297049141
# ['Web Administrators'
#  "Perform user testing or usage analyses to determine Web sites' effectiveness or usability."]
#  Cosine Similarity: 0.554110321281619, Person Cosine Similarity: 0.2532515282480632
#
# Processing Job: A marketing analyst or digital marketer conducts conversion optimization for a landing page.
# ['Web and Digital Interface Designers'
#  'Perform Web site tests according to planned schedules, or after any Web site or product revision.']
#  Cosine Similarity: 0.5877789554700213, Person Cosine Similarity: 0.32266296003665074
# ['Web and Digital Interface Designers'
#  'Conduct user research to determine design requirements and analyze user feedback to improve design quality.']
#  Cosine Similarity: 0.5579818819055502, Person Cosine Similarity: 0.3225955414477226
# ['Web Administrators'
#  "Perform user testing or usage analyses to determine Web sites' effectiveness or usability."]
#  Cosine Similarity: 0.554110321281619, Person Cosine Similarity: 0.20719814909713935
#
# Processing Job: A product manager conducts user testing for their new app to assess its usability.
# ['Web and Digital Interface Designers'
#  'Perform Web site tests according to planned schedules, or after any Web site or product revision.']
#  Cosine Similarity: 0.5877789554700213, Person Cosine Similarity: 0.2468360864541923
# ['Web and Digital Interface Designers'
#  'Conduct user research to determine design requirements and analyze user feedback to improve design quality.']
#  Cosine Similarity: 0.5579818819055502, Person Cosine Similarity: 0.2468278035260692
# ['Web Administrators'
#  "Perform user testing or usage analyses to determine Web sites' effectiveness or usability."]
#  Cosine Similarity: 0.554110321281619, Person Cosine Similarity: 0.18880937590133184
# ***********************
#
#
# ***********************
# Pacerr
# Pacerr is an AI-powered platform designed to assist managers in implementing effective and engaging strategies for their teams. It provides a user-friendly interface and intelligent tools to streamline team management and enhance productivity.
#
# Processing Job: Project manager manually tracks team member progress and assigns tasks based on their skills.
# ['Project Management Specialists'
#  'Assign duties or responsibilities to project personnel.']
#  Cosine Similarity: 0.5861968509988, Person Cosine Similarity: 0.4732541709032728
# ['Project Management Specialists'
#  'Monitor the performance of project team members to provide performance feedback.']
#  Cosine Similarity: 0.5187348677371103, Person Cosine Similarity: 0.4732541709032728
# ['Project Management Specialists'
#  'Request and review project updates to ensure deadlines are met.']
#  Cosine Similarity: 0.5010110410730318, Person Cosine Similarity: 0.4732541709032728
#
# Processing Job: Sales manager manually analyzes team performance metrics, identifies areas for improvement and provides personalized coaching.
# ['Project Management Specialists'
#  'Assign duties or responsibilities to project personnel.']
#  Cosine Similarity: 0.5861968509988, Person Cosine Similarity: 0.31772065919723835
# ['Project Management Specialists'
#  'Monitor the performance of project team members to provide performance feedback.']
#  Cosine Similarity: 0.5187348677371103, Person Cosine Similarity: 0.31772065919723835
# ['Project Management Specialists'
#  'Request and review project updates to ensure deadlines are met.']
#  Cosine Similarity: 0.5010110410730318, Person Cosine Similarity: 0.31772065919723835
#
# Processing Job: Team leader manually sends out team updates, reminders, and feedback.
# ['Project Management Specialists'
#  'Assign duties or responsibilities to project personnel.']
#  Cosine Similarity: 0.5861968509988, Person Cosine Similarity: 0.2649208877271185
# ['Project Management Specialists'
#  'Monitor the performance of project team members to provide performance feedback.']
#  Cosine Similarity: 0.5187348677371103, Person Cosine Similarity: 0.2649208877271185
# ['Project Management Specialists'
#  'Request and review project updates to ensure deadlines are met.']
#  Cosine Similarity: 0.5010110410730318, Person Cosine Similarity: 0.2649208877271185
# ***********************
#
#
# ***********************
# Thunder
# Thunder is a decentralized, peer-to-peer cloud computing platform designed to democratize access to GPUs and address the persistent GPU shortage. It provides a solution for individuals and businesses seeking high-performance computing power, enabling them to leverage unused GPU resources from around the world.
#
# Processing Job: NOT_ONET - Developers have to wait longer to train models.
# ['Training and Development Specialists'
#  'Develop alternative training methods if expected improvements are not seen.']
#  Cosine Similarity: 0.32655369894465414, Person Cosine Similarity: 0.2636130193615111
# ['Data Scientists'
#  'Test, validate, and reformulate models to ensure accurate prediction of outcomes of interest.']
#  Cosine Similarity: 0.2738000575843164, Person Cosine Similarity: 0.2572496524415724
# ['Software Developers' 'Train users to use new or modified equipment.']
#  Cosine Similarity: 0.27329532119094224, Person Cosine Similarity: 0.2974537464018999
#
# Processing Job: NOT_ONET - Researchers have to wait longer to complete their research.
# ['Training and Development Specialists'
#  'Develop alternative training methods if expected improvements are not seen.']
#  Cosine Similarity: 0.32655369894465414, Person Cosine Similarity: 0.1612249859359139
# ['Data Scientists'
#  'Test, validate, and reformulate models to ensure accurate prediction of outcomes of interest.']
#  Cosine Similarity: 0.2738000575843164, Person Cosine Similarity: 0.22502228599461682
# ['Software Developers' 'Train users to use new or modified equipment.']
#  Cosine Similarity: 0.27329532119094224, Person Cosine Similarity: 0.21493538360490982
#
# Processing Job: NOT_ONET - Data scientists have to wait longer to complete data analysis.
# ['Training and Development Specialists'
#  'Develop alternative training methods if expected improvements are not seen.']
#  Cosine Similarity: 0.32655369894465414, Person Cosine Similarity: 0.18978041780317517
# ['Data Scientists'
#  'Test, validate, and reformulate models to ensure accurate prediction of outcomes of interest.']
#  Cosine Similarity: 0.2738000575843164, Person Cosine Similarity: 0.46854834513164684
# ['Software Developers' 'Train users to use new or modified equipment.']
#  Cosine Similarity: 0.27329532119094224, Person Cosine Similarity: 0.28864799868788843
# ***********************
#
#
# ***********************
# Medicod AI
# Medicod AI is an innovative healthcare software that utilizes artificial intelligence to automate and enhance medical coding and billing procedures. It aims to increase efficiency, reduce errors, ensure compliance, and improve financial performance in healthcare organizations by streamlining workflows and integrating seamlessly into existing systems.
#
# Processing Job: A medical coder assigns codes to patient diagnoses and procedures.
# ['Diagnostic Medical Sonographers'
#  'Process and code film from procedures and complete appropriate documentation.']
#  Cosine Similarity: 0.5511784185860956, Person Cosine Similarity: 0.2909318674021558
# ['Health Information Technologists and Medical Registrars'
#  "Resolve or clarify codes or diagnoses with conflicting, missing, or unclear information by consulting with doctors or others or by participating in the coding team's regular meetings."]
#  Cosine Similarity: 0.5463302998304659, Person Cosine Similarity: 0.36744884799590455
# ['Health Information Technologists and Medical Registrars'
#  'Assign the patient to diagnosis-related groups (DRGs), using appropriate computer software.']
#  Cosine Similarity: 0.5453204310571637, Person Cosine Similarity: 0.36744884799590455
#
# Processing Job: A billing specialist processes claims electronically.
# ['Diagnostic Medical Sonographers'
#  'Process and code film from procedures and complete appropriate documentation.']
#  Cosine Similarity: 0.5511784185860956, Person Cosine Similarity: 0.15839220174092988
# ['Health Information Technologists and Medical Registrars'
#  "Resolve or clarify codes or diagnoses with conflicting, missing, or unclear information by consulting with doctors or others or by participating in the coding team's regular meetings."]
#  Cosine Similarity: 0.5463302998304659, Person Cosine Similarity: 0.2795822793742314
# ['Health Information Technologists and Medical Registrars'
#  'Assign the patient to diagnosis-related groups (DRGs), using appropriate computer software.']
#  Cosine Similarity: 0.5453204310571637, Person Cosine Similarity: 0.2794367791725214
#
# Processing Job: A physician generates detailed patient summaries and medical reports.
# ['Diagnostic Medical Sonographers'
#  'Process and code film from procedures and complete appropriate documentation.']
#  Cosine Similarity: 0.5511784185860956, Person Cosine Similarity: 0.29260046151079766
# ['Health Information Technologists and Medical Registrars'
#  "Resolve or clarify codes or diagnoses with conflicting, missing, or unclear information by consulting with doctors or others or by participating in the coding team's regular meetings."]
#  Cosine Similarity: 0.5463302998304659, Person Cosine Similarity: 0.3654769599593024
# ['Health Information Technologists and Medical Registrars'
#  'Assign the patient to diagnosis-related groups (DRGs), using appropriate computer software.']
#  Cosine Similarity: 0.5453204310571637, Person Cosine Similarity: 0.3654769599593024
# ***********************
#
#
# ***********************
# AiToolHunt
# AiToolHunt is a comprehensive online platform that aggregates and provides access to the best free AI tools, software, and websites to enhance users' digital experiences. It serves as a one-stop destination for discovering top-tier AI innovations and use cases, aiming to empower users in their tech journey.
#
# Processing Job: A developer spends time researching and comparing various image recognition APIs.
# ['Web Developers'
#  'Research, document, rate, or select alternatives for Web architecture or technologies.']
#  Cosine Similarity: 0.35780937474245056, Person Cosine Similarity: 0.2841696126766823
# ['Graphic Designers' 'Research new software or design concepts.']
#  Cosine Similarity: 0.33048732475770737, Person Cosine Similarity: 0.21200332320918824
# ['Blockchain Engineers'
#  'Evaluate new blockchain technologies and vendor products.']
#  Cosine Similarity: 0.31790298404737527, Person Cosine Similarity: 0.22805390491435393
#
# Processing Job: A business owner has to research AI-powered customer service chatbots.
# ['Web Developers'
#  'Research, document, rate, or select alternatives for Web architecture or technologies.']
#  Cosine Similarity: 0.35780937474245056, Person Cosine Similarity: 0.16540512873632907
# ['Graphic Designers' 'Research new software or design concepts.']
#  Cosine Similarity: 0.33048732475770737, Person Cosine Similarity: 0.13989400193782855
# ['Blockchain Engineers'
#  'Evaluate new blockchain technologies and vendor products.']
#  Cosine Similarity: 0.31790298404737527, Person Cosine Similarity: 0.19910139130884716
#
# Processing Job: A student writes essays.
# ['Web Developers'
#  'Research, document, rate, or select alternatives for Web architecture or technologies.']
#  Cosine Similarity: 0.35780937474245056, Person Cosine Similarity: 0.18275390775365052
# ['Graphic Designers' 'Research new software or design concepts.']
#  Cosine Similarity: 0.33048732475770737, Person Cosine Similarity: 0.20050637095788426
# ['Blockchain Engineers'
#  'Evaluate new blockchain technologies and vendor products.']
#  Cosine Similarity: 0.31790298404737527, Person Cosine Similarity: 0.15093660880758056
# ***********************
#
#
# ***********************
# AIrtizen
# AIrtizen is a solopreneur-driven venture that specializes in creating automated workflows using artificial intelligence to transform ordinary businesses into efficient entities. With a focus on simplicity and cost-effectiveness, AIrtizen leverages AI to develop innovative, time-saving tools that have proven to be lucrative game changers, contributing to over $30 million in business revenue.
#
# Processing Job: NOT_ONET A solopreneur would be the one responding to customer service requests.
# ['Spa Managers' 'Respond to customer inquiries or complaints.']
#  Cosine Similarity: 0.4127845577177761, Person Cosine Similarity: 0.24120625273896623
# ['Online Merchants'
#  'Correspond with online customers via electronic mail, telephone, or other electronic messaging to address questions or complaints about products, policies, or shipping methods.']
#  Cosine Similarity: 0.40729878173592277, Person Cosine Similarity: 0.28576063095751875
# ['Web and Digital Interface Designers'
#  'Respond to user email inquiries, or set up automated systems to send responses.']
#  Cosine Similarity: 0.3983876239003118, Person Cosine Similarity: 0.1944844813155484
#
# Processing Job: NOT_ONET An entrepreneur would be the one managing their social media marketing.
# ['Spa Managers' 'Respond to customer inquiries or complaints.']
#  Cosine Similarity: 0.4127845577177761, Person Cosine Similarity: 0.3088822207278932
# ['Online Merchants'
#  'Correspond with online customers via electronic mail, telephone, or other electronic messaging to address questions or complaints about products, policies, or shipping methods.']
#  Cosine Similarity: 0.40729878173592277, Person Cosine Similarity: 0.31363495973559385
# ['Web and Digital Interface Designers'
#  'Respond to user email inquiries, or set up automated systems to send responses.']
#  Cosine Similarity: 0.3983876239003118, Person Cosine Similarity: 0.2660742214360881
#
# Processing Job: NOT_ONET A solopreneur would be the one handling bookkeeping.
# ['Spa Managers' 'Respond to customer inquiries or complaints.']
#  Cosine Similarity: 0.4127845577177761, Person Cosine Similarity: 0.22606956722174293
# ['Online Merchants'
#  'Correspond with online customers via electronic mail, telephone, or other electronic messaging to address questions or complaints about products, policies, or shipping methods.']
#  Cosine Similarity: 0.40729878173592277, Person Cosine Similarity: 0.24294081952286062
# ['Web and Digital Interface Designers'
#  'Respond to user email inquiries, or set up automated systems to send responses.']
#  Cosine Similarity: 0.3983876239003118, Person Cosine Similarity: 0.1555144126067623
# ***********************
#
#
# ***********************
# fyby.io
# Fyby.io is an AI-powered marketplace that assists businesses in discovering, purchasing, and managing software, tech services, and bundled solutions. It streamlines the procurement process by providing a data-driven platform for SaaS products and tech-related service solutions.
#
# Processing Job: An IT manager researches and compares different cloud storage solutions.
# ['Information Technology Project Managers'
#  'Identify, review, or select vendors or consultants to meet project needs.']
#  Cosine Similarity: 0.4571159584392117, Person Cosine Similarity: 0.43520485434722844
# ['Information Technology Project Managers'
#  'Develop implementation plans that include analyses such as cost-benefit or return on investment (ROI).']
#  Cosine Similarity: 0.43012684111131594, Person Cosine Similarity: 0.43521903236036263
# ['Computer and Information Systems Managers'
#  'Evaluate data processing proposals to assess project feasibility and requirements.']
#  Cosine Similarity: 0.4276129566147498, Person Cosine Similarity: 0.3683467521997422
#
# Processing Job: A small business owner researches and compares different CRM systems.
# ['Information Technology Project Managers'
#  'Identify, review, or select vendors or consultants to meet project needs.']
#  Cosine Similarity: 0.4571159584392117, Person Cosine Similarity: 0.22975503000283287
# ['Information Technology Project Managers'
#  'Develop implementation plans that include analyses such as cost-benefit or return on investment (ROI).']
#  Cosine Similarity: 0.43012684111131594, Person Cosine Similarity: 0.22975503000283287
# ['Computer and Information Systems Managers'
#  'Evaluate data processing proposals to assess project feasibility and requirements.']
#  Cosine Similarity: 0.4276129566147498, Person Cosine Similarity: 0.24717889067047275
#
# Processing Job: A marketing manager researches and compares different marketing automation software.
# ['Information Technology Project Managers'
#  'Identify, review, or select vendors or consultants to meet project needs.']
#  Cosine Similarity: 0.4571159584392117, Person Cosine Similarity: 0.29383454921545393
# ['Information Technology Project Managers'
#  'Develop implementation plans that include analyses such as cost-benefit or return on investment (ROI).']
#  Cosine Similarity: 0.43012684111131594, Person Cosine Similarity: 0.29383454921545393
# ['Computer and Information Systems Managers'
#  'Evaluate data processing proposals to assess project feasibility and requirements.']
#  Cosine Similarity: 0.4276129566147498, Person Cosine Similarity: 0.24349064311558438
# ***********************
#
#
# ***********************
# Adhesible
# Adhesible is an AI-powered platform that scans and analyzes digital content in real time, extracting a multitude of data points such as sentiment, emotion, categories, keywords, age-rating, and brand safety. This service provides a comprehensive understanding of digital content, enabling users to make informed decisions and strategies.
#
# Processing Job: A social media analyst uses social media data to identify and address negative feedback about a product.
# ['Market Research Analysts and Marketing Specialists'
#  'Forecast and track marketing and sales trends, analyzing collected data.']
#  Cosine Similarity: 0.4588693272167561, Person Cosine Similarity: 0.3603970167912214
# ['Digital Forensics Analysts'
#  'Conduct predictive or reactive analyses on security measures to support cyber security initiatives.']
#  Cosine Similarity: 0.4569879770204166, Person Cosine Similarity: 0.3778565959271555
# ['Market Research Analysts and Marketing Specialists'
#  'Measure and assess customer and employee satisfaction.']
#  Cosine Similarity: 0.4518507956106528, Person Cosine Similarity: 0.3603970167912214
#
# Processing Job: A marketing specialist analyzes digital content to find the most appropriate keywords to use in an ad campaign.
# ['Market Research Analysts and Marketing Specialists'
#  'Forecast and track marketing and sales trends, analyzing collected data.']
#  Cosine Similarity: 0.4588693272167561, Person Cosine Similarity: 0.4465884021639706
# ['Digital Forensics Analysts'
#  'Conduct predictive or reactive analyses on security measures to support cyber security initiatives.']
#  Cosine Similarity: 0.4569879770204166, Person Cosine Similarity: 0.3320697489025946
# ['Market Research Analysts and Marketing Specialists'
#  'Measure and assess customer and employee satisfaction.']
#  Cosine Similarity: 0.4518507956106528, Person Cosine Similarity: 0.4465884021639706
#
# Processing Job: A content creator uses data to determine the age rating of their content.
# ['Market Research Analysts and Marketing Specialists'
#  'Forecast and track marketing and sales trends, analyzing collected data.']
#  Cosine Similarity: 0.4588693272167561, Person Cosine Similarity: 0.16710821658745534
# ['Digital Forensics Analysts'
#  'Conduct predictive or reactive analyses on security measures to support cyber security initiatives.']
#  Cosine Similarity: 0.4569879770204166, Person Cosine Similarity: 0.20501391361371377
# ['Market Research Analysts and Marketing Specialists'
#  'Measure and assess customer and employee satisfaction.']
#  Cosine Similarity: 0.4518507956106528, Person Cosine Similarity: 0.16710821658745534
# ***********************
#
#
# ***********************
# Ycotek
# Ycotek is an AI-powered professional services firm that provides expertise in cloud enablement, application development, data, analytics, and artificial intelligence. Their dynamic, global delivery model allows clients to gain a competitive edge through innovative and efficient solutions.
#
# Processing Job: A market researcher for a marketing manager analyzes customer data and trends in purchase behavior.
# ['Market Research Analysts and Marketing Specialists'
#  'Collect and analyze data on customer demographics, preferences, needs, and buying habits to identify potential markets and factors affecting product demand.']
#  Cosine Similarity: 0.6603691039703485, Person Cosine Similarity: 0.5408628315664692
# ['Marketing Managers'
#  'Initiate market research studies, or analyze their findings.']
#  Cosine Similarity: 0.6470770886915163, Person Cosine Similarity: 0.4514026062887594
# ['Market Research Analysts and Marketing Specialists'
#  'Forecast and track marketing and sales trends, analyzing collected data.']
#  Cosine Similarity: 0.6252979017989087, Person Cosine Similarity: 0.5408628315664692
#
# Processing Job: A software developer performs code testing and deployment tasks.
# ['Market Research Analysts and Marketing Specialists'
#  'Collect and analyze data on customer demographics, preferences, needs, and buying habits to identify potential markets and factors affecting product demand.']
#  Cosine Similarity: 0.6603691039703485, Person Cosine Similarity: 0.18204673371882973
# ['Marketing Managers'
#  'Initiate market research studies, or analyze their findings.']
#  Cosine Similarity: 0.6470770886915163, Person Cosine Similarity: 0.15475483223586714
# ['Market Research Analysts and Marketing Specialists'
#  'Forecast and track marketing and sales trends, analyzing collected data.']
#  Cosine Similarity: 0.6252979017989087, Person Cosine Similarity: 0.18204673371882973
#
# Processing Job: A loan officer assesses creditworthiness and performs loan application processing tasks.
# ['Market Research Analysts and Marketing Specialists'
#  'Collect and analyze data on customer demographics, preferences, needs, and buying habits to identify potential markets and factors affecting product demand.']
#  Cosine Similarity: 0.6603691039703485, Person Cosine Similarity: 0.16847957723257473
# ['Marketing Managers'
#  'Initiate market research studies, or analyze their findings.']
#  Cosine Similarity: 0.6470770886915163, Person Cosine Similarity: 0.1327135748657521
# ['Market Research Analysts and Marketing Specialists'
#  'Forecast and track marketing and sales trends, analyzing collected data.']
#  Cosine Similarity: 0.6252979017989087, Person Cosine Similarity: 0.16847957723257473
# ***********************
#
#
# ***********************
# Locusive
# Locusive is an AI-powered assistant designed to streamline customer service for businesses, providing users with quick and accurate answers to their queries. This platform not only enhances the user experience by simplifying the process of finding information, but also allows Customer Success Managers to focus on more strategic tasks by automating responses to common questions.
#
# Processing Job: A customer service agent answers customer questions about return policies.
# ['Postal Service Mail Carriers'
#  "Answer customers' questions about postal services and regulations."]
#  Cosine Similarity: 0.4718950269662069, Person Cosine Similarity: 0.2125128754699265
# ['Cashiers'
#  "Answer customers' questions, and provide information on procedures or policies."]
#  Cosine Similarity: 0.4425727853033462, Person Cosine Similarity: 0.27486270303144494
# ['Cashiers' 'Process merchandise returns and exchanges.']
#  Cosine Similarity: 0.4411858989320793, Person Cosine Similarity: 0.27486270303144494
#
# Processing Job: NOT_ONET A customer success manager creates a comprehensive knowledge base for their product.
# ['Postal Service Mail Carriers'
#  "Answer customers' questions about postal services and regulations."]
#  Cosine Similarity: 0.4718950269662069, Person Cosine Similarity: 0.08439520950057913
# ['Cashiers'
#  "Answer customers' questions, and provide information on procedures or policies."]
#  Cosine Similarity: 0.4425727853033462, Person Cosine Similarity: 0.14192238028552465
# ['Cashiers' 'Process merchandise returns and exchanges.']
#  Cosine Similarity: 0.4411858989320793, Person Cosine Similarity: 0.14192238028552465
#
# Processing Job: NOT_ONET A small business owner answers common customer inquiries.
# ['Postal Service Mail Carriers'
#  "Answer customers' questions about postal services and regulations."]
#  Cosine Similarity: 0.4718950269662069, Person Cosine Similarity: 0.1814202770498839
# ['Cashiers'
#  "Answer customers' questions, and provide information on procedures or policies."]
#  Cosine Similarity: 0.4425727853033462, Person Cosine Similarity: 0.21827121057842974
# ['Cashiers' 'Process merchandise returns and exchanges.']
#  Cosine Similarity: 0.4411858989320793, Person Cosine Similarity: 0.21825420931139802
# ***********************
#
#
# ***********************
# Embriot
# Embriot is a forward-thinking startup that leverages machine learning and deep learning technologies to create data-driven solutions capable of predicting industry trends and events. Their goal is to equip businesses and individuals with the ability to anticipate and strategize, transforming uncertainty into proactive planning and fostering data-driven growth and operational efficiency.
#
# Processing Job: A data analyst for a marketing agency uses data to analyze customer trends and predict product demand.
# ['Market Research Analysts and Marketing Specialists'
#  'Forecast and track marketing and sales trends, analyzing collected data.']
#  Cosine Similarity: 0.6138110443519379, Person Cosine Similarity: 0.46974101393141
# ['Market Research Analysts and Marketing Specialists'
#  'Collect and analyze data on customer demographics, preferences, needs, and buying habits to identify potential markets and factors affecting product demand.']
#  Cosine Similarity: 0.6017674545514023, Person Cosine Similarity: 0.46974101393141
# ['Business Intelligence Analysts'
#  'Analyze technology trends to identify markets for future product development or to improve sales of existing products.']
#  Cosine Similarity: 0.5630498532927227, Person Cosine Similarity: 0.47396092725346
#
# Processing Job: A financial analyst for a financial advising agency uses global economic indicators and political events to forecast potential market fluctuations.
# ['Market Research Analysts and Marketing Specialists'
#  'Forecast and track marketing and sales trends, analyzing collected data.']
#  Cosine Similarity: 0.6138110443519379, Person Cosine Similarity: 0.3188763522255028
# ['Market Research Analysts and Marketing Specialists'
#  'Collect and analyze data on customer demographics, preferences, needs, and buying habits to identify potential markets and factors affecting product demand.']
#  Cosine Similarity: 0.6017674545514023, Person Cosine Similarity: 0.3188763522255028
# ['Business Intelligence Analysts'
#  'Analyze technology trends to identify markets for future product development or to improve sales of existing products.']
#  Cosine Similarity: 0.5630498532927227, Person Cosine Similarity: 0.3545142851993691
#
# Processing Job: A data analyst for an HR agency uses data to identify emerging skills gaps in the workforce and predict future needs.
# ['Market Research Analysts and Marketing Specialists'
#  'Forecast and track marketing and sales trends, analyzing collected data.']
#  Cosine Similarity: 0.6138110443519379, Person Cosine Similarity: 0.3571242650744163
# ['Market Research Analysts and Marketing Specialists'
#  'Collect and analyze data on customer demographics, preferences, needs, and buying habits to identify potential markets and factors affecting product demand.']
#  Cosine Similarity: 0.6017674545514023, Person Cosine Similarity: 0.3571242650744163
# ['Business Intelligence Analysts'
#  'Analyze technology trends to identify markets for future product development or to improve sales of existing products.']
#  Cosine Similarity: 0.5630498532927227, Person Cosine Similarity: 0.47521957571840096
# ***********************
#
#
# ***********************
# Tellen
# Tellen provides an AI infrastructure specifically designed for accounting firms, facilitating the development and deployment of secure, compliant generative AI solutions. This platform aims to boost productivity, enhance quality, and address talent shortages in the accounting industry by enabling firms to seamlessly integrate generative AI technology into their operations.
#
# Processing Job: An accountant creates personalized financial reports for their clients.
# ['Accountants and Auditors'
#  'Prepare, analyze, or verify annual reports, financial statements, and other records, using accepted accounting and statistical procedures to assess financial condition and facilitate financial planning.']
#  Cosine Similarity: 0.5706816071060477, Person Cosine Similarity: 0.4482441384760299
# ['Personal Financial Advisors'
#  'Prepare or interpret for clients information, such as investment performance reports, financial document summaries, or income projections.']
#  Cosine Similarity: 0.568973478363652, Person Cosine Similarity: 0.46771345942215214
# ['Accountants and Auditors' 'Prepare detailed reports on audit findings.']
#  Cosine Similarity: 0.5526468740697918, Person Cosine Similarity: 0.4482441384760299
#
# Processing Job: A CPA audits financial records.
# ['Accountants and Auditors'
#  'Prepare, analyze, or verify annual reports, financial statements, and other records, using accepted accounting and statistical procedures to assess financial condition and facilitate financial planning.']
#  Cosine Similarity: 0.5706816071060477, Person Cosine Similarity: 0.47832377550662253
# ['Personal Financial Advisors'
#  'Prepare or interpret for clients information, such as investment performance reports, financial document summaries, or income projections.']
#  Cosine Similarity: 0.568973478363652, Person Cosine Similarity: 0.27953477114541103
# ['Accountants and Auditors' 'Prepare detailed reports on audit findings.']
#  Cosine Similarity: 0.5526468740697918, Person Cosine Similarity: 0.47832377550662253
#
# Processing Job: An accountant drafts tax preparation documents for clients.
# ['Accountants and Auditors'
#  'Prepare, analyze, or verify annual reports, financial statements, and other records, using accepted accounting and statistical procedures to assess financial condition and facilitate financial planning.']
#  Cosine Similarity: 0.5706816071060477, Person Cosine Similarity: 0.42971602475982285
# ['Personal Financial Advisors'
#  'Prepare or interpret for clients information, such as investment performance reports, financial document summaries, or income projections.']
# ...
#
# Processing Job: A lawyer spends time drafting contracts and ensuring they are legally sound.
# ['Lawyers'
#  'Prepare, draft, and review legal documents, such as wills, deeds, patent applications, mortgages, leases, and contracts.']
#  Cosine Similarity: 0.6119194498882919, Person Cosine Similarity: 0.44868693703954765
# ['Lawyers'
#  'Advise clients concerning business transactions, claim liability, advisability of prosecuting or defending lawsuits, or legal rights and obligations.']
#  Cosine Similarity: 0.4768733312267307, Person Cosine Similarity: 0.44864406035308335
# ['Paralegals and Legal Assistants'
#  'Prepare legal documents, including briefs, pleadings, appeals, wills, contracts, and real estate closing statements.']
#  Cosine Similarity: 0.4551111961715795, Person Cosine Similarity: 0.3072297637500897
#
# Processing Job: NOT_ONET A person needing legal advice regarding business operations would have to call a lawyer.
# ['Lawyers'
#  'Prepare, draft, and review legal documents, such as wills, deeds, patent applications, mortgages, leases, and contracts.']
#  Cosine Similarity: 0.6119194498882919, Person Cosine Similarity: 0.4071791415185734
# ['Lawyers'
#  'Advise clients concerning business transactions, claim liability, advisability of prosecuting or defending lawsuits, or legal rights and obligations.']
#  Cosine Similarity: 0.4768733312267307, Person Cosine Similarity: 0.4072534262350306
# ['Paralegals and Legal Assistants'
#  'Prepare legal documents, including briefs, pleadings, appeals, wills, contracts, and real estate closing statements.']
#  Cosine Similarity: 0.4551111961715795, Person Cosine Similarity: 0.2705408306714834
#
# Processing Job: A paralegal spends time conducting legal research, gathering relevant case law and statutes to support a case being prepared for trial.
# ['Lawyers'
#  'Prepare, draft, and review legal documents, such as wills, deeds, patent applications, mortgages, leases, and contracts.']
#  Cosine Similarity: 0.6119194498882919, Person Cosine Similarity: 0.2629541967747836
# ['Lawyers'
#  'Advise clients concerning business transactions, claim liability, advisability of prosecuting or defending lawsuits, or legal rights and obligations.']
#  Cosine Similarity: 0.4768733312267307, Person Cosine Similarity: 0.2629541967747836
# ['Paralegals and Legal Assistants'
#  'Prepare legal documents, including briefs, pleadings, appeals, wills, contracts, and real estate closing statements.']
#  Cosine Similarity: 0.4551111961715795, Person Cosine Similarity: 0.5174935043719473
# ***********************
#
#
# ***********************
# Diawiser
# Diawiser is an AI-powered health assistant designed to transform unstructured data into personalized, medically accurate insights for efficient diabetes management. It leverages artificial intelligence to provide actionable and understandable health insights, empowering individuals with diabetes to better manage their condition.
#
# Processing Job: A diabetic person manually analyzes their blood glucose readings, meal logs, and medication data to identify patterns and trends, allowing them to make informed decisions about their diabetes management.
# ['Pharmacists'
#  'Analyze prescribing trends to monitor patient compliance and to prevent excessive usage or harmful interactions.']
#  Cosine Similarity: 0.4097698654665945, Person Cosine Similarity: 0.19375117734513114
# ['Clinical Data Managers'
#  'Analyze clinical data using appropriate statistical tools.']
#  Cosine Similarity: 0.4080939082623162, Person Cosine Similarity: 0.36303090518541425
# ['Clinical Data Managers'
#  'Read technical literature and participate in continuing education or professional associations to maintain awareness of current database technology and best practices.']
#  Cosine Similarity: 0.40068485543487176, Person Cosine Similarity: 0.36303090518541425
#
# Processing Job: A healthcare professional manually tracks their diabetic patients' progress and provides personalized insights and recommendations for medication adjustments, lifestyle changes, and follow-up appointments.
# ['Pharmacists'
#  'Analyze prescribing trends to monitor patient compliance and to prevent excessive usage or harmful interactions.']
#  Cosine Similarity: 0.4097698654665945, Person Cosine Similarity: 0.27176427073573145
# ['Clinical Data Managers'
#  'Analyze clinical data using appropriate statistical tools.']
#  Cosine Similarity: 0.4080939082623162, Person Cosine Similarity: 0.3638577794453566
# ['Clinical Data Managers'
#  'Read technical literature and participate in continuing education or professional associations to maintain awareness of current database technology and best practices.']
#  Cosine Similarity: 0.40068485543487176, Person Cosine Similarity: 0.36389101184426065
#
# Processing Job: A diabetic individual sets manual reminders for medication intake, blood glucose testing, and appointments, ensuring they stay on track with their diabetes management plan.
# ['Pharmacists'
#  'Analyze prescribing trends to monitor patient compliance and to prevent excessive usage or harmful interactions.']
#  Cosine Similarity: 0.4097698654665945, Person Cosine Similarity: 0.18924010615248057
# ['Clinical Data Managers'
#  'Analyze clinical data using appropriate statistical tools.']
#  Cosine Similarity: 0.4080939082623162, Person Cosine Similarity: 0.30770483100317364
# ['Clinical Data Managers'
#  'Read technical literature and participate in continuing education or professional associations to maintain awareness of current database technology and best practices.']
#  Cosine Similarity: 0.40068485543487176, Person Cosine Similarity: 0.3066414527559323
# ***********************
#
#
# ***********************
# ROBOPIC
# ROBOPIC is an innovative platform that utilizes artificial intelligence to generate high-quality photos and videos without the need for a physical camera. It offers a unique solution for content creators, marketers, and businesses seeking to create visually appealing and professional-grade digital content.
#
# Processing Job: NOT_ONET A social media manager is in charge of generating high-quality images for an upcoming product launch.
# ['Public Relations Specialists'
#  "Post and update content on the company's Web site and social media outlets."]
#  Cosine Similarity: 0.43289875719992427, Person Cosine Similarity: 0.2795684449305255
# ['Chief Sustainability Officers'
#  'Develop, or oversee the development of, marketing or outreach media for sustainability projects or events.']
#  Cosine Similarity: 0.4314019977030056, Person Cosine Similarity: 0.2412378787216895
# ['Search Marketing Strategists'
#  'Execute or manage social media campaigns to inform search marketing tactics.']
#  Cosine Similarity: 0.41906486600857995, Person Cosine Similarity: 0.3211720375219673
#
# Processing Job: A freelance graphic designer is responsible for generating logo ideas for a client.
# ['Public Relations Specialists'
#  "Post and update content on the company's Web site and social media outlets."]
#  Cosine Similarity: 0.43289875719992427, Person Cosine Similarity: 0.18102447803848856
# ['Chief Sustainability Officers'
#  'Develop, or oversee the development of, marketing or outreach media for sustainability projects or events.']
#  Cosine Similarity: 0.4314019977030056, Person Cosine Similarity: 0.07809743566961458
# ['Search Marketing Strategists'
#  'Execute or manage social media campaigns to inform search marketing tactics.']
#  Cosine Similarity: 0.41906486600857995, Person Cosine Similarity: 0.19705974473289484
#
# Processing Job: NOT_ONET A marketer uses the platform to create engaging video content for a new marketing campaign.
# ['Public Relations Specialists'
#  "Post and update content on the company's Web site and social media outlets."]
#  Cosine Similarity: 0.43289875719992427, Person Cosine Similarity: 0.18563512987399416
# ['Chief Sustainability Officers'
#  'Develop, or oversee the development of, marketing or outreach media for sustainability projects or events.']
#  Cosine Similarity: 0.4314019977030056, Person Cosine Similarity: 0.14036089809644905
# ['Search Marketing Strategists'
#  'Execute or manage social media campaigns to inform search marketing tactics.']
#  Cosine Similarity: 0.41906486600857995, Person Cosine Similarity: 0.37664566264251753
# ***********************
#
#
# ***********************
# Permio AI
# Permio AI is an innovative platform that utilizes artificial intelligence to expedite the building permit approval process by identifying and correcting submittal and code compliance errors. This results in faster approval times, enabling users to commence construction sooner, reduce costs, and achieve better returns.
#
# Processing Job: A building inspector checks for code violations and submittal errors in building plans.
# ['Construction and Building Inspectors'
#  'Approve building plans that meet required specifications.']
#  Cosine Similarity: 0.6544157337260766, Person Cosine Similarity: 0.5466972845246929
# ['Construction and Building Inspectors'
#  'Review and interpret plans, blueprints, site layouts, specifications, or construction methods to ensure compliance to legal requirements and safety regulations.']
#  Cosine Similarity: 0.633126317868862, Person Cosine Similarity: 0.5466843127695866
# ['Fire Inspectors and Investigators'
#  'Review blueprints and plans for new or remodeled buildings to ensure the structures meet fire safety codes.']
#  Cosine Similarity: 0.6149014867054824, Person Cosine Similarity: 0.4479521328947429
#
# Processing Job: A building permit reviewer checks for completeness and code compliance in building plans.
# ['Construction and Building Inspectors'
#  'Approve building plans that meet required specifications.']
#  Cosine Similarity: 0.6544157337260766, Person Cosine Similarity: 0.46509611046752186
# ['Construction and Building Inspectors'
#  'Review and interpret plans, blueprints, site layouts, specifications, or construction methods to ensure compliance to legal requirements and safety regulations.']
#  Cosine Similarity: 0.633126317868862, Person Cosine Similarity: 0.46509611046752186
# ['Fire Inspectors and Investigators'
#  'Review blueprints and plans for new or remodeled buildings to ensure the structures meet fire safety codes.']
#  Cosine Similarity: 0.6149014867054824, Person Cosine Similarity: 0.32590661024276546
#
# Processing Job: A structural engineer reviews building plans for structural integrity and compliance with building codes.
# ['Construction and Building Inspectors'
#  'Approve building plans that meet required specifications.']
#  Cosine Similarity: 0.6544157337260766, Person Cosine Similarity: 0.3903097522305179
# ['Construction and Building Inspectors'
#  'Review and interpret plans, blueprints, site layouts, specifications, or construction methods to ensure compliance to legal requirements and safety regulations.']
#  Cosine Similarity: 0.633126317868862, Person Cosine Similarity: 0.3934443532421805
# ['Fire Inspectors and Investigators'
#  'Review blueprints and plans for new or remodeled buildings to ensure the structures meet fire safety codes.']
#  Cosine Similarity: 0.6149014867054824, Person Cosine Similarity: 0.2765579618107272
# ***********************
#
#
# ***********************
# Kapeta
# Kapeta is an innovative platform that utilizes advanced open-source technology and AI to streamline and automate the software development process. It integrates various aspects of software development such as framework, API management, CI/CD, security, and monitoring, allowing software engineers to focus on value creation while the platform handles the rest.
#
# Processing Job: A DevOps engineer deploys web applications to cloud servers.
# ['Web Developers' 'Evaluate or recommend server hardware or software.']
#  Cosine Similarity: 0.44892144779704735, Person Cosine Similarity: 0.38612379263517316
# ['Web Administrators'
#  'Test new software packages for use in Web operations or other applications.']
#  Cosine Similarity: 0.44192510002767194, Person Cosine Similarity: 0.31570391557155786
# ['Computer Systems Engineers/Architects'
#  'Configure servers to meet functional specifications.']
#  Cosine Similarity: 0.4372426604475973, Person Cosine Similarity: 0.34769915978937055
#
# Processing Job: A security engineer creates and maintains secure APIs for mobile applications.
# ['Web Developers' 'Evaluate or recommend server hardware or software.']
#  Cosine Similarity: 0.44892144779704735, Person Cosine Similarity: 0.28816152706082787
# ['Web Administrators'
#  'Test new software packages for use in Web operations or other applications.']
#  Cosine Similarity: 0.44192510002767194, Person Cosine Similarity: 0.21317829487297657
# ['Computer Systems Engineers/Architects'
#  'Configure servers to meet functional specifications.']
#  Cosine Similarity: 0.4372426604475973, Person Cosine Similarity: 0.3873033804072497
#
# Processing Job: A quality assurance engineer tests and monitors software for vulnerabilities.
# ['Web Developers' 'Evaluate or recommend server hardware or software.']
#  Cosine Similarity: 0.44892144779704735, Person Cosine Similarity: 0.2334117612872066
# ['Web Administrators'
#  'Test new software packages for use in Web operations or other applications.']
#  Cosine Similarity: 0.44192510002767194, Person Cosine Similarity: 0.1811070966020954
# ['Computer Systems Engineers/Architects'
#  'Configure servers to meet functional specifications.']
#  Cosine Similarity: 0.4372426604475973, Person Cosine Similarity: 0.3624889926164089
# ***********************
#
#
# ***********************
# Metalware
# Metalware is a cutting-edge platform that streamlines hardware development by automating the process of low-level programming, significantly reducing the time to market for embedded systems. It provides a solution for businesses seeking to expedite their hardware development process and launch their products more efficiently.
#
# Processing Job: A hardware engineer writes complex low-level code for a new smart home security system.
# ['Computer Hardware Engineers'
#  'Write detailed functional specifications that document the hardware development process and support hardware introduction.']
#  Cosine Similarity: 0.49860672875424217, Person Cosine Similarity: 0.4501615953922189
# ['Robotics Engineers'
#  'Write algorithms or programming code for ad hoc robotic applications.']
#  Cosine Similarity: 0.48471301008684914, Person Cosine Similarity: 0.41269030986477634
# ['Mechatronics Engineers' 'Create embedded software design programs.']
#  Cosine Similarity: 0.4734828098420408, Person Cosine Similarity: 0.38096207740176535
#
# Processing Job: A developer creates and tests different firmware versions for a new IoT sensor.
# ['Computer Hardware Engineers'
#  'Write detailed functional specifications that document the hardware development process and support hardware introduction.']
#  Cosine Similarity: 0.49860672875424217, Person Cosine Similarity: 0.2597290120953798
# ['Robotics Engineers'
#  'Write algorithms or programming code for ad hoc robotic applications.']
#  Cosine Similarity: 0.48471301008684914, Person Cosine Similarity: 0.2412383492929946
# ['Mechatronics Engineers' 'Create embedded software design programs.']
#  Cosine Similarity: 0.4734828098420408, Person Cosine Similarity: 0.24401200612450602
#
# Processing Job: A team of engineers develops a custom embedded system for a medical device.
# ['Computer Hardware Engineers'
#  'Write detailed functional specifications that document the hardware development process and support hardware introduction.']
#  Cosine Similarity: 0.49860672875424217, Person Cosine Similarity: 0.401952686151387
# ['Robotics Engineers'
#  'Write algorithms or programming code for ad hoc robotic applications.']
#  Cosine Similarity: 0.48471301008684914, Person Cosine Similarity: 0.4161730958518668
# ['Mechatronics Engineers' 'Create embedded software design programs.']
#  Cosine Similarity: 0.4734828098420408, Person Cosine Similarity: 0.41780571945455136
# ***********************

# %%
sample_df.to_csv("sample_df_with_onet_similarity.csv")

# %%
sample_df.loc[0, ["Job1_ONET", "Job2_ONET", "Job3_ONET"]] = startup_results

# %%
sample_df.iloc[0].Job1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/nf/2dvvlnxj5v962kwwzmpfj17h0000gn/T/ipykernel_10497/38484713.py in ?()
# ----> 1 sample_df.iloc[0].Job1
#
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'Job1'

# %%
sample_df.iloc[0].Job1_ONET
# Out:
# [['Loan Officers',
#   "Analyze applicants' financial status, credit, and property evaluations to determine feasibility of granting loans.",
#   0.576983110392953,
#   0.632143777461692],
#  ['Financial Managers',
#   'Examine, evaluate, or process loan applications.',
#   0.545331505006758,
#   0.29368268617098986],
#  ['Loan Officers',
#   'Review loan agreements to ensure that they are complete and accurate according to policy.',
#   0.5395771574671153,
#   0.6321613063587334]]

# %%
 cosine_similarity = cosine_similarity(single_embedding, embeddings, 'cosine')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[360], line 1
# ----> 1 cosine_similarity = cosine_similarity(single_embedding, embeddings, 'cosine')
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
df["Embeddings"] = df["Embeddings"].apply(lambda x: np.array(x))
embeddings = df["Embeddings"]

# %%
embeddings = np.array(embeddings)
embeddings = np.vstack(embeddings)
embeddings.shape
# Out:
# (11582, 3072)

# %%
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
print(job3)
single_embedding = np.array([job3_embedding])
cosine_similarity = cosine_similarity(single_embedding, embeddings, 'cosine')
print("Top 3 Cosine similarities and details:", sorted(zip(cosine_similarity[0], df_exp[['Title', 'Task']].values), reverse=True)[:3])

max_cosine_sim = np.max(cosine_similarity)
max_index = np.argmax(cosine_similarity)

print("Max Cosine similarity:", max_cosine_sim)
print("Index:", df_exp.iloc[max_index][["Title","Task"]].values)
# Out:
# A freelance writer manually reading and summarizing long email threads from clients.
# Top 3 Cosine similarities and details: [(0.4142085959362561, array(['Digital Forensics Analysts',
#        'Write technical summaries to report findings.'], dtype=object)), (0.39795679378787047, array(['Writers and Authors', 'Present drafts and ideas to clients.'],
#       dtype=object)), (0.39394958290327164, array(['Legal Secretaries and Administrative Assistants',
#        'Submit articles and information from searches to attorneys for review and approval for use.'],
#       dtype=object))]
# Max Cosine similarity: 0.4142085959362561
# Index: ['Digital Forensics Analysts'
#  'Write technical summaries to report findings.']

# %%
print("Top 3 Cosine similarities and details:", sorted(zip(cosine_similarity[0], df_exp[['Title', 'Task']].values), reverse=True)[:3])
# Out:
# Top 3 Cosine similarities and details: [(0.44830755574065523, array(['Web Developers',
#        'Respond to user email inquiries, or set up automated systems to send responses.'],
#       dtype=object)), (0.4343264557668538, array(['Web and Digital Interface Designers',
#        'Respond to user email inquiries, or set up automated systems to send responses.'],
#       dtype=object)), (0.41100481834492647, array(['Correspondence Clerks',
#        'Type acknowledgment letters to persons sending correspondence.'],
#       dtype=object))]

# %%
min_cosine_distance
# Out:
# 0.6529335707236348

# %%
from sklearn.metrics.pairwise import cosine_similarity
e = np.array(e)
e2 = np.array(e2)
similarity_score = cosine_similarity(e.reshape(1, -1), e2.reshape(1, -1))

# Output the similarity score
print(similarity_score)
# Out:
# [[0.33176111]]

# %%
e3 = x_chat.get_embedding("An AI tool that replaces a Food Service Managers by scheduling and receive food and beverage deliveries, checking delivery contents to verify product quality and quantity.")

# %%
df_exp = pd.read_csv("./input/gpts_labels_new.csv")

# %%
df_exp = df_exp[(df_exp.human_labels!='E0') | (df_exp.gpt_4_exposure!='E0')]

    
df_exp["description"] = df_exp.apply(lambda x: f"{x.Title.capitalize()} that {x.Task.lower()}",axis=1)

# %%
df_exp[(df_exp.gpt_4_exposure=='EO')]
df_exp.gpt_4_exposure.unique()
# Out:
# array(['E2', 'E0', 'E1'], dtype=object)

# %%
for i, row in df_exp[df_exp.Title == "Sales Managers"].iterrows():
    print(row.description)
# Out:
# Sales managers that resolve customer complaints regarding sales and service.
# Sales managers that monitor customer preferences to determine focus of sales efforts.
# Sales managers that determine price schedules and discount rates.
# Sales managers that review operational records and reports to project sales and determine profitability.
# Sales managers that confer or consult with department heads to plan advertising services and to secure information on equipment and customer specifications.
# Sales managers that advise dealers and distributors on policies and operating procedures to ensure functional effectiveness of business.
# Sales managers that prepare budgets and approve budget expenditures.
# Sales managers that plan and direct staffing, training, and performance evaluations to develop and control sales and service programs.
# Sales managers that visit franchised dealers to stimulate interest in establishment or expansion of leasing programs.
# Sales managers that oversee regional and local sales managers and their staffs.
# Sales managers that direct clerical staff to keep records of export correspondence, bid requests, and credit collections, and to maintain current information on tariffs, licenses, and restrictions.
# Sales managers that direct foreign sales and service outlets of an organization.
# Sales managers that assess marketing potential of new and existing store locations, considering statistics and expenditures.
# Sales managers that direct and coordinate activities involving sales of manufactured products, services, commodities, real estate, or other subjects of sale.
# Sales managers that direct, coordinate, and review sales and service accounting and record-keeping, as well as receiving and shipping.
# Sales managers that confer with potential customers regarding equipment needs, and advise customers on types of equipment to purchase.

# %%
# results = []
# for i, x in df_exp.reset_index().iterrows():
#     description = x["description"]
#     print(f"Processing {str(i), len(results)}: {description}")
#     result = x_chat.get_embedding(description)
#     results.append([description,result])
# Out:
# Processing ('0', 0): Sales managers that resolve customer complaints regarding sales and service.
# Processing ('1', 1): Sales managers that monitor customer preferences to determine focus of sales efforts.
# Processing ('2', 2): Sales managers that determine price schedules and discount rates.
# Processing ('3', 3): Sales managers that review operational records and reports to project sales and determine profitability.
# Processing ('4', 4): Sales managers that confer or consult with department heads to plan advertising services and to secure information on equipment and customer specifications.
# Processing ('5', 5): Sales managers that advise dealers and distributors on policies and operating procedures to ensure functional effectiveness of business.
# Processing ('6', 6): Sales managers that prepare budgets and approve budget expenditures.
# Processing ('7', 7): Sales managers that plan and direct staffing, training, and performance evaluations to develop and control sales and service programs.
# Processing ('8', 8): Sales managers that visit franchised dealers to stimulate interest in establishment or expansion of leasing programs.
# Processing ('9', 9): Sales managers that oversee regional and local sales managers and their staffs.
# Processing ('10', 10): Sales managers that direct clerical staff to keep records of export correspondence, bid requests, and credit collections, and to maintain current information on tariffs, licenses, and restrictions.
# Processing ('11', 11): Sales managers that direct foreign sales and service outlets of an organization.
# Processing ('12', 12): Sales managers that assess marketing potential of new and existing store locations, considering statistics and expenditures.
# Processing ('13', 13): Administrative services managers that direct or coordinate the supportive services department of a business, agency, or organization.
# Processing ('14', 14): Administrative services managers that set goals and deadlines for the department.
# Processing ('15', 15): Facilities managers that set goals and deadlines for the department.
# Processing ('16', 16): Administrative services managers that prepare and review operational reports and schedules to ensure accuracy and efficiency.
# Processing ('17', 17): Facilities managers that prepare and review operational reports and schedules to ensure accuracy and efficiency.
# Processing ('18', 18): Administrative services managers that analyze internal processes and recommend and implement procedural or policy changes to improve operations, such as supply changes or the disposal of records.
# Processing ('19', 19): Facilities managers that acquire, distribute and store supplies.
# Processing ('20', 20): Administrative services managers that plan, administer, and control budgets for contracts, equipment, and supplies.
# Processing ('21', 21): Facilities managers that plan, administer, and control budgets for contracts, equipment, and supplies.
# Processing ('22', 22): Administrative services managers that hire and terminate clerical and administrative personnel.
# Processing ('23', 23): Administrative services managers that conduct classes to teach procedures to staff.
# Processing ('24', 24): Facilities managers that conduct classes to teach procedures to staff.
# Processing ('25', 25): Industrial production managers that direct or coordinate production, processing, distribution, or marketing activities of industrial organizations.
# Processing ('26', 26): Industrial production managers that develop budgets or approve expenditures for supplies, materials, or human resources, ensuring that materials, labor, or equipment are used efficiently to meet production targets.
# Processing ('27', 27): Industrial production managers that review processing schedules or production orders to make decisions concerning inventory requirements, staffing requirements, work procedures, or duty assignments, considering budgetary limitations and time constraints.
# Processing ('28', 28): Industrial production managers that review operations and confer with technical or administrative staff to resolve production or processing problems.
# Processing ('29', 29): Industrial production managers that initiate or coordinate inventory or cost control programs.
# Processing ('30', 30): Industrial production managers that prepare and maintain production reports or personnel records.
# Processing ('31', 31): Industrial production managers that set and monitor product standards, examining samples of raw products or directing testing during processing, to ensure finished products are of prescribed quality.
# Processing ('32', 32): Industrial production managers that develop or implement production tracking or quality control systems, analyzing production, quality control, maintenance, or other operational reports to detect production problems.
# Processing ('33', 33): Industrial production managers that review plans and confer with research or support staff to develop new products or processes.
# Processing ('34', 34): Industrial production managers that coordinate or recommend procedures for facility or equipment maintenance or modification, including the replacement of machines.
# Processing ('35', 35): Industrial production managers that maintain current knowledge of the quality control field, relying on current literature pertaining to materials use, technological advances, or statistical studies.
# Processing ('36', 36): Industrial production managers that negotiate materials prices with suppliers.
# Processing ('37', 37): Medical and health services managers that direct, supervise and evaluate work activities of medical, nursing, technical, clerical, service, maintenance, and other personnel.
# Processing ('38', 38): Medical and health services managers that establish objectives and evaluative or operational criteria for units managed.
# Processing ('39', 39): Medical and health services managers that direct or conduct recruitment, hiring, and training of personnel.
# Processing ('40', 40): Medical and health services managers that develop and maintain computerized record management systems to store and process data, such as personnel activities and information, and to produce reports.
# Processing ('41', 41): Medical and health services managers that develop and implement organizational policies and procedures for the facility or medical unit.
# Processing ('42', 42): Medical and health services managers that conduct and administer fiscal operations, including accounting, planning budgets, authorizing expenditures, establishing rates for services, and coordinating financial reporting.
# Processing ('43', 43): Medical and health services managers that establish work schedules and assignments for staff, according to workload, space, and equipment availability.
# Processing ('44', 44): Medical and health services managers that monitor the use of diagnostic services, inpatient beds, facilities, and staff to ensure effective use of resources and assess the need for additional staff, equipment, and services.
# Processing ('45', 45): Medical and health services managers that maintain awareness of advances in medicine, computerized diagnostic and treatment equipment, data processing technology, government regulations, health insurance changes, and financing options.
# Processing ('46', 46): Medical and health services managers that manage change in integrated health care delivery systems, such as work restructuring, technological innovations, and shifts in the focus of care.
# Processing ('47', 47): Medical and health services managers that prepare activity reports to inform management of the status and implementation plans of programs, services, and quality initiatives.
# Processing ('48', 48): Medical and health services managers that plan, implement, and administer programs and services in a health care or medical facility, including personnel administration, training, and coordination of medical, nursing and physical plant staff.
# Processing ('49', 49): Medical and health services managers that review and analyze facility activities and data to aid planning and cash and risk management and to improve service utilization.
# Processing ('50', 50): Medical and health services managers that develop or expand and implement medical programs or health services that promote research, rehabilitation, and community health.
# Processing ('51', 51): Medical and health services managers that develop instructional materials and conduct in-service and community-based educational programs.
# Processing ('52', 52): Wholesale and retail buyers, except farm products that monitor and analyze sales records, trends, or economic conditions to anticipate consumer buying patterns, company sales, and needed inventory.
# Processing ('53', 53): Wholesale and retail buyers, except farm products that authorize payment of invoices or return of merchandise.
# Processing ('54', 54): Wholesale and retail buyers, except farm products that consult with store or merchandise managers about budgets or goods to be purchased.
# Processing ('55', 55): Wholesale and retail buyers, except farm products that provide clerks with information to print on price tags, such as price, mark-ups or mark-downs, manufacturer number, season code, or style number.
# Processing ('56', 56): Wholesale and retail buyers, except farm products that determine which products should be featured in advertising, the advertising medium to be used, or when the ads should be run.
# Processing ('57', 57): Wholesale and retail buyers, except farm products that monitor competitors' sales activities by following their advertisements in newspapers or other media.
# Processing ('58', 58): Cost estimators that analyze blueprints and other documentation to prepare time, cost, materials, and labor estimates.
# Processing ('59', 59): Cost estimators that assess cost effectiveness of products, projects or services, tracking actual costs relative to bids as the project develops.
# Processing ('60', 60): Cost estimators that consult with clients, vendors, personnel in other departments, or construction foremen to discuss and formulate estimates and resolve issues.
# Processing ('61', 61): Cost estimators that confer with engineers, architects, owners, contractors, and subcontractors on changes and adjustments to cost estimates.
# Processing ('62', 62): Cost estimators that prepare estimates used by management for purposes such as planning, organizing, and scheduling work.
# Processing ('63', 63): Cost estimators that prepare estimates for use in selecting vendors or subcontractors.
# Processing ('64', 64): Cost estimators that review material and labor requirements to decide whether it is more cost-effective to produce or purchase components.
# Processing ('65', 65): Cost estimators that prepare cost and expenditure statements and other necessary documentation at regular intervals for the duration of the project.
# Processing ('66', 66): Cost estimators that prepare and maintain a directory of suppliers, contractors and subcontractors.
# Processing ('67', 67): Cost estimators that set up cost monitoring and reporting systems and procedures.
# Processing ('68', 68): Cost estimators that establish and maintain tendering process, and conduct negotiations.
# Processing ('69', 69): Cost estimators that conduct special studies to develop and establish standard hour and related cost data or to reduce cost.
# Processing ('70', 70): Cost estimators that visit site and record information about access, drainage and topography, and availability of utility services.
# Processing ('71', 71): Training and development specialists that keep up with developments in area of expertise by reading current journals, books, or magazine articles.
# Processing ('72', 72): Training and development specialists that present information with a variety of instructional techniques or formats, such as role playing, simulations, team exercises, group discussions, videos, or lectures.
# Processing ('73', 73): Training and development specialists that schedule classes based on availability of classrooms, equipment, or instructors.
# Processing ('74', 74): Training and development specialists that offer specific training programs to help workers maintain or improve job skills.
# Processing ('75', 75): Training and development specialists that monitor, evaluate, or record training activities or program effectiveness.
# Processing ('76', 76): Training and development specialists that attend meetings or seminars to obtain information for use in training programs or to inform management of training program status.
# Processing ('77', 77): Training and development specialists that coordinate recruitment and placement of training program participants.
# Processing ('78', 78): Training and development specialists that evaluate training materials prepared by instructors, such as outlines, text, or handouts.
# Processing ('79', 79): Training and development specialists that develop alternative training methods if expected improvements are not seen.
# Processing ('80', 80): Training and development specialists that assess training needs through surveys, interviews with employees, focus groups, or consultation with managers, instructors, or customer representatives.
# Processing ('81', 81): Training and development specialists that select and assign instructors to conduct training.
# Processing ('82', 82): Training and development specialists that devise programs to develop executive potential among employees in lower-level positions.
# Processing ('83', 83): Training and development specialists that negotiate contracts with clients for desired training outcomes, fees, or expenses.
# Processing ('84', 84): Training and development specialists that refer trainees to employer relations representatives, to locations offering job placement assistance, or to appropriate social services agencies, if warranted.
# Processing ('85', 85): Architects, except landscape and naval that prepare information regarding design, structure specifications, materials, color, equipment, estimated costs, or construction time.
# Processing ('86', 86): Architects, except landscape and naval that prepare contract documents for building contractors.
# Processing ('87', 87): Architects, except landscape and naval that integrate engineering elements into unified architectural designs.
# Processing ('88', 88): Architects, except landscape and naval that administer construction contracts.
# Processing ('89', 89): Architects, except landscape and naval that represent clients in obtaining bids or awarding construction contracts.
# Processing ('90', 90): Architects, except landscape and naval that prepare operating and maintenance manuals, studies, or reports.
# Processing ('91', 91): Civil engineers that compute load and grade requirements, water flow rates, or material stress factors to determine design specifications.
# Processing ('92', 92): Civil engineers that direct or participate in surveying to lay out installations or establish reference points, grades, or elevations to guide construction.
# Processing ('93', 93): Civil engineers that estimate quantities and cost of materials, equipment, or labor to determine project feasibility.
# Processing ('94', 94): Civil engineers that prepare or present public reports on topics such as bid proposals, deeds, environmental impact statements, or property and right-of-way descriptions.
# Processing ('95', 95): Civil engineers that conduct studies of traffic patterns or environmental conditions to identify engineering problems and assess potential project impact.
# Processing ('96', 96): Biologists that program and use computers to store, process, and analyze data.
# Processing ('97', 97): Biologists that collect and analyze biological data about relationships among and between organisms and their environment.
# Processing ('98', 98): Biologists that study aquatic plants and animals and environmental conditions affecting them, such as radioactivity or pollution.
# Processing ('99', 99): Biologists that communicate test results to state and federal representatives and general public.
# Processing ('100', 100): Biologists that identify, classify, and study structure, behavior, ecology, physiology, nutrition, culture, and distribution of plant and animal species.
# Processing ('101', 101): Biologists that plan and administer biological research programs for government, research firms, medical industries, or manufacturing firms.
# Processing ('102', 102): Biologists that research environmental effects of present and potential uses of land and water areas, determining methods of improving environmental conditions or such outputs as crop yields.
# Processing ('103', 103): Biologists that measure salinity, acidity, light, oxygen content, and other physical conditions of water to determine their relationship to aquatic life.
# Processing ('104', 104): Biologists that teach or supervise students and perform research at universities and colleges.
# Processing ('105', 105): Biologists that study basic principles of plant and animal life, such as origin, relationship, development, anatomy, and function.
# Processing ('106', 106): Biologists that study and manage wild animal populations.
# Processing ('107', 107): Biologists that prepare requests for proposals or statements of work.
# Processing ('108', 108): Biologists that prepare plans for management of renewable resources.
# Processing ('109', 109): Biologists that study reactions of plants, animals, and marine species to parasites.
# Processing ('110', 110): Biologists that develop pest management and control measures, and conduct risk assessments related to pest exclusion, using scientific methods.
# Processing ('111', 111): Foresters that monitor contract compliance and results of forestry activities to assure adherence to government regulations.
# Processing ('112', 112): Foresters that establish short- and long-term plans for management of forest lands and forest resources.
# Processing ('113', 113): Foresters that plan and supervise forestry projects, such as determining the type, number and placement of trees to be planted, managing tree nurseries, thinning forest and monitoring growth of new seedlings.
# Processing ('114', 114): Foresters that negotiate terms and conditions of agreements and contracts for forest harvesting, forest management and leasing of forest lands.
# Processing ('115', 115): Foresters that determine methods of cutting and removing timber with minimum waste and environmental damage.
# Processing ('116', 116): Foresters that analyze effect of forest conditions on tree growth rates and tree species prevalence and the yield, duration, seed production, growth viability, and germination of different species.
# Processing ('117', 117): Foresters that monitor forest-cleared lands to ensure that they are reclaimed to their most suitable end use.
# Processing ('118', 118): Foresters that plan and implement projects for conservation of wildlife habitats and soil and water quality.
# Processing ('119', 119): Foresters that plan and direct forest surveys and related studies and prepare reports and recommendations.
# Processing ('120', 120): Foresters that perform inspections of forests or forest nurseries.
# Processing ('121', 121): Foresters that map forest area soils and vegetation to estimate the amount of standing timber and future value and growth.
# Processing ('122', 122): Foresters that plan cutting programs and manage timber sales from harvested areas, assisting companies to achieve production goals.
# Processing ('123', 123): Foresters that monitor wildlife populations and assess the impacts of forest operations on population and habitats.
# Processing ('124', 124): Foresters that plan and direct construction and maintenance of recreation facilities, fire towers, trails, roads and bridges, ensuring that they comply with guidelines and regulations set for forested public lands.
# Processing ('125', 125): Foresters that contact local forest owners and gain permission to take inventory of the type, amount, and location of all standing timber on the property.
# Processing ('126', 126): Foresters that provide advice and recommendations, as a consultant on forestry issues, to private woodlot owners, firefighters, government agencies or to companies.
# Processing ('127', 127): Foresters that study different tree species' classification, life history, light and soil requirements, adaptation to new environmental conditions and resistance to disease and insects.
# Processing ('128', 128): Foresters that develop new techniques for wood or residue use.
# Processing ('129', 129): Foresters that develop techniques for measuring and identifying trees.
# Processing ('130', 130): Urban and regional planners that design, promote, or administer government plans or policies affecting land use, zoning, public utilities, community facilities, housing, or transportation.
# Processing ('131', 131): Urban and regional planners that recommend approval, denial, or conditional approval of proposals.
# Processing ('132', 132): Urban and regional planners that create, prepare, or requisition graphic or narrative reports on land use data, including land area maps overlaid with geographic variables, such as population density.
# Processing ('133', 133): Urban and regional planners that advise planning officials on project feasibility, cost-effectiveness, regulatory conformance, or possible alternatives.
# Processing ('134', 134): Urban and regional planners that conduct field investigations, surveys, impact studies, or other research to compile and analyze data on economic, social, regulatory, or physical factors affecting land use.
# Processing ('135', 135): Urban and regional planners that discuss with planning officials the purpose of land use projects, such as transportation, conservation, residential, commercial, industrial, or community use.
# Processing ('136', 136): Urban and regional planners that keep informed about economic or legal issues involved in zoning codes, building codes, or environmental regulations.
# Processing ('137', 137): Urban and regional planners that mediate community disputes or assist in developing alternative plans or recommendations for programs or projects.
# Processing ('138', 138): Urban and regional planners that coordinate work with economic consultants or architects during the formulation of plans or the design of large pieces of infrastructure.
# Processing ('139', 139): Urban and regional planners that review and evaluate environmental impact reports pertaining to private or public planning projects or programs.
# Processing ('140', 140): Urban and regional planners that supervise or coordinate the work of urban planning technicians or technologists.
# Processing ('141', 141): Child, family, and school social workers that counsel individuals, groups, families, or communities regarding issues including mental health, poverty, unemployment, substance abuse, physical abuse, rehabilitation, social adjustment, child care, or medical care.
# Processing ('142', 142): Child, family, and school social workers that maintain case history records and prepare reports.
# Processing ('143', 143): Child, family, and school social workers that counsel students whose behavior, school progress, or mental or physical impairment indicate a need for assistance, diagnosing students' problems and arranging for needed services.
# Processing ('144', 144): Child, family, and school social workers that counsel parents with child rearing problems, interviewing the child and family to determine whether further action is required.
# Processing ('145', 145): Child, family, and school social workers that develop and review service plans in consultation with clients and perform follow-ups assessing the quantity and quality of services provided.
# Processing ('146', 146): Child, family, and school social workers that collect supplementary information needed to assist client, such as employment records, medical records, or school reports.
# Processing ('147', 147): Child, family, and school social workers that refer clients to community resources for services, such as job placement, debt counseling, legal aid, housing, medical treatment, or financial assistance, and provide concrete information, such as where to go and how to apply.
# Processing ('148', 148): Child, family, and school social workers that arrange for medical, psychiatric, and other tests that may disclose causes of difficulties and indicate remedial measures.
# Processing ('149', 149): Child, family, and school social workers that administer welfare programs.
# Processing ('150', 150): Child, family, and school social workers that determine clients' eligibility for financial assistance.
# Processing ('151', 151): Child, family, and school social workers that conduct social research.
# Processing ('152', 152): Child, family, and school social workers that serve on policy-making committees, assist in community development, and assist client groups by lobbying for solutions to problems.
# Processing ('153', 153): Healthcare social workers that collaborate with other professionals to evaluate patients' medical or physical condition and to assess client needs.
# Processing ('154', 154): Healthcare social workers that refer patient, client, or family to community resources to assist in recovery from mental or physical illness and to provide access to services such as financial assistance, legal aid, housing, job placement or education.
# Processing ('155', 155): Healthcare social workers that identify environmental impediments to client or patient progress through interviews and review of patient records.
# Processing ('156', 156): Healthcare social workers that utilize consultation data and social work experience to plan and coordinate client or patient care and rehabilitation, following through to ensure service efficacy.
# Processing ('157', 157): Healthcare social workers that modify treatment plans to comply with changes in clients' status.
# Processing ('158', 158): Healthcare social workers that monitor, evaluate, and record client progress according to measurable goals described in treatment and care plan.
# Processing ('159', 159): Healthcare social workers that develop or advise on social policy and assist in community development.
# Processing ('160', 160): Healthcare social workers that oversee medicaid- and medicare-related paperwork and recordkeeping in hospitals.
# Processing ('161', 161): Healthcare social workers that conduct social research to advance knowledge in the social work field.
# Processing ('162', 162): Healthcare social workers that plan and conduct programs to combat social problems, prevent substance abuse, or improve community health and counseling services.
# Processing ('163', 163): Mental health and substance abuse social workers that monitor, evaluate, and record client progress with respect to treatment goals.
# Processing ('164', 164): Mental health and substance abuse social workers that refer patient, client, or family to community resources for housing or treatment to assist in recovery from mental or physical illness, following through to ensure service efficacy.
# Processing ('165', 165): Mental health and substance abuse social workers that modify treatment plans according to changes in client status.
# Processing ('166', 166): Mental health and substance abuse social workers that plan or conduct programs to prevent substance abuse, combat social problems, or improve health or counseling services in community.
# Processing ('167', 167): Art directors that formulate basic layout design or presentation approach and specify material details, such as style and size of type, photographs, graphics, animation, video, and sound.
# Processing ('168', 168): Art directors that review and approve art materials, copy materials, and proofs of printed copy developed by staff members.
# Processing ('169', 169): Art directors that manage own accounts and projects, working within budget and scheduling requirements.
# Processing ('170', 170): Art directors that confer with creative, art, copywriting, or production department heads to discuss client requirements and presentation concepts and to coordinate creative activities.
# Processing ('171', 171): Art directors that present final layouts to clients for approval.
# Processing ('172', 172): Art directors that confer with clients to determine objectives, budget, background information, and presentation approaches, styles, and techniques.
# Processing ('173', 173): Art directors that hire, train, and direct staff members who develop design concepts into art layouts or who prepare layouts for printing.
# Processing ('174', 174): Art directors that work with creative directors to develop design solutions.
# Processing ('175', 175): Art directors that review illustrative material to determine if it conforms to standards and specifications.
# Processing ('176', 176): Art directors that attend photo shoots and printing sessions to ensure that the products needed are obtained.
# Processing ('177', 177): Art directors that create custom illustrations or other graphic elements.
# Processing ('178', 178): Art directors that mark up, paste, and complete layouts and write typography instructions to prepare materials for typesetting or printing.
# Processing ('179', 179): Art directors that negotiate with printers and estimators to determine what services will be performed.
# Processing ('180', 180): Art directors that conceptualize and help design interfaces for multimedia games, products, and devices.
# Processing ('181', 181): Art directors that prepare detailed storyboards showing sequence and timing of story development for television production.
# Processing ('182', 182): Graphic designers that create designs, concepts, and sample layouts, based on knowledge of layout principles and esthetic design concepts.
# Processing ('183', 183): Graphic designers that determine size and arrangement of illustrative material and copy, and select style and size of type.
# Processing ('184', 184): Graphic designers that use computer software to generate new images.
# Processing ('185', 185): Graphic designers that mark up, paste, and assemble final layouts to prepare layouts for printer.
# Processing ('186', 186): Graphic designers that draw and print charts, graphs, illustrations, and other artwork, using computer.
# Processing ('187', 187): Graphic designers that review final layouts and suggest improvements, as needed.
# Processing ('188', 188): Graphic designers that confer with clients to discuss and determine layout design.
# Processing ('189', 189): Graphic designers that develop graphics and layouts for product illustrations, company logos, and web sites.
# Processing ('190', 190): Graphic designers that key information into computer equipment to create layouts for client or supervisor.
# Processing ('191', 191): Graphic designers that prepare illustrations or rough sketches of material, discussing them with clients or supervisors and making necessary changes.
# Processing ('192', 192): Graphic designers that study illustrations and photographs to plan presentation of materials, products, or services.
# Processing ('193', 193): Graphic designers that prepare notes and instructions for workers who assemble and prepare final layouts for printing.
# Processing ('194', 194): Graphic designers that photograph layouts, using camera, to make layout prints for supervisors or clients.
# Processing ('195', 195): Graphic designers that produce still and animated graphics for on-air and taped portions of television news broadcasts, using electronic video equipment.
# Processing ('196', 196): Dietitians and nutritionists that assess nutritional needs, diet restrictions, and current health plans to develop and implement dietary-care plans and provide nutritional counseling.
# Processing ('197', 197): Dietitians and nutritionists that consult with physicians and health care personnel to determine nutritional needs and diet restrictions of patient or client.
# Processing ('198', 198): Dietitians and nutritionists that advise patients and their families on nutritional principles, dietary plans, diet modifications, and food selection and preparation.
# Processing ('199', 199): Dietitians and nutritionists that counsel individuals and groups on basic rules of good nutrition, healthy eating habits, and nutrition monitoring to improve their quality of life.
# Processing ('200', 200): Dietitians and nutritionists that monitor food service operations to ensure conformance to nutritional, safety, sanitation and quality standards.
# Processing ('201', 201): Dietitians and nutritionists that coordinate recipe development and standardization and develop new menus for independent food service operations.
# Processing ('202', 202): Dietitians and nutritionists that develop policies for food service or nutritional programs to assist in health promotion and disease control.
# Processing ('203', 203): Dietitians and nutritionists that inspect meals served for conformance to prescribed diets and standards of palatability and appearance.
# Processing ('204', 204): Dietitians and nutritionists that develop curriculum and prepare manuals, visual aids, course outlines, and other materials used in teaching.
# Processing ('205', 205): Dietitians and nutritionists that prepare and administer budgets for food, equipment, and supplies.
# Processing ('206', 206): Dietitians and nutritionists that select, train, and supervise workers who plan, prepare, and serve meals.
# Processing ('207', 207): Dietitians and nutritionists that manage quantity food service departments or clinical and community nutrition services.
# Processing ('208', 208): Dietitians and nutritionists that coordinate diet counseling services.
# Processing ('209', 209): Dietitians and nutritionists that advise food service managers and organizations on sanitation, safety procedures, menu development, budgeting, and planning to assist with establishment, operation, and evaluation of food service facilities and nutrition programs.
# Processing ('210', 210): Dietitians and nutritionists that organize, develop, analyze, test, and prepare special meals, such as low-fat, low-cholesterol, or chemical-free meals.
# Processing ('211', 211): Dietitians and nutritionists that plan, conduct, and evaluate dietary, nutritional, and epidemiological research.
# Processing ('212', 212): Dietitians and nutritionists that plan and conduct training programs in dietetics, nutrition, and institutional management and administration for medical students, health-care personnel, and the general public.
# Processing ('213', 213): Dietitians and nutritionists that make recommendations regarding public policy, such as nutrition labeling, food fortification, or nutrition standards for school programs.
# Processing ('214', 214): Dietitians and nutritionists that write research reports and other publications to document and communicate research findings.
# Processing ('215', 215): Dietitians and nutritionists that plan and prepare grant proposals to request program funding.
# Processing ('216', 216): Dietitians and nutritionists that confer with design, building, and equipment personnel to plan for construction and remodeling of food service units.
# Processing ('217', 217): Optometrists that analyze test results and develop a treatment plan.
# Processing ('218', 218): Optometrists that prescribe medications to treat eye diseases if state laws permit.
# Processing ('219', 219): Optometrists that educate and counsel patients on contact lens care, visual hygiene, lighting arrangements, and safety factors.
# Processing ('220', 220): Optometrists that consult with and refer patients to ophthalmologist or other health care practitioner if additional medical treatment is determined necessary.
# Processing ('221', 221): Optometrists that provide patients undergoing eye surgeries, such as cataract and laser vision correction, with pre- and post-operative care.
# Processing ('222', 222): Optometrists that prescribe therapeutic procedures to correct or conserve vision.
# Processing ('223', 223): Occupational therapists that complete and maintain necessary records.
# Processing ('224', 224): Occupational therapists that evaluate patients' progress and prepare reports that detail progress.
# Processing ('225', 225): Occupational therapists that test and evaluate patients' physical and mental abilities and analyze medical data to determine realistic rehabilitation goals for patients.
# Processing ('226', 226): Occupational therapists that select activities that will help individuals learn work and life-management skills within limits of their mental or physical capabilities.
# Processing ('227', 227): Occupational therapists that plan, organize, and conduct occupational therapy programs in hospital, institutional, or community settings to help rehabilitate those impaired because of illness, injury or psychological or developmental problems.
# Processing ('228', 228): Occupational therapists that recommend changes in patients' work or living environments, consistent with their needs and capabilities.
# Processing ('229', 229): Occupational therapists that consult with rehabilitation team to select activity programs or coordinate occupational therapy with other therapeutic activities.
# Processing ('230', 230): Occupational therapists that help clients improve decision making, abstract reasoning, memory, sequencing, coordination, and perceptual skills, using computer programs.
# Processing ('231', 231): Occupational therapists that design and create, or requisition, special supplies and equipment, such as splints, braces, and computer-aided adaptive equipment.
# Processing ('232', 232): Occupational therapists that plan and implement programs and social activities to help patients learn work or school skills and adjust to handicaps.
# Processing ('233', 233): Occupational therapists that advise on health risks in the workplace or on health-related transition to retirement.
# Processing ('234', 234): Occupational therapists that conduct research in occupational therapy.
# Processing ('235', 235): Physical therapists that plan, prepare, or carry out individually designed programs of physical treatment to maintain, improve, or restore physical functioning, alleviate pain, or prevent physical dysfunction in patients.
# Processing ('236', 236): Physical therapists that perform and document an initial exam, evaluating data to identify problems and determine a diagnosis prior to intervention.
# Processing ('237', 237): Physical therapists that confer with the patient, medical practitioners, or appropriate others to plan, implement, or assess the intervention program.
# Processing ('238', 238): Physical therapists that review physician's referral and patient's medical records to help determine diagnosis and physical therapy treatment required.
# Processing ('239', 239): Physical therapists that record prognosis, treatment, response, and progress in patient's chart or enter information into computer.
# Processing ('240', 240): Physical therapists that obtain patients' informed consent to proposed interventions.
# Processing ('241', 241): Physical therapists that discharge patient from physical therapy when goals or projected outcomes have been attained and provide for appropriate follow-up care or referrals.
# Processing ('242', 242): Physical therapists that identify and document goals, anticipated progress, and plans for reevaluation.
# Processing ('243', 243): Physical therapists that provide educational information about physical therapy or physical therapists, injury prevention, ergonomics, or ways to promote health.
# Processing ('244', 244): Physical therapists that refer clients to community resources or services.
# Processing ('245', 245): Physical therapists that conduct or support research and apply research findings to practice.
# Processing ('246', 246): Physical therapists that participate in community or community agency activities or help to formulate public policy.
# Processing ('247', 247): Recreational therapists that observe, analyze, and record patients' participation, reactions, and progress during treatment sessions, modifying treatment programs as needed.
# Processing ('248', 248): Recreational therapists that develop treatment plan to meet needs of patient, based on needs assessment, patient interests, and objectives of therapy.
# Processing ('249', 249): Recreational therapists that confer with members of treatment team to plan and evaluate therapy programs.
# Processing ('250', 250): Recreational therapists that conduct therapy sessions to improve patients' mental and physical well-being.
# Processing ('251', 251): Recreational therapists that obtain information from medical records, medical staff, family members and the patients, themselves, to assess patients' capabilities, needs and interests.
# Processing ('252', 252): Recreational therapists that prepare and submit reports and charts to treatment team to reflect patients' reactions and evidence of progress or regression.
# Processing ('253', 253): Respiratory therapists that determine requirements for treatment, such as type, method and duration of therapy, precautions to be taken, or medication and dosages, compatible with physicians' orders.
# Processing ('254', 254): Respiratory therapists that read prescription, measure arterial blood gases, and review patient information to assess patient condition.
# Processing ('255', 255): Respiratory therapists that enforce safety rules and ensure careful adherence to physicians' orders.
# Processing ('256', 256): Respiratory therapists that maintain charts that contain patients' pertinent identification and therapy information.
# Processing ('257', 257): Respiratory therapists that explain treatment procedures to patients to gain cooperation and allay fears.
# Processing ('258', 258): Respiratory therapists that relay blood analysis results to a physician.
# Processing ('259', 259): Respiratory therapists that use a variety of testing techniques to assist doctors in cardiac or pulmonary research or to diagnose disorders.
# Processing ('260', 260): Respiratory therapists that conduct tests, such as electrocardiograms (ekgs), stress testing, or lung capacity tests, to evaluate patients' cardiopulmonary functions.
# Processing ('261', 261): Dental hygienists that chart conditions of decay and disease for diagnosis and treatment by dentist.
# Processing ('262', 262): Dental hygienists that expose and develop x-ray film.
# Processing ('263', 263): Diagnostic medical sonographers that decide which images to include, looking for differences between healthy and pathological areas.
# Processing ('264', 264): Diagnostic medical sonographers that observe screen during scan to ensure that image produced is satisfactory for diagnostic purposes, making adjustments to equipment as required.
# Processing ('265', 265): Diagnostic medical sonographers that provide sonogram and oral or written summary of technical findings to physician for use in medical diagnosis.
# Processing ('266', 266): Diagnostic medical sonographers that determine whether scope of exam should be extended, based on findings.
# Processing ('267', 267): Diagnostic medical sonographers that process and code film from procedures and complete appropriate documentation.
# Processing ('268', 268): Diagnostic medical sonographers that obtain and record accurate patient history, including prior test results or information from physical examinations.
# Processing ('269', 269): Diagnostic medical sonographers that prepare patient for exam by explaining procedure, transferring patient to ultrasound table, scrubbing skin and applying gel, and positioning patient properly.
# Processing ('270', 270): Diagnostic medical sonographers that record and store suitable images, using camera unit connected to the ultrasound equipment.
# Processing ('271', 271): Diagnostic medical sonographers that coordinate work with physicians or other healthcare team members, including providing assistance during invasive procedures.
# Processing ('272', 272): Diagnostic medical sonographers that maintain records that include patient information, sonographs and interpretations, files of correspondence, publications and regulations, or quality assurance records, such as pathology, biopsy, or post-operative reports.
# Processing ('273', 273): Diagnostic medical sonographers that perform legal and ethical duties, including preparing safety or accident reports, obtaining written consent from patient to perform invasive procedures, or reporting symptoms of abuse or neglect.
# Processing ('274', 274): Diagnostic medical sonographers that perform clerical duties, such as scheduling exams or special procedures, keeping records, or archiving computerized images.
# Processing ('275', 275): Licensed practical and licensed vocational nurses that observe patients, charting and reporting changes in patients' conditions, such as adverse reactions to medication or treatment, and taking any necessary action.
# Processing ('276', 276): Licensed practical and licensed vocational nurses that administer prescribed medications or start intravenous fluids, noting times and amounts on patients' charts.
# Processing ('277', 277): Licensed practical and licensed vocational nurses that answer patients' calls and determine how to assist them.
# Processing ('278', 278): Licensed practical and licensed vocational nurses that measure and record patients' vital signs, such as height, weight, temperature, blood pressure, pulse, or respiration.
# Processing ('279', 279): Licensed practical and licensed vocational nurses that work as part of a healthcare team to assess patient needs, plan and modify care, and implement interventions.
# Processing ('280', 280): Licensed practical and licensed vocational nurses that record food and fluid intake and output.
# Processing ('281', 281): Licensed practical and licensed vocational nurses that evaluate nursing intervention outcomes, conferring with other healthcare team members as necessary.
# Processing ('282', 282): Licensed practical and licensed vocational nurses that prepare patients for examinations, tests, or treatments and explain procedures.
# Processing ('283', 283): Licensed practical and licensed vocational nurses that prepare or examine food trays for conformance to prescribed diet.
# Processing ('284', 284): Licensed practical and licensed vocational nurses that inventory and requisition supplies and instruments.
# Processing ('285', 285): Licensed practical and licensed vocational nurses that make appointments, keep records, or perform other clerical duties in doctors' offices or clinics.
# Processing ('286', 286): Dental assistants that expose dental diagnostic x-rays.
# Processing ('287', 287): Dental assistants that record treatment information in patient records.
# Processing ('288', 288): Dental assistants that take and record medical and dental histories and vital signs of patients.
# Processing ('289', 289): Dental assistants that provide postoperative instructions prescribed by dentist.
# Processing ('290', 290): Dental assistants that schedule appointments, prepare bills and receive payment for dental services, complete insurance forms, and maintain records, manually or using computer.
# Processing ('291', 291): First-line supervisors of police and detectives that inform personnel of changes in regulations and policies, implications of new or amended laws, and new techniques of police work.
# Processing ('292', 292): First-line supervisors of police and detectives that supervise and coordinate the investigation of criminal cases, offering guidance and expertise to investigators, and ensuring that procedures are conducted in accordance with laws and regulations.
# Processing ('293', 293): First-line supervisors of police and detectives that investigate and resolve personnel problems within organization and charges of misconduct against staff.
# Processing ('294', 294): First-line supervisors of police and detectives that maintain logs, prepare reports, and direct the preparation, handling, and maintenance of departmental records.
# ...
# Processing ('11497', 11497): Securities, commodities, and financial services sales agents that price securities or commodities based on market conditions.
# Processing ('11498', 11498): Securities, commodities, and financial services sales agents that purchase or sell financial derivatives for customers.
# Processing ('11499', 11499): Sales representatives of services, except advertising, insurance, financial services, and travel that answer customers' questions about services, prices, availability, or credit terms.
# Processing ('11500', 11500): Sales representatives of services, except advertising, insurance, financial services, and travel that attend sales or trade meetings or read related publications to obtain information about market conditions, business trends, regulations, or industry developments.
# Processing ('11501', 11501): Sales representatives of services, except advertising, insurance, financial services, and travel that compute and compare costs of services.
# Processing ('11502', 11502): Sales representatives of services, except advertising, insurance, financial services, and travel that consult with clients after sales or contract signings to resolve problems and provide ongoing support.
# Processing ('11503', 11503): Sales representatives of services, except advertising, insurance, financial services, and travel that contact prospective or existing customers to discuss how services can meet their needs.
# Processing ('11504', 11504): Sales representatives of services, except advertising, insurance, financial services, and travel that create forms or agreements to complete sales.
# Processing ('11505', 11505): Sales representatives of services, except advertising, insurance, financial services, and travel that develop sales presentations or proposals to explain service specifications.
# Processing ('11506', 11506): Sales representatives of services, except advertising, insurance, financial services, and travel that distribute promotional materials at meetings, conferences, or trade shows.
# Processing ('11507', 11507): Sales representatives of services, except advertising, insurance, financial services, and travel that emphasize or recommend service features based on knowledge of customers' needs and vendor capabilities and limitations.
# Processing ('11508', 11508): Sales representatives of services, except advertising, insurance, financial services, and travel that identify prospective customers using business directories, leads from clients, or information from conferences or trade shows.
# Processing ('11509', 11509): Sales representatives of services, except advertising, insurance, financial services, and travel that inform customers of contracts or other information pertaining to purchased services.
# Processing ('11510', 11510): Sales representatives of services, except advertising, insurance, financial services, and travel that maintain customer records using automated systems.
# Processing ('11511', 11511): Sales representatives of services, except advertising, insurance, financial services, and travel that monitor market conditions, innovations, and competitors' services, prices, and sales.
# Processing ('11512', 11512): Sales representatives of services, except advertising, insurance, financial services, and travel that quote prices, credit terms, contract terms, or fulfillment dates for services.
# Processing ('11513', 11513): Billing and posting clerks that answer inquiries regarding rates, routing, or procedures.
# Processing ('11514', 11514): Billing and posting clerks that compile reports of cost factors, such as labor, production, storage, and equipment.
# Processing ('11515', 11515): Billing and posting clerks that create billing documents, shipping labels, credit memorandums, or credit forms.
# Processing ('11516', 11516): Billing and posting clerks that perform general administrative tasks, such as answering telephones, scheduling appointments, and ordering supplies or equipment.
# Processing ('11517', 11517): Billing and posting clerks that return checks to customers or retrieve checks returned to customers in error, adjusting accounts and answering inquiries about errors as necessary.
# Processing ('11518', 11518): Payroll and timekeeping clerks that prepare and file payroll tax returns.
# Processing ('11519', 11519): Court, municipal, and license clerks that issue various permits and licenses, such as marriage, fishing, hunting, and dog licenses, and collect appropriate fees.
# Processing ('11520', 11520): Court, municipal, and license clerks that plan or direct the maintenance, filing, safekeeping, or computerization of all municipal documents.
# Processing ('11521', 11521): Court, municipal, and license clerks that prepare dockets or calendars of cases to be called.
# Processing ('11522', 11522): Credit authorizers, checkers, and clerks that call customers to collect payment on delinquent accounts.
# Processing ('11523', 11523): Credit authorizers, checkers, and clerks that consult with customers to resolve complaints or verify financial or credit transactions.
# Processing ('11524', 11524): Credit authorizers, checkers, and clerks that contact former employers and other acquaintances to verify applicants' references, employment, health history, or social behavior.
# Processing ('11525', 11525): Credit authorizers, checkers, and clerks that prepare reports of findings and recommendations.
# Processing ('11526', 11526): Freight forwarders that analyze shipping routes to determine how to minimize environmental impact.
# Processing ('11527', 11527): Freight forwarders that arrange for transport, using a variety of modes, such as rail, short sea shipping, air, or roadways, to minimize carbon emissions or other environmental impacts.
# Processing ('11528', 11528): Freight forwarders that consider environmental sustainability factors when determining merchandise packing methods.
# Processing ('11529', 11529): Freight forwarders that recommend shipping solutions to minimize cost or environmental impacts.
# Processing ('11530', 11530): Freight forwarders that review the environmental records of freight carriers to inform shipping decisions.
# Processing ('11531', 11531): Insurance claims and policy processing clerks that calculate premiums, refunds, commissions, adjustments, or new reserve requirements, using insurance rate standards.
# Processing ('11532', 11532): Insurance claims and policy processing clerks that enter insurance- and claims-related information into database systems.
# Processing ('11533', 11533): Insurance claims and policy processing clerks that modify, update, or process existing policies and claims to reflect any change in beneficiary, amount of coverage, or type of insurance.
# Processing ('11534', 11534): Insurance claims and policy processing clerks that organize or work with detailed office or warehouse records, maintaining files for each policyholder, including policies that are to be reinstated or cancelled.
# Processing ('11535', 11535): First-line supervisors of farming, fishing, and forestry workers that monitor operations to identify and solve problems, improve work methods, and ensure compliance with safety, company, and government regulations.
# Processing ('11536', 11536): First-line supervisors of farming, fishing, and forestry workers that plan work schedules according to personnel and equipment availability.
# Processing ('11537', 11537): Fishing and hunting workers that oversee the purchase of supplies, gear, and equipment.
# Processing ('11538', 11538): Log graders and scalers that communicate with coworkers by signals to direct log movement.
# Processing ('11539', 11539): Earth drillers, except oil and gas that monitor drilling operations, by checking gauges and listening to equipment to assess drilling conditions and to determine the need to adjust drilling or alter equipment.
# Processing ('11540', 11540): Loading and moving machine operators, underground mining that monitor loading processes to ensure that materials are loaded according to specifications.
# Processing ('11541', 11541): Loading and moving machine operators, underground mining that read written instructions or confer with supervisors about schedules and materials to be moved.
# Processing ('11542', 11542): Loading and moving machine operators, underground mining that maintain records of materials moved.
# Processing ('11543', 11543): Welders, cutters, solderers, and brazers that analyze engineering drawings, blueprints, specifications, sketches, work orders, and material safety data sheets to plan layout, assembly, and operations.
# Processing ('11544', 11544): Power plant operators that analyze the layout, instrumentation, or function of electrical generation or transmission facilities.
# Processing ('11545', 11545): Power plant operators that diagnose or troubleshoot problems with gas collection systems.
# Processing ('11546', 11546): Power plant operators that monitor well fields periodically to ensure proper functioning and performance.
# Processing ('11547', 11547): Power plant operators that prepare and submit compliance, operational, and safety forms or reports.
# Processing ('11548', 11548): Power plant operators that verify that well field monitoring data conforms to applicable regulations.
# Processing ('11549', 11549): Dental laboratory technicians that place tooth models on an apparatus that mimics bite and movement of patient's jaw to evaluate functionality of model.
# Processing ('11550', 11550): First-line supervisors of material-moving machine and vehicle operators that direct workers in transportation or related services, such as pumping, moving, storing, or loading or unloading of materials.
# Processing ('11551', 11551): First-line supervisors of material-moving machine and vehicle operators that plan and establish schedules.
# Processing ('11552', 11552): First-line supervisors of passenger attendants that compute or estimate cash, payroll, transportation, or personnel requirements.
# Processing ('11553', 11553): First-line supervisors of passenger attendants that inspect materials, stock, vehicles, equipment, or facilities to ensure that they are safe, free of defects, and consistent with specifications.
# Processing ('11554', 11554): First-line supervisors of passenger attendants that recommend and implement measures to improve worker motivation, work methods, or customer services.
# Processing ('11555', 11555): Bus drivers, school that maintain knowledge of first-aid procedures.
# Processing ('11556', 11556): Shuttle drivers and chauffeurs that maintain knowledge of first-aid procedures.
# Processing ('11557', 11557): Bus drivers, school that prepare and submit reports that may include the number of students or trips, hours worked, mileage, or fuel consumption.
# Processing ('11558', 11558): Bus drivers, school that read maps and follow written and verbal geographic directions.
# Processing ('11559', 11559): Bus drivers, school that record bus routes.
# Processing ('11560', 11560): Bus drivers, school that report any bus malfunctions or needed repairs.
# Processing ('11561', 11561): Bus drivers, school that report delays, accidents, or other traffic and transportation situations, using telephones or mobile two-way radios.
# Processing ('11562', 11562): Shuttle drivers and chauffeurs that report delays, accidents, or other traffic and transportation situations, using telephones or mobile two-way radios.
# Processing ('11563', 11563): Bus drivers, school that report delinquent student behaviors to school administration.
# Processing ('11564', 11564): Shuttle drivers and chauffeurs that arrange to pick up particular customers or groups on a regular schedule.
# Processing ('11565', 11565): Shuttle drivers and chauffeurs that communicate with dispatchers by radio, telephone, or computer to exchange information and receive requests for passenger service.
# Processing ('11566', 11566): Taxi drivers that communicate with dispatchers by radio, telephone, or computer to exchange information and receive requests for passenger service.
# Processing ('11567', 11567): Shuttle drivers and chauffeurs that complete accident reports when necessary.
# Processing ('11568', 11568): Taxi drivers that complete accident reports when necessary.
# Processing ('11569', 11569): Shuttle drivers and chauffeurs that notify dispatchers or company mechanics of vehicle problems.
# Processing ('11570', 11570): Taxi drivers that notify dispatchers or company mechanics of vehicle problems.
# Processing ('11571', 11571): Shuttle drivers and chauffeurs that prepare and submit reports that may include the number of passengers or trips, hours worked, mileage driven fuel consumed, or fares received.
# Processing ('11572', 11572): Shuttle drivers and chauffeurs that provide passengers with information or advice about the local area, points of interest, hotels, or restaurants.
# Processing ('11573', 11573): Taxi drivers that provide passengers with information or advice about the local area, points of interest, hotels, or restaurants.
# Processing ('11574', 11574): Shuttle drivers and chauffeurs that record vehicle routes.
# Processing ('11575', 11575): Taxi drivers that determine fares based on trip distances and times, using taximeters and fee schedules, and announce fares to passengers.
# Processing ('11576', 11576): Taxi drivers that report to taxicab services or garages to receive vehicle assignments.
# Processing ('11577', 11577): Aircraft service attendants that complete forms describing tasks completed.
# Processing ('11578', 11578): Aircraft service attendants that inspect aircraft components to locate cracks, breaks, leaks, or other problems.
# Processing ('11579', 11579): Aircraft service attendants that radio to flight dispatchers or other personnel to discuss incoming or outgoing aircraft.
# Processing ('11580', 11580): Transportation inspectors that calculate gross and net tonnage, hold capacities, volumes of stored fuel and water, cargo weights, and vessel stability factors, using mathematical formulas.
# Processing ('11581', 11581): Transportation inspectors that visually inspect cargo for damage upon arrival or discharge.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3209, in ndim(a)
#    3208 try:
# -> 3209     return a.ndim
#    3210 except AttributeError:
#
# AttributeError: 'list' object has no attribute 'ndim'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 8
#       5     result = x_chat.get_embedding(description)
#       6     results.append([description,result])
# ----> 8 df_exp[["description","openai_embedding"]] = results
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:4079, in DataFrame.__setitem__(self, key, value)
#    4077     self._setitem_frame(key, value)
#    4078 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 4079     self._setitem_array(key, value)
#    4080 elif isinstance(value, DataFrame):
#    4081     self._set_item_frame_value(key, value)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:4132, in DataFrame._setitem_array(self, key, value)
#    4129 elif isinstance(value, np.ndarray) and value.ndim == 2:
#    4130     self._iset_not_inplace(key, value)
# -> 4132 elif np.ndim(value) > 1:
#    4133     # list of lists
#    4134     value = DataFrame(value).values
#    4135     return self._setitem_array(key, value)
#
# File /opt/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3211, in ndim(a)
#    3209     return a.ndim
#    3210 except AttributeError:
# -> 3211     return asarray(a).ndim
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (11582, 2) + inhomogeneous part.

# %%
# df = pd.DataFrame(results, columns=['Description', 'Embeddings'])
# df_exp = pd.concat([df_exp.reset_index(), df], axis=1)

# %%
# df_exp.to_csv("gpt_exposure_embeddings.csv")
