# %%
import httpx
import re
import json

HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.94 Safari/537.36",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8",
    "Connection": "keep-alive",
    "Accept-Language": "en-US,en;q=0.9,lt;q=0.8,et;q=0.7,de;q=0.6",
}


def parse_search_page(html: str):
    soup = BeautifulSoup(html, 'html.parser')
    links = soup.find_all('a')
    for link in links:
        print(link.get('href')) 
    
while response.status_code == 403:
    response = httpx.get("https://www.indeed.com/jobs?q=python&l=Texas", headers=HEADERS)
    print(response.status_code)
    print(parse_search_page(response.text))
# Out:
# 403
# None
# 403
# None
# 403
# None
# 403
# None
# 403
# None
# 403
# None
# 403
# None
# 403
# None
# 403
# None
# 403
# None
# 403
# None
# 403
# None
# 403
# None
# 403
# None
# 403
# None
# 403
# None
# 403
# None
# 200
# #gnav-header-end
# https://support.indeed.com/hc/en-us/articles/4424221276173
# https://support.indeed.com/hc/en-us/articles/4424221276173
# /?from=gnav-jobsearch--indeedmobile
# https://www.indeed.com/
# https://www.indeed.com/companies
# https://www.indeed.com/career/salaries
# https://secure.indeed.com/account/login?hl=en_US&co=US&continue=https%3A%2F%2Fwww.indeed.com%2Fjobs%3Fq%3Dpython%26l%3DTexas&tmpl=desktop&from=gnav-util-jobsearch--indeedmobile&jsContinue=https%3A%2F%2Fwww.indeed.com%2Fjobs%3Fq%3Dpython%26l%3DTexas&empContinue=https%3A%2F%2Faccount.indeed.com%2Fmyaccess
# ...

# %%
def parse_search_page(html: str):
    soup = BeautifulSoup(html, 'html.parser')
    print(soup.text.split("About the company:")[1].split("Report")[0])
    company_info = re.search(r"About the company:(.*?)", soup.text, re.S)

    if company_info:
        print(company_info.group(1).strip())
    else:
        print("No company information found.")

# response = httpx.get("https://www.indeed.com/jobs?q=artificial+intelligence+startup&l=United+States&sc=0kf%3Ajt%28fulltime%29%3B&vjk=d1761ed9e5733c19", headers=HEADERS)
# print(response)
print(parse_search_page(response.text))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[62], line 13
#       9         print("No company information found.")
#      11 # response = httpx.get("https://www.indeed.com/jobs?q=artificial+intelligence+startup&l=United+States&sc=0kf%3Ajt%28fulltime%29%3B&vjk=d1761ed9e5733c19", headers=HEADERS)
#      12 # print(response)
# ---> 13 print(parse_search_page(response.text))
#
# Cell In[62], line 3, in parse_search_page(html)
#       1 def parse_search_page(html: str):
#       2     soup = BeautifulSoup(html, 'html.parser')
# ----> 3     print(soup.text.split("About the company:")[1].split("Report")[0])
#       4     company_info = re.search(r"About the company:(.*?)", soup.text, re.S)
#       6     if company_info:
#
# IndexError: list index out of range

# %%
# import module 
import requests 
from bs4 import BeautifulSoup 
  
  
# user define function 
# Scrape the data 
# and get in string 
def getdata(url): 
    r = requests.get(url) 
    print(r)
    return r.text 
  
# Get Html code using parse 
def html_code(url): 
  
    # pass the url 
    # into getdata function 
    htmldata = getdata(url) 
    soup = BeautifulSoup(htmldata, 'html.parser') 
  
    # return html code 
    return(soup) 
  
# filter job data using 
# find_all function 
def job_data(soup): 
    
    # find the Html tag 
    # with find() 
    # and convert into string 
    data_str = "" 
    for item in soup.find_all("a", class_="jobtitle turnstileLink"): 
        data_str = data_str + item.get_text() 
    result_1 = data_str.split("\n") 
    return(result_1) 
  
# filter company_data using 
# find_all function 
  
  
def company_data(soup): 
  
    # find the Html tag 
    # with find() 
    # and convert into string 
    data_str = "" 
    result = "" 
    for item in soup.find_all("div", class_="sjcl"): 
        data_str = data_str + item.get_text() 
    result_1 = data_str.split("\n") 
  
    res = [] 
    for i in range(1, len(result_1)): 
        if len(result_1[i]) > 1: 
            res.append(result_1[i]) 
    return(res) 
  
  
# driver nodes/main function 
if __name__ == "__main__": 
  
    # Data for URL 
    job = "data+science+internship"
    Location = "Noida%2C+Uttar+Pradesh"
    url = "https://in.indeed.com/jobs?q="+job+"&l="+Location 
  
    # Pass this URL into the soup 
    # which will return 
    # html string 
    soup = html_code(url) 
  
    # call job and company data 
    # and store into it var 
    job_res = job_data(soup) 
    com_res = company_data(soup) 
  
    # Traverse the both data 
    temp = 0
    for i in range(1, len(job_res)): 
        j = temp 
        for j in range(temp, 2+temp): 
            print("Company Name and Address : " + com_res[j]) 
  
        temp = j 
        print("Job : " + job_res[i]) 
        print("-----------------------------")
# Out:
# <Response [403]>

# %%
"jobkey" in response.text
# Out:
# False

# %%
# Out:
#   Cell In[27], line 9
#     async with httpx.AsyncClient(headers=HEADERS) as client:
#     ^
# SyntaxError: 'async with' outside async function
