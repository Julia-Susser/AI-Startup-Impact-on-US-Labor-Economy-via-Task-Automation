# %%
import pandas as pd
import numpy as np
from dotenv import load_dotenv
import os
from os import getenv
from openai import OpenAI
import pathlib
import textwrap
import google.generativeai as genai
import time
import requests
import ast
import json
from sklearn.metrics.pairwise import cosine_similarity
import re

load_dotenv("../../.env",override=True)
GOOGLE_API_KEY = getenv("GEMINI_API_KEY")
OPENAI_API_KEY = getenv("OPENAI_API_KEY")

sample_df = pd.read_csv('../output/df_with_examples_embeddings.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[40], line 21
#      18 GOOGLE_API_KEY = getenv("GEMINI_API_KEY")
#      19 OPENAI_API_KEY = getenv("OPENAI_API_KEY")
# ---> 21 sample_df = pd.read_csv('../output/df_with_examples_embeddings.csv')
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:617, in _read(filepath_or_buffer, kwds)
#     614     return parser
#     616 with parser:
# --> 617     return parser.read(nrows)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1748, in TextFileReader.read(self, nrows)
#    1741 nrows = validate_integer("nrows", nrows)
#    1742 try:
#    1743     # error: "ParserBase" has no attribute "read"
#    1744     (
#    1745         index,
#    1746         columns,
#    1747         col_dict,
# -> 1748     ) = self._engine.read(  # type: ignore[attr-defined]
#    1749         nrows
#    1750     )
#    1751 except Exception:
#    1752     self.close()
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:843, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:904, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:879, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:890, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2058, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %%
genai.configure(api_key=GOOGLE_API_KEY)
class gemini():
    def __init__(self):
        self.model = genai.GenerativeModel('gemini-1.5-flash')
    def request(self,prompt):
        url = 'https://generativelanguage.googleapis.com/v1beta/models/gemini-1.5-flash-latest:generateContent'
        headers = {
            'Content-Type': 'application/json',
        }
        data = {
            "contents": [
                {
                    "parts": [
                        {
                            "text": prompt
                        }
                    ]
                }
            ]
        }
        params = {
            'key': GOOGLE_API_KEY
        }
        
        response = requests.post(url, headers=headers, json=data, params=params)
        return json.loads(response.text)

    def ask(self,prompt):
        #response = self.model.generate_content(prompt)
        response = self.request(prompt)
        if response["candidates"][0]["finishReason"] == 'SAFETY': return "N/A"
        response = response["candidates"][0]["content"]["parts"][0]["text"]
        return response

x_gemini = gemini()
x_gemini.ask("hi")
# Out:
# 'Hi! How can I help you today? \n'

# %%
class chatGPT():
    def __init__(self):
        self.client = OpenAI(api_key=OPENAI_API_KEY)
        
    # def ask(self, q):
    #     stream = self.client.chat.completions.create(
    #         model="gpt-4",
    #         messages=[{"role": "user", "content": q}],
    #         stream=True,
    #         temperature=0
    #     )
    #     response = ""
    #     for chunk in stream:
    #         if chunk.choices[0].delta.content is not None:
    #             response += chunk.choices[0].delta.content

    #     self.response = response
    #     return response

    def get_embedding(self,text, model="text-embedding-3-large"):
       text = text.replace("\n", " ")
       return self.client.embeddings.create(input = [text], model=model).data[0].embedding

x_chat = chatGPT()

# %%
df_exp = pd.read_csv('../output/onet/gpt_exposure_embeddings.csv')
df_exp.Embeddings = df_exp.Embeddings.apply(lambda x: x.strip("[]").split(", "))
embeddings = []
for x in df_exp.Embeddings:
    embeddings.append([float(y) for y in x])


embeddings = np.array(embeddings)
embeddings = np.vstack(embeddings)
embeddings.shape

# %%
# df_exp["Embeddings_Object"] = embeddings
# embeddings = df_exp["Embeddings_Object"]
# df_exp.to_csv("../output/onet/gpt_exposure_parsable_embeddings.csv")
# df_exp = pd.read_csv("../output/onet/gpt_exposure_parsable_embeddings.csv")
# df_exp.head()

# %%
for i in range(3):
    sample_df[f"Job{i+1}_embedding"] = sample_df[f"Job{i+1}_embedding"].apply(lambda x: [float(y) for y in x.strip("[]").split(", ")])

# %%
prompt = """What is the first person in this sentence? Just return 1/2 words.
Example: 
************
Sentence:  A legal secretary would normally schedule appointments and send reminders.
Noun: legal secretary
************
Your turn:
Sentence: $sentence
Noun (1/2 words):
"""
def get_person(text):
    while True:
        try:
            result = x_gemini.ask(prompt.replace("$sentence",text)).replace(" \n","")
            return result
        except Exception as e:
            print(e)
            print(f"Error processing: {e}")
            time.sleep(20)

# %%
sample_df[["Job1_ONET", "Job2_ONET", "Job3_ONET"]].dtypes
# Out:
# Job1_ONET    object
# Job2_ONET    object
# Job3_ONET    object
# dtype: object

# %%
# results = []
for index, row in list(sample_df.iterrows())[801:]:
    print("***********************")
    print(f"Processing {index}")
    name = row["organization name"]
    print(name)
    print(row["generated_description"])
        
    job_results = []
    for i in range(3):  # 0, 1, 2 for Job1, Job2, Job3
        job = row[f'Job{i+1}']
        print(f"\nProcessing Job: {job}")
        example = row[f"Example{i+1}"]
        job_embedding = np.array(row[f'Job{i+1}_embedding']).reshape(1,-1)
        cosine_sim = cosine_similarity(job_embedding, embeddings, 'cosine')
        example_title = get_person(job)
        example_title_embedding = np.array([x_chat.get_embedding(example_title)])
        
        top3 = sorted(zip(cosine_sim[0], df_exp[['Title', 'Task']].values), reverse=True)[:3]
        local_results = []
        for cosine_sim_job, onet in top3:
            onet_title_embedding = np.array([x_chat.get_embedding(onet[0])])
            cosine_sim_title = cosine_similarity(job_embedding, onet_title_embedding, 'cosine')[0][0]
            print(f"{onet[0]}\nCosine Similarity: {cosine_sim_job}, Person Cosine Similarity: {cosine_sim_title}")
            results.append([name,example,job,onet[0],onet[1],example_title, cosine_sim_job,cosine_sim_title])
            local_results.append([onet[0],onet[1],example_title, cosine_sim_job,cosine_sim_title])
        job_results.append(json.dumps(local_results))
    sample_df.loc[index, ["Job1_ONET", "Job2_ONET", "Job3_ONET"]] = job_results

    if index % 5 == 0:
        print("**Saving Results**\n\n")
        onet_df = pd.DataFrame(results, columns=["organization_name","example","job","onet_title","onet_task","example_job_title","task_similarity", "job_title_similarity"])
        onet_df.to_csv("../output/onet_df.csv", index=False)
    if index % 30 == 0:
        sample_df.to_csv('../output/df_with_onet.csv', index=False)
        
    print("***********************\n\n")
# Out:
# ***********************
# Processing 801
# The Startup Valley
# The Startup Valley offers a range of AI-powered IT solutions and services designed to help businesses adapt to the rapidly changing digital landscape. Their services are tailored to meet the specific needs of modern businesses, helping them stay ahead of the curve and achieve their goals.
#
#
# Processing Job: A system administrator at a business performs routine IT tasks like backing up data and installing software updates.
# Bioinformatics Technicians
# Cosine Similarity: 0.5598774035993084, Person Cosine Similarity: 0.2440712238928286
# Network and Computer Systems Administrators
# Cosine Similarity: 0.5559693931818895, Person Cosine Similarity: 0.4580006424912139
# Network and Computer Systems Administrators
# Cosine Similarity: 0.5437653463707393, Person Cosine Similarity: 0.4580115427783257
#
# Processing Job: A QA engineer is responsible for testing and debugging software.
# Software Quality Assurance Analysts and Testers
# Cosine Similarity: 0.5968770686960674, Person Cosine Similarity: 0.5321020896364457
# Software Quality Assurance Analysts and Testers
# Cosine Similarity: 0.5886961870505274, Person Cosine Similarity: 0.5321038135191263
# Software Quality Assurance Analysts and Testers
# Cosine Similarity: 0.5855145997792848, Person Cosine Similarity: 0.5321020896364457
#
# Processing Job: A data analyst for a marketing team analyzes website traffic and customer behavior to optimize marketing campaigns.
# Search Marketing Strategists
# Cosine Similarity: 0.6074896035516066, Person Cosine Similarity: 0.4451593546068809
# Search Marketing Strategists
# Cosine Similarity: 0.5849964907789755, Person Cosine Similarity: 0.44512896348908876
# Market Research Analysts and Marketing Specialists
# Cosine Similarity: 0.5582108504798389, Person Cosine Similarity: 0.4560452754897588
# ***********************
#
#
# ***********************
# Processing 802
# qloudy AI
# Qloudy AI is a multi-cloud platform that simplifies the integration of artificial intelligence into business operations, offering practical AI solutions while prioritizing tech agility and maximizing the potential of your existing cloud infrastructure.  Qloudy AI helps businesses leverage the power of AI to optimize workflows, gain insights from data, and drive better decision-making.
#
#
# Processing Job: A data analyst for a marketing manager analyzes customer data to create targeted marketing campaigns.
# Market Research Analysts and Marketing Specialists
# Cosine Similarity: 0.5924740883187956, Person Cosine Similarity: 0.4983072443435568
# Market Research Analysts and Marketing Specialists
# Cosine Similarity: 0.5674457662208476, Person Cosine Similarity: 0.4983072443435568
# Marketing Managers
# Cosine Similarity: 0.5397858634006386, Person Cosine Similarity: 0.4596901075772775
#
# Processing Job: A data analyst for a manufacturing company analyzes data to prevent equipment failures.
# Manufacturing Engineers
# Cosine Similarity: 0.5783014113271983, Person Cosine Similarity: 0.4488467199162248
# Quality Control Analysts
# Cosine Similarity: 0.5475981229104927, Person Cosine Similarity: 0.4549449919992756
# Materials Engineers
# Cosine Similarity: 0.5271674633403969, Person Cosine Similarity: 0.2970003532705252
#
# Processing Job: A data analyst for a financial institution performs fraud detection and risk analysis.
# Fraud Examiners, Investigators and Analysts
# Cosine Similarity: 0.6685910784909815, Person Cosine Similarity: 0.559266573711501
# Fraud Examiners, Investigators and Analysts
# Cosine Similarity: 0.6139586734661306, Person Cosine Similarity: 0.5591592350919241
# Fraud Examiners, Investigators and Analysts
# Cosine Similarity: 0.6107090369236409, Person Cosine Similarity: 0.5593658305207404
# ***********************
#
#
# ***********************
# Processing 803
# geniusrise
# Geniusrise is a platform that offers a collection of powerful AI tools designed to automate and simplify various tasks, helping users to be more productive and efficient in their personal and professional lives. These AI tools cover a wide range of applications, from writing and content generation to data analysis and image editing, empowering users to achieve more with less effort.
#
#
# Processing Job: A student writes the first draft of an essay.
# Writers and Authors
# Cosine Similarity: 0.4020019142999346, Person Cosine Similarity: 0.2911398102724527
# Writers and Authors
# Cosine Similarity: 0.3365351774952441, Person Cosine Similarity: 0.29120990291878324
# Legislators
# Cosine Similarity: 0.32090022976723587, Person Cosine Similarity: 0.14571296275581863
#
# Processing Job: A graphic designer creates engaging visuals for social media.
# Graphic Designers
# Cosine Similarity: 0.5625377219545851, Person Cosine Similarity: 0.5984206643196719
# Graphic Designers
# Cosine Similarity: 0.556993106746179, Person Cosine Similarity: 0.5984595800268919
# Graphic Designers
# Cosine Similarity: 0.537671533866651, Person Cosine Similarity: 0.5983965416111019
#
# Processing Job: A data analyst analyzes large datasets to identify patterns and trends.
# Data Scientists
# Cosine Similarity: 0.6024448887600977, Person Cosine Similarity: 0.43572678895020367
# Intelligence Analysts
# Cosine Similarity: 0.5501570758231791, Person Cosine Similarity: 0.4259351328453175
# Statisticians
# Cosine Similarity: 0.5136820384931648, Person Cosine Similarity: 0.32617641918864754
# ***********************
#
#
# ***********************
# Processing 804
# PluginSavvy
# PluginSavvy is a curated marketplace offering a vast selection of plugins and extensions designed to enhance the functionality of popular AI platforms like ChatGPT and Stable Diffusion. This platform empowers users to unlock new capabilities and customize their AI experience, whether for personal or professional use.
#
#
# Processing Job: NOT_ONET A content writer performs research, brainstorming, and outline creation for blog articles.
# Writers and Authors
# Cosine Similarity: 0.491578016638992, Person Cosine Similarity: 0.40751152010705977
# Writers and Authors
# Cosine Similarity: 0.4856437476839628, Person Cosine Similarity: 0.40751152010705977
# Search Marketing Strategists
# Cosine Similarity: 0.48191470889891386, Person Cosine Similarity: 0.33326659645079426
#
# Processing Job: A graphic designer creates images for social media posts.
# Graphic Designers
# Cosine Similarity: 0.5817148151750859, Person Cosine Similarity: 0.6098940343101288
# Graphic Designers
# Cosine Similarity: 0.5778087306019675, Person Cosine Similarity: 0.6098940343101288
# Graphic Designers
# Cosine Similarity: 0.5596124889228979, Person Cosine Similarity: 0.6098940343101288
#
# Processing Job: A software developer designs and develops a chatbot that is able to understand and respond to user queries.
# Web Developers
# Cosine Similarity: 0.4358216820391859, Person Cosine Similarity: 0.3502320154343296
# Web and Digital Interface Designers
# Cosine Similarity: 0.428099932755834, Person Cosine Similarity: 0.28365495406665725
# Software Developers
# Cosine Similarity: 0.38525797412144885, Person Cosine Similarity: 0.42421990423610634
# ***********************
#
#
# ***********************
# Processing 805
# Ozone
# Ozone is a company focused on building a more sustainable future by promoting the use of Autogas (CNG/LPG) as a cleaner alternative fuel. They offer conversion solutions, vehicle financing, and AI-powered tools to help individuals and businesses transition to greener transportation options.
#
#
# Processing Job: A data analyst for a fleet manager analyzes fuel consumption data and determines which vehicles are inefficient.
# Logistics Analysts
# Cosine Similarity: 0.528968596108905, Person Cosine Similarity: 0.5162647455865647
# Logistics Analysts
# Cosine Similarity: 0.5265370620835772, Person Cosine Similarity: 0.5162647455865647
# Logistics Analysts
# Cosine Similarity: 0.5237217426180312, Person Cosine Similarity: 0.5162647455865647
#
# Processing Job: NOT_ONET
# Nuclear Monitoring Technicians
# Cosine Similarity: 0.21381090236370953, Person Cosine Similarity: 0.21824666986013475
# Computer Numerically Controlled Tool Operators
# Cosine Similarity: 0.205814640157761, Person Cosine Similarity: 0.24988105176495068
# Computer Numerically Controlled Tool Operators
# Cosine Similarity: 0.19883632832387022, Person Cosine Similarity: 0.2503833304141965
#
# Processing Job: A fleet manager analyzes driver performance data and uses that data to improve operational efficiency and reduce emissions.
# Heavy and Tractor-Trailer Truck Drivers
# Cosine Similarity: 0.4968531532874123, Person Cosine Similarity: 0.25925118030036726
# Transportation, Storage, and Distribution Managers
# Cosine Similarity: 0.4832867227323052, Person Cosine Similarity: 0.31340990398323354
# Logistics Engineers
# Cosine Similarity: 0.4771688128068228, Person Cosine Similarity: 0.3106347994087566
# **Saving Results**
#
#
# ***********************
#
#
# ***********************
# Processing 806
# Epsilla
# Epsilla is a platform that streamlines the development of Large Language Model (LLM) applications by providing a Retrieval-Augmented Generation as a Service (RAGaaS) solution.  This service allows users to quickly build and deploy LLM applications that leverage their own proprietary data, speeding up the process from prototype to production tenfold.
#
#
# Processing Job: A developer builds a chatbot that provides personalized customer support.
# Web Developers
# Cosine Similarity: 0.44049733929971807, Person Cosine Similarity: 0.3088172133195284
# Web and Digital Interface Designers
# Cosine Similarity: 0.4145513962331167, Person Cosine Similarity: 0.2073238112679112
# Telemarketers
# Cosine Similarity: 0.40248847599789295, Person Cosine Similarity: 0.2256975517246232
#
# Processing Job: A data scientist builds a research tool that answers complex questions by searching through scientific articles and experimental data.
# Data Scientists
# Cosine Similarity: 0.5777208252476065, Person Cosine Similarity: 0.5332620704297384
# Data Scientists
# Cosine Similarity: 0.5509954692851209, Person Cosine Similarity: 0.5332436639046226
# Data Scientists
# Cosine Similarity: 0.5327854242489348, Person Cosine Similarity: 0.5332436639046226
#
# Processing Job: A content marketer creates high-quality marketing materials.
# Search Marketing Strategists
# Cosine Similarity: 0.5713408400713086, Person Cosine Similarity: 0.41665223535061013
# Sustainability Specialists
# Cosine Similarity: 0.4371816003707444, Person Cosine Similarity: 0.1993040425381285
# Proofreaders and Copy Markers
# Cosine Similarity: 0.43078711013408005, Person Cosine Similarity: 0.3225435060391605
# ***********************
#
#
# ***********************
# Processing 807
# FUTURESEARCH
# FUTURESEARCH is an AI-powered platform that provides unbiased, deeply-researched answers to complex questions. By leveraging extensive data and advanced algorithms, FUTURESEARCH delivers comprehensive insights and evidence-based conclusions to support decision-making.
#
#
# Processing Job: NOT_ONET A journalist researching information for a news article.
# News Analysts, Reporters, and Journalists
# Cosine Similarity: 0.47555177556629674, Person Cosine Similarity: 0.424281675181192
# News Analysts, Reporters, and Journalists
# Cosine Similarity: 0.4731865561588501, Person Cosine Similarity: 0.424281675181192
# News Analysts, Reporters, and Journalists
# Cosine Similarity: 0.46783978876600796, Person Cosine Similarity: 0.424281675181192
#
# Processing Job: NOT_ONET A student researching information for a term paper.
# Social Science Research Assistants
# Cosine Similarity: 0.39467705723121876, Person Cosine Similarity: 0.3389805592136863
# Business Teachers, Postsecondary
# Cosine Similarity: 0.3642503870978305, Person Cosine Similarity: 0.21542648162913808
# Producers and Directors
# Cosine Similarity: 0.36244874601028554, Person Cosine Similarity: 0.10812881180617562
#
# Processing Job: NOT_ONET A business leader conducting market research.
# Marketing Managers
# Cosine Similarity: 0.48815351418143993, Person Cosine Similarity: 0.3609988456357238
# Marketing Managers
# Cosine Similarity: 0.4684210147255252, Person Cosine Similarity: 0.3609988456357238
# Market Research Analysts and Marketing Specialists
# Cosine Similarity: 0.466266989983614, Person Cosine Similarity: 0.4075024883211079
# ***********************
#
#
# ***********************
# Processing 808
# The Credit Genius App
# Description: The Credit Genius App is a mobile tool that uses gamified learning, AI coaching, and real-time data to empower users to understand and improve their credit scores. The app helps users make informed financial decisions and achieve their credit goals.
#
#
# Processing Job: A financial advisor gives recommendations on how to improve credit.
# Credit Counselors
# Cosine Similarity: 0.5160735885327545, Person Cosine Similarity: 0.4766066903205357
# Personal Financial Advisors
# Cosine Similarity: 0.5077821287475307, Person Cosine Similarity: 0.4708134679081146
# Credit Counselors
# Cosine Similarity: 0.4917382594523466, Person Cosine Similarity: 0.47664261501566707
#
# Processing Job: A personal finance planner helps users create and stick to their budgets.
# Credit Counselors
# Cosine Similarity: 0.5686464989541584, Person Cosine Similarity: 0.3297465826012822
# Personal Financial Advisors
# Cosine Similarity: 0.510759438748633, Person Cosine Similarity: 0.5146459624121561
# Personal Financial Advisors
# Cosine Similarity: 0.5049962548369216, Person Cosine Similarity: 0.5146459624121561
#
# Processing Job: A financial planner helps users plan out how to best manage their debts.
# Personal Financial Advisors
# Cosine Similarity: 0.634475031639921, Person Cosine Similarity: 0.49427420371120856
# Credit Counselors
# Cosine Similarity: 0.5712124771134603, Person Cosine Similarity: 0.4150695861010264
# Credit Counselors
# Cosine Similarity: 0.5261965194416303, Person Cosine Similarity: 0.41508872338422326
# ***********************
#
#
# ***********************
# Processing 809
# Zapptme LTD
# Zapptme is an AI-powered communication platform that helps you efficiently manage and schedule appointments. It simplifies the process by automating reminders, confirmations, and even rescheduling, saving you time and effort.
#
#
# Processing Job: A receptionist who sends appointment reminders to patients.
# Receptionists and Information Clerks
# Cosine Similarity: 0.604020801355901, Person Cosine Similarity: 0.45209034444237933
# Medical Assistants
# Cosine Similarity: 0.5735875141707645, Person Cosine Similarity: 0.33899508532907896
# Dental Hygienists
# Cosine Similarity: 0.5715602091767857, Person Cosine Similarity: 0.2945772844082064
#
# Processing Job: A receptionist who schedules and reschedules appointments.
# Receptionists and Information Clerks
# Cosine Similarity: 0.714675691512124, Person Cosine Similarity: 0.4791672037026694
# Medical Assistants
# Cosine Similarity: 0.6327796663965255, Person Cosine Similarity: 0.29242078451594844
# Spa Managers
# Cosine Similarity: 0.6148628548803589, Person Cosine Similarity: 0.3048996269417317
#
# Processing Job: A tutor sends confirmation emails to students.
# Tutors
# Cosine Similarity: 0.5987892492076754, Person Cosine Similarity: 0.5627337265288698
# Tutors
# Cosine Similarity: 0.5575490560552987, Person Cosine Similarity: 0.5627337265288698
# Tutors
# Cosine Similarity: 0.5305067189287368, Person Cosine Similarity: 0.5627905238195413
# ***********************
#
#
# ***********************
# Processing 810
# NodeOps
# NodeOps streamlines Web3 protocol development by providing AI-powered infrastructure for Node Operators. This allows them to quickly deploy and manage their nodes, freeing them to focus on building innovative applications.
#
#
# Processing Job: A developer configures and manages a node on a blockchain for the function of a decentralized application.
# Blockchain Engineers
# Cosine Similarity: 0.5139829853624288, Person Cosine Similarity: 0.38946133401608296
# Blockchain Engineers
# Cosine Similarity: 0.5023106419241792, Person Cosine Similarity: 0.38946133401608296
# Blockchain Engineers
# Cosine Similarity: 0.471497273548809, Person Cosine Similarity: 0.38946133401608296
#
# Processing Job: A node operator manages and configures validator nodes on a blockchain network.
# Blockchain Engineers
# Cosine Similarity: 0.428060335346125, Person Cosine Similarity: 0.2874505785954484
# Nuclear Power Reactor Operators
# Cosine Similarity: 0.39058924662711414, Person Cosine Similarity: 0.33810925523900526
# Nuclear Power Reactor Operators
# Cosine Similarity: 0.38575203962562377, Person Cosine Similarity: 0.33810925523900526
#
# Processing Job: NOT_ONET A developer configures and manages a decentralized file storage system for a Web3 protocol.
# Blockchain Engineers
# Cosine Similarity: 0.3749868528398149, Person Cosine Similarity: 0.3168434276890625
# Blockchain Engineers
# Cosine Similarity: 0.35675480184063646, Person Cosine Similarity: 0.31686574879112045
# Blockchain Engineers
# Cosine Similarity: 0.34173053921510554, Person Cosine Similarity: 0.3168534242890325
# **Saving Results**
#
#
# ***********************
#
#
# ***********************
# Processing 811
# MealByMeal
# MealByMeal is an AI-powered service that lets you track your calorie intake simply by texting what you eat. The platform calculates your calorie count and provides personalized insights to help you manage your diet effortlessly.
#
#
# Processing Job: NOT_ONET A dieter manually tracks their calorie intake.
# Dietetic Technicians
# Cosine Similarity: 0.39745903996507104, Person Cosine Similarity: 0.3194437063359747
# Nursing Assistants
# Cosine Similarity: 0.3645814952910921, Person Cosine Similarity: 0.19040491808328797
# Nursing Assistants
# Cosine Similarity: 0.3637121547174959, Person Cosine Similarity: 0.19036308687702422
#
# Processing Job: NOT_ONET A busy professional manually tracks their calorie intake.
# Food Preparation Workers
# Cosine Similarity: 0.3647666819863904, Person Cosine Similarity: 0.23830862699914923
# Fitness and Wellness Coordinators
# Cosine Similarity: 0.3619403190578454, Person Cosine Similarity: 0.2759764933821953
# Community Health Workers
# Cosine Similarity: 0.35245296397559056, Person Cosine Similarity: 0.2079741222665557
#
# Processing Job: NOT_ONET A weight loss enthusiast manually tracks their calorie intake and seeks out weightloss advice.
# Exercise Trainers and Group Fitness Instructors
# Cosine Similarity: 0.4157675957582418, Person Cosine Similarity: 0.2785335874175482
# Dietetic Technicians
# Cosine Similarity: 0.38783346547400516, Person Cosine Similarity: 0.2772395962091556
# Athletic Trainers
# Cosine Similarity: 0.3794461610290104, Person Cosine Similarity: 0.23217091293232672
# ***********************
#
#
# ***********************
# Processing 812
# GROATH Agen-zy
# GROATH Agen-zy is a user-friendly AI video tool that transforms lengthy videos into engaging short clips optimized for social media platforms. This service utilizes advanced algorithms to extract the most captivating moments from your videos, simplifying content creation and maximizing audience engagement.
#
#
# Processing Job: A video editor creates short-form videos from longer source material.
# Film and Video Editors
# Cosine Similarity: 0.6017401126831683, Person Cosine Similarity: 0.5341704501890343
# Film and Video Editors
# Cosine Similarity: 0.5801546672366311, Person Cosine Similarity: 0.5341704501890343
# Film and Video Editors
# Cosine Similarity: 0.5740653335919619, Person Cosine Similarity: 0.5342428684137046
#
# Processing Job: NOT_ONET A video editor creates short-form videos from longer source material to advertise products.
# Film and Video Editors
# Cosine Similarity: 0.5339737583123076, Person Cosine Similarity: 0.4951045690456455
# Film and Video Editors
# Cosine Similarity: 0.5192220096393233, Person Cosine Similarity: 0.4951045690456455
# Producers and Directors
# Cosine Similarity: 0.506651856678008, Person Cosine Similarity: 0.3489790226371697
#
# Processing Job: A video editor creates short-form videos from longer source material to advertise real estate properties.
# Film and Video Editors
# Cosine Similarity: 0.5395883898372693, Person Cosine Similarity: 0.48420314363062267
# Film and Video Editors
# Cosine Similarity: 0.5158570913725187, Person Cosine Similarity: 0.48420314363062267
# Film and Video Editors
# Cosine Similarity: 0.4983220980541011, Person Cosine Similarity: 0.48420314363062267
# ***********************
#
#
# ***********************
# Processing 813
# ENGINE Analytics
# ENGINE Analytics provides custom data analytics solutions for enterprises, including data automation, modeling, visualization, and predictive analytics. They aim to empower businesses to become more data-driven by offering a range of services, from cloud engineering and dashboard intelligence to data science and machine learning.
#
#
# Processing Job: A data analyst for a marketing manager performs data collection and analysis.
# Market Research Analysts and Marketing Specialists
# Cosine Similarity: 0.5949245047392427, Person Cosine Similarity: 0.500839482002996
# Market Research Analysts and Marketing Specialists
# Cosine Similarity: 0.5844801231295635, Person Cosine Similarity: 0.500839482002996
# Market Research Analysts and Marketing Specialists
# Cosine Similarity: 0.5573303157863829, Person Cosine Similarity: 0.500839482002996
#
# Processing Job: A data scientist for a financial analyst builds predictive models that forecast future sales and identify potential risks.
# Data Scientists
# Cosine Similarity: 0.640371295827118, Person Cosine Similarity: 0.5685301581873279
# Data Scientists
# Cosine Similarity: 0.611111827500354, Person Cosine Similarity: 0.5685029886273948
# Data Scientists
# Cosine Similarity: 0.610064588174491, Person Cosine Similarity: 0.5685301581873279
#
# Processing Job: A data scientist for a supply chain manager analyzes supply chain data.
# Supply Chain Managers
# Cosine Similarity: 0.628275972695516, Person Cosine Similarity: 0.5955772133848831
# Logistics Analysts
# Cosine Similarity: 0.6106238753673573, Person Cosine Similarity: 0.5335188568961342
# Logistics Engineers
# Cosine Similarity: 0.6074360391413098, Person Cosine Similarity: 0.4328101978275729
# ***********************
#
#
# ***********************
# Processing 814
# BeyondGravity
# BeyondGravity is a software development and talent solutions agency that helps technology-focused companies, from startups to established organizations, build custom software, validate product ideas, and find skilled team members. Their approach is tailored to each client's unique needs, prioritizing business goals and using the most appropriate technology to achieve them.
#
#
# Processing Job: A software developer builds the Minimum Viable Product (MVP) for a new mobile app.
# Web Developers
# Cosine Similarity: 0.38297684658552644, Person Cosine Similarity: 0.38844106431548314
# Software Developers
# Cosine Similarity: 0.36615768922888037, Person Cosine Similarity: 0.46427834420176506
# Web Developers
# Cosine Similarity: 0.35633105042917756, Person Cosine Similarity: 0.38841655119754553
#
# Processing Job: A market research analyst conducts market research and analyzes potential competitors to assess the viability of a new cloud-based solution.
# Market Research Analysts and Marketing Specialists
# Cosine Similarity: 0.6146340525253514, Person Cosine Similarity: 0.5406491222730098
# Market Research Analysts and Marketing Specialists
# Cosine Similarity: 0.6106807899060309, Person Cosine Similarity: 0.5406491222730098
# Market Research Analysts and Marketing Specialists
# Cosine Similarity: 0.5997640350258493, Person Cosine Similarity: 0.5406491222730098
#
# Processing Job: A talent recruiter sources and recruits highly skilled software engineers.
# Talent Directors
# Cosine Similarity: 0.5658619977743946, Person Cosine Similarity: 0.499151334605249
# Human Resources Specialists
# Cosine Similarity: 0.5177596320617222, Person Cosine Similarity: 0.3553721285264319
# Talent Directors
# Cosine Similarity: 0.515829157183789, Person Cosine Similarity: 0.4991170686853382
# ***********************
#
#
# ***********************
# Processing 815
# LeadForceTalent
# LeadForceTalent is an AI-powered recruitment platform designed for finding top and middle management candidates. It boasts a vast database of 25 million C-level professionals, automating interviews and skills assessments to deliver qualified candidates 10 times faster than traditional methods.
#
#
# Processing Job: NOT_ONET A recruiter performs candidate sourcing, skills assessment, and candidate ranking.
# Human Resources Specialists
# Cosine Similarity: 0.5333737704076668, Person Cosine Similarity: 0.3589693753013766
# Survey Researchers
# Cosine Similarity: 0.4829577841073476, Person Cosine Similarity: 0.28839038004082695
# Human Resources Specialists
# Cosine Similarity: 0.48045058947363495, Person Cosine Similarity: 0.3589693753013766
#
# Processing Job: An HR manager manages candidate communication and interview scheduling.
# Human Resources Managers
# Cosine Similarity: 0.5824260487733985, Person Cosine Similarity: 0.5111146825124936
# Human Resources Specialists
# Cosine Similarity: 0.5515753943820394, Person Cosine Similarity: 0.44012003571726593
# Spa Managers
# Cosine Similarity: 0.5319889394617445, Person Cosine Similarity: 0.30651437026451367
#
# Processing Job: A hiring manager evaluates candidate skillset and experience.
# Spa Managers
# Cosine Similarity: 0.49410473072182737, Person Cosine Similarity: 0.28576361260305533
# Lodging Managers
# Cosine Similarity: 0.4814169158140004, Person Cosine Similarity: 0.2529198614006529
# Investment Fund Managers
# Cosine Similarity: 0.4771570877688547, Person Cosine Similarity: 0.23876747078244515
# **Saving Results**
#
#
# ***********************
#
#
# ***********************
# Processing 816
# DermaQ
# DermaQ is an online dermatology clinic that leverages artificial intelligence to provide personalized treatment plans for skin and hair concerns. Through its AI-powered platform, DermaQ offers convenient and accessible solutions for individuals seeking professional dermatological care in India.
#
#
# Processing Job: A dermatologist analyzes patient photos and provides a diagnosis and treatment plan.
# Dermatologists
# Cosine Similarity: 0.5594884480132813, Person Cosine Similarity: 0.5284208992934982
# Dermatologists
# Cosine Similarity: 0.5241876507013101, Person Cosine Similarity: 0.5283665586536674
# Dermatologists
# Cosine Similarity: 0.5186515379596235, Person Cosine Similarity: 0.5283565613712095
#
# Processing Job: A dermatologist analyzes patient data and prescribes a personalized skincare plan.
# Dermatologists
# Cosine Similarity: 0.5626554778109916, Person Cosine Similarity: 0.5489366184253442
# Dermatologists
# Cosine Similarity: 0.5452584228623165, Person Cosine Similarity: 0.5488362037498556
# Dermatologists
# Cosine Similarity: 0.5412023645730271, Person Cosine Similarity: 0.5488633111653345
#
# Processing Job: NOT_ONET A receptionist schedules appointments with a dermatologist.
# Receptionists and Information Clerks
# Cosine Similarity: 0.5527584151037961, Person Cosine Similarity: 0.4245318484084075
# Spa Managers
# Cosine Similarity: 0.5340946587823558, Person Cosine Similarity: 0.3090932674208923
# Hairdressers, Hairstylists, and Cosmetologists
# Cosine Similarity: 0.4976256174912579, Person Cosine Similarity: 0.27631995459547853
# ***********************
#
#
# ***********************
# Processing 817
# Isiri AI
# Isiri AI is a platform that empowers users to leverage the power of GPT technologies by simplifying prompt creation and fostering collaboration. The platform provides dedicated support to translate industry-specific expertise into practical AI applications, making advanced AI tools accessible to everyone.
#
#
# Processing Job: A copywriter writes persuasive copy for new products, product descriptions and social media posts.
# Writers and Authors
# Cosine Similarity: 0.547620517674019, Person Cosine Similarity: 0.3410231060952702
# Writers and Authors
# Cosine Similarity: 0.5434866158764637, Person Cosine Similarity: 0.34101128481101656
# Writers and Authors
# Cosine Similarity: 0.5407508654623661, Person Cosine Similarity: 0.34101128481101656
#
# Processing Job: NOT_ONET A teacher develops personalized learning materials for students.
# Tutors
# Cosine Similarity: 0.5325230086334796, Person Cosine Similarity: 0.43924214191727223
# Self-Enrichment Teachers
# Cosine Similarity: 0.5123500270075962, Person Cosine Similarity: 0.4216136404061506
# Tutors
# Cosine Similarity: 0.5025218182399906, Person Cosine Similarity: 0.43924214191727223
#
# Processing Job: A research assistant analyzes large datasets and generates scientific hypotheses.
# Social Science Research Assistants
# Cosine Similarity: 0.6348929174543655, Person Cosine Similarity: 0.5485558533160418
# Social Science Research Assistants
# Cosine Similarity: 0.6202453412398329, Person Cosine Similarity: 0.5485138292067229
# Social Science Research Assistants
# Cosine Similarity: 0.6041699511958052, Person Cosine Similarity: 0.5485735286290914
# ***********************
#
#
# ***********************
# Processing 818
# Scroll
# Scroll is an AI-powered news aggregator that delivers concise, unbiased news summaries under 50 words, fostering a community where users can connect with like-minded individuals and earn revenue through content creation.
#
#
# Processing Job: NOT_ONET A student reads lengthy news articles to stay current on their field of research.
# Data Scientists
# Cosine Similarity: 0.4479279106927001, Person Cosine Similarity: 0.23492827150728887
# Nuclear Engineers
# Cosine Similarity: 0.43654799379318054, Person Cosine Similarity: 0.15982992303488197
# Training and Development Specialists
# Cosine Similarity: 0.42395494227726216, Person Cosine Similarity: 0.16808380195826808
#
# Processing Job: A news editor writes summaries of news articles.
# Editors
# Cosine Similarity: 0.6078633581666626, Person Cosine Similarity: 0.38589046426997264
# Producers and Directors
# Cosine Similarity: 0.5850737463921476, Person Cosine Similarity: 0.20960536027429974
# Editors
# Cosine Similarity: 0.5684297834872476, Person Cosine Similarity: 0.38589046426997264
#
# Processing Job: NOT_ONET A writer researches current news articles for content creation.
# Writers and Authors
# Cosine Similarity: 0.47699768910230256, Person Cosine Similarity: 0.38499630474582497
# News Analysts, Reporters, and Journalists
# Cosine Similarity: 0.4623972916321556, Person Cosine Similarity: 0.4149147005276538
# News Analysts, Reporters, and Journalists
# Cosine Similarity: 0.4566502528250564, Person Cosine Similarity: 0.4149147005276538
# ***********************
#
#
# ***********************
# Processing 819
# Telehire AI
# Telehire AI is an AI-powered platform that streamlines the hiring process, automating tasks like job description creation and pre-screening candidates. It provides a one-stop solution for both employers and job seekers, offering an efficient and effective way to find the perfect match.
#
#
# Processing Job: A recruiter writes a job description for a software engineer.
# Web Developers
# Cosine Similarity: 0.44774630441546004, Person Cosine Similarity: 0.305515634673578
# Sales Engineers
# Cosine Similarity: 0.44361513414104914, Person Cosine Similarity: 0.4122039932945086
# Software Developers
# Cosine Similarity: 0.4249919306550394, Person Cosine Similarity: 0.43128975289782445
#
# Processing Job: A recruiter pre-screens candidates for a marketing position.
# First-Line Supervisors of Personal Service Workers
# Cosine Similarity: 0.47627894132121257, Person Cosine Similarity: 0.1890243554838827
# Social Science Research Assistants
# Cosine Similarity: 0.46467710111248994, Person Cosine Similarity: 0.29392786467541127
# Survey Researchers
# Cosine Similarity: 0.45556053966477994, Person Cosine Similarity: 0.31053749495169136
#
# Processing Job: NOT_ONET
# Nuclear Monitoring Technicians
# Cosine Similarity: 0.21381090236370953, Person Cosine Similarity: 0.21828888673582647
# Computer Numerically Controlled Tool Operators
# Cosine Similarity: 0.205814640157761, Person Cosine Similarity: 0.24990503757335633
# Computer Numerically Controlled Tool Operators
# Cosine Similarity: 0.19883632832387022, Person Cosine Similarity: 0.2503833304141965
# ***********************
#
#
# ***********************
# Processing 820
# Simbuy
# Simbuy is a cloud-based procurement platform that centralizes data from various sources, providing businesses with comprehensive market insights and streamlined processes for supplier acquisition, onboarding, and tender management. Simbuy leverages AI to automate tasks and improve efficiency, making procurement easier and more effective.
#
#
# Processing Job: A procurement specialist uses data and analytics to identify the best option for a new manufacturing project based on cost, quality, and delivery timelines.
# Supply Chain Managers
# Cosine Similarity: 0.5774773617950539, Person Cosine Similarity: 0.3909186612044971
# Logistics Analysts
# Cosine Similarity: 0.5679891890341093, Person Cosine Similarity: 0.4791746587615357
# Logistics Analysts
# Cosine Similarity: 0.5606183192142459, Person Cosine Similarity: 0.4791391880140053
#
# Processing Job: A business manager is responsible for onboarding new suppliers and verifying documentation.
# Supply Chain Managers
# Cosine Similarity: 0.56446291939681, Person Cosine Similarity: 0.4871065257221516
# Supply Chain Managers
# Cosine Similarity: 0.4950175481241525, Person Cosine Similarity: 0.48708475601535794
# Purchasing Managers
# Cosine Similarity: 0.4666074463857464, Person Cosine Similarity: 0.4110249064585628
#
# Processing Job: A purchasing team member is responsible for generating custom tenders and tracking bids for construction projects.
# Purchasing Managers
# Cosine Similarity: 0.5915099923686512, Person Cosine Similarity: 0.4793100270614077
# Purchasing Managers
# Cosine Similarity: 0.5885182708713539, Person Cosine Similarity: 0.4793100270614077
# Cost Estimators
# Cosine Similarity: 0.5665697239563126, Person Cosine Similarity: 0.325696572870333
# **Saving Results**
#
#
# ***********************
#
#
# ***********************
# Processing 821
# NX Retail
# NX Retail provides an all-in-one platform for retailers and wholesalers to manage their online and physical stores, enabling unified commerce, data-driven insights, personalized customer experiences, and optimized supply chain management.  This SaaS solution simplifies retail operations and empowers businesses to deliver seamless and engaging shopping experiences across all channels.
#
#
# Processing Job: An inventory manager manually tracks sales data and predicts future demand to adjust inventory levels.
# Supply Chain Managers
# Cosine Similarity: 0.5542378153249286, Person Cosine Similarity: 0.44943256675233123
# Supply Chain Managers
# Cosine Similarity: 0.5233161312632937, Person Cosine Similarity: 0.44943256675233123
# Spa Managers
# Cosine Similarity: 0.5194060838019551, Person Cosine Similarity: 0.2523338166762302
#
# Processing Job: A customer service representative handles orders manually by routing them to the appropriate warehouse or fulfillment center.
# Online Merchants
# Cosine Similarity: 0.5352230904026254, Person Cosine Similarity: 0.28507143187860473
# Sales Representatives, Wholesale and Manufacturing, Except Technical and Scientific Products
# Cosine Similarity: 0.5256343191379323, Person Cosine Similarity: 0.3495724853758011
# Customer Service Representatives
# Cosine Similarity: 0.5228112844569168, Person Cosine Similarity: 0.547312928940728
#
# Processing Job: A marketing manager manually creates email campaigns and segments customer lists based on their purchasing history and preferences.
# Marketing Managers
# Cosine Similarity: 0.5028128831938596, Person Cosine Similarity: 0.4834954801517072
# Spa Managers
# Cosine Similarity: 0.4588777079182519, Person Cosine Similarity: 0.33426278158071865
# Sales Managers
# Cosine Similarity: 0.45738134019812904, Person Cosine Similarity: 0.4053742423238898
# ***********************
#
#
# ***********************
# Processing 822
# Creato.ai
# Creato.ai is a SaaS marketing platform that utilizes AI to automate content creation, enabling businesses and individuals to quickly generate high-quality images, videos, and social media posts, freeing up time for strategic growth.
#
#
# Processing Job: A social media manager creates eye-catching social media posts for a new product launch.
# Public Relations Specialists
# Cosine Similarity: 0.4739868118630864, Person Cosine Similarity: 0.31250152380072277
# Search Marketing Strategists
# Cosine Similarity: 0.4562696591739848, Person Cosine Similarity: 0.3587940256636604
# Advertising and Promotions Managers
# Cosine Similarity: 0.4384293157077372, Person Cosine Similarity: 0.38849792081658285
#
# Processing Job: A copywriter generates personalized product descriptions for an online store.
# Online Merchants
# Cosine Similarity: 0.6427035525559954, Person Cosine Similarity: 0.32126650923950983
# Online Merchants
# Cosine Similarity: 0.5856511596534404, Person Cosine Similarity: 0.32126650923950983
# Writers and Authors
# Cosine Similarity: 0.5307657366399375, Person Cosine Similarity: 0.32779803102039695
#
# Processing Job: A freelance writer generates compelling content for a blog.
# Writers and Authors
# Cosine Similarity: 0.41058301546777315, Person Cosine Similarity: 0.3929617414543326
# News Analysts, Reporters, and Journalists
# Cosine Similarity: 0.40998245363867075, Person Cosine Similarity: 0.2327326109687186
# Writers and Authors
# Cosine Similarity: 0.4057578362778063, Person Cosine Similarity: 0.3929617414543326
# ***********************
#
#
# ***********************
# Processing 823
# Stratosphere AI
# Stratosphere AI enhances the functionality and security of NFTs by integrating them with artificial intelligence. This allows for dynamic, personalized experiences, transforming static digital assets into interactive entities.
#
#
# Processing Job: NOT_ONET An NFT artist would normally create a static NFT, but this tool allows for dynamic NFT creation.
# Craft Artists
# Cosine Similarity: 0.3193215005331325, Person Cosine Similarity: 0.30128395880690617
# Special Effects Artists and Animators
# Cosine Similarity: 0.2958379708137219, Person Cosine Similarity: 0.2622653841022171
# Fine Artists, Including Painters, Sculptors, and Illustrators
# Cosine Similarity: 0.29316753799437567, Person Cosine Similarity: 0.24290507062955602
#
# Processing Job: NOT_ONET A NFT collector might normally interact with NFTs, but this tool allows for interactive personalized NFT creation.
# Craft Artists
# Cosine Similarity: 0.32232075006300703, Person Cosine Similarity: 0.2685131822421302
# Computer Numerically Controlled Tool Programmers
# Cosine Similarity: 0.2902802267943061, Person Cosine Similarity: 0.2603714925352577
# Craft Artists
# Cosine Similarity: 0.2892268402767548, Person Cosine Similarity: 0.26838493104034017
#
# Processing Job: A cybersecurity engineer would normally perform cybersecurity tasks, but this tool automates NFT security and authentication.
# Information Security Engineers
# Cosine Similarity: 0.5509494467251556, Person Cosine Similarity: 0.4925765021681725
# Information Security Engineers
# Cosine Similarity: 0.537074428108024, Person Cosine Similarity: 0.4925537571819674
# Information Security Engineers
# Cosine Similarity: 0.4982854334016204, Person Cosine Similarity: 0.4925765021681725
# ***********************
#
#
# ***********************
# Processing 824
# HQ Workspace
# HQ Workspace is a B2B marketplace that connects brands, agencies, and creative talents in the advertising industry. Leveraging fintech and AI, HQ streamlines the booking process, making it easier for all parties to collaborate and manage projects efficiently.
#
#
# Processing Job: A brand manager searches for a freelance photographer, books them, and manages workflow and communication.
# Photographers
# Cosine Similarity: 0.498196568806883, Person Cosine Similarity: 0.37607036910257474
# Photographers
# Cosine Similarity: 0.4866892584478685, Person Cosine Similarity: 0.37607036910257474
# Art Directors
# Cosine Similarity: 0.4631465196759216, Person Cosine Similarity: 0.3169771505184189
#
# Processing Job: A recruiter for a creative agency sources and vets graphic designers for a new project.
# Graphic Designers
# Cosine Similarity: 0.5041628704714037, Person Cosine Similarity: 0.5224516491030116
# Graphic Designers
# Cosine Similarity: 0.4875835383008425, Person Cosine Similarity: 0.5224397268546808
# Art Directors
# Cosine Similarity: 0.48282164015725065, Person Cosine Similarity: 0.44336717327355646
#
# Processing Job: A freelance writer manages client projects, tracks their hours, and receives payments.
# Writers and Authors
# Cosine Similarity: 0.45113070223099216, Person Cosine Similarity: 0.3531703568427432
# Editors
# Cosine Similarity: 0.4130875557841456, Person Cosine Similarity: 0.19367915370493596
# Art Directors
# Cosine Similarity: 0.39468658964853376, Person Cosine Similarity: 0.16010177580030516
# ***********************
#
#
# ***********************
# Processing 825
# VALU
# VALU is an AI-powered recruitment platform that streamlines the hiring process by using its innovative AI interviewer, Serena, to automate and enhance candidate screening interviews. This technology enables businesses to conduct unbiased, insightful assessments while saving time and resources.
#
#
# Processing Job: A recruiter conducts initial screening interviews.
# Human Resources Specialists
# Cosine Similarity: 0.5190969614059351, Person Cosine Similarity: 0.33869400514884174
# Human Resources Specialists
# Cosine Similarity: 0.4980540141878238, Person Cosine Similarity: 0.33874750602452053
# Social Science Research Assistants
# Cosine Similarity: 0.4963073298567853, Person Cosine Similarity: 0.2662629168977203
#
# Processing Job: A hiring manager analyzes feedback from candidate interviews.
# Human Resources Managers
# Cosine Similarity: 0.4879834490573375, Person Cosine Similarity: 0.3626230999999531
# Compensation and Benefits Managers
# Cosine Similarity: 0.4548451856062563, Person Cosine Similarity: 0.2646011030291036
# Funeral Home Managers
# Cosine Similarity: 0.45438652483244635, Person Cosine Similarity: 0.24211303224887276
#
# Processing Job: A recruiter schedules candidate interviews.
# Human Resources Specialists
# Cosine Similarity: 0.48285781422798113, Person Cosine Similarity: 0.32381138827589845
# Human Resources Specialists
# Cosine Similarity: 0.48261914230562086, Person Cosine Similarity: 0.32381138827589845
# Spa Managers
# Cosine Similarity: 0.473414957171838, Person Cosine Similarity: 0.18448873541506083
# **Saving Results**
#
#
# ***********************
#
#
# ***********************
# Processing 826
# nibnab
# Nibnab.ai is an AI-powered platform that streamlines the sales process, helping users discover, create, negotiate, and close deals more efficiently. It provides intelligent insights and automation tools to boost sales performance and drive revenue growth.
#
#
# Processing Job: A sales representative or sales development representative conducts market research to find leads.
# Sales Representatives, Wholesale and Manufacturing, Technical and Scientific Products
# Cosine Similarity: 0.5893058099216306, Person Cosine Similarity: 0.43613668516978177
# Sales Representatives, Wholesale and Manufacturing, Except Technical and Scientific Products
# Cosine Similarity: 0.5870447220088068, Person Cosine Similarity: 0.43297874482081633
# Sales Representatives of Services, Except Advertising, Insurance, Financial Services, and Travel
# Cosine Similarity: 0.5771492093601609, Person Cosine Similarity: 0.4215449427818717
#
# Processing Job: A sales manager reviews customer interaction data and identifies trends for closing deals.
# Sales Managers
# Cosine Similarity: 0.6062035129187716, Person Cosine Similarity: 0.4958761938421818
# Sales Managers
# Cosine Similarity: 0.5971652862249284, Person Cosine Similarity: 0.4958761938421818
# Sales Managers
# Cosine Similarity: 0.517220752409272, Person Cosine Similarity: 0.4958761938421818
#
# Processing Job: A business development manager performs administrative and customer outreach tasks.
# Financial Managers
# Cosine Similarity: 0.4444146582871594, Person Cosine Similarity: 0.27702628813629715
# Financial Managers
# Cosine Similarity: 0.4277488499439049, Person Cosine Similarity: 0.2770149523498458
# Advertising and Promotions Managers
# Cosine Similarity: 0.4019409817074605, Person Cosine Similarity: 0.30565243704019
# ***********************
#
#
# ***********************
# Processing 827
# Gala Coach
# Gala Coach is an AI-powered nutritionist that provides personalized guidance and support to help users achieve their health goals, whether it's weight loss, exercise, or managing anxiety. The platform offers proactive support and acts as a companion on your health journey.
#
#
# Processing Job: A nutritionist creates a meal plan that fits a person's dietary needs and goals.
# Dietitians and Nutritionists
# Cosine Similarity: 0.5957736869236725, Person Cosine Similarity: 0.48291753618648736
# Dietitians and Nutritionists
# Cosine Similarity: 0.5857860866367394, Person Cosine Similarity: 0.48291753618648736
# Dietitians and Nutritionists
# Cosine Similarity: 0.567248601435435, Person Cosine Similarity: 0.48291753618648736
#
# Processing Job: A fitness coach creates a personalized workout plan for a user.
# Exercise Trainers and Group Fitness Instructors
# Cosine Similarity: 0.4723871582696536, Person Cosine Similarity: 0.3922683516337843
# Exercise Trainers and Group Fitness Instructors
# Cosine Similarity: 0.4660226895015219, Person Cosine Similarity: 0.3922683516337843
# Fitness and Wellness Coordinators
# Cosine Similarity: 0.43373693870802815, Person Cosine Similarity: 0.43003339986714506
#
# Processing Job: A mental health professional provides personalized coping strategies and relaxation techniques for a user.
# Psychiatrists
# Cosine Similarity: 0.42000959398341037, Person Cosine Similarity: 0.3093403717339359
# Mental Health Counselors
# Cosine Similarity: 0.41850565318031147, Person Cosine Similarity: 0.41653170601256856
# Acupuncturists
# Cosine Similarity: 0.4155354467043376, Person Cosine Similarity: 0.22283727951808907
# ***********************
#
#
# ***********************
# Processing 828
# WonderStories.ai
# WonderStories.ai is an AI-powered platform that creates personalized bedtime stories for children, allowing parents to customize the stories with their child's name, interests, and even the voice of their choosing. With WonderStories.ai, bedtime becomes a magical experience filled with imaginative adventures and personalized narratives.
#
#
# Processing Job: A parent writes, personalizes, and voices a bedtime story for their child.
# Actors
# Cosine Similarity: 0.3465748955300584, Person Cosine Similarity: 0.12774337878373135
# Writers and Authors
# Cosine Similarity: 0.32776185118034085, Person Cosine Similarity: 0.277957013533648
# Childcare Workers
# Cosine Similarity: 0.3083158135203599, Person Cosine Similarity: 0.1872693518419945
#
# Processing Job: A parent writes, personalizes, and voices a bedtime story for their child.
# Actors
# Cosine Similarity: 0.3465748955300584, Person Cosine Similarity: 0.12774337878373135
# Writers and Authors
# Cosine Similarity: 0.32776185118034085, Person Cosine Similarity: 0.277957013533648
# Childcare Workers
# Cosine Similarity: 0.3083158135203599, Person Cosine Similarity: 0.1872693518419945
#
# Processing Job: A parent writes, personalizes, and voices a bedtime story for their child.
# Actors
# Cosine Similarity: 0.3465748955300584, Person Cosine Similarity: 0.12781977423453983
# Writers and Authors
# Cosine Similarity: 0.32776185118034085, Person Cosine Similarity: 0.277957013533648
# Childcare Workers
# Cosine Similarity: 0.3083158135203599, Person Cosine Similarity: 0.1872693518419945
# ***********************
#
#
# ***********************
# Processing 829
# BluechipAI
# BluechipAI is an AI-powered investment platform that connects investors with promising early-stage startups, often before they launch publicly. Through advanced screening and analysis, BluechipAI identifies high-potential companies and provides investors exclusive access to support innovative ventures with significant return potential.
#
#
# Processing Job: An angel investor uses tools to analyze and identify startup investments.
# Investment Fund Managers
# Cosine Similarity: 0.4971097279166191, Person Cosine Similarity: 0.3476105324239799
# Investment Fund Managers
# Cosine Similarity: 0.44523395856814907, Person Cosine Similarity: 0.3476105324239799
# Investment Fund Managers
# Cosine Similarity: 0.42940611077567115, Person Cosine Similarity: 0.3476105324239799
#
# Processing Job: A venture capitalist analyzes and prioritizes investments in startups based on their likelihood of growth.
# Investment Fund Managers
# Cosine Similarity: 0.5430806425455986, Person Cosine Similarity: 0.346736657123881
# Investment Fund Managers
# ...
# ***********************
#
#
# ***********************
# Processing 988
# Dub AI
# Dub AI is an AI-powered platform that automatically translates and dubs your media content into over 25 languages, including voice cloning and multi-speaker capabilities.  With Dub AI, you can quickly and easily create localized versions of your videos for a global audience.
#
#
# Processing Job: NOT_ONET A person translating the video from English to Spanish, French, and German.
# Interpreters and Translators
# Cosine Similarity: 0.40304335564323973, Person Cosine Similarity: 0.34157684524613174
# Historians
# Cosine Similarity: 0.40198193117110903, Person Cosine Similarity: 0.11691112950795748
# Interpreters and Translators
# Cosine Similarity: 0.38598752290831073, Person Cosine Similarity: 0.34157684524613174
#
# Processing Job: A translator would normally be responsible for localizing video content for different markets.
# Interpreters and Translators
# Cosine Similarity: 0.5510335808091504, Person Cosine Similarity: 0.4242777409692161
# Interpreters and Translators
# Cosine Similarity: 0.5356984383318274, Person Cosine Similarity: 0.4243629615178708
# Interpreters and Translators
# Cosine Similarity: 0.48085002230945434, Person Cosine Similarity: 0.4243629615178708
#
# Processing Job: A team of translators would normally be responsible for creating multi-language dubs for movies.
# Broadcast Technicians
# Cosine Similarity: 0.5964894156627398, Person Cosine Similarity: 0.22694646946318237
# Interpreters and Translators
# Cosine Similarity: 0.5012719962358634, Person Cosine Similarity: 0.4107579094627459
# Interpreters and Translators
# Cosine Similarity: 0.48893409298412815, Person Cosine Similarity: 0.4105670118440303
# ***********************
#
#
# ***********************
# Processing 989
# HALO HALO Corp
# HALO HALO Corp is a mobile app company that empowers Filipino creatives by providing a platform for them to showcase their digital comics globally.  The app utilizes innovative advertising and AI technology to enhance the user experience and provide creators with sustainable revenue streams.
#
#
# Processing Job: NOT_ONET A comic artist has to manually find and manage advertisement partnerships.
# Craft Artists
# Cosine Similarity: 0.40112645809654135, Person Cosine Similarity: 0.27488628892893285
# Advertising Sales Agents
# Cosine Similarity: 0.392451476714942, Person Cosine Similarity: 0.35932900588381206
# Fine Artists, Including Painters, Sculptors, and Illustrators
# Cosine Similarity: 0.3882222414898298, Person Cosine Similarity: 0.27224539521043056
#
# Processing Job: A comic artist has to manually track the popularity of their work, including views, likes, and comments.
# Fine Artists, Including Painters, Sculptors, and Illustrators
# Cosine Similarity: 0.3609225949115845, Person Cosine Similarity: 0.2612462416779786
# Fine Artists, Including Painters, Sculptors, and Illustrators
# Cosine Similarity: 0.32288975090429606, Person Cosine Similarity: 0.2612462416779786
# Desktop Publishers
# Cosine Similarity: 0.3092063255908958, Person Cosine Similarity: 0.23355435750056547
#
# Processing Job: NOT_ONET A comic artist has to manually create multi-chapter comic series.
# Fine Artists, Including Painters, Sculptors, and Illustrators
# Cosine Similarity: 0.36612759809430484, Person Cosine Similarity: 0.2554606378888987
# Fine Artists, Including Painters, Sculptors, and Illustrators
# Cosine Similarity: 0.3403682999962454, Person Cosine Similarity: 0.2554606378888987
# Special Effects Artists and Animators
# Cosine Similarity: 0.3237737652397851, Person Cosine Similarity: 0.2408858028790442
# ***********************
#
#
# ***********************
# Processing 990
# Myrddin Emrys
# Myrddin Emrys is a technology advisory firm that helps businesses navigate the complexities of technology by providing strategic guidance, technical due diligence, and fractional CTO services. They specialize in connecting technology, product development, business strategy, and investment, ensuring sustainable and secure technology solutions on a global scale.
#
#
# Processing Job: A technical consultant for a startup analyzes the company's technology to give investors a clear understanding of the platform.
# Blockchain Engineers
# Cosine Similarity: 0.4521774540963083, Person Cosine Similarity: 0.3015027481625072
# Software Developers
# Cosine Similarity: 0.433663922334393, Person Cosine Similarity: 0.26602634562687943
# Investment Fund Managers
# Cosine Similarity: 0.4330102531200044, Person Cosine Similarity: 0.24897167281031363
#
# Processing Job: A technology expert is in charge of determining what technologies the company needs to use and how to implement them.
# Computer Systems Engineers/Architects
# Cosine Similarity: 0.482364031676652, Person Cosine Similarity: 0.3463611208621307
# Computer and Information Systems Managers
# Cosine Similarity: 0.4759510701846145, Person Cosine Similarity: 0.3001886984581351
# Electrical and Electronic Engineering Technologists and Technicians
# Cosine Similarity: 0.45884098427912146, Person Cosine Similarity: 0.30703985101055276
#
# Processing Job: A chief technology officer (CTO) assesses a company's technology and team to make sure that it is a viable investment option.
# Investment Fund Managers
# Cosine Similarity: 0.44896074750867543, Person Cosine Similarity: 0.26527041993766265
# Chief Sustainability Officers
# Cosine Similarity: 0.4023165101215751, Person Cosine Similarity: 0.3170888047058213
# Financial and Investment Analysts
# Cosine Similarity: 0.4014297758354211, Person Cosine Similarity: 0.25831455967522177
# **Saving Results**
#
#
# ***********************
#
#
# ***********************
# Processing 991
# Alle-AI
# Alle-AI is a comprehensive platform that integrates various generative AI tools, allowing users to access and utilize their combined power for diverse creative tasks. This platform empowers users to generate various forms of content, such as text, images, audio, and video, with ease and efficiency.
#
#
# Processing Job: A video editor creates engaging video ads.
# Film and Video Editors
# Cosine Similarity: 0.5484732790996285, Person Cosine Similarity: 0.5461219659606704
# Film and Video Editors
# Cosine Similarity: 0.5459185667642179, Person Cosine Similarity: 0.5461219659606704
# Film and Video Editors
# Cosine Similarity: 0.5441839125381764, Person Cosine Similarity: 0.5461219659606704
#
# Processing Job: An artist creates digital paintings in a variety of styles and themes.
# Fine Artists, Including Painters, Sculptors, and Illustrators
# Cosine Similarity: 0.462156737389319, Person Cosine Similarity: 0.3567789200399763
# Fine Artists, Including Painters, Sculptors, and Illustrators
# Cosine Similarity: 0.461148458659304, Person Cosine Similarity: 0.3567789200399763
# Fine Artists, Including Painters, Sculptors, and Illustrators
# Cosine Similarity: 0.4491364675288847, Person Cosine Similarity: 0.35662235867871767
#
# Processing Job: A composer writes music scores for films.
# Music Directors and Composers
# Cosine Similarity: 0.6219245075441875, Person Cosine Similarity: 0.5591939165416431
# Music Directors and Composers
# Cosine Similarity: 0.6166862148047395, Person Cosine Similarity: 0.5591939165416431
# Music Directors and Composers
# Cosine Similarity: 0.606823078966477, Person Cosine Similarity: 0.5591939165416431
# ***********************
#
#
# ***********************
# Processing 992
# GoAudience
# GoAudience is a marketing platform that leverages AI and a vast consumer database to target potential customers for e-commerce brands on social media. This platform helps businesses reduce customer acquisition costs by up to 50% by finding new customers based on their credit card spending history.
#
#
# Processing Job: A marketing manager for a clothing store creates targeted ads for customers on social media.
# Advertising and Promotions Managers
# Cosine Similarity: 0.5004709586846858, Person Cosine Similarity: 0.4813581665940674
# Fashion Designers
# Cosine Similarity: 0.4996162972122124, Person Cosine Similarity: 0.3264886237935359
# Marketing Managers
# Cosine Similarity: 0.49923016023889905, Person Cosine Similarity: 0.5667740087433255
#
# Processing Job: A marketing manager for a furniture and home good company finds customers on social media to market to.
# Search Marketing Strategists
# Cosine Similarity: 0.5009034763932356, Person Cosine Similarity: 0.44261344534165126
# Marketing Managers
# Cosine Similarity: 0.4963973376281101, Person Cosine Similarity: 0.541345196245292
# Spa Managers
# Cosine Similarity: 0.4755776093038642, Person Cosine Similarity: 0.31663813725837675
#
# Processing Job: A marketing manager for a handmade jewelry company identifies customers on social media that have a history of purchasing jewelry.
# Craft Artists
# Cosine Similarity: 0.4861185051631768, Person Cosine Similarity: 0.3005176700073891
# Sales Managers
# Cosine Similarity: 0.45563276220331417, Person Cosine Similarity: 0.3627769813456535
# Fashion Designers
# Cosine Similarity: 0.4233333802383322, Person Cosine Similarity: 0.21256087571314444
# ***********************
#
#
# ***********************
# Processing 993
# Bridgecare
# BridgeCare offers a cutting-edge solution that combines AI-powered assessments with certified coaches to deliver on-demand mental health support to students, empowering them to thrive academically and emotionally.  This SaaS platform provides both mobile accessibility and personalized coaching sessions, ensuring students receive the support they need, when they need it.
#
#
# Processing Job: A student needs to be screened and connected with a coach for anxiety.
# Coaches and Scouts
# Cosine Similarity: 0.3952975163410276, Person Cosine Similarity: 0.3230452711487472
# Adapted Physical Education Specialists
# Cosine Similarity: 0.38967497899485254, Person Cosine Similarity: 0.3025230352641154
# Child, Family, and School Social Workers
# Cosine Similarity: 0.386202046368761, Person Cosine Similarity: 0.2133497594566079
#
# Processing Job: NOT_ONET A student needs to track their emotional well-being and access on-demand resources for managing stress and enhancing resilience.
# School Psychologists
# Cosine Similarity: 0.3703636806249814, Person Cosine Similarity: 0.31812203236474423
# Residential Advisors
# Cosine Similarity: 0.36241938426579423, Person Cosine Similarity: 0.2687448081601054
# Midwives
# Cosine Similarity: 0.35070783709711606, Person Cosine Similarity: 0.116223441990713
#
# Processing Job: A student needs to receive personalized recommendations for study strategies, time management techniques, and stress-reduction exercises based on their individual needs and learning style.
# Tutors
# Cosine Similarity: 0.5282960531422256, Person Cosine Similarity: 0.36500276929517494
# Tutors
# Cosine Similarity: 0.4316702681338179, Person Cosine Similarity: 0.36503185300702345
# Tutors
# Cosine Similarity: 0.43061058618773396, Person Cosine Similarity: 0.3651349610127927
# ***********************
#
#
# ***********************
# Processing 994
# BOOK HOTEL DIRECT
# BookHotel.direct is a commission-free booking platform dedicated to empowering independent hotels by offering direct booking solutions and personalized support to increase their online visibility and reduce reliance on third-party websites.  The platform also provides travelers with a diverse selection of independent hotels at the best prices, eliminating hidden fees and offering a convenient way to plan and book unique travel experiences.
#
#
# Processing Job: A travel agent books a hotel for a client.
# Travel Agents
# Cosine Similarity: 0.6306626169377467, Person Cosine Similarity: 0.6205858314776644
# Travel Agents
# Cosine Similarity: 0.5757379507120444, Person Cosine Similarity: 0.6205858314776644
# Travel Agents
# Cosine Similarity: 0.5551402502500375, Person Cosine Similarity: 0.6205858314776644
#
# Processing Job: A hotel website developer designs and manages a website for a hotelier.
# Web Developers
# Cosine Similarity: 0.5379498007462957, Person Cosine Similarity: 0.5039719390135706
# Web Developers
# Cosine Similarity: 0.5148672396275707, Person Cosine Similarity: 0.5039719390135706
# Web and Digital Interface Designers
# Cosine Similarity: 0.513954655987708, Person Cosine Similarity: 0.4513177912672517
#
# Processing Job: A customer service rep assists a customer with a booking.
# Travel Agents
# Cosine Similarity: 0.4799222316584124, Person Cosine Similarity: 0.40799560993109707
# Reservation and Transportation Ticket Agents and Travel Clerks
# Cosine Similarity: 0.4618159934959891, Person Cosine Similarity: 0.3725589914207358
# Travel Agents
# Cosine Similarity: 0.4591210419576677, Person Cosine Similarity: 0.4080275635067323
# ***********************
#
#
# ***********************
# Processing 995
# Commented
# Commented is a tool that allows teams to collaborate directly within their live digital projects, enabling them to leave comments and engage in discussions on the actual work itself, facilitating seamless communication and enhancing productivity. This platform empowers teams to build high-quality products through direct, contextual feedback and collaboration.
#
#
# Processing Job: NOT_ONET Designer provides feedback on a colleague's prototype.
# Video Game Designers
# Cosine Similarity: 0.4901232482660644, Person Cosine Similarity: 0.3062158704897977
# Video Game Designers
# Cosine Similarity: 0.4575224447733802, Person Cosine Similarity: 0.3062204262134637
# Graphic Designers
# Cosine Similarity: 0.4230441730989809, Person Cosine Similarity: 0.30529374949265464
#
# Processing Job: Product manager gathers feedback from a development team on a new feature.
# Marketing Managers
# Cosine Similarity: 0.4590645322599516, Person Cosine Similarity: 0.3298032307645348
# Information Technology Project Managers
# Cosine Similarity: 0.448818713319161, Person Cosine Similarity: 0.30520168245851265
# Information Technology Project Managers
# Cosine Similarity: 0.4424119979037828, Person Cosine Similarity: 0.3059313894037659
#
# Processing Job: Developers discuss implementation details on a project.
# Blockchain Engineers
# Cosine Similarity: 0.4905759425187184, Person Cosine Similarity: 0.3332783718061603
# Web Developers
# Cosine Similarity: 0.47497933168100326, Person Cosine Similarity: 0.43824723668644944
# Web Developers
# Cosine Similarity: 0.45544821751840137, Person Cosine Similarity: 0.43824723668644944
# **Saving Results**
#
#
# ***********************
#
#
# ***********************
# Processing 996
# SocialCap AI
# SocialCap AI is an AI-powered platform that helps users manage their contacts and build meaningful connections by leveraging insights from social, behavioral, and psychological sciences. This platform combines advanced technology with scientific principles to optimize social interactions and networking experiences, empowering users to achieve both personal and professional goals.
#
#
# Processing Job: A sales professional performs market research and identifies potential clients.
# Sales Engineers
# Cosine Similarity: 0.6262063876186775, Person Cosine Similarity: 0.3586962048095391
# Sales Representatives, Wholesale and Manufacturing, Technical and Scientific Products
# Cosine Similarity: 0.5448563981969448, Person Cosine Similarity: 0.37190492383685336
# Advertising Sales Agents
# Cosine Similarity: 0.5380371051882138, Person Cosine Similarity: 0.3944956165633446
#
# Processing Job: NOT_ONET
# Nuclear Monitoring Technicians
# Cosine Similarity: 0.21381869314527563, Person Cosine Similarity: 0.2183757505024831
# Computer Numerically Controlled Tool Operators
# Cosine Similarity: 0.20581030932278996, Person Cosine Similarity: 0.2504280258377792
# Computer Numerically Controlled Tool Operators
# Cosine Similarity: 0.19881764546443556, Person Cosine Similarity: 0.2504280258377792
#
# Processing Job: A social media marketing specialist analyzes customer interactions on social media and optimizes content to improve engagement.
# Search Marketing Strategists
# Cosine Similarity: 0.5523034642418914, Person Cosine Similarity: 0.46095884879704396
# Search Marketing Strategists
# Cosine Similarity: 0.5397598669841392, Person Cosine Similarity: 0.46095884879704396
# Search Marketing Strategists
# Cosine Similarity: 0.5142599746845424, Person Cosine Similarity: 0.4609577384690546
# ***********************

# %%
sample_df.loc[index, ["Job1_ONET", "Job2_ONET", "Job3_ONET"]] = job_results

# %%
onet_df.head()
# Out:
#   organization_name                                            example  \
# 0           Advoria  A lawyer uses Advoria to set up an automated b...
# 1           Advoria  A lawyer uses Advoria to set up an automated b...
# 2           Advoria  A lawyer uses Advoria to set up an automated b...
# 3           Advoria  A law firm uses Advoria to collect necessary c...
# 4           Advoria  A law firm uses Advoria to collect necessary c...
#
#                                                  job  \
# 0     Legal Secretary schedules client appointments.
# 1     Legal Secretary schedules client appointments.
# 2     Legal Secretary schedules client appointments.
# 3  Legal Secretary collects and organizes client ...
# 4  Legal Secretary collects and organizes client ...
#
#                                           onet_title  \
# 0    Legal Secretaries and Administrative Assistants
# 1  Medical Secretaries and Administrative Assistants
# 2    Legal Secretaries and Administrative Assistants
# 3    Legal Secretaries and Administrative Assistants
# 4    Legal Secretaries and Administrative Assistants
#
#                                            onet_task   example_job_title  \
# 0                    Schedule and make appointments.  Legal Secretary \n
# 1  Schedule and confirm patient diagnostic appoin...  Legal Secretary \n
# 2  Attend legal meetings, such as client intervie...  Legal Secretary \n
# 3  Assist attorneys in collecting information suc...  Legal Secretary \n
# 4  Organize and maintain law libraries, documents...  Legal Secretary \n
#
#    task_similarity  job_title_similarity
# 0         0.728097              0.529373
# 1         0.591421              0.440896
# 2         0.587042              0.529373
# 3         0.663853              0.546011
# 4         0.613759              0.546078

# %%
job_embedding.shape
# Out:
# (3072, 1)
