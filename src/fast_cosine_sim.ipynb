# %%
import pandas as pd
import numpy as np
from dotenv import load_dotenv
import os
from os import getenv
from openai import OpenAI
import pathlib
import textwrap
import google.generativeai as genai
import time
import requests
import ast
import json
from sklearn.metrics.pairwise import cosine_similarity
import re

load_dotenv("../../.env",override=True)
GOOGLE_API_KEY = getenv("GEMINI_API_KEY")
OPENAI_API_KEY = getenv("OPENAI_API_KEY")

sample_df = pd.read_csv('../output/df_with_examples_embeddings.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[40], line 21
#      18 GOOGLE_API_KEY = getenv("GEMINI_API_KEY")
#      19 OPENAI_API_KEY = getenv("OPENAI_API_KEY")
# ---> 21 sample_df = pd.read_csv('../output/df_with_examples_embeddings.csv')
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:617, in _read(filepath_or_buffer, kwds)
#     614     return parser
#     616 with parser:
# --> 617     return parser.read(nrows)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1748, in TextFileReader.read(self, nrows)
#    1741 nrows = validate_integer("nrows", nrows)
#    1742 try:
#    1743     # error: "ParserBase" has no attribute "read"
#    1744     (
#    1745         index,
#    1746         columns,
#    1747         col_dict,
# -> 1748     ) = self._engine.read(  # type: ignore[attr-defined]
#    1749         nrows
#    1750     )
#    1751 except Exception:
#    1752     self.close()
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:843, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:904, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:879, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:890, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2058, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %%
genai.configure(api_key=GOOGLE_API_KEY)
class gemini():
    def __init__(self):
        self.model = genai.GenerativeModel('gemini-1.5-flash')
    def request(self,prompt):
        url = 'https://generativelanguage.googleapis.com/v1beta/models/gemini-1.5-flash-latest:generateContent'
        headers = {
            'Content-Type': 'application/json',
        }
        data = {
            "contents": [
                {
                    "parts": [
                        {
                            "text": prompt
                        }
                    ]
                }
            ]
        }
        params = {
            'key': GOOGLE_API_KEY
        }
        
        response = requests.post(url, headers=headers, json=data, params=params)
        return json.loads(response.text)

    def ask(self,prompt):
        #response = self.model.generate_content(prompt)
        response = self.request(prompt)
        if response["candidates"][0]["finishReason"] == 'SAFETY': return "N/A"
        response = response["candidates"][0]["content"]["parts"][0]["text"]
        return response

x_gemini = gemini()
x_gemini.ask("hi")
# Out:
# 'Hi! How can I help you today? \n'

# %%
class chatGPT():
    def __init__(self):
        self.client = OpenAI(api_key=OPENAI_API_KEY)
        
    # def ask(self, q):
    #     stream = self.client.chat.completions.create(
    #         model="gpt-4",
    #         messages=[{"role": "user", "content": q}],
    #         stream=True,
    #         temperature=0
    #     )
    #     response = ""
    #     for chunk in stream:
    #         if chunk.choices[0].delta.content is not None:
    #             response += chunk.choices[0].delta.content

    #     self.response = response
    #     return response

    def get_embedding(self,text, model="text-embedding-3-large"):
       text = text.replace("\n", " ")
       return self.client.embeddings.create(input = [text], model=model).data[0].embedding

x_chat = chatGPT()

# %%
df_exp = pd.read_csv('../output/onet/gpt_exposure_embeddings.csv')
df_exp.Embeddings = df_exp.Embeddings.apply(lambda x: x.strip("[]").split(", "))
embeddings = []
for x in df_exp.Embeddings:
    embeddings.append([float(y) for y in x])


embeddings = np.array(embeddings)
embeddings = np.vstack(embeddings)
embeddings.shape

# %%
# df_exp["Embeddings_Object"] = embeddings
# embeddings = df_exp["Embeddings_Object"]
# df_exp.to_csv("../output/onet/gpt_exposure_parsable_embeddings.csv")
# df_exp = pd.read_csv("../output/onet/gpt_exposure_parsable_embeddings.csv")
# df_exp.head()

# %%
for i in range(3):
    sample_df[f"Job{i+1}_embedding"] = sample_df[f"Job{i+1}_embedding"].apply(lambda x: [float(y) for y in x.strip("[]").split(", ")])

# %%
prompt = """What is the first person in this sentence? Just return 1/2 words.
Example: 
************
Sentence:  A legal secretary would normally schedule appointments and send reminders.
Noun: legal secretary
************
Your turn:
Sentence: $sentence
Noun (1/2 words):
"""
def get_person(text):
    while True:
        try:
            result = x_gemini.ask(prompt.replace("$sentence",text)).replace(" \n","")
            return result
        except Exception as e:
            print(e)

            print(f"Error processing {str(i)}, {companies[i]}: {e}")

            time.sleep(20)

# %%
sample_df[["Job1_ONET", "Job2_ONET", "Job3_ONET"]].dtypes
# Out:
# Job1_ONET    object
# Job2_ONET    object
# Job3_ONET    object
# dtype: object

# %%
# results = []
for index, row in list(sample_df.iterrows())[700:]:
    print("***********************")
    print(f"Processing {index}")
    name = row["organization name"]
    print(name)
    print(row["generated_description"])
        
    job_results = []
    for i in range(3):  # 0, 1, 2 for Job1, Job2, Job3
        job = row[f'Job{i+1}']
        print(f"\nProcessing Job: {job}")
        example = row[f"Example{i+1}"]
        job_embedding = np.array(row[f'Job{i+1}_embedding']).reshape(1,-1)
        cosine_sim = cosine_similarity(job_embedding, embeddings, 'cosine')
        example_title = get_person(job)
        example_title_embedding = np.array([x_chat.get_embedding(example_title)])
        
        top3 = sorted(zip(cosine_sim[0], df_exp[['Title', 'Task']].values), reverse=True)[:3]
        local_results = []
        for cosine_sim_job, onet in top3:
            onet_title_embedding = np.array([x_chat.get_embedding(onet[0])])
            cosine_sim_title = cosine_similarity(job_embedding, onet_title_embedding, 'cosine')[0][0]
            print(f"{onet[0]}\nCosine Similarity: {cosine_sim_job}, Person Cosine Similarity: {cosine_sim_title}")
            results.append([name,example,job,onet[0],onet[1],example_title, cosine_sim_job,cosine_sim_title])
            local_results.append([onet[0],onet[1],example_title, cosine_sim_job,cosine_sim_title])
        job_results.append(json.dumps(local_results))
    sample_df.loc[index, ["Job1_ONET", "Job2_ONET", "Job3_ONET"]] = job_results

    if index % 5 == 0:
        print("**Saving Results**\n\n")
        onet_df = pd.DataFrame(results, columns=["organization_name","example","job","onet_title","onet_task","example_job_title","task_similarity", "job_title_similarity"])
        onet_df.to_csv("../output/onet_df.csv", index=False)
    if index % 30 == 0:
        sample_df.to_csv('../output/df_with_onet.csv', index=False)
        
    print("***********************\n\n")
# Out:
# ***********************
# Processing 0
# Advoria
# Advoria is a German-made, GDPR-compliant online appointment booking system specifically designed for law firms. It allows clients to schedule appointments 24/7, reducing the workload of secretaries and streamlining the client intake process.
#
#
# Processing Job: Legal Secretary schedules client appointments.
# Legal Secretaries and Administrative Assistants
# Cosine Similarity: 0.7280972380294118, Person Cosine Similarity: 0.5293727830875479
# Medical Secretaries and Administrative Assistants
# Cosine Similarity: 0.5914207395661782, Person Cosine Similarity: 0.4407247755069331
# Legal Secretaries and Administrative Assistants
# Cosine Similarity: 0.5870415399346863, Person Cosine Similarity: 0.5293532958601553
#
# Processing Job: Legal Secretary collects and organizes client information.
# Legal Secretaries and Administrative Assistants
# Cosine Similarity: 0.6638532554254232, Person Cosine Similarity: 0.5460107003511973
# Legal Secretaries and Administrative Assistants
# Cosine Similarity: 0.6137585432737288, Person Cosine Similarity: 0.5461422343712423
# Legal Secretaries and Administrative Assistants
# Cosine Similarity: 0.6097090964225534, Person Cosine Similarity: 0.5460107003511973
#
# Processing Job: Paralegal manages own calendar and appointment scheduling.
# Legal Secretaries and Administrative Assistants
# Cosine Similarity: 0.6190156713644905, Person Cosine Similarity: 0.4191903060132698
# Judicial Law Clerks
# Cosine Similarity: 0.5180981963389337, Person Cosine Similarity: 0.298238951776175
# Word Processors and Typists
# Cosine Similarity: 0.5136100420926767, Person Cosine Similarity: 0.23979046748862098
# **Saving Results**
#
#
# ***********************
#
#
# ***********************
# Processing 1
# Petville Global
# Petville Global is a business-to-business (B2B) software solution that combines a Customer Relationship Management (CRM) platform with veterinary technology to help pet businesses and vet clinics streamline their operations, increase efficiency, and expand their reach. Petville Global leverages AI and data analytics to provide insights, marketing tools, and cost savings, empowering pet industry professionals to provide better care and grow their businesses.
#
#
# Processing Job: A veterinary receptionist manually sends out reminder emails.
# Veterinary Assistants and Laboratory Animal Caretakers
# Cosine Similarity: 0.496319007851097, Person Cosine Similarity: 0.34277140855056526
# Animal Caretakers
# Cosine Similarity: 0.4839485700052757, Person Cosine Similarity: 0.3109760470390336
# Veterinary Technologists and Technicians
# Cosine Similarity: 0.48014844755652386, Person Cosine Similarity: 0.3505443522015736
#
# Processing Job: A pet grooming business manager uses data to track customer preferences and marketing trends.
# Spa Managers
# Cosine Similarity: 0.5371900571965766, Person Cosine Similarity: 0.42421772180799344
# Veterinarians
# Cosine Similarity: 0.4703235857407305, Person Cosine Similarity: 0.3082485289435922
# Sales Managers
# Cosine Similarity: 0.4666874634399483, Person Cosine Similarity: 0.322557486854346
#
# Processing Job: A veterinary receptionist schedules appointments manually.
# Veterinary Technologists and Technicians
# Cosine Similarity: 0.6276673447257752, Person Cosine Similarity: 0.38477649484607407
# Animal Caretakers
# Cosine Similarity: 0.6032313703475024, Person Cosine Similarity: 0.3303403546789276
# Veterinary Assistants and Laboratory Animal Caretakers
# Cosine Similarity: 0.6019611564277992, Person Cosine Similarity: 0.3808217084703192
# ***********************
#
#
# ***********************
# Processing 2
# InputAI
# InputAI is an online platform that provides over 1000 AI templates powered by OpenAI GPT and ChatGPT, enabling users to automate tasks and generate content for various applications. These templates can be used for tasks like writing, summarizing, translating, and generating code, offering a powerful tool for productivity and creativity.
#
#
# Processing Job: A social media marketer creates social media posts about product launches.
# Search Marketing Strategists
# Cosine Similarity: 0.5125099720785206, Person Cosine Similarity: 0.418411033269772
# Search Marketing Strategists
# Cosine Similarity: 0.5048115718676744, Person Cosine Similarity: 0.418411033269772
# Public Relations Specialists
# Cosine Similarity: 0.49384187214295117, Person Cosine Similarity: 0.30050407757642794
#
# Processing Job: A student reads and summarizes research papers.
# Data Scientists
# Cosine Similarity: 0.4859349574278462, Person Cosine Similarity: 0.2268892546475173
# Digital Forensics Analysts
# Cosine Similarity: 0.40202404255408664, Person Cosine Similarity: 0.16873178841562544
# Industrial-Organizational Psychologists
# Cosine Similarity: 0.36277627776141363, Person Cosine Similarity: 0.150501649029061
#
# Processing Job: NOT_ONET
# Nuclear Monitoring Technicians
# Cosine Similarity: 0.21381090236370953, Person Cosine Similarity: 0.21838572045412008
# Computer Numerically Controlled Tool Operators
# Cosine Similarity: 0.205814640157761, Person Cosine Similarity: 0.25038482469826595
# Computer Numerically Controlled Tool Operators
# Cosine Similarity: 0.19883632832387022, Person Cosine Similarity: 0.2503833304141965
# ***********************
#
#
# ***********************
# Processing 3
# Thunder
# Thunder offers decentralized, peer-to-peer GPU cloud computing, making powerful graphics processing accessible to everyone by connecting individuals with spare GPU resources and those in need. This addresses the ongoing GPU shortage and empowers users with affordable access to high-performance computing.
#
#
# Processing Job: NOT_ONET A developer spends hours training a complex machine learning model on a single GPU.
# Bioinformatics Technicians
# Cosine Similarity: 0.3322605703608031, Person Cosine Similarity: 0.1956585243765253
# Data Scientists
# Cosine Similarity: 0.33140380886057913, Person Cosine Similarity: 0.33458317364008855
# Data Scientists
# Cosine Similarity: 0.33124642450219327, Person Cosine Similarity: 0.33458317364008855
#
# Processing Job: NOT_ONET A research team struggles to find enough computational resources to run large-scale simulations for climate modeling.
# Atmospheric and Space Scientists
# Cosine Similarity: 0.43368453974350685, Person Cosine Similarity: 0.3160664973937082
# Physicists
# Cosine Similarity: 0.41057661705013626, Person Cosine Similarity: 0.27394698316277144
# Atmospheric and Space Scientists
# Cosine Similarity: 0.3861356803175529, Person Cosine Similarity: 0.3160664973937082
#
# Processing Job: NOT_ONET A small business owner cannot afford expensive hardware to render high-quality 3D animations for their marketing campaign.
# Craft Artists
# Cosine Similarity: 0.3326043015945882, Person Cosine Similarity: 0.26435134376498537
# Special Effects Artists and Animators
# Cosine Similarity: 0.3277745607137128, Person Cosine Similarity: 0.2911594214271113
# Special Effects Artists and Animators
# Cosine Similarity: 0.32210795893618427, Person Cosine Similarity: 0.2911594214271113
# ***********************
#
#
# ***********************
# Processing 4
# Tail and Skew
# Tail and Skew provides a platform where users can create AI-powered agents to automate various tasks. These agents are designed to learn and adapt over time, becoming increasingly efficient and personalized to individual needs.
#
#
# Processing Job: Customer service representative handles routine customer inquiries.
# Customer Service Representatives
# Cosine Similarity: 0.6273063687505553, Person Cosine Similarity: 0.6833687668653252
# Customer Service Representatives
# Cosine Similarity: 0.5956982182499313, Person Cosine Similarity: 0.6833687668653252
# Customer Service Representatives
# Cosine Similarity: 0.5838792571637005, Person Cosine Similarity: 0.6833687668653252
#
# Processing Job: NOT_ONET
# Nuclear Monitoring Technicians
# Cosine Similarity: 0.21381090236370953, Person Cosine Similarity: 0.21838572045412008
# Computer Numerically Controlled Tool Operators
# Cosine Similarity: 0.205814640157761, Person Cosine Similarity: 0.24991052142098957
# Computer Numerically Controlled Tool Operators
# Cosine Similarity: 0.19883632832387022, Person Cosine Similarity: 0.2498136394881859
#
# Processing Job: A software developer manually tests code for bugs and provides feedback.
# Software Quality Assurance Analysts and Testers
# Cosine Similarity: 0.6142472272475832, Person Cosine Similarity: 0.4319881531288814
# Software Quality Assurance Analysts and Testers
# Cosine Similarity: 0.5585021903047265, Person Cosine Similarity: 0.4319881531288814
# Bioinformatics Technicians
# Cosine Similarity: 0.5510525791591265, Person Cosine Similarity: 0.23379672399595763
# ***********************
#
#
# ***********************
# Processing 5
# AI Insider Tips
# AI Insider Tips is a comprehensive resource for navigating the rapidly evolving world of artificial intelligence. Through in-depth reviews, insightful tips, and informative tutorials, they empower users to make informed decisions about the latest AI tools and software.
#
#
# Processing Job: NOT_ONET A business owner research and selects the best AI chatbot for their customer service needs.
# Online Merchants
# Cosine Similarity: 0.3664762843240036, Person Cosine Similarity: 0.2944144586573769
# Online Merchants
# Cosine Similarity: 0.3619937268631619, Person Cosine Similarity: 0.29440448511257755
# Online Merchants
# Cosine Similarity: 0.33236514242731185, Person Cosine Similarity: 0.29445214465170555
#
# Processing Job: NOT_ONET A marketer learns how to use AI for personalized email marketing campaigns.
# Telemarketers
# Cosine Similarity: 0.39261741806216194, Person Cosine Similarity: 0.2584563217272662
# Search Marketing Strategists
# Cosine Similarity: 0.37903158232954104, Person Cosine Similarity: 0.39039693980775325
# Search Marketing Strategists
# Cosine Similarity: 0.36894220545352063, Person Cosine Similarity: 0.3903394266645851
#
# Processing Job: NOT_ONET A student finds the best online AI courses to learn about deep learning and computer vision.
# Psychology Teachers, Postsecondary
# Cosine Similarity: 0.3001325535761692, Person Cosine Similarity: 0.19563622988159582
# Computer Science Teachers, Postsecondary
# Cosine Similarity: 0.2855620470848379, Person Cosine Similarity: 0.24038145821066143
# History Teachers, Postsecondary
# Cosine Similarity: 0.27807362649487055, Person Cosine Similarity: 0.16621114686489302
# **Saving Results**
#
#
# ***********************
#
#
# ***********************
# Processing 6
# AI Budge
# Description: AI Budge is an AI-focused blog that provides a comprehensive hub for AI enthusiasts and professionals, delivering up-to-date news, expert insights, and actionable solutions for navigating the evolving landscape of artificial intelligence.
#
#
# Processing Job: NOT_ONET
# Nuclear Monitoring Technicians
# Cosine Similarity: 0.21381090236370953, Person Cosine Similarity: 0.21838572045412008
# Computer Numerically Controlled Tool Operators
# Cosine Similarity: 0.205814640157761, Person Cosine Similarity: 0.2503833304141965
# Computer Numerically Controlled Tool Operators
# Cosine Similarity: 0.19883632832387022, Person Cosine Similarity: 0.2503833304141965
#
# Processing Job: A software developer reads AI research papers and articles to keep up to date with the latest developments.
# Data Scientists
# Cosine Similarity: 0.5535206930765675, Person Cosine Similarity: 0.3024466199303521
# Training and Development Specialists
# Cosine Similarity: 0.5068612007132982, Person Cosine Similarity: 0.23873095105982367
# Bioengineers and Biomedical Engineers
# Cosine Similarity: 0.5033407367625401, Person Cosine Similarity: 0.1853339905234973
#
# Processing Job: A data scientist reads AI research papers and articles to keep up to date with the latest developments.
# Data Scientists
# Cosine Similarity: 0.6776780822646343, Person Cosine Similarity: 0.4544112090024558
# Health Informatics Specialists
# Cosine Similarity: 0.5088675635508078, Person Cosine Similarity: 0.23098565295192525
# Food Scientists and Technologists
# Cosine Similarity: 0.49633381212931504, Person Cosine Similarity: 0.24480749796492407
# ***********************
#
#
# ***********************
# Processing 7
# Semantic
# Semantic's generativemedia.ai platform utilizes advanced AI to create unique and high-quality media content, such as images and videos, tailored to specific needs and preferences. This platform empowers users to effortlessly generate engaging content for various purposes, from marketing campaigns to personal projects.
#
#
# Processing Job: A graphic designer creates social media images featuring new product launches.
# Graphic Designers
# Cosine Similarity: 0.5680238812913725, Person Cosine Similarity: 0.5778326255594928
# Graphic Designers
# Cosine Similarity: 0.5666448312153305, Person Cosine Similarity: 0.5778213467881389
# Graphic Designers
# Cosine Similarity: 0.531198694012304, Person Cosine Similarity: 0.5778326255594928
#
# Processing Job: A video editor creates explainer videos.
# Film and Video Editors
# Cosine Similarity: 0.5101602516112886, Person Cosine Similarity: 0.4887987344749302
# Film and Video Editors
# Cosine Similarity: 0.5032059256226891, Person Cosine Similarity: 0.488844042480967
# Film and Video Editors
# Cosine Similarity: 0.4973382487556024, Person Cosine Similarity: 0.48871130380586647
#
# Processing Job: NOT_ONET A person generates visuals for a product.
# Craft Artists
# Cosine Similarity: 0.4805728093144154, Person Cosine Similarity: 0.3711634263809712
# Broadcast Technicians
# Cosine Similarity: 0.4709645605098926, Person Cosine Similarity: 0.23655859687302305
# Graphic Designers
# Cosine Similarity: 0.4672058076756092, Person Cosine Similarity: 0.4678363512789315
# ***********************
#
#
# ***********************
# Processing 8
# Pariah AI
# Pariah AI is a Kubernetes debugging and remediation platform that leverages AI to automate the identification and resolution of issues within your clusters, significantly reducing debug time and increasing developer productivity. The platform's intuitive interface and 24/7 AI auto-piloting capabilities ensure smooth cluster operations and minimize downtime.
#
#
# Processing Job: A Kubernetes engineer debugs and resolves performance issues in a Kubernetes cluster.
# Robotics Engineers
# Cosine Similarity: 0.449782595887527, Person Cosine Similarity: 0.2853050650038191
# Information Security Engineers
# Cosine Similarity: 0.42928658213792603, Person Cosine Similarity: 0.26492763033953487
# Aerospace Engineers
# Cosine Similarity: 0.4254627113928794, Person Cosine Similarity: 0.2503897048308458
#
# Processing Job: A DevOps engineer monitors and maintains the stability of a Kubernetes cluster to ensure no downtime.
# Computer Systems Engineers/Architects
# Cosine Similarity: 0.43759289894049147, Person Cosine Similarity: 0.26123383659289423
# Software Developers
# Cosine Similarity: 0.37935034090698216, Person Cosine Similarity: 0.23968327674491519
# Stationary Engineers and Boiler Operators
# Cosine Similarity: 0.36892208258381887, Person Cosine Similarity: 0.27334778170128726
#
# Processing Job: A DevOps engineer performs error handling and remidiation for Kubernetes config errors during application deployments.
# Blockchain Engineers
# Cosine Similarity: 0.40821565632761236, Person Cosine Similarity: 0.24883646637929835
# Web Administrators
# Cosine Similarity: 0.40273830543826494, Person Cosine Similarity: 0.22437367208011363
# Computer Systems Engineers/Architects
# Cosine Similarity: 0.38944625181477255, Person Cosine Similarity: 0.2741418650352525
# ***********************
#
#
# ***********************
# Processing 9
# Doppler
# Doppler.bot empowers you to create a personalized AI chatbot that replicates your voice and personality, allowing you to engage with your fans, offer exclusive content, and earn income through one-on-one interactions with your AI clone.  This platform allows you to build a deeper connection with your audience and monetize your expertise by offering premium access to your AI Doppelgänger.
#
#
# Processing Job: NOT_ONET - A gaming influencer interacts with their audience to answer questions and offer exclusive content.
# Video Game Designers
# Cosine Similarity: 0.3246669988934172, Person Cosine Similarity: 0.24171905161593737
# Gambling Dealers
# Cosine Similarity: 0.320343974366433, Person Cosine Similarity: 0.20010317943333886
# Online Merchants
# Cosine Similarity: 0.31800207472226383, Person Cosine Similarity: 0.21339188316745183
#
# Processing Job: NOT_ONET - A fitness coach interacts with their audience by creating personalized workout plans and motivational messages.
# Fitness and Wellness Coordinators
# Cosine Similarity: 0.4651523650195827, Person Cosine Similarity: 0.44686569782884356
# Exercise Trainers and Group Fitness Instructors
# Cosine Similarity: 0.46052659289617504, Person Cosine Similarity: 0.42546517578984
# Fitness and Wellness Coordinators
# Cosine Similarity: 0.4556448127048415, Person Cosine Similarity: 0.44686569782884356
#
# Processing Job: NOT_ONET - A musician interacts with their audience by answering questions about their music.
# Musicians and Singers
# Cosine Similarity: 0.4285069373600062, Person Cosine Similarity: 0.3793480212033551
# Musicians and Singers
# Cosine Similarity: 0.3906407307444971, Person Cosine Similarity: 0.3793480212033551
# Astronomers
# Cosine Similarity: 0.38634148220794606, Person Cosine Similarity: 0.12305111038968018
# ***********************
#
#
# ***********************
# Processing 10
# healf.mx
# healf.mx is a digital platform that simplifies healthcare insurance by offering transparent insights into policy details, empowering individuals to make informed decisions. This platform also streamlines communication and automates processes for brokers, doctors, and insurers, promoting trust and efficiency within the healthcare ecosystem.
#
#
# Processing Job: NOT_ONET - A person compares different health insurance plans and purchases one.
# Insurance Sales Agents
# Cosine Similarity: 0.4045384650301487, Person Cosine Similarity: 0.34650409586127723
# Insurance Sales Agents
# Cosine Similarity: 0.35500791521506836, Person Cosine Similarity: 0.34650409586127723
# Insurance Sales Agents
# Cosine Similarity: 0.3477918115806218, Person Cosine Similarity: 0.34641309327487685
#
# Processing Job: A broker manually sends policy updates and notifications to clients.
# Insurance Sales Agents
# Cosine Similarity: 0.4737275683618134, Person Cosine Similarity: 0.3381673338705544
# Insurance Sales Agents
# Cosine Similarity: 0.4543713197286098, Person Cosine Similarity: 0.3381673338705544
# Personal Financial Advisors
# Cosine Similarity: 0.4441610146919826, Person Cosine Similarity: 0.2271896295266805
#
# Processing Job: A doctor manually submits claims and waits for approval.
# Insurance Claims and Policy Processing Clerks
# Cosine Similarity: 0.43827260481477537, Person Cosine Similarity: 0.40486575439932737
# Medical Secretaries and Administrative Assistants
# Cosine Similarity: 0.4328693381099008, Person Cosine Similarity: 0.2594461686783005
# Insurance Claims and Policy Processing Clerks
# Cosine Similarity: 0.4278655798561127, Person Cosine Similarity: 0.40486575439932737
# **Saving Results**
#
#
# ***********************
#
#
# ***********************
# Processing 11
# Latimer.AI
# Latimer.AI is an AI language model specifically trained on diverse histories and inclusive voices of Black and Brown people, aiming to combat the bias and erasure prevalent in traditional AI systems. It provides a more accurate and representative platform for Black and Brown communities.
#
#
# Processing Job: NOT_ONET A history student researches the impact of the Black Power Movement.
# Historians
# Cosine Similarity: 0.31789512999987235, Person Cosine Similarity: 0.349107694266925
# Historians
# Cosine Similarity: 0.3164293166638782, Person Cosine Similarity: 0.3490968371722295
# Historians
# Cosine Similarity: 0.31310016434437377, Person Cosine Similarity: 0.349107694266925
#
# Processing Job: A writer creates dialogue and narratives for their novel.
# Poets, Lyricists and Creative Writers
# Cosine Similarity: 0.5107689124674389, Person Cosine Similarity: 0.37528721200737525
# Video Game Designers
# Cosine Similarity: 0.48798381841970884, Person Cosine Similarity: 0.2548234929585804
# Writers and Authors
# Cosine Similarity: 0.4666326591194423, Person Cosine Similarity: 0.47291283769328013
#
# Processing Job: A journalist analyzes complex data for an article on systemic racism.
# News Analysts, Reporters, and Journalists
# Cosine Similarity: 0.4035814690566021, Person Cosine Similarity: 0.3992696504198516
# News Analysts, Reporters, and Journalists
# Cosine Similarity: 0.4007069144912858, Person Cosine Similarity: 0.3992696504198516
# Statisticians
# Cosine Similarity: 0.38826898077898997, Person Cosine Similarity: 0.304301650713172
# ***********************
#
#
# ***********************
# Processing 12
# Dune Security
# Dune Security utilizes AI to analyze user behavior and tailor cybersecurity measures for individual employees, effectively mitigating the risk of internal breaches. This innovative approach shifts from traditional security awareness training to proactive risk management, enabling organizations to quantify and address employee-specific vulnerabilities.
#
#
# Processing Job: NOT_ONET - A software developer would not be a role assigned to monitor their own cybersecurity, but rather they may get notifications and alerts to increase their security awareness and mitigate risk.
# Web Developers
# Cosine Similarity: 0.5235265431900862, Person Cosine Similarity: 0.3053094242465386
# Web Administrators
# Cosine Similarity: 0.48171162463534495, Person Cosine Similarity: 0.3198383255770505
# Information Security Engineers
# Cosine Similarity: 0.4577151291544921, Person Cosine Similarity: 0.42933156443147236
#
# Processing Job: NOT_ONET - While an IT team would manage the tool, it would not automate any of their responsibilities, rather it would give them greater insight into risk and threat.
# Information Technology Project Managers
# Cosine Similarity: 0.4382427784701187, Person Cosine Similarity: 0.39265152626109745
# Penetration Testers
# Cosine Similarity: 0.40515000418255304, Person Cosine Similarity: 0.28936944355398053
# Penetration Testers
# Cosine Similarity: 0.40474364974815324, Person Cosine Similarity: 0.28936944355398053
#
# Processing Job: NOT_ONET - A finance department employee would not perform their own security risk analysis, but rather may receive an alert to increase their security awareness and mitigate risk.
# Security Management Specialists
# Cosine Similarity: 0.4737617033635231, Person Cosine Similarity: 0.41452181813260225
# Financial Risk Specialists
# Cosine Similarity: 0.44982497900218366, Person Cosine Similarity: 0.40035460389851474
# Security Managers
# Cosine Similarity: 0.44865122163638654, Person Cosine Similarity: 0.3810375470496646
# ***********************
#
#
# ***********************
# Processing 13
# RAIBS
# RAIBS specializes in developing innovative mobile applications that seamlessly integrate artificial intelligence, enhancing businesses' online presence and user engagement.  Their team of experts focuses on creating immersive and dynamic app interfaces that not only attract customers but also drive business growth.
#
#
# Processing Job: A travel agent researches and suggests nearby attractions and restaurants based on user preferences.
# Travel Agents
# Cosine Similarity: 0.5239835541451052, Person Cosine Similarity: 0.5285752889081285
# Travel Agents
# Cosine Similarity: 0.5202108936275892, Person Cosine Similarity: 0.5285752889081285
# Travel Agents
# Cosine Similarity: 0.5191566578210187, Person Cosine Similarity: 0.5285752889081285
#
# Processing Job: A financial analyst analyzes market trends and investment strategies to provide personalized portfolio recommendations to clients.
# Personal Financial Advisors
# Cosine Similarity: 0.6375810820481015, Person Cosine Similarity: 0.49851635629751245
# Financial and Investment Analysts
# Cosine Similarity: 0.633770613966417, Person Cosine Similarity: 0.6174480953744383
# Personal Financial Advisors
# Cosine Similarity: 0.6298579121059644, Person Cosine Similarity: 0.49852134078936305
#
# Processing Job: A market research analyst tracks user behavior, analyzes customer data, and predicts customer needs, allowing them to optimize marketing campaigns and enhance customer engagement.
# Market Research Analysts and Marketing Specialists
# Cosine Similarity: 0.6943568046720905, Person Cosine Similarity: 0.5633319600852504
# Market Research Analysts and Marketing Specialists
# Cosine Similarity: 0.6658428740130566, Person Cosine Similarity: 0.5633319600852504
# Market Research Analysts and Marketing Specialists
# Cosine Similarity: 0.6066458126981351, Person Cosine Similarity: 0.5633789895433006
# ***********************
#
#
# ***********************
# Processing 14
# Wave Predict
# Wave Predict is an AI-powered trading assistant that analyzes market data and provides real-time insights and predictions, helping users make more informed trading decisions. Its intuitive interface and customizable features make it accessible for both novice and experienced traders.
#
#
# Processing Job: A day trader researches market data and makes trades based on market data.
# Financial Managers
# Cosine Similarity: 0.42967145562554554, Person Cosine Similarity: 0.20878185964536222
# Securities, Commodities, and Financial Services Sales Agents
# Cosine Similarity: 0.42615546415486794, Person Cosine Similarity: 0.23909008984148739
# Securities, Commodities, and Financial Services Sales Agents
# Cosine Similarity: 0.42265608085449774, Person Cosine Similarity: 0.2392762698426734
#
# Processing Job: A long-term investor conducts market research and analyzes potential risk and reward of investment strategies.
# Investment Fund Managers
# Cosine Similarity: 0.5216984178806539, Person Cosine Similarity: 0.3692959836421694
# Financial Managers
# Cosine Similarity: 0.47335058864684076, Person Cosine Similarity: 0.2710685642612142
# Financial Risk Specialists
# Cosine Similarity: 0.4651890856298539, Person Cosine Similarity: 0.3246983317349068
#
# Processing Job: NOT_ONET A hedge fund manager monitors portfolio performance and identifies areas of risk.
# Investment Fund Managers
# Cosine Similarity: 0.6227659838462747, Person Cosine Similarity: 0.503755831011277
# Investment Fund Managers
# Cosine Similarity: 0.5302915548609513, Person Cosine Similarity: 0.5037876131515235
# Investment Fund Managers
# Cosine Similarity: 0.5239037300750025, Person Cosine Similarity: 0.5037929130673829
# ***********************
#
#
# ***********************
# Processing 15
# Apptify
# Apptify.ai empowers businesses to effortlessly manage and automate their customer interactions through WhatsApp, streamlining communication and enhancing customer engagement.  This AI-powered solution provides a robust platform for marketing, sales, and support, boosting business growth and customer satisfaction.
#
#
# Processing Job: A sales representative sends follow up messages to potential customers.
# Telemarketers
# Cosine Similarity: 0.6353704314904586, Person Cosine Similarity: 0.36193637697433056
# Real Estate Sales Agents
# Cosine Similarity: 0.49973458565387924, Person Cosine Similarity: 0.31041476339664786
# Sales Representatives of Services, Except Advertising, Insurance, Financial Services, and Travel
# Cosine Similarity: 0.4882016444770074, Person Cosine Similarity: 0.35643462477802057
#
# Processing Job: Customer service representative answers inquiries.
# Sales Representatives of Services, Except Advertising, Insurance, Financial Services, and Travel
# Cosine Similarity: 0.6598520754141539, Person Cosine Similarity: 0.41714323276681664
# Customer Service Representatives
# Cosine Similarity: 0.6341075765857489, Person Cosine Similarity: 0.7227532413899601
# Customer Service Representatives
# Cosine Similarity: 0.6309674284195775, Person Cosine Similarity: 0.7227532413899601
#
# Processing Job: NOT_ONET A marketer sends out targeted promotions for a business.
# Online Merchants
# Cosine Similarity: 0.44299561458130327, Person Cosine Similarity: 0.35353396260366826
# Online Merchants
# Cosine Similarity: 0.44283190157127256, Person Cosine Similarity: 0.35353396260366826
# Demonstrators and Product Promoters
# Cosine Similarity: 0.4405063629345115, Person Cosine Similarity: 0.3565080256562121
# **Saving Results**
#
#
# ***********************
#
#
# ***********************
# Processing 16
# Snipzo
# Snipzo is an AI-powered content creation platform offering free tools to generate articles, images, and voiceovers. It empowers users to create engaging content with the help of cutting-edge AI technology.
#
#
# Processing Job: A copywriter for a marketing agency creates product descriptions.
# Writers and Authors
# Cosine Similarity: 0.5753522008945295, Person Cosine Similarity: 0.32728358815767583
# Writers and Authors
# Cosine Similarity: 0.5631487743132313, Person Cosine Similarity: 0.32734229085044886
# Online Merchants
# Cosine Similarity: 0.5464213164166698, Person Cosine Similarity: 0.22519802265083533
#
# Processing Job: NOT_ONET - A social media content creator creates posts with images.
# Public Relations Specialists
# Cosine Similarity: 0.39541202484935983, Person Cosine Similarity: 0.1996472806935949
# Search Marketing Strategists
# Cosine Similarity: 0.3902656100957964, Person Cosine Similarity: 0.26468768727266234
# Photographers
# Cosine Similarity: 0.36195693269627943, Person Cosine Similarity: 0.3089414831681547
#
# Processing Job: A writer creates a script for a podcast.
# Camera Operators, Television, Video, and Film
# Cosine Similarity: 0.4977138493518256, Person Cosine Similarity: 0.19000984986051822
# Producers and Directors
# Cosine Similarity: 0.4797138081823691, Person Cosine Similarity: 0.32516462124525486
# Writers and Authors
# Cosine Similarity: 0.4790741704781979, Person Cosine Similarity: 0.37442539907912525
# ***********************
#
#
# ***********************
# Processing 17
# Singularico
# Singularico is an AI-powered security tool that analyzes your codebase for vulnerabilities and misconfigurations, offering actionable insights and remediation guidance. It seamlessly integrates into your development workflow, continuously learning and adapting to stay ahead of emerging threats.
#
#
# Processing Job: A software developer has to find and fix vulnerabilities in their code.
# Penetration Testers
# Cosine Similarity: 0.5281498330046009, Person Cosine Similarity: 0.44278515189838236
# Penetration Testers
# Cosine Similarity: 0.521695406945327, Person Cosine Similarity: 0.44278515189838236
# Blockchain Engineers
# Cosine Similarity: 0.5035247714710471, Person Cosine Similarity: 0.22920429040524704
#
# Processing Job: A security engineer has to identify and remediate misconfigurations within their organization's cloud infrastructure.
# Information Security Engineers
# Cosine Similarity: 0.5420550971397027, Person Cosine Similarity: 0.4975772523810434
# Information Security Engineers
# Cosine Similarity: 0.5385428968773351, Person Cosine Similarity: 0.4975772523810434
# Information Security Engineers
# Cosine Similarity: 0.5074584451340316, Person Cosine Similarity: 0.4975772523810434
#
# Processing Job: A cybersecurity team uses Singularico to prioritize security tasks by identifying the most critical vulnerabilities in their systems.
# Information Security Engineers
# Cosine Similarity: 0.48991586574882867, Person Cosine Similarity: 0.4218027933913496
# Penetration Testers
# Cosine Similarity: 0.4753472548555228, Person Cosine Similarity: 0.3239732556298669
# Information Security Engineers
# Cosine Similarity: 0.4528454023471663, Person Cosine Similarity: 0.4218027933913496
# ***********************
#
#
# ***********************
# Processing 18
# Botvisor
# Botvisor is an AI-powered platform that streamlines short-term rental management by providing hosts with a customizable website and multilingual chatbot capable of handling common guest inquiries. This automated solution allows hosts to focus on providing exceptional guest experiences while reducing administrative burdens.
#
#
# Processing Job: A Airbnb host answers common guest questions about check-in/out times and local recommendations.
# Concierges
# Cosine Similarity: 0.4413242468611074, Person Cosine Similarity: 0.2670751253798563
# Concierges
# Cosine Similarity: 0.40553390576368264, Person Cosine Similarity: 0.2670970251649605
# Waiters and Waitresses
# Cosine Similarity: 0.38841059999295174, Person Cosine Similarity: 0.15152484623688606
#
# Processing Job: A vacation rental owner manages booking calendars and responds to inquiries.
# Spa Managers
# Cosine Similarity: 0.4721750397819103, Person Cosine Similarity: 0.32336023578012896
# Lodging Managers
# Cosine Similarity: 0.4458410130551352, Person Cosine Similarity: 0.39545318776573574
# Lodging Managers
# Cosine Similarity: 0.44373011004725704, Person Cosine Similarity: 0.39557785699116826
#
# Processing Job: NOT_ONET A homeowner with a short-term rental property creates a multilingual website and translates booking information and common inquiries.
# Lodging Managers
# Cosine Similarity: 0.3899370431210535, Person Cosine Similarity: 0.331040667130419
# Lodging Managers
# Cosine Similarity: 0.3583297542922407, Person Cosine Similarity: 0.331040667130419
# Concierges
# Cosine Similarity: 0.3418779850564594, Person Cosine Similarity: 0.2850418701218079
# ***********************
#
#
# ***********************
# Processing 19
# Intriq
# Intriq provides businesses with an AI-powered diagnostic tool that delivers strategic insights typically reserved for private equity firms. This affordable platform analyzes data to identify operational and financial inefficiencies, enabling companies to optimize their operations and make data-driven decisions for enhanced growth.
#
#
# Processing Job: A business owner identifies areas where they can improve efficiency.
# Budget Analysts
# Cosine Similarity: 0.504546229247624, Person Cosine Similarity: 0.22828927914444522
# Chief Executives
# Cosine Similarity: 0.48945867115426445, Person Cosine Similarity: 0.2608748047211719
# Logistics Engineers
# Cosine Similarity: 0.4546270005244706, Person Cosine Similarity: 0.23716268388088385
#
# Processing Job: A manufacturing manager performs operational optimization within the production process.
# Industrial Production Managers
# Cosine Similarity: 0.6688642259818701, Person Cosine Similarity: 0.5563233937040452
# Industrial Production Managers
# Cosine Similarity: 0.6261642643446031, Person Cosine Similarity: 0.5580677958740634
# General and Operations Managers
# Cosine Similarity: 0.6004296664636855, Person Cosine Similarity: 0.4545087743365068
#
# Processing Job: A retail manager performs a financial analysis of stores.
# Sales Managers
# Cosine Similarity: 0.5423170461638508, Person Cosine Similarity: 0.4035988280531712
# First-Line Supervisors of Retail Sales Workers
# Cosine Similarity: 0.5383628123450792, Person Cosine Similarity: 0.39520382901795065
# Transportation, Storage, and Distribution Managers
# Cosine Similarity: 0.5375380508106837, Person Cosine Similarity: 0.3337506408299852
# ***********************
#
#
# ***********************
# Processing 20
# StockCake
# StockCake is a free platform that provides a vast library of royalty-free, AI-generated images. It offers millions of high-quality visuals perfect for designers, marketers, and content creators, empowering them to elevate their projects with stunning imagery.
#
#
# Processing Job: A graphic designer searches for and downloads royalty free images.
# Graphic Designers
# Cosine Similarity: 0.5043459040930367, Person Cosine Similarity: 0.5103564585827057
# Graphic Designers
# Cosine Similarity: 0.48273842060040073, Person Cosine Similarity: 0.5103564585827057
# Graphic Designers
# Cosine Similarity: 0.47502593415467786, Person Cosine Similarity: 0.5103564585827057
#
# Processing Job: A social media manager searches for royalty-free images for social media posts.
# Graphic Designers
# Cosine Similarity: 0.407823157716174, Person Cosine Similarity: 0.32782388074377855
# Search Marketing Strategists
# Cosine Similarity: 0.4042711002479571, Person Cosine Similarity: 0.3129611107893925
# Public Relations Specialists
# Cosine Similarity: 0.4034471728697038, Person Cosine Similarity: 0.2432297732477831
#
# Processing Job: A content creator searches for royalty-free images to enhance the aesthetic appeal of a blog post.
# Online Merchants
# Cosine Similarity: 0.37821989101649744, Person Cosine Similarity: 0.18241116228213083
# Photographers
# Cosine Similarity: 0.36967657838127854, Person Cosine Similarity: 0.34043490969004
# Graphic Designers
# Cosine Similarity: 0.35889656336951414, Person Cosine Similarity: 0.34078005158260205
# **Saving Results**
#
#
# ***********************
#
#
# ***********************
# Processing 21
# ProperPlan
# ProperPlan is an online platform that utilizes artificial intelligence and expert knowledge to create personalized action plans for achieving specific goals. By combining AI-powered insights with human expertise, ProperPlan helps users turn their aspirations into actionable strategies.
#
#
# Processing Job: A student would normally create their own study plan and manage deadlines for themselves.
# Tutors
# Cosine Similarity: 0.3582104001489328, Person Cosine Similarity: 0.29343290910043673
# Tutors
# Cosine Similarity: 0.3442385427384993, Person Cosine Similarity: 0.29349093335374016
# Tutors
# Cosine Similarity: 0.3371297697532899, Person Cosine Similarity: 0.29349093335374016
#
# Processing Job: A freelancer would normally need to create their own project plan, set milestones, assign tasks, and track their own progress for clients.
# Information Technology Project Managers
# Cosine Similarity: 0.4081735724676469, Person Cosine Similarity: 0.2770707765273194
# Project Management Specialists
# Cosine Similarity: 0.3983471170971252, Person Cosine Similarity: 0.2932580091269876
# Art Directors
# Cosine Similarity: 0.3596975580685182, Person Cosine Similarity: 0.1604393882981691
#
# Processing Job: A new parent would normally create their own plan for their baby's feeding schedule, sleep routine, and developmental milestones and would track their own progress.
# Nannies
# Cosine Similarity: 0.4137436277418808, Person Cosine Similarity: 0.26154123965435105
# Nannies
# Cosine Similarity: 0.413005147917365, Person Cosine Similarity: 0.26147678789442497
# Nannies
# Cosine Similarity: 0.4086562916073556, Person Cosine Similarity: 0.26154123965435105
# ***********************
#
#
# ***********************
# Processing 22
# Archive Intel
# Archive Intel is an AI-powered archiving and surveillance software designed specifically for financial institutions. It automates the capture and analysis of critical communications like emails, social media posts, and website data, simplifying compliance efforts and reducing risk for RIAs and other financial firms.
#
#
# Processing Job: A compliance officer manually monitors all emails and social media posts from financial advisors to ensure they comply with regulations and industry standards.
# Compliance Managers
# Cosine Similarity: 0.7028240363268787, Person Cosine Similarity: 0.5527423299971258
# Compliance Officers
# Cosine Similarity: 0.6280959008992011, Person Cosine Similarity: 0.6183656789310037
# Compliance Officers
# Cosine Similarity: 0.5965436182284074, Person Cosine Similarity: 0.6189640205359949
#
# Processing Job: A risk manager manually analyzes website data and social media posts to identify potential reputational risks for their firm.
# Financial Risk Specialists
# Cosine Similarity: 0.5283460777853093, Person Cosine Similarity: 0.4188418410975536
# Financial Risk Specialists
# Cosine Similarity: 0.5076068529504949, Person Cosine Similarity: 0.4189235441714386
# Financial Managers
# Cosine Similarity: 0.4997581621738021, Person Cosine Similarity: 0.3068270848317926
#
# Processing Job: NOT_ONET A financial advisor manually captures and stores all client communications, simplifying their record-keeping process and ensuring they meet regulatory requirements.
# Securities, Commodities, and Financial Services Sales Agents
# Cosine Similarity: 0.4896922128433323, Person Cosine Similarity: 0.26439976351027317
# Credit Counselors
# Cosine Similarity: 0.47729192877732746, Person Cosine Similarity: 0.27778083146051347
# Personal Financial Advisors
# Cosine Similarity: 0.4662753225175401, Person Cosine Similarity: 0.38783545398393093
# ***********************
#
#
# ***********************
# Processing 23
# Nirah
# Nirah is a comprehensive suite of services that combines marketing, Web3 expertise, AI capabilities, event management, research and analytics. Their goal is to help businesses navigate the digital landscape and leverage emerging technologies to achieve their objectives.
#
#
# Processing Job: A social media marketing specialist for a company schedules and personalizes social media posts.
# Public Relations Specialists
# Cosine Similarity: 0.5768389579114954, Person Cosine Similarity: 0.3844036685376929
# Search Marketing Strategists
# Cosine Similarity: 0.5151829678081199, Person Cosine Similarity: 0.4346405476720855
# Search Marketing Strategists
# Cosine Similarity: 0.5022227126409837, Person Cosine Similarity: 0.4346405476720855
#
# Processing Job: An event planner analyzes data and optimizes event logistics.
# Meeting, Convention, and Event Planners
# Cosine Similarity: 0.5906316669838516, Person Cosine Similarity: 0.4644265702670197
# Logistics Analysts
# Cosine Similarity: 0.5706304746322123, Person Cosine Similarity: 0.5393953135329799
# Meeting, Convention, and Event Planners
# Cosine Similarity: 0.5592727252672314, Person Cosine Similarity: 0.4644265702670197
#
# Processing Job: An email marketer sends personalized messages based on customer behavior and preferences.
# Telemarketers
# Cosine Similarity: 0.43650954813559295, Person Cosine Similarity: 0.2719126899015798
# Web Developers
# Cosine Similarity: 0.4215712030953752, Person Cosine Similarity: 0.18000101491049197
# Web and Digital Interface Designers
# Cosine Similarity: 0.4009477581022075, Person Cosine Similarity: 0.181171743503334
# ***********************
#
#
# ***********************
# Processing 24
# Salesforge
# Salesforge is a sales execution platform that uses AI and machine learning to improve cold email outreach by enhancing email deliverability, personalizing messages at scale, and automating critical sales activities. This comprehensive solution helps sales teams increase conversion rates and achieve their targets.
#
#
# Processing Job: A sales person sends cold emails.
# Telemarketers
# Cosine Similarity: 0.4926480709212697, Person Cosine Similarity: 0.43163662041765805
# Real Estate Sales Agents
# Cosine Similarity: 0.47399214385264554, Person Cosine Similarity: 0.3584406243929966
# Telemarketers
# Cosine Similarity: 0.43163917543302044, Person Cosine Similarity: 0.43167287860118553
#
# Processing Job: A sales manager monitors email deliverability rates.
# Sales Managers
# Cosine Similarity: 0.5479674233541579, Person Cosine Similarity: 0.5129227803393897
# Sales Managers
# Cosine Similarity: 0.4826765974613132, Person Cosine Similarity: 0.5129330822982214
# Advertising and Promotions Managers
# Cosine Similarity: 0.4736696394592693, Person Cosine Similarity: 0.37829359238806914
#
# Processing Job: A sales team nurtures leads through automated email follow-up sequences.
# Telemarketers
# Cosine Similarity: 0.4607539405502957, Person Cosine Similarity: 0.2755617274897294
# Web Developers
# Cosine Similarity: 0.4119650262462504, Person Cosine Similarity: 0.17360653504839874
# Sales Engineers
# Cosine Similarity: 0.40481236982979507, Person Cosine Similarity: 0.3237101722825942
# ***********************
#
#
# ***********************
# Processing 25
# keymate
# Description: Keymate.it simplifies the check-in process for vacation rentals by providing a digital key system, allowing guests to access their accommodations using their smartphones, eliminating the need for physical keys or meeting an host. This platform also offers features like property management and guest communication tools, streamlining the overall experience for both hosts and guests.
#
#
# Processing Job: A vacation rental host handles guest check-ins and provides keys.
# Lodging Managers
# Cosine Similarity: 0.482664419193724, Person Cosine Similarity: 0.37420799436827945
# Lodging Managers
# Cosine Similarity: 0.46840511528496553, Person Cosine Similarity: 0.37415688328552604
# Concierges
# Cosine Similarity: 0.46552259819187614, Person Cosine Similarity: 0.37587709800458335
#
# Processing Job: A vacation rental host communicates with guests through text, email, and phone.
# Spa Managers
# Cosine Similarity: 0.3865289128458256, Person Cosine Similarity: 0.2293591313207597
# Lodging Managers
# Cosine Similarity: 0.3862858399240319, Person Cosine Similarity: 0.3202480923251233
# Concierges
# Cosine Similarity: 0.3842409572331271, Person Cosine Similarity: 0.27977523697880213
#
# Processing Job: NOT_ONET A vacation rental guest retrieves keys from a property manager.
# Lodging Managers
# Cosine Similarity: 0.41579484785115894, Person Cosine Similarity: 0.3669365042062879
# Lodging Managers
# Cosine Similarity: 0.4096851998248008, Person Cosine Similarity: 0.36686818450281883
# Concierges
# Cosine Similarity: 0.40415408217721804, Person Cosine Similarity: 0.3722739115018503
# **Saving Results**
#
#
# ***********************
#
#
# ***********************
# Processing 26
# Chopa AI
# Chopa AI is an AI-powered tool that streamlines and enhances pre-engagement company research by providing comprehensive and insightful information about potential partners, empowering professionals and businesses to make informed decisions. Chopa provides detailed insights, allowing users to gain a deep understanding of companies before initiating contact or negotiations.
#
#
# Processing Job: A market researcher for a sales team conducts financial performance, news, and decision-maker research for potential clients.
# Market Research Analysts and Marketing Specialists
# Cosine Similarity: 0.5744334860661083, Person Cosine Similarity: 0.498148935813141
# Marketing Managers
# Cosine Similarity: 0.5665226847313527, Person Cosine Similarity: 0.3717596077736255
# Market Research Analysts and Marketing Specialists
# Cosine Similarity: 0.5575667355211388, Person Cosine Similarity: 0.498148935813141
#
# Processing Job: A business development manager performs industry competitive analysis to find potential partners and understand strengths and weaknesses.
# Business Intelligence Analysts
# Cosine Similarity: 0.476446426281593, Person Cosine Similarity: 0.38743802346478895
# Business Intelligence Analysts
# Cosine Similarity: 0.46714374227369293, Person Cosine Similarity: 0.3874786392677574
# Business Intelligence Analysts
# Cosine Similarity: 0.4639415675994376, Person Cosine Similarity: 0.38743802346478895
#
# Processing Job: A financial analyst for venture capitalists conducts due diligence on a startup.
# Financial and Investment Analysts
# Cosine Similarity: 0.5267015506555414, Person Cosine Similarity: 0.4929518333737297
# Financial and Investment Analysts
# Cosine Similarity: 0.5256874274618684, Person Cosine Similarity: 0.4930078237851168
# Financial and Investment Analysts
# Cosine Similarity: 0.5250448003887275, Person Cosine Similarity: 0.4929518333737297
# ***********************
#
#
# ***********************
# Processing 27
# Xenos Labs
# Xenos Labs is developing AI-powered chat assistants that leverage cutting-edge Large Language Models (LLMs) to deliver real-time, personalized conversations. These assistants are designed to engage in natural and dynamic interactions, providing users with information, support, and entertainment.
#
#
# Processing Job: Customer service representative answers frequently asked questions about a company's products and services.
# Customer Service Representatives
# Cosine Similarity: 0.6310164255092289, Person Cosine Similarity: 0.6488200225510725
# Sales Representatives of Services, Except Advertising, Insurance, Financial Services, and Travel
# Cosine Similarity: 0.6189056919510902, Person Cosine Similarity: 0.38127345067123075
# Customer Service Representatives
# Cosine Similarity: 0.5720731477059904, Person Cosine Similarity: 0.6488692975564383
#
# Processing Job: NOT_ONET - Students who need to research a topic for an essay.
# Social Science Research Assistants
# Cosine Similarity: 0.4045168309836583, Person Cosine Similarity: 0.35521132683980255
# Social Science Research Assistants
# Cosine Similarity: 0.3955062246579052, Person Cosine Similarity: 0.35519217436404443
# Producers and Directors
# Cosine Similarity: 0.3925443944480581, Person Cosine Similarity: 0.13950055488432517
#
# Processing Job: A travel agent helps travelers book flights, hotels, and activities.
# Travel Agents
# Cosine Similarity: 0.6529009504926644, Person Cosine Similarity: 0.6263343012235336
# Travel Agents
# ...
# Web Developers
# Cosine Similarity: 0.5151666456634482, Person Cosine Similarity: 0.39960342369371127
# Web Developers
# Cosine Similarity: 0.4488908438470026, Person Cosine Similarity: 0.39960342369371127
# Web Developers
# Cosine Similarity: 0.4349291720969857, Person Cosine Similarity: 0.39960342369371127
#
# Processing Job: A career counselor for tech graduates helps them hone their interviewing skills.
# Educational, Guidance, and Career Counselors and Advisors
# Cosine Similarity: 0.48107090577380335, Person Cosine Similarity: 0.37469964439142517
# Educational, Guidance, and Career Counselors and Advisors
# Cosine Similarity: 0.46732916185556356, Person Cosine Similarity: 0.37469964439142517
# Educational, Guidance, and Career Counselors and Advisors
# Cosine Similarity: 0.4536065615887009, Person Cosine Similarity: 0.37469964439142517
# ***********************
#
#
# ***********************
# Processing 695
# Teraflop AI
# Teraflop AI is a platform that utilizes powerful big data solutions to optimize and enhance the performance of large language models (LLMs), enabling businesses to extract valuable insights and accelerate their AI development journey. By leveraging advanced analytics and optimization techniques, Teraflop AI helps businesses maximize the potential of their LLMs and drive innovation in various sectors.
#
#
# Processing Job: An AI developer analyzes customer interaction data to improve the performance of the chatbot.
# Business Intelligence Analysts
# Cosine Similarity: 0.40618556255838373, Person Cosine Similarity: 0.33481563388323754
# Business Intelligence Analysts
# Cosine Similarity: 0.39283502573249873, Person Cosine Similarity: 0.33481563388323754
# Telemarketers
# Cosine Similarity: 0.3865488592001849, Person Cosine Similarity: 0.1896004905403077
#
# Processing Job: A data scientist analyzes consumer sentiment towards a new product.
# Data Scientists
# Cosine Similarity: 0.535942003945203, Person Cosine Similarity: 0.5312080951290749
# Industrial-Organizational Psychologists
# Cosine Similarity: 0.5150288161258287, Person Cosine Similarity: 0.2970871091320221
# Data Scientists
# Cosine Similarity: 0.5150083951707038, Person Cosine Similarity: 0.5312080951290749
#
# Processing Job: NOT_ONET - A research team accelerates the training process for medical AI models.
# Data Scientists
# Cosine Similarity: 0.3355200639367434, Person Cosine Similarity: 0.2948677704797839
# Data Scientists
# Cosine Similarity: 0.32774616425343106, Person Cosine Similarity: 0.2948677704797839
# Orthoptists
# Cosine Similarity: 0.32120000656813674, Person Cosine Similarity: 0.18768899807750272
# **Saving Results**
#
#
# ***********************
#
#
# ***********************
# Processing 696
# TAG
# TAG, also known as The Aetherium Group, is an AI research company focused on developing advanced AI systems that enhance human intelligence. These systems act as cognitive collaborators, amplifying human creativity, reasoning, and problem-solving abilities across various industries.
#
#
# Processing Job: A data analyst for a scientist analyzes massive datasets of scientific literature to identify trends.
# Data Scientists
# Cosine Similarity: 0.665211747025944, Person Cosine Similarity: 0.5180344883112453
# Data Scientists
# Cosine Similarity: 0.5943246894437939, Person Cosine Similarity: 0.5180344883112453
# Data Scientists
# Cosine Similarity: 0.5843656460861768, Person Cosine Similarity: 0.5179723730253142
#
# Processing Job: A data analyst for a financial analyst uses data to assess financial risks and opportunities for investment.
# Financial and Investment Analysts
# Cosine Similarity: 0.6508793693721155, Person Cosine Similarity: 0.5901433244385443
# Financial and Investment Analysts
# Cosine Similarity: 0.6147204462459789, Person Cosine Similarity: 0.5901433244385443
# Financial Risk Specialists
# Cosine Similarity: 0.6009188420183632, Person Cosine Similarity: 0.41630217135216685
#
# Processing Job: A paralegal uses data to identify relevant legal precedents.
# Paralegals and Legal Assistants
# Cosine Similarity: 0.6585329373152596, Person Cosine Similarity: 0.5486673268437755
# Paralegals and Legal Assistants
# Cosine Similarity: 0.6238779247559461, Person Cosine Similarity: 0.5486673268437755
# Legal Secretaries and Administrative Assistants
# Cosine Similarity: 0.6038652519096761, Person Cosine Similarity: 0.38366351932745496
# ***********************
#
#
# ***********************
# Processing 697
# Chat Data
# Chat Data empowers businesses to create and deploy AI chatbots on their websites. The platform offers flexible chatbot building options, including custom training, pre-trained models, and backend integration, allowing businesses to choose the solution that best suits their needs and data privacy preferences.
#
#
# Processing Job: A customer service representative is in charge of handling basic inquiries and complex customer issues.
# Customer Service Representatives
# Cosine Similarity: 0.6123040498671266, Person Cosine Similarity: 0.6361581879416456
# Customer Service Representatives
# Cosine Similarity: 0.588535268060261, Person Cosine Similarity: 0.6361566922542417
# Customer Service Representatives
# Cosine Similarity: 0.5853009062146235, Person Cosine Similarity: 0.6361581879416456
#
# Processing Job: NOT_ONET
# Nuclear Monitoring Technicians
# Cosine Similarity: 0.21381090236370953, Person Cosine Similarity: 0.21838572045412008
# Computer Numerically Controlled Tool Operators
# Cosine Similarity: 0.205814640157761, Person Cosine Similarity: 0.2503833304141965
# Computer Numerically Controlled Tool Operators
# Cosine Similarity: 0.19883632832387022, Person Cosine Similarity: 0.2503833304141965
#
# Processing Job: NOT_ONET
# Nuclear Monitoring Technicians
# Cosine Similarity: 0.21381090236370953, Person Cosine Similarity: 0.21838572045412008
# Computer Numerically Controlled Tool Operators
# Cosine Similarity: 0.205814640157761, Person Cosine Similarity: 0.2503833304141965
# Computer Numerically Controlled Tool Operators
# Cosine Similarity: 0.19883632832387022, Person Cosine Similarity: 0.2503833304141965
# ***********************
#
#
# ***********************
# Processing 698
# SOMMS.AI
# SOMMS.AI empowers music industry professionals with custom AI models that analyze and generate music, streamlining workflows and uncovering new revenue streams.  This AI-powered platform helps labels, artists, and producers optimize their creative processes and monetize their music more effectively.
#
#
# Processing Job: A music producer analyses a song's structure and identifies potential remix opportunities.
# Musicians and Singers
# Cosine Similarity: 0.4674832013633627, Person Cosine Similarity: 0.23815257204564277
# Music Directors and Composers
# Cosine Similarity: 0.4168565925278898, Person Cosine Similarity: 0.2632862464743632
# Producers and Directors
# Cosine Similarity: 0.4065726124753162, Person Cosine Similarity: 0.2790085003076934
#
# Processing Job: A music producer or artist generates music in various genres.
# Music Directors and Composers
# Cosine Similarity: 0.514008938598257, Person Cosine Similarity: 0.335685393520771
# Musicians and Singers
# Cosine Similarity: 0.4909233479074381, Person Cosine Similarity: 0.4039107237576075
# Musicians and Singers
# Cosine Similarity: 0.48766352536219215, Person Cosine Similarity: 0.4039204106224398
#
# Processing Job: NOT_ONET A musician analyzes their audience's listening preferences.
# Musicians and Singers
# Cosine Similarity: 0.450431672945444, Person Cosine Similarity: 0.37107353539364274
# Musicians and Singers
# Cosine Similarity: 0.43965864250179276, Person Cosine Similarity: 0.37107353539364274
# Musicians and Singers
# Cosine Similarity: 0.4034036032279047, Person Cosine Similarity: 0.37107353539364274
# ***********************
#
#
# ***********************
# Processing 699
# LetzAI
# LetzAI is an AI-powered platform that specializes in creating realistic images based on textual descriptions, focusing on generating visuals of local subjects and places. This platform allows users to visualize their local communities, businesses, or specific locations with the help of AI-generated imagery.
#
#
# Processing Job: A graphic designer creates high-quality images for a bakery's website and social media.
# Graphic Designers
# Cosine Similarity: 0.5606218497860413, Person Cosine Similarity: 0.5843201974437273
# Graphic Designers
# Cosine Similarity: 0.5181234292953684, Person Cosine Similarity: 0.584399664037289
# Graphic Designers
# Cosine Similarity: 0.5150002761811565, Person Cosine Similarity: 0.584399664037289
#
# Processing Job: A photographer captures images of a neighborhood for use in community newsletters and social media campaigns.
# Photographers
# Cosine Similarity: 0.47474506342887834, Person Cosine Similarity: 0.5124619333201452
# News Analysts, Reporters, and Journalists
# Cosine Similarity: 0.44860000317084103, Person Cosine Similarity: 0.24485688515921494
# Photographers
# Cosine Similarity: 0.4474368226058062, Person Cosine Similarity: 0.5124711193271463
#
# Processing Job: A real estate agent creates images for marketing a new apartment building and park.
# Landscape Architects
# Cosine Similarity: 0.48614216055236775, Person Cosine Similarity: 0.3595967022015929
# Real Estate Sales Agents
# Cosine Similarity: 0.482515393031261, Person Cosine Similarity: 0.49336909875472285
# Property, Real Estate, and Community Association Managers
# Cosine Similarity: 0.478004467164683, Person Cosine Similarity: 0.3729602627444746
# ***********************
#
#
# ***********************
# Processing 700
# Wovu AI
# Wovu AI develops sophisticated artificial intelligence software designed for enterprise use, enabling businesses to leverage the power of AI for various applications. Their team also conducts extensive AI research, pushing the boundaries of what's possible with this transformative technology.
#
#
# Processing Job: A data analyst for a marketing director predicts customer churn for new products.
# Data Scientists
# Cosine Similarity: 0.5460887897845402, Person Cosine Similarity: 0.44724776612267725
# Market Research Analysts and Marketing Specialists
# Cosine Similarity: 0.5045989146594805, Person Cosine Similarity: 0.4215582683984892
# Advertising and Promotions Managers
# Cosine Similarity: 0.49310177388130766, Person Cosine Similarity: 0.29858756791879615
#
# Processing Job: A fraud detection analyst uses financial transaction data to identify suspicious activity and prevent financial losses.
# Fraud Examiners, Investigators and Analysts
# Cosine Similarity: 0.7092468754075125, Person Cosine Similarity: 0.5748187389051198
# Fraud Examiners, Investigators and Analysts
# Cosine Similarity: 0.6586703866702146, Person Cosine Similarity: 0.5751759751314983
# Fraud Examiners, Investigators and Analysts
# Cosine Similarity: 0.6401621403689347, Person Cosine Similarity: 0.5748187389051198
#
# Processing Job: A manufacturing engineer uses data to predict potential equipment failures and optimize production schedules.
# Manufacturing Engineers
# Cosine Similarity: 0.6862617414128866, Person Cosine Similarity: 0.6194789717114163
# Manufacturing Engineers
# Cosine Similarity: 0.6241105407771084, Person Cosine Similarity: 0.6194292746315816
# Manufacturing Engineers
# Cosine Similarity: 0.6188202783824239, Person Cosine Similarity: 0.6194789717114163
# **Saving Results**
#
#
# ***********************
#
#
# ***********************
# Processing 701
# EveryAnswer
# EveryAnswer is an AI-powered knowledge platform that empowers organizations to create intelligent "Experts" capable of providing instant, accurate answers to user inquiries. These AI Experts can be seamlessly integrated into existing websites, intranets, and apps, ensuring knowledge is readily accessible to everyone within the organization.
#
#
# Processing Job: A customer service representative researches the company's database and customer history to answer a customer's question about a product warranty.
# Customer Service Representatives
# Cosine Similarity: 0.5689743272452642, Person Cosine Similarity: 0.5510654910933832
# Customer Service Representatives
# Cosine Similarity: 0.5417849273691141, Person Cosine Similarity: 0.5510642868873654
# Customer Service Representatives
# Cosine Similarity: 0.5381059209647361, Person Cosine Similarity: 0.5510642868873654
#
# Processing Job: A new employee researches the company intranet for information regarding the company's policies on vacation time.
# Human Resources Managers
# Cosine Similarity: 0.3560919958424548, Person Cosine Similarity: 0.26716134512245915
# Human Resources Specialists
# Cosine Similarity: 0.35575124460415425, Person Cosine Similarity: 0.2649916086162699
# Human Resources Assistants, Except Payroll and Timekeeping
# Cosine Similarity: 0.3552353015729358, Person Cosine Similarity: 0.23642357637650938
#
# Processing Job: A sales representative researches the company database and previous sales history to find product information and pricing for a customer inquiry.
# Sales Representatives, Wholesale and Manufacturing, Technical and Scientific Products
# Cosine Similarity: 0.5600086477842031, Person Cosine Similarity: 0.43674190957516856
# Sales Representatives, Wholesale and Manufacturing, Technical and Scientific Products
# Cosine Similarity: 0.5563561460281429, Person Cosine Similarity: 0.43855993512837754
# Sales Representatives, Wholesale and Manufacturing, Except Technical and Scientific Products
# Cosine Similarity: 0.549286544453945, Person Cosine Similarity: 0.42818107635982605
# ***********************
#
#
# ***********************
# Processing 702
# baapp
# Description: Baapp is an all-in-one software platform designed specifically for building automation controls companies, streamlining their operations from proposal generation and project management to remote access and customer interaction. Baapp aims to increase efficiency, revenue, and scalability by centralizing and integrating all aspects of their business into a single, accessible ecosystem.
#
#
# Processing Job: A sales representative creates proposals for clients.
# Sales Representatives of Services, Except Advertising, Insurance, Financial Services, and Travel
# Cosine Similarity: 0.6501005423141817, Person Cosine Similarity: 0.44027058824547555
# Sales Representatives, Wholesale and Manufacturing, Technical and Scientific Products
# Cosine Similarity: 0.6392197943576303, Person Cosine Similarity: 0.45677933143855387
# Solar Sales Representatives and Assessors
# Cosine Similarity: 0.5790739937386786, Person Cosine Similarity: 0.4119591497612459
#
# Processing Job: A project manager for a building automation company manages project timelines and assigns tasks to team members.
# Project Management Specialists
# Cosine Similarity: 0.5575123368876103, Person Cosine Similarity: 0.4996299473969408
# Project Management Specialists
# Cosine Similarity: 0.5406263139553662, Person Cosine Similarity: 0.4996299473969408
# Construction Managers
# Cosine Similarity: 0.521822452648169, Person Cosine Similarity: 0.4471010575280995
#
# Processing Job: A building automation technician troubleshoots and adjusts building automation systems.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 16
#      14 job_embedding = np.array(row[f'Job{i+1}_embedding']).reshape(1,-1)
#      15 cosine_sim = cosine_similarity(job_embedding, embeddings, 'cosine')
# ---> 16 example_title = get_person(job)
#      17 example_title_embedding = np.array([x_chat.get_embedding(example_title)])
#      19 top3 = sorted(zip(cosine_sim[0], df_exp[['Title', 'Task']].values), reverse=True)[:3]
#
# Cell In[50], line 12, in get_person(text)
#      11 def get_person(text):
# ---> 12     result = x_gemini.ask(prompt.replace("$sentence",text)).replace(" \n","")
#      13     return result
#
# Cell In[15], line 31, in gemini.ask(self, prompt)
#      28 def ask(self,prompt):
#      29     #response = self.model.generate_content(prompt)
#      30     response = self.request(prompt)
# ---> 31     if response["candidates"][0]["finishReason"] == 'SAFETY': return "N/A"
#      32     response = response["candidates"][0]["content"]["parts"][0]["text"]
#      33     return response
#
# KeyError: 'candidates'

# %%
sample_df.loc[index, ["Job1_ONET", "Job2_ONET", "Job3_ONET"]] = job_results

# %%
onet_df.head()
# Out:
#   organization_name                                            example  \
# 0           Advoria  A lawyer uses Advoria to set up an automated b...
# 1           Advoria  A lawyer uses Advoria to set up an automated b...
# 2           Advoria  A lawyer uses Advoria to set up an automated b...
# 3           Advoria  A law firm uses Advoria to collect necessary c...
# 4           Advoria  A law firm uses Advoria to collect necessary c...
#
#                                                  job  \
# 0     Legal Secretary schedules client appointments.
# 1     Legal Secretary schedules client appointments.
# 2     Legal Secretary schedules client appointments.
# 3  Legal Secretary collects and organizes client ...
# 4  Legal Secretary collects and organizes client ...
#
#                                           onet_title  \
# 0    Legal Secretaries and Administrative Assistants
# 1  Medical Secretaries and Administrative Assistants
# 2    Legal Secretaries and Administrative Assistants
# 3    Legal Secretaries and Administrative Assistants
# 4    Legal Secretaries and Administrative Assistants
#
#                                            onet_task   example_job_title  \
# 0                    Schedule and make appointments.  Legal Secretary \n
# 1  Schedule and confirm patient diagnostic appoin...  Legal Secretary \n
# 2  Attend legal meetings, such as client intervie...  Legal Secretary \n
# 3  Assist attorneys in collecting information suc...  Legal Secretary \n
# 4  Organize and maintain law libraries, documents...  Legal Secretary \n
#
#    task_similarity  job_title_similarity
# 0         0.728097              0.529373
# 1         0.591421              0.440896
# 2         0.587042              0.529373
# 3         0.663853              0.546011
# 4         0.613759              0.546078

# %%
job_embedding.shape
# Out:
# (3072, 1)
