# %%
import ast
import pandas as pd
import numpy as np
from dotenv import load_dotenv
import os
from os import getenv
from openai import OpenAI
import pathlib
import textwrap
import google.generativeai as genai
import time

load_dotenv("../.env",override=True)
GOOGLE_API_KEY = getenv("GEMINI_API_KEY")
OPENAI_API_KEY = getenv("OPENAI_API_KEY")


sample_df = pd.read_csv("./output/sample_df_industry_level_embeddings.csv")
sample_df['openai_embedding_entire'] = sample_df['openai_embedding_entire'].apply(ast.literal_eval)
sample_df = sample_df.dropna(subset=['parsed_description'])
sample_df.head()
# Out:
#    Unnamed: 0                       organization name num employees  \
# 0       22341                                  Fytted          1-10
# 1       18944       Semilla Co. (Flou / Seed Academy)          1-10
# 2       19082  ChatGPT Nederlands - GPTNederlands.com          1-10
# 3       17578                               Pelles.ai          1-10
# 4       22004                              SimLoop AI          1-10
#
#   founded date                                        description  \
# 0   2024-03-01                                                  —
# 1   2023-02-01  Semilla Co. ("Seed") is building the future of...
# 2   2023-02-03  GPTNederlands.com is dé toonaangevende bestemm...
# 3   2023-01-01  Pelles.ai transforms the way MEP (mechanical, ...
# 4   2024-01-02  SimLoop allows companies run experiments with ...
#
#                                           industries  \
# 0                                                  —
# 1  Consumer Software, Content Creators, EdTech, L...
# 2                                                  —
# 3                       Construction, SaaS, Software
# 4  Analytics, Artificial Intelligence (AI), Gener...
#
#                      headquarters location  \
# 0        Venice, California, United States
# 1  Fort Lauderdale, Florida, United States
# 2                                        —
# 3        New York, New York, United States
# 4                                        —
#
#                                        description.1    cb rank postal code  \
# 0                      SaaS, Mobile App, AI, Fashion          —       90292
# 1  Building the future of the music and entertain...     43,978       33316
# 2  GPTNederlands.com is dé toonaangevende bestemm...  1,885,621           —
# 3                           Auto-Generate MEP Design     62,705           —
# 4   User testing platform powered by simulated users    360,457           —
#
#    ...                                    description_all  \
# 0  ...                    — SaaS, Mobile App, AI, Fashion
# 1  ...  Semilla Co. ("Seed") is building the future of...
# 2  ...  GPTNederlands.com is dé toonaangevende bestemm...
# 3  ...  Pelles.ai transforms the way MEP (mechanical, ...
# 4  ...  SimLoop allows companies run experiments with ...
#
#                                    industries_parsed  \
# 0                                                 []
# 1  ['Consumer Software', 'Content Creators', 'EdT...
# 2                                                 []
# 3               ['Construction', 'SaaS', 'Software']
# 4                     ['Analytics', 'Generative AI']
#
#                                generated_description  \
# 0  Fytted is a SaaS and mobile app that leverages...
# 1  Semilla Co., through its two products - Seed A...
# 2  ChatGPT Nederlands - GPTNederlands.com is a le...
# 3  Pelles.ai is an innovative platform that utili...
# 4  SimLoop AI is an innovative platform that enab...
#
#                                     openai_embedding  \
# 0  [-0.026910386979579926, 0.00429302453994751, -...
# 1  [-0.024784477427601814, -0.007316365372389555,...
# 2  [-0.04201542213559151, -0.02567780390381813, -...
# 3  [-0.026539845392107964, -0.014325139112770557,...
# 4  [-0.04071200266480446, -0.009665796533226967, ...
#
#                                   Company  \
# 0                                  Fytted
# 1       Semilla Co. (Flou / Seed Academy)
# 2  ChatGPT Nederlands - GPTNederlands.com
# 3                               Pelles.ai
# 4                              SimLoop AI
#
#                                   parsed_description  \
# 0  \nTasks/Jobs: Fashion recommendations, Virtual...
# 1  \nTasks/Jobs: Music Business Management, Marke...
# 2  \nTasks/Jobs: Language translation, Content ge...
# 3  \nTasks/Jobs: MEP plan generation, Clash detec...
# 4  \nTasks/Jobs: Website testing, User interactio...
#
#                                           Tasks/Jobs              Industry  \
# 0  Fashion recommendations, Virtual fitting, Styl...               Fashion
# 1  Music Business Management, Marketing, Business...        Music Industry
# 2  Language translation, Content generation, Cust...           Language AI
# 3  MEP plan generation, Clash detection, Design o...          Construction
# 4  Website testing, User interaction simulation, ...  Website optimization
#
#                 People Using Tool  \
# 0            Shoppers, Consumers
# 1  Music Creators, Entrepreneurs
# 2          Dutch speakers, Anyone
# 3           Architects, Engineers
# 4           Developers, Marketers
#
#                              openai_embedding_entire
# 0  [-0.04178014397621155, -0.020127102732658386, ...
# 1  [-0.004338318016380072, -0.021966977044939995,...
# 2  [-0.0312783420085907, -0.01716475374996662, -0...
# 3  [-0.021538328379392624, -0.010536273941397667,...
# 4  [-0.025433985516428947, -0.021480992436408997,...
#
# [5 rows x 33 columns]

# %%
sample_df.Industry.unique()
# Out:
# array(['Music Industry', 'Music', 'Music technology', 'Music creation',
#        'Music production ', 'Content creation', 'Podcast discovery',
#        'Music production', 'Language AI', 'Business automation',
#        'AI language model', 'AI Solutions', 'AI platform',
#        'Conversational AI', ' AI Development', 'IT Services',
#        'No-code AI platform', 'AI Services', 'AI development platform',
#        'Construction', 'Legal tech', 'Website optimization',
#        'Moving and relocation', 'Website analytics', 'Software Testing',
#        'Website migration', 'Domain name registration and management',
#        'AI Research', 'Database management', 'Consumer goods',
#        'Software development', 'AI information and guidance',
#        'Artificial Intelligence', 'Search Engine', 'Knowledge Management',
#        'Information management',
#        'Artificial Intelligence Research & Development',
#        'AI Training Data', 'AI tools discovery', 'AI/ML/DL development',
#        'AI Marketplace', 'Information management ', 'Research',
#        'AI research', 'AI Tool Marketplace', 'Artificial intelligence ',
#        'Enterprise software', 'Oil & Gas', ' Research and Development',
#        'Web3 News', 'Technology journalism', 'Digital Media',
#        'Digital media', 'Technology media', 'Human Resources ',
#        'Human Resources', 'Recruitment', 'Employer branding ',
#        ' Team communication management', 'Human Resources (HR)',
#        'Talent Management', 'Human resources', 'Recruitment ', 'Retail',
#        'Micro-fulfillment', 'Precious metals trading',
#        'Supply chain management', 'Cybersecurity ', 'Cybersecurity',
#        'Data privacy', 'Industrial IoT Security', 'SaaS Marketplace',
#        'Consumer SaaS and mobile application development',
#        'Software Development', 'Internet of Things (IoT)',
#        'Mobile App Development', 'Mobile app development',
#        'Business growth and development', 'Software development ',
#        ' Software development', 'Software consulting',
#        'Embedded systems development', 'IT services ', 'Online education',
#        'Education', 'Education ', 'Gig economy', 'Education Technology ',
#        'Early education', 'Medical education',
#        'Employee knowledge management',
#        'Social Impact, Educational Technology ',
#        'Education and workforce development', 'Healthcare ', 'Healthcare',
#        'Healthcare technology', 'Creative arts', 'Novel writing',
#        'Entertainment', 'Robotics', 'Digital content creation',
#        'Design platform', 'Video creation', 'Automation',
#        'Creative Writing ', 'Filmmaking', 'Video Production',
#        'Political campaigning ', 'Media production',
#        'Business Development', 'Website creation ', 'Self-service kiosks',
#        'Retail and hospitality', 'Short-term rental management',
#        'Quick Service Restaurants', 'Hospitality', 'Event planning ',
#        'Restaurant technology', 'Compliance', 'Data analytics',
#        'Real estate', 'Business consulting',
#        'Fintech, Proptech, Insuretech', 'EHS Management',
#        'Financial Services ', 'Trust & Safety', 'Property Management',
#        'Financial services', 'Online education & entertainment',
#        'Digital marketing', 'Marketing', 'Digital Marketing',
#        'Wearable Technology', 'Healthcare, Wellness', 'Fitness',
#        "Women's health", 'Health and Wellness', 'Sports technology',
#        'Online Dating', 'Online dating', 'Dating ', 'Social networking',
#        'Gift giving', 'E-commerce', 'Automotive retail ', 'AI Services ',
#        'AI Consulting', 'AIaaS (AI as a Service)', 'Behavioral health',
#        'AI adoption', 'Business Optimization',
#        'Digital marketing and business solutions', 'Mobile AI',
#        'IT services', ' AI solutions', 'AI development',
#        'Technology Consulting', 'AI assurance',
#        'Business process automation', ' AI development',
#        'Financial Services', 'AI Platform', 'AI consulting',
#        'Artificial Intelligence ', 'Job search',
#        'Artificial General Intelligence (AGI)', 'Predictive Analytics',
#        'AI solutions', 'Professional services', 'AI Development',
#        'Artificial intelligence solutions',
#        'Data science and AI consulting', 'AI Customization',
#        'AI-driven products', ' AI-powered SaaS', 'AI Education',
#        ' Software as a Service (SaaS)', 'Enterprise AI solutions',
#        'Social media marketing', 'Social media management ',
#        'Content marketing', 'Marketing automation',
#        'Customer Relationship Management (CRM)', 'Customer analytics',
#        'Business Intelligence', 'Government services ',
#        'Customer communication', 'Virtual assistance ',
#        'Retail analytics', 'Communication automation ', 'Manufacturing',
#        'Customer service', 'Meeting Management', 'Email management',
#        'Franchising', 'Enterprise security ', ' Neurodiversity support',
#        'Business Operations ', 'Personal productivity',
#        'Productivity and Workflow', 'Enterprise AI ', 'Transcription',
#        'Enterprise SaaS', 'Productivity & Workflow Automation',
#        'AI personal assistants', 'Career development ', 'Job Search',
#        'Career development', 'Animal healthcare ', 'Pet care',
#        'Customer management', 'Legal Tech', 'Legal Technology',
#        'Legal & Financial Services', 'Legal technology',
#        'Data management', 'Law enforcement ', 'Data analysis',
#        'Social media', 'Assistive technology', 'Memory preservation ',
#        'Memoir creation', 'Internet browsing', 'Business intelligence',
#        'Social media ', 'Digital content analysis', 'Travel planning',
#        'Travel', ' Commercial Real Estate', 'Real Estate Investment',
#        'Real Estate', 'Property insurance ', 'Real Estate ',
#        'Sneaker Resale', 'Financial intelligence', 'Financial management',
#        'Treasury Management ', 'Finance', 'Microfinance',
#        'Personal Finance', 'Personal finance', 'Cryptocurrency trading',
#        'Financial planning and analysis', ' Financial Literacy',
#        'Fintech ', 'Financial technology', 'Water management',
#        'Drone as a Service (DaaS)', 'Agriculture', 'Data Integrity',
#        'Aquaculture', 'AI Automation', 'Venture Capital', 'Fundraising',
#        'Startup support', 'Venture capital', 'Non-profit collaboration ',
#        'Sustainable tourism', 'Non-profit ', 'Non-profit',
#        'Dream analysis', 'Sleep technology', 'Sales automation',
#        'Pipe, Valve, Fitting, and Flange Industry', 'Tax preparation',
#        'Accounting', 'Sales Automation', 'Customer interaction',
#        'Sales and Marketing Automation', 'Sales & Marketing', 'B2B Sales',
#        'Automotive sales and finance ', 'Customer engagement',
#        'Image generation', 'Food & Beverage', ' AI-powered photography',
#        'Product visualization ', 'Digital photo management',
#        'Photography & Apparel', 'Stock Photography', 'AI writing tools ',
#        'AI-powered content creation', 'Productivity', 'Ecommerce ',
#        'AI tools', 'Website Content Creation', 'Home design',
#        'Home design ', 'Interior Design',
#        'Mental health & spiritual well-being', 'Mental health',
#        'Mental health ', 'Marketing Research', 'Business strategy',
#        'Lifestyle Manufacturing', ' Simulation technology',
#        'Game Development', 'Animation production', 'VFX', 'Gaming',
#        '3D asset management', 'Proposal management',
#        'Technical Communication ', 'Biotechnology', 'Bioprinting',
#        ' Biotechnology', 'Team Management', 'Product management ',
#        'Field Service Management', 'Business Management ',
#        'Business operations', 'Team management', 'B2B e-commerce',
#        'Ecommerce', 'Procurement', 'Industrial product marketplace',
#        'Business bidding ', 'Road Safety', 'Web3 ',
#        'AI-powered media creation', ' Digital identity management',
#        'Legal services', 'Legal', 'Artificial Companionship',
#        'Social interaction', 'Event Management', 'Document automation',
#        'Shipping and logistics', 'DevOps', 'AIOps', '3D Printing',
#        ' Discrete Manufacturing', 'Acting ', 'Language learning',
#        'Commercial insurance', 'Health insurance ', 'Goal achievement',
#        'Personal Development', 'Personal Growth', 'Remote computing',
#        'Cloud Computing'], dtype=object)

# %%
# sample_df['openai_embedding_industry'] = sample_df["Industry"].apply(lambda text: x.get_embedding(text))

# %%
sample_df["task_list"] = sample_df["Tasks/Jobs"].apply(lambda x: x.split(","))
task_df = sample_df.explode('task_list')
# Out:
# 0         Music Business Management
# 0                         Marketing
# 0                 Business Strategy
# 0                  Music Production
# 1                  Music production
#                    ...
# 466          Application deployment
# 467         GPU resource allocation
# 467           Access to unused GPUs
# 467     Distributed computing tasks
# 467      High-performance computing
# Name: task_list, Length: 1872, dtype: object

# %%
list(sample_df.task_list)
# Out:
# [['Music Business Management',
#   ' Marketing',
#   ' Business Strategy',
#   ' Music Production'],
#  ['Music production', ' Songwriting', ' Marketing', ' Promotion'],
#  ['Music analysis',
#   ' Playlist creation',
#   ' Music discovery',
#   ' Audience profiling'],
#  ['Song composition',
#   ' Music production',
#   ' Lyrics generation',
#   ' Music exploration'],
#  ['Music generation', ' Sound design', ' Audio mixing', ' Mastering '],
#  ['Music creation',
#   ' Music collaboration',
#   ' Gig booking',
#   ' Music discovery'],
#  ['Content creation',
#   ' Voiceover production',
#   ' Audiobook creation',
#   ' Monetization '],
#  ['Article generation',
#   ' Image creation',
#   ' Voiceover generation',
#   ' Content creation'],
#  ['Podcast discovery',
#   ' Content curation',
#   ' Recommendation engine',
#   ' Personalized listening experience '],
#  ['Content creation',
#   ' Audio transcription',
#   ' Video summarization',
#   ' Voiceover generation '],
#  ['Vocal sample licensing',
#   ' Sound design',
#   ' Music production',
#   ' Revenue generation'],
#  ['Language translation',
#   ' Content generation',
#   ' Customer service',
#   ' Information retrieval'],
#  ['Automation',
#   ' Chatbot development',
#   ' Content creation',
#   ' AI-Stack building'],
#  ['Text generation',
#   ' Content creation',
#   ' Language translation',
#   ' Research assistance'],
#  ['Language model development',
#   ' Customization',
#   ' Integration',
#   ' Maintenance'],
#  ['Document generation',
#   ' Code creation',
#   ' AI conversation',
#   ' Image generation'],
#  ['Content creation', ' Translation', ' Summarization', ' Question answering'],
#  [' Natural Language Understanding',
#   ' Text Summarization',
#   ' Sentiment Analysis',
#   ' Language Translation'],
#  ['Website development',
#   ' Digital marketing',
#   ' AI-powered chatbots',
#   ' Upselling'],
#  ['Chatbot development',
#   ' Content creation',
#   ' Email marketing',
#   ' Code generation'],
#  ['Content generation',
#   ' Chatbot development',
#   ' Data analysis',
#   ' Image editing'],
#  ['AI assistant creation',
#   ' Virtual personality development',
#   ' Human-machine interaction',
#   ' AI chatbot building '],
#  ['MEP plan generation',
#   ' Clash detection',
#   ' Design optimization',
#   ' Automated drafting '],
#  ['Permit review',
#   ' Code compliance checks',
#   ' Error identification',
#   ' Submittal correction'],
#  ['Contract drafting',
#   ' Contract markup',
#   ' Contract review',
#   ' Legal analysis'],
#  ['Website testing',
#   ' User interaction simulation',
#   ' Optimization',
#   ' A/B testing'],
#  ['Moving volume estimation',
#   ' Moving cost calculation',
#   ' Moving plan generation',
#   ' Moving checklist creation'],
#  ['Website analytics',
#   ' Design optimization',
#   ' Sales funnel improvement',
#   ' Business growth'],
#  ['Automated testing',
#   ' bug detection',
#   ' quality assurance',
#   ' feedback generation'],
#  ['Website migration',
#   ' Data transfer',
#   ' Content optimization',
#   ' Domain redirection'],
#  ['Domain name generation',
#   ' Bulk Whois lookup',
#   ' Reverse IP lookup',
#   ' Hosting provider detection'],
#  ['AI interface design',
#   ' Generative model development',
#   ' User interaction design',
#   ' AI system optimization '],
#  ['AI model integration',
#   ' Vector search',
#   ' Real-time inference',
#   ' Model training'],
#  ['Product development',
#   ' AI research',
#   ' Consumer product creation',
#   ' Innovation'],
#  ['AI model creation',
#   ' Machine learning development',
#   ' Automation script creation',
#   ' Project management'],
#  ['AI tool research',
#   ' AI tool evaluation',
#   ' AI tool selection',
#   ' AI education'],
#  [' AI product development',
#   ' AI model training',
#   ' AI model deployment',
#   ' AI solution integration'],
#  ['Information retrieval',
#   ' Search query refinement',
#   '  Answer generation',
#   ' Content discovery '],
#  ['Guide creation',
#   ' SOP documentation',
#   ' Training material development',
#   ' Knowledge sharing'],
#  ['Information retrieval',
#   ' Knowledge sharing',
#   ' Research',
#   ' Time management'],
#  ['Research', ' AI development', ' Patent acquisition', ' Startup support'],
#  ['Biometric Data Collection',
#   ' Liveness Detection',
#   ' AI Model Training',
#   ' Data Labeling'],
#  ['AI tool discovery',
#   ' AI tool comparison',
#   ' AI tool integration',
#   ' AI tool access'],
#  ['AI model training',
#   ' AI model inference',
#   ' AI development',
#   ' Serverless computing'],
#  ['AI application procurement',
#   ' AI integration',
#   ' AI deployment',
#   ' AI management'],
#  ['Data search',
#   ' Information retrieval',
#   ' Data analysis',
#   ' Knowledge discovery'],
#  ['Research paper discovery',
#   ' Research paper summarization',
#   ' Literature review creation',
#   ' Knowledge extraction'],
#  ['Model execution', ' AI deployment', ' Cost optimization', ' AI research'],
#  ['AI Tool Discovery',
#   ' AI Tool Evaluation',
#   ' AI Tool Comparison',
#   ' AI Tool Collaboration'],
#  ['AI tool discovery',
#   ' AI news updates',
#   ' AI tool selection',
#   ' AI project management'],
#  ['AI model integration',
#   ' Data security',
#   ' Business process automation',
#   ' AI adoption'],
#  ['Information retrieval',
#   ' Knowledge management',
#   ' Documentation',
#   ' Document summarization'],
#  [' Document analysis',
#   '  Information extraction',
#   '  Answer generation',
#   ' Research automation'],
#  ['News summarization',
#   ' Content personalization',
#   ' Web3 news filtering',
#   ' Interest-based news aggregation '],
#  ['News aggregation',
#   ' Product review',
#   ' Content creation',
#   ' Information dissemination'],
#  ['News Gathering', ' Content Creation', ' Data Analysis', ' Market Research'],
#  ['Content creation',
#   ' News aggregation',
#   ' Data analysis',
#   ' Trend identification'],
#  [' Research', ' Content creation', '  News aggregation', ' Market analysis'],
#  ['Team Alignment',
#   ' Organizational Culture',
#   ' Talent Retention',
#   ' Decision Making'],
#  ['Wellbeing program design',
#   ' Employee engagement',
#   ' Mental health support',
#   ' HR tasks automation'],
#  ['Interview question generation',
#   ' Candidate assessment',
#   ' Hiring process optimization',
#   ' Time-to-hire reduction'],
#  ['Employee story collection',
#   ' Content creation',
#   ' Talent campaign launch',
#   ' Social media management '],
#  ['Conflict detection',
#   ' Team communication monitoring',
#   ' Emotional well-being analysis',
#   '  Workplace harmony promotion'],
#  ['Pre-screening interviews',
#   ' FAQ answering',
#   ' Exit interview management',
#   ' Employee onboarding '],
#  ['Candidate messaging',
#   ' Resume screening',
#   ' Interview scheduling',
#   ' Hiring analytics'],
#  ['Candidate sourcing', ' Screening', ' Interviewing', ' Onboarding'],
#  ['Candidate screening',
#   ' Job matching',
#   ' Interview scheduling',
#   ' Hiring process automation'],
#  ['Background checks',
#   ' Workforce evaluation',
#   ' Talent acquisition',
#   ' Recruitment feedback'],
#  ['Candidate screening',
#   ' Interview scheduling',
#   ' Skills assessment',
#   ' Recruitment efficiency '],
#  ['Transaction processing',
#   ' Inventory management',
#   ' Customer engagement',
#   ' Data analysis'],
#  ['Inventory management',
#   ' Demand forecasting',
#   ' Purchase order optimization',
#   '  Stock level management'],
#  ['Order fulfillment',
#   ' Inventory management',
#   ' Warehouse operations',
#   ' Picking and packing'],
#  ['Inventory management',
#   ' Pricing calculations',
#   ' Transaction processing',
#   ' Security management'],
#  ['Supply chain tracking',
#   ' Product authentication',
#   ' Regulatory compliance',
#   ' Fraud detection'],
#  ['Threat detection',
#   ' Security monitoring',
#   ' Incident response',
#   ' Security patching'],
#  ['Endpoint security',
#   ' Threat detection',
#   ' Vulnerability assessment',
#   ' Security policy enforcement'],
#  ['OSINT investigations',
#   ' Threat detection',
#   ' Cybersecurity analysis',
#   ' Data analysis'],
#  ['Data leak detection',
#   ' Security analysis',
#   ' Threat assessment',
#   ' Vulnerability management'],
#  ['Code security analysis',
#   ' Vulnerability detection',
#   ' Risk assessment',
#   ' Remediation recommendations'],
#  ['Asset classification',
#   ' Vulnerability prioritization',
#   ' Remediation automation',
#   ' Threat intelligence'],
#  ['Risk assessment',
#   ' Security policy enforcement',
#   ' Threat detection',
#   ' Incident response'],
#  [' Data analysis',
#   ' Risk assessment',
#   ' Phishing detection',
#   ' Mitigation strategy development'],
#  ['Threat detection',
#   ' Vulnerability assessment',
#   ' Security patching',
#   ' Defense strategy development '],
#  ['Data mapping',
#   ' PII detection',
#   ' Data leak prevention',
#   ' GDPR compliance'],
#  ['Threat detection',
#   ' Security monitoring',
#   ' Cyberattack prevention',
#   ' Incident response'],
#  [' Cybersecurity threat detection',
#   ' AI-tailored decoy deployment',
#   ' Adaptive security strategies',
#   '  AI-enabled threat analysis'],
#  ['Software discovery',
#   ' Software procurement',
#   ' Software management',
#   ' Service discovery'],
#  ['User interface design',
#   ' User experience design',
#   ' App development',
#   ' Human-centered design'],
#  ['Software Development',
#   ' Code Generation',
#   ' Prototyping',
#   ' Application Building'],
#  ['IoT Application Development',
#   ' Data Analysis',
#   ' Process Automation',
#   ' Project Management'],
#  ['Business process automation',
#   ' Data analysis',
#   ' Software development',
#   '  Cloud migration'],
#  ['App Development',
#   ' User Interface Design',
#   ' Artificial Intelligence Integration',
#   ' Business Growth Promotion'],
#  ['Mobile app development',
#   ' UI/UX design',
#   ' Feature optimization',
#   ' Data analysis'],
#  ['Web development',
#   ' Mobile app development',
#   ' Big data analytics',
#   ' AI integration'],
#  ['Business process automation',
#   ' software development',
#   ' data analysis',
#   ' project management '],
#  ['Code generation', ' Bug detection', ' Optimization', ' Documentation '],
#  ['Code generation', ' Code completion', ' Code debugging', ' UI design'],
#  ['UI component generation',
#   ' Code optimization',
#   ' Screenshot-to-code conversion',
#   ' Front-end development'],
#  ['Software development',
#   ' Web app development',
#   ' Mobile app development',
#   ' AI implementation '],
#  ['Code generation',
#   ' Code completion',
#   ' Code debugging',
#   ' Code optimization'],
#  ['Software development',
#   '  UI/UX design',
#   '  Project management',
#   '  Technical consulting'],
#  ['Code generation',
#   ' Task estimation',
#   ' Software development',
#   ' Subcontractor management'],
#  ['Web application development',
#   ' Mobile application development',
#   ' Web task automation',
#   ' Code generation '],
#  ['Software development',
#   ' Data analysis',
#   ' System integration',
#   ' Business process automation '],
#  ['Embedded system programming',
#   ' Hardware development',
#   ' Low-level programming',
#   ' Time to market reduction'],
#  ['IT management',
#   ' Software development',
#   ' AI integration',
#   ' Business process automation'],
#  ['Software development',
#   ' Data analysis',
#   ' System integration',
#   ' Project management'],
#  ['Course creation',
#   ' Course marketing',
#   ' Student engagement',
#   ' Course management '],
#  ['Student performance analysis',
#   ' Personalized learning recommendations',
#   '  Learning material creation',
#   '  Teacher workload optimization'],
#  ['Email generation',
#   ' Personalized student support',
#   ' Workflow automation',
#   ' Learning management system integration'],
#  ['Personalized learning',
#   ' Adaptive content',
#   ' Educational assessment',
#   ' Learning progress tracking'],
#  ['Scheduling',
#   ' Earnings management',
#   ' Community building',
#   ' Work flexibility'],
#  ['Skill development',
#   ' Learning',
#   ' Career advancement',
#   ' Professional training'],
#  ['Interactive learning',
#   ' Personalized learning',
#   ' Educational content creation',
#   ' Curriculum development'],
#  ['Job search',
#   ' Gig work matching',
#   ' Skill assessment',
#   ' Job recommendations'],
#  [' Administrative tasks',
#   ' Academic tracking',
#   ' Communication management',
#   ' Bullying detection'],
#  [' Radiology training',
#   ' Medical knowledge acquisition',
#   ' Case study analysis',
#   ' Diagnostic skill improvement'],
#  ['Essay brainstorming',
#   ' Essay outlining',
#   ' Essay revision',
#   ' Essay feedback'],
#  ['Plagiarism detection',
#   ' Content verification',
#   ' Originality checking',
#   ' Academic integrity'],
#  ['Knowledge sharing', ' Skill development', ' Collaboration', ' Training'],
#  [' Education', ' Training', ' Simulation', ' Social Interaction'],
#  ['Personalized learning',
#   ' Adaptive assessments',
#   ' Interactive learning',
#   ' Knowledge retrieval'],
#  ['Content creation',
#   ' Curriculum design',
#   ' Personalized learning',
#   ' Knowledge assessment'],
#  [' Personalized learning',
#   '  Job matching',
#   '  Skill assessment',
#   '  Talent acquisition'],
#  ['Medical data aggregation',
#   ' Medical record management',
#   ' Patient health insights',
#   ' Disease trend analysis '],
#  ['Medical transcription',
#   ' Diagnosis',
#   ' Treatment plan generation',
#   ' Coding and billing'],
#  ['Molecular lab automation',
#   ' Healthcare data analysis',
#   ' Patient management',
#   ' Personalized healthcare recommendations'],
#  ['Blood pressure monitoring',
#   ' Blood sugar monitoring',
#   ' Oxygen level monitoring',
#   ' Body temperature monitoring'],
#  ['Fluid overload detection',
#   ' Heart failure monitoring',
#   ' Early intervention',
#   ' Remote patient monitoring'],
#  ['Transcription',
#   ' Summarization',
#   ' Data extraction',
#   ' Patient record management'],
#  ['Language translation',
#   ' Medical Terminology Explanation',
#   ' Patient Communication',
#   '  Medical Documentation'],
#  ['Data analysis',
#   ' Health insights',
#   ' Medication management',
#   ' Personalized recommendations'],
#  ['AMD risk prediction',
#   ' Personalized monitoring',
#   ' Vision health management',
#   ' Disease progression tracking'],
#  ['Image generation',
#   ' Artistic exploration',
#   ' Prompt engineering',
#   ' Social media sharing'],
#  ['Character development',
#   ' Story outlining',
#   ' Scene writing',
#   ' Manuscript editing'],
#  ['Workflow automation',
#   ' Business process optimization',
#   ' Customer service',
#   ' Data analysis'],
#  ['Film production', ' Content creation', ' Distribution', ' Marketing'],
#  [' Robotics prototyping',
#   ' Simulation',
#   ' Deployment',
#   ' Autonomous navigation '],
#  ['Invoice processing',
#   ' Data extraction',
#   ' Invoice validation',
#   ' Automated payments'],
#  ['Photo generation',
#   ' Video creation',
#   ' Content creation',
#   ' Marketing materials'],
#  ['Design automation',
#   ' UI/UX generation',
#   ' Content creation',
#   ' Interactive experiences'],
#  ['Content generation',
#   ' Code writing',
#   ' Image creation',
#   ' Media production'],
#  ['Crew hiring',
#   ' Crew scheduling',
#   ' Payroll management',
#   ' Crew communication'],
#  ['Video brainstorming',
#   ' Scripting',
#   ' Video editing',
#   ' Video distribution'],
#  ['Process automation',
#   ' Workflow optimization',
#   ' Data extraction',
#   ' Task delegation'],
#  ['Book outline creation', ' Content generation', ' Editing', ' Formatting'],
#  ['Image generation',
#   ' Visual storytelling',
#   ' Cinematic reference',
#   ' Concept art'],
#  ['3D video capture', ' Upscaling', ' Enhancement', ' Editing'],
#  ['Campaign content creation',
#   ' Interview preparation',
#   ' Debate simulation',
#   ' Political strategy guidance '],
#  ['Content creation', ' Media generation', ' Video editing', ' Scriptwriting'],
#  ['Content creation',
#   ' Marketing materials',
#   ' Social media posts',
#   ' Video scripts'],
#  ['Partnership identification',
#   ' Relationship management',
#   ' Contract negotiation',
#   ' Due diligence'],
#  ['Website design',
#   ' Website development',
#   ' Content creation',
#   ' Microsite creation'],
#  ['Donation processing',
#   ' Information delivery',
#   ' Order placement',
#   ' Appointment booking'],
#  ['Customer guidance',
#   ' Goods delivery',
#   ' Information provision',
#   ' Customer service'],
#  [' Guest communication',
#   '  Booking management',
#   ' Website creation',
#   ' Property marketing'],
#  ['Order Taking',
#   ' Menu Navigation',
#   ' Payment Processing',
#   ' Customer Service'],
#  ['Customer service',
#   ' Hotel management',
#   ' Marketing automation',
#   ' Data analysis'],
#  ['Venue booking', ' Vendor management', ' Ticketing', ' Event logistics'],
#  ['Menu visualization',
#   ' Table management',
#   ' Sales analysis',
#   ' Customer engagement '],
#  ['Check-in automation',
#   ' Guest access management',
#   ' Keyless entry',
#   ' Property management '],
#  ['Regulatory compliance',
#   ' Data analysis',
#   ' Risk assessment',
#   ' Reporting '],
#  ['Data analysis',
#   ' Compliance auditing',
#   ' Algorithmic auditing',
#   ' Vendor selection'],
#  ['Property matching',
#   ' Tenant screening',
#   ' Rental application processing',
#   ' Lease agreement generation'],
#  ['Certification process management',
#   ' Security audit compliance',
#   ' Regulatory compliance',
#   ' Customer relationship building'],
#  ['KYC verification',
#   ' KYB verification',
#   ' Customer onboarding',
#   ' Regulatory compliance'],
#  ['Risk assessment',
#   ' Incident reporting',
#   ' Compliance monitoring',
#   ' Training management '],
#  ['Risk analysis',
#   ' Regulatory compliance',
#   ' Data monitoring',
#   ' Workflow optimization '],
#  ['Reviews', ' Enforcement', ' Appeals', ' Onboarding'],
#  ['Identity Verification',
#   ' Access Control',
#   ' Data Management',
#   '  Service Provider Identification'],
#  ['Compliance monitoring',
#   ' Data archiving',
#   ' Communication capture',
#   ' Regulatory reporting'],
#  ['Quiz creation',
#   ' Quiz participation',
#   ' Reward distribution',
#   ' User engagement'],
#  ['Quiz generation',
#   ' Study aid',
#   ' Learning assessment',
#   ' Knowledge retention '],
#  ['Data analysis',
#   ' Marketing optimization',
#   ' Campaign performance tracking',
#   ' Insights generation'],
#  ['Influencer prediction',
#   ' Campaign effectiveness analysis',
#   ' Marketing optimization',
#   ' Data-driven insights'],
#  ['Ad Campaign Creation',
#   ' Ad Optimization',
#   ' Ad Performance Analysis',
#   ' Ad Budget Management '],
#  [' Gesture recognition',
#   ' Body motion control',
#   ' Human-computer interaction',
#   '  Wearable device interaction'],
#  ['Meal planning',
#   ' Diet tracking',
#   ' Health data analysis',
#   ' Wellness recommendations'],
#  ['Health advice',
#   ' Health data analysis',
#   ' Personalized health plans',
#   ' Wellness monitoring'],
#  ['Workout plan creation',
#   ' Nutrition guidance',
#   ' Personalized training',
#   ' Progress tracking'],
#  ['Symptom tracking',
#   ' Personalized recommendations',
#   ' Health information access',
#   ' Mental health support '],
#  ['Diet recommendations',
#   ' Exercise suggestions',
#   ' Sleep tracking',
#   ' Stress management'],
#  ['Gait analysis',
#   ' Biomechanical data collection',
#   ' Injury prevention',
#   ' Performance optimization'],
#  ['Health analysis',
#   ' Recommendation generation',
#   ' Monitoring plans',
#   ' Personal health optimization'],
#  ['Dating profile creation',
#   ' Match recommendations',
#   '  Conversation starters',
#   ' Relationship advice'],
#  ['Matchmaking',
#   ' Safety features',
#   '  Conversation management',
#   '  Profile optimization'],
#  ['Online dating profile optimization',
#   '  Dating app strategy',
#   ' Personalized advice',
#   '  Relationship guidance'],
#  ['Profile creation',
#   '  Match suggestion',
#   ' Conversation starters',
#   '  Dating app optimization'],
#  [' Personality matching',
#   ' Digital clone creation',
#   ' Socializing',
#   ' Self-discovery'],
#  ['Gift recommendations',
#   ' Shopping suggestions',
#   ' Business discovery',
#   ' Local delivery'],
#  ['Product discovery',
#   ' Recommendations',
#   ' Personalization',
#   ' Search optimization'],
#  ['Tire comparison',
#   ' Financing options',
#   ' Price comparison',
#   ' Tire recommendations '],
#  ['Customer interaction',
#   ' Shopping experience',
#   ' Conversational UI',
#   ' E-commerce platform'],
#  ['Product discovery',
#   ' Visual search',
#   ' Personalized recommendations',
#   ' Customer engagement'],
#  ['Product discovery',
#   ' Online shopping',
#   ' Community building',
#   ' Business networking'],
#  ['Customer service',
#   ' Product recommendations',
#   ' Inventory management',
#   ' Marketing automation'],
#  ['Generative AI workflow deployment',
#   ' LLM management',
#   ' Multi-modal LLM training',
#   ' Cost optimization'],
#  ['Medical coding', ' Billing', ' Claims processing', ' Workflow automation'],
#  [' Content generation', ' Customer support', ' Data analysis', ' Automation'],
#  ['AI strategy development',
#   ' Data analysis',
#   ' Model selection',
#   ' Algorithm development'],
#  [' Data analysis', ' Predictive modeling', ' Automation', ' Optimization'],
#  ['Clinical note creation',
#   ' Progress note generation',
#   ' Session note writing',
#   ' Documentation automation'],
#  ['AI adoption decision making',
#   ' Business insights',
#   ' Cost reduction',
#   ' Automation'],
#  ['AI strategy',
#   ' Google SGE implementation',
#   ' Conversational search optimization',
#   ' Digital interaction enhancement'],
#  ['Marketing automation',
#   ' Web3 development',
#   ' AI integration',
#   ' Data analysis'],
#  ['AI-powered search',
#   ' content generation',
#   ' translation',
#   ' image recognition'],
#  ['Process automation',
#   ' Data analysis',
#   ' Predictive modeling',
#   ' AI-powered insights '],
#  [' Data analysis',
#   '  Process optimization',
#   '  Predictive modeling',
#   '  Automated decision making '],
#  ['AI agent development',
#   ' AI agent monitoring',
#   ' AI agent analysis',
#   ' AI agent performance optimization'],
#  ['Process automation',
#   ' AI integration',
#   ' Business optimization',
#   ' Data analysis'],
#  ['AI system validation',
#   ' Trustworthiness assessment',
#   ' AI risk management',
#   ' AI compliance monitoring'],
#  ['Process automation',
#   ' Data analysis',
#   ' Predictive modeling',
#   ' Decision making'],
#  ['AI agent creation',
#   ' AI agent management',
#   ' AI agent deployment',
#   ' AI agent performance monitoring'],
#  ['AI Agent Development',
#   ' Financial Services Automation',
#   ' Customer Service Optimization',
#   ' Data Analysis'],
#  ['AI content detection',
#   ' prompt generation',
#   ' pricing calculation',
#   ' AI tool integration'],
#  ['Content creation',
#   ' Data analysis',
#   ' Business automation',
#   ' AI development'],
#  ['Data analysis',
#   ' Predictive modeling',
#   ' Process automation',
#   ' Business optimization'],
#  ['AI consulting',
#   ' AI development',
#   ' AI integration',
#   ' AI decision-making'],
#  ['Job matching',
#   ' Resume analysis',
#   ' Personalized recommendations',
#   ' Job application assistance'],
#  [' Content creation', ' Code generation', ' Problem-solving', ' Research'],
#  ['Trend prediction',
#   ' Event forecasting',
#   ' Data-driven strategy',
#   ' Operational optimization'],
#  ['AI strategy development',
#   ' Generative AI implementation',
#   ' AI model training',
#   ' AI system deployment'],
#  ['Cloud enablement',
#   ' application development',
#   ' data analysis',
#   ' AI implementation'],
#  ['AI agent development',
#   ' AI agent monitoring',
#   ' AI agent performance analysis',
#   ' AI agent optimization'],
#  ['Machine learning model development',
#   ' Data analysis',
#   ' Automation',
#   ' Business process optimization '],
#  ['Data analysis',
#   ' Machine learning model development',
#   ' Business process automation',
#   ' Data strategy development'],
#  ['Business process automation',
#   ' Marketing optimization',
#   ' Data analysis',
#   ' Strategic consulting'],
#  ['Data analysis', ' Model training', ' Prediction', ' Automation'],
#  ['Prompt engineering',
#   ' Content generation',
#   ' AI model training',
#   ' AI application development'],
#  [' AI-powered creative tools',
#   ' Content generation',
#   ' NFT minting',
#   ' Blockchain development'],
#  ['AI Education',
#   ' Bard training',
#   ' Bard usage',
#   ' AI application development'],
#  [' AI-powered automation',
#   ' blockchain integration',
#   ' data analysis',
#   ' decision-making optimization '],
#  [' Process automation',
#   ' Predictive analytics',
#   ' Data analysis',
#   ' AI model development'],
#  ['Social media management',
#   ' Content scheduling',
#   ' Audience engagement',
#   ' Campaign optimization'],
#  ['Content creation',
#   ' Content scheduling',
#   ' Social media management',
#   ' Audience engagement'],
#  ['Social media marketing strategy',
#   ' Client acquisition',
#   ' Content creation',
#   ' Agency management'],
#  ['Content creation',
#   ' Content scheduling',
#   ' Social media posting',
#   ' Email marketing'],
#  ['Content creation',
#   ' Social media posting',
#   ' Audience engagement',
#   '  Brand building '],
#  ['Customer engagement',
#   ' Churn prediction',
#   ' Offer optimization',
#   ' Revenue growth'],
#  ['Customer interaction optimization',
#   ' Personalized experiences',
#   ' Revenue generation',
#   ' Customer retention'],
#  ['Data analysis',
#   ' Actionable insights',
#   ' AI-powered guidance',
#   ' Customer engagement'],
#  ['User behavior prediction',
#   ' Data-driven decision-making',
#   ' Customer engagement strategies',
#   ' Business growth optimization'],
#  ['Government service navigation',
#   ' Multilingual assistance',
#   ' Application guidance',
#   ' Public service inquiries '],
#  ['Data analysis',
#   ' Task automation',
#   ' Workflow optimization',
#   ' Customer service'],
#  ['Customer engagement',
#   ' Message automation',
#   ' Sales outreach',
#   ' Support responses'],
#  ['Scheduling',
#   ' Email management',
#   ' Task prioritization',
#   ' Research and information gathering'],
#  ['People Counting',
#   ' Occupancy monitoring',
#   ' Data Analysis',
#   ' Process Automation'],
#  ['Scheduling meetings',
#   ' Sending messages',
#   '  Facilitating call backs',
#   '  Managing routine tasks '],
#  ['Data analysis',
#   ' Process automation',
#   ' Workflow management',
#   ' Business intelligence'],
#  [' Assembly tasks',
#   '  Repetitive tasks',
#   '  Manufacturing operations',
#   '  Warehousing logistics'],
#  ['Customer support',
#   ' Lead generation',
#   ' Query resolution',
#   '  Information retrieval'],
#  ['Data entry',
#   ' Data analysis',
#   ' Report generation',
#   ' Process automation '],
#  ['Meeting transcription',
#   ' Meeting summarization',
#   ' Task list creation',
#   ' Deadline setting'],
#  ['Email prioritization',
#   ' Email summarization',
#   ' Email response drafting',
#   ' Inbox management'],
#  ['Franchise onboarding',
#   ' knowledge retrieval',
#   ' query answering',
#   ' documentation automation'],
#  ['Meeting transcription',
#   ' Sensitive data analysis',
#   ' Security enhancement',
#   ' Compliance automation'],
#  [' Routine management',
#   ' Task scheduling',
#   ' Stress reduction',
#   ' Communication tools'],
#  ['Question extraction',
#   ' Response generation',
#   ' Collaboration facilitation',
#   ' Knowledge base creation '],
#  ['Process optimization',
#   ' Task automation',
#   ' Data analysis',
#   ' Performance evaluation'],
#  ['Task management',
#   ' Schedule optimization',
#   ' Information retrieval',
#   '  Personalized recommendations'],
#  ['Task Prioritization',
#   ' Workflow Management',
#   ' Time Management',
#   ' Productivity Enhancement'],
#  ['Data analysis',
#   ' Automation',
#   ' Workflow optimization',
#   ' Business intelligence'],
#  ['Customer support',
#   ' Troubleshooting',
#   ' Account management',
#   ' Sales calls'],
#  ['Meeting transcription',
#   ' User interview analysis',
#   ' Content repurposing',
#   ' Medical and legal transcription'],
#  ['Onboarding', ' Demoing', ' Training', ' Support'],
#  ['Customer sentiment analysis',
#   ' Customer service automation',
#   ' Product improvement recommendations',
#   ' Data-driven insights generation'],
#  ['Calendar scheduling',
#   ' Notifications prioritization',
#   ' Project tracking',
#   ' Data analysis'],
#  [' Task automation',
#   ' Scheduling',
#   ' Data analysis',
#   ' Information retrieval'],
#  ['Scheduling appointments',
#   ' Managing customer interactions',
#   ' Generating reports',
#   ' Sending automated reminders'],
#  ['Customer service automation',
#   ' Knowledge base management',
#   ' Response generation',
#   ' Customer support scaling'],
#  ['Resume creation',
#   ' Job matching',
#   ' Networking',
#   ' Application submission'],
#  ['Skill analysis',
#   ' Interview preparation',
#   ' Job application',
#   ' Career guidance '],
#  ['Resume writing',
#   ' Cover letter writing',
#   ' Job application optimization',
#   ' Resume customization'],
#  ['Resume writing',
#   ' Cover letter writing',
#   ' Job application',
#   ' Job search'],
#  ['Health risk prediction',
#   ' Disease prevention',
#   ' Early intervention',
#   ' Animal health management'],
#  ['Pet behavior analysis',
#   ' Personalized care recommendations',
#   ' Communication with pets',
#   ' Health monitoring'],
#  ['Data analysis',
#   ' Marketing automation',
#   ' Appointment scheduling',
#   ' Inventory management'],
#  ['Legal research', ' Document drafting', ' Contract review', ' Legal advice'],
#  ['Legal analysis', ' Case management', ' Research', ' Advocacy'],
#  ['Legal research',
#   ' Document analysis',
#   ' Case prediction',
#   ' Contract review'],
#  ['Legal Research',
#   ' Case Management',
#   ' Document Drafting',
#   ' Contract Review'],
#  ['Document creation',
#   ' Document editing',
#   ' Contract generation',
#   ' Financial report generation'],
#  ['Document review',
#   ' Due diligence',
#   ' Fraud detection',
#   ' Contract analysis '],
#  ['Legal document review',
#   ' Contract analysis',
#   ' Legal research',
#   ' Case management'],
#  ['Metadata management',
#   ' SQL analysis',
#   ' Data cataloging',
#   ' Data modeling'],
#  ['Data analysis',
#   ' Visual analytics',
#   ' Crime prediction',
#   ' Case management'],
#  ['SQL query writing',
#   ' Data analysis',
#   ' Chart creation',
#   ' Strategic insights'],
#  ['Data analysis', ' Data access', ' Data retrieval', ' Data comprehension'],
#  ['Data analysis',
#   ' Data visualization',
#   ' Decision making',
#   ' Business insights'],
#  ['Data analysis',
#   ' Ad-hoc query answering',
#   ' Report generation',
#   ' Data visualization '],
#  ['Multimedia sharing',
#   ' Life experience documentation',
#   ' Secure communication',
#   ' Social networking'],
#  ['Comment generation',
#   ' Sentiment analysis',
#   ' Moderation',
#   ' Engagement tracking'],
#  ['Communication enhancement',
#   ' Writing assistance',
#   ' Navigation aid',
#   ' Personalized assistance'],
#  ['Content creation',
#   ' Community management',
#   ' AI entity development',
#   ' Personalized experience generation'],
#  ['Memoir writing',
#   ' Interviewing',
#   ' Story creation',
#   ' Media organization '],
#  ['Memoir writing', ' Interviewing', ' Story creation', ' Media integration'],
#  ['Chatbot development', ' Fan engagement', ' Monetization', ' AI cloning'],
#  ['Website analysis',
#   ' Content evaluation',
#   ' Time management',
#   ' Online safety'],
#  ['Competitor analysis',
#   ' Market research',
#   ' Price monitoring',
#   ' Content tracking'],
#  ['Content creation',
#   ' Sports news aggregation',
#   ' Community moderation',
#   ' Fan engagement '],
#  ['Content creation',
#   ' Social media management',
#   ' Data ownership',
#   ' NFT integration'],
#  ['Content analysis',
#   ' Sentiment analysis',
#   ' Keyword extraction',
#   ' Brand safety assessment'],
#  ['Itinerary creation',
#   ' Trip planning',
#   ' Activity booking',
#   ' Dining reservation'],
#  ['Itinerary planning',
#   ' Destination research',
#   ' Booking recommendations',
#   ' Travel recommendations'],
#  [' Holiday planning',
#   ' Deal finding',
#   ' Flight and accommodation booking',
#   ' Itinerary generation'],
#  ['Travel planning', ' Booking', ' Itinerary creation', ' Customer service'],
#  ['Destination suggestions',
#   ' Price tracking',
#   ' Group planning',
#   ' Event discovery'],
#  ['Itinerary creation',
#   ' Restaurant recommendation',
#   ' Travel planning',
#   ' Trip booking'],
#  ['Destination recommendation',
#   ' Itinerary planning',
#   ' Trip booking',
#   ' Travel planning'],
#  ['Navigation',
#   ' Social Media Integration',
#   ' Booking',
#   ' Emergency Services'],
#  [' Lease administration',
#   ' Property management',
#   ' Reporting',
#   ' Investment analysis '],
#  ['Property valuation',
#   ' Investment analysis',
#   ' Value-add opportunity identification',
#   ' Market trend forecasting'],
#  ['Home valuations',
#   ' Property search',
#   ' Negotiation support',
#   ' Transaction management'],
#  ['Damage assessment',
#   ' Risk assessment',
#   ' Fraud detection',
#   ' Property valuation '],
#  ['Property valuation',
#   ' Investment analysis',
#   ' Market research',
#   ' Risk assessment'],
#  ['Portfolio management',
#   ' Property acquisition',
#   ' Investment analysis',
#   ' Rental management'],
#  ['Property Valuation',
#   ' Title Search',
#   ' Legal Document Review',
#   ' Risk Assessment'],
#  ['Property valuation',
#   ' Market analysis',
#   ' Investment strategy',
#   ' Risk assessment'],
#  ['Sneaker pricing',
#   ' Sneaker resale',
#   ' Market analysis',
#   ' Investment recommendations'],
#  ['Financial analysis',
#   '  Financial reporting',
#   ' Business planning',
#   ' Risk assessment'],
#  ['Cash flow forecasting',
#   ' Working capital management',
#   ' Financial analysis',
#   ' Loan application automation'],
#  ['Fraud detection',
#   ' Risk assessment',
#   ' Transaction monitoring',
#   ' Case management'],
#  ['Cash flow forecasting',
#   ' Investment optimization',
#   ' Liquidity management',
#   ' Risk mitigation'],
#  ['Trading strategy development',
#   ' Order execution',
#   ' Risk management',
#   ' Portfolio optimization'],
#  ['Credit scoring',
#   ' Loan processing',
#   ' Risk assessment',
#   ' Debt collection'],
#  ['Budget tracking',
#   ' Expense categorization',
#   ' Financial goal setting',
#   ' Investment analysis'],
#  ['Financial literacy', ' Budgeting', ' Investing', ' Savings planning'],
#  ['Market analysis',
#   ' Portfolio management',
#   ' Trade execution',
#   ' Risk assessment'],
#  ['Market analysis',
#   ' Trade signal generation',
#   ' Risk management',
#   ' Portfolio optimization'],
#  ['Financial analysis',
#   ' Operational diagnostics',
#   ' Strategic simulation',
#   ' Business insights'],
#  ['Financial analysis',
#   ' Predictive modeling',
#   ' Cash flow optimization',
#   ' Strategic planning'],
#  ['Data integration',
#   ' Financial analysis',
#   ' Forecasting',
#   ' Decision support'],
#  [' Financial research',
#   ' Investment analysis',
#   ' Online earning exploration',
#   ' Financial education'],
#  ['Risk assessment',
#   ' Data analysis',
#   ' Green financing decisions',
#   ' Regulatory compliance '],
#  ['Exchange process',
#   ' transaction verification',
#   ' contract automation',
#   ' closing time reduction'],
#  ['Financial analysis',
#   ' Investment recommendations',
#   ' Loan applications',
#   ' Fraud detection '],
#  ['Water quality monitoring',
#   ' Anomaly detection',
#   ' Water purification suggestion',
#   ' Predictive water quality forecasting'],
#  ['Aerial surveillance', ' Data collection', ' Inspection', ' Delivery'],
#  ['Soil analysis',
#   ' Crop health monitoring',
#   ' Yield optimization',
#   ' Drone operation'],
#  ['Carbon footprint measurement',
#   ' Sustainable farming practices',
#   ' Data analysis',
#   ' Resource optimization'],
#  ['Resource management',
#   ' Predictive analytics',
#   ' Crop monitoring',
#   ' Irrigation control'],
#  ['Data verification',
#   ' Data analysis',
#   ' Data validation',
#   ' Information Integrity'],
#  ['Data matching', ' Data cleansing', ' Data profiling', ' Data analysis '],
#  ['Fish monitoring',
#   ' Water quality management',
#   ' Feed optimization',
#   '  Production optimization'],
#  [' AI workflow automation',
#   ' Custom AI development',
#   ' No-code AI integration',
#   ' Business process automation '],
#  ['Process automation',
#   ' Workflow automation',
#   ' AI software development',
#   '  No-code app creation'],
#  ['AI model selection',
#   ' Data preparation',
#   ' AI application building',
#   ' AI solution deployment'],
#  ['Appointment scheduling',
#   ' Patient communication',
#   ' Administrative tasks',
#   ' Healthcare data analysis'],
#  ['Patient Check-in',
#   ' Reputation Management',
#   ' AI-assisted Diagnosis',
#   '  Clinical Workflow Optimization'],
#  ['Procedure duration prediction',
#   ' Schedule optimization',
#   ' Inventory management',
#   ' Surgical workflow automation'],
#  ['Patient diagnosis',
#   ' Treatment planning',
#   ' Medical documentation',
#   ' Administrative tasks'],
#  ['Patient intake',
#   ' Medical documentation',
#   ' Diagnosis support',
#   ' Treatment planning'],
#  ['Lead generation',
#   ' Portfolio management',
#   ' Due diligence',
#   ' Deal flow management'],
#  ['Investor identification',
#   ' Investor outreach',
#   ' Funding strategy',
#   ' Startup valuation'],
#  ['Investment analysis',
#   ' Deal sourcing',
#   ' Portfolio management',
#   ' Startup mentorship'],
#  ['Financial analysis',
#   ' Investment decision making',
#   ' Due diligence',
#   ' Portfolio management'],
#  ['Financial analysis',
#   ' M&A assessment',
#   ' Deal valuation',
#   ' Due diligence'],
#  ['Project evaluation',
#   ' Market research',
#   ' Financial mentoring',
#   ' Startup support'],
#  ['Startup scouting',
#   ' Investor matching',
#   ' Deal sourcing',
#   ' Talent identification'],
#  ['Portfolio management',
#   ' Investment analysis',
#   ' LP communication',
#   ' Fund performance tracking'],
#  ['Investment analysis',
#   ' Portfolio management',
#   ' Due diligence',
#   ' Deal sourcing'],
#  ['Investment analysis',
#   ' Portfolio management',
#   ' Risk assessment',
#   ' Due diligence'],
#  ['Collaboration identification',
#   ' Grant matching',
#   ' Impact optimization',
#   ' Non-profit partnership facilitation'],
#  ['Project management', ' Fundraising', ' Marketing', ' Impact measurement'],
#  ['Grant proposal writing',
#   ' Researching funding opportunities',
#   ' Grant application tracking',
#   ' Grant application editing '],
#  ['Grant management',
#   ' Donor engagement',
#   ' Fundraising',
#   ' Operational efficiency'],
#  ['Dream interpretation',
#   ' Dream analysis',
#   ' Sleep journaling',
#   ' Personalized insights'],
#  ['Sleep cycle analysis',
#   ' Sleep quality improvement',
#   ' Sleep duration enhancement',
#   ' Personalized sleep recommendations'],
#  ['Sales material creation',
#   ' Sales outreach',
#   ' Lead qualification',
#   ' Deal closing'],
#  ['Data processing',
#   ' Product code lookup',
#   ' Sales automation',
#   ' Inside sales support '],
#  ['Sales forecasting',
#   ' Lead qualification',
#   ' Customer engagement',
#   ' Deal closing'],
#  ['Tax return preparation',
#   ' Tax planning',
#   ' Tax documentation management',
#   ' Tax compliance reporting'],
#  ['Invoice processing',
#   ' Financial reporting',
#   ' Data analysis',
#   ' Reconciliation'],
#  ['Financial reporting',
#   ' Auditing',
#   ' Tax preparation',
#   ' Client communication'],
#  ['Lead generation', ' Follow-ups', ' Customer engagement', ' Sales outreach'],
#  ['Customer service',
#   ' Sales automation',
#   ' Lead generation',
#   ' Marketing automation '],
#  ['Sales outreach',
#   ' Lead generation',
#   ' Customer engagement',
#   ' Content creation'],
#  ['Lead generation',
#   ' Sales outreach',
#   ' Appointment scheduling',
#   ' Customer engagement '],
#  ['Conversation analysis',
#   ' Customer insights',
#   ' Sales performance tracking',
#   ' Team communication insights'],
#  ['Cold email outreach',
#   ' Email deliverability optimization',
#   ' Sales messaging personalization',
#   ' Sales conversion rate improvement'],
#  ['Prospect data enrichment',
#   ' Account-based research',
#   ' Sales workflow automation',
#   ' Lead generation'],
#  ['Sales outreach', ' Email writing', ' Lead generation', ' Sales automation'],
#  ['Lead generation',
#   ' Lead scoring',
#   ' Marketing automation',
#   ' Sales outreach'],
#  ['Lead generation',
#   ' Customer engagement',
#   ' Loan pre-approval',
#   '  Deal closing '],
#  ['Customer service', ' Marketing', ' Sales', ' Lead generation'],
#  ['Portrait generation',
#   ' Stock photo creation',
#   ' Image editing',
#   ' Content creation'],
#  ['Food photography',
#   ' Image enhancement',
#   ' Marketing',
#   ' Restaurant visibility'],
#  [' Facial feature analysis',
#   ' Image generation',
#   ' Headshot creation',
#   ' Digital portrait production'],
#  ['Product photography',
#   ' Image creation',
#   '  Image editing',
#   '  AI-generated images'],
#  ['Photo editing',
#   ' Album organization',
#   ' Photo enhancement',
#   ' Memory preservation'],
#  ['Image generation',
#   ' Design creation',
#   ' Apparel customization',
#   ' Photo editing'],
#  ['Image search', ' Image selection', ' Content creation', ' Design'],
#  ['Content creation', ' Blog writing', '  Copywriting', ' Email writing'],
#  ['Content generation',
#   ' Marketing copywriting',
#   ' Blog post creation',
#   ' Social media posts'],
#  ['Coding', ' Content creation', ' Research', ' Automation'],
#  ['Product description generation',
#   ' Title creation',
#   ' SEO content writing',
#   ' Bulk content creation'],
#  ['Content creation',
#   ' SEO optimization',
#   ' Marketing automation',
#   ' Copywriting'],
#  ['Content creation',
#   ' Text generation',
#   ' Brand voice consistency',
#   ' Marketing copywriting'],
#  ['Blog article creation',
#   ' SEO optimization',
#   ' Content generation',
#   ' Content management'],
#  ['Room design', ' Furniture selection', ' Shopping', ' Interior design'],
#  ['Interior design mockups',
#   ' Product visualization',
#   ' Room layout planning',
#   ' Color and style recommendations '],
#  ['Interior design planning',
#   ' Furniture selection',
#   ' Color palette recommendation',
#   ' Room layout design'],
#  ['Virtual staging',
#   ' Floor plan redrawing',
#   ' 3D rendering',
#   ' Property visualization'],
#  [' Emotional support',
#   ' Islamic guidance',
#   ' Mindfulness exercises',
#   ' Personalized content'],
#  ['Mental health monitoring',
#   ' Personalized wellbeing plans',
#   ' Stress management techniques',
#   '  Emotional regulation strategies'],
#  ['Stress reduction',
#   ' Anxiety management',
#   ' Mental wellness',
#   ' Virtual therapy'],
#  ['Mental health assessment',
#   ' Personalized therapy recommendations',
#   '  Mental health awareness campaigns',
#   ' Connecting with therapists '],
#  ['Market research',
#   ' Customer insights collection',
#   ' Persona development',
#   ' Data analysis'],
#  ['Market research',
#   ' Sales strategy',
#   ' Go-to-market strategy',
#   ' Customer acquisition'],
#  ['Market research',
#   ' Brand strategy',
#   ' E-commerce management',
#   ' Product development'],
#  ['Company research',
#   ' Competitor analysis',
#   ' Due diligence',
#   ' Lead generation'],
#  ['3D model creation',
#   ' Character animation',
#   ' Scriptwriting',
#   ' Game development '],
#  ['Game design', ' Level creation', ' Asset generation', ' AI integration'],
#  ['Motion capture',
#   ' Body scanning',
#   ' 3D model generation',
#   ' Digital avatar creation'],
#  ['Animation production',
#   ' Character design',
#   ' Object consistency',
#   ' Art style automation'],
#  ['Motion capture cleanup',
#   ' Animation',
#   ' VFX production',
#   ' Post-production'],
#  ['Game development',
#   ' Character creation',
#   '  Interactive story creation',
#   ' Thought-based control'],
#  ['Game development',
#   ' AI integration',
#   ' Level design',
#   '  Immersive experiences'],
#  ['3D asset search',
#   ' Content discovery',
#   ' Asset integration',
#   '  Creative workflow automation'],
#  ['Game development',
#   ' AR/VR application development',
#   ' Immersive experience design',
#   ' Mobile and PC game publishing'],
#  ['Proposal generation',
#   ' Proposal editing',
#   ' Proposal tracking',
#   ' Proposal analysis'],
#  ['Technical response management',
#   ' RFI/DDQ/RFP generation',
#   ' Proposal writing',
#   '  Document analysis'],
#  ['Drug discovery',
#   ' Molecular design',
#   ' Therapeutic development',
#   ' Clinical trial optimization'],
#  ['Tissue design',
#   ' Bioprinting optimization',
#   '  3D model generation',
#   '  Simulation analysis'],
#  ['Parallel simulations',
#   ' Attractor analysis',
#   ' Network analysis',
#   ' Command line scripting'],
#  ['Team management',
#   ' Performance tracking',
#   ' Task delegation',
#   ' Communication automation'],
#  ['Idea generation',
#   ' Product roadmap creation',
#   ' Feature prioritization',
#   ' Development tracking '],
#  ['Communication automation',
#   ' Task assignment',
#   ' Workflow management',
#   ' Data analysis'],
#  ['Project management',
#   ' Task automation',
#   ' Team collaboration',
#   ' Workflow optimization'],
#  ['Workflow automation',
#   ' Task management',
#   ' Data integration',
#   ' Collaboration'],
#  ['Project management',
#   ' Task automation',
#   ' Workflow optimization',
#   ' Team communication'],
#  ['Performance feedback',
#   ' Call analysis',
#   ' Skill development',
#   ' Coaching '],
#  ['Customer support',
#   ' Data analysis',
#   ' Inventory management',
#   ' Business intelligence'],
#  ['Product matching',
#   ' Inventory management',
#   ' Price negotiation',
#   ' Order fulfillment '],
#  ['Photo conversion',
#   ' Listing creation',
#   ' Multi-platform posting',
#   ' Sales management'],
#  ['Ecommerce store setup',
#   ' Product listing',
#   ' Marketing automation',
#   ' Order fulfillment'],
#  ['Supplier Discovery', ' RFx Generation', ' Negotiation', ' Sourcing'],
#  ['Supplier identification',
#   ' Price negotiation',
#   ' Order placement',
#   ' Contract management'],
#  ['Product discovery',
#   ' Order management',
#   ' Price negotiation',
#   ' Inventory tracking '],
#  ['Bid analysis',
#   ' Bid proposal generation',
#   ' Contract negotiation',
#   ' Bid management'],
#  [' Driving behavior analysis',
#   ' Reward distribution',
#   ' Blockchain transaction processing',
#   ' Incentive programs'],
#  ['Secure data storage',
#   ' Decentralized applications',
#   ' AI-powered decision-making',
#   ' Blockchain-based transactions'],
#  [' Deep fake generation',
#   ' Media creation',
#   ' Privacy protection',
#   ' Digital communication '],
#  [' Digital identity creation',
#   ' Privacy-focused transactions',
#   ' Personalized data management',
#   ' Secure communication'],
#  ['Appointment scheduling',
#   ' Client communication',
#   ' Administrative tasks',
#   ' Lead management'],
#  ['Client intake',
#   ' Prospect analysis',
#   ' Lead qualification',
#   ' Client onboarding'],
#  ['Conversation',
#   ' Relationship simulation',
#   ' Emotional support',
#   ' Personalized interaction'],
#  ['Relationship management',
#   ' Social planning',
#   ' Event coordination',
#   ' Conversation analysis'],
#  ['Event Planning',
#   ' Experience Design',
#   ' Event Orchestration',
#   ' AI-powered Decision Making'],
#  ['PDF form filling',
#   ' Data extraction',
#   ' Form validation',
#   ' Automated submission'],
#  ['Document processing',
#   ' Data extraction',
#   ' Workflow automation',
#   ' Compliance tracking'],
#  ['Kubernetes debugging',
#   ' Issue triaging',
#   ' Remediation',
#   ' Cluster optimization'],
#  ['Operations Management',
#   ' Performance Monitoring',
#   ' Issue Detection',
#   ' Root Cause Analysis'],
#  ['Framework creation',
#   ' API management',
#   ' CI/CD automation',
#   ' Security and monitoring'],
#  ['Process optimization',
#   ' Decision-making',
#   ' Efficiency improvement',
#   ' Cost reduction'],
#  ['Print quality optimization',
#   ' Production scheduling',
#   ' Material usage analysis',
#   ' Cost estimation'],
#  [' Production data collection',
#   ' Predictive analytics',
#   ' Equipment efficiency optimization',
#   ' Emergency stop reduction'],
#  ['Accent training',
#   ' Speech analysis',
#   ' Real-time feedback',
#   ' Audition preparation '],
#  ['Language learning',
#   ' Conversational practice',
#   ' Vocabulary expansion',
#   ' Grammar improvement'],
#  ['Language learning',
#   ' Conversation practice',
#   ' Feedback analysis',
#   ' Personalized learning'],
#  ['Insurance needs identification',
#   ' Insurance product recommendation',
#   ' Insurance carrier selection',
#   ' Insurance acquisition process'],
#  ['Policy comparison',
#   '  Claim tracking',
#   ' Broker communication',
#   '  Information access'],
#  ['Goal setting',
#   ' Action planning',
#   ' Progress tracking',
#   ' Task management'],
#  ['Habit tracking',
#   ' Goal setting',
#   ' Productivity optimization',
#   ' Personalized learning'],
#  ['Content Summarization',
#   ' Information Organization',
#   ' Self-Improvement Guidance',
#   ' Goal Setting'],
#  ['Model optimization',
#   ' Algorithm development',
#   ' AI infrastructure management',
#   ' Data analysis'],
#  ['Remote access management',
#   ' GPU resource allocation',
#   ' High-performance computing',
#   ' Application deployment'],
#  ['GPU resource allocation',
#   ' Access to unused GPUs',
#   ' Distributed computing tasks',
#   ' High-performance computing']]

# %%
list(task_df.task_list)
# Out:
# ['Music Business Management',
#  ' Marketing',
#  ' Business Strategy',
#  ' Music Production',
#  'Music production',
#  ' Songwriting',
#  ' Marketing',
#  ' Promotion',
#  'Music analysis',
#  ' Playlist creation',
#  ' Music discovery',
#  ' Audience profiling',
#  'Song composition',
#  ' Music production',
#  ' Lyrics generation',
#  ' Music exploration',
#  'Music generation',
#  ' Sound design',
#  ' Audio mixing',
#  ' Mastering ',
#  'Music creation',
#  ' Music collaboration',
#  ' Gig booking',
#  ' Music discovery',
#  'Content creation',
#  ' Voiceover production',
#  ' Audiobook creation',
#  ' Monetization ',
#  'Article generation',
#  ' Image creation',
#  ' Voiceover generation',
#  ' Content creation',
#  'Podcast discovery',
#  ' Content curation',
#  ' Recommendation engine',
#  ' Personalized listening experience ',
#  'Content creation',
#  ' Audio transcription',
#  ' Video summarization',
#  ' Voiceover generation ',
#  'Vocal sample licensing',
#  ' Sound design',
#  ' Music production',
#  ' Revenue generation',
#  'Language translation',
#  ' Content generation',
#  ' Customer service',
#  ' Information retrieval',
#  'Automation',
#  ' Chatbot development',
#  ' Content creation',
#  ' AI-Stack building',
#  'Text generation',
#  ' Content creation',
#  ' Language translation',
#  ' Research assistance',
#  'Language model development',
#  ' Customization',
#  ' Integration',
#  ' Maintenance',
#  'Document generation',
#  ' Code creation',
#  ' AI conversation',
#  ' Image generation',
#  'Content creation',
#  ' Translation',
#  ' Summarization',
#  ' Question answering',
#  ' Natural Language Understanding',
#  ' Text Summarization',
#  ' Sentiment Analysis',
#  ' Language Translation',
#  'Website development',
#  ' Digital marketing',
#  ' AI-powered chatbots',
#  ' Upselling',
#  'Chatbot development',
#  ' Content creation',
#  ' Email marketing',
#  ' Code generation',
#  'Content generation',
#  ' Chatbot development',
#  ' Data analysis',
#  ' Image editing',
#  'AI assistant creation',
#  ' Virtual personality development',
#  ' Human-machine interaction',
#  ' AI chatbot building ',
#  'MEP plan generation',
#  ' Clash detection',
#  ' Design optimization',
#  ' Automated drafting ',
#  'Permit review',
#  ' Code compliance checks',
#  ' Error identification',
#  ' Submittal correction',
#  'Contract drafting',
#  ' Contract markup',
#  ' Contract review',
#  ' Legal analysis',
#  'Website testing',
#  ' User interaction simulation',
#  ' Optimization',
#  ' A/B testing',
#  'Moving volume estimation',
#  ' Moving cost calculation',
#  ' Moving plan generation',
#  ' Moving checklist creation',
#  'Website analytics',
#  ' Design optimization',
#  ' Sales funnel improvement',
#  ' Business growth',
#  'Automated testing',
#  ' bug detection',
#  ' quality assurance',
#  ' feedback generation',
#  'Website migration',
#  ' Data transfer',
#  ' Content optimization',
#  ' Domain redirection',
#  'Domain name generation',
#  ' Bulk Whois lookup',
#  ' Reverse IP lookup',
#  ' Hosting provider detection',
#  'AI interface design',
#  ' Generative model development',
#  ' User interaction design',
#  ' AI system optimization ',
#  'AI model integration',
#  ' Vector search',
#  ' Real-time inference',
#  ' Model training',
#  'Product development',
#  ' AI research',
#  ' Consumer product creation',
#  ' Innovation',
#  'AI model creation',
#  ' Machine learning development',
#  ' Automation script creation',
#  ' Project management',
#  'AI tool research',
#  ' AI tool evaluation',
#  ' AI tool selection',
#  ' AI education',
#  ' AI product development',
#  ' AI model training',
#  ' AI model deployment',
#  ' AI solution integration',
#  'Information retrieval',
#  ' Search query refinement',
#  '  Answer generation',
#  ' Content discovery ',
#  'Guide creation',
#  ' SOP documentation',
#  ' Training material development',
#  ' Knowledge sharing',
#  'Information retrieval',
#  ' Knowledge sharing',
#  ' Research',
#  ' Time management',
#  'Research',
#  ' AI development',
#  ' Patent acquisition',
#  ' Startup support',
#  'Biometric Data Collection',
#  ' Liveness Detection',
#  ' AI Model Training',
#  ' Data Labeling',
#  'AI tool discovery',
#  ' AI tool comparison',
#  ' AI tool integration',
#  ' AI tool access',
#  'AI model training',
#  ' AI model inference',
#  ' AI development',
#  ' Serverless computing',
#  'AI application procurement',
#  ' AI integration',
#  ' AI deployment',
#  ' AI management',
#  'Data search',
#  ' Information retrieval',
#  ' Data analysis',
#  ' Knowledge discovery',
#  'Research paper discovery',
#  ' Research paper summarization',
#  ' Literature review creation',
#  ' Knowledge extraction',
#  'Model execution',
#  ' AI deployment',
#  ' Cost optimization',
#  ' AI research',
#  'AI Tool Discovery',
#  ' AI Tool Evaluation',
#  ' AI Tool Comparison',
#  ' AI Tool Collaboration',
#  'AI tool discovery',
#  ' AI news updates',
#  ' AI tool selection',
#  ' AI project management',
#  'AI model integration',
#  ' Data security',
#  ' Business process automation',
#  ' AI adoption',
#  'Information retrieval',
#  ' Knowledge management',
#  ' Documentation',
#  ' Document summarization',
#  ' Document analysis',
#  '  Information extraction',
#  '  Answer generation',
#  ' Research automation',
#  'News summarization',
#  ' Content personalization',
#  ' Web3 news filtering',
#  ' Interest-based news aggregation ',
#  'News aggregation',
#  ' Product review',
#  ' Content creation',
#  ' Information dissemination',
#  'News Gathering',
#  ' Content Creation',
#  ' Data Analysis',
#  ' Market Research',
#  'Content creation',
#  ' News aggregation',
#  ' Data analysis',
#  ' Trend identification',
#  ' Research',
#  ' Content creation',
#  '  News aggregation',
#  ' Market analysis',
#  'Team Alignment',
#  ' Organizational Culture',
#  ' Talent Retention',
#  ' Decision Making',
#  'Wellbeing program design',
#  ' Employee engagement',
#  ' Mental health support',
#  ' HR tasks automation',
#  'Interview question generation',
#  ' Candidate assessment',
#  ' Hiring process optimization',
#  ' Time-to-hire reduction',
#  'Employee story collection',
#  ' Content creation',
#  ' Talent campaign launch',
#  ' Social media management ',
#  'Conflict detection',
#  ' Team communication monitoring',
#  ' Emotional well-being analysis',
#  '  Workplace harmony promotion',
#  'Pre-screening interviews',
#  ' FAQ answering',
#  ' Exit interview management',
#  ' Employee onboarding ',
#  'Candidate messaging',
#  ' Resume screening',
#  ' Interview scheduling',
#  ' Hiring analytics',
#  'Candidate sourcing',
#  ' Screening',
#  ' Interviewing',
#  ' Onboarding',
#  'Candidate screening',
#  ' Job matching',
#  ' Interview scheduling',
#  ' Hiring process automation',
#  'Background checks',
#  ' Workforce evaluation',
#  ' Talent acquisition',
#  ' Recruitment feedback',
#  'Candidate screening',
#  ' Interview scheduling',
#  ' Skills assessment',
#  ' Recruitment efficiency ',
#  'Transaction processing',
#  ' Inventory management',
#  ' Customer engagement',
#  ' Data analysis',
#  'Inventory management',
#  ' Demand forecasting',
#  ' Purchase order optimization',
#  '  Stock level management',
#  'Order fulfillment',
#  ' Inventory management',
#  ' Warehouse operations',
#  ' Picking and packing',
#  'Inventory management',
#  ' Pricing calculations',
#  ' Transaction processing',
#  ' Security management',
#  'Supply chain tracking',
#  ' Product authentication',
#  ' Regulatory compliance',
#  ' Fraud detection',
#  'Threat detection',
#  ' Security monitoring',
#  ' Incident response',
#  ' Security patching',
#  'Endpoint security',
#  ' Threat detection',
#  ' Vulnerability assessment',
#  ' Security policy enforcement',
#  'OSINT investigations',
#  ' Threat detection',
#  ' Cybersecurity analysis',
#  ' Data analysis',
#  'Data leak detection',
#  ' Security analysis',
#  ' Threat assessment',
#  ' Vulnerability management',
#  'Code security analysis',
#  ' Vulnerability detection',
#  ' Risk assessment',
#  ' Remediation recommendations',
#  'Asset classification',
#  ' Vulnerability prioritization',
#  ' Remediation automation',
#  ' Threat intelligence',
#  'Risk assessment',
#  ' Security policy enforcement',
#  ' Threat detection',
#  ' Incident response',
#  ' Data analysis',
#  ' Risk assessment',
#  ' Phishing detection',
#  ' Mitigation strategy development',
#  'Threat detection',
#  ' Vulnerability assessment',
#  ' Security patching',
#  ' Defense strategy development ',
#  'Data mapping',
#  ' PII detection',
#  ' Data leak prevention',
#  ' GDPR compliance',
#  'Threat detection',
#  ' Security monitoring',
#  ' Cyberattack prevention',
#  ' Incident response',
#  ' Cybersecurity threat detection',
#  ' AI-tailored decoy deployment',
#  ' Adaptive security strategies',
#  '  AI-enabled threat analysis',
#  'Software discovery',
#  ' Software procurement',
#  ' Software management',
#  ' Service discovery',
#  'User interface design',
#  ' User experience design',
#  ' App development',
#  ' Human-centered design',
#  'Software Development',
#  ' Code Generation',
#  ' Prototyping',
#  ' Application Building',
#  'IoT Application Development',
#  ' Data Analysis',
#  ' Process Automation',
#  ' Project Management',
#  'Business process automation',
#  ' Data analysis',
#  ' Software development',
#  '  Cloud migration',
#  'App Development',
#  ' User Interface Design',
#  ' Artificial Intelligence Integration',
#  ' Business Growth Promotion',
#  'Mobile app development',
#  ' UI/UX design',
#  ' Feature optimization',
#  ' Data analysis',
#  'Web development',
#  ' Mobile app development',
#  ' Big data analytics',
#  ' AI integration',
#  'Business process automation',
#  ' software development',
#  ' data analysis',
#  ' project management ',
#  'Code generation',
#  ' Bug detection',
#  ' Optimization',
#  ' Documentation ',
#  'Code generation',
#  ' Code completion',
#  ' Code debugging',
#  ' UI design',
#  'UI component generation',
#  ' Code optimization',
#  ' Screenshot-to-code conversion',
#  ' Front-end development',
#  'Software development',
#  ' Web app development',
#  ' Mobile app development',
#  ' AI implementation ',
#  'Code generation',
#  ' Code completion',
#  ' Code debugging',
#  ' Code optimization',
#  'Software development',
#  '  UI/UX design',
#  '  Project management',
#  '  Technical consulting',
#  'Code generation',
#  ' Task estimation',
#  ' Software development',
#  ' Subcontractor management',
#  'Web application development',
#  ' Mobile application development',
#  ' Web task automation',
#  ' Code generation ',
#  'Software development',
#  ' Data analysis',
#  ' System integration',
#  ' Business process automation ',
#  'Embedded system programming',
#  ' Hardware development',
#  ' Low-level programming',
#  ' Time to market reduction',
#  'IT management',
#  ' Software development',
#  ' AI integration',
#  ' Business process automation',
#  'Software development',
#  ' Data analysis',
#  ' System integration',
#  ' Project management',
#  'Course creation',
#  ' Course marketing',
#  ' Student engagement',
#  ' Course management ',
#  'Student performance analysis',
#  ' Personalized learning recommendations',
#  '  Learning material creation',
#  '  Teacher workload optimization',
#  'Email generation',
#  ' Personalized student support',
#  ' Workflow automation',
#  ' Learning management system integration',
#  'Personalized learning',
#  ' Adaptive content',
#  ' Educational assessment',
#  ' Learning progress tracking',
#  'Scheduling',
#  ' Earnings management',
#  ' Community building',
#  ' Work flexibility',
#  'Skill development',
#  ' Learning',
#  ' Career advancement',
#  ' Professional training',
#  'Interactive learning',
#  ' Personalized learning',
#  ' Educational content creation',
#  ' Curriculum development',
#  'Job search',
#  ' Gig work matching',
#  ' Skill assessment',
#  ' Job recommendations',
#  ' Administrative tasks',
#  ' Academic tracking',
#  ' Communication management',
#  ' Bullying detection',
#  ' Radiology training',
#  ' Medical knowledge acquisition',
#  ' Case study analysis',
#  ' Diagnostic skill improvement',
#  'Essay brainstorming',
#  ' Essay outlining',
#  ' Essay revision',
#  ' Essay feedback',
#  'Plagiarism detection',
#  ' Content verification',
#  ' Originality checking',
#  ' Academic integrity',
#  'Knowledge sharing',
#  ' Skill development',
#  ' Collaboration',
#  ' Training',
#  ' Education',
#  ' Training',
#  ' Simulation',
#  ' Social Interaction',
#  'Personalized learning',
#  ' Adaptive assessments',
#  ' Interactive learning',
#  ' Knowledge retrieval',
#  'Content creation',
#  ' Curriculum design',
#  ' Personalized learning',
#  ' Knowledge assessment',
#  ' Personalized learning',
#  '  Job matching',
#  '  Skill assessment',
#  '  Talent acquisition',
#  'Medical data aggregation',
#  ' Medical record management',
#  ' Patient health insights',
#  ' Disease trend analysis ',
#  'Medical transcription',
#  ' Diagnosis',
#  ' Treatment plan generation',
#  ' Coding and billing',
#  'Molecular lab automation',
#  ' Healthcare data analysis',
#  ' Patient management',
#  ' Personalized healthcare recommendations',
#  'Blood pressure monitoring',
#  ' Blood sugar monitoring',
#  ' Oxygen level monitoring',
#  ' Body temperature monitoring',
#  'Fluid overload detection',
#  ' Heart failure monitoring',
#  ' Early intervention',
#  ' Remote patient monitoring',
#  'Transcription',
#  ' Summarization',
#  ' Data extraction',
#  ' Patient record management',
#  'Language translation',
#  ' Medical Terminology Explanation',
#  ' Patient Communication',
#  '  Medical Documentation',
#  'Data analysis',
#  ' Health insights',
#  ' Medication management',
#  ' Personalized recommendations',
#  'AMD risk prediction',
#  ' Personalized monitoring',
#  ' Vision health management',
#  ' Disease progression tracking',
#  'Image generation',
#  ' Artistic exploration',
#  ' Prompt engineering',
#  ' Social media sharing',
#  'Character development',
#  ' Story outlining',
#  ' Scene writing',
#  ' Manuscript editing',
#  'Workflow automation',
#  ' Business process optimization',
#  ' Customer service',
#  ' Data analysis',
#  'Film production',
#  ' Content creation',
#  ' Distribution',
#  ' Marketing',
#  ' Robotics prototyping',
#  ' Simulation',
#  ' Deployment',
#  ' Autonomous navigation ',
#  'Invoice processing',
#  ' Data extraction',
#  ' Invoice validation',
#  ' Automated payments',
#  'Photo generation',
#  ' Video creation',
#  ' Content creation',
#  ' Marketing materials',
#  'Design automation',
#  ' UI/UX generation',
#  ' Content creation',
#  ' Interactive experiences',
#  'Content generation',
#  ' Code writing',
#  ' Image creation',
#  ' Media production',
#  'Crew hiring',
#  ' Crew scheduling',
#  ' Payroll management',
#  ' Crew communication',
#  'Video brainstorming',
#  ' Scripting',
#  ' Video editing',
#  ' Video distribution',
#  'Process automation',
#  ' Workflow optimization',
#  ' Data extraction',
#  ' Task delegation',
#  'Book outline creation',
#  ' Content generation',
#  ' Editing',
#  ' Formatting',
#  'Image generation',
#  ' Visual storytelling',
#  ' Cinematic reference',
#  ' Concept art',
#  '3D video capture',
#  ' Upscaling',
#  ' Enhancement',
#  ' Editing',
#  'Campaign content creation',
#  ' Interview preparation',
#  ' Debate simulation',
#  ' Political strategy guidance ',
#  'Content creation',
#  ' Media generation',
#  ' Video editing',
#  ' Scriptwriting',
#  'Content creation',
#  ' Marketing materials',
#  ' Social media posts',
#  ' Video scripts',
#  'Partnership identification',
#  ' Relationship management',
#  ' Contract negotiation',
#  ' Due diligence',
#  'Website design',
#  ' Website development',
#  ' Content creation',
#  ' Microsite creation',
#  'Donation processing',
#  ' Information delivery',
#  ' Order placement',
#  ' Appointment booking',
#  'Customer guidance',
#  ' Goods delivery',
#  ' Information provision',
#  ' Customer service',
#  ' Guest communication',
#  '  Booking management',
#  ' Website creation',
#  ' Property marketing',
#  'Order Taking',
#  ' Menu Navigation',
#  ' Payment Processing',
#  ' Customer Service',
#  'Customer service',
#  ' Hotel management',
#  ' Marketing automation',
#  ' Data analysis',
#  'Venue booking',
#  ' Vendor management',
#  ' Ticketing',
#  ' Event logistics',
#  'Menu visualization',
#  ' Table management',
#  ' Sales analysis',
#  ' Customer engagement ',
#  'Check-in automation',
#  ' Guest access management',
#  ' Keyless entry',
#  ' Property management ',
#  'Regulatory compliance',
#  ' Data analysis',
#  ' Risk assessment',
#  ' Reporting ',
#  'Data analysis',
#  ' Compliance auditing',
#  ' Algorithmic auditing',
#  ' Vendor selection',
#  'Property matching',
#  ' Tenant screening',
#  ' Rental application processing',
#  ' Lease agreement generation',
#  'Certification process management',
#  ' Security audit compliance',
#  ' Regulatory compliance',
#  ' Customer relationship building',
#  'KYC verification',
#  ' KYB verification',
#  ' Customer onboarding',
#  ' Regulatory compliance',
#  'Risk assessment',
#  ' Incident reporting',
#  ' Compliance monitoring',
#  ' Training management ',
#  'Risk analysis',
#  ' Regulatory compliance',
#  ' Data monitoring',
#  ' Workflow optimization ',
#  'Reviews',
#  ' Enforcement',
#  ' Appeals',
#  ' Onboarding',
#  'Identity Verification',
#  ' Access Control',
#  ' Data Management',
#  '  Service Provider Identification',
#  'Compliance monitoring',
#  ' Data archiving',
#  ' Communication capture',
#  ' Regulatory reporting',
#  'Quiz creation',
#  ' Quiz participation',
#  ' Reward distribution',
#  ' User engagement',
#  'Quiz generation',
#  ' Study aid',
#  ' Learning assessment',
#  ' Knowledge retention ',
#  'Data analysis',
#  ' Marketing optimization',
#  ' Campaign performance tracking',
#  ' Insights generation',
#  'Influencer prediction',
#  ' Campaign effectiveness analysis',
#  ' Marketing optimization',
#  ' Data-driven insights',
#  'Ad Campaign Creation',
#  ' Ad Optimization',
#  ' Ad Performance Analysis',
#  ' Ad Budget Management ',
#  ' Gesture recognition',
#  ' Body motion control',
#  ' Human-computer interaction',
#  '  Wearable device interaction',
#  'Meal planning',
#  ' Diet tracking',
#  ' Health data analysis',
#  ' Wellness recommendations',
#  'Health advice',
#  ' Health data analysis',
#  ' Personalized health plans',
#  ' Wellness monitoring',
#  'Workout plan creation',
#  ' Nutrition guidance',
#  ' Personalized training',
#  ' Progress tracking',
#  'Symptom tracking',
#  ' Personalized recommendations',
#  ' Health information access',
#  ' Mental health support ',
#  'Diet recommendations',
#  ' Exercise suggestions',
#  ' Sleep tracking',
#  ' Stress management',
#  'Gait analysis',
#  ' Biomechanical data collection',
#  ' Injury prevention',
#  ' Performance optimization',
#  'Health analysis',
#  ' Recommendation generation',
#  ' Monitoring plans',
#  ' Personal health optimization',
#  'Dating profile creation',
#  ' Match recommendations',
#  '  Conversation starters',
#  ' Relationship advice',
#  'Matchmaking',
#  ' Safety features',
#  '  Conversation management',
#  '  Profile optimization',
#  'Online dating profile optimization',
#  '  Dating app strategy',
#  ' Personalized advice',
#  '  Relationship guidance',
#  'Profile creation',
#  '  Match suggestion',
#  ' Conversation starters',
#  '  Dating app optimization',
#  ' Personality matching',
#  ' Digital clone creation',
#  ' Socializing',
#  ' Self-discovery',
#  'Gift recommendations',
#  ' Shopping suggestions',
#  ' Business discovery',
#  ' Local delivery',
#  'Product discovery',
#  ' Recommendations',
#  ' Personalization',
#  ' Search optimization',
#  'Tire comparison',
#  ' Financing options',
#  ' Price comparison',
#  ' Tire recommendations ',
#  'Customer interaction',
#  ' Shopping experience',
#  ' Conversational UI',
#  ' E-commerce platform',
#  'Product discovery',
#  ' Visual search',
#  ' Personalized recommendations',
#  ' Customer engagement',
#  'Product discovery',
#  ' Online shopping',
#  ' Community building',
#  ' Business networking',
#  'Customer service',
#  ' Product recommendations',
#  ' Inventory management',
#  ' Marketing automation',
#  'Generative AI workflow deployment',
#  ' LLM management',
#  ' Multi-modal LLM training',
#  ' Cost optimization',
#  'Medical coding',
#  ' Billing',
#  ' Claims processing',
#  ' Workflow automation',
#  ' Content generation',
#  ' Customer support',
#  ' Data analysis',
#  ' Automation',
#  'AI strategy development',
#  ' Data analysis',
#  ' Model selection',
#  ' Algorithm development',
#  ' Data analysis',
#  ' Predictive modeling',
#  ' Automation',
#  ' Optimization',
#  'Clinical note creation',
#  ' Progress note generation',
#  ' Session note writing',
#  ' Documentation automation',
#  'AI adoption decision making',
#  ' Business insights',
#  ' Cost reduction',
#  ' Automation',
#  'AI strategy',
#  ' Google SGE implementation',
#  ' Conversational search optimization',
#  ' Digital interaction enhancement',
#  'Marketing automation',
#  ' Web3 development',
#  ' AI integration',
#  ' Data analysis',
#  'AI-powered search',
#  ' content generation',
#  ' translation',
#  ' image recognition',
#  'Process automation',
#  ' Data analysis',
#  ' Predictive modeling',
#  ' AI-powered insights ',
#  ' Data analysis',
#  '  Process optimization',
#  '  Predictive modeling',
#  '  Automated decision making ',
#  'AI agent development',
#  ' AI agent monitoring',
#  ' AI agent analysis',
#  ' AI agent performance optimization',
#  'Process automation',
#  ' AI integration',
#  ' Business optimization',
#  ' Data analysis',
#  'AI system validation',
#  ' Trustworthiness assessment',
#  ' AI risk management',
#  ' AI compliance monitoring',
#  'Process automation',
#  ' Data analysis',
#  ' Predictive modeling',
#  ' Decision making',
#  'AI agent creation',
#  ' AI agent management',
#  ' AI agent deployment',
#  ' AI agent performance monitoring',
#  'AI Agent Development',
#  ' Financial Services Automation',
#  ' Customer Service Optimization',
#  ' Data Analysis',
#  'AI content detection',
#  ' prompt generation',
#  ' pricing calculation',
#  ' AI tool integration',
#  'Content creation',
#  ' Data analysis',
#  ' Business automation',
#  ' AI development',
#  'Data analysis',
#  ' Predictive modeling',
#  ' Process automation',
#  ' Business optimization',
#  'AI consulting',
#  ' AI development',
#  ' AI integration',
#  ' AI decision-making',
#  'Job matching',
#  ' Resume analysis',
#  ' Personalized recommendations',
#  ' Job application assistance',
#  ' Content creation',
#  ' Code generation',
#  ' Problem-solving',
#  ' Research',
#  'Trend prediction',
#  ' Event forecasting',
#  ' Data-driven strategy',
#  ' Operational optimization',
#  'AI strategy development',
#  ' Generative AI implementation',
#  ' AI model training',
#  ' AI system deployment',
#  'Cloud enablement',
#  ' application development',
#  ' data analysis',
#  ' AI implementation',
#  'AI agent development',
#  ' AI agent monitoring',
#  ' AI agent performance analysis',
#  ' AI agent optimization',
#  'Machine learning model development',
#  ' Data analysis',
#  ' Automation',
#  ' Business process optimization ',
#  'Data analysis',
#  ' Machine learning model development',
#  ' Business process automation',
#  ' Data strategy development',
#  'Business process automation',
#  ' Marketing optimization',
#  ' Data analysis',
#  ' Strategic consulting',
#  'Data analysis',
#  ' Model training',
#  ' Prediction',
#  ' Automation',
#  'Prompt engineering',
#  ' Content generation',
#  ' AI model training',
#  ' AI application development',
#  ' AI-powered creative tools',
#  ' Content generation',
#  ' NFT minting',
#  ' Blockchain development',
#  'AI Education',
#  ' Bard training',
#  ' Bard usage',
#  ' AI application development',
#  ' AI-powered automation',
#  ' blockchain integration',
#  ' data analysis',
#  ' decision-making optimization ',
#  ' Process automation',
#  ' Predictive analytics',
#  ' Data analysis',
#  ' AI model development',
#  'Social media management',
#  ' Content scheduling',
#  ' Audience engagement',
#  ' Campaign optimization',
#  'Content creation',
#  ' Content scheduling',
#  ' Social media management',
#  ' Audience engagement',
#  'Social media marketing strategy',
#  ' Client acquisition',
#  ' Content creation',
#  ' Agency management',
#  'Content creation',
#  ' Content scheduling',
#  ' Social media posting',
#  ' Email marketing',
#  'Content creation',
#  ' Social media posting',
#  ' Audience engagement',
#  '  Brand building ',
#  'Customer engagement',
#  ' Churn prediction',
#  ' Offer optimization',
#  ' Revenue growth',
#  'Customer interaction optimization',
#  ' Personalized experiences',
#  ' Revenue generation',
#  ' Customer retention',
#  'Data analysis',
#  ' Actionable insights',
#  ' AI-powered guidance',
#  ' Customer engagement',
#  'User behavior prediction',
#  ' Data-driven decision-making',
#  ' Customer engagement strategies',
#  ' Business growth optimization',
#  'Government service navigation',
#  ' Multilingual assistance',
#  ' Application guidance',
#  ' Public service inquiries ',
#  'Data analysis',
#  ' Task automation',
#  ' Workflow optimization',
#  ' Customer service',
#  'Customer engagement',
#  ' Message automation',
#  ' Sales outreach',
#  ' Support responses',
#  'Scheduling',
#  ' Email management',
#  ' Task prioritization',
#  ' Research and information gathering',
#  'People Counting',
#  ' Occupancy monitoring',
#  ' Data Analysis',
#  ' Process Automation',
#  'Scheduling meetings',
#  ' Sending messages',
#  '  Facilitating call backs',
#  '  Managing routine tasks ',
#  'Data analysis',
#  ' Process automation',
#  ' Workflow management',
#  ' Business intelligence',
#  ' Assembly tasks',
#  '  Repetitive tasks',
#  '  Manufacturing operations',
#  '  Warehousing logistics',
#  ...]

# %%
pd.DataFrame(task_df.task_list.value_counts())
# Out:
#                               count
# task_list
#  Data analysis                   38
#  Content creation                17
# Content creation                 17
# Data analysis                    15
#  Risk assessment                 11
# ...                             ...
#  Property management              1
#  Keyless entry                    1
#  Guest access management          1
# Check-in automation               1
#  Distributed computing tasks      1
#
# [1441 rows x 1 columns]

# %%
# genai.configure(api_key=GOOGLE_API_KEY)
# class gemini():
#     def __init__(self):
#         self.model = genai.GenerativeModel('gemini-1.5-flash')
#     def ask(self,prompt):
#         response = self.model.generate_content(prompt)
#         print(response)
#         if response.candidates[0].finish_reason == 3: return "N/A"
#         response = response.candidates[0].content.parts[0].text
#         return response

# x = gemini()
# x.ask("hi")

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import SpectralClustering
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Assuming 'sample_df' and its 'openai_embedding_entire' column exist and contain appropriate data
embeddings = np.array(sample_df['openai_embedding_entire'].tolist())

similarity_matrix = cosine_similarity(embeddings)
distance_matrix = 1 - similarity_matrix

# Define the number of neighbors
n_neighbors = 5

# Create a KNN model for connectivity based on cosine distance
knn = NearestNeighbors(n_neighbors=n_neighbors, metric='cosine')
knn.fit(embeddings)
connectivity_matrix = knn.kneighbors_graph(embeddings, mode='connectivity')

# Use Spectral Clustering with the connectivity matrix defined by KNN
clustering = SpectralClustering(n_clusters=100, affinity='precomputed', assign_labels='kmeans', random_state=42)
cluster_labels = clustering.fit_predict(connectivity_matrix)

# Assign cluster labels back to the original DataFrame
sample_df['cluster_label'] = cluster_labels
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/manifold/_spectral_embedding.py:248: UserWarning: Array is not symmetric, and will be converted to symmetric by average with its transpose.
#   adjacency = check_symmetric(adjacency)

# %%
for i in range(10):
    num_companies = len(sample_df[sample_df["cluster_label"] == i])
    print(f"Cluster {i}, Number of companies: {num_companies}")
# Out:
# Cluster 0, Number of companies: 8
# Cluster 1, Number of companies: 6
# Cluster 2, Number of companies: 7
# Cluster 3, Number of companies: 7
# Cluster 4, Number of companies: 4
# Cluster 5, Number of companies: 6
# Cluster 6, Number of companies: 8
# Cluster 7, Number of companies: 9
# Cluster 8, Number of companies: 5
# Cluster 9, Number of companies: 8

# %%
for i in range(0,10):
    print(f"Processing {i}:\n************************\n")
    vals = sample_df[sample_df["cluster_label"]==i][["organization name","generated_description","parsed_description"]]
    for index, row in vals.iterrows():
        print(f"Organization Name: {row['organization name']}")
        print(f"Generated Description: {row['generated_description']}")
        print(f"Generated Description: {row['parsed_description']}\n")
    print(f"************************\n\n")
# Out:
# Processing 0:
# ************************
#
# Organization Name: fyby.io
# Generated Description: Fyby.io is an AI-powered marketplace that assists businesses in discovering, purchasing, and managing software, tech services, and bundled solutions. It streamlines the procurement process by providing a data-driven platform for SaaS products and tech-related service solutions.
# Generated Description:
# Tasks/Jobs: Software discovery, Software procurement, Software management, Service discovery
# Industry: SaaS Marketplace
# People Using Tool: Businesses, IT managers
#
#
#
# Organization Name: beeta.one
# Generated Description: Beeta.one is a digital platform specializing in the development of Internet of Things (IoT) applications through its user-friendly, no-code environment and AI-powered project assistant. Primarily serving SMEs in the DACH and EU markets, it enables businesses to leverage their data, streamline operations, and foster innovation, simplifying the process of digital transformation.
# Generated Description:
# Tasks/Jobs: IoT Application Development, Data Analysis, Process Automation, Project Management
# Industry: Internet of Things (IoT)
# People Using Tool: SMEs, Engineers, Developers
#
#
#
# Organization Name: Digital Meld
# Generated Description: Digital Meld provides businesses with AI-powered tools and consulting services designed to streamline operations, reduce costs, and drive growth. Their offerings include SaaS, Microsoft 365, Azure, Power Platform, and app development, all aimed at leveraging data to unlock a company's full potential.
# Generated Description:
# Tasks/Jobs: Business process automation, Data analysis, Software development,  Cloud migration
# Industry: Business automation
# People Using Tool: Business owners, IT professionals
#
#
#
# Organization Name: Ebris Tech
# Generated Description: Ebris Tech is a technology company that specializes in creating bespoke digital solutions to help businesses accelerate their growth and development. Catering to both startups and established enterprises, Ebris Tech leverages its expertise and experience to transition businesses to their next phase of growth.
# Generated Description:
# Tasks/Jobs: Business process automation, software development, data analysis, project management
# Industry: Business growth and development
# People Using Tool: Startups, Enterprises
#
#
#
# Organization Name: KubicBits
# Generated Description: KubicBits is a software consulting firm that specializes in creating bespoke software solutions, tailored to meet and exceed client expectations. They offer services in SaaS solutions, software and data consulting, with a focus on innovation and building lasting partnerships.
# Generated Description:
# Tasks/Jobs: Software development, Data analysis, System integration, Business process automation
# Industry: Software consulting
# People Using Tool: Businesses, Enterprises
#
#
#
# Organization Name: Metalware
# Generated Description: Metalware is a cutting-edge platform that streamlines hardware development by automating the process of low-level programming, significantly reducing the time to market for embedded systems. It provides a solution for businesses seeking to expedite their hardware development process and launch their products more efficiently.
# Generated Description:
# Tasks/Jobs: Embedded system programming, Hardware development, Low-level programming, Time to market reduction
# Industry: Embedded systems development
# People Using Tool: Hardware engineers, Developers
#
#
#
# Organization Name: Incendrify LTD
# Generated Description: Incendrify LTD is a technology company specializing in IT management, artificial intelligence, and software development to enhance business performance. They provide innovative solutions that streamline operations, improve efficiency, and drive growth for businesses across various industries.
# Generated Description:
# Tasks/Jobs: IT management, Software development, AI integration, Business process automation
# Industry: IT services
# People Using Tool: Businesses, Organizations
#
#
#
# Organization Name: KubicBits
# Generated Description: KubicBits is a software consulting firm that specializes in creating bespoke software solutions, tailored to meet and exceed client expectations. They offer services in SaaS solutions, software consulting, and data consulting, with a focus on innovation and building lasting partnerships.
# Generated Description:
# Tasks/Jobs: Software development, Data analysis, System integration, Project management
# Industry: Software consulting
# People Using Tool: Businesses, Organizations
#
#
#
# ************************
#
#
# Processing 1:
# ************************
#
# Organization Name: Medstow
# Generated Description: Medstow is an AI-powered mobile application and web portal that consolidates comprehensive medical information from various sources, providing secure data storage and valuable insights for both patients and healthcare facilities. It aims to improve patient care, disease trend analysis, and medical data sharing in regions where healthcare data systems are not prioritized, offering tiered pricing based on data usage.
# Generated Description:
# Tasks/Jobs: Medical data aggregation, Medical record management, Patient health insights, Disease trend analysis
# Industry: Healthcare
# People Using Tool: Patients, Healthcare providers
#
#
#
# Organization Name: Pasbox
# Generated Description: Pasbox is an innovative technology company that leverages artificial intelligence to provide cost-effective solutions for bio molecular labs in South East Asia, enhancing their business expansion and reducing costs for end customers. Additionally, Pasbox offers a comprehensive healthcare platform for mothers and children, delivering a full circle of daily healthcare options to improve lives.
# Generated Description:
# Tasks/Jobs: Molecular lab automation, Healthcare data analysis, Patient management, Personalized healthcare recommendations
# Industry: Healthcare
# People Using Tool: Lab technicians, Doctors, Mothers, Children
#
#
#
# Organization Name: doctor Z
# Generated Description: Doctor Z is developing a compact, all-in-one diagnostic device that measures blood pressure, sugar levels, oxygen levels, and body temperature, and uses AI to detect early signs of lifestyle diseases. The device pairs with your smartphone, sending reports directly to your doctor, making it a convenient tool for online consultations and rendering traditional individual devices obsolete.
# Generated Description:
# Tasks/Jobs: Blood pressure monitoring, Blood sugar monitoring, Oxygen level monitoring, Body temperature monitoring
# Industry: Healthcare
# People Using Tool: Everyone, Doctors
#
#
#
# Organization Name: Pulsli
# Generated Description: Pulsli is a healthcare technology company that uses artificial intelligence to provide non-invasive solutions for heart failure care, specifically in detecting fluid overload in a timely manner. Their innovative approach aims to prevent hospitalizations by enabling early detection and intervention.
# Generated Description:
# Tasks/Jobs: Fluid overload detection, Heart failure monitoring, Early intervention, Remote patient monitoring
# Industry: Healthcare technology
# People Using Tool: Patients, Clinicians
#
#
#
# Organization Name: Diawiser
# Generated Description: Diawiser is an AI-powered health assistant designed to transform unstructured data into personalized, medically accurate insights for efficient diabetes management. It leverages artificial intelligence to provide actionable and understandable health insights, empowering individuals with diabetes to better manage their condition.
# Generated Description:
# Tasks/Jobs: Data analysis, Health insights, Medication management, Personalized recommendations
# Industry: Healthcare
# People Using Tool: Diabetics, Healthcare professionals
#
#
#
# Organization Name: RetiNov
# Generated Description: RetiNov offers MacuTest, a web application designed to prevent blindness from Age-related Macular Degeneration (AMD) by predicting the risk of disease progression using AI algorithms. The app provides personalized monitoring tailored to individual needs, helping patients maintain their vision and prevent the onset of this debilitating disease.
# Generated Description:
# Tasks/Jobs: AMD risk prediction, Personalized monitoring, Vision health management, Disease progression tracking
# Industry: Healthcare
# People Using Tool: AMD patients, Ophthalmologists
#
#
#
# ************************
#
#
# Processing 2:
# ************************
#
# Organization Name: AI Insider Tips
# Generated Description: AI Insider Tips is a comprehensive online resource that offers in-depth reviews, tips, and tutorials on the latest artificial intelligence tools and software. It serves as a guide to help users navigate the complex world of AI technology, providing valuable insights and news updates.
# Generated Description:
# Tasks/Jobs: AI tool research, AI news aggregation, AI tutorial creation, AI tool comparison
# Industry: AI education
# People Using Tool:  AI professionals, Students, Businesses
#
#
#
# Organization Name: Job.zip
# Generated Description: Job.zip is a data-driven platform that provides comprehensive insights and trends about the global job market. It aims to identify and analyze the resilience and growth of various job sectors in the face of advancing artificial intelligence technologies.
# Generated Description:
# Tasks/Jobs: Job market analysis, Trend identification,  Sector resilience analysis, AI impact assessment
# Industry: Job market insights
# People Using Tool: Recruiters, Businesses, Researchers
#
#
#
# Organization Name: AI Budge
# Generated Description: AI Budge is a leading online platform that provides the latest news, insights, and in-depth analysis in the field of artificial intelligence, catering to AI enthusiasts, professionals, and tech-savvy individuals. With content created by AI experts, it offers practical guides and solutions to AI-related challenges, fostering a vibrant community where users can engage in discussions, exchange ideas, and stay ahead in the AI landscape.
# Generated Description:
# Tasks/Jobs: AI news aggregation, AI content creation, AI insights analysis, AI community engagement
# Industry: AI news and information
# People Using Tool: AI enthusiasts, AI professionals
#
#
#
# Organization Name: MoAIJobs
# Generated Description: MoAIJobs is a specialized job search platform dedicated to connecting job seekers with the latest opportunities in the rapidly evolving field of artificial intelligence. It offers a comprehensive database of AI-related roles from top companies in areas such as machine learning, generative AI, and data science, allowing users to filter jobs by category, location, and keyword.
# Generated Description:
# Tasks/Jobs: Job search, AI job filtering, AI job matching, AI career advice
# Industry: AI job recruitment
# People Using Tool: AI professionals, Data scientists
#
#
#
# Organization Name: JeezAI
# Generated Description: JeezAI is an AI-powered platform that connects students with top-tier internship opportunities in the AI and technology fields, using advanced matching algorithms to align with the students' visions, backgrounds, and aspirations. The platform also provides access to AI products, organizes industry events, and fosters engagement with AI companies and leaders, creating a comprehensive and personalized career development experience in the AI industry.
# Generated Description:
# Tasks/Jobs: Internship matching, AI product access, Event organization, Career development
# Industry: AI education and career development
# People Using Tool: Students, AI professionals
#
#
#
# Organization Name: Open AI Sea
# Generated Description: Open AI Sea is a comprehensive online resource that provides the latest news, funding updates, tool guides, and reviews in the field of artificial intelligence. It aims to simplify and democratize AI knowledge, making it accessible to individuals of all expertise levels.
# Generated Description:
# Tasks/Jobs: AI news aggregation, AI tool discovery, Funding research, AI resource curation
# Industry: AI information and resources
# People Using Tool: Developers, Researchers, Businesses, Everyone
#
#
#
# Organization Name: Superpower Daily
# Generated Description: Superpower Daily is a digital platform providing daily updates and insights on artificial intelligence trends and news. It serves as a valuable resource for individuals and businesses looking to stay informed and ahead in the rapidly evolving field of AI.
# Generated Description:
# Tasks/Jobs: AI news curation, AI trend analysis, AI education, AI resource discovery
# Industry: Artificial Intelligence (AI) Information
# People Using Tool: Professionals, Businesses, Students, Enthusiasts
#
#
#
# ************************
#
#
# Processing 3:
# ************************
#
# Organization Name: SuperDuperDB
# Generated Description: SuperDuperDB is a platform that simplifies the process of building AI applications by allowing users to integrate AI and vector search directly with their databases, eliminating the need for complex pipelines and specialized vector databases. It supports real-time inference and model training using Python, making AI integration more accessible and efficient.
# Generated Description:
# Tasks/Jobs: AI model integration, Vector search, Real-time inference, Model training
# Industry: Database management
# People Using Tool: Developers, Data scientists
#
#
#
# Organization Name: RobotTools.AI
# Generated Description: RobotTools.AI is a comprehensive library offering Artificial Intelligence, Machine Learning, and automation software tools to facilitate the creation of various projects. It serves as a one-stop resource for users, regardless of their technical expertise, to leverage advanced technologies in their work.
# Generated Description:
# Tasks/Jobs: AI model creation, Machine learning development, Automation script creation, Project management
# Industry: Software development
# People Using Tool: Developers, Researchers, Businesses
#
#
#
# Organization Name: Icelabs
# Generated Description: Icelabs is a cutting-edge technology company specializing in the development of innovative artificial intelligence products. Their focus lies in creating AI solutions that are not only efficient and reliable, but also user-friendly and accessible to a wide range of industries.
# Generated Description:
# Tasks/Jobs:  AI product development, AI model training, AI model deployment, AI solution integration
# Industry: Artificial Intelligence
# People Using Tool: Developers, Businesses
#
#
#
# Organization Name: Axon Labs
# Generated Description: Axon Labs is a leading provider of high-quality biometric and medical datasets, designed to train and enhance artificial intelligence models. Their specialized data offerings, including ready-to-use biometric data for liveness detection, serve as a comprehensive resource for projects requiring superior data accuracy and reliability.
# Generated Description:
# Tasks/Jobs: Biometric Data Collection, Liveness Detection, AI Model Training, Data Labeling
# Industry: AI Training Data
# People Using Tool: AI Developers, Researchers
#
#
#
# Organization Name: Dataoorts | GPU Cloud
# Generated Description: Dataoorts GPU Cloud is a cost-effective solution designed to enhance AI development and deployment tasks by providing high-performance GC2 and T4s GPU instances. The platform also offers serverless computing, enabling users to create their own inference endpoint API, making it an ideal tool for all AI/ML/DL developers.
# Generated Description:
# Tasks/Jobs: AI model training, AI model inference, AI development, Serverless computing
# Industry: AI/ML/DL development
# People Using Tool: Developers, Researchers
#
#
#
# Organization Name: ShuttleAI
# Generated Description: ShuttleAI is an AI research firm offering a user-friendly API to execute AI models efficiently and cost-effectively. It provides a scalable and ready-for-production service, making AI implementation accessible for businesses of all sizes.
# Generated Description:
# Tasks/Jobs: Model execution, AI deployment, Cost optimization, AI research
# Industry: AI research
# People Using Tool: Developers, Researchers, Businesses
#
#
#
# Organization Name: Enkrypt AI
# Generated Description: Enkrypt AI provides a platform that facilitates the swift and secure integration of General AI models into enterprise systems. Their service is designed to enhance business operations by leveraging the power of AI, ensuring data security and accelerating the AI adoption process.
# Generated Description:
# Tasks/Jobs: AI model integration, Data security, Business process automation, AI adoption
# Industry: Enterprise software
# People Using Tool: Developers, Data scientists
#
#
#
# ************************
#
#
# Processing 4:
# ************************
#
# Organization Name: Trident AI
# Generated Description: Trident AI is a B2B SaaS company that develops AI-powered fraud investigators designed to assist banks and fintechs in combating the increasing rates of fraud and scams. Their mission is to create a world with zero fraud victims by equipping financial institutions with advanced AI tools to keep pace with AI-enabled fraud.
# Generated Description:
# Tasks/Jobs: Fraud detection, Risk assessment, Transaction monitoring, Case management
# Industry: Financial Services
# People Using Tool: Banks, Fintechs
#
#
#
# Organization Name: Grupago
# Generated Description: Grupago is a trailblazer in providing digital microcredit to small and mid-sized businesses in Latin America, utilizing artificial intelligence, group collateral, and community distribution. It offers an innovative credit solution to micro-SMBs that have been excluded from traditional lending methods, using AI to drive the process.
# Generated Description:
# Tasks/Jobs: Credit scoring, Loan processing, Risk assessment, Debt collection
# Industry: Microfinance
# People Using Tool: Small businesses, Entrepreneurs
#
#
#
# Organization Name: Earthian AI
# Generated Description: Earthian AI is a fintech firm that offers an AI-powered platform designed to help financial institutions manage the risks and opportunities associated with the $10 trillion sustainable transition. The platform provides comprehensive, high-resolution sustainability-focused financial and regulatory data, enabling effective green financing decisions in areas such as insurance, loan issuance, and investment.
# Generated Description:
# Tasks/Jobs: Risk assessment, Data analysis, Green financing decisions, Regulatory compliance
# Industry: Fintech
# People Using Tool: Financial institutions, Investors
#
#
#
# Organization Name: Porfin
# Generated Description: Porfin is a fintech company that leverages artificial intelligence to streamline and enhance financial services. It aims to simplify complex financial processes, making them more accessible and efficient for users.
# Generated Description:
# Tasks/Jobs: Financial analysis, Investment recommendations, Loan applications, Fraud detection
# Industry: Fintech
# People Using Tool: Consumers, Businesses
#
#
#
# ************************
#
#
# Processing 5:
# ************************
#
# Organization Name: Smartsistant
# Generated Description: Smartsistant is a SaaS platform that leverages artificial intelligence to provide virtual assistant services, streamlining tasks and improving productivity. It offers personalized assistance for various tasks, making it an ideal solution for individuals and businesses seeking to optimize their time and efficiency.
# Generated Description:
# Tasks/Jobs: Scheduling, Email management, Task prioritization, Research and information gathering
# Industry: Virtual assistance
# People Using Tool: Professionals, Entrepreneurs
#
#
#
# Organization Name: Emilio
# Generated Description: Emilio is an AI-driven email management tool that streamlines and automates email tasks, saving users significant time by prioritizing important emails, summarizing messages, and drafting responses in the user's tone. Seamlessly integrating with Gmail, Emilio operates in the background, helping users to manage their inbox more efficiently and reduce email overload.
# Generated Description:
# Tasks/Jobs: Email prioritization, Email summarization, Email response drafting, Inbox management
# Industry: Email management
# People Using Tool: Gmail users, Everyone
#
#
#
# Organization Name: Thruday
# Generated Description: Thruday is an AI-powered planner specifically designed to support individuals with Autism, ADHD, and ADD, as well as their caregivers, by providing structured routines and tools to reduce stress and meltdown frequency. As a SaaS mobile and web app, Thruday aims to enhance daily functioning and lower stress levels for those with neurodiverse conditions, while also assisting family members and caregivers in planning and managing day-to-day activities.
# Generated Description:
# Tasks/Jobs:  Routine management, Task scheduling, Stress reduction, Communication tools
# Industry:  Neurodiversity support
# People Using Tool:  Individuals with Autism, ADHD, ADD, Caregivers
#
#
#
# Organization Name: MULTI·ON
# Generated Description: MULTI·ON is an AI-powered personal agent designed to streamline and enhance various aspects of your life, acting as a virtual copilot. It utilizes advanced artificial intelligence to provide personalized assistance, helping users manage their daily tasks, schedules, and overall lifestyle more efficiently.
# Generated Description:
# Tasks/Jobs: Task management, Schedule optimization, Information retrieval,  Personalized recommendations
# Industry: Personal productivity
# People Using Tool: Everyone
#
#
#
# Organization Name: Twing
# Generated Description: Twing is a digital platform that consolidates data from various work applications into a single, prioritized view, streamlining your workflow and enhancing productivity. Utilizing AI, Twing helps you focus on critical tasks, meet deadlines, and filter out unnecessary distractions, enabling you to perform your best work.
# Generated Description:
# Tasks/Jobs: Task Prioritization, Workflow Management, Time Management, Productivity Enhancement
# Industry: Productivity and Workflow
# People Using Tool: Everyone, Professionals, Workers
#
#
#
# Organization Name: four40
# Generated Description: four40 is an AI-powered platform designed to streamline work processes for knowledge workers by managing tasks such as calendar scheduling, notifications prioritization, project tracking, data analysis, and internal company search. The platform integrates seamlessly with popular collaboration tools like Slack, Teams, Gmail, and Notion, enabling teams to enhance their productivity and unlock their company's potential.
# Generated Description:
# Tasks/Jobs: Calendar scheduling, Notifications prioritization, Project tracking, Data analysis
# Industry: Productivity & Workflow Automation
# People Using Tool: Knowledge Workers, Teams
#
#
#
# ************************
#
#
# Processing 6:
# ************************
#
# Organization Name: Soar
# Generated Description: Soar is a comprehensive web platform designed to simplify travel planning by allowing users to create, share, and monetize their own itineraries, as well as book activities and dining experiences. It serves as a single platform for all travel needs, offering inspiration from other users' plans and streamlining the booking process.
# Generated Description:
# Tasks/Jobs: Itinerary creation, Trip planning, Activity booking, Dining reservation
# Industry: Travel planning
# People Using Tool: Travelers, Tourists
#
#
#
# Organization Name: TripTap
# Generated Description: TripTap is an AI-powered travel platform that revolutionizes trip planning by providing personalized, tailor-made itineraries based on user interests. The platform simplifies the travel planning process, allowing users to explore a variety of destinations and experiences more efficiently and enjoyably.
# Generated Description:
# Tasks/Jobs: Itinerary planning, Destination research, Booking recommendations, Travel recommendations
# Industry: Travel planning
# People Using Tool: Travelers, Tourists
#
#
#
# Organization Name: ReiseGenie
# Generated Description: ReiseGenie is an AI-powered travel assistant tool that specializes in finding the best holiday deals tailored to user's preferences, destination, and travel period. With its proprietary algorithm, it not only uncovers cheaper deals than traditional booking channels but also significantly reduces the time and effort required for holiday planning.
# Generated Description:
# Tasks/Jobs:  Holiday planning, Deal finding, Flight and accommodation booking, Itinerary generation
# Industry: Travel
# People Using Tool: Travelers, Holidaymakers
#
#
#
# Organization Name: TRAIVL AG
# Generated Description: TRAIVL AG is a Swiss digital travel agency that leverages artificial intelligence to curate personalized travel experiences, handling everything from accommodation and transportation bookings to arranging unique local tours. The company emphasizes stress-free travel, connecting clients with trusted local operators for authentic experiences, while ensuring competitive pricing and secure booking systems.
# Generated Description:
# Tasks/Jobs: Travel planning, Booking, Itinerary creation, Customer service
# Industry: Travel
# People Using Tool: Travelers, Travel agents
#
#
#
# Organization Name: WayWay
# Generated Description: WayWay is an AI-powered mobile application designed to streamline trip planning by offering personalized destination suggestions, price tracking, weather updates, group planning features, and event discovery. It serves as a comprehensive travel companion, revolutionizing the way trips are planned and experienced.
# Generated Description:
# Tasks/Jobs: Destination suggestions, Price tracking, Group planning, Event discovery
# Industry: Travel planning
# People Using Tool: Travelers, Tourists
#
#
#
# Organization Name: Trundle Technology LLP
# Generated Description: Trundle Technology LLP offers a travel web and mobile app designed to provide personalized travel experiences, including custom itineraries, restaurant recommendations, and assistance from travel ambassadors. The platform also features a unique pay-as-you-go system and the ability to share itineraries with friends or follow those of travel influencers.
# Generated Description:
# Tasks/Jobs: Itinerary creation, Restaurant recommendation, Travel planning, Trip booking
# Industry: Travel
# People Using Tool: Travelers, Tourists
#
#
#
# Organization Name: Holiwise
# Generated Description: Holiwise is an AI-powered travel platform that provides personalized destination and itinerary recommendations based on user preferences. Analyzing thousands of data sources, it offers a wide variety of travel options, catering to diverse holiday types and is trusted by travelers in over 100 countries.
# Generated Description:
# Tasks/Jobs: Destination recommendation, Itinerary planning, Trip booking, Travel planning
# Industry: Travel
# People Using Tool: Travelers, Tourists
#
#
#
# Organization Name: Voyager Global Ltd.
# Generated Description: Voyager Global Ltd. offers a comprehensive travel application that integrates navigation, social media, booking, emergency services, and an AI assistant to revolutionize the travel experience. Utilizing advanced AI and AR technologies, Voyager is pioneering the future of travel, providing a seamless, interactive, and safe journey for users.
# Generated Description:
# Tasks/Jobs: Navigation, Social Media Integration, Booking, Emergency Services
# Industry: Travel
# People Using Tool: Travelers, Tourists
#
#
#
# ************************
#
#
# Processing 7:
# ************************
#
# Organization Name: CREcentric
# Generated Description: CREcentric is an AI-driven SaaS platform designed to simplify and optimize the entire process of commercial real estate investment management. It offers a comprehensive digital transformation solution by automating manual tasks, centralizing workflows, unifying crucial data, and providing real-time, actionable insights for effective decision-making in the commercial real estate sector.
# Generated Description:
# Tasks/Jobs:  Lease administration, Property management, Reporting, Investment analysis
# Industry:  Commercial Real Estate
# People Using Tool:  Property managers, Investors
#
#
#
# Organization Name: Supas
# Generated Description: Supas is an investment platform that specializes in supermarket-anchored properties, providing investors with crucial insights to make informed decisions. Utilizing a deep learning valuation model, Supas identifies potential value-add opportunities, enabling predictable and strategic investments in the supermarket property sector.
# Generated Description:
# Tasks/Jobs: Property valuation, Investment analysis, Value-add opportunity identification, Market trend forecasting
# Industry: Real Estate Investment
# People Using Tool: Investors, Property Developers
#
#
#
# Organization Name: Perisphere
# Generated Description: Perisphere is revolutionizing the residential real estate sector with its AI-powered super-app, Relm, designed to address the challenges of high costs, inefficiencies, and lack of transparency in traditional brokerages. The platform offers a comprehensive suite of tools, including AI-driven home valuations and intuitive natural language search capabilities, empowering buyers and sellers to effectively represent themselves in the real estate market.
# Generated Description:
# Tasks/Jobs: Home valuations, Property search, Negotiation support, Transaction management
# Industry: Real Estate
# People Using Tool: Home buyers, Home sellers
#
#
#
# Organization Name: Drodat
# Generated Description: Drodat is a pioneering insurtech platform that utilizes high-resolution aerial imagery and AI analytics to revolutionize property insurance by providing precise damage and risk assessments. The platform's automated drones and AI visual intelligence capture and analyze geotagged images of properties, aiding in fraud prevention, optimizing underwriting, pricing, and risk management in the property insurance sector.
# Generated Description:
# Tasks/Jobs: Damage assessment, Risk assessment, Fraud detection, Property valuation
# Industry: Property insurance
# People Using Tool: Insurers, Underwriters
#
#
#
# Organization Name: Supas
# Generated Description: Supas is an investment platform that specializes in supermarket-anchored properties, providing investors with crucial insights to make informed decisions. Utilizing a deep learning valuation model, Supas identifies potential value-add opportunities, enabling predictable and strategic investments in the supermarket property sector.
# Generated Description:
# Tasks/Jobs: Property valuation, Investment analysis, Market research, Risk assessment
# Industry: Real Estate
# People Using Tool: Investors, Real estate professionals
#
#
#
# Organization Name: OM Live Real Estate
# Generated Description: OM Live Real Estate is a vertically integrated company that specializes in rebuilding small asset portfolios using expert knowledge in alternative and rental residential Real Estate 3.0. They offer scalable investment opportunities in high-performing niche assets, all while maintaining a low cost structure, and aim to build resilient, value-added portfolios for a new living experience.
# Generated Description:
# Tasks/Jobs: Portfolio management, Property acquisition, Investment analysis, Rental management
# Industry: Real Estate
# People Using Tool: Investors, Property Managers
#
#
#
# Organization Name: VDiX AI
# Generated Description: VDiX AI is a software developer specializing in AI-powered real estate due diligence solutions, offering a comprehensive suite of tools and applications to automate the entire process. Additionally, VDiX AI provides an online professional development program for real estate and mortgage professionals, featuring self-paced courses designed by industry experts.
# Generated Description:
# Tasks/Jobs: Property Valuation, Title Search, Legal Document Review, Risk Assessment
# Industry: Real Estate
# People Using Tool: Real Estate Agents, Mortgage Professionals
#
#
#
# Organization Name: Brixely
# Generated Description: Brixely is a SaaS platform that leverages artificial intelligence to provide comprehensive real estate property analysis. It offers data-driven insights to help users make informed investment decisions in the real estate market.
# Generated Description:
# Tasks/Jobs: Property valuation, Market analysis, Investment strategy, Risk assessment
# Industry: Real Estate
# People Using Tool: Investors, Real estate agents
#
#
#
# Organization Name: Arbit
# Generated Description: Arbit is an AI-driven marketplace designed for the resale of sneakers, providing users with optimal buying and selling times and prices. The platform leverages artificial intelligence to ensure users get the best deals and maximize their profits in the sneaker resale market.
# Generated Description:
# Tasks/Jobs: Sneaker pricing, Sneaker resale, Market analysis, Investment recommendations
# Industry: Sneaker Resale
# People Using Tool: Sneakerheads, Resellers
#
#
#
# ************************
#
#
# Processing 8:
# ************************
#
# Organization Name: ChatGPT Nederlands - GPTNederlands.com
# Generated Description: ChatGPT Nederlands - GPTNederlands.com is a leading platform for interacting with ChatGPT in Dutch, leveraging the power of AI to enhance human interactions. It offers reliable and positive AI-driven conversations for Dutch-speaking audiences, aiming to make their lives easier, more productive, and enjoyable.
# Generated Description:
# Tasks/Jobs: Language translation, Content generation, Customer service, Information retrieval
# Industry: Language AI
# People Using Tool: Dutch speakers, Anyone
#
#
#
# Organization Name: Latimer.AI
# Generated Description: Latimer.AI is an innovative platform that utilizes a large language model, specifically trained to incorporate diverse histories and inclusive voices for Black and Brown communities. It aims to counteract the bias, inaccuracy, and erasure of Black cultural data in AI, providing a more equitable and inclusive platform.
# Generated Description:
# Tasks/Jobs: Text generation, Content creation, Language translation, Research assistance
# Industry: AI language model
# People Using Tool: Writers, Researchers, Educators, Students
#
#
#
# Organization Name: OneGenerative AI
# Generated Description: OneGenerative AI is a Singapore-based company specializing in the development, customization, integration, and maintenance of sophisticated AI-powered language models. Their expertise lies in creating large language models tailored to meet specific business needs, providing a competitive edge in the era of artificial intelligence.
# Generated Description:
# Tasks/Jobs: Language model development, Customization, Integration, Maintenance
# Industry: AI Solutions
# People Using Tool: Businesses, Organizations
#
#
#
# Organization Name: ChatGPT Online AI
# Generated Description: ChatGPT Online AI is a sophisticated language model developed by OpenAI, capable of generating human-like text responses to a wide range of prompts. This AI chatbot is designed to assist users in answering questions, engaging in diverse conversations, creating unique content, and boosting overall productivity, all accessible for free on their website.
# Generated Description:
# Tasks/Jobs: Content creation, Translation, Summarization, Question answering
# Industry: Conversational AI
# People Using Tool: Everyone, Students, Professionals
#
#
#
# Organization Name: Axar AI
# Generated Description: Axar AI is a cutting-edge platform that leverages Language Model (LLM) technology to provide a comprehensive and robust Natural Language Processing (NLP) API repository. It offers advanced AI solutions for businesses and developers, enabling them to integrate and utilize NLP capabilities in their applications and services.
# Generated Description:
# Tasks/Jobs:  Natural Language Understanding, Text Summarization, Sentiment Analysis, Language Translation
# Industry:  AI Development
# People Using Tool: Developers, Businesses
#
#
#
# ************************
#
#
# Processing 9:
# ************************
#
# Organization Name: Tail and Skew
# Generated Description: Tail and Skew is a technology company that specializes in developing AI agents designed to automate a variety of tasks, enhancing efficiency and productivity. Their advanced AI solutions are tailored to meet the specific needs of businesses, helping them streamline operations and reduce manual workload.
# Generated Description:
# Tasks/Jobs: Data analysis, Task automation, Workflow optimization, Customer service
# Industry: Business automation
# People Using Tool: Business owners, Employees
#
#
#
# Organization Name: Supersight
# Generated Description: Supersight offers a privacy-preserving mobile application that utilizes artificial intelligence to count people in a given space, providing an efficient solution for real-world business process automation. Primarily serving customers in Finland and France, this high-tech product ensures total privacy while promoting a productive environment.
# Generated Description:
# Tasks/Jobs: People Counting, Occupancy monitoring, Data Analysis, Process Automation
# Industry: Retail analytics
# People Using Tool: Businesses, Retailers
#
#
#
# Organization Name: Fincortex.ai
# Generated Description: Fincortex.ai is an AI-powered platform that enhances business productivity by providing real-time insights, intelligence, and automated workflows through a conversational interface named Leo. Users can interact with Leo using voice commands to ask questions or give complex instructions, unlocking endless possibilities for business growth and efficiency.
# Generated Description:
# Tasks/Jobs: Data analysis, Process automation, Workflow management, Business intelligence
# Industry: Business automation
# People Using Tool: Business owners, Managers, Employees
#
#
#
# Organization Name: mimic
# Generated Description: Mimic Robotics offers innovative solutions to labor shortages by creating and implementing robots that integrate effortlessly into human work environments. Their advanced AI model, built on a scalable foundation, allows for highly skilled robotic manipulation, learned directly from human data, and they specialize in constructing versatile humanoid hands for universal robotic manipulation.
# Generated Description:
# Tasks/Jobs:  Assembly tasks,  Repetitive tasks,  Manufacturing operations,  Warehousing logistics
# Industry: Manufacturing
# People Using Tool: Workers,  Businesses
#
#
#
# Organization Name: San Justo Research Corporation
# Generated Description: San Justo Research Corporation specializes in AI automation, providing solutions that streamline and optimize business processes. Their product leverages artificial intelligence to automate repetitive tasks, enhancing efficiency and productivity across various industries.
# Generated Description:
# Tasks/Jobs: Data entry, Data analysis, Report generation, Process automation
# Industry: Business automation
# People Using Tool: Employees, Businesses
#
#
#
# Organization Name: Horizon AI
# Generated Description: Horizon AI is a platform that utilizes artificial intelligence to identify and rectify process inefficiencies, repetitive tasks, and misaligned areas within companies. By creating a neural map of the organization, it visually pinpoints areas for improvement and calculates the impact and relationships between processes, KPIs, and people, enabling businesses to streamline their operations faster and more cost-effectively than traditional methods.
# Generated Description:
# Tasks/Jobs: Process optimization, Task automation, Data analysis, Performance evaluation
# Industry: Business Operations
# People Using Tool: Business leaders, Managers
#
#
#
# Organization Name: DeltaGen
# Generated Description: DeltaGen is an AI platform designed to empower employees by eliminating the need for coding, making AI accessible and powerful for all users. The platform offers an enterprise solution with LinkedIn integration, role-specific workflows, and multi-model capabilities, all while ensuring top-tier data privacy.
# Generated Description:
# Tasks/Jobs: Data analysis, Automation, Workflow optimization, Business intelligence
# Industry: Enterprise AI
# People Using Tool: Employees, Business users
#
#
#
# Organization Name: Sage
# Generated Description: Sage, found at www.wizzysage.com, is an AI development company specializing in creating accessible AI personal assistants. Their mission is to democratize AI technology, ensuring it is available to all, regardless of their technical knowledge, financial resources, or hardware capabilities.
# Generated Description:
# Tasks/Jobs:  Task automation, Scheduling, Data analysis, Information retrieval
# Industry: AI personal assistants
# People Using Tool: Everyone
#
#
#
# ************************

# %%
sample_df
# Out:
#                      organization name num employees founded date  \
# 0    Semilla Co. (Flou / Seed Academy)          1-10   2023-02-01
# 1                         NaijaBuzz300          1-10   2024-03-03
# 2                           SONOTELLER          1-10   2023-02-01
# 3                               AISong          1-10   2024-03-01
# 4                              SoundAI          1-10   2023-04-17
# ..                                 ...           ...          ...
# 463                            Regimen          1-10   2023-10-06
# 464                       Dropofwisdom          1-10   2023-05-15
# 465        Supercomputing Intelligence          1-10   2024-02-23
# 466                        Localportal          1-10   2024-04-07
# 467                            Thunder          1-10   2024-02-02
#
#                                            description  \
# 0    Semilla Co. ("Seed") is building the future of...
# 1    NaijaBuzz300's AI content tools helps artists ...
# 2    SONOTELLER is an AI engine capable of 'listeni...
# 3    AISong.Fun is a platform that uses the AI to p...
# 4                                                    —
# ..                                                 ...
# 463  Regimen helps ambitious professionals apply th...
# 464                                                  —
# 465  Supercomputing Intelligence offers intelligent...
# 466  Localportal is the first pseudo operating syst...
# 467  Thunder is a Cloud computing to democratize ac...
#
#                                             industries  \
# 0    Consumer Software, Content Creators, EdTech, L...
# 1                                            Marketing
# 2    Artificial Intelligence (AI), Music, SaaS, Sof...
# 3                  Artificial Intelligence (AI), Music
# 4    Artificial Intelligence (AI), Information Tech...
# ..                                                 ...
# 463                                                  —
# 464                                                  —
# 465  Artificial Intelligence (AI), Information Tech...
# 466  Artificial Intelligence (AI), Cloud Computing,...
# 467  Artificial Intelligence (AI), Cloud Computing,...
#
#                        headquarters location  \
# 0    Fort Lauderdale, Florida, United States
# 1                    Kaduna, Kaduna, Nigeria
# 2                      Madrid, Madrid, Spain
# 3                                          —
# 4         Dubai, Dubai, United Arab Emirates
# ..                                       ...
# 463                                        —
# 464                                        —
# 465                   Kunming, Yunnan, China
# 466                                        —
# 467           Lewes, Delaware, United States
#
#                                          description.1    cb rank postal code  \
# 0    Building the future of the music and entertain...     43,978       33316
# 1    Helping artists grow & scale up their music ca...          —      902101
# 2                    SaaS AI music and lyrics analysis    240,839       28005
# 3               Free AI Song, Music & Lyrics Generator          —           —
# 4    is an artificial intelligence service that is ...    330,604           —
# ..                                                 ...        ...         ...
# 463     Ed-tech AI platform, Consumer App, Marketplace          —           —
# 464  Providing personal growth and self-help conten...  3,061,012           —
# 465  Supercomputing Intelligence offers intelligent...          —           —
# 466  Localportal revolutionizes access to remote co...          —           —
# 467  Thunder is a Cloud computing to democratize ac...          —       19958
#
#                                    headquarters region  ...  \
# 0          Greater Miami Area, East Coast, Southern US  ...
# 1               Europe, Middle East, and Africa (EMEA)  ...
# 2    European Union (EU), Europe, Middle East, and ...  ...
# 3                                                    —  ...
# 4    Europe, Middle East, and Africa (EMEA), Gulf C...  ...
# ..                                                 ...  ...
# 463                                                  —  ...
# 464                                                  —  ...
# 465                                Asia-Pacific (APAC)  ...
# 466                                                  —  ...
# 467                            East Coast, Southern US  ...
#
#                                       openai_embedding  \
# 0    [-0.024784477427601814, -0.007316365372389555,...
# 1    [-0.018274663016200066, -0.018083689734339714,...
# 2    [-0.002750448416918516, -0.04076295718550682, ...
# 3    [-0.013055133633315563, -0.007749421522021294,...
# 4    [-0.021745074540376663, -0.02082068845629692, ...
# ..                                                 ...
# 463  [-0.055983927100896835, 0.017206678166985512, ...
# 464  [-0.03574720397591591, 0.014340822584927082, -...
# 465  [-0.005478728096932173, 0.017174074426293373, ...
# 466  [-0.04504650458693504, -0.003858223557472229, ...
# 467  [-0.05050375312566757, -0.027182575315237045, ...
#
#                                Company  \
# 0    Semilla Co. (Flou / Seed Academy)
# 1                         NaijaBuzz300
# 2                           SONOTELLER
# 3                               AISong
# 4                              SoundAI
# ..                                 ...
# 463                            Regimen
# 464                       Dropofwisdom
# 465        Supercomputing Intelligence
# 466                        Localportal
# 467                            Thunder
#
#                                     parsed_description  \
# 0    \nTasks/Jobs: Music Business Management, Marke...
# 1    \nTasks/Jobs: Music production, Songwriting, M...
# 2    \nTasks/Jobs: Music analysis, Playlist creatio...
# 3    \nTasks/Jobs: Song composition, Music producti...
# 4    \nTasks/Jobs: Music generation, Sound design, ...
# ..                                                 ...
# 463  \nTasks/Jobs: Habit tracking, Goal setting, Pr...
# 464  \nTasks/Jobs: Content Summarization, Informati...
# 465  \nTasks/Jobs: Model optimization, Algorithm de...
# 466  \nTasks/Jobs: Remote access management, GPU re...
# 467  \nTasks/Jobs: GPU resource allocation, Access ...
#
#                                             Tasks/Jobs              Industry  \
# 0    Music Business Management, Marketing, Business...        Music Industry
# 1    Music production, Songwriting, Marketing, Prom...                 Music
# 2    Music analysis, Playlist creation, Music disco...      Music technology
# 3    Song composition, Music production, Lyrics gen...        Music creation
# 4    Music generation, Sound design, Audio mixing, ...     Music production
# ..                                                 ...                   ...
# 463  Habit tracking, Goal setting, Productivity opt...  Personal Development
# 464  Content Summarization, Information Organizatio...       Personal Growth
# 465  Model optimization, Algorithm development, AI ...           AI Services
# 466  Remote access management, GPU resource allocat...      Remote computing
# 467  GPU resource allocation, Access to unused GPUs...       Cloud Computing
#
#                              People Using Tool  \
# 0               Music Creators, Entrepreneurs
# 1                Musicians, Labels, Promoters
# 2      Music enthusiasts, Music professionals
# 3                 Artists, Creators, Musicians
# 4                        Musicians, Producers
# ..                                         ...
# 463      Professionals, Ambitious individuals
# 464                      Everyone, Individuals
# 465         Government agencies, Corporations
# 466  Developers, Researchers, Data scientists
# 467   Developers, Researchers, Data Scientists
#
#                                openai_embedding_entire cluster_label  \
# 0    [-0.004338318016380072, -0.021966977044939995,...            33
# 1    [-0.006098032463341951, -0.021988358348608017,...            33
# 2    [-0.012888072989881039, -0.0282617025077343, -...            33
# 3    [0.005447404459118843, -0.03911559656262398, -...            33
# 4    [-0.0040488275699317455, -0.010498875752091408...            33
# ..                                                 ...           ...
# 463  [-0.016550462692975998, 0.014065012335777283, ...            39
# 464  [-0.006916402373462915, -0.004029091913253069,...            39
# 465  [-0.024272453039884567, -0.02577846683561802, ...            83
# 466  [-0.03364584222435951, 0.0008783882367424667, ...            83
# 467  [-0.024437395855784416, -0.010938230901956558,...            83
#
#                   generated_cluster_label new_cluster_index
# 0        Music and Audio Production Tools                37
# 1        Music and Audio Production Tools                37
# 2        Music and Audio Production Tools                37
# 3        Music and Audio Production Tools                37
# 4        Music and Audio Production Tools                37
# ..                                    ...               ...
# 463       Personal Growth and Development                61
# 464       Personal Growth and Development                61
# 465  High-Performance Computing Solutions                62
# 466  High-Performance Computing Solutions                62
# 467  High-Performance Computing Solutions                62
#
# [468 rows x 35 columns]

# %%
prompt = f"""
Your role is to generate a label name for the following combined descriptions. Make it simple and understandable. Make it specific to the industry. Do not use vague words like comprehensive. Do not use the word AI-Powered.
EXAMPLE BELOW
_________________
Organization Name: Askflow AI
Generated Description: Product: Product recommendation platform, E-commerce suite solution, Personalized product finders
Target Customers/Industries: E-commerce businesses, Brands and merchants

Organization Name: Neuron Expert
Generated Description: Product: Expert Network Platform, AI Content Builder, Digital Workers, Message Center
Target Customers/Industries: businesses looking to increase sales, social media managers, customer service departments

Organization Name: Consumable AI
Generated Description: Product: SEO performance analysis, Automated SEO content publishing and management
Target Customers/Industries: Online businesses, E-commerce platforms, Digital marketing agencies

Organization Name: WNE3
Generated Description: Product: E-commerce platform, Generative AI, ONDC
Target Customers/Industries: Online shoppers, Retail industry

Organization Name: Anarix
Generated Description: Product: Marketplace Optimization Platform, Advertising Management, Amazon Marketing Cloud (AMC), Review Sentiment Analysis, Listing Optimization, Comprehensive Reporting Capabilities, Customizable Visualization Tools
Target Customers/Industries: Agencies, Brands, Online Sellers, E-commerce Businesses

Organization Name: Plugin Support
Generated Description: Product: Customer Support Services, Plugin Support, Real-time Interactions
Target Customers/Industries: Software companies, Tech startups, E-commerce businesses

Organization Name: InboxIgniter
Generated Description: Product: Email Warmup Tool, Outreach Campaign Management
Target Customers/Industries: Email Marketers, Sales Teams, PR Agencies

Label Name: E-commerce and Sales
_________________
Now, your turn:
Descriptions: $descriptions
Label name:
"""

# %%
class chatGPT():
    def __init__(self):
        self.client = OpenAI(api_key=OPENAI_API_KEY)
        
    def ask(self, q):
        stream = self.client.chat.completions.create(
            model="gpt-4",
            messages=[{"role": "user", "content": q}],
            stream=True,
            temperature=0
        )
        response = ""
        for chunk in stream:
            if chunk.choices[0].delta.content is not None:
                response += chunk.choices[0].delta.content

        self.response = response
        return response

    def get_embedding(self,text, model="text-embedding-3-large"):
       text = text.replace("\n", " ")
       return self.client.embeddings.create(input = [text], model=model).data[0].embedding

x = chatGPT()

# %%
cluster_labels = {}

for index, label in enumerate(sample_df['cluster_label'].unique()):
    print(f"Processing {index}")
    descriptions = list(sample_df[sample_df['cluster_label'] == label]['parsed_description'])
    descriptions = " ".join(descriptions)
    while True:
        try:
            p1 = prompt.replace("$descriptions",descriptions)
            text_label = x.ask(p1)
            cluster_labels[label] = text_label
            print(text_label)
            break
        except Exception as e:
            print(f"Error processing: {e}")
            time.sleep(20)



sample_df['generated_cluster_label'] = sample_df['cluster_label'].map(cluster_labels)
# Out:
# Processing 0
# Fashion and Design
# Processing 1
# Music and Audio Production Tools
# Processing 2
# AI Toolset for Developers
# Processing 3
# Construction and Workflow Automation
# Processing 4
# Web Development and AI tools
# Processing 5
# AI Research and Development
# Processing 6
# Tech and Blockchain News
# Processing 7
# HR and Recruitment Automation
# Processing 8
# Retail Supply Chain Management
# Processing 9
# Advanced Cybersecurity Solutions
# Processing 10
# Mobile and Software Development Technologies
# Processing 11
# Educational Technologies and Learning Platforms
# Processing 12
# Healthcare Data Management Systems
# Processing 13
# Logistics and Transportation Solutions
# Processing 14
# Mobile and Software Development Technologies
# Processing 15
# Creative Business Tools
# Processing 16
# Restaurant and Hospitality Services
# Processing 17
# Regulatory Compliance and Risk Management
# Processing 18
# Gamification in Education
# Processing 19
# Marketing Data Analytics
# Processing 20
# AI Research and Development
# Processing 21
# Personalized Wellness Programs
# Processing 22
# Customer Service Innovations
# Processing 23
# AI-Driven Business Strategies
# Processing 24
# E-commerce and Retail Strategies
# Processing 25
# AI Systems Development
# Processing 26
# Creative Business Tools
# Processing 27
# Social Media and Marketing Strategies
# Processing 28
# Customer Data Analysis
# Processing 29
# Automated Business Systems
# Processing 30
# Automated Business Systems
# Processing 31
# AI Systems Development
# Processing 32
# Automated Business Systems
# Processing 33
# Career Development Tools
# Processing 34
# Veterinary and Pet Care Technologies
# Processing 35
# AI Systems Development
# Processing 36
# Legal and Technological Automation
# Processing 37
# Data Insights and Analytics
# Processing 38
# Social Media and Digital Insights
#
# Assistive Technology and Personalized Assistance
#
# Memory Preservation and Story Creation Tools
#
# Memoir Creation and Media Integration Tools
# Processing 39
# Travel Booking and Planning Systems
# Processing 40
# AI Educational Resources
# Processing 41
# Mobile and Software Development Technologies
# Processing 42
# Social Media and Digital Insights
# Processing 43
# Advanced Cybersecurity Solutions
# Processing 44
# AI Research and Development
# Processing 45
# Real Estate Investment Analysis
# Processing 46
# Logistics and Transportation Solutions
# Processing 47
# Web Development and AI tools
# Processing 48
# Healthcare Data Management Systems
# Processing 49
# Financial Management Systems
# Processing 50
# AI Toolset for Developers
# Processing 51
# Data Management and Quality Control
# Processing 52
# No-Code AI Platforms
# Processing 53
# Healthcare Workflow Optimization
# Processing 54
# Automated Business Systems
# Processing 55
# Venture Capital and Financing
# Processing 56
# Sustainability and Non-Profit Solutions
# Processing 57
# Wellness and Sleep Health
# Processing 58
# Industrial Sales Automation
# Processing 59
# Tax and Accounting Automation
# Processing 60
# Sales and Marketing Outreach
# Processing 61
# Image Enhancement Solutions
# Processing 62
# Creative Content and Media Tools
# Processing 63
# HR and Recruitment Automation
# Processing 64
# AI Research and Development
# Processing 65
# Home and Interior Design
# Processing 66
# Venture Capital and Financing
# Processing 67
# Restaurant and Hospitality Services
# Processing 68
# Financial Management Systems
# Processing 69
# Mental Health and Therapy
# Processing 70
# Market and Business Strategy
# Processing 71
# Financial Management Systems
# Processing 72
# Animation and Visual Effects Tools
# Processing 73
# Personalized Wellness Programs
# Processing 74
# Financial Management Systems
# Processing 75
# Social Media and Digital Insights
# Processing 76
# Educational Technologies and Learning Platforms
# Processing 77
# Technical Writing and Proposals
# Processing 78
# Biotechnological Research
# Processing 79
# Project and Team Management
# Processing 80
# E-commerce Management
# Processing 81
# Industrial Sourcing Solutions
# Processing 82
# Decentralized Tech and Identity
# Processing 83
# AI Systems Development
# Processing 84
# Music and Audio Production Tools
# Processing 85
# Regulatory Compliance and Risk Management
# Processing 86
# Client Management in Legal Services
# Processing 87
# Automated Business Systems
# Processing 88
# Animation and Visual Effects Tools
# Processing 89
# Social and Event Planning Tools
# Processing 90
# Document Management Automation
# Processing 91
# Development Tools Automation
# Processing 92
# Creative Business Tools
# Processing 93
# Solutions for Industrial Automation
# Processing 94
# Language and Speech Learning
# Processing 95
# Insurance Management Services
# Processing 96
# Personal Growth and Development
# Processing 97
# Sales and Marketing Outreach
# Processing 98
# High-Performance Computing Solutions
# Processing 99
# Data Management and Quality Control

# %%
# sample_df['generated_cluster_label'] = sample_df['generated_cluster_label'].apply(lambda x: str(x).replace("Label Name: ","").replace("Label name:","").replace("\n","").replace("**","").strip())
# sample_df.generated_cluster_label = sample_df.generated_cluster_label.apply(lambda x: x.replace("AI-Powered ",""))

sample_df.to_csv("./output/sample_df_with_generated_labels2.csv")

# %%
# import ast
# sample_df = pd.read_csv("./output/sample_df_with_generated_labels2.csv")
# sample_df['openai_embedding_entire'] = sample_df['openai_embedding_entire'].apply(ast.literal_eval)
# sample_df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                       organization name  \
# 0             0       22341                                  Fytted
# 1             1       18944       Semilla Co. (Flou / Seed Academy)
# 2             2       19082  ChatGPT Nederlands - GPTNederlands.com
# 3             3       17578                               Pelles.ai
# 4             4       22004                              SimLoop AI
#
#   num employees founded date  \
# 0          1-10   2024-03-01
# 1          1-10   2023-02-01
# 2          1-10   2023-02-03
# 3          1-10   2023-01-01
# 4          1-10   2024-01-02
#
#                                          description  \
# 0                                                  —
# 1  Semilla Co. ("Seed") is building the future of...
# 2  GPTNederlands.com is dé toonaangevende bestemm...
# 3  Pelles.ai transforms the way MEP (mechanical, ...
# 4  SimLoop allows companies run experiments with ...
#
#                                           industries  \
# 0                                                  —
# 1  Consumer Software, Content Creators, EdTech, L...
# 2                                                  —
# 3                       Construction, SaaS, Software
# 4  Analytics, Artificial Intelligence (AI), Gener...
#
#                      headquarters location  \
# 0        Venice, California, United States
# 1  Fort Lauderdale, Florida, United States
# 2                                        —
# 3        New York, New York, United States
# 4                                        —
#
#                                        description.1    cb rank  ...  \
# 0                      SaaS, Mobile App, AI, Fashion          —  ...
# 1  Building the future of the music and entertain...     43,978  ...
# 2  GPTNederlands.com is dé toonaangevende bestemm...  1,885,621  ...
# 3                           Auto-Generate MEP Design     62,705  ...
# 4   User testing platform powered by simulated users    360,457  ...
#
#                                generated_description  \
# 0  Fytted is a SaaS and mobile app that leverages...
# 1  Semilla Co., through its two products - Seed A...
# 2  ChatGPT Nederlands - GPTNederlands.com is a le...
# 3  Pelles.ai is an innovative platform that utili...
# 4  SimLoop AI is an innovative platform that enab...
#
#                                     openai_embedding  \
# 0  [-0.026910386979579926, 0.00429302453994751, -...
# 1  [-0.024784477427601814, -0.007316365372389555,...
# 2  [-0.04201542213559151, -0.02567780390381813, -...
# 3  [-0.026539845392107964, -0.014325139112770557,...
# 4  [-0.04071200266480446, -0.009665796533226967, ...
#
#                                   Company  \
# 0                                  Fytted
# 1       Semilla Co. (Flou / Seed Academy)
# 2  ChatGPT Nederlands - GPTNederlands.com
# 3                               Pelles.ai
# 4                              SimLoop AI
#
#                                   parsed_description  \
# 0  \nTasks/Jobs: Fashion recommendations, Virtual...
# 1  \nTasks/Jobs: Music Business Management, Marke...
# 2  \nTasks/Jobs: Language translation, Content ge...
# 3  \nTasks/Jobs: MEP plan generation, Clash detec...
# 4  \nTasks/Jobs: Website testing, User interactio...
#
#                                           Tasks/Jobs              Industry  \
# 0  Fashion recommendations, Virtual fitting, Styl...               Fashion
# 1  Music Business Management, Marketing, Business...        Music Industry
# 2  Language translation, Content generation, Cust...           Language AI
# 3  MEP plan generation, Clash detection, Design o...          Construction
# 4  Website testing, User interaction simulation, ...  Website optimization
#
#                 People Using Tool  \
# 0            Shoppers, Consumers
# 1  Music Creators, Entrepreneurs
# 2          Dutch speakers, Anyone
# 3           Architects, Engineers
# 4           Developers, Marketers
#
#                              openai_embedding_entire cluster_label  \
# 0  [-0.04178014397621155, -0.020127102732658386, ...            88
# 1  [-0.004338318016380072, -0.021966977044939995,...            33
# 2  [-0.0312783420085907, -0.01716475374996662, -0...             8
# 3  [-0.021538328379392624, -0.010536273941397667,...            17
# 4  [-0.025433985516428947, -0.021480992436408997,...            96
#
#                 generated_cluster_label
# 0                    Fashion and Design
# 1      Music and Audio Production Tools
# 2             AI Toolset for Developers
# 3  Construction and Workflow Automation
# 4          Web Development and AI tools
#
# [5 rows x 36 columns]

# %%
list(sample_df['generated_cluster_label'].unique())
# Out:
# ['Music and Audio Production Tools',
#  'AI Toolset for Developers',
#  'Construction and Workflow Automation',
#  'Web Development and AI tools',
#  'AI Research and Development',
#  'Tech and Blockchain News',
#  'HR and Recruitment Automation',
#  'Retail Supply Chain Management',
#  'Advanced Cybersecurity Solutions',
#  'Mobile and Software Development Technologies',
#  'Educational Technologies and Learning Platforms',
#  'Healthcare Data Management Systems',
#  'Creative Business Tools',
#  'Restaurant and Hospitality Services',
#  'Regulatory Compliance and Risk Management',
#  'Gamification in Education',
#  'Marketing Data Analytics',
#  'Personalized Wellness Programs',
#  'AI-Driven Business Strategies',
#  'E-commerce and Retail Strategies',
#  'AI Systems Development',
#  'Social Media and Marketing Strategies',
#  'Customer Data Analysis',
#  'Automated Business Systems',
#  'Career Development Tools',
#  'Veterinary and Pet Care Technologies',
#  'Legal and Technological Automation',
#  'Data Insights and Analytics',
#  'Social Media and Digital Insights',
#  'Travel Booking and Planning Systems',
#  'Real Estate Investment Analysis',
#  'Financial Management Systems',
#  'Data Management and Quality Control',
#  'No-Code AI Platforms',
#  'Healthcare Workflow Optimization',
#  'Venture Capital and Financing',
#  'Sustainability and Non-Profit Solutions',
#  'Wellness and Sleep Health',
#  'Industrial Sales Automation',
#  'Tax and Accounting Automation',
#  'Sales and Marketing Outreach',
#  'Image Enhancement Solutions',
#  'Creative Content and Media Tools',
#  'Home and Interior Design',
#  'Mental Health and Therapy',
#  'Market and Business Strategy',
#  'Animation and Visual Effects Tools',
#  'Technical Writing and Proposals',
#  'Biotechnological Research',
#  'Project and Team Management',
#  'E-commerce Management',
#  'Industrial Sourcing Solutions',
#  'Decentralized Tech and Identity',
#  'Client Management in Legal Services',
#  'Social and Event Planning Tools',
#  'Document Management Automation',
#  'Development Tools Automation',
#  'Solutions for Industrial Automation',
#  'Language and Speech Learning',
#  'Insurance Management Services',
#  'Personal Growth and Development',
#  'High-Performance Computing Solutions']

# %%
sorted_labels = """
Technical Writing and Proposals
Data Insights and Analytics
Market and Business Strategy
Project and Team Management
HR and Recruitment Automation
Career Development Tools
Job Search & Career Development Tools
AI Research and Development
AI Toolset for Developers
Web Development and AI tools
Development Tools Automation
AI Systems Development
No-Code AI Platforms
Advanced Cybersecurity Solutions
Data Management and Quality Control
Tech and Blockchain News
Social Media and Digital Insights
Social Media and Marketing Strategies
Marketing Data Analytics
Customer Data Analysis
Sales and Marketing Outreach
AI-Driven Business Strategies
Financial Management Systems
Tax and Accounting Automation
Automated Business Systems
E-commerce and Retail Strategies
E-commerce Management
Retail Supply Chain Management
Industrial Sourcing Solutions
Industrial Sales Automation
Solutions for Industrial Automation
Mobile and Software Development Technologies
Creative Business Tools
Image Enhancement Solutions
Creative Content and Media Tools
Animation and Visual Effects Tools
Music and Audio Production Tools
Construction and Workflow Automation
Legal and Technological Automation
Client Management in Legal Services
Regulatory Compliance and Risk Management
Document Management Automation
Healthcare Data Management Systems
Healthcare Workflow Optimization
Personalized Wellness Programs
Wellness and Sleep Health
Mental Health and Therapy
Veterinary and Pet Care Technologies
Educational Technologies and Learning Platforms
Gamification in Education
Restaurant and Hospitality Services
Hospitality and Travel Operations
Travel Booking and Planning Systems
Real Estate Investment Analysis
Home and Interior Design
Biotechnological Research
Language and Speech Learning
Decentralized Tech and Identity
Venture Capital and Financing
Sustainability and Non-Profit Solutions
Insurance Management Services
Personal Growth and Development
High-Performance Computing Solutions
Social and Event Planning Tools"""

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D  # for 3D plotting
import numpy as np
import pandas as pd

# Assuming 'sample_df' contains a column 'openai_embedding_entire' with appropriate data
embeddings = np.vstack(sample_df['openai_embedding_entire'].values)

# Apply t-SNE to the embeddings with 3 components for 3D visualization
tsne = TSNE(n_components=3, perplexity=30, n_iter=1000)
tsne_results = tsne.fit_transform(embeddings)

# Plotting the t-SNE result with labels in 3D
fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(111, projection='3d')

# Create a 3D scatter plot
scatter = ax.scatter(
    tsne_results[:, 0],
    tsne_results[:, 1],
    tsne_results[:, 2],
    c=sample_df['new_cluster_index'],
    cmap='viridis',  # Viridis is a good perceptually-uniform colormap for distinguishing clusters
    alpha=0.8
)

# Adding labels and title
ax.set_title('3D t-SNE Visualization of Embeddings')
ax.set_xlabel('t-SNE Dimension 1')
ax.set_ylabel('t-SNE Dimension 2')
ax.set_zlabel('t-SNE Dimension 3')
fig.colorbar(scatter)

# Show the plot
plt.show()

# %%
# Prepare DataFrame for Plotly
plot_df = pd.DataFrame(tsne_results[:, [0,1]], columns=['x', 'y'])
plot_df['cluster'] =sample_df["new_cluster_index"]
plot_df['generated_cluster_label'] = sample_df["generated_cluster_label"] + " XX " + sample_df['Tasks/Jobs']
# Plot using Plotly with clusters
fig = px.scatter(plot_df, x='x', y='y',
                 color='cluster',
                 color_continuous_scale=px.colors.diverging.Tealrose,
                 hover_data=['generated_cluster_label'])
fig.update_traces(marker_size=10)
fig.update_layout(
    title=f"2D Visualization of Embeddings with Clusters and {len(sample_df)} startups", 
    hovermode='closest',
    width=1000,  # Set the width of the figure
    height=600  # Set the height of the figure
)
fig.show()

# %%
fig.write_html("startups.html")

# %%
len(sample_df)
# Out:
# 468

# %%
sorted_generated_labels.head()
# Out:
#    new_cluster_index           generated_cluster_label
# 0                  0         AI Research & Development
# 1                  1       AI Development & Deployment
# 2                  2        AI Development & Assurance
# 3                  3                 AI Tool Ecosystem
# 4                  4  AI Automation & No-Code Platform

# %%
for i in range(0,1):
    vals = sample_df[(sample_df["new_cluster_index"]==1) | (sample_df["generated_cluster_label"]=="x")]
    if len(vals) < 0: continue
    label = vals.generated_cluster_label.iloc[0]
    print(f"Processing {i} and {label}:\n************************\n")
    for index, row in vals.iterrows():
        print(f"Organization Name: {row['organization name']}")
        print(f"Generated Description: {row['generated_description']}")
        print(f"Generated Description: {row['parsed_description']}\n")
    print(f"************************\n\n")
# Out:
# Processing 0 and AI Research and Development:
# ************************
#
# Organization Name: Synthine
# Generated Description: Synthine is an AI research lab dedicated to developing and applying deep generative AI solutions to create robust interfaces. Their focus lies in practical generative technologies, aiming to revolutionize the way we interact with AI systems.
# Generated Description:
# Tasks/Jobs: AI interface design, Generative model development, User interaction design, AI system optimization
# Industry: AI Research
# People Using Tool: AI researchers, Developers
#
#
#
# Organization Name: SuperDuperDB
# Generated Description: SuperDuperDB is a platform that simplifies the process of building AI applications by allowing users to integrate AI and vector search directly with their databases, eliminating the need for complex pipelines and specialized vector databases. It supports real-time inference and model training using Python, making AI integration more accessible and efficient.
# Generated Description:
# Tasks/Jobs: AI model integration, Vector search, Real-time inference, Model training
# Industry: Database management
# People Using Tool: Developers, Data scientists
#
#
#
# Organization Name: ANIMA AI
# Generated Description: ANIMA AI is a platform that leverages advanced AI research and technology to transform them into popular consumer products. It provides businesses with the opportunity to innovate and create AI-driven goods that cater to the evolving needs of consumers.
# Generated Description:
# Tasks/Jobs: Product development, AI research, Consumer product creation, Innovation
# Industry: Consumer goods
# People Using Tool:  Businesses, Product developers
#
#
#
# Organization Name: RobotTools.AI
# Generated Description: RobotTools.AI is a comprehensive library offering Artificial Intelligence, Machine Learning, and automation software tools to facilitate the creation of various projects. It serves as a one-stop resource for users, regardless of their technical expertise, to leverage advanced technologies in their work.
# Generated Description:
# Tasks/Jobs: AI model creation, Machine learning development, Automation script creation, Project management
# Industry: Software development
# People Using Tool: Developers, Researchers, Businesses
#
#
#
# Organization Name: Best AI Sites
# Generated Description: Best AI Sites is a premier online resource offering in-depth reviews, analyses, and recommendations of top AI tools, products, and services. The platform aims to guide businesses, developers, and individuals through the complex landscape of artificial intelligence and machine learning, providing unbiased reviews and educational content to help users make informed decisions.
# Generated Description:
# Tasks/Jobs: AI tool research, AI tool evaluation, AI tool selection, AI education
# Industry: AI information and guidance
# People Using Tool: Businesses, Developers, Individuals
#
#
#
# Organization Name: Icelabs
# Generated Description: Icelabs is a cutting-edge technology company specializing in the development of innovative artificial intelligence products. Their focus lies in creating AI solutions that are not only efficient and reliable, but also user-friendly and accessible to a wide range of industries.
# Generated Description:
# Tasks/Jobs:  AI product development, AI model training, AI model deployment, AI solution integration
# Industry: Artificial Intelligence
# People Using Tool: Developers, Businesses
#
#
#
# Organization Name: Egger AI
# Generated Description: Egger AI is an advanced AI-powered search engine designed to revolutionize the way users discover information. It combines intelligent algorithms with user-friendly interfaces to provide accurate and relevant answers, transforming the traditional search experience.
# Generated Description:
# Tasks/Jobs: Information retrieval, Search query refinement,  Answer generation, Content discovery
# Industry: Search Engine
# People Using Tool: Everyone, Researchers, Students
#
#
#
# Organization Name: Kopyst
# Generated Description: Kopyst is an AI-powered tool that simplifies the creation and sharing of step-by-step guides, SOPs, user manuals, and training materials within teams. It captures workflows and transforms them into comprehensive guides, enhancing collaboration, efficiency, and organization in the workplace.
# Generated Description:
# Tasks/Jobs: Guide creation, SOP documentation, Training material development, Knowledge sharing
# Industry: Knowledge Management
# People Using Tool: Teams, Employees
#
#
#
# Organization Name: Reveal
# Generated Description: Reveal is developing an AI-powered search and knowledge-sharing tool designed specifically for individuals with time constraints. This software utilizes artificial intelligence to streamline the search process and facilitate efficient knowledge exchange.
# Generated Description:
# Tasks/Jobs: Information retrieval, Knowledge sharing, Research, Time management
# Industry: Information management
# People Using Tool: Professionals, Students
#
#
#
# Organization Name: ICAI Icelandic Center for Artificial Intelligence
# Generated Description: The ICAI Icelandic Center for Artificial Intelligence is a hub for AI innovation, offering executive education, conducting advanced research, and fostering the growth of AI startups in Iceland. Additionally, it aids in the acquisition of patents, further promoting the development and application of artificial intelligence technologies.
# Generated Description:
# Tasks/Jobs: Research, AI development, Patent acquisition, Startup support
# Industry: Artificial Intelligence Research & Development
# People Using Tool: Researchers, Developers, Entrepreneurs, Businesses
#
#
#
# Organization Name: Axon Labs
# Generated Description: Axon Labs is a leading provider of high-quality biometric and medical datasets, designed to train and enhance artificial intelligence models. Their specialized data offerings, including ready-to-use biometric data for liveness detection, serve as a comprehensive resource for projects requiring superior data accuracy and reliability.
# Generated Description:
# Tasks/Jobs: Biometric Data Collection, Liveness Detection, AI Model Training, Data Labeling
# Industry: AI Training Data
# People Using Tool: AI Developers, Researchers
#
#
#
# Organization Name: AiToolHunt
# Generated Description: AiToolHunt is a comprehensive online platform that aggregates and provides access to the best free AI tools, software, and websites to enhance users' digital experiences. It serves as a one-stop destination for discovering top-tier AI innovations and use cases, aiming to empower users in their tech journey.
# Generated Description:
# Tasks/Jobs: AI tool discovery, AI tool comparison, AI tool integration, AI tool access
# Industry: AI tools discovery
# People Using Tool:  Everyone, Developers, Businesses
#
#
#
# Organization Name: Dataoorts | GPU Cloud
# Generated Description: Dataoorts GPU Cloud is a cost-effective solution designed to enhance AI development and deployment tasks by providing high-performance GC2 and T4s GPU instances. The platform also offers serverless computing, enabling users to create their own inference endpoint API, making it an ideal tool for all AI/ML/DL developers.
# Generated Description:
# Tasks/Jobs: AI model training, AI model inference, AI development, Serverless computing
# Industry: AI/ML/DL development
# People Using Tool: Developers, Researchers
#
#
#
# Organization Name: Cybernetic Labs
# Generated Description: Cybernetic Labs is a premier marketplace for purchasing AI applications, providing a streamlined platform for businesses and individuals to acquire cutting-edge AI technology. It serves as a one-stop-shop for a wide range of AI solutions, catering to diverse needs and industries.
# Generated Description:
# Tasks/Jobs: AI application procurement, AI integration, AI deployment, AI management
# Industry: AI Marketplace
# People Using Tool: Businesses, Individuals
#
#
#
# Organization Name: mixedbread ai
# Generated Description: Mixedbread.ai is an advanced AI platform designed to enhance information retrieval and discovery processes, constantly self-improving for optimal results. It leverages artificial intelligence to streamline data search and exploration, making it an invaluable tool for researchers, data analysts, and businesses seeking efficient information management.
# Generated Description:
# Tasks/Jobs: Data search, Information retrieval, Data analysis, Knowledge discovery
# Industry: Information management
# People Using Tool: Researchers, Data analysts, Businesses
#
#
#
# Organization Name: EasyTelling AI
# Generated Description: EasyTelling AI is an innovative platform that leverages artificial intelligence to swiftly locate and comprehend academic papers and research documents. It is designed to streamline the process of research and study, making it an invaluable tool for students, academics, and professionals alike.
# Generated Description:
# Tasks/Jobs: Research paper discovery, Research paper summarization, Literature review creation, Knowledge extraction
# Industry: Research
# People Using Tool: Students, Researchers, Professionals
#
#
#
# Organization Name: ShuttleAI
# Generated Description: ShuttleAI is an AI research firm offering a user-friendly API to execute AI models efficiently and cost-effectively. It provides a scalable and ready-for-production service, making AI implementation accessible for businesses of all sizes.
# Generated Description:
# Tasks/Jobs: Model execution, AI deployment, Cost optimization, AI research
# Industry: AI research
# People Using Tool: Developers, Researchers, Businesses
#
#
#
# Organization Name: AIToolWise
# Generated Description: AIToolWise is a premier platform that facilitates the sharing and discovery of top-tier AI tools, fostering a community of innovation and learning. It serves as a comprehensive resource for those interested in AI, providing access to the most effective and cutting-edge tools in the field.
# Generated Description:
# Tasks/Jobs: AI Tool Discovery, AI Tool Evaluation, AI Tool Comparison, AI Tool Collaboration
# Industry: AI Tool Marketplace
# People Using Tool: Developers, Researchers, Businesses
#
#
#
# Organization Name: Everything AI Hub
# Generated Description: Everything AI Hub is a comprehensive online platform that provides a vast collection of AI tools and the latest news in the field of artificial intelligence. It serves as a one-stop resource for discovering innovative AI products, saving users time and effort by centralizing AI knowledge and updates, and assisting in finding the most suitable AI tool for their needs.
# Generated Description:
# Tasks/Jobs: AI tool discovery, AI news updates, AI tool selection, AI project management
# Industry: Artificial intelligence
# People Using Tool: Developers, Researchers, Businesses
#
#
#
# Organization Name: Enkrypt AI
# Generated Description: Enkrypt AI provides a platform that facilitates the swift and secure integration of General AI models into enterprise systems. Their service is designed to enhance business operations by leveraging the power of AI, ensuring data security and accelerating the AI adoption process.
# Generated Description:
# Tasks/Jobs: AI model integration, Data security, Business process automation, AI adoption
# Industry: Enterprise software
# People Using Tool: Developers, Data scientists
#
#
#
# Organization Name: Bolo AI
# Generated Description: Bolo AI is an innovative platform that utilizes advanced AI technology to revolutionize knowledge management in heavy industries, with a focus on Oil & Gas. Their products, Bolo AI Answer and Bolo AI Writer, enhance access to crucial information and simplify documentation processes, thereby improving productivity, safety, and efficiency in these sectors.
# Generated Description:
# Tasks/Jobs: Information retrieval, Knowledge management, Documentation, Document summarization
# Industry: Oil & Gas
# People Using Tool: Engineers, Operators
#
#
#
# Organization Name: Sharly AI
# Generated Description: Sharly AI is an advanced AI-powered tool designed to assist industry researchers by extracting high-quality answers from complex documents. It simplifies the research process by providing clear, concise, and accurate information, making it an invaluable resource for those seeking to understand intricate industry-specific documents.
# Generated Description:
# Tasks/Jobs:  Document analysis,  Information extraction,  Answer generation, Research automation
# Industry:  Research and Development
# People Using Tool: Researchers,  Industry Professionals
#
#
#
# ************************

# %%
grouped_counts = sample_df.groupby("new_cluster_index").aggregate({
    'generated_cluster_label': 'first', 
    'organization name': 'count'        
}).rename({"organization name":"count"},axis=1)
grouped_counts
# Out:
#                                 generated_cluster_label  count
# new_cluster_index
# 1                           AI Research and Development     22
# 2                             AI Toolset for Developers     11
# 3                          Web Development and AI tools      6
# 4                          Development Tools Automation      3
# 5                                AI Systems Development     37
# ...                                                 ...    ...
# 60                          Image Enhancement Solutions      7
# 61                        Insurance Management Services      2
# 62                      Personal Growth and Development      3
# 63                 High-Performance Computing Solutions      3
# 64                      Social and Event Planning Tools      3
#
# [62 rows x 2 columns]

# %%
for index, row in grouped_counts.iterrows():
    print(f"{row['generated_cluster_label']}, Count: {row['count']}")
# Out:
# AI Research and Development, Count: 22
# AI Toolset for Developers, Count: 11
# Web Development and AI tools, Count: 6
# Development Tools Automation, Count: 3
# AI Systems Development, Count: 37
# No-Code AI Platforms, Count: 3
# Advanced Cybersecurity Solutions, Count: 12
# Data Management and Quality Control, Count: 8
# Tech and Blockchain News, Count: 5
# Social Media and Digital Insights, Count: 12
# Social Media and Marketing Strategies, Count: 5
# Marketing Data Analytics, Count: 3
# Customer Data Analysis, Count: 4
# Sales and Marketing Outreach, Count: 11
# AI-Driven Business Strategies, Count: 5
# Financial Management Systems, Count: 17
# Tax and Accounting Automation, Count: 3
# Automated Business Systems, Count: 28
# E-commerce and Retail Strategies, Count: 7
# E-commerce Management, Count: 4
# Retail Supply Chain Management, Count: 5
# Industrial Sourcing Solutions, Count: 4
# Industrial Sales Automation, Count: 3
# Solutions for Industrial Automation, Count: 3
# Mobile and Software Development Technologies, Count: 21
# Creative Business Tools, Count: 20
# Creative Content and Media Tools, Count: 7
# Animation and Visual Effects Tools, Count: 9
# Music and Audio Production Tools, Count: 11
# Construction and Workflow Automation, Count: 3
# Legal and Technological Automation, Count: 7
# Client Management in Legal Services, Count: 2
# Regulatory Compliance and Risk Management, Count: 10
# Document Management Automation, Count: 2
# Healthcare Data Management Systems, Count: 9
# Healthcare Workflow Optimization, Count: 5
# Personalized Wellness Programs, Count: 8
# Wellness and Sleep Health, Count: 2
# Mental Health and Therapy, Count: 4
# Veterinary and Pet Care Technologies, Count: 3
# Educational Technologies and Learning Platforms, Count: 17
# Gamification in Education, Count: 2
# Technical Writing and Proposals, Count: 2
# Data Insights and Analytics, Count: 6
# Market and Business Strategy, Count: 4
# Project and Team Management, Count: 7
# HR and Recruitment Automation, Count: 11
# Career Development Tools, Count: 4
# Restaurant and Hospitality Services, Count: 8
# Travel Booking and Planning Systems, Count: 8
# Real Estate Investment Analysis, Count: 9
# Home and Interior Design, Count: 4
# Biotechnological Research, Count: 3
# Language and Speech Learning, Count: 3
# Decentralized Tech and Identity, Count: 4
# Venture Capital and Financing, Count: 10
# Sustainability and Non-Profit Solutions, Count: 4
# Image Enhancement Solutions, Count: 7
# Insurance Management Services, Count: 2
# Personal Growth and Development, Count: 3
# High-Performance Computing Solutions, Count: 3
# Social and Event Planning Tools, Count: 3

# %%
import plotly.express as px
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA

clusters = sample_df["generated_cluster_label"]

# Use PCA to reduce dimensions to 3 for 3D visualization
pca = PCA(n_components=3)
embeddings_3d = pca.fit_transform(np.array(sample_df['openai_embedding_entire'].tolist()))

# Prepare DataFrame for Plotly
plot_df = pd.DataFrame(tsne_results, columns=['x', 'y', 'z'])
plot_df['cluster'] =sample_df["new_cluster_index"]
plot_df['generated_cluster_label'] = sample_df["generated_cluster_label"] + " XX " + sample_df['Tasks/Jobs']

# Create a 3D scatter plot using Plotly
fig = px.scatter_3d(plot_df, x='x', y='y', z='z', 
                 color='cluster',
                 color_continuous_scale=px.colors.diverging.Tealrose,
                 hover_data=['generated_cluster_label'])
fig.update_traces(marker_size=5)
fig.update_layout(
    title='3D Visualization of Embeddings with PCA',
    hovermode='closest',
    width=1000,  # Set the width of the figure
    height=600  # Set the height of the figure
)
# Show the plot
fig.show()

# %%
import plotly.express as px
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA

clusters = sample_df["merged_label"]

# Use PCA to reduce dimensions to 3 for 3D visualization
pca = PCA(n_components=3)
embeddings_3d = pca.fit_transform(np.array(sample_df['openai_embedding_entire'].tolist()))

# Prepare DataFrame for Plotly
plot_df = pd.DataFrame(tsne_results, columns=['x', 'y', 'z'])
plot_df['cluster'] = clusters  # Add cluster assignments to the DataFrame

# Create a 3D scatter plot using Plotly
fig = px.scatter_3d(plot_df, x='x', y='y', z='z', color='cluster', hover_data=['cluster'])
fig.update_traces(marker_size=5)
fig.update_layout(
    title='3D Visualization of Embeddings with PCA',
    hovermode='closest',
    width=1000,  # Set the width of the figure
    height=1000  # Set the height of the figure
)
# Show the plot
fig.show()

# %%
tsne_results
# Out:
# array([[-20.14677  ,   2.0260096, -30.416681 ],
#        [-18.313572 ,  -1.406669 , -31.094774 ],
#        [ -7.3892174, -16.522545 ,   0.8111613],
#        ...,
#        [  1.9683405,  17.504587 , -24.546268 ],
#        [  6.5245504,  16.097193 ,   2.4974155],
#        [ 10.679577 ,  17.057632 ,   1.6603855]], dtype=float32)

# %%
services_mapping = {
    "AI Research & Development": [
        "AI Research & Development",
        "AI Development & Deployment",
        "AI Development & Assurance",
        "AI Tool Ecosystem",
        "AI Automation & No-Code Platform"
    ],
    "Creative and Media": [
        "Fashion",
        "Music Production & Creation Tools",
        "Tools for Creative & Business",
        "Content Creation & Audio Tools",
        "Design & Marketing",
        "Animation & VFX Production Tools"
    ],
    "Software and Web Development": [
        "Website & Software Optimization",
        "Mobile & Software Development",
        "Dev Tools & Automation",
        "DevOps & Infrastructure Management"
    ],
    "Tech News and Insights": [
        "Web3 & Tech News Automation",
        "Social & Digital Insights"
    ],
    "Retail and Commerce": [
        "Retail Operations & Supply Chain Management",
        "Retail & E-commerce",
        "E-commerce Operations & Management",
        "Industrial Procurement & Sourcing"
    ],
    "Cybersecurity": [
        "Cybersecurity Platform",
        "Cybersecurity & Data Privacy Automation"
    ],
    "Business Solutions": [
        "Tech & Business Solutions",
        "AI & Business",
        "AI Business Solutions",
        "Business Solutions",
        "Business Automation & Analytics",
        "Financial Management & Analytics",
        "Sales Automation for Industrial Equipment",
        "Accounting & Tax Automation",
        "Financial Risk & Compliance"
    ],
    "Marketing and Customer Management": [
        "Marketing Automation & Analytics",
        "Social Media Marketing Suite",
        "Customer Intelligence & Growth",
        "Customer Engagement & Automation",
        "Customer & Business Support",
        "AI Content & Marketing Tools"
    ],
    "Legal and Compliance": [
        "Construction Workflow Automation",
        "Legal Tech Automation",
        "Legal Client Management",
        "Compliance & Risk Management",
        "Document Automation for Business"
    ],
    "Education and Learning": [
        "EdTech & Learning",
        "Educational Gamification & Assessment",
        "Learning & Development Platforms",
        "Speech & Language Learning"
    ],
    "Healthcare": [
        "Healthcare Data & Management",
        "Healthcare Operations & Workflow",
        "Clinical AI Assistant",
        "Personalized Health & Wellness",
        "Mental Wellness & Therapy"
    ],
    "Hospitality": [
        "Restaurant & Hospitality Automation",
        "Hospitality & Travel Operations"
    ],
    "Travel and Booking": [
        "Travel Planning & Booking"
    ],
    "AI Resources": [
        "AI Resources & Education"
    ],
    "Venture and Non-profit": [
        "Venture Capital Operations",
        "Non-profit & Sustainability Solutions"
    ],
    "Wellness and Lifestyle": [
        "Sleep & Dream Wellness",
        "Personal & Professional Growth"
    ],
    "Recruitment and HR": [
        "Recruitment & HR Automation",
        "Job Search & Career Development Tools"
    ],
    "Real Estate": [
        "Real Estate & Investment Analytics",
        "Real Estate & Trust & Safety Automation",
        "Home Design & Visualization"
    ],
    "Data Management": [
        "Data Analysis & Insights",
        "Data Quality & Management",
        "Market Research & Business Strategy"
    ],
    "Management and Operations": [
        "Team & Project Management",
        "Proposal & Technical Writing Automation"
    ],
    "Innovative Technologies": [
        "Decentralized Technologies & Digital Identity",
        "High-Performance Computing"
    ],
    "Insurance and Support": [
        "Insurance Management & Support"
    ],
    "Biotech": [
        "Biotech Research & Development"
    ],
    "Industry Solutions": [
        "Industrial Automation Solutions"
    ],
    "Event and Social Tools": [
        "Social & Event Tools"
    ]
}

vals = []
for x in services_mapping:
    for y in services_mapping[x]:
        vals.append([x, y])
merged_labels = pd.DataFrame(vals, columns=["merged_label", "generated_cluster_label"])

# %%
for i in range(0,1):
    vals = sample_df[(sample_df["new_cluster_index"]==1000) | (sample_df["generated_cluster_label"]=="AI & Business")]
    if len(vals) == 0: continue
    label = vals.generated_cluster_label.iloc[0]
    print(f"Processing {i} and {label}:\n************************\n")
    for index, row in vals.iterrows():
        print(f"Organization Name: {row['organization name']}")
        print(f"Generated Description: {row['generated_description']}")
        print(f"Generated Description: {row['parsed_description']}\n")
    print(f"************************\n\n")
# Out:
# Processing 0 and AI & Business:
# ************************
#
# Organization Name: FoundationFlow
# Generated Description: FoundationFlow is a B2B platform that streamlines the deployment of generative AI business workflows, offering a cost-effective and secure solution for managing multi-modal LLMs. With advanced capabilities, it significantly reduces both the computational and memory requirements for training, leading to an average total cost of ownership reduction by 60%.
# Generated Description:
# Tasks/Jobs: Generative AI workflow deployment, LLM management, Multi-modal LLM training, Cost optimization
# Industry: Business automation
# People Using Tool: Businesses, Developers
#
#
#
# Organization Name: CloudGPT
# Generated Description: CloudGPT is an innovative AI company providing cloud-based solutions powered by advanced generative pre-trained transformer (GPT) technology, specializing in natural language processing, machine learning, and data analytics. Their scalable platform is designed to serve businesses of all sizes, enabling them to automate complex processes, enhance decision-making, and unlock valuable insights.
# Generated Description:
# Tasks/Jobs:  Content generation, Customer support, Data analysis, Automation
# Industry: AI Services
# People Using Tool: Businesses, Developers
#
#
#
# Organization Name: geminiaiapk
# Generated Description: Geminiaiapk is a platform that provides the latest version of Google Gemini APK AI for Android, aimed at enhancing productivity with advanced applications from Google LLC. It offers free downloads of Google Gemini APK, ensuring users have access to the most recent and efficient tools for their Android devices.
# Generated Description:
# Tasks/Jobs: AI-powered search, content generation, translation, image recognition
# Industry: Mobile AI
# People Using Tool: Android users, Everyone
#
#
#
# Organization Name: ChatGPT AI Hub
# Generated Description: ChatGPT AI Hub is a pioneering platform that facilitates the integration of artificial intelligence into businesses and individual projects, enhancing productivity and decision-making processes. The platform offers a range of AI tools, including an AI content detector, prompt generator, and pricing calculator, designed to be user-friendly and effective in harnessing the power of AI.
# Generated Description:
# Tasks/Jobs: AI content detection, prompt generation, pricing calculation, AI tool integration
# Industry: AI Platform
# People Using Tool: Businesses, Individuals
#
#
#
# Organization Name: AISolvesThat
# Generated Description: AISolvesThat is a comprehensive platform offering a vast array of AI tools and solutions to cater to diverse needs, from creativity to business analytics. It also serves as a hub for AI-related news, job listings, and a detailed glossary of AI terms, making it an ideal resource for both AI professionals and enthusiasts.
# Generated Description:
# Tasks/Jobs: Content creation, Data analysis, Business automation, AI development
# Industry: AI Solutions
# People Using Tool: Businesses, Developers, Researchers
#
#
#
# Organization Name: GenPen AI
# Generated Description: GenPen AI is an advanced artificial intelligence platform that aims to develop and implement Artificial General Intelligence (AGI). It focuses on creating AI systems that possess the ability to understand, learn, adapt, and implement knowledge across a wide range of tasks, much like a human brain.
# Generated Description:
# Tasks/Jobs:  Content creation, Code generation, Problem-solving, Research
# Industry: Artificial General Intelligence (AGI)
# People Using Tool: Everyone, Businesses, Researchers
#
#
#
# Organization Name: AI Generative Lab - AIGL
# Generated Description: AI Generative Lab - AIGL is a company focused on the development and commercialization of AI-driven products designed to enhance human potential and transform lifestyles. Their diverse range of AI products, including the Prompt Engineer, are aimed at simplifying and optimizing AI interactions.
# Generated Description:
# Tasks/Jobs: Prompt engineering, Content generation, AI model training, AI application development
# Industry: AI-driven products
# People Using Tool: Developers, Businesses, Individuals
#
#
#
# Organization Name: Procreation AI
# Generated Description: Procreation AI offers a suite of AI tools as a Software-as-a-Service (SaaS) on the Solana Blockchain, providing advanced solutions for businesses and individuals. Their services leverage the power of artificial intelligence and blockchain technology to deliver efficient, secure, and scalable solutions.
# Generated Description:
# Tasks/Jobs:  AI-powered creative tools, Content generation, NFT minting, Blockchain development
# Industry:  AI-powered SaaS
# People Using Tool:  Artists, Businesses, Developers
#
#
#
# Organization Name: Opbardai
# Generated Description: Opbardai is a platform dedicated to educating users about the Google Bard chatbot, enabling them to harness the capabilities of AI technology. It serves as a comprehensive resource for understanding and utilizing the Bard chatbot for various applications.
# Generated Description:
# Tasks/Jobs: AI Education, Bard training, Bard usage, AI application development
# Industry: AI Education
# People Using Tool: Everyone, Students, Professionals
#
#
#
# ************************

# %%
merged_labels.merged_label.unique()
# Out:
# array(['AI Research & Development', 'Creative and Media',
#        'Software and Web Development', 'Tech News and Insights',
#        'Retail and Commerce', 'Cybersecurity', 'Business Solutions',
#        'Marketing and Customer Management', 'Legal and Compliance',
#        'Education and Learning', 'Healthcare', 'Hospitality',
#        'Travel and Booking', 'AI Resources', 'Venture and Non-profit',
#        'Wellness and Lifestyle', 'Recruitment and HR', 'Real Estate',
#        'Data Management', 'Management and Operations',
#        'Innovative Technologies', 'Insurance and Support', 'Biotech',
#        'Industry Solutions', 'Event and Social Tools'], dtype=object)

# %%
if "merged_label" in sample_df.columns:
    sample_df = sample_df.drop(columns="merged_label")
sample_df = sample_df.merge(merged_labels, on="generated_cluster_label")
sample_df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                  organization name num employees  \
# 0             1       18944  Semilla Co. (Flou / Seed Academy)          1-10
# 1            10       22382                       NaijaBuzz300          1-10
# 2            28       19022                         SONOTELLER          1-10
# 3            82       22374                             AISong          1-10
# 4           126       19675                            SoundAI          1-10
#
#   founded date                                        description  \
# 0   2023-02-01  Semilla Co. ("Seed") is building the future of...
# 1   2024-03-03  NaijaBuzz300's AI content tools helps artists ...
# 2   2023-02-01  SONOTELLER is an AI engine capable of 'listeni...
# 3   2024-03-01  AISong.Fun is a platform that uses the AI to p...
# 4   2023-04-17                                                  —
#
#                                           industries  \
# 0  Consumer Software, Content Creators, EdTech, L...
# 1                                          Marketing
# 2  Artificial Intelligence (AI), Music, SaaS, Sof...
# 3                Artificial Intelligence (AI), Music
# 4  Artificial Intelligence (AI), Information Tech...
#
#                      headquarters location  \
# 0  Fort Lauderdale, Florida, United States
# 1                  Kaduna, Kaduna, Nigeria
# 2                    Madrid, Madrid, Spain
# 3                                        —
# 4       Dubai, Dubai, United Arab Emirates
#
#                                        description.1  cb rank  ...  \
# 0  Building the future of the music and entertain...   43,978  ...
# 1  Helping artists grow & scale up their music ca...        —  ...
# 2                  SaaS AI music and lyrics analysis  240,839  ...
# 3             Free AI Song, Music & Lyrics Generator        —  ...
# 4  is an artificial intelligence service that is ...  330,604  ...
#
#                              Company  \
# 0  Semilla Co. (Flou / Seed Academy)
# 1                       NaijaBuzz300
# 2                         SONOTELLER
# 3                             AISong
# 4                            SoundAI
#
#                                   parsed_description  \
# 0  \nTasks/Jobs: Music Business Management, Marke...
# 1  \nTasks/Jobs: Music production, Songwriting, M...
# 2  \nTasks/Jobs: Music analysis, Playlist creatio...
# 3  \nTasks/Jobs: Song composition, Music producti...
# 4  \nTasks/Jobs: Music generation, Sound design, ...
#
#                                           Tasks/Jobs           Industry  \
# 0  Music Business Management, Marketing, Business...     Music Industry
# 1  Music production, Songwriting, Marketing, Prom...              Music
# 2  Music analysis, Playlist creation, Music disco...   Music technology
# 3  Song composition, Music production, Lyrics gen...     Music creation
# 4  Music generation, Sound design, Audio mixing, ...  Music production
#
#                          People Using Tool  \
# 0           Music Creators, Entrepreneurs
# 1            Musicians, Labels, Promoters
# 2  Music enthusiasts, Music professionals
# 3             Artists, Creators, Musicians
# 4                    Musicians, Producers
#
#                              openai_embedding_entire cluster_label  \
# 0  [-0.004338318016380072, -0.021966977044939995,...            33
# 1  [-0.006098032463341951, -0.021988358348608017,...            33
# 2  [-0.012888072989881039, -0.0282617025077343, -...            33
# 3  [0.005447404459118843, -0.03911559656262398, -...            33
# 4  [-0.0040488275699317455, -0.010498875752091408...            33
#
#              generated_cluster_label new_cluster_index        merged_label
# 0  Music Production & Creation Tools                25  Creative and Media
# 1  Music Production & Creation Tools                25  Creative and Media
# 2  Music Production & Creation Tools                25  Creative and Media
# 3  Music Production & Creation Tools                25  Creative and Media
# 4  Music Production & Creation Tools                25  Creative and Media
#
# [5 rows x 38 columns]

# %%
len(sample_df)
# Out:
# 325
