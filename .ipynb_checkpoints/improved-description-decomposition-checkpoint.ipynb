# %%
import pandas as pd
import numpy as np
from dotenv import load_dotenv
import os
from os import getenv
from openai import OpenAI

load_dotenv("../.env",override=True)
# Out:
# True

# %%
df = pd.read_csv("./output/data.csv")
df = df[df["num employees"]=="11-50"]
df.head()
# Out:
#      Unnamed: 0 organization name num employees founded date  \
# 981         981        Mistral AI         11-50         2023
# 982         982            Sierra         11-50         2023
# 983         983      Essential AI         11-50         2023
# 984         984             Lindy         11-50         2023
# 985         985          Poolside         11-50         2023
#
#                                            description  \
# 981  Mistral AI is an AI startup that provides deve...
# 982  Sierra is an AI startup that tackles essential...
# 983  Essential AI creates AI solutions that enhance...
# 984  Lindy is an AI assistant that can help with al...
# 985  Poolside is an artificial intelligence platfor...
#
#                                             industries  \
# 981  Artificial Intelligence (AI), Generative AI, M...
# 982  Artificial Intelligence (AI), Enterprise Softw...
# 983  Artificial Intelligence (AI), Information Tech...
# 984  Artificial Intelligence (AI), Internet, Softwa...
# 985  Artificial Intelligence (AI), Developer Platfo...
#
#                         headquarters location  \
# 981              Paris, Ile-de-France, France
# 982  San Francisco, California, United States
# 983  San Francisco, California, United States
# 984  San Francisco, California, United States
# 985              Paris, Ile-de-France, France
#
#                                          description.1 cb rank postal code  \
# 981  Mistral AI is an AI startup that provides deve...       7       75001
# 982  Sierra is an AI startup that tackles essential...     259           —
# 983  Essential AI creates AI solutions that enhance...     321           —
# 984                       Your AI executive assistant.     599           —
# 985  Poolside is an artificial intelligence platfor...     924           —
#
#      ...               email     hub tag phone num num of sub org  \
# 981  ...  contact@mistral.ai           —   Unicorn              —
# 982  ...                   —           —         —              —
# 983  ...                   —           —         —              —
# 984  ...      lindy@lindy.ai  6048488619         —              —
# 985  ...                   —           —         —              —
#
#                                        industry groups total funding amt  \
# 981  Artificial Intelligence (AI), Data and Analyti...    €1,105,000,000
# 982  Artificial Intelligence (AI), Data and Analyti...      $110,000,000
# 983  Artificial Intelligence (AI), Data and Analyti...       $64,500,000
# 984  Apps, Artificial Intelligence (AI), Data and A...       $49,900,000
# 985  Artificial Intelligence (AI), Data and Analyti...      $126,000,000
#
#     company type estimated rev  \
# 981   For Profit             —
# 982            —             —
# 983   For Profit             —
# 984   For Profit   $1M to $10M
# 985   For Profit             —
#
#                                        description_all  \
# 981  Mistral AI is an AI startup that provides deve...
# 982  Sierra is an AI startup that tackles essential...
# 983  Essential AI creates AI solutions that enhance...
# 984  Lindy is an AI assistant that can help with al...
# 985  Poolside is an artificial intelligence platfor...
#
#                                      industries_parsed
# 981  ['Generative AI', 'Machine Learning', 'Natural...
# 982                    ['Enterprise Software', 'SaaS']
# 983             ['Information Technology', 'Software']
# 984  ['Internet', 'Software', 'Virtual Assistant', ...
# 985                 ['Developer Platform', 'Software']
#
# [5 rows x 25 columns]

# %%
sample_df = df.iloc[0:200]
sample_df.head()
# Out:
#      Unnamed: 0 organization name num employees founded date  \
# 981         981        Mistral AI         11-50         2023
# 982         982            Sierra         11-50         2023
# 983         983      Essential AI         11-50         2023
# 984         984             Lindy         11-50         2023
# 985         985          Poolside         11-50         2023
#
#                                            description  \
# 981  Mistral AI is an AI startup that provides deve...
# 982  Sierra is an AI startup that tackles essential...
# 983  Essential AI creates AI solutions that enhance...
# 984  Lindy is an AI assistant that can help with al...
# 985  Poolside is an artificial intelligence platfor...
#
#                                             industries  \
# 981  Artificial Intelligence (AI), Generative AI, M...
# 982  Artificial Intelligence (AI), Enterprise Softw...
# 983  Artificial Intelligence (AI), Information Tech...
# 984  Artificial Intelligence (AI), Internet, Softwa...
# 985  Artificial Intelligence (AI), Developer Platfo...
#
#                         headquarters location  \
# 981              Paris, Ile-de-France, France
# 982  San Francisco, California, United States
# 983  San Francisco, California, United States
# 984  San Francisco, California, United States
# 985              Paris, Ile-de-France, France
#
#                                          description.1 cb rank postal code  \
# 981  Mistral AI is an AI startup that provides deve...       7       75001
# 982  Sierra is an AI startup that tackles essential...     259           —
# 983  Essential AI creates AI solutions that enhance...     321           —
# 984                       Your AI executive assistant.     599           —
# 985  Poolside is an artificial intelligence platfor...     924           —
#
#      ...               email     hub tag phone num num of sub org  \
# 981  ...  contact@mistral.ai           —   Unicorn              —
# 982  ...                   —           —         —              —
# 983  ...                   —           —         —              —
# 984  ...      lindy@lindy.ai  6048488619         —              —
# 985  ...                   —           —         —              —
#
#                                        industry groups total funding amt  \
# 981  Artificial Intelligence (AI), Data and Analyti...    €1,105,000,000
# 982  Artificial Intelligence (AI), Data and Analyti...      $110,000,000
# 983  Artificial Intelligence (AI), Data and Analyti...       $64,500,000
# 984  Apps, Artificial Intelligence (AI), Data and A...       $49,900,000
# 985  Artificial Intelligence (AI), Data and Analyti...      $126,000,000
#
#     company type estimated rev  \
# 981   For Profit             —
# 982            —             —
# 983   For Profit             —
# 984   For Profit   $1M to $10M
# 985   For Profit             —
#
#                                        description_all  \
# 981  Mistral AI is an AI startup that provides deve...
# 982  Sierra is an AI startup that tackles essential...
# 983  Essential AI creates AI solutions that enhance...
# 984  Lindy is an AI assistant that can help with al...
# 985  Poolside is an artificial intelligence platfor...
#
#                                      industries_parsed
# 981  ['Generative AI', 'Machine Learning', 'Natural...
# 982                    ['Enterprise Software', 'SaaS']
# 983             ['Information Technology', 'Software']
# 984  ['Internet', 'Software', 'Virtual Assistant', ...
# 985                 ['Developer Platform', 'Software']
#
# [5 rows x 25 columns]

# %%
class chatGPT():
    def __init__(self):
        my_key = getenv("OPENAI_API_KEY")
        self.client = OpenAI(api_key=my_key)
        
    def ask(self, q):
        stream = self.client.chat.completions.create(
            model="gpt-4",
            messages=[{"role": "user", "content": q}],
            stream=True,
            temperature=0
        )
        response = ""
        for chunk in stream:
            if chunk.choices[0].delta.content is not None:
                response += chunk.choices[0].delta.content

        self.response = response
        return response

    def get_embedding(self,text, model="text-embedding-3-small"):
       text = text.replace("\n", " ")
       return self.client.embeddings.create(input = [text], model=model).data[0].embedding

x = chatGPT()

# %%
prompt = """
Your role is to give a description of what a company does as well as their target client/industries. Make it simple and understandable. Do not use a full sentence.

- DO NOT INCLUDE WORDS IN THIS LIST: ["AI-driven", "AI-powered", "workflow", "AI"]
- ONLY USE NOUNS IN THE PRODUCT (make it simple for someone not in tech to understand)
- TARGET INDUSTRY has to be specific business, CANNOT be "someone/business in need of ..."
- DO NOT MAKE FULL SENTENCE (comma separated list) 

EXAMPLES BELOW 
_________________________
Company: Genmo
Website: https://www.genmo.ai/
Description:Genmo is an artificial intelligence creative content generation platform that specializes in developing creative products. Genmo is an artificial intelligence creative content generation platform that specializes in developing creative products.
Industries:['Content', 'Digital Entertainment']
Product: AI-powered video creation, Text-to-video generation, Generative art
Target Client/Industries: content creators, marketers, educators

Company: GuardRails
Website: https://www.guardrails.io/
Description: Guardrails AI aim to unlock an unparalleled scale of potential, ensuring the reliable, safe, and beneficial application of AI technology to improve human life. It is committed to eliminating the uncertainties inherent in AI interactions, providing goal-oriented, contractually bound solutions. Guardrails AI empowers humanity to harness the unprecedented capabilities of foundation AI models.
Industries: []
Product:Continuous Security Scanning, Source Code Analysis (SAST), Dependency Analysis (SCA), Secret Detection, Cloud Security Analysis
Target Client/Industries: code development teams 

Company: Liquid AI
Website: https://www.liquid.ai/
Description: Liquid AI is a developer of AI applications that help improve human experience. It focuses on researching and developing tools that use artificial intelligence to improve creative workflows and help clients manage their workflow efficiently. Liquid AI is a developer of AI applications that help improve human experience
Industries:['Generative AI', 'Information Technology', 'Machine Learning']
Product: neural network ai application
Target Client/Industries: general purpose

________________________
Now, your turn:
Company: $company
Website: $website
Description: $description
Industries: $industries
Product: --
Target Client/Industries: --
"""


websites = list(sample_df['website'])
companies = list(sample_df['organization name'])
descriptions = list(sample_df['description_all'])
industries = list(sample_df['industries_parsed'])
results = []
n = len(sample_df)
for i in range(n):
    try:
        print(f"Processing {str(i)}: {companies[i]}")
        p1 = prompt.replace("$website", websites[i])\
                   .replace("$company", companies[i])\
                   .replace("$description", descriptions[i])\
                   .replace("$industries",industries[i])
        result = x.ask(p1)
        print(f"Result: {result}\n")
        results.append(result)
    except Exception as e:
        print(f"Error processing {str(i)}, {companies[i]}: {e}")
        results.append(None)


sample_df['generated_description'] = results

sample_df.to_csv('./output/sample_df_with_results.csv', index=False)
# Out:
# Processing 0: Mistral AI
# Result: Product: Generative solutions, Open AI tools, Portable AI solutions
# Target Client/Industries: software developers, tech businesses, AI industry professionals
#
# Processing 1: Sierra
# Result: Product: Conversational agents, Business solutions integration
# Target Client/Industries: Enterprise businesses, Customer support services
#
# Processing 2: Essential AI
# Result: Product: Automation solutions, Large Language Models
# Target Client/Industries: IT companies, software development firms
#
# Processing 3: Lindy
# Result: Product: Virtual assistant, Calendar management, Email drafting, Contract sending
# Target Client/Industries: Executives, Managers, Professionals needing administrative assistance
#
# Processing 4: Poolside
# Result: Product: Software creation platform
# Target Client/Industries: software developers, tech startups
#
# Processing 5: Sarvam AI
# Result: Product: Large language models, Enterprise model development
# Target Client/Industries: App developers, software companies in India
#
# Processing 6: Patronus AI
# Result: Product: Automated evaluation platform, Security analysis framework
# Target Client/Industries: Network security firms, IT companies
#
# Processing 7: Sixfold AI
# Result: Product: Insurance underwriting tool
# Target Client/Industries: Insurance underwriters, insurance companies
#
# Processing 8: MyShell
# Result: Product: Decentralized platform, AI-native apps discovery, App creation, Staking apps
# Target Client/Industries: App developers, Mobile app industry, Software industry
#
# Processing 9: Sakana AI
# Result: Product: Nature-inspired intelligence model
# Target Client/Industries: Tech companies, Research institutions
#
# Processing 10: Flower Labs
# Result: Product: Federated learning framework, Distributed data training, AI model improvement
# Target Client/Industries: Banking Circle, Nokia, Porsche, Brave
#
# Processing 11: Norm Ai
# Result: Product: Regulatory compliance software
# Target Client/Industries: Compliance teams in financial institutions, healthcare organizations, legal firms
#
# Processing 12: Oliv AI
# Result: Product: Virtual meeting platform, Sales script updates, Discovery question identification, Customer query analysis
# Target Client/Industries: Sales teams, Customer service teams, Productivity-focused businesses
#
# Processing 13: Vespa.ai
# Result: Product: Search engine, Vector database
# Target Client/Industries: Online retailers, News agencies, Financial institutions
#
# Processing 14: Alpheya
# Result: Product: Wealth management software, Cloud-based financial solutions
# Target Client/Industries: Wealth management firms, Financial advisors, Banks
#
# Processing 15: Mindtrip
# Result: Product: Travel data provision, Map suggestions, Visit recommendations
# Target Client/Industries: Travel agencies, Tour operators, Hospitality industry
#
# Processing 16: Baichuan Intelligence
# Result: Product: Language intelligence services, Large model base development
# Target Client/Industries: Search engine companies, Educational institutions, Healthcare providers
#
# Processing 17: Arkifi
# Result: Product: Financial analysis tools
# Target Client/Industries: Financial analysts, investment firms, banks
#
# Processing 18: Worth AI
# Result: Product: Underwriting platform, Onboarding activities, Risk monitoring
# Target Client/Industries: Financial institutions, Insurance companies, Risk management firms
#
# Processing 19: Initia Labs
# Result: Product: Network for omnichain rollups, All-in-one portal for ecosystem tools, Omnitia-ecosystem wallet, Block explorer, Market Minitia for NFT trading and creation
# Target Client/Industries: Cryptocurrency traders, NFT creators, Blockchain developers
#
# Processing 20: Workhack
# Result: Product: Conversational bot creation, Template adaptation, Mobile and web deployment
# Target Client/Industries: Mobile app developers, Web developers, Customer service industries
#
# Processing 21: Prompt Security
# Result: Product: GenAI Security Platform
# Target Client/Industries: Enterprises adopting Generative AI, Cybersecurity teams
#
# Processing 22: Harmonic Security
# Result: Product: Enterprise security solutions, Network visibility tools, Threat detection systems
# Target Client/Industries: IT departments, Network administrators, Cybersecurity firms
#
# Processing 23: XponentL Data
# Result: Product: Data analysis tools, Decision-making software, Productivity enhancement tools
# Target Client/Industries: Data-driven businesses, Decision-makers in corporations, Productivity-focused industries
#
# Processing 24: Series.AI
# Result: Product: Game development, Character design, Level design
# Target Client/Industries: Game studios, Independent game developers
#
# Processing 25: LighthouseAI
# Result: Product: Inventory management software, Supply chain optimization software, Data analytics software
# Target Client/Industries: Pharmaceutical manufacturers, Logistics companies, Wholesalers, Pharmacies
#
# Processing 26: Terminal Industries
# Result: Product: Supply chain optimization platform
# Target Client/Industries: Logistics operators, Supply chain management companies
#
# Processing 27: DALPHA
# Result: Product: Customized B2B solutions, Secure cloud environment, Differential privacy technology
# Target Client/Industries: Enterprises in beauty, e-commerce, fashion, marketing, software industries
#
# Processing 28: GIGA Venture
# Result: Product: Startup incubation, Venture funding, Business development assistance
# Target Client/Industries: Startup founders, Technology entrepreneurs, Angel investors, Financial institutions
#
# Processing 29: Vieu
# Result: Product: Execution strategy generation, Prospecting, Proposal, Procurement
# Target Client/Industries: Business consultants, Sales teams, Procurement departments
#
# Processing 30: Pave Bank
# Result: Product: Multi-asset banking platform, Programmable financial services
# Target Client/Industries: Financial institutions, Blockchain companies, Fintech startups
#
# Processing 31: Yuma AI
# Result: Product: Automated customer service platform
# Target Client/Industries: Shopify merchants, E-commerce businesses
#
# Processing 32: FORA
# Result: Product: Executive Relationship Management Platform
# Target Client/Industries: C-suite executives, large corporations, business management teams
#
# Processing 33: Asato
# Result: Product: Enterprise copilot platform
# Target Client/Industries: Chief Information Officers, IT departments
#
# Processing 34: Cortex
# Result: Product: Integrated platform for AFib assessment and treatment
# Target Client/Industries: Healthcare providers, Cardiology clinics, Hospitals
#
# Processing 35: Haltia.AI
# Result: Product: Personal AI assistant, On-device AI technology, Large Language Models, Real-time knowledge capture, Voice interactions
# Target Client/Industries: mobile app users, privacy-conscious individuals, public and private sectors
#
# Processing 36: Era Finance
# Result: Product: Financial management platform, Asset management
# Target Client/Industries: Financial advisors, Asset managers, Wealth management firms
#
# Processing 37: Sensigo
# Result: Product: Vehicle service platform, Maintenance data simplification tools
# Target Client/Industries: Service technicians, Original Equipment Manufacturers (OEMs) in the automotive industry
#
# Processing 38: Flojoy
# Result: Product: Open source solution, No-code Python testing, Automated test scripts
# Target Client/Industries: Software development firms, Quality assurance teams
#
# Processing 39: WorkMagic
# Result: Product: Marketing automation platform
# Target Client/Industries: E-commerce companies, online retailers
#
# Processing 40: EZee Assist
# Result: Product: Franchisee support system, Instant answer tool
# Target Client/Industries: Franchise businesses, Retail chains
#
# Processing 41: Comand AI
# Result: Product: Decision-making software, Operating capabilities software
# Target Client/Industries: Defense forces, Military organizations, National security agencies
#
# Processing 42: AGII
# Result: Product: Content generation platform
# Target Client/Industries: Web developers, online publishers, digital marketers
#
# Processing 43: Lex
# Result: Product: Writing tool, Idea organization, Communication enhancement
# Target Client/Industries: Writers, Journalists, Researchers
#
# Processing 44: Pull Systems
# Result: Product: Vehicle data capturing, Data analysis service
# Target Client/Industries: Automotive manufacturers, Fleet management companies, Logistics companies
#
# Processing 45: Visionify
# Result: Product: Computer vision technology, Safety applications, Risk detection, Compliance monitoring, Surveillance systems
# Target Client/Industries: EHS professionals, businesses with physical workspaces, public safety organizations
#
# Processing 46: WAVs AI
# Result: Product: AI music generation, Music streaming platform
# Target Client/Industries: music listeners, music artists, entertainment industry
#
# Processing 47: HaiVE
# Result: Product: Customer experience optimization platform
# Target Client/Industries: Pre-sales teams, on-boarding teams, product and service support teams
#
# Processing 48: HyperGPT
# Result: Product: Marketplace for AI solutions, SDK access
# Target Client/Industries: Blockchain developers, Machine learning specialists, Tech startups
#
# Processing 49: Katalis AI
# Result: Product: E-commerce marketing tools, Image editing software, Advertising campaign management
# Target Client/Industries: E-commerce businesses, Online retailers, Digital marketing agencies
#
# Processing 50: nutrād
# Result: Product: Supply chain software, Commercial trade automation
# Target Client/Industries: Brands, Distributors, Retailers
#
# Processing 51: Osmo
# Result: Product: Digital scent detection, Fragrance analysis
# Target Client/Industries: Fragrance manufacturers, Healthcare providers, Food and beverage industry
#
# Processing 52: Nexus AI
# Result: Product: Legal advice tool, Legal professional services
# Target Client/Industries: Legal professionals, Law firms, Individual consumers seeking legal advice
#
# Processing 53: AQX
# Result: Product: Voice communication software, Business contact center technology
# Target Client/Industries: Customer service centers, Telecommunication companies, Retail businesses
#
# Processing 54: Plai Labs
# Result: Product: Social platform development, Game mechanics technology
# Target Client/Industries: Social media companies, Online gaming industries, Web development firms
#
# Processing 55: Cohere Commerce
# Result: Product: Review platform
# Target Client/Industries: Retail businesses, B2B companies
#
# Processing 56: AiONE
# Result: Product: Decentralized AI integration service
# Target Client/Industries: Businesses in Blockchain, IaaS, Information Services, Software industries
#
# Processing 57: Potis AI
# Result: Product: Hiring co-pilot, Skills assessment, Behavioral testing, Virtual Interview Platform
# Target Client/Industries: HR departments, recruitment agencies, large corporations with HR needs
#
# Processing 58: Deep Wisdom
# Result: Product: Interactive entertainment platform, AI anchors, E-commerce live broadcast, Short videos
# Target Client/Industries: E-commerce businesses, Live broadcasting platforms, Video content creators
#
# Processing 59: Babel AI
# Result: Product: Software development services, Operation and maintenance services
# Target Client/Industries: Software development companies, IT service providers
#
# Processing 60: Platterhub.ai
# Result: Product: Content creation tools, Monetization strategies, Digital platform navigation
# Target Client/Industries: YouTubers, podcasters, writers, artists, digital entrepreneurs
#
# Processing 61: Testaify
# Result: Product: Testing platform, Defect detection, Functional test generation, Test input data creation, Test validation
# Target Client/Industries: Software development organizations, IT companies
#
# Processing 62: Cusman
# Result: Product: Customer success platform, churn reduction, customer lifetime value increase, data point connection, proactive client engagement, trial to client conversion, product adoption, retention increase, net revenue increase
# Target Client/Industries: B2B companies, CRM providers, enterprise software companies, SaaS providers, software companies
#
# Processing 63: Traderlands
# Result: Product: Algorithmic trading strategies creation, Trading strategies marketplace, Automated trading, Mobile trading applications
# Target Client/Industries: Trading experts, Novice traders, Cryptocurrency exchanges, Financial service providers
#
# Processing 64: Airosphera
# Result: Product: Indoor air quality solutions, Personalized air reforming devices, CO2 level management
# Target Client/Industries: homeowners, office spaces, indoor public spaces
#
# Processing 65: AugMend
# Result: Product: Virtual reality therapy platform, Biofeedback tools
# Target Client/Industries: Therapists, Mental health clinics, Home care providers
#
# Processing 66: Joble
# Result: Product: Task management platform, Project oversight system, Scheduling tool, Real-time translation service, Meeting analytics
# Target Client/Industries: Professionals, Project managers, Enterprise teams
#
# Processing 67: Et Cetera Robotics
# Result: Product: Motion sensor software, Human-like robot movements
# Target Client/Industries: Robotics manufacturers, Automation industries, Healthcare robotics
#
# Processing 68: Maven AGI
# Result: Product: Customer support solutions, Operational planning services, Customer acquisition strategy
# Target Client/Industries: Customer service departments, Sales and marketing teams, Enterprise businesses
#
# Processing 69: FLIPJUNGLE
# Result: Product: Digital diary, Real-time progress tracking, Immersive learning adventures
# Target Client/Industries: Parents, educators, children's educational institutions
#
# Processing 70: MakeMeLook.ai
# Result: Product: Virtual stylist, Digital fitting room, Personalized fashion recommendations
# Target Client/Industries: Online shoppers, Fashion retailers, Clothing brands
#
# Processing 71: Lepton AI
# Result: Product: Cloud-native platform, AI applications operation
# Target Client/Industries: SaaS companies, Cloud Infrastructure businesses, Software firms
#
# Processing 72: Vocadian
# Result: Product: Voice-based diagnostic tool, Sleep management tool, Performance improvement tool
# Target Client/Industries: Fitness trainers, Healthcare providers, Wellness centers
#
# Processing 73: Huirong Technology
# Result: Product: Corporate financial consulting, Internet-based solutions, Big data analysis
# Target Client/Industries: Financial institutions, Corporate businesses
#
# Processing 74: Xiaozhi Future
# Result: Product: Artificial intelligence courses, Consulting services
# Target Client/Industries: Students, Professionals seeking AI knowledge, Companies in need of AI training
#
# Processing 75: Future State University
# Result: Product: 3D open-world learning environment, professional networking, career guidance, performance insights, culture match technology
# Target Client/Industries: universities, job marketplaces, employers seeking diverse workforce
#
# Processing 76: Chi AI
# Result: Product: Incident intelligence co-pilot
# Target Client/Industries: IT service management teams, software development companies
#
# Processing 77: Candle
# Result: Product: Job matching software, Online agent connection tools
# Target Client/Industries: HR departments, Recruitment agencies, Job seekers
#
# Processing 78: Aegis AI
# Result: Product: Smart contract auditing tool
# Target Client/Industries: Blockchain developers, Cryptocurrency companies, Financial technology firms
#
# Processing 79: Warranty Life
# Result: Product: Mobile device insurance technology, Usage-based telematics for phones
# Target Client/Industries: Mobile device users, Insurance companies
#
# Processing 80: Overland AI
# Result: Product: Autonomous navigation system, Off-road vehicle software
# Target Client/Industries: Off-road vehicle manufacturers, Autonomous vehicle companies
#
# Processing 81: PeoplePlus
# Result: Product: HR management software, employee record management, performance tracking, applicant tracking system, benefits administration, advanced reporting tools
# Target Client/Industries: HR departments, recruitment agencies, large corporations, small and medium businesses
#
# Processing 82: Cantina
# Result: Product: Social interaction platform
# Target Client/Industries: Social media companies, online community platforms
#
# Processing 83: Oblio
# Result: Product: Inbox-based communication tool, Large scale email and text sending, University enrollment enhancement
# Target Client/Industries: universities, admissions officers, faculty staff, coaches
#
# Processing 84: VitVio
# Result: Product: Operating room efficiency software, Staff movement tracking, Equipment positioning system
# Target Client/Industries: Hospitals, Surgical centers, Healthcare providers
#
# Processing 85: SuperKalam
# Result: Product: Online learning platform, UPSC preparation resources
# Target Client/Industries: UPSC aspirants, students in India
#
# Processing 86: SpreeAI
# Result: Product: E-commerce optimization, Fashion trend prediction
# Target Client/Industries: Online retailers, Fashion brands, E-commerce businesses
#
# Processing 87: Assort Health
# Result: Product: Automated call system, Patient interaction improvement
# Target Client/Industries: Healthcare providers, Telehealth services
#
# Processing 88: Multimodal
# Result: Product: Document classification, Decision making tools, Information retrieval, Content generation
# Target Client/Industries: Banking sector, Insurance sector, Healthcare industry, Legal firms, Real estate companies, Technology companies
#
# Processing 89: Scavenger AI
# Result: Product: Data analysis, Decision-making tool
# Target Client/Industries: Business managers, Data analysts, Retail industry, Healthcare industry
#
# Processing 90: Autoblocks AI
# Result: Product: Evaluation tools, Testing tools for LLM products
# Target Client/Industries: Software developers, IT companies
#
# Processing 91: eComID
# Result: Product: Online product return reduction, Environmental footprint shrinkage, Shopping guidance
# Target Client/Industries: online retailers, fashion industry, retail technology firms
#
# Processing 92: Firsthand
# Result: Product: Agent platform
# Target Client/Industries: Brands, publishers
#
# Processing 93: Revocalize AI
# Result: Product: Singing voice platform, Vocal track creation, Human voice training models
# Target Client/Industries: music producers, audio engineers, entertainment industry
#
# Processing 94: Scaled Cognition
# Result: Product: Rational AI models, Domain expert systems
# Target Client/Industries: Tech companies, Healthcare providers, Financial institutions
#
# Processing 95: Caju AI
# Result: Product: Customer engagement platform, Workforce productivity tool, Business insight software
# Target Client/Industries: Internet service providers, Software development companies
#
# Processing 96: Cerbrec
# Result: Product: Deep learning framework, AI model builder
# Target Client/Industries: Biopharma researchers, Biotechnology engineers
#
# Processing 97: Shadeform AI
# Result: Product: API platform, GPU workloads access, Inference deployment, Training jobs deployment
# Target Client/Industries: software developers, tech companies
#
# Processing 98: Jan
# Result: Product: Cross-platform framework, Local-first framework, AI native framework
# Target Client/Industries: software developers, businesses seeking secure solutions
#
# Processing 99: NcodiN
# Result: Product: Nanophotonic chips, Data transport for processors
# Target Client/Industries: Semiconductor manufacturers, Data centers, High-performance computing industries
#
# Processing 100: Cimphony
# Result: Product: Legal solutions platform, Fixed price legal services, Commercial contracts, Fundraising support, Data privacy compliance, Employment compliance
# Target Client/Industries: Startups, Small to medium-sized businesses, Corporate legal departments
#
# Processing 101: Sendsteps.ai
# Result: Product: Presentation generation, Quiz creation
# Target Client/Industries: educators, corporate trainers, event organizers
#
# Processing 102: Spot On Chain
# Result: Product: Blockchain data platform
# Target Client/Industries: Financial institutions, Supply chain companies, Healthcare providers
#
# Processing 103: AIsphere
# Result: Product: Visual multimodal models, AIGC technology
# Target Client/Industries: content producers, service industry businesses
#
# Processing 104: Entrada
# Result: Product: Data modernization services, Data monetization services, Decision-making data services, Customer experience data services
# Target Client/Industries: Databricks users, businesses with data-centric services
#
# Processing 105: Vatic AI LLC
# Result: Product: Natural Language Processing algorithm, User-Generated Taxonomies creation
# Target Client/Industries: advertising agencies, IT companies
#
# Processing 106: FinanceOps.AI
# Result: Product: Collections Management Software, Risk Dataset Evaluation, Borrower Authentication, Personalized Collection Strategies
# Target Client/Industries: financial service providers, loan originators, debt collection agencies
#
# Processing 107: Uptime Industries
# Result: Product: LLM assistant, Compute Blade, Cluster Computing
# Target Client/Industries: enterprise businesses, computing industries, developers
#
# Processing 108: Forescribe
# Result: Product: SaaS expenditure and utilization dashboard, digital infrastructure management solution
# Target Client/Industries: modern enterprises, IT departments, finance departments
#
# Processing 109: Kamoto.AI
# Result: Product: Virtual AI character creation, AI character training, AI character rental, AI personality licensing, AI persona API
# Target Client/Industries: celebrities, influencers, social media personalities, app developers, fitness industry, language learning industry
#
# Processing 110: Twee
# Result: Product: Language learning platform, Teaching content generator, Lesson planning tools
# Target Client/Industries: English as a Foreign Language teachers, Education institutions
#
# Processing 111: Diagnose Early
# Result: Product: Health data platform, Breath analysis technology
# Target Client/Industries: Healthcare providers, Medical researchers, Wellness centers
#
# Processing 112: NeuralFabric
# Result: Product: Generative platform, AI model building
# Target Client/Industries: IT companies, data science firms
#
# Processing 113: LLUMO AI
# Result: Product: Engineering intelligence tools
# Target Client/Industries: Engineering firms, manufacturing companies
#
# Processing 114: Hear.ai
# Result: Product: Contact center platform
# Target Client/Industries: Customer service departments, Call centers, Telecommunication companies
#
# Processing 115: Myriad Venture Partners
# Result: Product: Investment funding, Financial solutions
# Target Client/Industries: AI startups, Software startups, Clean technology startups
#
# Processing 116: Smart Retrieval
# Result: Product: Document intelligence service, Data structuring automation
# Target Client/Industries: Businesses with large unstructured data, Consulting firms, IT companies
#
# Processing 117: Sol Health
# Result: Product: Therapy platform, Mental health support
# Target Client/Industries: College students, Early-career therapists
#
# Processing 118: Obinex
# Result: Product: Blockchain technology, Centralized Finance solutions
# Target Client/Industries: Financial institutions, Cryptocurrency exchanges, Blockchain startups
#
# Processing 119: Talentium
# Result: Product: Talent discovery platform, Automated communication system, Job dashboard, Performance statistics
# Target Client/Industries: recruiters, human resource departments, talent acquisition teams
#
# Processing 120: ZippiAi
# Result: Product: Maintenance assistance software, Troubleshooting tool, Knowledge sharing platform
# Target Client/Industries: Manufacturing engineers, Maintenance teams in industrial plants
#
# Processing 121: DailyAI
# Result: Product: News aggregation, Insights generation, Review platform
# Target Client/Industries: News agencies, Media companies, Journalists
#
# Processing 122: Dayos
# Result: Product: Managed services, Implementation support, ERP platforms, HR platforms
# Target Client/Industries: Oracle and SAP users, businesses in financial services, IT companies
#
# Processing 123: SS Ventures
# Result: Product: tech talent sourcing, startup investment, technology development
# Target Client/Industries: U.S. tech companies, startups, Series A companies
#
# Processing 124: Harmony
# Result: Product: Digital communication platform
# Target Client/Industries: Corporate businesses, remote teams
#
# Processing 125: Sobo
# Result: Product: Web-based dashboard, Data profile creation, Key metrics and peer benchmarking, Consultant matching
# Target Client/Industries: Small and medium-sized businesses, Consulting firms
#
# Processing 126: Orphex
# Result: Product: Digital marketing services, User behavior analytics
# Target Client/Industries: Advertising agencies, Music labels, Online retailers
#
# Processing 127: ApplyPass.com
# Result: Product: Job search tool, Job application submission
# Target Client/Industries: Job seekers, Recruitment agencies, HR departments
#
# Processing 128: IZDAT
# Result: Product: IT outsourcing, tech project development, venture studio services
# Target Client/Industries: startups, early-stage venture capital firms, tech innovators in AgTech, Biotechnology, FinTech, Human Resources, InsurTech, Life Science, Mobile Apps, Smart Home industries
#
# Processing 129: Echelon AI
# Result: Product: Autonomous drone software platform, Swarm intelligence algorithms, Real-time analytics, Mission planning and execution tools
# Target Client/Industries: Law enforcement agencies, Fire departments, Search-and-rescue teams, Military organizations
#
# Processing 130: LemonRocks
# Result: Product: Real-time startup insights, VC performance tracking, Co-investment opportunities
# Target Client/Industries: startup founders, venture capitalists, angel investors
#
# Processing 131: Qubex
# Result: Product: Kubernetes scaling solution
# Target Client/Industries: Enterprises in cloud computing, IT service providers
#
# Processing 132: Hypermode
# Result: Product: Operational framework for app development
# Target Client/Industries: App developers, tech startups
#
# Processing 133: Wagawin by W² Group
# Result: Product: Audience identification, Creative and audience data combination, Conversational Ads, Target group data generation, Motion data enrichment
# Target Client/Industries: Media agencies, Advertisers, Brands in various industries such as food, telecommunications, cosmetics
#
# Processing 134: GENIE AI
# Result: Product: Assistive intelligence technologies, Enterprise resource planning, Marketing automation, Sales automation
# Target Client/Industries: Enterprises, Marketing teams, Sales teams
#
# Processing 135: Neontra
# Result: Product: Personal finance management app, budgeting tool, cashflow analysis, financial planning, forecasting, net worth tracking
# Target Client/Industries: individuals seeking financial management, wealth management firms
#
# Processing 136: Nine Minds
# Result: Product: Managed service solutions
# Target Client/Industries: Managed service providers, IT service companies
#
# Processing 137: Payfederate
# Result: Product: Data analytics platform, Budgeting tool, Employee communication system
# Target Client/Industries: Financial departments, HR departments, Management teams
#
# Processing 138: Zion AI
# Result: Product: Dynamic learning capabilities, Real-time application creation, Intelligent resource management, Decentralized architecture
# Target Client/Industries: IT companies, Data centers, Cloud service providers
#
# Processing 139: OpenIntervue
# Result: Product: Interview platform, Recruitment process tool
# Target Client/Industries: Human resource departments, recruitment agencies
#
# Processing 140: Creative.ai
# Result: Product: Generative video platform, data-driven ads, predictive scores
# Target Client/Industries: gaming industry, marketing agencies, SaaS companies
#
# Processing 141: Clidrive
# Result: Product: Car financing platform, Credit risk evaluation
# Target Client/Industries: Car owners, Banks, Financial institutions
#
# Processing 142: Eilago
# Result: Product: Mobile travel booking application, Price tracking tool, Cancellation solutions, Gamified customer experience
# Target Client/Industries: Frequent travelers, Tourism industry, Hotel industry, Airline industry
#
# Processing 143: Synamics Therapeutics
# Result: Product: Computational drug design, Disease mechanism identification, Therapeutic target identification, Customized treatment design
# Target Client/Industries: Biotechnology companies, Pharmaceutical companies, Therapeutic research institutions, Life science research centers
#
# Processing 144: Maria Saúde
# Result: Product: Digital health platform, Personal doctor access, Health concierge, Nutritionist consultation, Unified health record, Virtual consultations, Intelligent referral system
# Target Client/Industries: Individuals seeking healthcare services, Healthcare providers, Insurance companies
#
# Processing 145: Byterise
# Result: Product: Product Optimization, Marketing Support, Budget Management, Finance Support, System Infrastructures
# Target Client/Industries: Tech startups, Small to medium-sized businesses in the tech industry
#
# Processing 146: goML
# Result: Product: Data engineering solutions, MLOps applications, LLM applications
# Target Client/Industries: Enterprises in need of data management, software companies
#
# Processing 147: H9 Technologies
# Result: Product: Web applications, Mobile apps, Website development, UI/UX design, Software development, Database development, Cloud operations, Data science, Virtual assistant development
# Target Client/Industries: businesses in need of digital transformation, mobile app developers, website owners, data-driven companies
#
# Processing 148: oodash
# Result: Product: Business Intelligence platform, Data chat service
# Target Client/Industries: Business analysts, data-driven companies
#
# Processing 149: BIOME9
# Result: Product: Home canine gut microbiome test
# Target Client/Industries: Pet owners, Veterinarians, Pet care services
#
# Processing 150: Propel Health AI
# Result: Product: Healthcare data platform, Clinical patient record collection, Data integration
# Target Client/Industries: Healthcare companies, Life sciences companies
#
# Processing 151: Dealerverse
# Result: Product: Integrated marketing platform, Single sign-on tech stack, Precision decision-making tool
# Target Client/Industries: Advertising agencies, Digital marketing firms, SaaS companies
#
# Processing 152: Emunocare
# Result: Product: Disease management services, Pain relief treatments, Mental health services
# Target Client/Industries: Patients with serious illnesses, Healthcare providers
#
# Processing 153: CanFY
# Result: Product: Data structure simplification, Help center system management, File metadata organization
# Target Client/Industries: IT companies, Internet service providers, SaaS businesses
#
# Processing 154: Wuwen Xinqiong
# Result: Product: AGI computing power solutions, Large model energy efficiency optimization tools
# Target Client/Industries: cloud service providers, electronics manufacturers
#
# Processing 155: Ambivo
# Result: Product: CRM platform, Email and SMS marketing, Task management, Customizable widgets, Payment solutions, Telephony
# Target Client/Industries: growing businesses, enterprises seeking productivity enhancement
#
# Processing 156: Krakatoa Technologies Pte. Ltd
# Result: Product: Power-efficient core, Battery Management System, Inference Accelerator
# Target Client/Industries: IoT companies, mobile market businesses, metaverse platforms
#
# Processing 157: Jaz
# Result: Product: Accounting and finance platform, mobile application
# Target Client/Industries: Accounting teams, finance teams, fintech companies
#
# Processing 158: Dataplatr
# Result: Product: Data engineering models, Data analytics, Data transformation, Data integration
# Target Client/Industries: enterprise clients, sales and marketing departments, operations management, financial institutions, supply chain companies, human resources departments
#
# Processing 159: blujin
# Result: Product: Employment Intelligence Platform, Job search technology, Candidate search technology
# Target Client/Industries: Job seekers, Recruitment agencies, HR departments in companies
#
# Processing 160: Anchor Node
# Result: Product: Game development, Mobile app creation
# Target Client/Industries: Game publishers, Mobile app companies
#
# Processing 161: Quantem.io
# Result: Product: Device Management Solution, Remote Device Locking, Data Wiping
# Target Client/Industries: Enterprises of all sizes, IT teams, Businesses with large device fleets
#
# Processing 162: Vanguard Tech
# Result: Product: Robotics software, Augmented Reality applications
# Target Client/Industries: small and medium enterprises, manufacturing companies, logistics companies
#
# Processing 163: {descrb}
# Result: Product: E-commerce content generation, Product identification, Online search, Content creation, Product image generation
# Target Client/Industries: online retailers, e-commerce businesses, digital marketers
#
# Processing 164: HeyWire AI
# Result: Product: Automated journalism software, Corporate content creation tool
# Target Client/Industries: Journalists, Corporate communication teams, Content creation agencies
#
# Processing 165: Selfweller
# Result: Product: Self-therapy application, Interactive exercises, Voice sessions
# Target Client/Industries: Individuals seeking mental health support, Healthcare providers
#
# Processing 166: Runwayer AI
# Result: Product: App onboarding solution, User journey creation, Subscription-based mobile apps
# Target Client/Industries: Mobile app developers, marketing teams, subscription service providers
#
# Processing 167: yippy GREEN
# Result: Product: Search engine, Online community
# Target Client/Industries: Green consumer goods manufacturers, Home and garden businesses, Organic food producers, Renewable energy companies, Sustainability-focused organizations
#
# Processing 168: EasyODM
# Result: Product: Machine vision software, Quality control, Defect detection, Production optimization
# Target Client/Industries: Textile manufacturers, Glass manufacturers, Wood processing companies, Pharmaceutical companies
#
# Processing 169: Zuzzuu
# Result: Product: Digital sales tools, Marketing tools
# Target Client/Industries: Digital marketing agencies, E-commerce businesses
#
# Processing 170: TechnoMigrate
# Result: Product: Technology solutions, Cloud services, Data analytics, CRM systems, Quantum computing services, Software engineering
# Target Client/Industries: IT departments, Data analysis firms, Customer service businesses, Quantum research institutions, Software development companies
#
# Processing 171: IQFluence
# Result: Product: Influence marketing platform, Data insights, Real-time analytics, Performance metrics
# Target Client/Industries: Marketing agencies, Brands
#
# Processing 172: Salma AI
# Result: Product: Conversational financial assistant, Banking app integration
# Target Client/Industries: Banks, Financial institutions
#
# Processing 173: Huoshan Innovation
# Result: Product: English teaching application
# Target Client/Industries: English learners, education institutions
#
# Processing 174: MedETechni
# Result: Product: UV phototherapy devices, Wound healing technology, Dermatological treatment devices
# Target Client/Industries: hospitals, dermatology clinics, wound care centers
#
# Processing 175: Maax Ai
# Result: Product: Machine learning solution, Lead nurturing, Customer service
# Target Client/Industries: Coaches, Experts
#
# Processing 176: Ai Model Agency
# Result: Product: Generative model creation, Try-on technology
# Target Client/Industries: Fashion brands, Advertising agencies, Media production companies
#
# Processing 177: WeForge
# Result: Product: Content creation platform, Brand asset customization, Social media post generator, Blog generator, Landing page generator
# Target Client/Industries: Brands, marketers, e-commerce stores, software companies
#
# Processing 178: WhataCart
# Result: Product: WhatsApp marketing platform, consumer segmentation, automation tools
# Target Client/Industries: e-commerce businesses, marketing agencies, retail companies
#
# Processing 179: DeepRad.AI
# Result: Product: Medical imaging software, Radiology analysis tool
# Target Client/Industries: Hospitals, Radiology clinics, Medical research institutions
#
# Processing 180: LowTech AI
# Result: Product: User-friendly AI tool
# Target Client/Industries: First-time AI users, non-technical individuals, UX designers
#
# Processing 181: Yunban AIGC
# Result: Product: Cloud platform, Short video and live broadcast operations, Technology research and development, Industry data solutions
# Target Client/Industries: Small and medium-sized enterprises
#
# Processing 182: Jacobi Robot
# Result: Product: Intelligent robot control systems
# Target Client/Industries: Manufacturing industries, Healthcare, Home automation companies
#
# Processing 183: XRF.ai
# Result: Product: Decision support system, Visual information presentation, Generative learning tools
# Target Client/Industries: Military decision-makers, Port and harbor authorities, Wildlife conservation organizations
#
# Processing 184: Sputee
# Result: Product: Confidential computing co-processor, Data security, High-performance computing
# Target Client/Industries: Data centers, Financial institutions, Healthcare providers
#
# Processing 185: AutomAI
# Result: Product: AI training, consultancy services, technology solutions
# Target Client/Industries: entrepreneurs, small to medium businesses
#
# Processing 186: Browills
# Result: Product: Blockchain solutions, IT consulting, Investment services
# Target Client/Industries: Financial institutions, IT companies, Investment firms
#
# Processing 187: CxC
# Result: Product: Customer sentiment analysis, Real-time sales insights, Personalized customer interactions, Compliance and accountability tools, Call transcript reviews
# Target Client/Industries: HVAC companies, Plumbing companies, Electrical service companies, Home service businesses
#
# Processing 188: Croppinn
# Result: Product: Crop health insights platform, Yield prediction tool, Satellite imagery analysis
# Target Client/Industries: Farmers, Agricultural businesses, Sustainable farming advocates
#
# Processing 189: SendBuzz
# Result: Product: Multi-channel cold outreach platform, Sales engagement, CRM integration, A/B testing, Flow testing, Mailbox warm up
# Target Client/Industries: B2B businesses, Sales teams, Marketing teams
#
# Processing 190: Avkalan
# Result: Product: Data analysis, Business transformation consulting
# Target Client/Industries: Retail businesses, Healthcare providers, Financial institutions
#
# Processing 191: TheStage AI
# Result: Description: Full-stack platform for artificial intelligence
# Industries: ['Artificial Intelligence', 'Technology']
# Product: AI platform development
# Target Client/Industries: tech companies, data science teams
#
# Processing 192: Veloce Cloud Computing
# Result: Product: Cloud-based analytical models, Multi-cloud environment tools, Hybrid environment tools
# Target Client/Industries: data analysis firms, cloud service providers, tech startups
#
# Processing 193: Amani Creative Studios
# Result: Product: Brand Development, Graphic and Digital Design, Creative Space, Content Creation, Web Design and Development, E-commerce Solutions, Mobile App Development, Chatbot Integration, Content Localization, Legal and Compliance Consulting, Cybersecurity Services, Print and Online Advertising Campaigns
# Target Client/Industries: businesses needing brand development, digital design, web and app development, e-commerce businesses, businesses expanding globally, businesses needing legal and compliance consulting, businesses needing cybersecurity services, businesses needing advertising campaigns.
#
# Processing 194: Magnify
# Result: Product: Cloud-based solutions, DevOps engineering, Quality assurance services
# Target Client/Industries: IT companies, software development firms, businesses transitioning to cloud infrastructure
#
# Processing 195: SolaaX
# Result: Product: Event management software, Venue booking system, Data analytics
# Target Client/Industries: Event planners, Venue owners, Hospitality industry
#
# Processing 196: Bright AI
# Result: Product: Language learning mobile applications
# Target Client/Industries: Language learners, educators, educational institutions
#
# Processing 197: Tutorac Academy
# Result: Product: Online learning platform, Video content, Doubt sessions, Test generation
# Target Client/Industries: Students, Teachers, Educational Institutions
#
# Processing 198: DashStack
# Result: Product: Data integration platform, Data analysis, Data protection
# Target Client/Industries: Cloud-based businesses, Data-driven organizations, Cybersecurity firms
#
# Processing 199: Enigma Genomics
# Result: Product: Genomic data analysis, Genetic research software
# Target Client/Industries: Biotech companies, Genetic research institutions, Healthcare providers
# /var/folders/nf/2dvvlnxj5v962kwwzmpfj17h0000gn/T/ipykernel_43654/1423487665.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_df['generated_result'] = results

# %%
sample_df.head()
# Out:
#      Unnamed: 0 organization name num employees founded date  \
# 981         981        Mistral AI         11-50         2023
# 982         982            Sierra         11-50         2023
# 983         983      Essential AI         11-50         2023
# 984         984             Lindy         11-50         2023
# 985         985          Poolside         11-50         2023
#
#                                            description  \
# 981  Mistral AI is an AI startup that provides deve...
# 982  Sierra is an AI startup that tackles essential...
# 983  Essential AI creates AI solutions that enhance...
# 984  Lindy is an AI assistant that can help with al...
# 985  Poolside is an artificial intelligence platfor...
#
#                                             industries  \
# 981  Artificial Intelligence (AI), Generative AI, M...
# 982  Artificial Intelligence (AI), Enterprise Softw...
# 983  Artificial Intelligence (AI), Information Tech...
# 984  Artificial Intelligence (AI), Internet, Softwa...
# 985  Artificial Intelligence (AI), Developer Platfo...
#
#                         headquarters location  \
# 981              Paris, Ile-de-France, France
# 982  San Francisco, California, United States
# 983  San Francisco, California, United States
# 984  San Francisco, California, United States
# 985              Paris, Ile-de-France, France
#
#                                          description.1 cb rank postal code  \
# 981  Mistral AI is an AI startup that provides deve...       7       75001
# 982  Sierra is an AI startup that tackles essential...     259           —
# 983  Essential AI creates AI solutions that enhance...     321           —
# 984                       Your AI executive assistant.     599           —
# 985  Poolside is an artificial intelligence platfor...     924           —
#
#      ...     hub tag phone num num of sub org  \
# 981  ...           —   Unicorn              —
# 982  ...           —         —              —
# 983  ...           —         —              —
# 984  ...  6048488619         —              —
# 985  ...           —         —              —
#
#                                        industry groups total funding amt  \
# 981  Artificial Intelligence (AI), Data and Analyti...    €1,105,000,000
# 982  Artificial Intelligence (AI), Data and Analyti...      $110,000,000
# 983  Artificial Intelligence (AI), Data and Analyti...       $64,500,000
# 984  Apps, Artificial Intelligence (AI), Data and A...       $49,900,000
# 985  Artificial Intelligence (AI), Data and Analyti...      $126,000,000
#
#     company type estimated rev  \
# 981   For Profit             —
# 982            —             —
# 983   For Profit             —
# 984   For Profit   $1M to $10M
# 985   For Profit             —
#
#                                        description_all  \
# 981  Mistral AI is an AI startup that provides deve...
# 982  Sierra is an AI startup that tackles essential...
# 983  Essential AI creates AI solutions that enhance...
# 984  Lindy is an AI assistant that can help with al...
# 985  Poolside is an artificial intelligence platfor...
#
#                                      industries_parsed  \
# 981  ['Generative AI', 'Machine Learning', 'Natural...
# 982                    ['Enterprise Software', 'SaaS']
# 983             ['Information Technology', 'Software']
# 984  ['Internet', 'Software', 'Virtual Assistant', ...
# 985                 ['Developer Platform', 'Software']
#
#                                       generated_result
# 981  Product: Generative solutions, Open AI tools, ...
# 982  Product: Conversational agents, Business solut...
# 983  Product: Automation solutions, Large Language ...
# 984  Product: Virtual assistant, Calendar managemen...
# 985  Product: Software creation platform\nTarget Cl...
#
# [5 rows x 26 columns]

# %%
sample_df[['shortened_description', 'target_industries']] = sample_df['generated_description'].str.extract(r'Product:\s*(.*)\s*Target Client/Industries:\s*(.*)').apply(lambda x: x.str.strip())
sample_df.head()
sample_df.to_csv('./output/sample_df_with_results.csv', index=False)
# Out:
# /var/folders/nf/2dvvlnxj5v962kwwzmpfj17h0000gn/T/ipykernel_43654/1876620023.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_df[['shortened_description', 'target_industries']] = sample_df['generated_description'].str.extract(r'Product:\s*(.*)\s*Target Client/Industries:\s*(.*)').apply(lambda x: x.str.strip())

# %%
sample_df['embedding'] = sample_df.generated_description.apply(lambda text: x.get_embedding(text, model='text-embedding-3-small'))
sample_df.to_csv('./output/sample_df_with_openai_embeddings.csv', index=False)
# Out:
# /var/folders/nf/2dvvlnxj5v962kwwzmpfj17h0000gn/T/ipykernel_43654/4022179025.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_df['embedding'] = sample_df.generated_description.apply(lambda text: x.get_embedding(text, model='text-embedding-3-small'))

# %%
from sklearn.metrics.pairwise import cosine_similarity
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
import matplotlib.pyplot as plt
import seaborn as sns

# Convert embeddings column to a numpy array
embeddings = np.array(sample_df['embedding'].tolist())

# Compute the cosine similarity matrix
similarity_matrix = cosine_similarity(embeddings)

# Display the similarity matrix
print("Cosine Similarity Matrix:")
print(similarity_matrix)

# Convert cosine similarity to cosine distance
distance_matrix = 1 - similarity_matrix

# Perform hierarchical clustering using the distance matrix
linkage_matrix = linkage(distance_matrix, method='average')

# Plot the dendrogram
plt.figure(figsize=(8, 6))
dendrogram(linkage_matrix, labels=np.arange(len(embeddings)))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.show()

# Extract cluster labels (e.g., for 2 clusters)
cluster_labels = fcluster(linkage_matrix, t=30, criterion='maxclust')
print("Cluster Labels:", cluster_labels)

# Add cluster labels to the DataFrame using .loc
sample_df.loc[:, 'cluster_label'] = cluster_labels



# Display the DataFrame with the new cluster labels
sample_df.head()
# Out:
# Cosine Similarity Matrix:
# [[1.         0.54476921 0.6145647  ... 0.4358054  0.4570117  0.51331288]
#  [0.54476921 1.         0.63979845 ... 0.43738703 0.51161952 0.42438187]
#  [0.6145647  0.63979845 1.         ... 0.43126491 0.53040371 0.4835241 ]
#  ...
#  [0.4358054  0.43738703 0.43126491 ... 1.         0.38599076 0.39323736]
#  [0.4570117  0.51161952 0.53040371 ... 0.38599076 1.         0.56876676]
#  [0.51331288 0.42438187 0.4835241  ... 0.39323736 0.56876676 1.        ]]
# Cluster Labels: [ 2 11  2 30  7  2 16  9  4  1  1  9  5 17  9 26  2  9  9 19  4  1 18 10
#   4 17 17 17  3  5  8  7 11 18 24  1  9 18 16  7 27 18  6 30 18 18 28 11
#   2  7 17 21 27 11  4  7  2  5  6 11  6 16 11  4 21 24 11 12 11 29 25  2
#  24 10  2  5 18  5 19 22 12 17  7 30 24 29 25 24 18 10 16 25  7 28  2 11
#   1  2  4 20 27 29  8 25 15 25  9 14 18 28 29 23  2 10 11  3 18 24  8  5
#  18  6 11  3 11 10  7  5  3 12  3 14  4  7 11  9 11 10 11  5  7  9 26 21
#  23 11 10  3 10 21 23  7 21 18 14 11 14  9 10  5  4 18 12  6  6 24  4 25
#  18  7 10  7  9 29 21 11 25  6  7 23  1 11 12 13 20  2  8  5 18  5 10  2
#  10 27 11 17 29 29 10 23]
# /var/folders/nf/2dvvlnxj5v962kwwzmpfj17h0000gn/T/ipykernel_43654/2725226299.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_df.loc[:, 'cluster_label'] = cluster_labels
#      Unnamed: 0 organization name num employees founded date  \
# 981         981        Mistral AI         11-50         2023
# 982         982            Sierra         11-50         2023
# 983         983      Essential AI         11-50         2023
# 984         984             Lindy         11-50         2023
# 985         985          Poolside         11-50         2023
#
#                                            description  \
# 981  Mistral AI is an AI startup that provides deve...
# 982  Sierra is an AI startup that tackles essential...
# 983  Essential AI creates AI solutions that enhance...
# 984  Lindy is an AI assistant that can help with al...
# 985  Poolside is an artificial intelligence platfor...
#
#                                             industries  \
# 981  Artificial Intelligence (AI), Generative AI, M...
# 982  Artificial Intelligence (AI), Enterprise Softw...
# 983  Artificial Intelligence (AI), Information Tech...
# 984  Artificial Intelligence (AI), Internet, Softwa...
# 985  Artificial Intelligence (AI), Developer Platfo...
#
#                         headquarters location  \
# 981              Paris, Ile-de-France, France
# 982  San Francisco, California, United States
# 983  San Francisco, California, United States
# 984  San Francisco, California, United States
# 985              Paris, Ile-de-France, France
#
#                                          description.1 cb rank postal code  \
# 981  Mistral AI is an AI startup that provides deve...       7       75001
# 982  Sierra is an AI startup that tackles essential...     259           —
# 983  Essential AI creates AI solutions that enhance...     321           —
# 984                       Your AI executive assistant.     599           —
# 985  Poolside is an artificial intelligence platfor...     924           —
#
#      ... total funding amt company type estimated rev  \
# 981  ...    €1,105,000,000   For Profit             —
# 982  ...      $110,000,000            —             —
# 983  ...       $64,500,000   For Profit             —
# 984  ...       $49,900,000   For Profit   $1M to $10M
# 985  ...      $126,000,000   For Profit             —
#
#                                        description_all  \
# 981  Mistral AI is an AI startup that provides deve...
# 982  Sierra is an AI startup that tackles essential...
# 983  Essential AI creates AI solutions that enhance...
# 984  Lindy is an AI assistant that can help with al...
# 985  Poolside is an artificial intelligence platfor...
#
#                                      industries_parsed  \
# 981  ['Generative AI', 'Machine Learning', 'Natural...
# 982                    ['Enterprise Software', 'SaaS']
# 983             ['Information Technology', 'Software']
# 984  ['Internet', 'Software', 'Virtual Assistant', ...
# 985                 ['Developer Platform', 'Software']
#
#                                  generated_description  \
# 981  Product: Generative solutions, Open AI tools, ...
# 982  Product: Conversational agents, Business solut...
# 983  Product: Automation solutions, Large Language ...
# 984  Product: Virtual assistant, Calendar managemen...
# 985  Product: Software creation platform\nTarget Cl...
#
#                                  shortened_description  \
# 981  Generative solutions, Open AI tools, Portable ...
# 982  Conversational agents, Business solutions inte...
# 983        Automation solutions, Large Language Models
# 984  Virtual assistant, Calendar management, Email ...
# 985                         Software creation platform
#
#                                      target_industries  \
# 981  software developers, tech businesses, AI indus...
# 982   Enterprise businesses, Customer support services
# 983           IT companies, software development firms
# 984  Executives, Managers, Professionals needing ad...
# 985                 software developers, tech startups
#
#                                              embedding cluster_label
# 981  [-0.015639672055840492, -0.006143242586404085,...             2
# 982  [-0.035755936056375504, -0.00605357950553298, ...            11
# 983  [-0.04780449718236923, -0.0036870490293949842,...             2
# 984  [-0.03962145373225212, 0.019231606274843216, 0...            30
# 985  [0.0005861703539267182, 0.006601412780582905, ...             7
#
# [5 rows x 30 columns]

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler


# Convert embeddings column to a numpy array
embeddings = np.array(sample_df['embedding'].tolist())
cluster_labels = list(sample_df["cluster_label"])
# Standardize the embeddings (optional but recommended)
scaler = StandardScaler()
embeddings_scaled = scaler.fit_transform(embeddings)

# Apply PCA to reduce dimensions to 2
pca = PCA(n_components=2)
embeddings_pca = pca.fit_transform(embeddings_scaled)

# Create a new DataFrame with the PCA results and cluster labels
pca_df = pd.DataFrame(data=embeddings_pca, columns=['PC1', 'PC2'])
pca_df['cluster_label'] = cluster_labels

# Plot the PCA results with cluster labels
plt.figure(figsize=(15, 6))
for label in np.unique(cluster_labels):
    subset = pca_df[pca_df['cluster_label'] == label]
    plt.scatter(subset['PC1'], subset['PC2'], label=f'Cluster {label}')
plt.title('PCA of Embeddings with Clustering')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()
plt.show()

# Display the DataFrame with the new cluster labels
print(sample_df)
# Out:
#       Unnamed: 0 organization name num employees founded date  \
# 981          981        Mistral AI         11-50         2023
# 982          982            Sierra         11-50         2023
# 983          983      Essential AI         11-50         2023
# 984          984             Lindy         11-50         2023
# 985          985          Poolside         11-50         2023
# ...          ...               ...           ...          ...
# 1186        1186            SolaaX         11-50         2023
# 1187        1187         Bright AI         11-50         2023
# 1188        1188   Tutorac Academy         11-50  Jan 1, 2023
# 1190        1190         DashStack         11-50         2023
# 1191        1191   Enigma Genomics         11-50         2023
#
#                                             description  \
# 981   Mistral AI is an AI startup that provides deve...
# 982   Sierra is an AI startup that tackles essential...
# 983   Essential AI creates AI solutions that enhance...
# 984   Lindy is an AI assistant that can help with al...
# 985   Poolside is an artificial intelligence platfor...
# ...                                                 ...
# 1186  SolaaX is an Experience Focused, AI-Powered, a...
# 1187  UAE-based Bright AI is a publisher of innovati...
# 1188  Tutorac Academy is a 360o e-learning platform ...
# 1190  DashStack empowers organizations to make meani...
# 1191                                                  —
#
#                                              industries  \
# 981   Artificial Intelligence (AI), Generative AI, M...
# 982   Artificial Intelligence (AI), Enterprise Softw...
# 983   Artificial Intelligence (AI), Information Tech...
# 984   Artificial Intelligence (AI), Internet, Softwa...
# 985   Artificial Intelligence (AI), Developer Platfo...
# ...                                                 ...
# 1186                                                  —
# 1187                                                  —
# 1188                                  EdTech, Education
# 1190  Analytics, Artificial Intelligence (AI), Big D...
# 1191          Biotechnology, Genetics, Machine Learning
#
#                            headquarters location  \
# 981                 Paris, Ile-de-France, France
# 982     San Francisco, California, United States
# 983     San Francisco, California, United States
# 984     San Francisco, California, United States
# 985                 Paris, Ile-de-France, France
# ...                                          ...
# 1186   Eindhoven, Noord-Brabant, The Netherlands
# 1187  Abu Dhabi, Abu Dhabi, United Arab Emirates
# 1188            Hyderabad, Andhra Pradesh, India
# 1190                                           —
# 1191         Dammam, Ash Sharqiyah, Saudi Arabia
#
#                                           description.1  cb rank postal code  \
# 981   Mistral AI is an AI startup that provides deve...        7       75001
# 982   Sierra is an AI startup that tackles essential...      259           —
# 983   Essential AI creates AI solutions that enhance...      321           —
# 984                        Your AI executive assistant.      599           —
# 985   Poolside is an artificial intelligence platfor...      924           —
# ...                                                 ...      ...         ...
# 1186  SolaaX is an Experience Focused, AI-Powered, a...  568,183           —
# 1187          Mobile apps for language learning with AI  598,854           —
# 1188        Tutorac Academy: An online edtech platform.  611,511       50081
# 1190  DashStack simplifies the integration, analysis...  633,387           —
# 1191  Enigma Genomics is a genomics company that spe...  653,027       34265
#
#       ... total funding amt company type estimated rev  \
# 981   ...    €1,105,000,000   For Profit             —
# 982   ...      $110,000,000            —             —
# 983   ...       $64,500,000   For Profit             —
# 984   ...       $49,900,000   For Profit   $1M to $10M
# 985   ...      $126,000,000   For Profit             —
# ...   ...               ...          ...           ...
# 1186  ...                 —            —             —
# 1187  ...                 —   For Profit             —
# 1188  ...                 —   For Profit             —
# 1190  ...                 —   For Profit   $1M to $10M
# 1191  ...                 —   For Profit             —
#
#                                         description_all  \
# 981   Mistral AI is an AI startup that provides deve...
# 982   Sierra is an AI startup that tackles essential...
# 983   Essential AI creates AI solutions that enhance...
# 984   Lindy is an AI assistant that can help with al...
# 985   Poolside is an artificial intelligence platfor...
# ...                                                 ...
# 1186  SolaaX is an Experience Focused, AI-Powered, a...
# 1187  UAE-based Bright AI is a publisher of innovati...
# 1188  Tutorac Academy is a 360o e-learning platform ...
# 1190  DashStack empowers organizations to make meani...
# 1191  — Enigma Genomics is a genomics company that s...
#
#                                       industries_parsed  \
# 981   ['Generative AI', 'Machine Learning', 'Natural...
# 982                     ['Enterprise Software', 'SaaS']
# 983              ['Information Technology', 'Software']
# 984   ['Internet', 'Software', 'Virtual Assistant', ...
# 985                  ['Developer Platform', 'Software']
# ...                                                 ...
# 1186                                                 []
# 1187                                                 []
# 1188                            ['EdTech', 'Education']
# 1190  ['Analytics', 'Big Data', 'Cyber Security', 'D...
# 1191  ['Biotechnology', 'Genetics', 'Machine Learning']
#
#                                   generated_description  \
# 981   Product: Generative solutions, Open AI tools, ...
# 982   Product: Conversational agents, Business solut...
# 983   Product: Automation solutions, Large Language ...
# 984   Product: Virtual assistant, Calendar managemen...
# 985   Product: Software creation platform\nTarget Cl...
# ...                                                 ...
# 1186  Product: Event management software, Venue book...
# 1187  Product: Language learning mobile applications...
# 1188  Product: Online learning platform, Video conte...
# 1190  Product: Data integration platform, Data analy...
# 1191  Product: Genomic data analysis, Genetic resear...
#
#                                   shortened_description  \
# 981   Generative solutions, Open AI tools, Portable ...
# 982   Conversational agents, Business solutions inte...
# 983         Automation solutions, Large Language Models
# 984   Virtual assistant, Calendar management, Email ...
# 985                          Software creation platform
# ...                                                 ...
# 1186  Event management software, Venue booking syste...
# 1187              Language learning mobile applications
# 1188  Online learning platform, Video content, Doubt...
# 1190  Data integration platform, Data analysis, Data...
# 1191   Genomic data analysis, Genetic research software
#
#                                       target_industries  \
# 981   software developers, tech businesses, AI indus...
# 982    Enterprise businesses, Customer support services
# 983            IT companies, software development firms
# 984   Executives, Managers, Professionals needing ad...
# 985                  software developers, tech startups
# ...                                                 ...
# 1186  Event planners, Venue owners, Hospitality indu...
# 1187  Language learners, educators, educational inst...
# 1188       Students, Teachers, Educational Institutions
# 1190  Cloud-based businesses, Data-driven organizati...
# 1191  Biotech companies, Genetic research institutio...
#
#                                               embedding cluster_label
# 981   [-0.015639672055840492, -0.006143242586404085,...             2
# 982   [-0.035755936056375504, -0.00605357950553298, ...            11
# 983   [-0.04780449718236923, -0.0036870490293949842,...             2
# 984   [-0.03962145373225212, 0.019231606274843216, 0...            30
# 985   [0.0005861703539267182, 0.006601412780582905, ...             7
# ...                                                 ...           ...
# 1186  [-0.06166321784257889, 0.035745106637477875, 0...            17
# 1187  [-0.04158160090446472, -0.011192887090146542, ...            29
# 1188  [-0.021622052416205406, -0.02330751344561577, ...            29
# 1190  [0.009390056133270264, 0.0023903215769678354, ...            10
# 1191  [-0.018494145944714546, 0.02626429684460163, 0...            23
#
# [200 rows x 30 columns]

# %%
list(sample_df[sample_df["cluster_label"]==1].generated_description)
# Out:
# ['Product: Nature-inspired intelligence model\nTarget Client/Industries: Tech companies, Research institutions',
#  'Product: Federated learning framework, Distributed data training, AI model improvement\nTarget Client/Industries: Banking Circle, Nokia, Porsche, Brave',
#  'Product: GenAI Security Platform\nTarget Client/Industries: Enterprises adopting Generative AI, Cybersecurity teams',
#  'Product: Personal AI assistant, On-device AI technology, Large Language Models, Real-time knowledge capture, Voice interactions\nTarget Client/Industries: mobile app users, privacy-conscious individuals, public and private sectors',
#  'Product: Deep learning framework, AI model builder\nTarget Client/Industries: Biopharma researchers, Biotechnology engineers',
#  'Product: User-friendly AI tool\nTarget Client/Industries: First-time AI users, non-technical individuals, UX designers']

# %%
x = sample_df[sample_df["cluster_label"]==2][["organization name","generated_description"]]
for index, row in x.iterrows():
    print(f"Organization Name: {row['organization name']}")
    print(f"Generated Description: {row['generated_description']}\n")
# Out:
# Organization Name: Finpilot
# Generated Description: Product: Chatbot tool, Corporate file exploration, Natural language response system
# Target Client/Industries: Financial analysts, Corporate researchers
#
# Organization Name: Spiffy AI
# Generated Description: Product: Outcome-Oriented Models, Client behavior comprehension, Experience enhancement tools
# Target Client/Industries: Customer service providers, Retail businesses, E-commerce platforms
#
# Organization Name: Fifth Dimension AI
# Generated Description: Product: Data analysis, Content creation, Marketing performance
# Target Client/Industries: Research teams, Marketing teams
#
# Organization Name: Sentify
# Generated Description: Product: Sentiment analysis tool, Customer experience insights, Conversation analysis
# Target Client/Industries: Customer service departments, Market research firms, Social media management teams
#
# Organization Name: Salespeak
# Generated Description: Product: Sales conversation analysis, Sales coaching tools, Sales performance metrics
# Target Client/Industries: B2B sales teams, Sales training organizations
#
# Organization Name: Magic Feedback
# Generated Description: Product:
# Review compilation platform, User feedback analysis
# Target Client/Industries:
# Online retailers, E-commerce businesses, Customer service departments
#
# Organization Name: tellet.ai
# Generated Description: Product:
# Conversational platform, Market research tools
# Target Client/Industries: Marketers, Insight specialists, Market research industry

# %%
# Function to generate labels using x.ask
def generate_label(text_bubble):
    prompt = f"""
    Your role is to generate a label name for the following combined descriptions. Make it simple and understandable. Make it specific to the industry. Do not use vague words like comprehensive.
    EXAMPLE BELOW
    _________________
    Descriptions:
    'Product: Chatbot tool, Corporate file exploration, Natural language response system\nTarget Client/Industries: Financial analysts, Corporate researchers',
    'Product: Outcome-Oriented Models, Client behavior comprehension, Experience enhancement tools\nTarget Client/Industries: Customer service providers, Retail businesses, E-commerce platforms',
    'Product: Data analysis, Content creation, Marketing performance\nTarget Client/Industries: Research teams, Marketing teams',
    'Product: Sentiment analysis tool, Customer experience insights, Conversation analysis\nTarget Client/Industries: Customer service departments, Market research firms, Social media management teams',
    'Product: Sales conversation analysis, Sales coaching tools, Sales performance metrics\nTarget Client/Industries: B2B sales teams, Sales training organizations',
    'Product: \nReview compilation platform, User feedback analysis\nTarget Client/Industries: \nOnline retailers, E-commerce businesses, Customer service departments',
    'Product: \nConversational platform, Market research tools\nTarget Client/Industries: Marketers, Insight specialists, Market research industry
    Label Name: Sales/Customer Service
    _________________
    Now, your turn:
    Descriptions: {text_bubble}
    Label name:
    """
    return x.ask(prompt)

# Create a dictionary to store text bubbles for each cluster
text_bubbles = {}

# Group descriptions by cluster labels and concatenate them
for label in sample_df['cluster_label'].unique():
    descriptions = list(sample_df[sample_df['cluster_label'] == label]['generated_description'])
    text_bubbles[label] = " ".join(descriptions)

# Generate label names for each cluster
cluster_labels = {}
for label, text_bubble in text_bubbles.items():
    cluster_labels[label] = generate_label(text_bubble)

# Add the generated labels back to the DataFrame
sample_df['generated_cluster_label'] = sample_df['cluster_label'].map(cluster_labels)

# Display the updated DataFrame
print(sample_df)
# Out:
#     organization name num employees founded date  \
# 0                Pika          1-10         2023
# 1       Contextual AI          1-10         2023
# 2           Liquid AI          1-10         2023
# 3                 Ava          1-10         2023
# 4          LlamaIndex          1-10         2023
# ..                ...           ...          ...
# 164             Twine          1-10         2023
# 165          Tabor.AI          1-10         2023
# 166           Kontigo          1-10         2023
# 167            AiFlow          1-10     Jan 2023
# 168           BitSync          1-10         2023
#
#                                            description  \
# 0    Pika is a startup that is developing an AI-pow...
# 1    Contextual AI offers a pioneering approach to ...
# 2    Liquid AI is a developer of AI applications th...
# 3                             Ava is an AI dating app.
# 4    LlamaIndex is a simple, flexible data framewor...
# ..                                                 ...
# 164  Twine makes sure your small business never mis...
# 165  Tabor AI has developed a groundbreaking ChatGP...
# 166  We help underbanked gig workers in Latam build...
# 167  AiFlow Powers Executive Search and Board Advis...
# 168  BitSync provides unparalleled access to GPUs f...
#
#                                             industries  \
# 0    Artificial Intelligence (AI), Generative AI, G...
# 1    Artificial Intelligence (AI), Generative AI, S...
# 2    Artificial Intelligence (AI), Generative AI, I...
# 3                                             Software
# 4               Artificial Intelligence (AI), Software
# ..                                                 ...
# 164  Artificial Intelligence (AI), Customer Service...
# 165                              Health Care, Software
# 166    Artificial Intelligence (AI), FinTech, Software
# 167  Artificial Intelligence (AI), FinTech, Natural...
# 168  Artificial Intelligence (AI), Cloud Computing,...
#
#                         headquarters location  \
# 0        Palo Alto, California, United States
# 1    Mountain View, California, United States
# 2     Cambridge, Massachusetts, United States
# 3                Paris, Ile-de-France, France
# 4    San Francisco, California, United States
# ..                                        ...
# 164  San Francisco, California, United States
# 165           Atlanta, Georgia, United States
# 166  San Francisco, California, United States
# 167  San Francisco, California, United States
# 168         New York, New York, United States
#
#                                          description.1 cb rank postal code  \
# 0    Pika is a startup that develops an AI-powered ...      78           —
# 1    Contextual AI offers a pioneering approach to ...     219       94040
# 2    Liquid AI is a developer of AI applications th...     516        2142
# 3                             Ava is an AI dating app.     653           —
# 4    LlamaIndex is a simple, flexible data framewor...     814           —
# ..                                                 ...     ...         ...
# 164  Turning missed calls into bookings for small b...  46,665       94103
# 165  Tabor AI has developed a groundbreaking ChatGP...  46,808       30326
# 166     A bank built in WhatsApp for Latam gig workers  46,893       94123
# 167  AI-Based Candidate Identification for the C-Suite  46,953           —
# 168                     BitSync is a GPU Cloud for AI.  47,059           —
#
#                                    headquarters region  ... cluster_label  \
# 0    San Francisco Bay Area, Silicon Valley, West C...  ...            19
# 1    San Francisco Bay Area, Silicon Valley, West C...  ...             4
# 2         Greater Boston Area, East Coast, New England  ...            19
# 3    European Union (EU), Europe, Middle East, and ...  ...            22
# 4       San Francisco Bay Area, West Coast, Western US  ...            10
# ..                                                 ...  ...           ...
# 164     San Francisco Bay Area, West Coast, Western US  ...             1
# 165      Greater Atlanta Area, East Coast, Southern US  ...             1
# 166     San Francisco Bay Area, West Coast, Western US  ...            25
# 167     San Francisco Bay Area, West Coast, Western US  ...             3
# 168  Greater New York Area, East Coast, Northeaster...  ...            10
#
#                                  generated_description  \
# 0    Product: Film editing platform, Caption-to-vid...
# 1    Product: Generative software, Workplace effici...
# 2    Product: Neural network applications, Creative...
# 3    Product: Dating application, Matchmaking servi...
# 4    Product: Data framework, Custom data source co...
# ..                                                 ...
# 164  Product: \nConversational customer engagement,...
# 165  Product: ChatGPT Plugin, Competitive Market In...
# 166  Product: \nIncome validation, Group savings, G...
# 167  Product: Executive search software, Board advi...
# 168  Product: GPU cloud computing, Deep learning pl...
#
#                                    shortened_embedding  \
# 0    [-0.004095326643437147, 0.04505584016442299, -...
# 1    [0.01654336415231228, 0.023287253454327583, 0....
# 2    [0.01920264959335327, 0.04073550924658775, 0.0...
# 3    [-0.0316319614648819, -0.0006165459053590894, ...
# 4    [0.0005234783166088164, -0.03611835464835167, ...
# ..                                                 ...
# 164  [-0.012939393520355225, -0.007424606010317802,...
# 165  [-0.048156388103961945, -0.02235727198421955, ...
# 166  [-0.029866522178053856, 0.0167820043861866, 0....
# 167  [-0.001711074379272759, -0.01742435432970524, ...
# 168  [-0.001169081311672926, -0.03234323486685753, ...
#
#                                  shortened_description  \
# 0    AI-powered film editing and generation, Video ...
# 1    Generative AI for workplace applications, AI-p...
# 2    AI-driven workflow improvement tools, Creative...
# 3     AI-powered dating app, Virtual dating assistance
# 4    Data integration, Custom data sourcing, Langua...
# ..                                                 ...
# 164  Conversational AI for customer engagement, Cal...
# 165  AI Chatbot for senior housing and care sector,...
# 166  Credit building, group financing, income valid...
# 167  AI-powered executive search, Board advisory, C...
# 168  GPU Cloud provider for deep learning, Scalable...
#
#                                      target_industries  \
# 0    Filmmakers, Video Editors, Content Creators, M...
# 1    Corporations, tech companies, startups, AI con...
# 2    Creative agencies, workflow managers, producti...
# 3     Singles, dating services, online dating industry
# 4    Companies dealing with large datasets, data sc...
# ..                                                 ...
# 164                Small businesses, Service providers
# 165  Senior living communities operators, REITs, in...
# 166  gig workers in Latin America, underbanked indi...
# 167  Executive search firms, business enterprises, ...
# 168  AI researchers, data scientists, deep learning...
#
#                                   industries_embedding  \
# 0    [-0.013917695730924606, 0.03840973228216171, -...
# 1    [-0.023459946736693382, 0.0033064140006899834,...
# 2    [0.014888757839798927, 0.028724199160933495, 0...
# 3    [-0.03009849414229393, -0.004982085898518562, ...
# 4    [0.020727330818772316, -0.01563122123479843, 0...
# ..                                                 ...
# 164  [-0.03155858442187309, 0.014619050547480583, 0...
# 165  [0.030657118186354637, -0.018827883526682854, ...
# 166  [-0.029082998633384705, 0.0019731686916202307,...
# 167  [0.012867594137787819, 0.0006080437451601028, ...
# 168  [0.0102543318644166, -0.03356866165995598, 0.0...
#
#                        shortened_description_embedding  \
# 0    [-0.013025224208831787, 0.03505336120724678, 0...
# 1    [0.000775037391576916, 0.00012744541163556278,...
# 2    [0.009727372787892818, 0.048165734857320786, 0...
# 3    [-0.06198641285300255, 0.01912080869078636, 0....
# 4    [-0.049139682203531265, 0.01791500672698021, 0...
# ..                                                 ...
# 164  [-0.0166468545794487, -0.014596434310078621, 0...
# 165  [0.012190119363367558, -0.03467714414000511, 0...
# 166  [-0.014095190912485123, 0.019871223717927933, ...
# 167  [0.007570903282612562, -0.005809573456645012, ...
# 168  [-0.018745331093668938, -0.03904515132308006, ...
#
#                                 shortened_description2  \
# 0    film editing and generation, Video creation fr...
# 1    workplace applications, Insights, Strategy Con...
# 2    workflow improvement tools, Creative Process E...
# 3                dating app, Virtual dating assistance
# 4    Data integration, Custom data sourcing, Langua...
# ..                                                 ...
# 164  Conversational for customer engagement, Call m...
# 165  Chatbot for senior housing and care sector, Re...
# 166  Credit building, group financing, income valid...
# 167  executive search, Board advisory, Candidate id...
# 168  GPU Cloud provider for deep learning, Scalable...
#
#                                         bert_embedding  \
# 0    [0.086574286, 0.3509696, 0.42089736, 0.1412194...
# 1    [0.07241155, 0.22152354, 0.3112464, 0.23988587...
# 2    [0.39010373, 0.2946603, 0.5143907, 0.09073612,...
# 3    [0.31766137, 0.030905485, 0.44550037, 0.044492...
# 4    [-0.007811274, 0.0003206219, 0.6476342, 0.3873...
# ..                                                 ...
# 164  [-0.0034607535, 0.079632625, 0.31038848, 0.129...
# 165  [0.06851848, -0.0975014, 0.76486164, 0.1768996...
# 166  [-0.134429, -0.037543297, 0.094173804, 0.12651...
# 167  [-0.118605465, 0.18785885, 0.4804795, 0.246437...
# 168  [-0.15953614, 0.11833379, 0.5635602, 0.262942,...
#
#                              generated_cluster_label
# 0               Digital Media Creation & Enhancement
# 1               AI Software Development & Management
# 2               Digital Media Creation & Enhancement
# 3      Digital Entertainment & Relationship Services
# 4                        AI & Data Science Solutions
# ..                                               ...
# 164  Conversational AI/Customer Engagement Solutions
# 165  Conversational AI/Customer Engagement Solutions
# 166              Financial Services/Consumer Banking
# 167       Business Process Automation & Optimization
# 168                      AI & Data Science Solutions
#
# [169 rows x 34 columns]

# %%
list(sample_df.cluster_label)
# Out:
# [19,
#  4,
#  19,
#  22,
#  10,
#  21,
#  10,
#  12,
#  7,
#  19,
#  4,
#  10,
#  9,
#  13,
#  10,
#  3,
#  1,
#  9,
#  6,
#  4,
#  15,
#  17,
#  6,
#  22,
#  21,
#  9,
#  7,
#  7,
#  9,
#  3,
#  9,
#  10,
#  27,
#  8,
#  7,
#  15,
#  20,
#  5,
#  9,
#  3,
#  10,
#  10,
#  1,
#  7,
#  10,
#  3,
#  9,
#  4,
#  2,
#  2,
#  3,
#  21,
#  8,
#  9,
#  10,
#  3,
#  19,
#  14,
#  18,
#  10,
#  2,
#  13,
#  3,
#  5,
#  3,
#  10,
#  14,
#  13,
#  3,
#  10,
#  13,
#  5,
#  13,
#  9,
#  5,
#  3,
#  1,
#  4,
#  3,
#  16,
#  3,
#  3,
#  3,
#  25,
#  11,
#  5,
#  5,
#  26,
#  29,
#  9,
#  19,
#  5,
#  24,
#  23,
#  21,
#  3,
#  8,
#  3,
#  16,
#  3,
#  5,
#  3,
#  6,
#  3,
#  24,
#  18,
#  3,
#  2,
#  1,
#  19,
#  8,
#  22,
#  10,
#  1,
#  4,
#  23,
#  3,
#  26,
#  7,
#  22,
#  28,
#  9,
#  4,
#  16,
#  3,
#  5,
#  2,
#  3,
#  9,
#  5,
#  13,
#  17,
#  3,
#  10,
#  6,
#  2,
#  8,
#  9,
#  25,
#  5,
#  8,
#  14,
#  6,
#  18,
#  28,
#  15,
#  5,
#  9,
#  8,
#  9,
#  5,
#  14,
#  5,
#  23,
#  26,
#  12,
#  18,
#  2,
#  28,
#  1,
#  6,
#  20,
#  30,
#  26,
#  1,
#  1,
#  25,
#  3,
#  10]

# %%
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from scipy.cluster.hierarchy import linkage, fcluster
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler


# Convert embeddings column to a numpy array
embeddings = np.array(sample_df['embedding'].tolist())
cluster_labels = sample_df["generated_cluster_label"]
# Standardize the embeddings (optional but recommended)
scaler = StandardScaler()
embeddings_scaled = scaler.fit_transform(embeddings)

# Apply PCA to reduce dimensions to 2
pca = PCA(n_components=2)
embeddings_pca = pca.fit_transform(embeddings_scaled)

# Create a new DataFrame with the PCA results and cluster labels
pca_df = pd.DataFrame(data=embeddings_pca, columns=['PC1', 'PC2'])
pca_df['cluster_label'] = cluster_labels

# Plot the PCA results with cluster labels
plt.figure(figsize=(15, 6))
for label in np.unique(cluster_labels):
    subset = pca_df[pca_df['cluster_label'] == label]
    plt.scatter(subset['PC1'], subset['PC2'], label=f'Cluster {label}')
plt.title('PCA of Embeddings with Clustering')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()
plt.show()

# Display the DataFrame with the new cluster labels
print(sample_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'generated_cluster_label'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 12
#      10 # Convert embeddings column to a numpy array
#      11 embeddings = np.array(sample_df['embedding'].tolist())
# ---> 12 cluster_labels = sample_df["generated_cluster_label"]
#      13 # Standardize the embeddings (optional but recommended)
#      14 scaler = StandardScaler()
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'generated_cluster_label'

# %%
pca_df
# Out:
#            PC1        PC2                                    cluster_label
# 0   -13.310558   3.098237                                              NaN
# 1   -10.343402   0.871480  Conversational AI/Customer Engagement Solutions
# 2    -9.063376  -3.913245        Business Communication and Analysis Tools
# 3    -6.286851   2.557780       Business Process Automation & Optimization
# 4    10.599595  -8.421306             AI Software Development & Management
# ..         ...        ...                                              ...
# 164 -12.118962  -0.993006                                              NaN
# 165  -5.945734   3.635855                                              NaN
# 166   0.537042   3.995894                                              NaN
# 167   2.535824  11.011376                                              NaN
# 168   9.510317 -17.202169                                              NaN
#
# [169 rows x 3 columns]

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns
#probably that one point would pick another point to be close to it
embeddings = np.vstack(sample_df['embedding'].values)

# Apply t-SNE to the embeddings
tsne = TSNE(n_components=2, perplexity=30, n_iter=300)
tsne_results = tsne.fit_transform(embeddings)

# Add t-SNE results to the DataFrame
sample_df['tsne-2d-one'] = tsne_results[:, 0]
sample_df['tsne-2d-two'] = tsne_results[:, 1]

# Plotting the t-SNE result with labels
plt.figure(figsize=(20, 8))
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue="generated_cluster_label",
    palette=sns.color_palette("hsv", len(sample_df['generated_cluster_label'].unique())),
    data=sample_df,
    legend="full",
    alpha=0.8
)
plt.title('t-SNE visualization of Embeddings')
plt.show()
