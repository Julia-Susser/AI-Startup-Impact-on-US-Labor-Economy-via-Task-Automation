# %%
import pandas as pd
import numpy as np

# %%
ls
# Out:
# 2019/      2020/      2022/      2023/      2024/      EDA.ipynb  notes.txt

# %%
data = open("2023/data2023.txt").read().split("\n\n")
data = [[y for y in x.split("\n") if y != "" and "Logo" not in y] for x in data if x != ""]
bad = [[len(x),x] for x in data if len(x) != 22]
good2023 = [x for x in data if len(x) == 22]
len(good2023)
# Out:
# 4266

# %%
data = open("2024/data2024.txt").read().split("\n\n")
data = [[y for y in x.split("\n") if y != "" and "Logo" not in y] for x in data if x != ""]
bad = [[len(x),x] for x in data if len(x) != 22]
good2024 = [x for x in data if len(x) == 22]
len(good2024)
# Out:
# 987

# %%
labels = ["organization name","num employees", "founded date","description","industries","headquarters location","description","cb rank","postal code","headquarters region","website","actively hiring","linkedin","num articles","email","hub tag","phone num","num of sub org","industry groups","total funding amt","company type","estimated rev"]

# %%
dataset = good2023 + good2024

# %%
df = pd.DataFrame(dataset,columns=labels)

# %%
df.iloc[0]
# Out:
# organization name                                                     Pika
# num employees                                                         1-10
# founded date                                                          2023
# description              Pika is a startup that is developing an AI-pow...
# industries               Artificial Intelligence (AI), Generative AI, G...
# headquarters location                 Palo Alto, California, United States
# description              Pika is a startup that develops an AI-powered ...
# cb rank                                                                 78
# postal code                                                              —
# headquarters region      San Francisco Bay Area, Silicon Valley, West C...
# website                                                           pika.art
# actively hiring                                                          —
# linkedin                                                  View on LinkedIn
# num articles                                                             7
# email                                                                    —
# hub tag                                                                  —
# phone num                                                                —
# num of sub org                                                           —
# industry groups          Artificial Intelligence (AI), Data and Analyti...
# total funding amt                                             $135,000,000
# company type                                                    For Profit
# estimated rev                                                            —
# Name: 0, dtype: object

# %%
df
# Out:
#         organization name num employees  founded date  \
# 0                    Pika          1-10          2023
# 1           Contextual AI          1-10          2023
# 2               Liquid AI          1-10          2023
# 3                     Ava          1-10          2023
# 4              LlamaIndex          1-10          2023
# ...                   ...           ...           ...
# 5248              Solatis         11-50   Jun 5, 2024
# 5249  Degrees of Interest          1-10   Jun 6, 2024
# 5250        AI Compliance          1-10   Jun 6, 2024
# 5251              PawFoto          1-10   Jun 9, 2024
# 5252            SleepFast          1-10  Jun 10, 2024
#
#                                             description  \
# 0     Pika is a startup that is developing an AI-pow...
# 1     Contextual AI offers a pioneering approach to ...
# 2     Liquid AI is a developer of AI applications th...
# 3                              Ava is an AI dating app.
# 4     LlamaIndex is a simple, flexible data framewor...
# ...                                                 ...
# 5248  Solatis is an innovative AI technology tool de...
# 5249  Harnessing the power of AI to help law enforce...
# 5250  Many potential users of AI are held back by th...
# 5251  PawFoto operates and develops an online platfo...
# 5252  Sleeping Pills Alternative, to help you sleep ...
#
#                                              industries  \
# 0     Artificial Intelligence (AI), Generative AI, G...
# 1     Artificial Intelligence (AI), Generative AI, S...
# 2     Artificial Intelligence (AI), Generative AI, I...
# 3                                              Software
# 4                Artificial Intelligence (AI), Software
# ...                                                 ...
# 5248  Artificial Intelligence (AI), Information Tech...
# 5249      Artificial Intelligence (AI), Law Enforcement
# 5250  Artificial Intelligence (AI), Internet, Legal ...
# 5251                                                  —
# 5252                                                  —
#
#                          headquarters location  \
# 0         Palo Alto, California, United States
# 1     Mountain View, California, United States
# 2      Cambridge, Massachusetts, United States
# 3                 Paris, Ile-de-France, France
# 4     San Francisco, California, United States
# ...                                        ...
# 5248         New York, New York, United States
# 5249        Arlington, Virginia, United States
# 5250           Newark, Delaware, United States
# 5251                                         —
# 5252                                         —
#
#                                             description  cb rank postal code  \
# 0     Pika is a startup that develops an AI-powered ...       78           —
# 1     Contextual AI offers a pioneering approach to ...      219       94040
# 2     Liquid AI is a developer of AI applications th...      516       02142
# 3                              Ava is an AI dating app.      653           —
# 4     LlamaIndex is a simple, flexible data framewor...      814           —
# ...                                                 ...      ...         ...
# 5248  Solatis is an AI technology workforce tool tha...  370,592           —
# 5249   Visual analytics AI for criminal investigations.        —       22201
# 5250   Online Audit tools for AI compliance regulations        —       19713
# 5251  PawFoto operates and develops an online platfo...        —           —
# 5252  Sleeping Pills Alternative, to help you sleep ...        —           —
#
#                                     headquarters region  ...  \
# 0     San Francisco Bay Area, Silicon Valley, West C...  ...
# 1     San Francisco Bay Area, Silicon Valley, West C...  ...
# 2          Greater Boston Area, East Coast, New England  ...
# 3     European Union (EU), Europe, Middle East, and ...  ...
# 4        San Francisco Bay Area, West Coast, Western US  ...
# ...                                                 ...  ...
# 5248  Greater New York Area, East Coast, Northeaster...  ...
# 5249  Washington DC Metro Area, East Coast, Southern US  ...
# 5250  Greater Philadelphia Area, East Coast, Souther...  ...
# 5251                                                  —  ...
# 5252                                                  —  ...
#
#               linkedin num articles                       email hub tag  \
# 0     View on LinkedIn            7                           —       —
# 1     View on LinkedIn            4                           —       —
# 2     View on LinkedIn           12             ramin@liquid.ai       —
# 3     View on LinkedIn            —           clara@deeptime.io       —
# 4     View on LinkedIn           13                           —       —
# ...                ...          ...                         ...     ...
# 5248                 —            —            david@solatis.io       —
# 5249                 —            —  info@degreesofinterest.com       —
# 5250  View on LinkedIn            —          anneke@aicomply.ai       —
# 5251                 —            —             hey@pawfoto.com       —
# 5252  View on LinkedIn            —      sleepfast.io@gmail.com       —
#
#          phone num num of sub org  \
# 0                —              —
# 1                —              —
# 2                —              —
# 3                —              —
# 4                —              —
# ...            ...            ...
# 5248  201-329-4395              —
# 5249  703-540-0194              —
# 5250             —              —
# 5251             —              —
# 5252             —              —
#
#                                         industry groups total funding amt  \
# 0     Artificial Intelligence (AI), Data and Analyti...      $135,000,000
# 1     Artificial Intelligence (AI), Data and Analyti...       $20,000,000
# 2     Artificial Intelligence (AI), Data and Analyti...       $43,200,000
# 3                                              Software        $5,750,000
# 4     Artificial Intelligence (AI), Data and Analyti...        $8,500,000
# ...                                                 ...               ...
# 5248  Apps, Artificial Intelligence (AI), Data and A...                 —
# 5249  Artificial Intelligence (AI), Data and Analyti...                 —
# 5250  Artificial Intelligence (AI), Data and Analyti...                 —
# 5251                                                  —                 —
# 5252                                                  —                 —
#
#      company type estimated rev
# 0      For Profit             —
# 1      For Profit             —
# 2      For Profit   $1M to $10M
# 3      For Profit             —
# 4      For Profit   $1M to $10M
# ...           ...           ...
# 5248   For Profit             —
# 5249   For Profit             —
# 5250   For Profit             —
# 5251   For Profit             —
# 5252   For Profit             —
#
# [5253 rows x 22 columns]
