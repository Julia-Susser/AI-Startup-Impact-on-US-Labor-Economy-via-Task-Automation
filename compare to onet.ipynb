# %%
import pandas as pd
import numpy as np
from dotenv import load_dotenv
import os
from os import getenv
from openai import OpenAI


tf = pd.read_csv("./input/Task Statements.csv")
tf.head()
# Out:
#   O*NET-SOC Code             Title  Task ID  \
# 0     11-1011.00  Chief Executives     8823
# 1     11-1011.00  Chief Executives     8824
# 2     11-1011.00  Chief Executives     8827
# 3     11-1011.00  Chief Executives     8826
# 4     11-1011.00  Chief Executives     8834
#
#                                                 Task Task Type  \
# 0  Direct or coordinate an organization's financi...      Core
# 1  Confer with board members, organization offici...      Core
# 2  Prepare budgets for approval, including those ...      Core
# 3  Direct, plan, or implement policies, objective...      Core
# 4  Prepare or present reports concerning activiti...      Core
#
#    Incumbents Responding     Date Domain Source
# 0                   95.0  08/2023     Incumbent
# 1                   95.0  08/2023     Incumbent
# 2                   95.0  08/2023     Incumbent
# 3                   94.0  08/2023     Incumbent
# 4                   95.0  08/2023     Incumbent

# %%
tf = tf.sample(n=2000, random_state=1)
# Out:
#       O*NET-SOC Code                              Title  Task ID  \
# 0         11-1011.00                   Chief Executives     8823
# 1         11-1011.00                   Chief Executives     8824
# 2         11-1011.00                   Chief Executives     8827
# 3         11-1011.00                   Chief Executives     8826
# 4         11-1011.00                   Chief Executives     8834
# ...              ...                                ...      ...
# 19276     53-7121.00  Tank Car, Truck, and Ship Loaders    12807
# 19277     53-7121.00  Tank Car, Truck, and Ship Loaders    12804
# 19278     53-7121.00  Tank Car, Truck, and Ship Loaders    12803
# 19279     53-7121.00  Tank Car, Truck, and Ship Loaders    12805
# 19280     53-7121.00  Tank Car, Truck, and Ship Loaders    12810
#
#                                                     Task     Task Type  \
# 0      Direct or coordinate an organization's financi...          Core
# ...

# %%
#run task statements through berg
import pandas as pd
from transformers import BertTokenizer, BertModel
import torch

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')

def get_bert_embedding(text):
    inputs = tokenizer(text, return_tensors='pt')
    with torch.no_grad():
        outputs = model(**inputs)
        hidden_states = outputs.last_hidden_state
    sentence_embedding = torch.mean(hidden_states, dim=1).squeeze().numpy()
    return sentence_embedding
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 #run task statements through berg
#       2 import pandas as pd
# ----> 3 from transformers import BertTokenizer, BertModel
#       4 import torch
#       6 tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
#
# File /opt/anaconda3/lib/python3.11/site-packages/transformers/__init__.py:26
#      23 from typing import TYPE_CHECKING
#      25 # Check the dependencies satisfy the minimal versions required.
# ---> 26 from . import dependency_versions_check
#      27 from .utils import (
#      28     OptionalDependencyNotAvailable,
#      29     _LazyModule,
#    (...)
#      48     logging,
#      49 )
#      52 logger = logging.get_logger(__name__)  # pylint: disable=invalid-name
#
# File /opt/anaconda3/lib/python3.11/site-packages/transformers/dependency_versions_check.py:16
# ...

# %%
tf['bert_embedding'] = tf['Task'].apply(get_bert_embedding)

# %%
sample_df['bert_embedding'] = sample_df['generated_description'].apply(get_bert_embedding)
sample_df.to_csv('./output/sample_df_with_bert_embeddings.csv', index=False)
print(sample_df.head())
